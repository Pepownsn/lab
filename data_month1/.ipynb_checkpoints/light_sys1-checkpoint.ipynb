# %% [markdown]
# # data_TIMELInE
# ### ระบบหลอดไฟส่องสว่าง | LED 7 Watt |

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random



d =31
time_a = pd.date_range('2016-10-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-10-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####### set databases to empty #########
query_empty = """truncate table data_timeline.light_sys1""" 
c.execute(query_empty)
print "data_timeline.light_sys1 are Empty!!! \n"

query = "SELECT watt FROM collected_info.15_light_sys WHERE no >= '%s'   AND no <= '%s'; "% (0,1500)
df = pd.read_sql(query, conn)

## set no.of light = 2:ห้องน้ำ || 4:ห้องนอน || 2:ห้องครัว || 4 ห้องนั่งเล่น  


def bed():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(0, 59)
    random_bed =   ['20'] * 45 + ['21'] * 50  + ['22'] * 5  
    on_bed = random.choice(random_bed) 
    
    if 0 < duration_sec <= 15 :
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
        
    start_bed = (int(on_bed)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on lamp at bedroom on",on_bed,":",duration_min,":",duration_sec,"equal to", start_bed,"items"
           
    duration_hour1 = ['1'] * 5 + ['2'] * 15 + ['3'] * 42  + ['4'] * 38 
    duration_hour = int(random.choice(duration_hour1))    
    duration_min =  random.randint(0, 59)
    duration_sec =  random.randint(0, 59)
    seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
    no_item_bed = seconds/15
    print "consuming the lamp", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item_bed,"items\n"
    return (start_bed,no_item_bed)

def living():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(0, 59)
    random_living = ['17'] * 25 + ['18'] * 55 + ['19'] * 20
    on_living = random.choice(random_living)   
                    
    if 0 < duration_sec <= 15:
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
    start_living = (int(on_living)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on lamp at living-room on",on_living,":",duration_min,":",duration_sec,"equal to", start_living,"items"
           
    duration_hour1 =  ['2'] * 5 + ['3'] * 65 + ['4'] *25 + ['5'] * 5
    duration_hour = int(random.choice(duration_hour1))        
    duration_min =  random.randint(0, 59)
    duration_sec =  random.randint(0, 59)
    seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
    no_item_living = seconds/15
    print "consuming the lamp", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item_living,"items\n"
    return (start_living,no_item_living)

def kitchen():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(0, 59)
    random_kitc = ['17'] * 60 + ['18'] * 25 + ['19'] * 10  + ['20'] * 5  
    on_kitc = random.choice(random_kitc)     
    
    if 0 < duration_sec <= 15:
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
    start_kitc = (int(on_kitc)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on lamp at kitchen on",on_kitc,":",duration_min,":",duration_sec,"equal to", start_kitc,"items"
           
    duration_hour1 = ['1'] * 60 + ['2'] * 40
    duration_hour = int(random.choice(duration_hour1))      
    duration_min =  random.randint(0, 59)
    duration_sec =  random.randint(0, 59)
    seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
    no_item_kitc= seconds/15
    print "consuming the lamp", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item_kitc,"items\n"
    return (start_kitc,no_item_kitc)


j = 0
days = 0

while (j <= (5760*d)-1): 
            
    if (j%5760 == 0):
        print "\nDays :",days ,":",time_b[j].strftime('%a')
        days +=1        
        turn_bed = bed()
        turn_living = living()
        turn_kitchen = kitchen()
    
    if int(turn_bed[0])+(5760*(days-1) )<= j <= (int(turn_bed[0])+int(turn_bed[1]))+(5760*(days-1) )and int(turn_kitchen[0])+(5760*(days-1)) <= j <= (int(turn_kitchen[0])+int(turn_kitchen[1]))+(5760*(days-1))and int(turn_living[0])+(5760*(days-1)) <= j <= (int(turn_living[0])+int(turn_living[1]))+(5760*(days-1)):
        c.execute("INSERT INTO data_timeline.light_sys1 (Timestamp, watt_bed,watt_living, watt_kitc) VALUES (%s, %s, %s, %s)",(time_b[j],4,4,2))
        
    elif  int(turn_bed[0])+(5760*(days-1)) <= j <= (int(turn_bed[0])+int(turn_bed[1]))+(5760*(days-1)) and int(turn_living[0])+(5760*(days-1)) <= j <= (int(turn_living[0])+int(turn_living[1]))+(5760*(days-1)):
        c.execute("INSERT INTO data_timeline.light_sys1 (Timestamp, watt_bed,watt_living, watt_kitc) VALUES (%s, %s, %s, %s)",(time_b[j],4,4,0))      
        
    elif  int(turn_kitchen[0])+(5760*(days-1)) <= j <= (int(turn_kitchen[0])+int(turn_kitchen[1]))+(5760*(days-1)) and int(turn_living[0])+(5760*(days-1)) <= j <= (int(turn_living[0])+int(turn_living[1]))+(5760*(days-1)):
        c.execute("INSERT INTO data_timeline.light_sys1 (Timestamp, watt_bed,watt_living, watt_kitc) VALUES (%s, %s, %s, %s)",(time_b[j],0,4,2))
        
    elif  int(turn_bed[0])+(5760*(days-1)) <= j <=(int(turn_bed[0])+int(turn_bed[1]))+(5760*(days-1)) and int(turn_kitchen[0])+(5760*(days-1)) <= j <= (int(turn_kitchen[0])+int(turn_kitchen[1]))+(5760*(days-1)):
        c.execute("INSERT INTO data_timeline.light_sys1(Timestamp, watt_bed,watt_living, watt_kitc) VALUES (%s, %s, %s, %s)",(time_b[j],4,0,2))
      
    elif  int(turn_bed[0])+(5760*(days-1)) <= j <= (int(turn_bed[0])+int(turn_bed[1]))+(5760*(days-1)):
        c.execute("INSERT INTO data_timeline.light_sys1 (Timestamp, watt_bed,watt_living, watt_kitc) VALUES (%s, %s, %s, %s)",(time_b[j],4,0,0))
        
    elif int(turn_living[0])+(5760*(days-1) )<= j <= (int(turn_living[0])+int(turn_living[1]))+(5760*(days-1)):
        c.execute("INSERT INTO data_timeline.light_sys1 (Timestamp, watt_bed,watt_living, watt_kitc) VALUES (%s, %s, %s, %s)",(time_b[j],0,4,0))
        
    elif int(turn_kitchen[0]) +(5760*(days-1))<= j <= (int(turn_kitchen[0])+int(turn_kitchen[1]))+(5760*(days-1)):
        c.execute("INSERT INTO data_timeline.light_sys1 (Timestamp, watt_bed,watt_living, watt_kitc) VALUES (%s, %s, %s, %s)",(time_b[j],0,0,2))
    else:
        c.execute("INSERT INTO data_timeline.light_sys1 (Timestamp, watt_bed,watt_living, watt_kitc) VALUES (%s, %s, %s, %s)",(time_b[j],0,0,0))
            
    j += 1
    conn.commit()
    

print "DONE!"
# Out:
# data_timeline.light_sys1 are Empty!!!
#
#
# Days : 0 : Sat
# time to turn-on lamp at bedroom on 20 : 29 : 56 equal to 4919 items
# consuming the lamp 2 hours 44 minutes 57 seconds that equal to 9897 seconds or 659 items
#
# time to turn-on lamp at living-room on 17 : 34 : 58 equal to 4219 items
# consuming the lamp 3 hours 40 minutes 40 seconds that equal to 13240 seconds or 882 items
#
# time to turn-on lamp at kitchen on 18 : 0 : 52 equal to 4323 items
# consuming the lamp 1 hours 2 minutes 1 seconds that equal to 3721 seconds or 248 items
#
#
# Days : 1 : Sun
# time to turn-on lamp at bedroom on 21 : 21 : 39 equal to 5126 items
# consuming the lamp 1 hours 3 minutes 44 seconds that equal to 3824 seconds or 254 items
#
# time to turn-on lamp at living-room on 17 : 59 : 42 equal to 4318 items
# consuming the lamp 5 hours 25 minutes 1 seconds that equal to 19501 seconds or 1300 items
#
# time to turn-on lamp at kitchen on 18 : 54 : 21 equal to 4537 items
# consuming the lamp 2 hours 5 minutes 55 seconds that equal to 7555 seconds or 503 items
#
#
# Days : 2 : Mon
# time to turn-on lamp at bedroom on 21 : 21 : 0 equal to 5127 items
# consuming the lamp 4 hours 44 minutes 39 seconds that equal to 17079 seconds or 1138 items
#
# time to turn-on lamp at living-room on 19 : 5 : 38 equal to 4582 items
# consuming the lamp 5 hours 12 minutes 34 seconds that equal to 18754 seconds or 1250 items
#
# time to turn-on lamp at kitchen on 17 : 43 : 21 equal to 4253 items
# consuming the lamp 1 hours 20 minutes 5 seconds that equal to 4805 seconds or 320 items
#
#
# Days : 3 : Tue
# time to turn-on lamp at bedroom on 20 : 49 : 58 equal to 4999 items
# consuming the lamp 4 hours 9 minutes 43 seconds that equal to 14983 seconds or 998 items
#
# time to turn-on lamp at living-room on 19 : 23 : 20 equal to 4653 items
# consuming the lamp 4 hours 18 minutes 36 seconds that equal to 15516 seconds or 1034 items
#
# time to turn-on lamp at kitchen on 17 : 59 : 35 equal to 4318 items
# consuming the lamp 1 hours 32 minutes 42 seconds that equal to 5562 seconds or 370 items
#
#
# Days : 4 : Wed
# time to turn-on lamp at bedroom on 21 : 17 : 24 equal to 5109 items
# consuming the lamp 4 hours 58 minutes 32 seconds that equal to 17912 seconds or 1194 items
#
# time to turn-on lamp at living-room on 18 : 3 : 19 equal to 4333 items
# consuming the lamp 3 hours 50 minutes 51 seconds that equal to 13851 seconds or 923 items
#
# time to turn-on lamp at kitchen on 18 : 30 : 33 equal to 4442 items
# consuming the lamp 2 hours 31 minutes 53 seconds that equal to 9113 seconds or 607 items
#
#
# Days : 5 : Thu
# time to turn-on lamp at bedroom on 20 : 18 : 10 equal to 4872 items
# consuming the lamp 4 hours 39 minutes 44 seconds that equal to 16784 seconds or 1118 items
#
# time to turn-on lamp at living-room on 18 : 3 : 42 equal to 4334 items
# consuming the lamp 3 hours 2 minutes 54 seconds that equal to 10974 seconds or 731 items
#
# time to turn-on lamp at kitchen on 17 : 45 : 6 equal to 4260 items
# consuming the lamp 1 hours 58 minutes 44 seconds that equal to 7124 seconds or 474 items
#
#
# Days : 6 : Fri
# time to turn-on lamp at bedroom on 20 : 46 : 16 equal to 4985 items
# consuming the lamp 2 hours 21 minutes 53 seconds that equal to 8513 seconds or 567 items
#
# time to turn-on lamp at living-room on 17 : 41 : 39 equal to 4246 items
# consuming the lamp 3 hours 54 minutes 52 seconds that equal to 14092 seconds or 939 items
#
# time to turn-on lamp at kitchen on 18 : 48 : 4 equal to 4512 items
# consuming the lamp 2 hours 7 minutes 58 seconds that equal to 7678 seconds or 511 items
#
#
# Days : 7 : Sat
# time to turn-on lamp at bedroom on 22 : 46 : 2 equal to 5464 items
# consuming the lamp 4 hours 57 minutes 28 seconds that equal to 17848 seconds or 1189 items
#
# time to turn-on lamp at living-room on 18 : 33 : 25 equal to 4453 items
# consuming the lamp 2 hours 53 minutes 47 seconds that equal to 10427 seconds or 695 items
#
# time to turn-on lamp at kitchen on 17 : 4 : 24 equal to 4097 items
# consuming the lamp 2 hours 16 minutes 3 seconds that equal to 8163 seconds or 544 items
#
#
# Days : 8 : Sun
# time to turn-on lamp at bedroom on 21 : 7 : 7 equal to 5068 items
# consuming the lamp 4 hours 47 minutes 35 seconds that equal to 17255 seconds or 1150 items
#
# time to turn-on lamp at living-room on 17 : 45 : 25 equal to 4261 items
# consuming the lamp 3 hours 20 minutes 47 seconds that equal to 12047 seconds or 803 items
#
# time to turn-on lamp at kitchen on 17 : 50 : 6 equal to 4280 items
# consuming the lamp 1 hours 59 minutes 49 seconds that equal to 7189 seconds or 479 items
#
#
# Days : 9 : Mon
# time to turn-on lamp at bedroom on 21 : 6 : 23 equal to 5065 items
# consuming the lamp 4 hours 49 minutes 28 seconds that equal to 17368 seconds or 1157 items
#
# time to turn-on lamp at living-room on 18 : 42 : 1 equal to 4488 items
# consuming the lamp 5 hours 6 minutes 21 seconds that equal to 18381 seconds or 1225 items
#
# time to turn-on lamp at kitchen on 19 : 49 : 53 equal to 4759 items
# consuming the lamp 2 hours 45 minutes 15 seconds that equal to 9915 seconds or 661 items
#
#
# Days : 10 : Tue
# time to turn-on lamp at bedroom on 21 : 37 : 46 equal to 5191 items
# consuming the lamp 3 hours 49 minutes 15 seconds that equal to 13755 seconds or 917 items
#
# time to turn-on lamp at living-room on 17 : 7 : 15 equal to 4108 items
# consuming the lamp 3 hours 17 minutes 5 seconds that equal to 11825 seconds or 788 items
#
# time to turn-on lamp at kitchen on 17 : 24 : 39 equal to 4178 items
# consuming the lamp 2 hours 44 minutes 36 seconds that equal to 9876 seconds or 658 items
#
#
# Days : 11 : Wed
# time to turn-on lamp at bedroom on 20 : 19 : 58 equal to 4879 items
# consuming the lamp 4 hours 39 minutes 4 seconds that equal to 16744 seconds or 1116 items
#
# time to turn-on lamp at living-room on 18 : 23 : 30 equal to 4413 items
# consuming the lamp 3 hours 43 minutes 18 seconds that equal to 13398 seconds or 893 items
#
# time to turn-on lamp at kitchen on 17 : 48 : 48 equal to 4275 items
# consuming the lamp 2 hours 6 minutes 3 seconds that equal to 7563 seconds or 504 items
#
#
# Days : 12 : Thu
# time to turn-on lamp at bedroom on 20 : 34 : 55 equal to 4939 items
# consuming the lamp 4 hours 58 minutes 5 seconds that equal to 17885 seconds or 1192 items
#
# time to turn-on lamp at living-room on 18 : 24 : 28 equal to 4417 items
# consuming the lamp 3 hours 56 minutes 58 seconds that equal to 14218 seconds or 947 items
#
# time to turn-on lamp at kitchen on 19 : 57 : 43 equal to 4790 items
# consuming the lamp 2 hours 21 minutes 53 seconds that equal to 8513 seconds or 567 items
#
#
# Days : 13 : Fri
# time to turn-on lamp at bedroom on 20 : 18 : 6 equal to 4872 items
# consuming the lamp 3 hours 9 minutes 6 seconds that equal to 11346 seconds or 756 items
#
# time to turn-on lamp at living-room on 17 : 28 : 28 equal to 4193 items
# consuming the lamp 3 hours 27 minutes 35 seconds that equal to 12455 seconds or 830 items
#
# time to turn-on lamp at kitchen on 19 : 48 : 42 equal to 4754 items
# consuming the lamp 2 hours 51 minutes 2 seconds that equal to 10262 seconds or 684 items
#
#
# Days : 14 : Sat
# time to turn-on lamp at bedroom on 21 : 54 : 34 equal to 5258 items
# consuming the lamp 4 hours 14 minutes 9 seconds that equal to 15249 seconds or 1016 items
#
# time to turn-on lamp at living-room on 17 : 19 : 28 equal to 4157 items
# consuming the lamp 3 hours 6 minutes 25 seconds that equal to 11185 seconds or 745 items
#
# time to turn-on lamp at kitchen on 18 : 26 : 17 equal to 4425 items
# consuming the lamp 2 hours 22 minutes 8 seconds that equal to 8528 seconds or 568 items
#
#
# Days : 15 : Sun
# time to turn-on lamp at bedroom on 21 : 50 : 26 equal to 5241 items
# consuming the lamp 4 hours 21 minutes 15 seconds that equal to 15675 seconds or 1045 items
#
# time to turn-on lamp at living-room on 18 : 40 : 30 equal to 4481 items
# consuming the lamp 2 hours 6 minutes 56 seconds that equal to 7616 seconds or 507 items
#
# time to turn-on lamp at kitchen on 17 : 24 : 46 equal to 4179 items
# consuming the lamp 2 hours 39 minutes 9 seconds that equal to 9549 seconds or 636 items
#
#
# Days : 16 : Mon
# time to turn-on lamp at bedroom on 21 : 20 : 41 equal to 5122 items
# consuming the lamp 4 hours 35 minutes 51 seconds that equal to 16551 seconds or 1103 items
#
# time to turn-on lamp at living-room on 18 : 29 : 28 equal to 4437 items
# consuming the lamp 5 hours 29 minutes 47 seconds that equal to 19787 seconds or 1319 items
#
# time to turn-on lamp at kitchen on 17 : 23 : 7 equal to 4172 items
# consuming the lamp 2 hours 53 minutes 25 seconds that equal to 10405 seconds or 693 items
#
#
# Days : 17 : Tue
# time to turn-on lamp at bedroom on 20 : 59 : 29 equal to 5037 items
# consuming the lamp 2 hours 24 minutes 3 seconds that equal to 8643 seconds or 576 items
#
# time to turn-on lamp at living-room on 18 : 5 : 45 equal to 4342 items
# consuming the lamp 2 hours 18 minutes 11 seconds that equal to 8291 seconds or 552 items
#
# time to turn-on lamp at kitchen on 17 : 10 : 56 equal to 4123 items
# consuming the lamp 1 hours 54 minutes 41 seconds that equal to 6881 seconds or 458 items
#
#
# Days : 18 : Wed
# time to turn-on lamp at bedroom on 20 : 22 : 55 equal to 4891 items
# consuming the lamp 4 hours 58 minutes 16 seconds that equal to 17896 seconds or 1193 items
#
# time to turn-on lamp at living-room on 17 : 59 : 21 equal to 4317 items
# consuming the lamp 4 hours 10 minutes 48 seconds that equal to 15048 seconds or 1003 items
#
# time to turn-on lamp at kitchen on 17 : 11 : 33 equal to 4126 items
# consuming the lamp 2 hours 4 minutes 7 seconds that equal to 7447 seconds or 496 items
#
#
# Days : 19 : Thu
# time to turn-on lamp at bedroom on 21 : 3 : 33 equal to 5054 items
# consuming the lamp 3 hours 25 minutes 3 seconds that equal to 12303 seconds or 820 items
#
# time to turn-on lamp at living-room on 18 : 57 : 27 equal to 4549 items
# consuming the lamp 3 hours 57 minutes 0 seconds that equal to 14220 seconds or 948 items
#
# time to turn-on lamp at kitchen on 17 : 14 : 30 equal to 4137 items
# consuming the lamp 2 hours 18 minutes 57 seconds that equal to 8337 seconds or 555 items
#
#
# Days : 20 : Fri
# time to turn-on lamp at bedroom on 21 : 20 : 31 equal to 5122 items
# consuming the lamp 4 hours 36 minutes 43 seconds that equal to 16603 seconds or 1106 items
#
# time to turn-on lamp at living-room on 18 : 17 : 28 equal to 4389 items
# consuming the lamp 3 hours 14 minutes 10 seconds that equal to 11650 seconds or 776 items
#
# time to turn-on lamp at kitchen on 17 : 56 : 12 equal to 4304 items
# consuming the lamp 1 hours 42 minutes 22 seconds that equal to 6142 seconds or 409 items
#
#
# Days : 21 : Sat
# time to turn-on lamp at bedroom on 21 : 3 : 58 equal to 5055 items
# consuming the lamp 3 hours 52 minutes 44 seconds that equal to 13964 seconds or 930 items
#
# time to turn-on lamp at living-room on 18 : 6 : 30 equal to 4345 items
# consuming the lamp 3 hours 36 minutes 35 seconds that equal to 12995 seconds or 866 items
#
# time to turn-on lamp at kitchen on 18 : 29 : 0 equal to 4439 items
# consuming the lamp 2 hours 4 minutes 53 seconds that equal to 7493 seconds or 499 items
#
#
# Days : 22 : Sun
# time to turn-on lamp at bedroom on 20 : 10 : 21 equal to 4841 items
# consuming the lamp 4 hours 34 minutes 13 seconds that equal to 16453 seconds or 1096 items
#
# time to turn-on lamp at living-room on 19 : 27 : 9 equal to 4668 items
# consuming the lamp 5 hours 31 minutes 28 seconds that equal to 19888 seconds or 1325 items
#
# time to turn-on lamp at kitchen on 18 : 0 : 55 equal to 4323 items
# consuming the lamp 2 hours 16 minutes 9 seconds that equal to 8169 seconds or 544 items
#
#
# Days : 23 : Mon
# time to turn-on lamp at bedroom on 21 : 34 : 57 equal to 5179 items
# consuming the lamp 3 hours 30 minutes 54 seconds that equal to 12654 seconds or 843 items
#
# time to turn-on lamp at living-room on 19 : 23 : 9 equal to 4652 items
# consuming the lamp 3 hours 22 minutes 27 seconds that equal to 12147 seconds or 809 items
#
# time to turn-on lamp at kitchen on 20 : 22 : 10 equal to 4888 items
# consuming the lamp 2 hours 48 minutes 19 seconds that equal to 10099 seconds or 673 items
#
#
# Days : 24 : Tue
# time to turn-on lamp at bedroom on 20 : 35 : 42 equal to 4942 items
# consuming the lamp 4 hours 43 minutes 54 seconds that equal to 17034 seconds or 1135 items
#
# time to turn-on lamp at living-room on 17 : 19 : 28 equal to 4157 items
# consuming the lamp 3 hours 3 minutes 34 seconds that equal to 11014 seconds or 734 items
#
# time to turn-on lamp at kitchen on 17 : 23 : 53 equal to 4175 items
# consuming the lamp 2 hours 2 minutes 25 seconds that equal to 7345 seconds or 489 items
#
#
# Days : 25 : Wed
# time to turn-on lamp at bedroom on 21 : 7 : 43 equal to 5070 items
# consuming the lamp 4 hours 37 minutes 51 seconds that equal to 16671 seconds or 1111 items
#
# time to turn-on lamp at living-room on 19 : 42 : 23 equal to 4729 items
# consuming the lamp 4 hours 1 minutes 54 seconds that equal to 14514 seconds or 967 items
#
# time to turn-on lamp at kitchen on 17 : 14 : 32 equal to 4138 items
# consuming the lamp 1 hours 22 minutes 49 seconds that equal to 4969 seconds or 331 items
#
#
# Days : 26 : Thu
# time to turn-on lamp at bedroom on 20 : 27 : 59 equal to 4911 items
# consuming the lamp 3 hours 21 minutes 48 seconds that equal to 12108 seconds or 807 items
#
# time to turn-on lamp at living-room on 17 : 24 : 11 equal to 4176 items
# consuming the lamp 3 hours 44 minutes 1 seconds that equal to 13441 seconds or 896 items
#
# time to turn-on lamp at kitchen on 18 : 17 : 25 equal to 4389 items
# consuming the lamp 2 hours 15 minutes 13 seconds that equal to 8113 seconds or 540 items
#
#
# Days : 27 : Fri
# time to turn-on lamp at bedroom on 21 : 29 : 16 equal to 5157 items
# consuming the lamp 3 hours 6 minutes 50 seconds that equal to 11210 seconds or 747 items
#
# time to turn-on lamp at living-room on 18 : 12 : 46 equal to 4371 items
# consuming the lamp 3 hours 41 minutes 45 seconds that equal to 13305 seconds or 887 items
#
# time to turn-on lamp at kitchen on 17 : 2 : 40 equal to 4090 items
# consuming the lamp 1 hours 10 minutes 40 seconds that equal to 4240 seconds or 282 items
#
#
# Days : 28 : Sat
# time to turn-on lamp at bedroom on 21 : 45 : 16 equal to 5221 items
# consuming the lamp 4 hours 36 minutes 6 seconds that equal to 16566 seconds or 1104 items
#
# time to turn-on lamp at living-room on 18 : 41 : 56 equal to 4487 items
# consuming the lamp 3 hours 41 minutes 49 seconds that equal to 13309 seconds or 887 items
#
# time to turn-on lamp at kitchen on 17 : 47 : 25 equal to 4269 items
# consuming the lamp 2 hours 23 minutes 46 seconds that equal to 8626 seconds or 575 items
#
#
# Days : 29 : Sun
# time to turn-on lamp at bedroom on 20 : 51 : 17 equal to 5005 items
# consuming the lamp 3 hours 40 minutes 53 seconds that equal to 13253 seconds or 883 items
#
# time to turn-on lamp at living-room on 19 : 35 : 14 equal to 4700 items
# consuming the lamp 3 hours 47 minutes 10 seconds that equal to 13630 seconds or 908 items
#
# time to turn-on lamp at kitchen on 17 : 13 : 52 equal to 4135 items
# consuming the lamp 2 hours 46 minutes 19 seconds that equal to 9979 seconds or 665 items
#
#
# Days : 30 : Mon
# time to turn-on lamp at bedroom on 21 : 49 : 53 equal to 5239 items
# consuming the lamp 4 hours 22 minutes 7 seconds that equal to 15727 seconds or 1048 items
#
# time to turn-on lamp at living-room on 18 : 21 : 34 equal to 4406 items
# consuming the lamp 3 hours 2 minutes 41 seconds that equal to 10961 seconds or 730 items
#
# time to turn-on lamp at kitchen on 19 : 28 : 11 equal to 4672 items
# consuming the lamp 1 hours 54 minutes 10 seconds that equal to 6850 seconds or 456 items
#
# DONE!

# %%
import matplotlib.pyplot as plt
# %matplotlib inline  


# query = "SELECT watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
query = "SELECT * FROM data_timeline.light_sys1 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[4000],time_b[6500])
df = pd.read_sql(query, conn, index_col=['Timestamp'])
fig, ax = plt.subplots()
ax.set_title('data_timeline.IRON')
df.plot(ax=ax )
plt.show()
df.to_csv('file.csv')
