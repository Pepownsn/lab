# %% [markdown]
# # data_TIMELInE
# ### COMPUTER | psu 600W + LED 23" |

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random


d = 31
time_a = pd.date_range('2016-10-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-10-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()


####### set databases to empty #########
query_empty = """truncate table data_timeline.Computer""" 
c.execute(query_empty)
print "data_timeline.Computer are Empty!!! \n"

query = "SELECT watt FROM collected_info.4_Computer WHERE no >= '%s'   AND no <= '%s'; "% (0,1240)
df = pd.read_sql(query, conn)
# print df.watt[5]

#### Random the turning-on time appliances
def rand_turnon():
    duration_sec =  random.randint(10, 59)
    duration_min =  random.randint(10, 59)
    duration_hour1 = ['18'] * 4+['19'] * 6 + ['20'] * 46 + ['21'] * 41 +['22'] * 3     #SET Start 7-10 pm.
    duration_hour = random.choice(duration_hour1)     
    if 0 < duration_sec <= 15:
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
    off_item = (int(duration_hour)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on appliacne on",duration_hour,":",duration_min,":",duration_sec,"equal to",off_item,"items"
    return off_item

 
#### Random the off-duration appliances 
def rand_duration():
    duration_sec =  random.randint(10, 59)
    duration_min =  random.randint(10, 59)
    duration_hour1 = ['1'] * 9 + ['2'] * 59 + ['3'] * 30 +['4'] * 1+['5'] * 1   
    duration_hour = random.choice(duration_hour1)   
    seconds = (int(duration_hour)*3600)+(duration_min*60)+duration_sec
    no_item = seconds/15
    print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items"
    return no_item

days = 0
j = 0
i = 0
print "\nDays :",days ,":",time_b[j].strftime('%a')
off_item = rand_turnon()  
no_item = rand_duration()  

while (j <= (5760*d)-1):  
    c.execute("INSERT INTO data_timeline.Computer (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
    conn.commit()
    j += 1 
    
    while (off_item+(5760*(days)) <= j <= (no_item+off_item)+(5760*(days))):                   
        c.execute("INSERT INTO data_timeline.Computer (Timestamp, watt) VALUES (%s, %s)",(time_b[j],df.watt[i]))
        conn.commit()
        i += 1 
        j += 1
        if (j == (no_item+off_item)+(5760*(days))):
            days +=1
            print "\nDays :",days ,":",time_b[j].strftime('%a')
            off_item = rand_turnon()  
            no_item = rand_duration() 
            i= 0   
                    
print "DONE!"
# Out:
# data_timeline.Computer are Empty!!!
#
#
# Days : 0 : Sat
# time to turn-on appliacne on 20 : 54 : 26 equal to 5017 items
# consuming the appliance 2 hours 13 minutes 42 seconds that equal to 8022 seconds or 534 items
#
# Days : 1 : Sat
# time to turn-on appliacne on 20 : 51 : 55 equal to 5007 items
# consuming the appliance 2 hours 18 minutes 56 seconds that equal to 8336 seconds or 555 items
#
# Days : 2 : Sun
# time to turn-on appliacne on 20 : 30 : 51 equal to 4923 items
# consuming the appliance 2 hours 17 minutes 51 seconds that equal to 8271 seconds or 551 items
#
# Days : 3 : Mon
# time to turn-on appliacne on 21 : 33 : 11 equal to 5172 items
# consuming the appliance 3 hours 25 minutes 30 seconds that equal to 12330 seconds or 822 items
#
# Days : 4 : Wed
# time to turn-on appliacne on 21 : 36 : 28 equal to 5185 items
# consuming the appliance 2 hours 10 minutes 11 seconds that equal to 7811 seconds or 520 items
#
# Days : 5 : Wed
# time to turn-on appliacne on 21 : 12 : 52 equal to 5091 items
# consuming the appliance 2 hours 28 minutes 50 seconds that equal to 8930 seconds or 595 items
#
# Days : 6 : Thu
# time to turn-on appliacne on 21 : 20 : 54 equal to 5123 items
# consuming the appliance 2 hours 34 minutes 37 seconds that equal to 9277 seconds or 618 items
#
# Days : 7 : Fri
# time to turn-on appliacne on 21 : 45 : 37 equal to 5222 items
# consuming the appliance 3 hours 58 minutes 46 seconds that equal to 14326 seconds or 955 items
#
# Days : 8 : Sun
# time to turn-on appliacne on 21 : 20 : 31 equal to 5122 items
# consuming the appliance 1 hours 53 minutes 53 seconds that equal to 6833 seconds or 455 items
#
# Days : 9 : Sun
# time to turn-on appliacne on 21 : 13 : 27 equal to 5093 items
# consuming the appliance 3 hours 14 minutes 23 seconds that equal to 11663 seconds or 777 items
#
# Days : 10 : Tue
# time to turn-on appliacne on 20 : 14 : 52 equal to 4859 items
# consuming the appliance 2 hours 11 minutes 10 seconds that equal to 7870 seconds or 524 items
#
# Days : 11 : Tue
# time to turn-on appliacne on 21 : 30 : 39 equal to 5162 items
# consuming the appliance 2 hours 45 minutes 26 seconds that equal to 9926 seconds or 661 items
#
# Days : 12 : Thu
# time to turn-on appliacne on 21 : 25 : 16 equal to 5141 items
# consuming the appliance 2 hours 28 minutes 41 seconds that equal to 8921 seconds or 594 items
#
# Days : 13 : Thu
# time to turn-on appliacne on 20 : 28 : 57 equal to 4915 items
# consuming the appliance 3 hours 17 minutes 23 seconds that equal to 11843 seconds or 789 items
#
# Days : 14 : Fri
# time to turn-on appliacne on 21 : 44 : 27 equal to 5217 items
# consuming the appliance 2 hours 58 minutes 55 seconds that equal to 10735 seconds or 715 items
#
# Days : 15 : Sun
# time to turn-on appliacne on 19 : 20 : 18 equal to 4641 items
# consuming the appliance 2 hours 41 minutes 52 seconds that equal to 9712 seconds or 647 items
#
# Days : 16 : Sun
# time to turn-on appliacne on 20 : 30 : 38 equal to 4922 items
# consuming the appliance 3 hours 18 minutes 35 seconds that equal to 11915 seconds or 794 items
#
# Days : 17 : Mon
# time to turn-on appliacne on 21 : 57 : 42 equal to 5270 items
# consuming the appliance 2 hours 47 minutes 49 seconds that equal to 10069 seconds or 671 items
#
# Days : 18 : Wed
# time to turn-on appliacne on 20 : 19 : 56 equal to 4879 items
# consuming the appliance 2 hours 33 minutes 38 seconds that equal to 9218 seconds or 614 items
#
# Days : 19 : Wed
# time to turn-on appliacne on 21 : 35 : 12 equal to 5180 items
# consuming the appliance 2 hours 10 minutes 42 seconds that equal to 7842 seconds or 522 items
#
# Days : 20 : Thu
# time to turn-on appliacne on 20 : 44 : 28 equal to 4977 items
# consuming the appliance 2 hours 11 minutes 51 seconds that equal to 7911 seconds or 527 items
#
# Days : 21 : Fri
# time to turn-on appliacne on 21 : 46 : 42 equal to 5226 items
# consuming the appliance 2 hours 59 minutes 43 seconds that equal to 10783 seconds or 718 items
#
# Days : 22 : Sun
# time to turn-on appliacne on 21 : 54 : 31 equal to 5258 items
# consuming the appliance 3 hours 12 minutes 21 seconds that equal to 11541 seconds or 769 items
#
# Days : 23 : Mon
# time to turn-on appliacne on 21 : 42 : 48 equal to 5211 items
# consuming the appliance 3 hours 20 minutes 52 seconds that equal to 12052 seconds or 803 items
#
# Days : 24 : Tue
# time to turn-on appliacne on 21 : 20 : 31 equal to 5122 items
# consuming the appliance 2 hours 27 minutes 49 seconds that equal to 8869 seconds or 591 items
#
# Days : 25 : Tue
# time to turn-on appliacne on 20 : 38 : 56 equal to 4955 items
# consuming the appliance 3 hours 13 minutes 33 seconds that equal to 11613 seconds or 774 items
#
# Days : 26 : Wed
# time to turn-on appliacne on 21 : 19 : 44 equal to 5118 items
# consuming the appliance 2 hours 30 minutes 52 seconds that equal to 9052 seconds or 603 items
#
# Days : 27 : Thu
# time to turn-on appliacne on 20 : 22 : 12 equal to 4888 items
# consuming the appliance 2 hours 50 minutes 46 seconds that equal to 10246 seconds or 683 items
#
# Days : 28 : Fri
# time to turn-on appliacne on 20 : 24 : 37 equal to 4898 items
# consuming the appliance 2 hours 15 minutes 13 seconds that equal to 8113 seconds or 540 items
#
# Days : 29 : Sat
# time to turn-on appliacne on 21 : 39 : 37 equal to 5198 items
# consuming the appliance 3 hours 40 minutes 54 seconds that equal to 13254 seconds or 883 items
#
# Days : 30 : Mon
# time to turn-on appliacne on 20 : 42 : 15 equal to 4968 items
# consuming the appliance 2 hours 45 minutes 18 seconds that equal to 9918 seconds or 661 items
#
# Days : 31 : Mon
# time to turn-on appliacne on 21 : 33 : 51 equal to 5175 items
# consuming the appliance 2 hours 19 minutes 10 seconds that equal to 8350 seconds or 556 items
# DONE!
