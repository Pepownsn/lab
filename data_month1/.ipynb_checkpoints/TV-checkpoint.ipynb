# %% [markdown]
# # data_TIMELInE
# ### TV | LCD ขนาด 49 นิ้ว |

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random


d = 31

time_a = pd.date_range('2016-10-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-10-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####### set databases to empty #########
query_empty = """truncate table data_timeline.TV""" 
c.execute(query_empty)
print "data_timeline.TV are Empty!!! \n"

query = "SELECT watt FROM collected_info.3_TV WHERE no >= '%s'   AND no <= '%s'; "% (0,1200)
df = pd.read_sql(query, conn)
# print df.watt[5]

#### Random the number of turnon-time per day
def manytime():
    many  = ['1'] * 50 + ['2'] * 44 + ['3'] * 6  ## The number of turn-on time of this appliance 
    manytime = random.choice(many)
    print "\nDays :",days ,":",time_b[j].strftime('%a')
    print "in recent day turn on TV",manytime,"times\n"
    if (int(manytime) == 1):
        x,y,endx,endy = 18,20,2,4  # fix turn on only in evening      
        open_hour =  random.randint(x, y)
        open_min =  random.randint(0, 59)
        open_sec =  random.randint(0, 59)
        if 0 < open_sec  <= 15:
            k = 0
        elif 15 < open_sec  <= 30:
            k = 1
        elif 30 < open_sec  <= 45:
            k = 2
        else:
            k = 3
        off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
        print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
        
        duration_hour =  random.randint(endx, endy)
        duration_min =  random.randint(0, 59)
        duration_sec =  random.randint(0, 59)
        seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
        no_item = seconds/15
        print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"
        return (off_item,no_item)

        
    elif (int(manytime) == 2):
        turn_duratrion  = ['1'] * 70 + ['2'] * 30       #### '1' turn-on morning and evening   OR  '2' turn-on 2 times in evening 
        howturn = random.choice(turn_duratrion)
#         print howturn
        if (int(howturn)== 1 ):
            x,y,endx,endy = 6,7,1,59
            open_hour =  random.randint(x, y)
            open_min =  random.randint(0, 59)
            open_sec =  random.randint(0, 59)
            if 0 < open_sec  <= 15:
                k = 0
            elif 15 < open_sec  <= 30:
                k = 1
            elif 30 < open_sec  <= 45:
                k = 2
            else:
                k = 3
            off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
            print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
            
            duration_hour =  random.randint(0, 0)
            duration_min =  random.randint(endx, endy)
            duration_sec =  random.randint(0, 59)
            seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
            no_item = seconds/15
            print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"

        
            
            x1,y1,endx1,endy1 = 18,20,2,4
            open_hour1 =  random.randint(x1, y1)
            open_min1 =  random.randint(0, 59)
            open_sec1 =  random.randint(0, 59)
            if 0 < open_sec1  <= 15:
                k = 0
            elif 15 < open_sec1  <= 30:
                k = 1
            elif 30 < open_sec1  <= 45:
                k = 2
            else:
                k = 3
            off_item1 = (int(open_hour1)*240) + (int(open_min1)*4)+ k 
            print "time to turn-on appliacne on",open_hour1,":",open_min1,":",open_sec1,"equal to",off_item1,"items"     
            
            duration_hour1 =  random.randint(endx1, endy1)
            duration_min1 =  random.randint(0, 59)
            duration_sec1 =  random.randint(0, 59)
            seconds1 = (duration_hour1*3600)+(duration_min1*60)+duration_sec1
            no_item1 = seconds1/15
            print "consuming the appliance", duration_hour1,"hours",duration_min1,"minutes",duration_sec1,"seconds that equal to",seconds1,"seconds or",no_item1,"items\n"

        else :
            x,y,endx,endy = 18,19,1,59
            open_hour =  random.randint(x, y)
            open_min =  random.randint(0, 59)
            open_sec =  random.randint(0, 59)
            if 0 < open_sec  <= 15:
                k = 0
            elif 15 < open_sec  <= 30:
                k = 1
            elif 30 < open_sec  <= 45:
                k = 2
            else:
                k = 3
            off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
            print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
            
            duration_hour =  random.randint(0, 0)
            duration_min =  random.randint(endx, endy)
            duration_sec =  random.randint(0, 59)
            seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
            no_item = seconds/15
            print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"

        
            x1,y1,endx1,endy1 = 20,22,1,4
            open_hour1 =  random.randint(x1, y1)
            open_min1 =  random.randint(0, 59)
            open_sec1 =  random.randint(0, 59)
            if 0 < open_sec1  <= 15:
                k = 0
            elif 15 < open_sec1  <= 30:
                k = 1
            elif 30 < open_sec1  <= 45:
                k = 2
            else:
                k = 3
            off_item1 = (int(open_hour1)*240) + (int(open_min1)*4)+ k 
            print "time to turn-on appliacne on",open_hour1,":",open_min1,":",open_sec1,"equal to",off_item1,"items"   
            
            duration_hour1 =  random.randint(endx1, endy1)
            duration_min1 =  random.randint(0, 59)
            duration_sec1 =  random.randint(0, 59)
            seconds1 = (duration_hour1*3600)+(duration_min1*60)+duration_sec1
            no_item1 = seconds1/15
            print "consuming the appliance", duration_hour1,"hours",duration_min1,"minutes",duration_sec1,"seconds that equal to",seconds1,"seconds or",no_item1,"items\n"

        return (off_item,no_item,off_item1,no_item1)        
    else:
        x,y,endx,endy = 6,7,30,60
        open_hour =  random.randint(x, y)
        open_min =  random.randint(0, 59)
        open_sec =  random.randint(0, 59)
        if 0 < open_sec  <= 15:
            k = 0
        elif 15 < open_sec  <= 30:
            k = 1
        elif 30 < open_sec  <= 45:
            k = 2
        else:
            k = 3
        off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
        print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
        
        duration_hour =  random.randint(0,0)
        duration_min =  random.randint(endx, endy)
        duration_sec =  random.randint(0, 59)
        seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
        no_item = seconds/15
        print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"

    
    
        x1,y1,endx1,endy1 = 18,19,1,59
        open_hour1 =  random.randint(x1, y1)
        open_min1 =  random.randint(0, 59)
        open_sec1 =  random.randint(0, 59)
        if 0 < open_sec1  <= 15:
            k = 0
        elif 15 < open_sec1  <= 30:
            k = 1
        elif 30 < open_sec1  <= 45:
            k = 2
        else:
            k = 3
        off_item1 = (int(open_hour1)*240) + (int(open_min1)*4)+ k 
        print "time to turn-on appliacne on",open_hour1,":",open_min1,":",open_sec1,"equal to",off_item1,"items" 
        duration_hour1 =  random.randint(0, 0)
        duration_min1 =  random.randint(endx1, endy1)
        duration_sec1 =  random.randint(0, 59)
        seconds1 = (duration_hour1*3600)+(duration_min1*60)+duration_sec1
        no_item1 = seconds1/15
        print "consuming the appliance", duration_hour1,"hours",duration_min1,"minutes",duration_sec1,"seconds that equal to",seconds1,"seconds or",no_item1,"items\n"
    
    
        x2,y2,endx2,endy2 = 20,22,1,4
        open_hour2 =  random.randint(x2, y2)
        open_min2 =  random.randint(0, 59)
        open_sec2 =  random.randint(0, 59)
        if 0 < open_sec2  <= 15:
            k = 0
        elif 15 < open_sec2  <= 30:
            k = 1
        elif 30 < open_sec2  <= 45:
            k = 2
        else:
            k = 3
        off_item2 = (int(open_hour2)*240) + (int(open_min2)*4)+ k 
        print "time to turn-on appliacne on",open_hour2,":",open_min2,":",open_sec2,"equal to",off_item2,"items" 
        duration_hour2 =  random.randint(endx2, endy2)
        duration_min2 =  random.randint(0, 59)
        duration_sec2 =  random.randint(0, 59)
        seconds2 = (duration_hour2*3600)+(duration_min2*60)+duration_sec2
        no_item2 = seconds2/15
        print "consuming the appliance", duration_hour2,"hours",duration_min2,"minutes",duration_sec2,"seconds that equal to",seconds2,"seconds or",no_item2,"items\n"
        return (off_item,no_item,off_item1,no_item1,off_item2,no_item2)    
    
    
        
days = 1
j = 0

## (off_item,no_item,off_item1,no_item1,off_item2,no_item2)    

turn = manytime()
while (j <= (5760*d)-1):   
    if (j == 5760+(5760*(days-1))):
        days +=1
        print "-------------------------ENd-----------------------------\n"
        turn = manytime()          
        
    if len(turn)==2:
        off_item = turn[0] 
        no_item = turn[1]
        if (off_item+(5760*(days-1)) <= j <= (no_item+off_item)+(5760*(days-1))):
            c.execute("INSERT INTO data_timeline.TV (Timestamp, watt) VALUES (%s, %s)",(time_b[j],random.randint(64, 68)))
            conn.commit()
            j += 1
        else:
            c.execute("INSERT INTO data_timeline.TV (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
            conn.commit()
            j += 1
        
    elif len(turn)==4:
        off_item = turn[0] 
        no_item = turn[1]
        off_item1 = turn[2] 
        no_item1 = turn[3]
        if (off_item+(5760*(days-1)) <= j <= (no_item+off_item)+(5760*(days-1)) or off_item1+(5760*(days-1)) <= j <= (no_item1+off_item1)+(5760*(days-1))):
            c.execute("INSERT INTO data_timeline.TV (Timestamp, watt) VALUES (%s, %s)",(time_b[j],random.randint(64, 68)))
            conn.commit()
            j += 1
        else:
            c.execute("INSERT INTO data_timeline.TV (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
            conn.commit()
            j += 1
             
    else:
        off_item = turn[0] 
        no_item = turn[1]
        off_item1 = turn[2] 
        no_item1 = turn[3]
        off_item2 = turn[4] 
        no_item2 = turn[5]
        
        if (off_item+(5760*(days-1)) <= j <= (no_item+off_item)+(5760*(days-1)) or off_item1+(5760*(days-1)) <= j <= (no_item1+off_item1)+(5760*(days-1)) or off_item2+(5760*(days-1)) <= j <= (no_item2+off_item2)+(5760*(days-1)))  :
            c.execute("INSERT INTO data_timeline.TV (Timestamp, watt) VALUES (%s, %s)",(time_b[j],random.randint(64, 68)))
            conn.commit()
            j += 1
        else:
            c.execute("INSERT INTO data_timeline.TV (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
            conn.commit()
            j += 1
 
           
print "DONE!"
# Out:
# data_timeline.TV are Empty!!!
#
#
# Days : 1 : Sat
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 20 : 11 : 44 equal to 4846 items
# consuming the appliance 4 hours 3 minutes 22 seconds that equal to 14602 seconds or 973 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 2 : Sun
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 20 : 42 : 7 equal to 4968 items
# consuming the appliance 2 hours 9 minutes 24 seconds that equal to 7764 seconds or 517 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 3 : Mon
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 19 : 3 : 45 equal to 4574 items
# consuming the appliance 0 hours 16 minutes 24 seconds that equal to 984 seconds or 65 items
#
# time to turn-on appliacne on 22 : 18 : 14 equal to 5352 items
# consuming the appliance 3 hours 51 minutes 40 seconds that equal to 13900 seconds or 926 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 4 : Tue
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 18 : 50 : 2 equal to 4520 items
# consuming the appliance 4 hours 14 minutes 40 seconds that equal to 15280 seconds or 1018 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 5 : Wed
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 18 : 21 : 41 equal to 4406 items
# consuming the appliance 4 hours 8 minutes 7 seconds that equal to 14887 seconds or 992 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 6 : Thu
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 20 : 57 : 30 equal to 5029 items
# consuming the appliance 4 hours 29 minutes 42 seconds that equal to 16182 seconds or 1078 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 7 : Fri
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 18 : 25 : 44 equal to 4422 items
# consuming the appliance 4 hours 16 minutes 31 seconds that equal to 15391 seconds or 1026 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 8 : Sat
# in recent day turn on TV 3 times
#
# time to turn-on appliacne on 7 : 49 : 19 equal to 1877 items
# consuming the appliance 0 hours 56 minutes 28 seconds that equal to 3388 seconds or 225 items
#
# time to turn-on appliacne on 19 : 22 : 40 equal to 4650 items
# consuming the appliance 0 hours 59 minutes 57 seconds that equal to 3597 seconds or 239 items
#
# time to turn-on appliacne on 21 : 59 : 53 equal to 5279 items
# consuming the appliance 1 hours 48 minutes 45 seconds that equal to 6525 seconds or 435 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 9 : Sun
# in recent day turn on TV 3 times
#
# time to turn-on appliacne on 7 : 46 : 55 equal to 1867 items
# consuming the appliance 0 hours 43 minutes 19 seconds that equal to 2599 seconds or 173 items
#
# time to turn-on appliacne on 18 : 23 : 7 equal to 4412 items
# consuming the appliance 0 hours 41 minutes 3 seconds that equal to 2463 seconds or 164 items
#
# time to turn-on appliacne on 21 : 27 : 22 equal to 5149 items
# consuming the appliance 1 hours 2 minutes 21 seconds that equal to 3741 seconds or 249 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 10 : Mon
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 19 : 29 : 2 equal to 4676 items
# consuming the appliance 3 hours 51 minutes 18 seconds that equal to 13878 seconds or 925 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 11 : Tue
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 18 : 5 : 18 equal to 4341 items
# consuming the appliance 2 hours 57 minutes 57 seconds that equal to 10677 seconds or 711 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 12 : Wed
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 18 : 47 : 19 equal to 4509 items
# consuming the appliance 2 hours 17 minutes 26 seconds that equal to 8246 seconds or 549 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 13 : Thu
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 7 : 19 : 0 equal to 1759 items
# consuming the appliance 0 hours 35 minutes 9 seconds that equal to 2109 seconds or 140 items
#
# time to turn-on appliacne on 20 : 54 : 27 equal to 5017 items
# consuming the appliance 3 hours 17 minutes 20 seconds that equal to 11840 seconds or 789 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 14 : Fri
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 6 : 6 : 42 equal to 1466 items
# consuming the appliance 0 hours 35 minutes 5 seconds that equal to 2105 seconds or 140 items
#
# time to turn-on appliacne on 20 : 47 : 59 equal to 4991 items
# consuming the appliance 4 hours 46 minutes 9 seconds that equal to 17169 seconds or 1144 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 15 : Sat
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 18 : 51 : 0 equal to 4527 items
# consuming the appliance 0 hours 51 minutes 17 seconds that equal to 3077 seconds or 205 items
#
# time to turn-on appliacne on 21 : 27 : 44 equal to 5150 items
# consuming the appliance 4 hours 56 minutes 41 seconds that equal to 17801 seconds or 1186 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 16 : Sun
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 6 : 17 : 3 equal to 1508 items
# consuming the appliance 0 hours 17 minutes 39 seconds that equal to 1059 seconds or 70 items
#
# time to turn-on appliacne on 20 : 56 : 4 equal to 5024 items
# consuming the appliance 2 hours 23 minutes 47 seconds that equal to 8627 seconds or 575 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 17 : Mon
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 20 : 20 : 48 equal to 4883 items
# consuming the appliance 2 hours 3 minutes 10 seconds that equal to 7390 seconds or 492 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 18 : Tue
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 6 : 43 : 15 equal to 1612 items
# consuming the appliance 0 hours 6 minutes 13 seconds that equal to 373 seconds or 24 items
#
# time to turn-on appliacne on 19 : 30 : 46 equal to 4683 items
# consuming the appliance 4 hours 20 minutes 7 seconds that equal to 15607 seconds or 1040 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 19 : Wed
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 6 : 32 : 32 equal to 1570 items
# consuming the appliance 0 hours 36 minutes 59 seconds that equal to 2219 seconds or 147 items
#
# time to turn-on appliacne on 19 : 24 : 51 equal to 4659 items
# consuming the appliance 3 hours 2 minutes 36 seconds that equal to 10956 seconds or 730 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 20 : Thu
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 19 : 8 : 7 equal to 4592 items
# consuming the appliance 0 hours 31 minutes 39 seconds that equal to 1899 seconds or 126 items
#
# time to turn-on appliacne on 21 : 13 : 28 equal to 5093 items
# consuming the appliance 3 hours 34 minutes 43 seconds that equal to 12883 seconds or 858 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 21 : Fri
# in recent day turn on TV 3 times
#
# time to turn-on appliacne on 6 : 35 : 21 equal to 1581 items
# consuming the appliance 0 hours 35 minutes 54 seconds that equal to 2154 seconds or 143 items
#
# time to turn-on appliacne on 19 : 56 : 56 equal to 4787 items
# consuming the appliance 0 hours 46 minutes 26 seconds that equal to 2786 seconds or 185 items
#
# time to turn-on appliacne on 20 : 39 : 53 equal to 4959 items
# consuming the appliance 1 hours 11 minutes 39 seconds that equal to 4299 seconds or 286 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 22 : Sat
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 20 : 26 : 53 equal to 4907 items
# consuming the appliance 2 hours 1 minutes 8 seconds that equal to 7268 seconds or 484 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 23 : Sun
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 6 : 58 : 46 equal to 1675 items
# consuming the appliance 0 hours 44 minutes 34 seconds that equal to 2674 seconds or 178 items
#
# time to turn-on appliacne on 19 : 55 : 34 equal to 4782 items
# consuming the appliance 2 hours 37 minutes 46 seconds that equal to 9466 seconds or 631 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 24 : Mon
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 19 : 18 : 37 equal to 4634 items
# consuming the appliance 4 hours 57 minutes 44 seconds that equal to 17864 seconds or 1190 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 25 : Tue
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 7 : 50 : 56 equal to 1883 items
# consuming the appliance 0 hours 29 minutes 16 seconds that equal to 1756 seconds or 117 items
#
# time to turn-on appliacne on 20 : 9 : 19 equal to 4837 items
# consuming the appliance 2 hours 32 minutes 29 seconds that equal to 9149 seconds or 609 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 26 : Wed
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 7 : 29 : 46 equal to 1799 items
# consuming the appliance 0 hours 57 minutes 44 seconds that equal to 3464 seconds or 230 items
#
# time to turn-on appliacne on 19 : 1 : 42 equal to 4566 items
# consuming the appliance 4 hours 34 minutes 26 seconds that equal to 16466 seconds or 1097 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 27 : Thu
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 6 : 2 : 15 equal to 1448 items
# consuming the appliance 0 hours 44 minutes 29 seconds that equal to 2669 seconds or 177 items
#
# time to turn-on appliacne on 19 : 9 : 5 equal to 4596 items
# consuming the appliance 3 hours 40 minutes 2 seconds that equal to 13202 seconds or 880 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 28 : Fri
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 6 : 19 : 33 equal to 1518 items
# consuming the appliance 0 hours 2 minutes 16 seconds that equal to 136 seconds or 9 items
#
# time to turn-on appliacne on 20 : 47 : 1 equal to 4988 items
# consuming the appliance 2 hours 36 minutes 48 seconds that equal to 9408 seconds or 627 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 29 : Sat
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 7 : 31 : 55 equal to 1807 items
# consuming the appliance 0 hours 48 minutes 51 seconds that equal to 2931 seconds or 195 items
#
# time to turn-on appliacne on 18 : 11 : 13 equal to 4364 items
# consuming the appliance 3 hours 24 minutes 24 seconds that equal to 12264 seconds or 817 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 30 : Sun
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 18 : 23 : 29 equal to 4413 items
# consuming the appliance 0 hours 8 minutes 59 seconds that equal to 539 seconds or 35 items
#
# time to turn-on appliacne on 20 : 5 : 54 equal to 4823 items
# consuming the appliance 1 hours 13 minutes 12 seconds that equal to 4392 seconds or 292 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 31 : Mon
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 20 : 3 : 32 equal to 4814 items
# consuming the appliance 4 hours 18 minutes 12 seconds that equal to 15492 seconds or 1032 items
#
# DONE!

# %%
import matplotlib.pyplot as plt
# %matplotlib inline  


# query = "SELECT watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
query = "SELECT Timestamp,watt FROM data_timeline.TV WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[3000],time_b[5760*4])
df = pd.read_sql(query, conn, index_col=['Timestamp'])

fig, ax = plt.subplots()
ax.set_title('data_timeline.TV')
ax.set_ylim(64,68)
df.plot(ax=ax )
plt.show()
# df.to_csv('file.csv')
# len(time_b)
