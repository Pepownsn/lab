# %% [markdown]
# # data_TIMELInE
# ### Elec_thermos | ขนาด 2.8 ลิตร  |

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random


d = 31
time_a = pd.date_range('2016-10-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-10-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####### set databases to empty #########
query_empty = """truncate table data_timeline.elec_thermos""" 
c.execute(query_empty)
print "data_timeline.elec_thermos are Empty!!! \n"

query = "SELECT watt FROM collected_info.8_elec_thermos WHERE no >= '%s'   AND no <= '%s'; "% (0,1167)
df = pd.read_sql(query, conn)
# print df.watt[5]

#### Random the turning-on time appliances
def rand_turnon():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(0, 59)
    duration_hour1 = ['6'] * 2 + ['7'] * 48 + ['8'] * 47 + ['9'] * 3    #SET Start 6-9 am.
    duration_hour = random.choice(duration_hour1)     
    if 0 < duration_sec <= 15:
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
    off_item = (int(duration_hour)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on appliacne on",duration_hour,":",duration_min,":",duration_sec,"equal to",off_item,"items"
    return off_item

 
#### Random the off-duration appliances 
def rand_duration():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(0, 59)
    duration_hour1 = ['0'] * 97 + ['1'] * 2+ ['2'] * 1
    duration_hour = random.choice(duration_hour1)   
    seconds = (int(duration_hour)*3600)+(duration_min*60)+duration_sec
    no_item = seconds/15
    print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items"
    return no_item

days = 0
j = 0
i = 0
print "\nDays :",days ,":",time_b[j].strftime('%a')
off_item = rand_turnon()  
no_item = rand_duration()  

while (j <= (5760*d)-1):  
    c.execute("INSERT INTO data_timeline.elec_thermos (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
    conn.commit()
    j += 1 
    
    while (off_item+(5760*(days)) <= j <= (no_item+off_item)+(5760*(days))):                   
        c.execute("INSERT INTO data_timeline.elec_thermos (Timestamp, watt) VALUES (%s, %s)",(time_b[j],df.watt[i]))
        conn.commit()
        i += 1 
        j += 1
        if (j == (no_item+off_item)+(5760*(days))):
            days +=1
            print "\nDays :",days ,":",time_b[j].strftime('%a')
            off_item = rand_turnon()  
            no_item = rand_duration() 
            i= 0   

                    
print "DONE!"
# Out:
# data_timeline.elec_thermos are Empty!!!
#
#
# Days : 0 : Sat
# time to turn-on appliacne on 8 : 35 : 26 equal to 2061 items
# consuming the appliance 0 hours 37 minutes 7 seconds that equal to 2227 seconds or 148 items
#
# Days : 1 : Sat
# time to turn-on appliacne on 8 : 33 : 3 equal to 2052 items
# consuming the appliance 0 hours 15 minutes 35 seconds that equal to 935 seconds or 62 items
#
# Days : 2 : Sun
# time to turn-on appliacne on 8 : 17 : 7 equal to 1988 items
# consuming the appliance 0 hours 56 minutes 32 seconds that equal to 3392 seconds or 226 items
#
# Days : 3 : Mon
# time to turn-on appliacne on 7 : 3 : 45 equal to 1694 items
# consuming the appliance 0 hours 13 minutes 44 seconds that equal to 824 seconds or 54 items
#
# Days : 4 : Tue
# time to turn-on appliacne on 8 : 22 : 31 equal to 2010 items
# consuming the appliance 0 hours 46 minutes 13 seconds that equal to 2773 seconds or 184 items
#
# Days : 5 : Wed
# time to turn-on appliacne on 8 : 5 : 58 equal to 1943 items
# consuming the appliance 1 hours 0 minutes 4 seconds that equal to 3604 seconds or 240 items
#
# Days : 6 : Thu
# time to turn-on appliacne on 7 : 14 : 29 equal to 1737 items
# consuming the appliance 0 hours 12 minutes 44 seconds that equal to 764 seconds or 50 items
#
# Days : 7 : Fri
# time to turn-on appliacne on 7 : 43 : 15 equal to 1852 items
# consuming the appliance 0 hours 10 minutes 3 seconds that equal to 603 seconds or 40 items
#
# Days : 8 : Sat
# time to turn-on appliacne on 8 : 22 : 4 equal to 2008 items
# consuming the appliance 0 hours 33 minutes 49 seconds that equal to 2029 seconds or 135 items
#
# Days : 9 : Sun
# time to turn-on appliacne on 7 : 54 : 52 equal to 1899 items
# consuming the appliance 0 hours 8 minutes 19 seconds that equal to 499 seconds or 33 items
#
# Days : 10 : Mon
# time to turn-on appliacne on 7 : 43 : 43 equal to 1854 items
# consuming the appliance 0 hours 25 minutes 50 seconds that equal to 1550 seconds or 103 items
#
# Days : 11 : Tue
# time to turn-on appliacne on 7 : 24 : 18 equal to 1777 items
# consuming the appliance 0 hours 30 minutes 54 seconds that equal to 1854 seconds or 123 items
#
# Days : 12 : Wed
# time to turn-on appliacne on 8 : 51 : 27 equal to 2125 items
# consuming the appliance 0 hours 15 minutes 35 seconds that equal to 935 seconds or 62 items
#
# Days : 13 : Thu
# time to turn-on appliacne on 6 : 40 : 1 equal to 1600 items
# consuming the appliance 0 hours 27 minutes 54 seconds that equal to 1674 seconds or 111 items
#
# Days : 14 : Fri
# time to turn-on appliacne on 7 : 15 : 38 equal to 1742 items
# consuming the appliance 0 hours 45 minutes 41 seconds that equal to 2741 seconds or 182 items
#
# Days : 15 : Sat
# time to turn-on appliacne on 8 : 49 : 32 equal to 2118 items
# consuming the appliance 0 hours 56 minutes 6 seconds that equal to 3366 seconds or 224 items
#
# Days : 16 : Sun
# time to turn-on appliacne on 7 : 53 : 26 equal to 1893 items
# consuming the appliance 0 hours 6 minutes 2 seconds that equal to 362 seconds or 24 items
#
# Days : 17 : Mon
# time to turn-on appliacne on 7 : 6 : 28 equal to 1705 items
# consuming the appliance 0 hours 26 minutes 57 seconds that equal to 1617 seconds or 107 items
#
# Days : 18 : Tue
# time to turn-on appliacne on 7 : 4 : 11 equal to 1696 items
# consuming the appliance 0 hours 25 minutes 42 seconds that equal to 1542 seconds or 102 items
#
# Days : 19 : Wed
# time to turn-on appliacne on 7 : 12 : 29 equal to 1729 items
# consuming the appliance 0 hours 26 minutes 33 seconds that equal to 1593 seconds or 106 items
#
# Days : 20 : Thu
# time to turn-on appliacne on 7 : 25 : 16 equal to 1781 items
# consuming the appliance 0 hours 4 minutes 19 seconds that equal to 259 seconds or 17 items
#
# Days : 21 : Fri
# time to turn-on appliacne on 7 : 17 : 51 equal to 1751 items
# consuming the appliance 0 hours 25 minutes 28 seconds that equal to 1528 seconds or 101 items
#
# Days : 22 : Sat
# time to turn-on appliacne on 7 : 56 : 13 equal to 1904 items
# consuming the appliance 0 hours 8 minutes 44 seconds that equal to 524 seconds or 34 items
#
# Days : 23 : Sun
# time to turn-on appliacne on 8 : 16 : 29 equal to 1985 items
# consuming the appliance 0 hours 7 minutes 42 seconds that equal to 462 seconds or 30 items
#
# Days : 24 : Mon
# time to turn-on appliacne on 7 : 7 : 31 equal to 1710 items
# consuming the appliance 0 hours 40 minutes 4 seconds that equal to 2404 seconds or 160 items
#
# Days : 25 : Tue
# time to turn-on appliacne on 8 : 57 : 46 equal to 2151 items
# consuming the appliance 0 hours 0 minutes 34 seconds that equal to 34 seconds or 2 items
#
# Days : 26 : Wed
# time to turn-on appliacne on 7 : 54 : 27 equal to 1897 items
# consuming the appliance 0 hours 27 minutes 44 seconds that equal to 1664 seconds or 110 items
#
# Days : 27 : Thu
# time to turn-on appliacne on 8 : 3 : 24 equal to 1933 items
# consuming the appliance 0 hours 51 minutes 43 seconds that equal to 3103 seconds or 206 items
#
# Days : 28 : Fri
# time to turn-on appliacne on 8 : 10 : 56 equal to 1963 items
# consuming the appliance 0 hours 20 minutes 53 seconds that equal to 1253 seconds or 83 items
#
# Days : 29 : Sat
# time to turn-on appliacne on 7 : 17 : 10 equal to 1748 items
# consuming the appliance 2 hours 56 minutes 32 seconds that equal to 10592 seconds or 706 items
#
# Days : 30 : Sun
# time to turn-on appliacne on 7 : 33 : 41 equal to 1814 items
# consuming the appliance 0 hours 41 minutes 58 seconds that equal to 2518 seconds or 167 items
#
# Days : 31 : Mon
# time to turn-on appliacne on 8 : 44 : 15 equal to 2096 items
# consuming the appliance 0 hours 35 minutes 7 seconds that equal to 2107 seconds or 140 items
# DONE!

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
# %matplotlib inline  


# query = "SELECT watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
query = "SELECT Timestamp,watt FROM data_timeline.elec_thermos WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
df = pd.read_sql(query, conn, index_col=['Timestamp'])
fig, ax = plt.subplots()
ax.set_title('data_timeline.elec_thermos')
df.plot(ax=ax )
plt.show()
