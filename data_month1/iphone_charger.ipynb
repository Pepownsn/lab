# %% [markdown]
# # data_TIMELInE
# ### IPHONE charger | ipad 9.7 นิ้ว |

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random


d = 31
time_a = pd.date_range('2016-10-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-10-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####### set databases to empty #########
query_empty = """truncate table data_timeline.iphonecharger""" 
c.execute(query_empty)
print "data_timeline.iphonecharger are Empty!!! \n"

query = "SELECT watt FROM collected_info.13_iphonecharger WHERE no >= '%s'   AND no <= '%s'; "% (0,1200)
df = pd.read_sql(query, conn)
# print df.watt[5]

#### Random the turning-on time appliances
def rand_turnon():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(0, 59)
    duration_hour1 = ['18'] * 5 + ['19'] * 8 + ['20'] * 36 + ['21'] * 30 + ['22'] * 13 + ['23'] * 6 + ['0'] * 2
    duration_hour = random.choice(duration_hour1)     
    if 0 < duration_sec <= 15:
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
    off_item = (int(duration_hour)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on appliacne on",duration_hour,":",duration_min,":",duration_sec,"equal to",off_item,"items"
    return off_item

 
#### Random the off-duration appliances 
def rand_duration():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(10, 40)
    duration_hour1 = ['0'] * 2 + ['1'] * 25 + ['2'] * 35+ ['3'] * 20 + ['4'] * 10 + ['5'] * 8
    duration_hour = random.choice(duration_hour1)   
    seconds = (int(duration_hour)*3600)+(duration_min*60)+duration_sec
    no_item = seconds/15
    print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items"
    return no_item

days = 0
j = 0
i = 0
print "\nDays :",days ,":",time_b[j].strftime('%a')
off_item = rand_turnon()  
no_item = rand_duration()  

while (j <= (5760*d)-1):  
    c.execute("INSERT INTO data_timeline.iphonecharger (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
    conn.commit()
    j += 1 
  
        
    while (off_item+(5760*(days)) <= j <= (no_item+off_item)+(5760*(days))):                   
        c.execute("INSERT INTO data_timeline.iphonecharger (Timestamp, watt) VALUES (%s, %s)",(time_b[j],df.watt[i]))
        conn.commit()
        i += 1 
        j += 1
            
        if (i >= len(df)):
            i = 0  
        if (j == (no_item+off_item)+(5760*(days))):
            days +=1
            print "\nDays :",days ,":",time_b[j].strftime('%a')
            off_item = rand_turnon()  
            no_item = rand_duration() 
            i= 0   

                    
print "DONE!"
# Out:
# data_timeline.iphonecharger are Empty!!!
#
#
# Days : 0 : Sat
# time to turn-on appliacne on 20 : 36 : 39 equal to 4946 items
# consuming the appliance 1 hours 13 minutes 19 seconds that equal to 4399 seconds or 293 items
#
# Days : 1 : Sat
# time to turn-on appliacne on 20 : 8 : 5 equal to 4832 items
# consuming the appliance 1 hours 27 minutes 53 seconds that equal to 5273 seconds or 351 items
#
# Days : 2 : Sun
# time to turn-on appliacne on 22 : 19 : 11 equal to 5356 items
# consuming the appliance 1 hours 22 minutes 53 seconds that equal to 4973 seconds or 331 items
#
# Days : 3 : Mon
# time to turn-on appliacne on 20 : 41 : 17 equal to 4965 items
# consuming the appliance 2 hours 37 minutes 4 seconds that equal to 9424 seconds or 628 items
#
# Days : 4 : Tue
# time to turn-on appliacne on 21 : 11 : 55 equal to 5087 items
# consuming the appliance 5 hours 26 minutes 34 seconds that equal to 19594 seconds or 1306 items
#
# Days : 5 : Thu
# time to turn-on appliacne on 21 : 14 : 21 equal to 5097 items
# consuming the appliance 5 hours 18 minutes 48 seconds that equal to 19128 seconds or 1275 items
#
# Days : 6 : Fri
# time to turn-on appliacne on 21 : 42 : 12 equal to 5208 items
# consuming the appliance 3 hours 34 minutes 24 seconds that equal to 12864 seconds or 857 items
#
# Days : 7 : Sat
# time to turn-on appliacne on 20 : 47 : 59 equal to 4991 items
# consuming the appliance 3 hours 24 minutes 36 seconds that equal to 12276 seconds or 818 items
#
# Days : 8 : Sun
# time to turn-on appliacne on 21 : 37 : 20 equal to 5189 items
# consuming the appliance 1 hours 22 minutes 38 seconds that equal to 4958 seconds or 330 items
#
# Days : 9 : Sun
# time to turn-on appliacne on 21 : 26 : 31 equal to 5146 items
# consuming the appliance 1 hours 31 minutes 39 seconds that equal to 5499 seconds or 366 items
#
# Days : 10 : Mon
# time to turn-on appliacne on 18 : 7 : 11 equal to 4348 items
# consuming the appliance 3 hours 22 minutes 35 seconds that equal to 12155 seconds or 810 items
#
# Days : 11 : Tue
# time to turn-on appliacne on 22 : 58 : 24 equal to 5513 items
# consuming the appliance 2 hours 37 minutes 56 seconds that equal to 9476 seconds or 631 items
#
# Days : 12 : Thu
# time to turn-on appliacne on 20 : 35 : 25 equal to 4941 items
# consuming the appliance 3 hours 20 minutes 33 seconds that equal to 12033 seconds or 802 items
#
# Days : 13 : Thu
# time to turn-on appliacne on 21 : 41 : 25 equal to 5205 items
# consuming the appliance 3 hours 17 minutes 29 seconds that equal to 11849 seconds or 789 items
#
# Days : 14 : Sat
# time to turn-on appliacne on 22 : 55 : 53 equal to 5503 items
# consuming the appliance 2 hours 12 minutes 14 seconds that equal to 7934 seconds or 528 items
#
# Days : 15 : Sun
# time to turn-on appliacne on 22 : 8 : 19 equal to 5313 items
# consuming the appliance 1 hours 17 minutes 43 seconds that equal to 4663 seconds or 310 items
#
# Days : 16 : Sun
# time to turn-on appliacne on 20 : 53 : 21 equal to 5013 items
# consuming the appliance 2 hours 18 minutes 21 seconds that equal to 8301 seconds or 553 items
#
# Days : 17 : Mon
# time to turn-on appliacne on 21 : 34 : 12 equal to 5176 items
# consuming the appliance 5 hours 21 minutes 47 seconds that equal to 19307 seconds or 1287 items
#
# Days : 18 : Wed
# time to turn-on appliacne on 18 : 43 : 7 equal to 4492 items
# consuming the appliance 4 hours 20 minutes 36 seconds that equal to 15636 seconds or 1042 items
#
# Days : 19 : Wed
# time to turn-on appliacne on 19 : 27 : 26 equal to 4669 items
# consuming the appliance 4 hours 35 minutes 15 seconds that equal to 16515 seconds or 1101 items
#
# Days : 20 : Fri
# time to turn-on appliacne on 22 : 19 : 39 equal to 5358 items
# consuming the appliance 3 hours 29 minutes 12 seconds that equal to 12552 seconds or 836 items
#
# Days : 21 : Sat
# time to turn-on appliacne on 21 : 55 : 36 equal to 5262 items
# consuming the appliance 4 hours 39 minutes 36 seconds that equal to 16776 seconds or 1118 items
#
# Days : 22 : Sun
# time to turn-on appliacne on 20 : 39 : 21 equal to 4957 items
# consuming the appliance 1 hours 32 minutes 33 seconds that equal to 5553 seconds or 370 items
#
# Days : 23 : Sun
# time to turn-on appliacne on 21 : 39 : 12 equal to 5196 items
# consuming the appliance 2 hours 31 minutes 18 seconds that equal to 9078 seconds or 605 items
#
# Days : 24 : Tue
# time to turn-on appliacne on 19 : 11 : 47 equal to 4607 items
# consuming the appliance 2 hours 14 minutes 30 seconds that equal to 8070 seconds or 538 items
#
# Days : 25 : Tue
# time to turn-on appliacne on 20 : 9 : 10 equal to 4836 items
# consuming the appliance 4 hours 15 minutes 41 seconds that equal to 15341 seconds or 1022 items
#
# Days : 26 : Thu
# time to turn-on appliacne on 23 : 46 : 38 equal to 5706 items
# consuming the appliance 3 hours 24 minutes 27 seconds that equal to 12267 seconds or 817 items
#
# Days : 27 : Fri
# time to turn-on appliacne on 21 : 14 : 38 equal to 5098 items
# consuming the appliance 3 hours 19 minutes 3 seconds that equal to 11943 seconds or 796 items
#
# Days : 28 : Sat
# time to turn-on appliacne on 19 : 59 : 15 equal to 4796 items
# consuming the appliance 5 hours 29 minutes 10 seconds that equal to 19750 seconds or 1316 items
#
# Days : 29 : Sun
# time to turn-on appliacne on 21 : 0 : 9 equal to 5040 items
# consuming the appliance 2 hours 29 minutes 14 seconds that equal to 8954 seconds or 596 items
#
# Days : 30 : Sun
# time to turn-on appliacne on 21 : 13 : 16 equal to 5093 items
# consuming the appliance 2 hours 39 minutes 15 seconds that equal to 9555 seconds or 637 items
#
# Days : 31 : Mon
# time to turn-on appliacne on 21 : 34 : 11 equal to 5176 items
# consuming the appliance 1 hours 22 minutes 12 seconds that equal to 4932 seconds or 328 items
# DONE!

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
# %matplotlib inline  


query = "SELECT Timestamp,watt FROM data_timeline.iphonecharger WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[5760*10])
df = pd.read_sql(query, conn, index_col=['Timestamp'])
fig, ax = plt.subplots()
ax.set_title('data_timeline.iphonecharger')
df.plot(ax=ax )
plt.show()
