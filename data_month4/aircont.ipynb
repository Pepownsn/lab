# %% [markdown]
# ## data_month4
# #### เครื่องปรับอากาศ | 9000btu |

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random


d = 31
time_a = pd.date_range('2017-01-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2017-01-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####### set databases to empty #########
query_empty = """truncate table data_month4.aircont""" 
c.execute(query_empty)
print "data_month4.aircont are Empty!!! \n"

query = "SELECT watt FROM collected_info.1_aircont WHERE no >= '%s'   AND no <= '%s'; "% (0,3276)
df = pd.read_sql(query, conn)
# print df.watt[5]

#### Random the turning-on time appliances
def rand_turnon():
    duration_sec =  random.randint(10, 59)
    duration_min =  random.randint(10, 59)
    duration_hour1 = ['19'] * 5 + ['20'] * 50 + ['21'] * 43 +['22'] * 2     #SET Start 7-10 pm.
    duration_hour = random.choice(duration_hour1)     
    if 0 < duration_sec <= 15:
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
    off_item = (int(duration_hour)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on appliacne on",duration_hour,":",duration_min,":",duration_sec,"equal to",off_item,"items"
    return off_item

 
#### Random the off-duration appliances 
def rand_duration():
    duration_sec =  random.randint(10,59)
    duration_min =  random.randint(10, 59)
    duration_hour =  random.randint(6, 8)     #SET 6-8 Hours
    seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
    no_item = seconds/15
    print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items"
    return no_item

days = 0
j = 0
i = 0
print "\nDays :",days ,":",time_b[j].strftime('%a')
off_item = rand_turnon()  
no_item = rand_duration()  

while (j <= (5760*d)-1):    
    c.execute("INSERT INTO data_month4.aircont (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
    conn.commit()
    j += 1 
    
    while (off_item+(5760*(days)) <= j <= (no_item+off_item)+(5760*(days))):                   
        c.execute("INSERT INTO data_month4.aircont (Timestamp, watt) VALUES (%s, %s)",(time_b[j],df.watt[i]))
        conn.commit()
        i += 1 
        j += 1
        if (j == (no_item+off_item)+(5760*(days))):
            days +=1
            print "\nDays :",days ,":",time_b[j].strftime('%a')
            off_item = rand_turnon()  
            no_item = rand_duration() 
            i= 0   
                    
print "DONE!"
# Out:
# data_month4.aircont are Empty!!!
#
#
# Days : 0 : Sun
# time to turn-on appliacne on 21 : 27 : 55 equal to 5151 items
# consuming the appliance 6 hours 30 minutes 47 seconds that equal to 23447 seconds or 1563 items
#
# Days : 1 : Mon
# time to turn-on appliacne on 20 : 44 : 37 equal to 4978 items
# consuming the appliance 8 hours 42 minutes 28 seconds that equal to 31348 seconds or 2089 items
#
# Days : 2 : Tue
# time to turn-on appliacne on 21 : 10 : 36 equal to 5082 items
# consuming the appliance 7 hours 53 minutes 33 seconds that equal to 28413 seconds or 1894 items
#
# Days : 3 : Wed
# time to turn-on appliacne on 20 : 37 : 32 equal to 4950 items
# consuming the appliance 7 hours 35 minutes 40 seconds that equal to 27340 seconds or 1822 items
#
# Days : 4 : Thu
# time to turn-on appliacne on 20 : 33 : 50 equal to 4935 items
# consuming the appliance 6 hours 48 minutes 16 seconds that equal to 24496 seconds or 1633 items
#
# Days : 5 : Fri
# time to turn-on appliacne on 20 : 48 : 36 equal to 4994 items
# consuming the appliance 6 hours 45 minutes 55 seconds that equal to 24355 seconds or 1623 items
#
# Days : 6 : Sat
# time to turn-on appliacne on 21 : 29 : 41 equal to 5158 items
# consuming the appliance 6 hours 38 minutes 26 seconds that equal to 23906 seconds or 1593 items
#
# Days : 7 : Sun
# time to turn-on appliacne on 21 : 28 : 42 equal to 5154 items
# consuming the appliance 8 hours 38 minutes 45 seconds that equal to 31125 seconds or 2075 items
#
# Days : 8 : Mon
# time to turn-on appliacne on 19 : 13 : 22 equal to 4613 items
# consuming the appliance 7 hours 40 minutes 57 seconds that equal to 27657 seconds or 1843 items
#
# Days : 9 : Tue
# time to turn-on appliacne on 22 : 48 : 55 equal to 5475 items
# consuming the appliance 6 hours 15 minutes 48 seconds that equal to 22548 seconds or 1503 items
#
# Days : 10 : Wed
# time to turn-on appliacne on 20 : 17 : 38 equal to 4870 items
# consuming the appliance 6 hours 33 minutes 49 seconds that equal to 23629 seconds or 1575 items
#
# Days : 11 : Thu
# time to turn-on appliacne on 21 : 51 : 52 equal to 5247 items
# consuming the appliance 8 hours 48 minutes 18 seconds that equal to 31698 seconds or 2113 items
#
# Days : 12 : Fri
# time to turn-on appliacne on 20 : 22 : 43 equal to 4890 items
# consuming the appliance 6 hours 13 minutes 46 seconds that equal to 22426 seconds or 1495 items
#
# Days : 13 : Sat
# time to turn-on appliacne on 20 : 13 : 16 equal to 4853 items
# consuming the appliance 7 hours 17 minutes 24 seconds that equal to 26244 seconds or 1749 items
#
# Days : 14 : Sun
# time to turn-on appliacne on 20 : 52 : 29 equal to 5009 items
# consuming the appliance 6 hours 45 minutes 27 seconds that equal to 24327 seconds or 1621 items
#
# Days : 15 : Mon
# time to turn-on appliacne on 20 : 58 : 34 equal to 5034 items
# consuming the appliance 8 hours 43 minutes 35 seconds that equal to 31415 seconds or 2094 items
#
# Days : 16 : Tue
# time to turn-on appliacne on 20 : 29 : 27 equal to 4917 items
# consuming the appliance 8 hours 55 minutes 44 seconds that equal to 32144 seconds or 2142 items
#
# Days : 17 : Wed
# time to turn-on appliacne on 21 : 48 : 47 equal to 5235 items
# consuming the appliance 7 hours 46 minutes 30 seconds that equal to 27990 seconds or 1866 items
#
# Days : 18 : Thu
# time to turn-on appliacne on 20 : 11 : 13 equal to 4844 items
# consuming the appliance 7 hours 50 minutes 28 seconds that equal to 28228 seconds or 1881 items
#
# Days : 19 : Fri
# time to turn-on appliacne on 21 : 44 : 50 equal to 5219 items
# consuming the appliance 6 hours 15 minutes 32 seconds that equal to 22532 seconds or 1502 items
#
# Days : 20 : Sat
# time to turn-on appliacne on 21 : 18 : 53 equal to 5115 items
# consuming the appliance 7 hours 39 minutes 52 seconds that equal to 27592 seconds or 1839 items
#
# Days : 21 : Sun
# time to turn-on appliacne on 21 : 19 : 39 equal to 5118 items
# consuming the appliance 8 hours 57 minutes 54 seconds that equal to 32274 seconds or 2151 items
#
# Days : 22 : Mon
# time to turn-on appliacne on 20 : 27 : 17 equal to 4909 items
# consuming the appliance 6 hours 46 minutes 16 seconds that equal to 24376 seconds or 1625 items
#
# Days : 23 : Tue
# time to turn-on appliacne on 20 : 52 : 24 equal to 5009 items
# consuming the appliance 8 hours 43 minutes 38 seconds that equal to 31418 seconds or 2094 items
#
# Days : 24 : Wed
# time to turn-on appliacne on 20 : 13 : 40 equal to 4854 items
# consuming the appliance 6 hours 43 minutes 27 seconds that equal to 24207 seconds or 1613 items
#
# Days : 25 : Thu
# time to turn-on appliacne on 20 : 17 : 34 equal to 4870 items
# consuming the appliance 7 hours 45 minutes 30 seconds that equal to 27930 seconds or 1862 items
#
# Days : 26 : Fri
# time to turn-on appliacne on 21 : 49 : 50 equal to 5239 items
# consuming the appliance 8 hours 35 minutes 41 seconds that equal to 30941 seconds or 2062 items
#
# Days : 27 : Sat
# time to turn-on appliacne on 20 : 14 : 33 equal to 4858 items
# consuming the appliance 6 hours 23 minutes 22 seconds that equal to 23002 seconds or 1533 items
#
# Days : 28 : Sun
# time to turn-on appliacne on 21 : 32 : 23 equal to 5169 items
# consuming the appliance 6 hours 53 minutes 29 seconds that equal to 24809 seconds or 1653 items
#
# Days : 29 : Mon
# time to turn-on appliacne on 20 : 25 : 55 equal to 4903 items
# consuming the appliance 8 hours 38 minutes 19 seconds that equal to 31099 seconds or 2073 items
#
# Days : 30 : Tue
# time to turn-on appliacne on 21 : 24 : 11 equal to 5136 items
# consuming the appliance 7 hours 37 minutes 35 seconds that equal to 27455 seconds or 1830 items
# IndexErrorTraceback (most recent call last)
# <ipython-input-1-bf2dc81a956d> in <module>()
#      67
#      68     while (off_item+(5760*(days)) <= j <= (no_item+off_item)+(5760*(days))):
# ---> 69         c.execute("INSERT INTO data_month4.aircont (Timestamp, watt) VALUES (%s, %s)",(time_b[j],df.watt[i]))
#      70         conn.commit()
#      71         i += 1
#
# /usr/local/lib/python2.7/dist-packages/pandas/tseries/base.pyc in __getitem__(self, key)
#     249         getitem = self._data.__getitem__
#     250         if is_int:
# --> 251             val = getitem(key)
#     252             return self._box_func(val)
#     253         else:
#
# IndexError: index 178560 is out of bounds for axis 0 with size 178560

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
# %matplotlib inline  

d = 31
time_a = pd.date_range('2017-01-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2017-01-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

# print time_b
# query = "SELECT watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
query = "SELECT Timestamp,watt FROM data_month4.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[5760*10])
df = pd.read_sql(query, conn, index_col=['Timestamp'])
fig, ax = plt.subplots()
ax.set_title(' data_month4.aircont ')
df.plot(ax=ax )
plt.show()
