# %% [markdown]
# ## data_month4
# #### RICE COOKER| ??? |

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random


d =31
time_a = pd.date_range('2017-01-01 00:00:00', periods=5760*(d+1), freq='15S')
# print time_a
time_b = pd.date_range('2017-01-01 00:00:14', periods=5760*(d+1), freq='15S')
# print time_b

clock1 = time_b.strftime("%H:%M:%S")

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

conn1= MySQLdb.connect("localhost","conn","hems")
c1 = conn1.cursor()

####### set databases to empty #########
query_empty = """truncate table data_month4.rice_cooker """ 
c1.execute(query_empty)
print "data_month4.rice_cooker are Empty!!! \n"

query = "SELECT watt FROM collected_info.10_rice_cooker WHERE no >= '%s'   AND no <= '%s'; "% (0,1200)
df = pd.read_sql(query, conn)
# print df.watt[5]


#### Random the turning-on time appliances
def rand_turnon():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(0, 59)
    duration_hour1 = ['16'] * 10 +  ['17'] * 60 + ['18'] * 27 + ['19'] * 3
    duration_hour = random.choice(duration_hour1)     
    if 0 < duration_sec <= 15:
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
    off_item = (int(duration_hour)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on appliacne on",duration_hour,":",duration_min,":",duration_sec,"equal to",off_item,"items"
    return off_item

 
#### Random the off-duration appliances 
def rand_duration():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(40, 59)
    duration_hour1 = ['0'] * 27 + ['0'] * 70 + ['1'] * 3
    duration_hour = random.choice(duration_hour1)       
    seconds = (int(duration_hour)*3600)+(duration_min*60)+duration_sec
    no_item = seconds/15
    print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items"
    return no_item


a = 0
days = 0
j = 0
i = 0
do_days1 = ['5'] * 3 + ['6'] * 55 + ['0'] * 42
do_days = random.choice(do_days1)
dict = {'5': 'Friday', '6': 'Saturday', '0': 'Sunday'}
print "| use rice_cooker in next week on | ... ",dict[do_days]
off_item = rand_turnon()  
no_item = rand_duration()


while (j <= (5760*d)-1):
    no_days = int(time_b[j].strftime('%w'))  # find 0-6 of no_days

    
    if (no_days == 0 and clock1[j] == u'23:59:59'):    #if no_day is SUNDAY at 23:59:59 check d0_days in week 
        do_days1 = ['5'] * 3 + ['6'] * 55 + ['0'] * 42   #fri-sat-sun
        do_days = random.choice(do_days1) 
        dict = {'5': 'Friday', '6': 'Saturday', '0': 'Sunday'}
        print "\n| use rice_cooker in next week on | ... ",dict[do_days]
        off_item = rand_turnon()  
        no_item = rand_duration()


    if (int(do_days) == no_days):
        i= 0  
        c1.execute("INSERT INTO data_month4.rice_cooker (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
        while (off_item+(5760*(days-1))<= j <= (no_item+off_item)+(5760*(days-1))):
            
            if (i >= len(df)):
                i = 400   
                
            c1.execute("INSERT INTO data_month4.rice_cooker (Timestamp, watt) VALUES (%s, %s)",(time_b[j],df.watt[i]))
            conn1.commit()
            i += 1 
            j += 1     
            print "|",j,
            

    else : 
        c1.execute("INSERT INTO data_month4.rice_cooker (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
        
    if (j%5760 == 0):
        print "\nDays :",days ,":",time_b[j].strftime('%a')
        days +=1        
    j += 1
    conn1.commit()
print "DONE!"
# Out:
# data_month4.rice_cooker are Empty!!!
#
# | use rice_cooker in next week on | ...  Sunday
# time to turn-on appliacne on 18 : 43 : 12 equal to 4492 items
# consuming the appliance 0 hours 47 minutes 43 seconds that equal to 2863 seconds or 190 items
#
# Days : 0 : Sun
# | 4493 | 4494 | 4495 | 4496 | 4497 | 4498 | 4499 | 4500 | 4501 | 4502 | 4503 | 4504 | 4505 | 4506 | 4507 | 4508 | 4509 | 4510 | 4511 | 4512 | 4513 | 4514 | 4515 | 4516 | 4517 | 4518 | 4519 | 4520 | 4521 | 4522 | 4523 | 4524 | 4525 | 4526 | 4527 | 4528 | 4529 | 4530 | 4531 | 4532 | 4533 | 4534 | 4535 | 4536 | 4537 | 4538 | 4539 | 4540 | 4541 | 4542 | 4543 | 4544 | 4545 | 4546 | 4547 | 4548 | 4549 | 4550 | 4551 | 4552 | 4553 | 4554 | 4555 | 4556 | 4557 | 4558 | 4559 | 4560 | 4561 | 4562 | 4563 | 4564 | 4565 | 4566 | 4567 | 4568 | 4569 | 4570 | 4571 | 4572 | 4573 | 4574 | 4575 | 4576 | 4577 | 4578 | 4579 | 4580 | 4581 | 4582 | 4583 | 4584 | 4585 | 4586 | 4587 | 4588 | 4589 | 4590 | 4591 | 4592 | 4593 | 4594 | 4595 | 4596 | 4597 | 4598 | 4599 | 4600 | 4601 | 4602 | 4603 | 4604 | 4605 | 4606 | 4607 | 4608 | 4609 | 4610 | 4611 | 4612 | 4613 | 4614 | 4615 | 4616 | 4617 | 4618 | 4619 | 4620 | 4621 | 4622 | 4623 | 4624 | 4625 | 4626 | 4627 | 4628 | 4629 | 4630 | 4631 | 4632 | 4633 | 4634 | 4635 | 4636 | 4637 | 4638 | 4639 | 4640 | 4641 | 4642 | 4643 | 4644 | 4645 | 4646 | 4647 | 4648 | 4649 | 4650 | 4651 | 4652 | 4653 | 4654 | 4655 | 4656 | 4657 | 4658 | 4659 | 4660 | 4661 | 4662 | 4663 | 4664 | 4665 | 4666 | 4667 | 4668 | 4669 | 4670 | 4671 | 4672 | 4673 | 4674 | 4675 | 4676 | 4677 | 4678 | 4679 | 4680 | 4681 | 4682 | 4683
# | use rice_cooker in next week on | ...  Saturday
# time to turn-on appliacne on 18 : 52 : 58 equal to 4531 items
# consuming the appliance 0 hours 44 minutes 34 seconds that equal to 2674 seconds or 178 items
#
# Days : 1 : Mon
#
# Days : 2 : Tue
#
# Days : 3 : Wed
#
# Days : 4 : Thu
#
# Days : 5 : Fri
#
# Days : 6 : Sat
# | 39092 | 39093 | 39094 | 39095 | 39096 | 39097 | 39098 | 39099 | 39100 | 39101 | 39102 | 39103 | 39104 | 39105 | 39106 | 39107 | 39108 | 39109 | 39110 | 39111 | 39112 | 39113 | 39114 | 39115 | 39116 | 39117 | 39118 | 39119 | 39120 | 39121 | 39122 | 39123 | 39124 | 39125 | 39126 | 39127 | 39128 | 39129 | 39130 | 39131 | 39132 | 39133 | 39134 | 39135 | 39136 | 39137 | 39138 | 39139 | 39140 | 39141 | 39142 | 39143 | 39144 | 39145 | 39146 | 39147 | 39148 | 39149 | 39150 | 39151 | 39152 | 39153 | 39154 | 39155 | 39156 | 39157 | 39158 | 39159 | 39160 | 39161 | 39162 | 39163 | 39164 | 39165 | 39166 | 39167 | 39168 | 39169 | 39170 | 39171 | 39172 | 39173 | 39174 | 39175 | 39176 | 39177 | 39178 | 39179 | 39180 | 39181 | 39182 | 39183 | 39184 | 39185 | 39186 | 39187 | 39188 | 39189 | 39190 | 39191 | 39192 | 39193 | 39194 | 39195 | 39196 | 39197 | 39198 | 39199 | 39200 | 39201 | 39202 | 39203 | 39204 | 39205 | 39206 | 39207 | 39208 | 39209 | 39210 | 39211 | 39212 | 39213 | 39214 | 39215 | 39216 | 39217 | 39218 | 39219 | 39220 | 39221 | 39222 | 39223 | 39224 | 39225 | 39226 | 39227 | 39228 | 39229 | 39230 | 39231 | 39232 | 39233 | 39234 | 39235 | 39236 | 39237 | 39238 | 39239 | 39240 | 39241 | 39242 | 39243 | 39244 | 39245 | 39246 | 39247 | 39248 | 39249 | 39250 | 39251 | 39252 | 39253 | 39254 | 39255 | 39256 | 39257 | 39258 | 39259 | 39260 | 39261 | 39262 | 39263 | 39264 | 39265 | 39266 | 39267 | 39268 | 39269 | 39270
# Days : 7 : Sun
#
# | use rice_cooker in next week on | ...  Saturday
# time to turn-on appliacne on 17 : 58 : 15 equal to 4312 items
# consuming the appliance 0 hours 41 minutes 49 seconds that equal to 2509 seconds or 167 items
#
# Days : 8 : Mon
#
# Days : 9 : Tue
#
# Days : 10 : Wed
#
# Days : 11 : Thu
#
# Days : 12 : Fri
#
# Days : 13 : Sat
# | 79193 | 79194 | 79195 | 79196 | 79197 | 79198 | 79199 | 79200 | 79201 | 79202 | 79203 | 79204 | 79205 | 79206 | 79207 | 79208 | 79209 | 79210 | 79211 | 79212 | 79213 | 79214 | 79215 | 79216 | 79217 | 79218 | 79219 | 79220 | 79221 | 79222 | 79223 | 79224 | 79225 | 79226 | 79227 | 79228 | 79229 | 79230 | 79231 | 79232 | 79233 | 79234 | 79235 | 79236 | 79237 | 79238 | 79239 | 79240 | 79241 | 79242 | 79243 | 79244 | 79245 | 79246 | 79247 | 79248 | 79249 | 79250 | 79251 | 79252 | 79253 | 79254 | 79255 | 79256 | 79257 | 79258 | 79259 | 79260 | 79261 | 79262 | 79263 | 79264 | 79265 | 79266 | 79267 | 79268 | 79269 | 79270 | 79271 | 79272 | 79273 | 79274 | 79275 | 79276 | 79277 | 79278 | 79279 | 79280 | 79281 | 79282 | 79283 | 79284 | 79285 | 79286 | 79287 | 79288 | 79289 | 79290 | 79291 | 79292 | 79293 | 79294 | 79295 | 79296 | 79297 | 79298 | 79299 | 79300 | 79301 | 79302 | 79303 | 79304 | 79305 | 79306 | 79307 | 79308 | 79309 | 79310 | 79311 | 79312 | 79313 | 79314 | 79315 | 79316 | 79317 | 79318 | 79319 | 79320 | 79321 | 79322 | 79323 | 79324 | 79325 | 79326 | 79327 | 79328 | 79329 | 79330 | 79331 | 79332 | 79333 | 79334 | 79335 | 79336 | 79337 | 79338 | 79339 | 79340 | 79341 | 79342 | 79343 | 79344 | 79345 | 79346 | 79347 | 79348 | 79349 | 79350 | 79351 | 79352 | 79353 | 79354 | 79355 | 79356 | 79357 | 79358 | 79359 | 79360
# Days : 14 : Sun
#
# | use rice_cooker in next week on | ...  Sunday
# time to turn-on appliacne on 17 : 7 : 35 equal to 4110 items
# consuming the appliance 0 hours 40 minutes 33 seconds that equal to 2433 seconds or 162 items
#
# Days : 15 : Mon
#
# Days : 16 : Tue
#
# Days : 17 : Wed
#
# Days : 18 : Thu
#
# Days : 19 : Fri
#
# Days : 20 : Sat
#
# Days : 21 : Sun
# | 125071 | 125072 | 125073 | 125074 | 125075 | 125076 | 125077 | 125078 | 125079 | 125080 | 125081 | 125082 | 125083 | 125084 | 125085 | 125086 | 125087 | 125088 | 125089 | 125090 | 125091 | 125092 | 125093 | 125094 | 125095 | 125096 | 125097 | 125098 | 125099 | 125100 | 125101 | 125102 | 125103 | 125104 | 125105 | 125106 | 125107 | 125108 | 125109 | 125110 | 125111 | 125112 | 125113 | 125114 | 125115 | 125116 | 125117 | 125118 | 125119 | 125120 | 125121 | 125122 | 125123 | 125124 | 125125 | 125126 | 125127 | 125128 | 125129 | 125130 | 125131 | 125132 | 125133 | 125134 | 125135 | 125136 | 125137 | 125138 | 125139 | 125140 | 125141 | 125142 | 125143 | 125144 | 125145 | 125146 | 125147 | 125148 | 125149 | 125150 | 125151 | 125152 | 125153 | 125154 | 125155 | 125156 | 125157 | 125158 | 125159 | 125160 | 125161 | 125162 | 125163 | 125164 | 125165 | 125166 | 125167 | 125168 | 125169 | 125170 | 125171 | 125172 | 125173 | 125174 | 125175 | 125176 | 125177 | 125178 | 125179 | 125180 | 125181 | 125182 | 125183 | 125184 | 125185 | 125186 | 125187 | 125188 | 125189 | 125190 | 125191 | 125192 | 125193 | 125194 | 125195 | 125196 | 125197 | 125198 | 125199 | 125200 | 125201 | 125202 | 125203 | 125204 | 125205 | 125206 | 125207 | 125208 | 125209 | 125210 | 125211 | 125212 | 125213 | 125214 | 125215 | 125216 | 125217 | 125218 | 125219 | 125220 | 125221 | 125222 | 125223 | 125224 | 125225 | 125226 | 125227 | 125228 | 125229 | 125230 | 125231 | 125232 | 125233
# | use rice_cooker in next week on | ...  Saturday
# time to turn-on appliacne on 17 : 48 : 12 equal to 4272 items
# consuming the appliance 0 hours 44 minutes 39 seconds that equal to 2679 seconds or 178 items
#
# Days : 22 : Mon
#
# Days : 23 : Tue
#
# Days : 24 : Wed
#
# Days : 25 : Thu
#
# Days : 26 : Fri
#
# Days : 27 : Sat
# | 159793 | 159794 | 159795 | 159796 | 159797 | 159798 | 159799 | 159800 | 159801 | 159802 | 159803 | 159804 | 159805 | 159806 | 159807 | 159808 | 159809 | 159810 | 159811 | 159812 | 159813 | 159814 | 159815 | 159816 | 159817 | 159818 | 159819 | 159820 | 159821 | 159822 | 159823 | 159824 | 159825 | 159826 | 159827 | 159828 | 159829 | 159830 | 159831 | 159832 | 159833 | 159834 | 159835 | 159836 | 159837 | 159838 | 159839 | 159840 | 159841 | 159842 | 159843 | 159844 | 159845 | 159846 | 159847 | 159848 | 159849 | 159850 | 159851 | 159852 | 159853 | 159854 | 159855 | 159856 | 159857 | 159858 | 159859 | 159860 | 159861 | 159862 | 159863 | 159864 | 159865 | 159866 | 159867 | 159868 | 159869 | 159870 | 159871 | 159872 | 159873 | 159874 | 159875 | 159876 | 159877 | 159878 | 159879 | 159880 | 159881 | 159882 | 159883 | 159884 | 159885 | 159886 | 159887 | 159888 | 159889 | 159890 | 159891 | 159892 | 159893 | 159894 | 159895 | 159896 | 159897 | 159898 | 159899 | 159900 | 159901 | 159902 | 159903 | 159904 | 159905 | 159906 | 159907 | 159908 | 159909 | 159910 | 159911 | 159912 | 159913 | 159914 | 159915 | 159916 | 159917 | 159918 | 159919 | 159920 | 159921 | 159922 | 159923 | 159924 | 159925 | 159926 | 159927 | 159928 | 159929 | 159930 | 159931 | 159932 | 159933 | 159934 | 159935 | 159936 | 159937 | 159938 | 159939 | 159940 | 159941 | 159942 | 159943 | 159944 | 159945 | 159946 | 159947 | 159948 | 159949 | 159950 | 159951 | 159952 | 159953 | 159954 | 159955 | 159956 | 159957 | 159958 | 159959 | 159960 | 159961 | 159962 | 159963 | 159964 | 159965 | 159966 | 159967 | 159968 | 159969 | 159970 | 159971
# Days : 28 : Sun
#
# | use rice_cooker in next week on | ...  Saturday
# time to turn-on appliacne on 17 : 10 : 56 equal to 4123 items
# consuming the appliance 0 hours 59 minutes 56 seconds that equal to 3596 seconds or 239 items
#
# Days : 29 : Mon
#
# Days : 30 : Tue
# DONE!

# %%
import matplotlib.pyplot as plt
# %matplotlib inline  


# query = "SELECT watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
query = "SELECT Timestamp,watt FROM data_month3.rice_cooker WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[5760],time_b[5760*30])
df = pd.read_sql(query, conn1, index_col=['Timestamp'])
fig, ax = plt.subplots()
ax.set_title('data_month3.rice_cooker')
df.plot(ax=ax )
plt.show()
# df.to_csv('file.csv')
# print len(df)
