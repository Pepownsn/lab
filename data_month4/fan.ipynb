# %% [markdown]
# ## data_month4
# #### FAN | พัดลมตั้งพื้น 16 นิ้ว |

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random


d = 31

time_a = pd.date_range('2017-01-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2017-01-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####### set databases to empty #########
query_empty = """truncate table data_month4.fan""" 
c.execute(query_empty)
print "data_month4.fan are Empty!!! \n"

query = "SELECT watt FROM collected_info.2_fan WHERE no >= '%s'   AND no <= '%s'; "% (0,1016)
df = pd.read_sql(query, conn)
# print df.watt[5]

#### Random the number of turnon-time per day
def manytime():
    many  = ['1'] * 50 + ['2'] * 44 + ['3'] * 6  ## The number of turn-on time of this appliance 
    manytime = random.choice(many)
    print "\nDays :",days-1 ,":",time_b[j].strftime('%a')
    print "in recent day turn on fan",manytime,"times\n"
    if (int(manytime) == 1):
        x,y,endx,endy = 18,20,2,4  # fix turn on only in evening      
        open_hour =  random.randint(x, y)
        open_min =  random.randint(0, 59)
        open_sec =  random.randint(0, 59)
        if 0 < open_sec  <= 15:
            k = 0
        elif 15 < open_sec  <= 30:
            k = 1
        elif 30 < open_sec  <= 45:
            k = 2
        else:
            k = 3
        off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
        print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
        
        duration_hour =  random.randint(endx, endy)
        duration_min =  random.randint(0, 59)
        duration_sec =  random.randint(0, 59)
        seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
        no_item = seconds/15
        print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"
        return (off_item,no_item)

        
    elif (int(manytime) == 2):
        turn_duratrion  = ['1'] * 70 + ['2'] * 30       #### '1' turn-on morning and evening   OR  '2' turn-on 2 times in evening 
        howturn = random.choice(turn_duratrion)
#         print howturn
        if (int(howturn)== 1 ):
            x,y,endx,endy = 6,7,1,59
            open_hour =  random.randint(x, y)
            open_min =  random.randint(0, 59)
            open_sec =  random.randint(0, 59)
            if 0 < open_sec  <= 15:
                k = 0
            elif 15 < open_sec  <= 30:
                k = 1
            elif 30 < open_sec  <= 45:
                k = 2
            else:
                k = 3
            off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
            print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
            
            duration_hour =  random.randint(0, 0)
            duration_min =  random.randint(endx, endy)
            duration_sec =  random.randint(0, 59)
            seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
            no_item = seconds/15
            print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"

        
            
            x1,y1,endx1,endy1 = 18,20,2,4
            open_hour1 =  random.randint(x1, y1)
            open_min1 =  random.randint(0, 59)
            open_sec1 =  random.randint(0, 59)
            if 0 < open_sec1  <= 15:
                k = 0
            elif 15 < open_sec1  <= 30:
                k = 1
            elif 30 < open_sec1  <= 45:
                k = 2
            else:
                k = 3
            off_item1 = (int(open_hour1)*240) + (int(open_min1)*4)+ k 
            print "time to turn-on appliacne on",open_hour1,":",open_min1,":",open_sec1,"equal to",off_item1,"items"     
            
            duration_hour1 =  random.randint(endx1, endy1)
            duration_min1 =  random.randint(0, 59)
            duration_sec1 =  random.randint(0, 59)
            seconds1 = (duration_hour1*3600)+(duration_min1*60)+duration_sec1
            no_item1 = seconds1/15
            print "consuming the appliance", duration_hour1,"hours",duration_min1,"minutes",duration_sec1,"seconds that equal to",seconds1,"seconds or",no_item1,"items\n"

        else :
            x,y,endx,endy = 18,19,1,59
            open_hour =  random.randint(x, y)
            open_min =  random.randint(0, 59)
            open_sec =  random.randint(0, 59)
            if 0 < open_sec  <= 15:
                k = 0
            elif 15 < open_sec  <= 30:
                k = 1
            elif 30 < open_sec  <= 45:
                k = 2
            else:
                k = 3
            off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
            print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
            
            duration_hour =  random.randint(0, 0)
            duration_min =  random.randint(endx, endy)
            duration_sec =  random.randint(0, 59)
            seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
            no_item = seconds/15
            print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"

        
            x1,y1,endx1,endy1 = 20,22,1,4
            open_hour1 =  random.randint(x1, y1)
            open_min1 =  random.randint(0, 59)
            open_sec1 =  random.randint(0, 59)
            if 0 < open_sec1  <= 15:
                k = 0
            elif 15 < open_sec1  <= 30:
                k = 1
            elif 30 < open_sec1  <= 45:
                k = 2
            else:
                k = 3
            off_item1 = (int(open_hour1)*240) + (int(open_min1)*4)+ k 
            print "time to turn-on appliacne on",open_hour1,":",open_min1,":",open_sec1,"equal to",off_item1,"items"   
            
            duration_hour1 =  random.randint(endx1, endy1)
            duration_min1 =  random.randint(0, 59)
            duration_sec1 =  random.randint(0, 59)
            seconds1 = (duration_hour1*3600)+(duration_min1*60)+duration_sec1
            no_item1 = seconds1/15
            print "consuming the appliance", duration_hour1,"hours",duration_min1,"minutes",duration_sec1,"seconds that equal to",seconds1,"seconds or",no_item1,"items\n"

        return (off_item,no_item,off_item1,no_item1)        
    else:
        x,y,endx,endy = 6,7,30,60
        open_hour =  random.randint(x, y)
        open_min =  random.randint(0, 59)
        open_sec =  random.randint(0, 59)
        if 0 < open_sec  <= 15:
            k = 0
        elif 15 < open_sec  <= 30:
            k = 1
        elif 30 < open_sec  <= 45:
            k = 2
        else:
            k = 3
        off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
        print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
        
        duration_hour =  random.randint(0,0)
        duration_min =  random.randint(endx, endy)
        duration_sec =  random.randint(0, 59)
        seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
        no_item = seconds/15
        print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"

    
    
        x1,y1,endx1,endy1 = 18,19,1,59
        open_hour1 =  random.randint(x1, y1)
        open_min1 =  random.randint(0, 59)
        open_sec1 =  random.randint(0, 59)
        if 0 < open_sec1  <= 15:
            k = 0
        elif 15 < open_sec1  <= 30:
            k = 1
        elif 30 < open_sec1  <= 45:
            k = 2
        else:
            k = 3
        off_item1 = (int(open_hour1)*240) + (int(open_min1)*4)+ k 
        print "time to turn-on appliacne on",open_hour1,":",open_min1,":",open_sec1,"equal to",off_item1,"items" 
        duration_hour1 =  random.randint(0, 0)
        duration_min1 =  random.randint(endx1, endy1)
        duration_sec1 =  random.randint(0, 59)
        seconds1 = (duration_hour1*3600)+(duration_min1*60)+duration_sec1
        no_item1 = seconds1/15
        print "consuming the appliance", duration_hour1,"hours",duration_min1,"minutes",duration_sec1,"seconds that equal to",seconds1,"seconds or",no_item1,"items\n"
    
    
        x2,y2,endx2,endy2 = 20,22,1,4
        open_hour2 =  random.randint(x2, y2)
        open_min2 =  random.randint(0, 59)
        open_sec2 =  random.randint(0, 59)
        if 0 < open_sec2  <= 15:
            k = 0
        elif 15 < open_sec2  <= 30:
            k = 1
        elif 30 < open_sec2  <= 45:
            k = 2
        else:
            k = 3
        off_item2 = (int(open_hour2)*240) + (int(open_min2)*4)+ k 
        print "time to turn-on appliacne on",open_hour2,":",open_min2,":",open_sec2,"equal to",off_item2,"items" 
        duration_hour2 =  random.randint(endx2, endy2)
        duration_min2 =  random.randint(0, 59)
        duration_sec2 =  random.randint(0, 59)
        seconds2 = (duration_hour2*3600)+(duration_min2*60)+duration_sec2
        no_item2 = seconds2/15
        print "consuming the appliance", duration_hour2,"hours",duration_min2,"minutes",duration_sec2,"seconds that equal to",seconds2,"seconds or",no_item2,"items\n"
        return (off_item,no_item,off_item1,no_item1,off_item2,no_item2)    
    
    
        
days = 1
j = 0

## (off_item,no_item,off_item1,no_item1,off_item2,no_item2)    

turn = manytime()
while (j <= (5760*d)-1):   
    if (j == 5760+(5760*(days-1))):
        days +=1
        print "-------------------------ENd-----------------------------\n"
        turn = manytime()          
        
    if len(turn)==2:
        off_item = turn[0] 
        no_item = turn[1]
        if (off_item+(5760*(days-1)) <= j <= (no_item+off_item)+(5760*(days-1))):
            c.execute("INSERT INTO data_month4.fan (Timestamp, watt) VALUES (%s, %s)",(time_b[j],random.randint(64, 68)))
            conn.commit()
            j += 1
        else:
            c.execute("INSERT INTO data_month4.fan (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
            conn.commit()
            j += 1
        
    elif len(turn)==4:
        off_item = turn[0] 
        no_item = turn[1]
        off_item1 = turn[2] 
        no_item1 = turn[3]
        if (off_item+(5760*(days-1)) <= j <= (no_item+off_item)+(5760*(days-1)) or off_item1+(5760*(days-1)) <= j <= (no_item1+off_item1)+(5760*(days-1))):
            c.execute("INSERT INTO data_month4.fan (Timestamp, watt) VALUES (%s, %s)",(time_b[j],random.randint(64, 68)))
            conn.commit()
            j += 1
        else:
            c.execute("INSERT INTO data_month4.fan (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
            conn.commit()
            j += 1
             
    else:
        off_item = turn[0] 
        no_item = turn[1]
        off_item1 = turn[2] 
        no_item1 = turn[3]
        off_item2 = turn[4] 
        no_item2 = turn[5]
        
        if (off_item+(5760*(days-1)) <= j <= (no_item+off_item)+(5760*(days-1)) or off_item1+(5760*(days-1)) <= j <= (no_item1+off_item1)+(5760*(days-1)) or off_item2+(5760*(days-1)) <= j <= (no_item2+off_item2)+(5760*(days-1)))  :
            c.execute("INSERT INTO data_month4.fan (Timestamp, watt) VALUES (%s, %s)",(time_b[j],random.randint(64, 68)))
            conn.commit()
            j += 1
        else:
            c.execute("INSERT INTO data_month4.fan (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
            conn.commit()
            j += 1
 
           
print "DONE!"
# Out:
# data_month4.fan are Empty!!!
#
#
# Days : 0 : Sun
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 7 : 16 : 32 equal to 1746 items
# consuming the appliance 0 hours 58 minutes 40 seconds that equal to 3520 seconds or 234 items
#
# time to turn-on appliacne on 18 : 59 : 44 equal to 4558 items
# consuming the appliance 3 hours 32 minutes 23 seconds that equal to 12743 seconds or 849 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 1 : Mon
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 6 : 51 : 19 equal to 1645 items
# consuming the appliance 0 hours 24 minutes 9 seconds that equal to 1449 seconds or 96 items
#
# time to turn-on appliacne on 20 : 31 : 55 equal to 4927 items
# consuming the appliance 4 hours 30 minutes 13 seconds that equal to 16213 seconds or 1080 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 2 : Tue
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 20 : 3 : 3 equal to 4812 items
# consuming the appliance 4 hours 4 minutes 4 seconds that equal to 14644 seconds or 976 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 3 : Wed
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 19 : 41 : 31 equal to 4726 items
# consuming the appliance 0 hours 53 minutes 36 seconds that equal to 3216 seconds or 214 items
#
# time to turn-on appliacne on 21 : 5 : 56 equal to 5063 items
# consuming the appliance 2 hours 4 minutes 38 seconds that equal to 7478 seconds or 498 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 4 : Thu
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 19 : 39 : 21 equal to 4717 items
# consuming the appliance 3 hours 23 minutes 47 seconds that equal to 12227 seconds or 815 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 5 : Fri
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 6 : 24 : 11 equal to 1536 items
# consuming the appliance 0 hours 48 minutes 52 seconds that equal to 2932 seconds or 195 items
#
# time to turn-on appliacne on 20 : 41 : 45 equal to 4966 items
# consuming the appliance 3 hours 47 minutes 46 seconds that equal to 13666 seconds or 911 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 6 : Sat
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 20 : 49 : 51 equal to 4999 items
# consuming the appliance 3 hours 35 minutes 51 seconds that equal to 12951 seconds or 863 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 7 : Sun
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 6 : 30 : 28 equal to 1561 items
# consuming the appliance 0 hours 50 minutes 44 seconds that equal to 3044 seconds or 202 items
#
# time to turn-on appliacne on 19 : 35 : 13 equal to 4700 items
# consuming the appliance 2 hours 1 minutes 32 seconds that equal to 7292 seconds or 486 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 8 : Mon
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 18 : 41 : 8 equal to 4484 items
# consuming the appliance 2 hours 50 minutes 37 seconds that equal to 10237 seconds or 682 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 9 : Tue
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 6 : 46 : 39 equal to 1626 items
# consuming the appliance 0 hours 11 minutes 0 seconds that equal to 660 seconds or 44 items
#
# time to turn-on appliacne on 19 : 43 : 34 equal to 4734 items
# consuming the appliance 2 hours 25 minutes 51 seconds that equal to 8751 seconds or 583 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 10 : Wed
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 19 : 4 : 34 equal to 4578 items
# consuming the appliance 0 hours 57 minutes 44 seconds that equal to 3464 seconds or 230 items
#
# time to turn-on appliacne on 21 : 0 : 19 equal to 5041 items
# consuming the appliance 3 hours 12 minutes 21 seconds that equal to 11541 seconds or 769 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 11 : Thu
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 19 : 29 : 59 equal to 4679 items
# consuming the appliance 3 hours 43 minutes 59 seconds that equal to 13439 seconds or 895 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 12 : Fri
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 19 : 47 : 23 equal to 4749 items
# consuming the appliance 2 hours 33 minutes 39 seconds that equal to 9219 seconds or 614 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 13 : Sat
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 6 : 30 : 57 equal to 1563 items
# consuming the appliance 0 hours 30 minutes 30 seconds that equal to 1830 seconds or 122 items
#
# time to turn-on appliacne on 18 : 46 : 39 equal to 4506 items
# consuming the appliance 3 hours 14 minutes 22 seconds that equal to 11662 seconds or 777 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 14 : Sun
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 7 : 28 : 42 equal to 1794 items
# consuming the appliance 0 hours 31 minutes 31 seconds that equal to 1891 seconds or 126 items
#
# time to turn-on appliacne on 20 : 35 : 56 equal to 4943 items
# consuming the appliance 4 hours 55 minutes 28 seconds that equal to 17728 seconds or 1181 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 15 : Mon
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 20 : 12 : 57 equal to 4851 items
# consuming the appliance 4 hours 6 minutes 9 seconds that equal to 14769 seconds or 984 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 16 : Tue
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 7 : 29 : 53 equal to 1799 items
# consuming the appliance 0 hours 38 minutes 34 seconds that equal to 2314 seconds or 154 items
#
# time to turn-on appliacne on 19 : 22 : 53 equal to 4651 items
# consuming the appliance 3 hours 9 minutes 3 seconds that equal to 11343 seconds or 756 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 17 : Wed
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 19 : 37 : 39 equal to 4710 items
# consuming the appliance 0 hours 20 minutes 4 seconds that equal to 1204 seconds or 80 items
#
# time to turn-on appliacne on 20 : 12 : 59 equal to 4851 items
# consuming the appliance 2 hours 24 minutes 19 seconds that equal to 8659 seconds or 577 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 18 : Thu
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 18 : 12 : 24 equal to 4369 items
# consuming the appliance 4 hours 35 minutes 0 seconds that equal to 16500 seconds or 1100 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 19 : Fri
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 6 : 2 : 15 equal to 1448 items
# consuming the appliance 0 hours 29 minutes 57 seconds that equal to 1797 seconds or 119 items
#
# time to turn-on appliacne on 20 : 35 : 42 equal to 4942 items
# consuming the appliance 3 hours 12 minutes 51 seconds that equal to 11571 seconds or 771 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 20 : Sat
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 19 : 55 : 3 equal to 4780 items
# consuming the appliance 0 hours 8 minutes 38 seconds that equal to 518 seconds or 34 items
#
# time to turn-on appliacne on 22 : 44 : 51 equal to 5459 items
# consuming the appliance 1 hours 46 minutes 54 seconds that equal to 6414 seconds or 427 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 21 : Sun
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 18 : 47 : 53 equal to 4511 items
# consuming the appliance 0 hours 15 minutes 23 seconds that equal to 923 seconds or 61 items
#
# time to turn-on appliacne on 20 : 34 : 15 equal to 4936 items
# consuming the appliance 1 hours 0 minutes 50 seconds that equal to 3650 seconds or 243 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 22 : Mon
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 19 : 5 : 30 equal to 4581 items
# consuming the appliance 4 hours 31 minutes 24 seconds that equal to 16284 seconds or 1085 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 23 : Tue
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 6 : 2 : 52 equal to 1451 items
# consuming the appliance 0 hours 6 minutes 44 seconds that equal to 404 seconds or 26 items
#
# time to turn-on appliacne on 18 : 37 : 37 equal to 4470 items
# consuming the appliance 2 hours 46 minutes 31 seconds that equal to 9991 seconds or 666 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 24 : Wed
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 18 : 53 : 59 equal to 4535 items
# consuming the appliance 0 hours 23 minutes 29 seconds that equal to 1409 seconds or 93 items
#
# time to turn-on appliacne on 22 : 59 : 5 equal to 5516 items
# consuming the appliance 3 hours 41 minutes 47 seconds that equal to 13307 seconds or 887 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 25 : Thu
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 7 : 16 : 28 equal to 1745 items
# consuming the appliance 0 hours 29 minutes 53 seconds that equal to 1793 seconds or 119 items
#
# time to turn-on appliacne on 18 : 22 : 37 equal to 4410 items
# consuming the appliance 3 hours 37 minutes 17 seconds that equal to 13037 seconds or 869 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 26 : Fri
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 18 : 5 : 0 equal to 4343 items
# consuming the appliance 0 hours 6 minutes 24 seconds that equal to 384 seconds or 25 items
#
# time to turn-on appliacne on 21 : 39 : 4 equal to 5196 items
# consuming the appliance 4 hours 27 minutes 42 seconds that equal to 16062 seconds or 1070 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 27 : Sat
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 19 : 33 : 35 equal to 4694 items
# consuming the appliance 2 hours 20 minutes 26 seconds that equal to 8426 seconds or 561 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 28 : Sun
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 7 : 12 : 8 equal to 1728 items
# consuming the appliance 0 hours 29 minutes 10 seconds that equal to 1750 seconds or 116 items
#
# time to turn-on appliacne on 19 : 23 : 42 equal to 4654 items
# consuming the appliance 2 hours 52 minutes 57 seconds that equal to 10377 seconds or 691 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 29 : Mon
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 19 : 55 : 47 equal to 4783 items
# consuming the appliance 4 hours 4 minutes 24 seconds that equal to 14664 seconds or 977 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 30 : Tue
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 20 : 13 : 54 equal to 4855 items
# consuming the appliance 2 hours 25 minutes 19 seconds that equal to 8719 seconds or 581 items
#
# DONE!

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
# %matplotlib inline  


# query = "SELECT watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
query = "SELECT Timestamp,watt FROM data_month3.fan WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[5760*12])
df = pd.read_sql(query, conn, index_col=['Timestamp'])
fig, ax = plt.subplots()
ax.set_title('data_month3.fan')
df.plot(ax=ax )
plt.show()
