# %%
import pandas as pd
import matplotlib.pyplot as plt
import MySQLdb
import time

j = 0
d = 0 #Day
all_p = 0
min_p = 0

conn= MySQLdb.connect("54.169.29.169","conn","hems","power")
c = conn.cursor()

conn1= MySQLdb.connect("localhost","conn","hems","power")
c1 = conn1.cursor()
 
# query_empty = """truncate table watt.unit_per_hr_sum""" 
# c.execute(query_empty)
# print "watt.unit_per_hr_sum are Empty!!! \n"
        
while(True):
    clock = time.strftime("%M:%S")
    if (clock == '56:00'):
        print "hello"
        j+=1
    else:
#         time.sleep(1)
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# ...

# %%
clock = time.strftime("%M:%S")
clock
# Out:
# '36:54'
