# %% [markdown]
# # data_TIMELInE
# ### Hair_dryer | ขนาด ??? |

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random


d = 31
time_a = pd.date_range('2016-10-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-10-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####### set databases to empty #########
query_empty = """truncate table data_timeline.hair_dryer""" 
c.execute(query_empty)
print "data_timeline.elec_thermos are Empty!!! \n"

query = "SELECT watt FROM collected_info.11_hair_dryer WHERE no >= '%s'   AND no <= '%s'; "% (0,1200)
df = pd.read_sql(query, conn)
# print df.watt[5]

#### Random the turning-on time appliances
def rand_turnon():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(0, 59)
    duration_hour1 = ['21'] * 40 + ['22'] *45 + ['23'] * 15
    duration_hour = random.choice(duration_hour1)     
    if 0 < duration_sec <= 15:
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
    off_item = (int(duration_hour)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on appliacne on",duration_hour,":",duration_min,":",duration_sec,"equal to",off_item,"items"
    return off_item

 
#### Random the off-duration appliances 
def rand_duration():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(30, 59)
    duration_hour1 = ['0'] * 50 + ['1'] * 1+ ['0'] * 49
    duration_hour = random.choice(duration_hour1)   
    seconds = (int(duration_hour)*3600)+(duration_min*60)+duration_sec
    no_item = seconds/15
    print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items"
    return no_item

days = 0
j = 0
i = 0
print "\nDays :",days ,":",time_b[j].strftime('%a')
off_item = rand_turnon()  
no_item = rand_duration()  

while (j <= (5760*d)-1):  
    c.execute("INSERT INTO data_timeline.hair_dryer (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
    conn.commit()
    j += 1 
    
    while (off_item+(5760*(days)) <= j <= (no_item+off_item)+(5760*(days))):                   
        c.execute("INSERT INTO data_timeline.hair_dryer (Timestamp, watt) VALUES (%s, %s)",(time_b[j],df.watt[i]))
        conn.commit()
        i += 1 
        j += 1
        if (j == (no_item+off_item)+(5760*(days))):
            days +=1
            print "\nDays :",days ,":",time_b[j].strftime('%a')
            off_item = rand_turnon()  
            no_item = rand_duration() 
            i= 0   

                    
print "DONE!"
# Out:
# data_timeline.elec_thermos are Empty!!!
#
#
# Days : 0 : Sat
# time to turn-on appliacne on 22 : 20 : 29 equal to 5361 items
# consuming the appliance 0 hours 40 minutes 16 seconds that equal to 2416 seconds or 161 items
#
# Days : 1 : Sat
# time to turn-on appliacne on 22 : 5 : 56 equal to 5303 items
# consuming the appliance 0 hours 45 minutes 40 seconds that equal to 2740 seconds or 182 items
#
# Days : 2 : Sun
# time to turn-on appliacne on 21 : 23 : 42 equal to 5134 items
# consuming the appliance 0 hours 37 minutes 45 seconds that equal to 2265 seconds or 151 items
#
# Days : 3 : Mon
# time to turn-on appliacne on 23 : 31 : 11 equal to 5644 items
# consuming the appliance 0 hours 56 minutes 17 seconds that equal to 3377 seconds or 225 items
#
# Days : 4 : Wed
# time to turn-on appliacne on 22 : 24 : 19 equal to 5377 items
# consuming the appliance 0 hours 43 minutes 23 seconds that equal to 2603 seconds or 173 items
#
# Days : 5 : Wed
# time to turn-on appliacne on 23 : 0 : 25 equal to 5521 items
# consuming the appliance 0 hours 54 minutes 1 seconds that equal to 3241 seconds or 216 items
#
# Days : 6 : Thu
# time to turn-on appliacne on 21 : 28 : 2 equal to 5152 items
# consuming the appliance 0 hours 37 minutes 4 seconds that equal to 2224 seconds or 148 items
#
# Days : 7 : Fri
# time to turn-on appliacne on 21 : 33 : 5 equal to 5172 items
# consuming the appliance 0 hours 31 minutes 21 seconds that equal to 1881 seconds or 125 items
#
# Days : 8 : Sat
# time to turn-on appliacne on 23 : 1 : 29 equal to 5525 items
# consuming the appliance 0 hours 54 minutes 30 seconds that equal to 3270 seconds or 218 items
#
# Days : 9 : Sun
# time to turn-on appliacne on 22 : 18 : 51 equal to 5355 items
# consuming the appliance 0 hours 47 minutes 21 seconds that equal to 2841 seconds or 189 items
#
# Days : 10 : Mon
# time to turn-on appliacne on 22 : 26 : 33 equal to 5386 items
# consuming the appliance 0 hours 51 minutes 0 seconds that equal to 3060 seconds or 204 items
#
# Days : 11 : Tue
# time to turn-on appliacne on 21 : 15 : 58 equal to 5103 items
# consuming the appliance 0 hours 37 minutes 49 seconds that equal to 2269 seconds or 151 items
#
# Days : 12 : Wed
# time to turn-on appliacne on 22 : 21 : 6 equal to 5364 items
# consuming the appliance 0 hours 45 minutes 12 seconds that equal to 2712 seconds or 180 items
#
# Days : 13 : Thu
# time to turn-on appliacne on 22 : 51 : 22 equal to 5485 items
# consuming the appliance 0 hours 32 minutes 57 seconds that equal to 1977 seconds or 131 items
#
# Days : 14 : Fri
# time to turn-on appliacne on 21 : 47 : 25 equal to 5229 items
# consuming the appliance 0 hours 59 minutes 50 seconds that equal to 3590 seconds or 239 items
#
# Days : 15 : Sat
# time to turn-on appliacne on 21 : 42 : 28 equal to 5209 items
# consuming the appliance 0 hours 50 minutes 35 seconds that equal to 3035 seconds or 202 items
#
# Days : 16 : Sun
# time to turn-on appliacne on 21 : 26 : 31 equal to 5146 items
# consuming the appliance 0 hours 40 minutes 30 seconds that equal to 2430 seconds or 162 items
#
# Days : 17 : Mon
# time to turn-on appliacne on 21 : 56 : 21 equal to 5265 items
# consuming the appliance 0 hours 31 minutes 26 seconds that equal to 1886 seconds or 125 items
#
# Days : 18 : Tue
# time to turn-on appliacne on 23 : 51 : 23 equal to 5725 items
# consuming the appliance 0 hours 58 minutes 13 seconds that equal to 3493 seconds or 232 items
#
# Days : 19 : Thu
# time to turn-on appliacne on 22 : 8 : 33 equal to 5314 items
# consuming the appliance 0 hours 58 minutes 58 seconds that equal to 3538 seconds or 235 items
#
# Days : 20 : Thu
# time to turn-on appliacne on 21 : 13 : 55 equal to 5095 items
# consuming the appliance 0 hours 41 minutes 2 seconds that equal to 2462 seconds or 164 items
#
# Days : 21 : Fri
# time to turn-on appliacne on 22 : 27 : 22 equal to 5389 items
# consuming the appliance 0 hours 54 minutes 2 seconds that equal to 3242 seconds or 216 items
#
# Days : 22 : Sat
# time to turn-on appliacne on 21 : 44 : 19 equal to 5217 items
# consuming the appliance 0 hours 48 minutes 57 seconds that equal to 2937 seconds or 195 items
#
# Days : 23 : Sun
# time to turn-on appliacne on 22 : 56 : 54 equal to 5507 items
# consuming the appliance 0 hours 31 minutes 31 seconds that equal to 1891 seconds or 126 items
#
# Days : 24 : Mon
# time to turn-on appliacne on 21 : 31 : 31 equal to 5166 items
# consuming the appliance 0 hours 40 minutes 4 seconds that equal to 2404 seconds or 160 items
#
# Days : 25 : Tue
# time to turn-on appliacne on 22 : 42 : 50 equal to 5451 items
# consuming the appliance 0 hours 30 minutes 0 seconds that equal to 1800 seconds or 120 items
#
# Days : 26 : Wed
# time to turn-on appliacne on 23 : 17 : 39 equal to 5590 items
# consuming the appliance 0 hours 36 minutes 34 seconds that equal to 2194 seconds or 146 items
#
# Days : 27 : Thu
# time to turn-on appliacne on 21 : 0 : 22 equal to 5041 items
# consuming the appliance 0 hours 41 minutes 32 seconds that equal to 2492 seconds or 166 items
#
# Days : 28 : Fri
# time to turn-on appliacne on 22 : 17 : 25 equal to 5349 items
# consuming the appliance 0 hours 58 minutes 33 seconds that equal to 3513 seconds or 234 items
#
# Days : 29 : Sat
# time to turn-on appliacne on 23 : 35 : 10 equal to 5660 items
# consuming the appliance 0 hours 57 minutes 1 seconds that equal to 3421 seconds or 228 items
#
# Days : 30 : Mon
# time to turn-on appliacne on 21 : 27 : 19 equal to 5149 items
# consuming the appliance 0 hours 56 minutes 51 seconds that equal to 3411 seconds or 227 items
#
# Days : 31 : Mon
# time to turn-on appliacne on 23 : 0 : 28 equal to 5521 items
# consuming the appliance 0 hours 43 minutes 41 seconds that equal to 2621 seconds or 174 items
# DONE!

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
# %matplotlib inline  


# query = "SELECT watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
query = "SELECT Timestamp,watt FROM data_timeline.hair_dryer WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[5000],time_b[5760*3])
df = pd.read_sql(query, conn, index_col=['Timestamp'])
fig, ax = plt.subplots()
ax.set_title('data_timeline.hair_dryer')
df.plot(ax=ax )
plt.show()
