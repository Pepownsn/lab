# %% [markdown]
# # data_TIMELInE
# ### ระบบหลอดไฟส่องสว่าง | LED 7 Watt |

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random



d =31
time_a = pd.date_range('2016-10-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-10-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####### set databases to empty #########
query_empty = """truncate table data_timeline.light_sys1""" 
c.execute(query_empty)
print "data_timeline.light_sys1 are Empty!!! \n"

query = "SELECT watt FROM collected_info.15_light_sys WHERE no >= '%s'   AND no <= '%s'; "% (0,1500)
df = pd.read_sql(query, conn)

## set no.of light = 2:ห้องน้ำ || 4:ห้องนอน || 2:ห้องครัว || 4 ห้องนั่งเล่น  


def bed():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(0, 59)
    random_bed =   ['20'] * 45 + ['21'] * 50  + ['22'] * 5  
    on_bed = random.choice(random_bed) 
    
    if 0 < duration_sec <= 15 :
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
        
    start_bed = (int(on_bed)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on lamp at bedroom on",on_bed,":",duration_min,":",duration_sec,"equal to", start_bed,"items"
           
    duration_hour1 = ['1'] * 5 + ['2'] * 15 + ['3'] * 42  + ['4'] * 38 
    duration_hour = int(random.choice(duration_hour1))    
    duration_min =  random.randint(0, 59)
    duration_sec =  random.randint(0, 59)
    seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
    no_item_bed = seconds/15
    print "consuming the lamp", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item_bed,"items\n"
    return (start_bed,no_item_bed)

def living():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(0, 59)
    random_living = ['17'] * 25 + ['18'] * 55 + ['19'] * 20
    on_living = random.choice(random_living)   
                    
    if 0 < duration_sec <= 15:
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
    start_living = (int(on_living)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on lamp at living-room on",on_living,":",duration_min,":",duration_sec,"equal to", start_living,"items"
           
    duration_hour1 =  ['2'] * 5 + ['3'] * 65 + ['4'] *25 + ['5'] * 5
    duration_hour = int(random.choice(duration_hour1))        
    duration_min =  random.randint(0, 59)
    duration_sec =  random.randint(0, 59)
    seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
    no_item_living = seconds/15
    print "consuming the lamp", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item_living,"items\n"
    return (start_living,no_item_living)

def kitchen():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(0, 59)
    random_kitc = ['17'] * 60 + ['18'] * 25 + ['19'] * 10  + ['20'] * 5  
    on_kitc = random.choice(random_kitc)     
    
    if 0 < duration_sec <= 15:
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
    start_kitc = (int(on_kitc)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on lamp at kitchen on",on_kitc,":",duration_min,":",duration_sec,"equal to", start_kitc,"items"
           
    duration_hour1 = ['1'] * 60 + ['2'] * 40
    duration_hour = int(random.choice(duration_hour1))      
    duration_min =  random.randint(0, 59)
    duration_sec =  random.randint(0, 59)
    seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
    no_item_kitc= seconds/15
    print "consuming the lamp", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item_kitc,"items\n"
    return (start_kitc,no_item_kitc)


j = 0
days = 0

while (j <= (5760*d)-1): 
            
    if (j%5760 == 0):
        print "\nDays :",days ,":",time_b[j].strftime('%a')
        days +=1        
        turn_bed = bed()
        turn_living = living()
        turn_kitchen = kitchen()
    
    if int(turn_bed[0])+(5760*(days-1) )<= j <= (int(turn_bed[0])+int(turn_bed[1]))+(5760*(days-1) )and int(turn_kitchen[0])+(5760*(days-1)) <= j <= (int(turn_kitchen[0])+int(turn_kitchen[1]))+(5760*(days-1))and int(turn_living[0])+(5760*(days-1)) <= j <= (int(turn_living[0])+int(turn_living[1]))+(5760*(days-1)):
        c.execute("INSERT INTO data_timeline.light_sys1 (Timestamp, watt_bed,watt_living, watt_kitc) VALUES (%s, %s, %s, %s)",(time_b[j],4,4,2))
        
    elif  int(turn_bed[0])+(5760*(days-1)) <= j <= (int(turn_bed[0])+int(turn_bed[1]))+(5760*(days-1)) and int(turn_living[0])+(5760*(days-1)) <= j <= (int(turn_living[0])+int(turn_living[1]))+(5760*(days-1)):
        c.execute("INSERT INTO data_timeline.light_sys1 (Timestamp, watt_bed,watt_living, watt_kitc) VALUES (%s, %s, %s, %s)",(time_b[j],4,4,0))      
        
    elif  int(turn_kitchen[0])+(5760*(days-1)) <= j <= (int(turn_kitchen[0])+int(turn_kitchen[1]))+(5760*(days-1)) and int(turn_living[0])+(5760*(days-1)) <= j <= (int(turn_living[0])+int(turn_living[1]))+(5760*(days-1)):
        c.execute("INSERT INTO data_timeline.light_sys1 (Timestamp, watt_bed,watt_living, watt_kitc) VALUES (%s, %s, %s, %s)",(time_b[j],0,4,2))
        
    elif  int(turn_bed[0])+(5760*(days-1)) <= j <=(int(turn_bed[0])+int(turn_bed[1]))+(5760*(days-1)) and int(turn_kitchen[0])+(5760*(days-1)) <= j <= (int(turn_kitchen[0])+int(turn_kitchen[1]))+(5760*(days-1)):
        c.execute("INSERT INTO data_timeline.light_sys1(Timestamp, watt_bed,watt_living, watt_kitc) VALUES (%s, %s, %s, %s)",(time_b[j],4,0,2))
      
    elif  int(turn_bed[0])+(5760*(days-1)) <= j <= (int(turn_bed[0])+int(turn_bed[1]))+(5760*(days-1)):
        c.execute("INSERT INTO data_timeline.light_sys1 (Timestamp, watt_bed,watt_living, watt_kitc) VALUES (%s, %s, %s, %s)",(time_b[j],4,0,0))
        
    elif int(turn_living[0])+(5760*(days-1) )<= j <= (int(turn_living[0])+int(turn_living[1]))+(5760*(days-1)):
        c.execute("INSERT INTO data_timeline.light_sys1 (Timestamp, watt_bed,watt_living, watt_kitc) VALUES (%s, %s, %s, %s)",(time_b[j],0,4,0))
        
    elif int(turn_kitchen[0]) +(5760*(days-1))<= j <= (int(turn_kitchen[0])+int(turn_kitchen[1]))+(5760*(days-1)):
        c.execute("INSERT INTO data_timeline.light_sys1 (Timestamp, watt_bed,watt_living, watt_kitc) VALUES (%s, %s, %s, %s)",(time_b[j],0,0,2))
    else:
        c.execute("INSERT INTO data_timeline.light_sys1 (Timestamp, watt_bed,watt_living, watt_kitc) VALUES (%s, %s, %s, %s)",(time_b[j],0,0,0))
            
    j += 1
    conn.commit()
    

print "DONE!"
# Out:
# data_timeline.light_sys1 are Empty!!!
#
#
# Days : 0 : Sat
# time to turn-on lamp at bedroom on 21 : 40 : 14 equal to 5200 items
# consuming the lamp 4 hours 53 minutes 12 seconds that equal to 17592 seconds or 1172 items
#
# time to turn-on lamp at living-room on 17 : 33 : 38 equal to 4214 items
# consuming the lamp 3 hours 20 minutes 59 seconds that equal to 12059 seconds or 803 items
#
# time to turn-on lamp at kitchen on 18 : 15 : 42 equal to 4382 items
# consuming the lamp 1 hours 15 minutes 45 seconds that equal to 4545 seconds or 303 items
#
#
# Days : 1 : Sun
# time to turn-on lamp at bedroom on 21 : 51 : 55 equal to 5247 items
# consuming the lamp 4 hours 52 minutes 23 seconds that equal to 17543 seconds or 1169 items
#
# time to turn-on lamp at living-room on 17 : 33 : 19 equal to 4213 items
# consuming the lamp 3 hours 40 minutes 47 seconds that equal to 13247 seconds or 883 items
#
# time to turn-on lamp at kitchen on 18 : 2 : 54 equal to 4331 items
# consuming the lamp 1 hours 14 minutes 52 seconds that equal to 4492 seconds or 299 items
#
#
# Days : 2 : Mon
# time to turn-on lamp at bedroom on 20 : 46 : 8 equal to 4984 items
# consuming the lamp 3 hours 2 minutes 50 seconds that equal to 10970 seconds or 731 items
#
# time to turn-on lamp at living-room on 17 : 15 : 43 equal to 4142 items
# consuming the lamp 3 hours 45 minutes 37 seconds that equal to 13537 seconds or 902 items
#
# time to turn-on lamp at kitchen on 17 : 24 : 1 equal to 4176 items
# consuming the lamp 1 hours 9 minutes 45 seconds that equal to 4185 seconds or 279 items
#
#
# Days : 3 : Tue
# time to turn-on lamp at bedroom on 22 : 19 : 48 equal to 5359 items
# consuming the lamp 3 hours 34 minutes 45 seconds that equal to 12885 seconds or 859 items
#
# time to turn-on lamp at living-room on 18 : 59 : 20 equal to 4557 items
# consuming the lamp 3 hours 12 minutes 30 seconds that equal to 11550 seconds or 770 items
#
# time to turn-on lamp at kitchen on 17 : 48 : 14 equal to 4272 items
# consuming the lamp 2 hours 47 minutes 14 seconds that equal to 10034 seconds or 668 items
#
#
# Days : 4 : Wed
# time to turn-on lamp at bedroom on 20 : 55 : 16 equal to 5021 items
# consuming the lamp 3 hours 8 minutes 43 seconds that equal to 11323 seconds or 754 items
#
# time to turn-on lamp at living-room on 18 : 46 : 30 equal to 4505 items
# consuming the lamp 3 hours 21 minutes 17 seconds that equal to 12077 seconds or 805 items
#
# time to turn-on lamp at kitchen on 19 : 54 : 36 equal to 4778 items
# consuming the lamp 2 hours 44 minutes 11 seconds that equal to 9851 seconds or 656 items
#
#
# Days : 5 : Thu
# time to turn-on lamp at bedroom on 22 : 38 : 37 equal to 5434 items
# consuming the lamp 4 hours 44 minutes 18 seconds that equal to 17058 seconds or 1137 items
#
# time to turn-on lamp at living-room on 17 : 13 : 7 equal to 4132 items
# consuming the lamp 3 hours 22 minutes 49 seconds that equal to 12169 seconds or 811 items
#
# time to turn-on lamp at kitchen on 17 : 0 : 39 equal to 4082 items
# consuming the lamp 2 hours 34 minutes 1 seconds that equal to 9241 seconds or 616 items
#
#
# Days : 6 : Fri
# time to turn-on lamp at bedroom on 21 : 0 : 34 equal to 5042 items
# consuming the lamp 1 hours 32 minutes 34 seconds that equal to 5554 seconds or 370 items
#
# time to turn-on lamp at living-room on 19 : 32 : 3 equal to 4688 items
# consuming the lamp 3 hours 6 minutes 16 seconds that equal to 11176 seconds or 745 items
#
# time to turn-on lamp at kitchen on 17 : 40 : 45 equal to 4242 items
# consuming the lamp 1 hours 9 minutes 13 seconds that equal to 4153 seconds or 276 items
#
#
# Days : 7 : Sat
# time to turn-on lamp at bedroom on 21 : 0 : 18 equal to 5041 items
# consuming the lamp 2 hours 25 minutes 45 seconds that equal to 8745 seconds or 583 items
#
# time to turn-on lamp at living-room on 17 : 18 : 25 equal to 4153 items
# consuming the lamp 3 hours 30 minutes 51 seconds that equal to 12651 seconds or 843 items
#
# time to turn-on lamp at kitchen on 17 : 47 : 21 equal to 4269 items
# consuming the lamp 1 hours 39 minutes 42 seconds that equal to 5982 seconds or 398 items
#
#
# Days : 8 : Sun
# time to turn-on lamp at bedroom on 20 : 57 : 10 equal to 5028 items
# consuming the lamp 4 hours 6 minutes 19 seconds that equal to 14779 seconds or 985 items
#
# time to turn-on lamp at living-room on 19 : 39 : 27 equal to 4717 items
# consuming the lamp 3 hours 59 minutes 33 seconds that equal to 14373 seconds or 958 items
#
# time to turn-on lamp at kitchen on 17 : 59 : 41 equal to 4318 items
# consuming the lamp 2 hours 41 minutes 50 seconds that equal to 9710 seconds or 647 items
#
#
# Days : 9 : Mon
# time to turn-on lamp at bedroom on 21 : 13 : 49 equal to 5095 items
# consuming the lamp 4 hours 26 minutes 37 seconds that equal to 15997 seconds or 1066 items
#
# time to turn-on lamp at living-room on 19 : 1 : 36 equal to 4566 items
# consuming the lamp 3 hours 0 minutes 27 seconds that equal to 10827 seconds or 721 items
#
# time to turn-on lamp at kitchen on 19 : 47 : 19 equal to 4749 items
# consuming the lamp 2 hours 54 minutes 40 seconds that equal to 10480 seconds or 698 items
#
#
# Days : 10 : Tue
# time to turn-on lamp at bedroom on 20 : 16 : 56 equal to 4867 items
# consuming the lamp 3 hours 54 minutes 55 seconds that equal to 14095 seconds or 939 items
#
# time to turn-on lamp at living-room on 17 : 42 : 57 equal to 4251 items
# consuming the lamp 5 hours 56 minutes 6 seconds that equal to 21366 seconds or 1424 items
#
# time to turn-on lamp at kitchen on 17 : 5 : 21 equal to 4101 items
# consuming the lamp 2 hours 21 minutes 45 seconds that equal to 8505 seconds or 567 items
#
#
# Days : 11 : Wed
# time to turn-on lamp at bedroom on 20 : 24 : 6 equal to 4896 items
# consuming the lamp 3 hours 38 minutes 53 seconds that equal to 13133 seconds or 875 items
#
# time to turn-on lamp at living-room on 18 : 26 : 31 equal to 4426 items
# consuming the lamp 3 hours 19 minutes 26 seconds that equal to 11966 seconds or 797 items
#
# time to turn-on lamp at kitchen on 17 : 22 : 44 equal to 4170 items
# consuming the lamp 1 hours 4 minutes 29 seconds that equal to 3869 seconds or 257 items
#
#
# Days : 12 : Thu
# time to turn-on lamp at bedroom on 21 : 1 : 16 equal to 5045 items
# consuming the lamp 3 hours 41 minutes 34 seconds that equal to 13294 seconds or 886 items
#
# time to turn-on lamp at living-room on 18 : 22 : 39 equal to 4410 items
# consuming the lamp 3 hours 18 minutes 47 seconds that equal to 11927 seconds or 795 items
#
# time to turn-on lamp at kitchen on 18 : 11 : 49 equal to 4367 items
# consuming the lamp 2 hours 31 minutes 42 seconds that equal to 9102 seconds or 606 items
#
#
# Days : 13 : Fri
# time to turn-on lamp at bedroom on 20 : 35 : 21 equal to 4941 items
# consuming the lamp 4 hours 21 minutes 3 seconds that equal to 15663 seconds or 1044 items
#
# time to turn-on lamp at living-room on 18 : 21 : 28 equal to 4405 items
# consuming the lamp 3 hours 29 minutes 20 seconds that equal to 12560 seconds or 837 items
#
# time to turn-on lamp at kitchen on 17 : 13 : 30 equal to 4133 items
# consuming the lamp 1 hours 30 minutes 56 seconds that equal to 5456 seconds or 363 items
#
#
# Days : 14 : Sat
# time to turn-on lamp at bedroom on 21 : 18 : 41 equal to 5114 items
# consuming the lamp 2 hours 38 minutes 27 seconds that equal to 9507 seconds or 633 items
#
# time to turn-on lamp at living-room on 18 : 8 : 35 equal to 4354 items
# consuming the lamp 3 hours 38 minutes 3 seconds that equal to 13083 seconds or 872 items
#
# time to turn-on lamp at kitchen on 17 : 32 : 0 equal to 4211 items
# consuming the lamp 2 hours 48 minutes 59 seconds that equal to 10139 seconds or 675 items
#
#
# Days : 15 : Sun
# time to turn-on lamp at bedroom on 20 : 5 : 32 equal to 4822 items
# consuming the lamp 4 hours 27 minutes 53 seconds that equal to 16073 seconds or 1071 items
#
# time to turn-on lamp at living-room on 17 : 59 : 45 equal to 4318 items
# consuming the lamp 3 hours 16 minutes 52 seconds that equal to 11812 seconds or 787 items
#
# time to turn-on lamp at kitchen on 17 : 30 : 11 equal to 4200 items
# consuming the lamp 2 hours 31 minutes 55 seconds that equal to 9115 seconds or 607 items
#
#
# Days : 16 : Mon
# time to turn-on lamp at bedroom on 20 : 37 : 35 equal to 4950 items
# consuming the lamp 1 hours 47 minutes 32 seconds that equal to 6452 seconds or 430 items
#
# time to turn-on lamp at living-room on 17 : 35 : 28 equal to 4221 items
# consuming the lamp 3 hours 13 minutes 59 seconds that equal to 11639 seconds or 775 items
#
# time to turn-on lamp at kitchen on 20 : 52 : 24 equal to 5009 items
# consuming the lamp 1 hours 36 minutes 38 seconds that equal to 5798 seconds or 386 items
#
#
# Days : 17 : Tue
# time to turn-on lamp at bedroom on 20 : 55 : 42 equal to 5022 items
# consuming the lamp 2 hours 24 minutes 10 seconds that equal to 8650 seconds or 576 items
#
# time to turn-on lamp at living-room on 18 : 27 : 27 equal to 4429 items
# consuming the lamp 4 hours 57 minutes 17 seconds that equal to 17837 seconds or 1189 items
#
# time to turn-on lamp at kitchen on 17 : 32 : 32 equal to 4210 items
# consuming the lamp 2 hours 39 minutes 53 seconds that equal to 9593 seconds or 639 items
#
#
# Days : 18 : Wed
# time to turn-on lamp at bedroom on 21 : 34 : 35 equal to 5178 items
# consuming the lamp 3 hours 48 minutes 1 seconds that equal to 13681 seconds or 912 items
#
# time to turn-on lamp at living-room on 18 : 11 : 19 equal to 4365 items
# consuming the lamp 2 hours 39 minutes 39 seconds that equal to 9579 seconds or 638 items
#
# time to turn-on lamp at kitchen on 17 : 38 : 57 equal to 4235 items
# consuming the lamp 2 hours 27 minutes 7 seconds that equal to 8827 seconds or 588 items
#
#
# Days : 19 : Thu
# time to turn-on lamp at bedroom on 21 : 20 : 54 equal to 5123 items
# consuming the lamp 3 hours 27 minutes 6 seconds that equal to 12426 seconds or 828 items
#
# time to turn-on lamp at living-room on 19 : 19 : 29 equal to 4637 items
# consuming the lamp 3 hours 31 minutes 13 seconds that equal to 12673 seconds or 844 items
#
# time to turn-on lamp at kitchen on 17 : 26 : 26 equal to 4185 items
# consuming the lamp 1 hours 42 minutes 49 seconds that equal to 6169 seconds or 411 items
#
#
# Days : 20 : Fri
# time to turn-on lamp at bedroom on 20 : 20 : 5 equal to 4880 items
# consuming the lamp 2 hours 24 minutes 58 seconds that equal to 8698 seconds or 579 items
#
# time to turn-on lamp at living-room on 17 : 35 : 16 equal to 4221 items
# consuming the lamp 3 hours 58 minutes 46 seconds that equal to 14326 seconds or 955 items
#
# time to turn-on lamp at kitchen on 18 : 26 : 52 equal to 4427 items
# consuming the lamp 1 hours 22 minutes 1 seconds that equal to 4921 seconds or 328 items
#
#
# Days : 21 : Sat
# time to turn-on lamp at bedroom on 21 : 13 : 54 equal to 5095 items
# consuming the lamp 3 hours 56 minutes 52 seconds that equal to 14212 seconds or 947 items
#
# time to turn-on lamp at living-room on 18 : 22 : 31 equal to 4410 items
# consuming the lamp 3 hours 22 minutes 39 seconds that equal to 12159 seconds or 810 items
#
# time to turn-on lamp at kitchen on 17 : 45 : 13 equal to 4260 items
# consuming the lamp 1 hours 19 minutes 39 seconds that equal to 4779 seconds or 318 items
#
#
# Days : 22 : Sun
# time to turn-on lamp at bedroom on 20 : 15 : 31 equal to 4862 items
# consuming the lamp 3 hours 43 minutes 35 seconds that equal to 13415 seconds or 894 items
#
# time to turn-on lamp at living-room on 18 : 44 : 51 equal to 4499 items
# consuming the lamp 3 hours 43 minutes 43 seconds that equal to 13423 seconds or 894 items
#
# time to turn-on lamp at kitchen on 19 : 39 : 3 equal to 4716 items
# consuming the lamp 2 hours 57 minutes 39 seconds that equal to 10659 seconds or 710 items
#
#
# Days : 23 : Mon
# time to turn-on lamp at bedroom on 20 : 57 : 40 equal to 5030 items
# consuming the lamp 4 hours 43 minutes 38 seconds that equal to 17018 seconds or 1134 items
#
# time to turn-on lamp at living-room on 19 : 47 : 56 equal to 4751 items
# consuming the lamp 4 hours 6 minutes 14 seconds that equal to 14774 seconds or 984 items
#
# time to turn-on lamp at kitchen on 19 : 5 : 18 equal to 4581 items
# consuming the lamp 1 hours 54 minutes 40 seconds that equal to 6880 seconds or 458 items
#
#
# Days : 24 : Tue
# time to turn-on lamp at bedroom on 20 : 28 : 36 equal to 4914 items
# consuming the lamp 1 hours 5 minutes 10 seconds that equal to 3910 seconds or 260 items
#
# time to turn-on lamp at living-room on 18 : 45 : 30 equal to 4501 items
# consuming the lamp 3 hours 37 minutes 53 seconds that equal to 13073 seconds or 871 items
#
# time to turn-on lamp at kitchen on 17 : 51 : 23 equal to 4285 items
# consuming the lamp 1 hours 47 minutes 11 seconds that equal to 6431 seconds or 428 items
#
#
# Days : 25 : Wed
# time to turn-on lamp at bedroom on 20 : 52 : 34 equal to 5010 items
# consuming the lamp 2 hours 50 minutes 8 seconds that equal to 10208 seconds or 680 items
#
# time to turn-on lamp at living-room on 17 : 32 : 31 equal to 4210 items
# consuming the lamp 3 hours 28 minutes 58 seconds that equal to 12538 seconds or 835 items
#
# time to turn-on lamp at kitchen on 17 : 18 : 44 equal to 4154 items
# consuming the lamp 1 hours 23 minutes 45 seconds that equal to 5025 seconds or 335 items
#
#
# Days : 26 : Thu
# time to turn-on lamp at bedroom on 21 : 10 : 39 equal to 5082 items
# consuming the lamp 4 hours 56 minutes 0 seconds that equal to 17760 seconds or 1184 items
#
# time to turn-on lamp at living-room on 19 : 45 : 47 equal to 4743 items
# consuming the lamp 4 hours 0 minutes 46 seconds that equal to 14446 seconds or 963 items
#
# time to turn-on lamp at kitchen on 17 : 41 : 32 equal to 4246 items
# consuming the lamp 2 hours 0 minutes 56 seconds that equal to 7256 seconds or 483 items
#
#
# Days : 27 : Fri
# time to turn-on lamp at bedroom on 21 : 8 : 25 equal to 5073 items
# consuming the lamp 4 hours 41 minutes 57 seconds that equal to 16917 seconds or 1127 items
#
# time to turn-on lamp at living-room on 18 : 23 : 21 equal to 4413 items
# consuming the lamp 3 hours 31 minutes 0 seconds that equal to 12660 seconds or 844 items
#
# time to turn-on lamp at kitchen on 17 : 59 : 24 equal to 4317 items
# consuming the lamp 2 hours 1 minutes 53 seconds that equal to 7313 seconds or 487 items
#
#
# Days : 28 : Sat
# time to turn-on lamp at bedroom on 21 : 7 : 12 equal to 5068 items
# consuming the lamp 3 hours 40 minutes 17 seconds that equal to 13217 seconds or 881 items
#
# time to turn-on lamp at living-room on 19 : 56 : 53 equal to 4787 items
# consuming the lamp 3 hours 51 minutes 5 seconds that equal to 13865 seconds or 924 items
#
# time to turn-on lamp at kitchen on 17 : 7 : 31 equal to 4110 items
# consuming the lamp 1 hours 37 minutes 15 seconds that equal to 5835 seconds or 389 items
#
#
# Days : 29 : Sun
# time to turn-on lamp at bedroom on 20 : 16 : 52 equal to 4867 items
# consuming the lamp 3 hours 3 minutes 17 seconds that equal to 10997 seconds or 733 items
#
# time to turn-on lamp at living-room on 19 : 31 : 11 equal to 4684 items
# consuming the lamp 3 hours 12 minutes 32 seconds that equal to 11552 seconds or 770 items
#
# time to turn-on lamp at kitchen on 20 : 43 : 23 equal to 4973 items
# consuming the lamp 1 hours 33 minutes 3 seconds that equal to 5583 seconds or 372 items
#
#
# Days : 30 : Mon
# time to turn-on lamp at bedroom on 21 : 30 : 25 equal to 5161 items
# consuming the lamp 2 hours 15 minutes 44 seconds that equal to 8144 seconds or 542 items
#
# time to turn-on lamp at living-room on 19 : 57 : 24 equal to 4789 items
# consuming the lamp 4 hours 56 minutes 3 seconds that equal to 17763 seconds or 1184 items
#
# time to turn-on lamp at kitchen on 17 : 48 : 59 equal to 4275 items
# consuming the lamp 1 hours 16 minutes 40 seconds that equal to 4600 seconds or 306 items
#
# DONE!

# %%
import matplotlib.pyplot as plt
# %matplotlib inline  


# query = "SELECT watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
query = "SELECT * FROM data_timeline.light_sys1 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[4000],time_b[6500])
df = pd.read_sql(query, conn, index_col=['Timestamp'])
fig, ax = plt.subplots()
ax.set_title('data_timeline.IRON')
df.plot(ax=ax )
plt.show()
df.to_csv('file.csv')
