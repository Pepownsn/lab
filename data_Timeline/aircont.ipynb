# %% [markdown]
# # data_TIMELInE
# ### เครื่องปรับอากาศ | 9000btu |

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random


d = 31
time_a = pd.date_range('2016-10-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-10-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####### set databases to empty #########
query_empty = """truncate table data_timeline.aircont""" 
c.execute(query_empty)
print "data_timeline.aircont are Empty!!! \n"

query = "SELECT watt FROM collected_info.1_aircont WHERE no >= '%s'   AND no <= '%s'; "% (0,3276)
df = pd.read_sql(query, conn)
# print df.watt[5]

#### Random the turning-on time appliances
def rand_turnon():
    duration_sec =  random.randint(10, 59)
    duration_min =  random.randint(10, 59)
    duration_hour1 = ['19'] * 5 + ['20'] * 50 + ['21'] * 43 +['22'] * 2     #SET Start 7-10 pm.
    duration_hour = random.choice(duration_hour1)     
    if 0 < duration_sec <= 15:
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
    off_item = (int(duration_hour)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on appliacne on",duration_hour,":",duration_min,":",duration_sec,"equal to",off_item,"items"
    return off_item

 
#### Random the off-duration appliances 
def rand_duration():
    duration_sec =  random.randint(10,59)
    duration_min =  random.randint(10, 59)
    duration_hour =  random.randint(6, 8)     #SET 6-8 Hours
    seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
    no_item = seconds/15
    print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items"
    return no_item

days = 0
j = 0
i = 0
print "\nDays :",days ,":",time_b[j].strftime('%a')
off_item = rand_turnon()  
no_item = rand_duration()  

while (j <= (5760*d)-1):    
    c.execute("INSERT INTO data_timeline.aircont (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
    conn.commit()
    j += 1 
    
    while (off_item+(5760*(days)) <= j <= (no_item+off_item)+(5760*(days))):                   
        c.execute("INSERT INTO data_timeline.aircont (Timestamp, watt) VALUES (%s, %s)",(time_b[j],df.watt[i]))
        conn.commit()
        i += 1 
        j += 1
        if (j == (no_item+off_item)+(5760*(days))):
            days +=1
            print "\nDays :",days ,":",time_b[j].strftime('%a')
            off_item = rand_turnon()  
            no_item = rand_duration() 
            i= 0   
                    
print "DONE!"
# Out:
# data_timeline.aircont are Empty!!!
#
#
# Days : 0 : Sat
# time to turn-on appliacne on 20 : 29 : 38 equal to 4918 items
# consuming the appliance 8 hours 21 minutes 45 seconds that equal to 30105 seconds or 2007 items
#
# Days : 1 : Sun
# time to turn-on appliacne on 21 : 53 : 39 equal to 5254 items
# consuming the appliance 7 hours 29 minutes 34 seconds that equal to 26974 seconds or 1798 items
#
# Days : 2 : Mon
# time to turn-on appliacne on 20 : 51 : 44 equal to 5006 items
# consuming the appliance 6 hours 31 minutes 55 seconds that equal to 23515 seconds or 1567 items
#
# Days : 3 : Tue
# time to turn-on appliacne on 20 : 38 : 46 equal to 4955 items
# consuming the appliance 7 hours 15 minutes 56 seconds that equal to 26156 seconds or 1743 items
#
# Days : 4 : Wed
# time to turn-on appliacne on 20 : 53 : 39 equal to 5014 items
# consuming the appliance 8 hours 47 minutes 41 seconds that equal to 31661 seconds or 2110 items
#
# Days : 5 : Thu
# time to turn-on appliacne on 21 : 51 : 38 equal to 5246 items
# consuming the appliance 7 hours 43 minutes 57 seconds that equal to 27837 seconds or 1855 items
#
# Days : 6 : Fri
# time to turn-on appliacne on 21 : 36 : 40 equal to 5186 items
# consuming the appliance 7 hours 11 minutes 55 seconds that equal to 25915 seconds or 1727 items
#
# Days : 7 : Sat
# time to turn-on appliacne on 21 : 45 : 38 equal to 5222 items
# consuming the appliance 8 hours 51 minutes 41 seconds that equal to 31901 seconds or 2126 items
#
# Days : 8 : Sun
# time to turn-on appliacne on 20 : 10 : 37 equal to 4842 items
# consuming the appliance 6 hours 25 minutes 26 seconds that equal to 23126 seconds or 1541 items
#
# Days : 9 : Mon
# time to turn-on appliacne on 19 : 12 : 35 equal to 4610 items
# consuming the appliance 6 hours 19 minutes 58 seconds that equal to 22798 seconds or 1519 items
#
# Days : 10 : Tue
# time to turn-on appliacne on 21 : 31 : 51 equal to 5167 items
# consuming the appliance 6 hours 27 minutes 11 seconds that equal to 23231 seconds or 1548 items
#
# Days : 11 : Wed
# time to turn-on appliacne on 20 : 24 : 58 equal to 4899 items
# consuming the appliance 7 hours 20 minutes 52 seconds that equal to 26452 seconds or 1763 items
#
# Days : 12 : Thu
# time to turn-on appliacne on 19 : 56 : 45 equal to 4786 items
# consuming the appliance 8 hours 50 minutes 14 seconds that equal to 31814 seconds or 2120 items
#
# Days : 13 : Fri
# time to turn-on appliacne on 20 : 48 : 29 equal to 4993 items
# consuming the appliance 8 hours 29 minutes 39 seconds that equal to 30579 seconds or 2038 items
#
# Days : 14 : Sat
# time to turn-on appliacne on 20 : 41 : 37 equal to 4966 items
# consuming the appliance 7 hours 48 minutes 10 seconds that equal to 28090 seconds or 1872 items
#
# Days : 15 : Sun
# time to turn-on appliacne on 21 : 33 : 11 equal to 5172 items
# consuming the appliance 8 hours 44 minutes 31 seconds that equal to 31471 seconds or 2098 items
#
# Days : 16 : Mon
# time to turn-on appliacne on 21 : 43 : 58 equal to 5215 items
# consuming the appliance 7 hours 40 minutes 40 seconds that equal to 27640 seconds or 1842 items
#
# Days : 17 : Tue
# time to turn-on appliacne on 20 : 47 : 55 equal to 4991 items
# consuming the appliance 6 hours 32 minutes 22 seconds that equal to 23542 seconds or 1569 items
#
# Days : 18 : Wed
# time to turn-on appliacne on 21 : 50 : 21 equal to 5241 items
# consuming the appliance 6 hours 13 minutes 24 seconds that equal to 22404 seconds or 1493 items
#
# Days : 19 : Thu
# time to turn-on appliacne on 20 : 18 : 59 equal to 4875 items
# consuming the appliance 6 hours 44 minutes 42 seconds that equal to 24282 seconds or 1618 items
#
# Days : 20 : Fri
# time to turn-on appliacne on 20 : 16 : 11 equal to 4864 items
# consuming the appliance 6 hours 27 minutes 32 seconds that equal to 23252 seconds or 1550 items
#
# Days : 21 : Sat
# time to turn-on appliacne on 20 : 37 : 55 equal to 4951 items
# consuming the appliance 8 hours 21 minutes 21 seconds that equal to 30081 seconds or 2005 items
#
# Days : 22 : Sun
# time to turn-on appliacne on 21 : 37 : 35 equal to 5190 items
# consuming the appliance 8 hours 29 minutes 13 seconds that equal to 30553 seconds or 2036 items
#
# Days : 23 : Mon
# time to turn-on appliacne on 21 : 30 : 36 equal to 5162 items
# consuming the appliance 8 hours 13 minutes 48 seconds that equal to 29628 seconds or 1975 items
#
# Days : 24 : Tue
# time to turn-on appliacne on 22 : 30 : 52 equal to 5403 items
# consuming the appliance 7 hours 40 minutes 29 seconds that equal to 27629 seconds or 1841 items
#
# Days : 25 : Wed
# time to turn-on appliacne on 20 : 26 : 31 equal to 4906 items
# consuming the appliance 7 hours 14 minutes 44 seconds that equal to 26084 seconds or 1738 items
#
# Days : 26 : Thu
# time to turn-on appliacne on 21 : 26 : 58 equal to 5147 items
# consuming the appliance 8 hours 45 minutes 20 seconds that equal to 31520 seconds or 2101 items
#
# Days : 27 : Fri
# time to turn-on appliacne on 20 : 50 : 23 equal to 5001 items
# consuming the appliance 6 hours 42 minutes 33 seconds that equal to 24153 seconds or 1610 items
#
# Days : 28 : Sat
# time to turn-on appliacne on 21 : 55 : 57 equal to 5263 items
# consuming the appliance 7 hours 51 minutes 32 seconds that equal to 28292 seconds or 1886 items
#
# Days : 29 : Sun
# time to turn-on appliacne on 20 : 35 : 59 equal to 4943 items
# consuming the appliance 6 hours 16 minutes 14 seconds that equal to 22574 seconds or 1504 items
#
# Days : 30 : Mon
# time to turn-on appliacne on 21 : 38 : 12 equal to 5192 items
# consuming the appliance 8 hours 33 minutes 50 seconds that equal to 30830 seconds or 2055 items
# IndexErrorTraceback (most recent call last)
# <ipython-input-13-f9f51401e203> in <module>()
#      67
#      68     while (off_item+(5760*(days)) <= j <= (no_item+off_item)+(5760*(days))):
# ---> 69         c.execute("INSERT INTO data_timeline.aircont (Timestamp, watt) VALUES (%s, %s)",(time_b[j],df.watt[i]))
#      70         conn.commit()
#      71         i += 1
#
# /usr/local/lib/python2.7/dist-packages/pandas/tseries/base.pyc in __getitem__(self, key)
#     249         getitem = self._data.__getitem__
#     250         if is_int:
# --> 251             val = getitem(key)
#     252             return self._box_func(val)
#     253         else:
#
# IndexError: index 178560 is out of bounds for axis 0 with size 178560
