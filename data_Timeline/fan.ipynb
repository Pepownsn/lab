# %% [markdown]
# # data_TIMELInE
# ### FAN | พัดลมตั้งพื้น 16 นิ้ว |

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random


d = 31

time_a = pd.date_range('2016-10-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-10-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####### set databases to empty #########
query_empty = """truncate table data_timeline.fan""" 
c.execute(query_empty)
print "data_timeline.fan are Empty!!! \n"

query = "SELECT watt FROM collected_info.2_fan WHERE no >= '%s'   AND no <= '%s'; "% (0,1016)
df = pd.read_sql(query, conn)
# print df.watt[5]

#### Random the number of turnon-time per day
def manytime():
    many  = ['1'] * 50 + ['2'] * 44 + ['3'] * 6  ## The number of turn-on time of this appliance 
    manytime = random.choice(many)
    print "\nDays :",days-1 ,":",time_b[j].strftime('%a')
    print "in recent day turn on fan",manytime,"times\n"
    if (int(manytime) == 1):
        x,y,endx,endy = 18,20,2,4  # fix turn on only in evening      
        open_hour =  random.randint(x, y)
        open_min =  random.randint(0, 59)
        open_sec =  random.randint(0, 59)
        if 0 < open_sec  <= 15:
            k = 0
        elif 15 < open_sec  <= 30:
            k = 1
        elif 30 < open_sec  <= 45:
            k = 2
        else:
            k = 3
        off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
        print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
        
        duration_hour =  random.randint(endx, endy)
        duration_min =  random.randint(0, 59)
        duration_sec =  random.randint(0, 59)
        seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
        no_item = seconds/15
        print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"
        return (off_item,no_item)

        
    elif (int(manytime) == 2):
        turn_duratrion  = ['1'] * 70 + ['2'] * 30       #### '1' turn-on morning and evening   OR  '2' turn-on 2 times in evening 
        howturn = random.choice(turn_duratrion)
#         print howturn
        if (int(howturn)== 1 ):
            x,y,endx,endy = 6,7,1,59
            open_hour =  random.randint(x, y)
            open_min =  random.randint(0, 59)
            open_sec =  random.randint(0, 59)
            if 0 < open_sec  <= 15:
                k = 0
            elif 15 < open_sec  <= 30:
                k = 1
            elif 30 < open_sec  <= 45:
                k = 2
            else:
                k = 3
            off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
            print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
            
            duration_hour =  random.randint(0, 0)
            duration_min =  random.randint(endx, endy)
            duration_sec =  random.randint(0, 59)
            seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
            no_item = seconds/15
            print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"

        
            
            x1,y1,endx1,endy1 = 18,20,2,4
            open_hour1 =  random.randint(x1, y1)
            open_min1 =  random.randint(0, 59)
            open_sec1 =  random.randint(0, 59)
            if 0 < open_sec1  <= 15:
                k = 0
            elif 15 < open_sec1  <= 30:
                k = 1
            elif 30 < open_sec1  <= 45:
                k = 2
            else:
                k = 3
            off_item1 = (int(open_hour1)*240) + (int(open_min1)*4)+ k 
            print "time to turn-on appliacne on",open_hour1,":",open_min1,":",open_sec1,"equal to",off_item1,"items"     
            
            duration_hour1 =  random.randint(endx1, endy1)
            duration_min1 =  random.randint(0, 59)
            duration_sec1 =  random.randint(0, 59)
            seconds1 = (duration_hour1*3600)+(duration_min1*60)+duration_sec1
            no_item1 = seconds1/15
            print "consuming the appliance", duration_hour1,"hours",duration_min1,"minutes",duration_sec1,"seconds that equal to",seconds1,"seconds or",no_item1,"items\n"

        else :
            x,y,endx,endy = 18,19,1,59
            open_hour =  random.randint(x, y)
            open_min =  random.randint(0, 59)
            open_sec =  random.randint(0, 59)
            if 0 < open_sec  <= 15:
                k = 0
            elif 15 < open_sec  <= 30:
                k = 1
            elif 30 < open_sec  <= 45:
                k = 2
            else:
                k = 3
            off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
            print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
            
            duration_hour =  random.randint(0, 0)
            duration_min =  random.randint(endx, endy)
            duration_sec =  random.randint(0, 59)
            seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
            no_item = seconds/15
            print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"

        
            x1,y1,endx1,endy1 = 20,22,1,4
            open_hour1 =  random.randint(x1, y1)
            open_min1 =  random.randint(0, 59)
            open_sec1 =  random.randint(0, 59)
            if 0 < open_sec1  <= 15:
                k = 0
            elif 15 < open_sec1  <= 30:
                k = 1
            elif 30 < open_sec1  <= 45:
                k = 2
            else:
                k = 3
            off_item1 = (int(open_hour1)*240) + (int(open_min1)*4)+ k 
            print "time to turn-on appliacne on",open_hour1,":",open_min1,":",open_sec1,"equal to",off_item1,"items"   
            
            duration_hour1 =  random.randint(endx1, endy1)
            duration_min1 =  random.randint(0, 59)
            duration_sec1 =  random.randint(0, 59)
            seconds1 = (duration_hour1*3600)+(duration_min1*60)+duration_sec1
            no_item1 = seconds1/15
            print "consuming the appliance", duration_hour1,"hours",duration_min1,"minutes",duration_sec1,"seconds that equal to",seconds1,"seconds or",no_item1,"items\n"

        return (off_item,no_item,off_item1,no_item1)        
    else:
        x,y,endx,endy = 6,7,30,60
        open_hour =  random.randint(x, y)
        open_min =  random.randint(0, 59)
        open_sec =  random.randint(0, 59)
        if 0 < open_sec  <= 15:
            k = 0
        elif 15 < open_sec  <= 30:
            k = 1
        elif 30 < open_sec  <= 45:
            k = 2
        else:
            k = 3
        off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
        print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
        
        duration_hour =  random.randint(0,0)
        duration_min =  random.randint(endx, endy)
        duration_sec =  random.randint(0, 59)
        seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
        no_item = seconds/15
        print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"

    
    
        x1,y1,endx1,endy1 = 18,19,1,59
        open_hour1 =  random.randint(x1, y1)
        open_min1 =  random.randint(0, 59)
        open_sec1 =  random.randint(0, 59)
        if 0 < open_sec1  <= 15:
            k = 0
        elif 15 < open_sec1  <= 30:
            k = 1
        elif 30 < open_sec1  <= 45:
            k = 2
        else:
            k = 3
        off_item1 = (int(open_hour1)*240) + (int(open_min1)*4)+ k 
        print "time to turn-on appliacne on",open_hour1,":",open_min1,":",open_sec1,"equal to",off_item1,"items" 
        duration_hour1 =  random.randint(0, 0)
        duration_min1 =  random.randint(endx1, endy1)
        duration_sec1 =  random.randint(0, 59)
        seconds1 = (duration_hour1*3600)+(duration_min1*60)+duration_sec1
        no_item1 = seconds1/15
        print "consuming the appliance", duration_hour1,"hours",duration_min1,"minutes",duration_sec1,"seconds that equal to",seconds1,"seconds or",no_item1,"items\n"
    
    
        x2,y2,endx2,endy2 = 20,22,1,4
        open_hour2 =  random.randint(x2, y2)
        open_min2 =  random.randint(0, 59)
        open_sec2 =  random.randint(0, 59)
        if 0 < open_sec2  <= 15:
            k = 0
        elif 15 < open_sec2  <= 30:
            k = 1
        elif 30 < open_sec2  <= 45:
            k = 2
        else:
            k = 3
        off_item2 = (int(open_hour2)*240) + (int(open_min2)*4)+ k 
        print "time to turn-on appliacne on",open_hour2,":",open_min2,":",open_sec2,"equal to",off_item2,"items" 
        duration_hour2 =  random.randint(endx2, endy2)
        duration_min2 =  random.randint(0, 59)
        duration_sec2 =  random.randint(0, 59)
        seconds2 = (duration_hour2*3600)+(duration_min2*60)+duration_sec2
        no_item2 = seconds2/15
        print "consuming the appliance", duration_hour2,"hours",duration_min2,"minutes",duration_sec2,"seconds that equal to",seconds2,"seconds or",no_item2,"items\n"
        return (off_item,no_item,off_item1,no_item1,off_item2,no_item2)    
    
    
        
days = 1
j = 0

## (off_item,no_item,off_item1,no_item1,off_item2,no_item2)    

turn = manytime()
while (j <= (5760*d)-1):   
    if (j == 5760+(5760*(days-1))):
        days +=1
        print "-------------------------ENd-----------------------------\n"
        turn = manytime()          
        
    if len(turn)==2:
        off_item = turn[0] 
        no_item = turn[1]
        if (off_item+(5760*(days-1)) <= j <= (no_item+off_item)+(5760*(days-1))):
            c.execute("INSERT INTO data_timeline.fan (Timestamp, watt) VALUES (%s, %s)",(time_b[j],random.randint(64, 68)))
            conn.commit()
            j += 1
        else:
            c.execute("INSERT INTO data_timeline.fan (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
            conn.commit()
            j += 1
        
    elif len(turn)==4:
        off_item = turn[0] 
        no_item = turn[1]
        off_item1 = turn[2] 
        no_item1 = turn[3]
        if (off_item+(5760*(days-1)) <= j <= (no_item+off_item)+(5760*(days-1)) or off_item1+(5760*(days-1)) <= j <= (no_item1+off_item1)+(5760*(days-1))):
            c.execute("INSERT INTO data_timeline.fan (Timestamp, watt) VALUES (%s, %s)",(time_b[j],random.randint(64, 68)))
            conn.commit()
            j += 1
        else:
            c.execute("INSERT INTO data_timeline.fan (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
            conn.commit()
            j += 1
             
    else:
        off_item = turn[0] 
        no_item = turn[1]
        off_item1 = turn[2] 
        no_item1 = turn[3]
        off_item2 = turn[4] 
        no_item2 = turn[5]
        
        if (off_item+(5760*(days-1)) <= j <= (no_item+off_item)+(5760*(days-1)) or off_item1+(5760*(days-1)) <= j <= (no_item1+off_item1)+(5760*(days-1)) or off_item2+(5760*(days-1)) <= j <= (no_item2+off_item2)+(5760*(days-1)))  :
            c.execute("INSERT INTO data_timeline.fan (Timestamp, watt) VALUES (%s, %s)",(time_b[j],random.randint(64, 68)))
            conn.commit()
            j += 1
        else:
            c.execute("INSERT INTO data_timeline.fan (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
            conn.commit()
            j += 1
 
           
print "DONE!"
# Out:
# data_timeline.fan are Empty!!!
#
#
# Days : 0 : Sat
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 6 : 17 : 56 equal to 1511 items
# consuming the appliance 0 hours 19 minutes 15 seconds that equal to 1155 seconds or 77 items
#
# time to turn-on appliacne on 20 : 3 : 4 equal to 4812 items
# consuming the appliance 3 hours 53 minutes 54 seconds that equal to 14034 seconds or 935 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 1 : Sun
# in recent day turn on fan 3 times
#
# time to turn-on appliacne on 6 : 7 : 22 equal to 1469 items
# consuming the appliance 0 hours 46 minutes 34 seconds that equal to 2794 seconds or 186 items
#
# time to turn-on appliacne on 18 : 8 : 27 equal to 4353 items
# consuming the appliance 0 hours 35 minutes 19 seconds that equal to 2119 seconds or 141 items
#
# time to turn-on appliacne on 21 : 46 : 40 equal to 5226 items
# consuming the appliance 4 hours 29 minutes 3 seconds that equal to 16143 seconds or 1076 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 2 : Mon
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 6 : 49 : 50 equal to 1639 items
# consuming the appliance 0 hours 32 minutes 3 seconds that equal to 1923 seconds or 128 items
#
# time to turn-on appliacne on 18 : 34 : 23 equal to 4457 items
# consuming the appliance 3 hours 48 minutes 1 seconds that equal to 13681 seconds or 912 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 3 : Tue
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 20 : 22 : 25 equal to 4889 items
# consuming the appliance 3 hours 46 minutes 57 seconds that equal to 13617 seconds or 907 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 4 : Wed
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 7 : 23 : 15 equal to 1772 items
# consuming the appliance 0 hours 56 minutes 59 seconds that equal to 3419 seconds or 227 items
#
# time to turn-on appliacne on 20 : 7 : 42 equal to 4830 items
# consuming the appliance 2 hours 43 minutes 18 seconds that equal to 9798 seconds or 653 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 5 : Thu
# in recent day turn on fan 3 times
#
# time to turn-on appliacne on 7 : 6 : 14 equal to 1704 items
# consuming the appliance 0 hours 34 minutes 34 seconds that equal to 2074 seconds or 138 items
#
# time to turn-on appliacne on 19 : 9 : 53 equal to 4599 items
# consuming the appliance 0 hours 47 minutes 4 seconds that equal to 2824 seconds or 188 items
#
# time to turn-on appliacne on 20 : 52 : 28 equal to 5009 items
# consuming the appliance 3 hours 48 minutes 35 seconds that equal to 13715 seconds or 914 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 6 : Fri
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 6 : 50 : 11 equal to 1640 items
# consuming the appliance 0 hours 23 minutes 26 seconds that equal to 1406 seconds or 93 items
#
# time to turn-on appliacne on 20 : 53 : 40 equal to 5014 items
# consuming the appliance 4 hours 53 minutes 22 seconds that equal to 17602 seconds or 1173 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 7 : Sat
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 19 : 12 : 3 equal to 4608 items
# consuming the appliance 4 hours 17 minutes 39 seconds that equal to 15459 seconds or 1030 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 8 : Sun
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 18 : 42 : 39 equal to 4490 items
# consuming the appliance 2 hours 36 minutes 14 seconds that equal to 9374 seconds or 624 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 9 : Mon
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 6 : 4 : 14 equal to 1456 items
# consuming the appliance 0 hours 21 minutes 16 seconds that equal to 1276 seconds or 85 items
#
# time to turn-on appliacne on 18 : 51 : 22 equal to 4525 items
# consuming the appliance 4 hours 48 minutes 29 seconds that equal to 17309 seconds or 1153 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 10 : Tue
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 6 : 54 : 9 equal to 1656 items
# consuming the appliance 0 hours 30 minutes 28 seconds that equal to 1828 seconds or 121 items
#
# time to turn-on appliacne on 20 : 4 : 51 equal to 4819 items
# consuming the appliance 2 hours 25 minutes 45 seconds that equal to 8745 seconds or 583 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 11 : Wed
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 6 : 18 : 44 equal to 1514 items
# consuming the appliance 0 hours 13 minutes 24 seconds that equal to 804 seconds or 53 items
#
# time to turn-on appliacne on 19 : 48 : 13 equal to 4752 items
# consuming the appliance 3 hours 8 minutes 56 seconds that equal to 11336 seconds or 755 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 12 : Thu
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 7 : 25 : 56 equal to 1783 items
# consuming the appliance 0 hours 26 minutes 46 seconds that equal to 1606 seconds or 107 items
#
# time to turn-on appliacne on 20 : 28 : 40 equal to 4914 items
# consuming the appliance 3 hours 4 minutes 54 seconds that equal to 11094 seconds or 739 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 13 : Fri
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 19 : 8 : 40 equal to 4594 items
# consuming the appliance 4 hours 34 minutes 36 seconds that equal to 16476 seconds or 1098 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 14 : Sat
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 6 : 54 : 18 equal to 1657 items
# consuming the appliance 0 hours 1 minutes 47 seconds that equal to 107 seconds or 7 items
#
# time to turn-on appliacne on 19 : 37 : 58 equal to 4711 items
# consuming the appliance 2 hours 3 minutes 48 seconds that equal to 7428 seconds or 495 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 15 : Sun
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 20 : 53 : 33 equal to 5014 items
# consuming the appliance 3 hours 20 minutes 9 seconds that equal to 12009 seconds or 800 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 16 : Mon
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 20 : 37 : 29 equal to 4949 items
# consuming the appliance 2 hours 33 minutes 43 seconds that equal to 9223 seconds or 614 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 17 : Tue
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 19 : 54 : 17 equal to 4777 items
# consuming the appliance 4 hours 4 minutes 50 seconds that equal to 14690 seconds or 979 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 18 : Wed
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 20 : 50 : 51 equal to 5003 items
# consuming the appliance 3 hours 6 minutes 46 seconds that equal to 11206 seconds or 747 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 19 : Thu
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 7 : 41 : 31 equal to 1846 items
# consuming the appliance 0 hours 52 minutes 23 seconds that equal to 3143 seconds or 209 items
#
# time to turn-on appliacne on 19 : 42 : 4 equal to 4728 items
# consuming the appliance 3 hours 11 minutes 4 seconds that equal to 11464 seconds or 764 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 20 : Fri
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 7 : 54 : 32 equal to 1898 items
# consuming the appliance 0 hours 18 minutes 3 seconds that equal to 1083 seconds or 72 items
#
# time to turn-on appliacne on 18 : 51 : 42 equal to 4526 items
# consuming the appliance 4 hours 19 minutes 40 seconds that equal to 15580 seconds or 1038 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 21 : Sat
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 20 : 50 : 26 equal to 5001 items
# consuming the appliance 4 hours 49 minutes 50 seconds that equal to 17390 seconds or 1159 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 22 : Sun
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 19 : 42 : 4 equal to 4728 items
# consuming the appliance 0 hours 22 minutes 32 seconds that equal to 1352 seconds or 90 items
#
# time to turn-on appliacne on 20 : 21 : 31 equal to 4886 items
# consuming the appliance 4 hours 27 minutes 21 seconds that equal to 16041 seconds or 1069 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 23 : Mon
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 7 : 22 : 4 equal to 1768 items
# consuming the appliance 0 hours 8 minutes 2 seconds that equal to 482 seconds or 32 items
#
# time to turn-on appliacne on 18 : 38 : 19 equal to 4473 items
# consuming the appliance 2 hours 0 minutes 42 seconds that equal to 7242 seconds or 482 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 24 : Tue
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 20 : 22 : 45 equal to 4890 items
# consuming the appliance 2 hours 30 minutes 44 seconds that equal to 9044 seconds or 602 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 25 : Wed
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 20 : 38 : 58 equal to 4955 items
# consuming the appliance 2 hours 3 minutes 17 seconds that equal to 7397 seconds or 493 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 26 : Thu
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 20 : 33 : 11 equal to 4932 items
# consuming the appliance 2 hours 40 minutes 48 seconds that equal to 9648 seconds or 643 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 27 : Fri
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 7 : 50 : 2 equal to 1880 items
# consuming the appliance 0 hours 42 minutes 18 seconds that equal to 2538 seconds or 169 items
#
# time to turn-on appliacne on 19 : 35 : 15 equal to 4700 items
# consuming the appliance 3 hours 6 minutes 9 seconds that equal to 11169 seconds or 744 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 28 : Sat
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 20 : 36 : 37 equal to 4946 items
# consuming the appliance 3 hours 35 minutes 51 seconds that equal to 12951 seconds or 863 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 29 : Sun
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 19 : 15 : 24 equal to 4621 items
# consuming the appliance 3 hours 48 minutes 7 seconds that equal to 13687 seconds or 912 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 30 : Mon
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 18 : 41 : 44 equal to 4486 items
# consuming the appliance 0 hours 26 minutes 47 seconds that equal to 1607 seconds or 107 items
#
# time to turn-on appliacne on 20 : 50 : 57 equal to 5003 items
# consuming the appliance 4 hours 21 minutes 34 seconds that equal to 15694 seconds or 1046 items
#
# DONE!

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
# %matplotlib inline  


# query = "SELECT watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
query = "SELECT Timestamp,watt FROM data_timeline.fan WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[5760*12])
df = pd.read_sql(query, conn, index_col=['Timestamp'])
fig, ax = plt.subplots()
ax.set_title('data_timeline.fan')
df.plot(ax=ax )
plt.show()
