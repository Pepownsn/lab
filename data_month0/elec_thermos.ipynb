# %% [markdown]
# ### Elec_thermos | ขนาด 2.8 ลิตร  |
# ##### TYPE 2 " TURN ON EVERYDAY//ONCE TIME

# %% [markdown]
# ## NO. 8 (กระติกน้ำร้อน)
# ![image](https://raw.githubusercontent.com/skyfighter/iHEMS/master/Device/pic/Boiler.png)

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random


d = 31
time_a = pd.date_range('2016-09-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-09-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####### set databases to empty #########
query_empty = """truncate table device.elec_thermos""" 
c.execute(query_empty)
print "device.elec_thermos are Empty!!! \n"

query = "SELECT watt FROM collected_info.8_elec_thermos WHERE no >= '%s'   AND no <= '%s'; "% (0,1167)
df = pd.read_sql(query, conn)
# print df.watt[5]

#### Random the turning-on time appliances
def rand_turnon():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(0, 59)
    duration_hour1 = ['6'] * 2 + ['7'] * 48 + ['8'] * 47 + ['9'] * 3    #SET Start 6-9 am.
    duration_hour = random.choice(duration_hour1)     
    if 0 < duration_sec <= 15:
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
    off_item = (int(duration_hour)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on appliacne on",duration_hour,":",duration_min,":",duration_sec,"equal to",off_item,"items"
    return off_item

 
#### Random the off-duration appliances 
def rand_duration():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(0, 59)
    duration_hour1 = ['0'] * 97 + ['1'] * 2+ ['2'] * 1
    duration_hour = random.choice(duration_hour1)   
    seconds = (int(duration_hour)*3600)+(duration_min*60)+duration_sec
    no_item = seconds/15
    print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items"
    return no_item

days = 0
j = 0
i = 0
print "\nDays :",days ,":",time_b[j].strftime('%a')
off_item = rand_turnon()  
no_item = rand_duration()  

while (j <= (5760*d)-1):  
    c.execute("INSERT INTO device.elec_thermos (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
    conn.commit()
    j += 1 
    
    while (off_item+(5760*(days)) <= j <= (no_item+off_item)+(5760*(days))):                   
        c.execute("INSERT INTO device.elec_thermos (Timestamp, watt) VALUES (%s, %s)",(time_b[j],df.watt[i]))
        conn.commit()
        i += 1 
        j += 1
        if (j == (no_item+off_item)+(5760*(days))):
            days +=1
            print "\nDays :",days ,":",time_b[j].strftime('%a')
            off_item = rand_turnon()  
            no_item = rand_duration() 
            i= 0   

                    
print "DONE!"
# Out:
# device.elec_thermos are Empty!!!
#
#
# Days : 0 : Thu
# time to turn-on appliacne on 7 : 35 : 9 equal to 1820 items
# consuming the appliance 0 hours 37 minutes 41 seconds that equal to 2261 seconds or 150 items
#
# Days : 1 : Thu
# time to turn-on appliacne on 8 : 22 : 23 equal to 2009 items
# consuming the appliance 0 hours 6 minutes 7 seconds that equal to 367 seconds or 24 items
#
# Days : 2 : Fri
# time to turn-on appliacne on 8 : 45 : 34 equal to 2102 items
# consuming the appliance 0 hours 20 minutes 39 seconds that equal to 1239 seconds or 82 items
#
# Days : 3 : Sat
# time to turn-on appliacne on 8 : 12 : 14 equal to 1968 items
# consuming the appliance 0 hours 5 minutes 14 seconds that equal to 314 seconds or 20 items
#
# Days : 4 : Sun
# time to turn-on appliacne on 9 : 43 : 49 equal to 2335 items
# consuming the appliance 0 hours 4 minutes 2 seconds that equal to 242 seconds or 16 items
#
# Days : 5 : Mon
# time to turn-on appliacne on 7 : 33 : 15 equal to 1812 items
# consuming the appliance 0 hours 12 minutes 25 seconds that equal to 745 seconds or 49 items
#
# Days : 6 : Tue
# time to turn-on appliacne on 7 : 50 : 29 equal to 1881 items
# consuming the appliance 0 hours 51 minutes 45 seconds that equal to 3105 seconds or 207 items
#
# Days : 7 : Wed
# time to turn-on appliacne on 7 : 21 : 42 equal to 1766 items
# consuming the appliance 0 hours 59 minutes 3 seconds that equal to 3543 seconds or 236 items
#
# Days : 8 : Thu
# time to turn-on appliacne on 7 : 39 : 59 equal to 1839 items
# consuming the appliance 0 hours 56 minutes 54 seconds that equal to 3414 seconds or 227 items
#
# Days : 9 : Fri
# time to turn-on appliacne on 8 : 51 : 31 equal to 2126 items
# consuming the appliance 0 hours 29 minutes 13 seconds that equal to 1753 seconds or 116 items
#
# Days : 10 : Sat
# time to turn-on appliacne on 7 : 58 : 44 equal to 1914 items
# consuming the appliance 2 hours 50 minutes 53 seconds that equal to 10253 seconds or 683 items
#
# Days : 11 : Sun
# time to turn-on appliacne on 7 : 30 : 28 equal to 1801 items
# consuming the appliance 0 hours 21 minutes 51 seconds that equal to 1311 seconds or 87 items
#
# Days : 12 : Mon
# time to turn-on appliacne on 8 : 59 : 14 equal to 2156 items
# consuming the appliance 0 hours 27 minutes 53 seconds that equal to 1673 seconds or 111 items
#
# Days : 13 : Tue
# time to turn-on appliacne on 8 : 39 : 53 equal to 2079 items
# consuming the appliance 0 hours 23 minutes 17 seconds that equal to 1397 seconds or 93 items
#
# Days : 14 : Wed
# time to turn-on appliacne on 7 : 36 : 34 equal to 1826 items
# consuming the appliance 0 hours 7 minutes 49 seconds that equal to 469 seconds or 31 items
#
# Days : 15 : Thu
# time to turn-on appliacne on 7 : 36 : 51 equal to 1827 items
# consuming the appliance 0 hours 52 minutes 12 seconds that equal to 3132 seconds or 208 items
#
# Days : 16 : Fri
# time to turn-on appliacne on 7 : 1 : 44 equal to 1686 items
# consuming the appliance 0 hours 52 minutes 43 seconds that equal to 3163 seconds or 210 items
#
# Days : 17 : Sat
# time to turn-on appliacne on 9 : 40 : 25 equal to 2321 items
# consuming the appliance 0 hours 20 minutes 20 seconds that equal to 1220 seconds or 81 items
#
# Days : 18 : Sun
# time to turn-on appliacne on 8 : 9 : 34 equal to 1958 items
# consuming the appliance 1 hours 35 minutes 54 seconds that equal to 5754 seconds or 383 items
#
# Days : 19 : Mon
# time to turn-on appliacne on 7 : 11 : 9 equal to 1724 items
# consuming the appliance 0 hours 15 minutes 12 seconds that equal to 912 seconds or 60 items
#
# Days : 20 : Tue
# time to turn-on appliacne on 8 : 2 : 9 equal to 1928 items
# consuming the appliance 0 hours 9 minutes 9 seconds that equal to 549 seconds or 36 items
#
# Days : 21 : Wed
# time to turn-on appliacne on 7 : 8 : 1 equal to 1712 items
# consuming the appliance 0 hours 29 minutes 32 seconds that equal to 1772 seconds or 118 items
#
# Days : 22 : Thu
# time to turn-on appliacne on 8 : 51 : 57 equal to 2127 items
# consuming the appliance 0 hours 59 minutes 33 seconds that equal to 3573 seconds or 238 items
#
# Days : 23 : Fri
# time to turn-on appliacne on 8 : 56 : 25 equal to 2145 items
# consuming the appliance 0 hours 30 minutes 32 seconds that equal to 1832 seconds or 122 items
#
# Days : 24 : Sat
# time to turn-on appliacne on 7 : 57 : 41 equal to 1910 items
# consuming the appliance 0 hours 57 minutes 38 seconds that equal to 3458 seconds or 230 items
#
# Days : 25 : Sun
# time to turn-on appliacne on 7 : 29 : 10 equal to 1796 items
# consuming the appliance 0 hours 44 minutes 24 seconds that equal to 2664 seconds or 177 items
#
# Days : 26 : Mon
# time to turn-on appliacne on 7 : 19 : 21 equal to 1757 items
# consuming the appliance 0 hours 6 minutes 23 seconds that equal to 383 seconds or 25 items
#
# Days : 27 : Tue
# time to turn-on appliacne on 9 : 52 : 3 equal to 2368 items
# consuming the appliance 0 hours 28 minutes 4 seconds that equal to 1684 seconds or 112 items
#
# Days : 28 : Wed
# time to turn-on appliacne on 8 : 15 : 53 equal to 1983 items
# consuming the appliance 0 hours 19 minutes 7 seconds that equal to 1147 seconds or 76 items
#
# Days : 29 : Thu
# time to turn-on appliacne on 7 : 9 : 46 equal to 1719 items
# consuming the appliance 1 hours 56 minutes 26 seconds that equal to 6986 seconds or 465 items
#
# Days : 30 : Fri
# time to turn-on appliacne on 8 : 1 : 5 equal to 1924 items
# consuming the appliance 0 hours 55 minutes 8 seconds that equal to 3308 seconds or 220 items
#
# Days : 31 : Sat
# time to turn-on appliacne on 7 : 2 : 34 equal to 1690 items
# consuming the appliance 0 hours 57 minutes 58 seconds that equal to 3478 seconds or 231 items
# DONE!

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
# %matplotlib inline  


# query = "SELECT watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
query = "SELECT Timestamp,watt FROM device.elec_thermos WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[1200],time_b[2300])
df = pd.read_sql(query, conn, index_col=['Timestamp'])
fig, ax = plt.subplots()
ax.set_title('device.elec_thermos')
df.plot(ax=ax )
plt.show()
