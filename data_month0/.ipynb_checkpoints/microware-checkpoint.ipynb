# %% [markdown]
# ### Microwave | ขนาด 400W |
# ##### TYPE 2 " TURN ON EVERYDAY//ONCE TIME

# %% [markdown]
# ## NO. 12 (เตาไมโครเวฟ)
# * **รูปบนคิอที่วัดจริงได้ รูปล่างคือเอารูปบนไปทำซ่ำให้ได้ datasests = 1000 ค่า (ข้อมูลที่เก็บอยู่ใน MySQL คือรูปล่าง)**
# ![image](https://raw.githubusercontent.com/skyfighter/iHEMS/master/Device/pic/microwave%20oven_2.png)
# ![image](https://raw.githubusercontent.com/skyfighter/iHEMS/master/Device/pic/microwave%20oven_3.png)

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random


d = 31
time_a = pd.date_range('2016-09-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-09-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####### set databases to empty #########
query_empty = """truncate table device.Microwave""" 
c.execute(query_empty)
print "device.Microwave are Empty!!! \n"

query = "SELECT watt FROM collected_info.12_Microwave WHERE no >= '%s'   AND no <= '%s'; "% (0,1300)
df = pd.read_sql(query, conn)
# print df.watt[5]

#### Random the turning-on time appliances
def rand_turnon():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(0, 59)
    duration_hour1 = ['18'] * 40 + ['19'] * 45 + ['20'] * 12 + ['21'] * 3
    duration_hour = random.choice(duration_hour1)     
    if 0 < duration_sec <= 15:
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
    off_item = (int(duration_hour)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on appliacne on",duration_hour,":",duration_min,":",duration_sec,"equal to",off_item,"items"
    return off_item

 
#### Random the off-duration appliances 
def rand_duration():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(10, 40)
    duration_hour1 = ['0'] * 50 + ['0'] * 1+ ['0'] * 49
    duration_hour = random.choice(duration_hour1)   
    seconds = (int(duration_hour)*3600)+(duration_min*60)+duration_sec
    no_item = seconds/15
    print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items"
    return no_item

days = 0
j = 0
i = 0
print "\nDays :",days ,":",time_b[j].strftime('%a')
off_item = rand_turnon()  
no_item = rand_duration()  

while (j <= (5760*d)-1):  
    c.execute("INSERT INTO device.Microwave (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
    conn.commit()
    j += 1 
    
    while (off_item+(5760*(days)) <= j <= (no_item+off_item)+(5760*(days))):                   
        c.execute("INSERT INTO device.Microwave (Timestamp, watt) VALUES (%s, %s)",(time_b[j],df.watt[i]))
        conn.commit()
        i += 1 
        j += 1
        if (j == (no_item+off_item)+(5760*(days))):
            days +=1
            print "\nDays :",days ,":",time_b[j].strftime('%a')
            off_item = rand_turnon()  
            no_item = rand_duration() 
            i= 0   

                    
print "DONE!"
# Out:
# device.Microwave are Empty!!!
#
#
# Days : 0 : Thu
# time to turn-on appliacne on 18 : 10 : 10 equal to 4360 items
# consuming the appliance 0 hours 21 minutes 21 seconds that equal to 1281 seconds or 85 items
#
# Days : 1 : Thu
# time to turn-on appliacne on 19 : 43 : 56 equal to 4735 items
# consuming the appliance 0 hours 20 minutes 19 seconds that equal to 1219 seconds or 81 items
#
# Days : 2 : Fri
# time to turn-on appliacne on 19 : 40 : 33 equal to 4722 items
# consuming the appliance 0 hours 23 minutes 20 seconds that equal to 1400 seconds or 93 items
#
# Days : 3 : Sat
# time to turn-on appliacne on 20 : 21 : 59 equal to 4887 items
# consuming the appliance 0 hours 30 minutes 4 seconds that equal to 1804 seconds or 120 items
#
# Days : 4 : Sun
# time to turn-on appliacne on 19 : 20 : 41 equal to 4642 items
# consuming the appliance 0 hours 18 minutes 31 seconds that equal to 1111 seconds or 74 items
#
# Days : 5 : Mon
# time to turn-on appliacne on 19 : 44 : 29 equal to 4737 items
# consuming the appliance 0 hours 23 minutes 10 seconds that equal to 1390 seconds or 92 items
#
# Days : 6 : Tue
# time to turn-on appliacne on 19 : 45 : 0 equal to 4743 items
# consuming the appliance 0 hours 13 minutes 41 seconds that equal to 821 seconds or 54 items
#
# Days : 7 : Wed
# time to turn-on appliacne on 19 : 41 : 58 equal to 4727 items
# consuming the appliance 0 hours 31 minutes 40 seconds that equal to 1900 seconds or 126 items
#
# Days : 8 : Thu
# time to turn-on appliacne on 20 : 57 : 0 equal to 5031 items
# consuming the appliance 0 hours 11 minutes 54 seconds that equal to 714 seconds or 47 items
#
# Days : 9 : Fri
# time to turn-on appliacne on 19 : 7 : 48 equal to 4591 items
# consuming the appliance 0 hours 27 minutes 59 seconds that equal to 1679 seconds or 111 items
#
# Days : 10 : Sat
# time to turn-on appliacne on 18 : 30 : 14 equal to 4440 items
# consuming the appliance 0 hours 14 minutes 52 seconds that equal to 892 seconds or 59 items
#
# Days : 11 : Sun
# time to turn-on appliacne on 19 : 17 : 31 equal to 4630 items
# consuming the appliance 0 hours 22 minutes 12 seconds that equal to 1332 seconds or 88 items
#
# Days : 12 : Mon
# time to turn-on appliacne on 20 : 3 : 32 equal to 4814 items
# consuming the appliance 0 hours 30 minutes 37 seconds that equal to 1837 seconds or 122 items
#
# Days : 13 : Tue
# time to turn-on appliacne on 19 : 55 : 19 equal to 4781 items
# consuming the appliance 0 hours 21 minutes 43 seconds that equal to 1303 seconds or 86 items
#
# Days : 14 : Wed
# time to turn-on appliacne on 18 : 7 : 55 equal to 4351 items
# consuming the appliance 0 hours 19 minutes 16 seconds that equal to 1156 seconds or 77 items
#
# Days : 15 : Thu
# time to turn-on appliacne on 18 : 44 : 17 equal to 4497 items
# consuming the appliance 0 hours 38 minutes 5 seconds that equal to 2285 seconds or 152 items
#
# Days : 16 : Fri
# time to turn-on appliacne on 20 : 40 : 34 equal to 4962 items
# consuming the appliance 0 hours 12 minutes 40 seconds that equal to 760 seconds or 50 items
#
# Days : 17 : Sat
# time to turn-on appliacne on 18 : 37 : 10 equal to 4468 items
# consuming the appliance 0 hours 23 minutes 10 seconds that equal to 1390 seconds or 92 items
#
# Days : 18 : Sun
# time to turn-on appliacne on 19 : 5 : 8 equal to 4580 items
# consuming the appliance 0 hours 16 minutes 57 seconds that equal to 1017 seconds or 67 items
#
# Days : 19 : Mon
# time to turn-on appliacne on 18 : 21 : 25 equal to 4405 items
# consuming the appliance 0 hours 40 minutes 27 seconds that equal to 2427 seconds or 161 items
#
# Days : 20 : Tue
# time to turn-on appliacne on 19 : 50 : 6 equal to 4760 items
# consuming the appliance 0 hours 38 minutes 45 seconds that equal to 2325 seconds or 155 items
#
# Days : 21 : Wed
# time to turn-on appliacne on 19 : 43 : 15 equal to 4732 items
# consuming the appliance 0 hours 36 minutes 33 seconds that equal to 2193 seconds or 146 items
#
# Days : 22 : Thu
# time to turn-on appliacne on 19 : 19 : 2 equal to 4636 items
# consuming the appliance 0 hours 31 minutes 25 seconds that equal to 1885 seconds or 125 items
#
# Days : 23 : Fri
# time to turn-on appliacne on 20 : 23 : 27 equal to 4893 items
# consuming the appliance 0 hours 39 minutes 17 seconds that equal to 2357 seconds or 157 items
#
# Days : 24 : Sat
# time to turn-on appliacne on 18 : 52 : 35 equal to 4530 items
# consuming the appliance 0 hours 22 minutes 37 seconds that equal to 1357 seconds or 90 items
#
# Days : 25 : Sun
# time to turn-on appliacne on 18 : 24 : 43 equal to 4418 items
# consuming the appliance 0 hours 19 minutes 57 seconds that equal to 1197 seconds or 79 items
#
# Days : 26 : Mon
# time to turn-on appliacne on 19 : 28 : 32 equal to 4674 items
# consuming the appliance 0 hours 32 minutes 27 seconds that equal to 1947 seconds or 129 items
#
# Days : 27 : Tue
# time to turn-on appliacne on 19 : 43 : 16 equal to 4733 items
# consuming the appliance 0 hours 21 minutes 29 seconds that equal to 1289 seconds or 85 items
#
# Days : 28 : Wed
# time to turn-on appliacne on 18 : 55 : 37 equal to 4542 items
# consuming the appliance 0 hours 36 minutes 51 seconds that equal to 2211 seconds or 147 items
#
# Days : 29 : Thu
# time to turn-on appliacne on 20 : 47 : 26 equal to 4989 items
# consuming the appliance 0 hours 37 minutes 1 seconds that equal to 2221 seconds or 148 items
#
# Days : 30 : Fri
# time to turn-on appliacne on 20 : 31 : 36 equal to 4926 items
# consuming the appliance 0 hours 35 minutes 39 seconds that equal to 2139 seconds or 142 items
#
# Days : 31 : Sat
# time to turn-on appliacne on 18 : 3 : 5 equal to 4332 items
# consuming the appliance 0 hours 17 minutes 17 seconds that equal to 1037 seconds or 69 items
# DONE!

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
# %matplotlib inline  


# query = "SELECT watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
query = "SELECT Timestamp,watt FROM device.Microwave WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[3000],time_b[5760])
df = pd.read_sql(query, conn, index_col=['Timestamp'])
fig, ax = plt.subplots()
ax.set_title('device.Microwave')
df.plot(ax=ax )
plt.show()
