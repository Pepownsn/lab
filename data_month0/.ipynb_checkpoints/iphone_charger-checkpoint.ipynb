# %% [markdown]
# ### IPHONE charger | ipad 9.7 นิ้ว |
# ##### TYPE 2 " TURN ON EVERYDAY//ONCE TIME

# %% [markdown]
# ## NO. 13 (เชาร์ตแบตโทรศัพท์มือถือ)
# * ** iPad 9.7 **
# ![image](https://raw.githubusercontent.com/skyfighter/iHEMS/master/Device/pic/ipad.png)

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random


d = 31
time_a = pd.date_range('2016-09-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-09-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####### set databases to empty #########
query_empty = """truncate table device.iphonecharger""" 
c.execute(query_empty)
print "device.iphonecharger are Empty!!! \n"

query = "SELECT watt FROM collected_info.13_iphonecharger WHERE no >= '%s'   AND no <= '%s'; "% (0,1200)
df = pd.read_sql(query, conn)
# print df.watt[5]

#### Random the turning-on time appliances
def rand_turnon():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(0, 59)
    duration_hour1 = ['18'] * 5 + ['19'] * 8 + ['20'] * 36 + ['21'] * 30 + ['22'] * 13 + ['23'] * 6 + ['0'] * 2
    duration_hour = random.choice(duration_hour1)     
    if 0 < duration_sec <= 15:
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
    off_item = (int(duration_hour)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on appliacne on",duration_hour,":",duration_min,":",duration_sec,"equal to",off_item,"items"
    return off_item

 
#### Random the off-duration appliances 
def rand_duration():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(10, 40)
    duration_hour1 = ['0'] * 2 + ['1'] * 25 + ['2'] * 35+ ['3'] * 20 + ['4'] * 10 + ['5'] * 8
    duration_hour = random.choice(duration_hour1)   
    seconds = (int(duration_hour)*3600)+(duration_min*60)+duration_sec
    no_item = seconds/15
    print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items"
    return no_item

days = 0
j = 0
i = 0
print "\nDays :",days ,":",time_b[j].strftime('%a')
off_item = rand_turnon()  
no_item = rand_duration()  

while (j <= (5760*d)-1):  
    c.execute("INSERT INTO device.iphonecharger (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
    conn.commit()
    j += 1 
  
        
    while (off_item+(5760*(days)) <= j <= (no_item+off_item)+(5760*(days))):                   
        c.execute("INSERT INTO device.iphonecharger (Timestamp, watt) VALUES (%s, %s)",(time_b[j],df.watt[i]))
        conn.commit()
        i += 1 
        j += 1
            
        if (i >= len(df)):
            i = 0  
        if (j == (no_item+off_item)+(5760*(days))):
            days +=1
            print "\nDays :",days ,":",time_b[j].strftime('%a')
            off_item = rand_turnon()  
            no_item = rand_duration() 
            i= 0   

                    
print "DONE!"
# Out:
# device.iphonecharger are Empty!!!
#
#
# Days : 0 : Thu
# time to turn-on appliacne on 20 : 27 : 10 equal to 4908 items
# consuming the appliance 2 hours 24 minutes 18 seconds that equal to 8658 seconds or 577 items
#
# Days : 1 : Thu
# time to turn-on appliacne on 20 : 8 : 47 equal to 4835 items
# consuming the appliance 2 hours 27 minutes 46 seconds that equal to 8866 seconds or 591 items
#
# Days : 2 : Fri
# time to turn-on appliacne on 20 : 50 : 6 equal to 5000 items
# consuming the appliance 1 hours 27 minutes 56 seconds that equal to 5276 seconds or 351 items
#
# Days : 3 : Sat
# time to turn-on appliacne on 18 : 41 : 40 equal to 4486 items
# consuming the appliance 3 hours 26 minutes 47 seconds that equal to 12407 seconds or 827 items
#
# Days : 4 : Sun
# time to turn-on appliacne on 19 : 24 : 36 equal to 4658 items
# consuming the appliance 1 hours 26 minutes 54 seconds that equal to 5214 seconds or 347 items
#
# Days : 5 : Mon
# time to turn-on appliacne on 23 : 38 : 36 equal to 5674 items
# consuming the appliance 1 hours 30 minutes 1 seconds that equal to 5401 seconds or 360 items
#
# Days : 6 : Wed
# time to turn-on appliacne on 21 : 11 : 35 equal to 5086 items
# consuming the appliance 1 hours 32 minutes 3 seconds that equal to 5523 seconds or 368 items
#
# Days : 7 : Wed
# time to turn-on appliacne on 23 : 51 : 2 equal to 5724 items
# consuming the appliance 4 hours 33 minutes 21 seconds that equal to 16401 seconds or 1093 items
#
# Days : 8 : Fri
# time to turn-on appliacne on 19 : 11 : 36 equal to 4606 items
# consuming the appliance 5 hours 26 minutes 41 seconds that equal to 19601 seconds or 1306 items
#
# Days : 9 : Sat
# time to turn-on appliacne on 19 : 15 : 5 equal to 4620 items
# consuming the appliance 5 hours 38 minutes 52 seconds that equal to 20332 seconds or 1355 items
#
# Days : 10 : Sun
# time to turn-on appliacne on 21 : 24 : 23 equal to 5137 items
# consuming the appliance 2 hours 11 minutes 26 seconds that equal to 7886 seconds or 525 items
#
# Days : 11 : Sun
# time to turn-on appliacne on 22 : 6 : 27 equal to 5305 items
# consuming the appliance 2 hours 34 minutes 44 seconds that equal to 9284 seconds or 618 items
#
# Days : 12 : Tue
# time to turn-on appliacne on 20 : 7 : 20 equal to 4829 items
# consuming the appliance 3 hours 25 minutes 57 seconds that equal to 12357 seconds or 823 items
#
# Days : 13 : Tue
# time to turn-on appliacne on 22 : 24 : 4 equal to 5376 items
# consuming the appliance 4 hours 31 minutes 32 seconds that equal to 16292 seconds or 1086 items
#
# Days : 14 : Thu
# time to turn-on appliacne on 19 : 56 : 44 equal to 4786 items
# consuming the appliance 2 hours 30 minutes 39 seconds that equal to 9039 seconds or 602 items
#
# Days : 15 : Thu
# time to turn-on appliacne on 0 : 14 : 52 equal to 59 items
# consuming the appliance 1 hours 27 minutes 13 seconds that equal to 5233 seconds or 348 items
#
# Days : 16 : Fri
# time to turn-on appliacne on 20 : 59 : 13 equal to 5036 items
# consuming the appliance 5 hours 34 minutes 33 seconds that equal to 20073 seconds or 1338 items
#
# Days : 17 : Sun
# time to turn-on appliacne on 20 : 20 : 52 equal to 4883 items
# consuming the appliance 1 hours 27 minutes 7 seconds that equal to 5227 seconds or 348 items
#
# Days : 18 : Sun
# time to turn-on appliacne on 21 : 40 : 36 equal to 5202 items
# consuming the appliance 2 hours 17 minutes 37 seconds that equal to 8257 seconds or 550 items
#
# Days : 19 : Mon
# time to turn-on appliacne on 23 : 0 : 33 equal to 5522 items
# consuming the appliance 1 hours 18 minutes 18 seconds that equal to 4698 seconds or 313 items
#
# Days : 20 : Wed
# time to turn-on appliacne on 23 : 9 : 49 equal to 5559 items
# consuming the appliance 1 hours 30 minutes 7 seconds that equal to 5407 seconds or 360 items
#
# Days : 21 : Thu
# time to turn-on appliacne on 22 : 38 : 12 equal to 5432 items
# consuming the appliance 2 hours 29 minutes 6 seconds that equal to 8946 seconds or 596 items
#
# Days : 22 : Fri
# time to turn-on appliacne on 20 : 50 : 47 equal to 5003 items
# consuming the appliance 1 hours 19 minutes 44 seconds that equal to 4784 seconds or 318 items
#
# Days : 23 : Fri
# time to turn-on appliacne on 20 : 13 : 38 equal to 4854 items
# consuming the appliance 2 hours 31 minutes 51 seconds that equal to 9111 seconds or 607 items
#
# Days : 24 : Sat
# time to turn-on appliacne on 20 : 13 : 12 equal to 4852 items
# consuming the appliance 1 hours 20 minutes 28 seconds that equal to 4828 seconds or 321 items
#
# Days : 25 : Sun
# time to turn-on appliacne on 21 : 23 : 54 equal to 5135 items
# consuming the appliance 3 hours 23 minutes 33 seconds that equal to 12213 seconds or 814 items
#
# Days : 26 : Tue
# time to turn-on appliacne on 21 : 10 : 12 equal to 5080 items
# consuming the appliance 2 hours 34 minutes 52 seconds that equal to 9292 seconds or 619 items
#
# Days : 27 : Tue
# time to turn-on appliacne on 21 : 31 : 20 equal to 5165 items
# consuming the appliance 2 hours 40 minutes 44 seconds that equal to 9644 seconds or 642 items
#
# Days : 28 : Thu
# time to turn-on appliacne on 20 : 11 : 31 equal to 4846 items
# consuming the appliance 3 hours 39 minutes 3 seconds that equal to 13143 seconds or 876 items
#
# Days : 29 : Thu
# time to turn-on appliacne on 20 : 7 : 17 equal to 4829 items
# consuming the appliance 1 hours 15 minutes 30 seconds that equal to 4530 seconds or 302 items
#
# Days : 30 : Fri
# time to turn-on appliacne on 19 : 27 : 15 equal to 4668 items
# consuming the appliance 2 hours 32 minutes 9 seconds that equal to 9129 seconds or 608 items
#
# Days : 31 : Sat
# time to turn-on appliacne on 21 : 44 : 1 equal to 5216 items
# consuming the appliance 1 hours 36 minutes 45 seconds that equal to 5805 seconds or 387 items
# DONE!

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
# %matplotlib inline  


query = "SELECT Timestamp,watt FROM device.iphonecharger WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[5760*5])
df = pd.read_sql(query, conn, index_col=['Timestamp'])
fig, ax = plt.subplots()
ax.set_title('device.iphonecharger')
df.plot(ax=ax )
plt.show()
