# %% [markdown]
# ### TV | LCD ขนาด 49 นิ้ว |
# ##### TYPE 3 " TURN ON EVERYDAY // 1-3 TIMES

# %% [markdown]
# ## NO. 3 (โทรทัศน์)
# ![image](https://raw.githubusercontent.com/skyfighter/iHEMS/master/Device/pic/TV.png)

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random


d = 31

time_a = pd.date_range('2016-09-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-09-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####### set databases to empty #########
query_empty = """truncate table device.TV""" 
c.execute(query_empty)
print "device.TV are Empty!!! \n"

query = "SELECT watt FROM collected_info.3_TV WHERE no >= '%s'   AND no <= '%s'; "% (0,1200)
df = pd.read_sql(query, conn)
# print df.watt[5]

#### Random the number of turnon-time per day
def manytime():
    many  = ['1'] * 50 + ['2'] * 44 + ['3'] * 6  ## The number of turn-on time of this appliance 
    manytime = random.choice(many)
    print "\nDays :",days ,":",time_b[j].strftime('%a')
    print "in recent day turn on TV",manytime,"times\n"
    if (int(manytime) == 1):
        x,y,endx,endy = 18,20,2,4  # fix turn on only in evening      
        open_hour =  random.randint(x, y)
        open_min =  random.randint(0, 59)
        open_sec =  random.randint(0, 59)
        if 0 < open_sec  <= 15:
            k = 0
        elif 15 < open_sec  <= 30:
            k = 1
        elif 30 < open_sec  <= 45:
            k = 2
        else:
            k = 3
        off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
        print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
        
        duration_hour =  random.randint(endx, endy)
        duration_min =  random.randint(0, 59)
        duration_sec =  random.randint(0, 59)
        seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
        no_item = seconds/15
        print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"
        return (off_item,no_item)

        
    elif (int(manytime) == 2):
        turn_duratrion  = ['1'] * 70 + ['2'] * 30       #### '1' turn-on morning and evening   OR  '2' turn-on 2 times in evening 
        howturn = random.choice(turn_duratrion)
#         print howturn
        if (int(howturn)== 1 ):
            x,y,endx,endy = 6,7,1,59
            open_hour =  random.randint(x, y)
            open_min =  random.randint(0, 59)
            open_sec =  random.randint(0, 59)
            if 0 < open_sec  <= 15:
                k = 0
            elif 15 < open_sec  <= 30:
                k = 1
            elif 30 < open_sec  <= 45:
                k = 2
            else:
                k = 3
            off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
            print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
            
            duration_hour =  random.randint(0, 0)
            duration_min =  random.randint(endx, endy)
            duration_sec =  random.randint(0, 59)
            seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
            no_item = seconds/15
            print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"

        
            
            x1,y1,endx1,endy1 = 18,20,2,4
            open_hour1 =  random.randint(x1, y1)
            open_min1 =  random.randint(0, 59)
            open_sec1 =  random.randint(0, 59)
            if 0 < open_sec1  <= 15:
                k = 0
            elif 15 < open_sec1  <= 30:
                k = 1
            elif 30 < open_sec1  <= 45:
                k = 2
            else:
                k = 3
            off_item1 = (int(open_hour1)*240) + (int(open_min1)*4)+ k 
            print "time to turn-on appliacne on",open_hour1,":",open_min1,":",open_sec1,"equal to",off_item1,"items"     
            
            duration_hour1 =  random.randint(endx1, endy1)
            duration_min1 =  random.randint(0, 59)
            duration_sec1 =  random.randint(0, 59)
            seconds1 = (duration_hour1*3600)+(duration_min1*60)+duration_sec1
            no_item1 = seconds1/15
            print "consuming the appliance", duration_hour1,"hours",duration_min1,"minutes",duration_sec1,"seconds that equal to",seconds1,"seconds or",no_item1,"items\n"

        else :
            x,y,endx,endy = 18,19,1,59
            open_hour =  random.randint(x, y)
            open_min =  random.randint(0, 59)
            open_sec =  random.randint(0, 59)
            if 0 < open_sec  <= 15:
                k = 0
            elif 15 < open_sec  <= 30:
                k = 1
            elif 30 < open_sec  <= 45:
                k = 2
            else:
                k = 3
            off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
            print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
            
            duration_hour =  random.randint(0, 0)
            duration_min =  random.randint(endx, endy)
            duration_sec =  random.randint(0, 59)
            seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
            no_item = seconds/15
            print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"

        
            x1,y1,endx1,endy1 = 20,22,1,4
            open_hour1 =  random.randint(x1, y1)
            open_min1 =  random.randint(0, 59)
            open_sec1 =  random.randint(0, 59)
            if 0 < open_sec1  <= 15:
                k = 0
            elif 15 < open_sec1  <= 30:
                k = 1
            elif 30 < open_sec1  <= 45:
                k = 2
            else:
                k = 3
            off_item1 = (int(open_hour1)*240) + (int(open_min1)*4)+ k 
            print "time to turn-on appliacne on",open_hour1,":",open_min1,":",open_sec1,"equal to",off_item1,"items"   
            
            duration_hour1 =  random.randint(endx1, endy1)
            duration_min1 =  random.randint(0, 59)
            duration_sec1 =  random.randint(0, 59)
            seconds1 = (duration_hour1*3600)+(duration_min1*60)+duration_sec1
            no_item1 = seconds1/15
            print "consuming the appliance", duration_hour1,"hours",duration_min1,"minutes",duration_sec1,"seconds that equal to",seconds1,"seconds or",no_item1,"items\n"

        return (off_item,no_item,off_item1,no_item1)        
    else:
        x,y,endx,endy = 6,7,30,60
        open_hour =  random.randint(x, y)
        open_min =  random.randint(0, 59)
        open_sec =  random.randint(0, 59)
        if 0 < open_sec  <= 15:
            k = 0
        elif 15 < open_sec  <= 30:
            k = 1
        elif 30 < open_sec  <= 45:
            k = 2
        else:
            k = 3
        off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
        print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
        
        duration_hour =  random.randint(0,0)
        duration_min =  random.randint(endx, endy)
        duration_sec =  random.randint(0, 59)
        seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
        no_item = seconds/15
        print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"

    
    
        x1,y1,endx1,endy1 = 18,19,1,59
        open_hour1 =  random.randint(x1, y1)
        open_min1 =  random.randint(0, 59)
        open_sec1 =  random.randint(0, 59)
        if 0 < open_sec1  <= 15:
            k = 0
        elif 15 < open_sec1  <= 30:
            k = 1
        elif 30 < open_sec1  <= 45:
            k = 2
        else:
            k = 3
        off_item1 = (int(open_hour1)*240) + (int(open_min1)*4)+ k 
        print "time to turn-on appliacne on",open_hour1,":",open_min1,":",open_sec1,"equal to",off_item1,"items" 
        duration_hour1 =  random.randint(0, 0)
        duration_min1 =  random.randint(endx1, endy1)
        duration_sec1 =  random.randint(0, 59)
        seconds1 = (duration_hour1*3600)+(duration_min1*60)+duration_sec1
        no_item1 = seconds1/15
        print "consuming the appliance", duration_hour1,"hours",duration_min1,"minutes",duration_sec1,"seconds that equal to",seconds1,"seconds or",no_item1,"items\n"
    
    
        x2,y2,endx2,endy2 = 20,22,1,4
        open_hour2 =  random.randint(x2, y2)
        open_min2 =  random.randint(0, 59)
        open_sec2 =  random.randint(0, 59)
        if 0 < open_sec2  <= 15:
            k = 0
        elif 15 < open_sec2  <= 30:
            k = 1
        elif 30 < open_sec2  <= 45:
            k = 2
        else:
            k = 3
        off_item2 = (int(open_hour2)*240) + (int(open_min2)*4)+ k 
        print "time to turn-on appliacne on",open_hour2,":",open_min2,":",open_sec2,"equal to",off_item2,"items" 
        duration_hour2 =  random.randint(endx2, endy2)
        duration_min2 =  random.randint(0, 59)
        duration_sec2 =  random.randint(0, 59)
        seconds2 = (duration_hour2*3600)+(duration_min2*60)+duration_sec2
        no_item2 = seconds2/15
        print "consuming the appliance", duration_hour2,"hours",duration_min2,"minutes",duration_sec2,"seconds that equal to",seconds2,"seconds or",no_item2,"items\n"
        return (off_item,no_item,off_item1,no_item1,off_item2,no_item2)    
    
    
        
days = 1
j = 0

## (off_item,no_item,off_item1,no_item1,off_item2,no_item2)    

turn = manytime()
while (j <= (5760*d)-1):   
    if (j == 5760+(5760*(days-1))):
        days +=1
        print "-------------------------ENd-----------------------------\n"
        turn = manytime()          
        
    if len(turn)==2:
        off_item = turn[0] 
        no_item = turn[1]
        if (off_item+(5760*(days-1)) <= j <= (no_item+off_item)+(5760*(days-1))):
            c.execute("INSERT INTO device.TV (Timestamp, watt) VALUES (%s, %s)",(time_b[j],random.randint(64, 68)))
            conn.commit()
            j += 1
        else:
            c.execute("INSERT INTO device.TV (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
            conn.commit()
            j += 1
        
    elif len(turn)==4:
        off_item = turn[0] 
        no_item = turn[1]
        off_item1 = turn[2] 
        no_item1 = turn[3]
        if (off_item+(5760*(days-1)) <= j <= (no_item+off_item)+(5760*(days-1)) or off_item1+(5760*(days-1)) <= j <= (no_item1+off_item1)+(5760*(days-1))):
            c.execute("INSERT INTO device.TV (Timestamp, watt) VALUES (%s, %s)",(time_b[j],random.randint(64, 68)))
            conn.commit()
            j += 1
        else:
            c.execute("INSERT INTO device.TV (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
            conn.commit()
            j += 1
             
    else:
        off_item = turn[0] 
        no_item = turn[1]
        off_item1 = turn[2] 
        no_item1 = turn[3]
        off_item2 = turn[4] 
        no_item2 = turn[5]
        
        if (off_item+(5760*(days-1)) <= j <= (no_item+off_item)+(5760*(days-1)) or off_item1+(5760*(days-1)) <= j <= (no_item1+off_item1)+(5760*(days-1)) or off_item2+(5760*(days-1)) <= j <= (no_item2+off_item2)+(5760*(days-1)))  :
            c.execute("INSERT INTO device.TV (Timestamp, watt) VALUES (%s, %s)",(time_b[j],random.randint(64, 68)))
            conn.commit()
            j += 1
        else:
            c.execute("INSERT INTO device.TV (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
            conn.commit()
            j += 1
 
           
print "DONE!"
# Out:
# device.TV are Empty!!!
#
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 20 : 14 : 47 equal to 4859 items
# consuming the appliance 3 hours 23 minutes 17 seconds that equal to 12197 seconds or 813 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 20 : 26 : 30 equal to 4905 items
# consuming the appliance 3 hours 29 minutes 5 seconds that equal to 12545 seconds or 836 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 7 : 52 : 28 equal to 1889 items
# consuming the appliance 0 hours 59 minutes 2 seconds that equal to 3542 seconds or 236 items
#
# time to turn-on appliacne on 20 : 12 : 2 equal to 4848 items
# consuming the appliance 2 hours 24 minutes 14 seconds that equal to 8654 seconds or 576 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 19 : 46 : 31 equal to 4746 items
# consuming the appliance 0 hours 20 minutes 54 seconds that equal to 1254 seconds or 83 items
#
# time to turn-on appliacne on 22 : 39 : 21 equal to 5437 items
# consuming the appliance 4 hours 47 minutes 8 seconds that equal to 17228 seconds or 1148 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 19 : 41 : 11 equal to 4724 items
# consuming the appliance 3 hours 34 minutes 42 seconds that equal to 12882 seconds or 858 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 18 : 25 : 45 equal to 4422 items
# consuming the appliance 0 hours 32 minutes 43 seconds that equal to 1963 seconds or 130 items
#
# time to turn-on appliacne on 20 : 11 : 19 equal to 4845 items
# consuming the appliance 1 hours 29 minutes 1 seconds that equal to 5341 seconds or 356 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 20 : 4 : 43 equal to 4818 items
# consuming the appliance 3 hours 34 minutes 5 seconds that equal to 12845 seconds or 856 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 6 : 25 : 38 equal to 1542 items
# consuming the appliance 0 hours 39 minutes 7 seconds that equal to 2347 seconds or 156 items
#
# time to turn-on appliacne on 18 : 14 : 56 equal to 4379 items
# consuming the appliance 2 hours 31 minutes 20 seconds that equal to 9080 seconds or 605 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 18 : 38 : 53 equal to 4475 items
# consuming the appliance 3 hours 56 minutes 4 seconds that equal to 14164 seconds or 944 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 6 : 30 : 12 equal to 1560 items
# consuming the appliance 0 hours 57 minutes 4 seconds that equal to 3424 seconds or 228 items
#
# time to turn-on appliacne on 19 : 34 : 36 equal to 4698 items
# consuming the appliance 2 hours 51 minutes 38 seconds that equal to 10298 seconds or 686 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 6 : 30 : 1 equal to 1560 items
# consuming the appliance 0 hours 31 minutes 45 seconds that equal to 1905 seconds or 127 items
#
# time to turn-on appliacne on 20 : 19 : 26 equal to 4877 items
# consuming the appliance 3 hours 59 minutes 48 seconds that equal to 14388 seconds or 959 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 18 : 53 : 54 equal to 4535 items
# consuming the appliance 0 hours 43 minutes 8 seconds that equal to 2588 seconds or 172 items
#
# time to turn-on appliacne on 20 : 13 : 39 equal to 4854 items
# consuming the appliance 4 hours 51 minutes 55 seconds that equal to 17515 seconds or 1167 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 19 : 35 : 25 equal to 4701 items
# consuming the appliance 3 hours 34 minutes 4 seconds that equal to 12844 seconds or 856 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on TV 3 times
#
# time to turn-on appliacne on 6 : 56 : 21 equal to 1665 items
# consuming the appliance 0 hours 54 minutes 6 seconds that equal to 3246 seconds or 216 items
#
# time to turn-on appliacne on 18 : 13 : 29 equal to 4373 items
# consuming the appliance 0 hours 26 minutes 35 seconds that equal to 1595 seconds or 106 items
#
# time to turn-on appliacne on 22 : 1 : 19 equal to 5285 items
# consuming the appliance 1 hours 37 minutes 24 seconds that equal to 5844 seconds or 389 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 7 : 23 : 51 equal to 1775 items
# consuming the appliance 0 hours 46 minutes 36 seconds that equal to 2796 seconds or 186 items
#
# time to turn-on appliacne on 18 : 58 : 58 equal to 4555 items
# consuming the appliance 3 hours 9 minutes 21 seconds that equal to 11361 seconds or 757 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 20 : 1 : 18 equal to 4805 items
# consuming the appliance 4 hours 3 minutes 31 seconds that equal to 14611 seconds or 974 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 18 : 16 : 22 equal to 4385 items
# consuming the appliance 4 hours 25 minutes 48 seconds that equal to 15948 seconds or 1063 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 20 : 56 : 52 equal to 5027 items
# consuming the appliance 2 hours 16 minutes 22 seconds that equal to 8182 seconds or 545 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on TV 3 times
#
# time to turn-on appliacne on 7 : 57 : 11 equal to 1908 items
# consuming the appliance 0 hours 34 minutes 12 seconds that equal to 2052 seconds or 136 items
#
# time to turn-on appliacne on 18 : 0 : 43 equal to 4322 items
# consuming the appliance 0 hours 56 minutes 59 seconds that equal to 3419 seconds or 227 items
#
# time to turn-on appliacne on 21 : 37 : 21 equal to 5189 items
# consuming the appliance 3 hours 3 minutes 31 seconds that equal to 11011 seconds or 734 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 19 : 13 : 36 equal to 4614 items
# consuming the appliance 4 hours 5 minutes 20 seconds that equal to 14720 seconds or 981 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 19 : 56 : 32 equal to 4786 items
# consuming the appliance 3 hours 37 minutes 12 seconds that equal to 13032 seconds or 868 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 19 : 15 : 31 equal to 4622 items
# consuming the appliance 0 hours 20 minutes 2 seconds that equal to 1202 seconds or 80 items
#
# time to turn-on appliacne on 21 : 57 : 8 equal to 5268 items
# consuming the appliance 1 hours 8 minutes 1 seconds that equal to 4081 seconds or 272 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 6 : 12 : 52 equal to 1491 items
# consuming the appliance 0 hours 31 minutes 52 seconds that equal to 1912 seconds or 127 items
#
# time to turn-on appliacne on 18 : 29 : 22 equal to 4437 items
# consuming the appliance 3 hours 43 minutes 14 seconds that equal to 13394 seconds or 892 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 19 : 15 : 35 equal to 4622 items
# consuming the appliance 2 hours 27 minutes 6 seconds that equal to 8826 seconds or 588 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 18 : 12 : 46 equal to 4371 items
# consuming the appliance 3 hours 13 minutes 21 seconds that equal to 11601 seconds or 773 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 6 : 15 : 11 equal to 1500 items
# consuming the appliance 0 hours 17 minutes 54 seconds that equal to 1074 seconds or 71 items
#
# time to turn-on appliacne on 18 : 1 : 6 equal to 4324 items
# consuming the appliance 2 hours 18 minutes 22 seconds that equal to 8302 seconds or 553 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 18 : 52 : 24 equal to 4529 items
# consuming the appliance 3 hours 21 minutes 12 seconds that equal to 12072 seconds or 804 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 6 : 17 : 59 equal to 1511 items
# consuming the appliance 0 hours 26 minutes 34 seconds that equal to 1594 seconds or 106 items
#
# time to turn-on appliacne on 19 : 6 : 4 equal to 4584 items
# consuming the appliance 2 hours 19 minutes 57 seconds that equal to 8397 seconds or 559 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 7 : 1 : 29 equal to 1685 items
# consuming the appliance 0 hours 41 minutes 48 seconds that equal to 2508 seconds or 167 items
#
# time to turn-on appliacne on 20 : 53 : 19 equal to 5013 items
# consuming the appliance 4 hours 24 minutes 10 seconds that equal to 15850 seconds or 1056 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 18 : 9 : 56 equal to 4359 items
# consuming the appliance 3 hours 43 minutes 26 seconds that equal to 13406 seconds or 893 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 18 : 39 : 0 equal to 4479 items
# consuming the appliance 0 hours 48 minutes 32 seconds that equal to 2912 seconds or 194 items
#
# time to turn-on appliacne on 22 : 5 : 49 equal to 5303 items
# consuming the appliance 1 hours 4 minutes 12 seconds that equal to 3852 seconds or 256 items
#
# DONE!

# %%
import matplotlib.pyplot as plt
# %matplotlib inline  


# query = "SELECT watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
query = "SELECT Timestamp,watt FROM device.TV WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[3000],time_b[5760*2])
df = pd.read_sql(query, conn, index_col=['Timestamp'])

fig, ax = plt.subplots()
ax.set_title('device.TV')
ax.set_ylim(64,68)
df.plot(ax=ax )
plt.show()
df.to_csv('file.csv')
len(time_b)
# Out:
# 178560
