# %% [markdown]
# # DEATH ZONE
# ## ห้ามลบนะ ห้ามแก้ด้วย ห้ามรันใหม่

# %%
import pandas as pd
import MySQLdb
import time
import sys
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt

j = 0
y= []
z= []
y1= []
z1= []
y2= []
z2= []
conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()


query_empty = """truncate table check_event.active""" 
c.execute(query_empty)
print "check_event.active are Empty!!! \n"

while (j<=2700):
    x = round(random.uniform(1,100))
    if x <= 5 :
        y.append(j) 
        g = 1  
 
    else:
        z.append(j)
        g = 0

        
    x2 = round(random.uniform(1,100))
    if x2 <= 10 :
        y1.append(j) 
        g1 = 1     
    else:
        z1.append(j)
        g1 = 0
  
        
    x3 = round(random.uniform(1,100))
    if x3 <= 15 :
        y2.append(j) 
        g2 = 1  
    else:
        z2.append(j)   
        g2 = 0
        
    c.execute("INSERT INTO check_event.active (no, active5,active10,active15) VALUES ( %s, %s,%s,%s)",(j,g,g1,g2))
    conn.commit()
    
    j +=1
    print ".",
         
print "|||||||||||||||DONE|||||||||||||||"
# Out:
# check_event.active are Empty!!!
#
# ...
