# %%
import matplotlib.pyplot as plt
import pandas as pd # v. 1.7
import MySQLdb
import numpy as np
from sklearn.metrics import mean_absolute_error,mean_squared_error
import statistics 
# %matplotlib inline

# %%
conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

query = "SELECT * FROM active.target_all WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% ('2016-10-01 00:00:00','2016-10-1 23:59:59')
print query
df = pd.read_sql(query, conn )


df['load'] = df.p10 * 1.2031160051

del df["watt"]
fig, (ax0) = plt.subplots(nrows=1,figsize=(9*2, 4*2))
ax0.set_title('Data in 15 Minute @ 10W')
df.plot(ax=ax0)

plt.show()
# Out:
# SELECT * FROM active.target_all WHERE Timestamp >= '2016-10-01 00:00:00'   AND Timestamp <= '2016-10-1 23:59:59';
