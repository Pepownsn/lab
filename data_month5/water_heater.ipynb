# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random

d = 29
time_a = pd.date_range('2017-02-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2017-02-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####### set databases to empty #########
query_empty = """truncate table data_month5.water_heater""" 
c.execute(query_empty)
print "data_month5.water_heater are Empty!!! \n"

query = "SELECT watt FROM collected_info.5_water_heater WHERE no >= '%s'   AND no <= '%s'; "% (0,1000)
df = pd.read_sql(query, conn)


#### Random the number of turnon-time per day
def manytime():
    many  = ['0'] * 50 + ['1'] * 30 + ['2'] * 20  ## The number of turn-on time of this appliance 
    manytime = random.choice(many)
    print "in recent day turn on water_heater",manytime,"times\n" 
    if (int(manytime) == 0):
        off_item = [0]
        return (off_item)
    
    elif (int(manytime) == 1):
        x,y,endx,endy = 20,23,1,59
        open_hour =  random.randint(x, y)
        open_min =  random.randint(0, 59)
        open_sec =  random.randint(0, 59)
        if 0 < open_sec  <= 15:
            k = 0
        elif 15 < open_sec  <= 30:
            k = 1
        elif 30 < open_sec  <= 45:
            k = 2
        else:
            k = 3
        off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
        print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
            
        duration_hour =  random.randint(0, 0)
        duration_min =  random.randint(endx, endy)
        duration_sec =  random.randint(0, 59)
        seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
        no_item = seconds/15
        print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n" 
        return (off_item,no_item)
              
    else :
        x,y,endx,endy = 7,10,1,59
        open_hour =  random.randint(x, y)
        open_min =  random.randint(0, 59)
        open_sec =  random.randint(0, 59)
        if 0 < open_sec  <= 15:
            k = 0
        elif 15 < open_sec  <= 30:
            k = 1
        elif 30 < open_sec  <= 45:
            k = 2
        else:
            k = 3
        off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
        print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
            
        duration_hour =  random.randint(0, 0)
        duration_min =  random.randint(endx, endy)
        duration_sec =  random.randint(0, 59)
        seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
        no_item = seconds/15
        print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"
            
        x1,y1,endx1,endy1 = 20,23,1,59
        open_hour1 =  random.randint(x1, y1)
        open_min1 =  random.randint(0, 59)
        open_sec1 =  random.randint(0, 59)
        if 0 < open_sec1  <= 15:
            k = 0
        elif 15 < open_sec1  <= 30:
            k = 1
        elif 30 < open_sec1  <= 45:
            k = 2
        else:
            k = 3
        off_item1 = (int(open_hour1)*240) + (int(open_min1)*4)+ k 
        print "time to turn-on appliacne on",open_hour1,":",open_min1,":",open_sec1,"equal to",off_item1,"items"   
            
        duration_hour1 =  random.randint(0, 0)
        duration_min1 =  random.randint(endx1, endy1)
        duration_sec1 =  random.randint(0, 59)
        seconds1 = (duration_hour1*3600)+(duration_min1*60)+duration_sec1
        no_item1 = seconds1/15
        print "consuming the appliance", duration_hour1,"hours",duration_min1,"minutes",duration_sec1,"seconds that equal to",seconds1,"seconds or",no_item1,"items\n"
        return (off_item,no_item,off_item1,no_item1)        
    
        
days = 1
j = 0    
i = 0
turn = manytime()

while (j <= (5760*d)-1):   
    if (j == 5760+(5760*(days-1))):
        days +=1
        i = 0
        print "-------------------------ENd-----------------------------\n"
        turn = manytime()       
           

    if len(turn) == 1 :
        c.execute("INSERT INTO data_month5.water_heater (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
        conn.commit()
        j += 1

    elif len(turn)== 2 :
        off_item = turn[0] 
        no_item = turn[1]
        if (off_item+(5760*(days-1)) <= j <= (no_item+off_item)+(5760*(days-1))):
            c.execute("INSERT INTO data_month5.water_heater (Timestamp, watt) VALUES (%s, %s)",(time_b[j],df.watt[i]))
            conn.commit()
            i += 1 
            j += 1
        else:
            c.execute("INSERT INTO data_month5.water_heater (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
            conn.commit()
            j += 1
            i = 0
              
    else:
        off_item = turn[0] 
        no_item = turn[1]
        off_item1 = turn[2] 
        no_item1 = turn[3]
        if (off_item+(5760*(days-1)) <= j <= (no_item+off_item)+(5760*(days-1)) or off_item1+(5760*(days-1)) <= j <= (no_item1+off_item1)+(5760*(days-1))):
            c.execute("INSERT INTO data_month5.water_heater(Timestamp, watt) VALUES (%s, %s)",(time_b[j],df.watt[i]))
            conn.commit()
            j += 1
            i += 1 
        else:
            c.execute("INSERT INTO data_month5.water_heater(Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
            conn.commit()
            j += 1     
            i = 0
            

print "DONE!"
# print df
# Out:
# data_month5.water_heater are Empty!!!
#
# in recent day turn on water_heater 0 times
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 0 times
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 0 times
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 0 times
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 0 times
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 0 times
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 0 times
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 0 times
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 1 times
#
# time to turn-on appliacne on 20 : 35 : 59 equal to 4943 items
# consuming the appliance 0 hours 39 minutes 46 seconds that equal to 2386 seconds or 159 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 0 times
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 1 times
#
# time to turn-on appliacne on 20 : 6 : 23 equal to 4825 items
# consuming the appliance 0 hours 58 minutes 49 seconds that equal to 3529 seconds or 235 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 1 times
#
# time to turn-on appliacne on 21 : 11 : 10 equal to 5084 items
# consuming the appliance 0 hours 27 minutes 43 seconds that equal to 1663 seconds or 110 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 1 times
#
# time to turn-on appliacne on 21 : 53 : 31 equal to 5254 items
# consuming the appliance 0 hours 34 minutes 21 seconds that equal to 2061 seconds or 137 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 0 times
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 2 times
#
# time to turn-on appliacne on 8 : 53 : 20 equal to 2133 items
# consuming the appliance 0 hours 1 minutes 40 seconds that equal to 100 seconds or 6 items
#
# time to turn-on appliacne on 21 : 24 : 53 equal to 5139 items
# consuming the appliance 0 hours 11 minutes 47 seconds that equal to 707 seconds or 47 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 2 times
#
# time to turn-on appliacne on 9 : 35 : 26 equal to 2301 items
# consuming the appliance 0 hours 6 minutes 25 seconds that equal to 385 seconds or 25 items
#
# time to turn-on appliacne on 23 : 25 : 43 equal to 5622 items
# consuming the appliance 0 hours 7 minutes 3 seconds that equal to 423 seconds or 28 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 2 times
#
# time to turn-on appliacne on 8 : 40 : 52 equal to 2083 items
# consuming the appliance 0 hours 26 minutes 44 seconds that equal to 1604 seconds or 106 items
#
# time to turn-on appliacne on 23 : 50 : 26 equal to 5721 items
# consuming the appliance 0 hours 45 minutes 8 seconds that equal to 2708 seconds or 180 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 0 times
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 0 times
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 1 times
#
# time to turn-on appliacne on 21 : 11 : 56 equal to 5087 items
# consuming the appliance 0 hours 28 minutes 4 seconds that equal to 1684 seconds or 112 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 2 times
#
# time to turn-on appliacne on 10 : 58 : 50 equal to 2635 items
# consuming the appliance 0 hours 40 minutes 47 seconds that equal to 2447 seconds or 163 items
#
# time to turn-on appliacne on 21 : 10 : 11 equal to 5080 items
# consuming the appliance 0 hours 44 minutes 28 seconds that equal to 2668 seconds or 177 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 1 times
#
# time to turn-on appliacne on 20 : 42 : 28 equal to 4969 items
# consuming the appliance 0 hours 3 minutes 57 seconds that equal to 237 seconds or 15 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 0 times
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 1 times
#
# time to turn-on appliacne on 23 : 42 : 58 equal to 5691 items
# consuming the appliance 0 hours 35 minutes 50 seconds that equal to 2150 seconds or 143 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 1 times
#
# time to turn-on appliacne on 21 : 24 : 40 equal to 5138 items
# consuming the appliance 0 hours 12 minutes 52 seconds that equal to 772 seconds or 51 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 2 times
#
# time to turn-on appliacne on 7 : 59 : 1 equal to 1916 items
# consuming the appliance 0 hours 9 minutes 23 seconds that equal to 563 seconds or 37 items
#
# time to turn-on appliacne on 21 : 48 : 32 equal to 5234 items
# consuming the appliance 0 hours 6 minutes 50 seconds that equal to 410 seconds or 27 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 0 times
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 0 times
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 0 times
#
# DONE!

# %%
import matplotlib.pyplot as plt
# %matplotlib inline  


# query = "SELECT watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
query = "SELECT Timestamp,watt FROM data_month3.water_heater WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
df = pd.read_sql(query, conn, index_col=['Timestamp'])
fig, ax = plt.subplots()
ax.set_title('data_month3.water_heater')
df.plot(ax=ax )
plt.show()
df.to_csv('file.csv')
print len(df)
# Out:
# 178560
