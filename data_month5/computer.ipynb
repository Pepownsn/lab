# %% [markdown]
# ## data_month5
# #### COMPUTER | psu 600W + LED 23" |

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random


d = 29
time_a = pd.date_range('2017-02-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2017-02-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()


####### set databases to empty #########
query_empty = """truncate table data_month5.Computer""" 
c.execute(query_empty)
print " data_month5.Computer are Empty!!! \n"

query = "SELECT watt FROM collected_info.4_Computer WHERE no >= '%s'   AND no <= '%s'; "% (0,1240)
df = pd.read_sql(query, conn)
# print df.watt[5]

#### Random the turning-on time appliances
def rand_turnon():
    duration_sec =  random.randint(10, 59)
    duration_min =  random.randint(10, 59)
    duration_hour1 = ['18'] * 4+['19'] * 6 + ['20'] * 46 + ['21'] * 41 +['22'] * 3     #SET Start 7-10 pm.
    duration_hour = random.choice(duration_hour1)     
    if 0 < duration_sec <= 15:
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
    off_item = (int(duration_hour)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on appliacne on",duration_hour,":",duration_min,":",duration_sec,"equal to",off_item,"items"
    return off_item

 
#### Random the off-duration appliances 
def rand_duration():
    duration_sec =  random.randint(10, 59)
    duration_min =  random.randint(10, 59)
    duration_hour1 = ['1'] * 9 + ['2'] * 59 + ['3'] * 30 +['4'] * 1+['5'] * 1   
    duration_hour = random.choice(duration_hour1)   
    seconds = (int(duration_hour)*3600)+(duration_min*60)+duration_sec
    no_item = seconds/15
    print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items"
    return no_item

days = 0
j = 0
i = 0
print "\nDays :",days ,":",time_b[j].strftime('%a')
off_item = rand_turnon()  
no_item = rand_duration()  

while (j <= (5760*d)-1):  
    c.execute("INSERT INTO  data_month5.Computer (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
    conn.commit()
    j += 1 
    
    while (off_item+(5760*(days)) <= j <= (no_item+off_item)+(5760*(days))):                   
        c.execute("INSERT INTO data_month5.Computer (Timestamp, watt) VALUES (%s, %s)",(time_b[j],df.watt[i]))
        conn.commit()
        i += 1 
        j += 1
        if (j == (no_item+off_item)+(5760*(days))):
            days +=1
            print "\nDays :",days ,":",time_b[j].strftime('%a')
            off_item = rand_turnon()  
            no_item = rand_duration() 
            i= 0   
                    
print "DONE!"
# Out:
#  data_month5.Computer are Empty!!!
#
#
# Days : 0 : Wed
# time to turn-on appliacne on 19 : 30 : 35 equal to 4682 items
# consuming the appliance 2 hours 51 minutes 22 seconds that equal to 10282 seconds or 685 items
#
# Days : 1 : Wed
# time to turn-on appliacne on 21 : 52 : 20 equal to 5249 items
# consuming the appliance 2 hours 30 minutes 18 seconds that equal to 9018 seconds or 601 items
#
# Days : 2 : Fri
# time to turn-on appliacne on 20 : 21 : 58 equal to 4887 items
# consuming the appliance 1 hours 56 minutes 50 seconds that equal to 7010 seconds or 467 items
#
# Days : 3 : Fri
# time to turn-on appliacne on 21 : 14 : 32 equal to 5098 items
# consuming the appliance 2 hours 16 minutes 13 seconds that equal to 8173 seconds or 544 items
#
# Days : 4 : Sat
# time to turn-on appliacne on 21 : 56 : 19 equal to 5265 items
# consuming the appliance 3 hours 39 minutes 51 seconds that equal to 13191 seconds or 879 items
#
# Days : 5 : Mon
# time to turn-on appliacne on 19 : 16 : 40 equal to 4626 items
# consuming the appliance 3 hours 14 minutes 54 seconds that equal to 11694 seconds or 779 items
#
# Days : 6 : Mon
# time to turn-on appliacne on 20 : 40 : 29 equal to 4961 items
# consuming the appliance 2 hours 28 minutes 31 seconds that equal to 8911 seconds or 594 items
#
# Days : 7 : Tue
# time to turn-on appliacne on 18 : 14 : 31 equal to 4378 items
# consuming the appliance 3 hours 27 minutes 45 seconds that equal to 12465 seconds or 831 items
#
# Days : 8 : Wed
# time to turn-on appliacne on 20 : 18 : 41 equal to 4874 items
# consuming the appliance 2 hours 48 minutes 22 seconds that equal to 10102 seconds or 673 items
#
# Days : 9 : Thu
# time to turn-on appliacne on 21 : 49 : 43 equal to 5238 items
# consuming the appliance 3 hours 31 minutes 28 seconds that equal to 12688 seconds or 845 items
#
# Days : 10 : Sat
# time to turn-on appliacne on 21 : 15 : 16 equal to 5101 items
# consuming the appliance 2 hours 33 minutes 10 seconds that equal to 9190 seconds or 612 items
#
# Days : 11 : Sat
# time to turn-on appliacne on 20 : 24 : 34 equal to 4898 items
# consuming the appliance 3 hours 31 minutes 45 seconds that equal to 12705 seconds or 847 items
#
# Days : 12 : Sun
# time to turn-on appliacne on 21 : 36 : 33 equal to 5186 items
# consuming the appliance 2 hours 55 minutes 16 seconds that equal to 10516 seconds or 701 items
#
# Days : 13 : Tue
# time to turn-on appliacne on 21 : 38 : 58 equal to 5195 items
# consuming the appliance 2 hours 33 minutes 31 seconds that equal to 9211 seconds or 614 items
#
# Days : 14 : Wed
# time to turn-on appliacne on 20 : 32 : 32 equal to 4930 items
# consuming the appliance 3 hours 40 minutes 46 seconds that equal to 13246 seconds or 883 items
#
# Days : 15 : Thu
# time to turn-on appliacne on 21 : 15 : 23 equal to 5101 items
# consuming the appliance 2 hours 13 minutes 35 seconds that equal to 8015 seconds or 534 items
#
# Days : 16 : Thu
# time to turn-on appliacne on 20 : 25 : 56 equal to 4903 items
# consuming the appliance 2 hours 27 minutes 58 seconds that equal to 8878 seconds or 591 items
#
# Days : 17 : Fri
# time to turn-on appliacne on 20 : 11 : 54 equal to 4847 items
# consuming the appliance 3 hours 20 minutes 39 seconds that equal to 12039 seconds or 802 items
#
# Days : 18 : Sat
# time to turn-on appliacne on 20 : 46 : 32 equal to 4986 items
# consuming the appliance 1 hours 19 minutes 10 seconds that equal to 4750 seconds or 316 items
#
# Days : 19 : Sun
# time to turn-on appliacne on 21 : 30 : 59 equal to 5163 items
# consuming the appliance 3 hours 56 minutes 29 seconds that equal to 14189 seconds or 945 items
#
# Days : 20 : Tue
# time to turn-on appliacne on 21 : 31 : 11 equal to 5164 items
# consuming the appliance 3 hours 11 minutes 55 seconds that equal to 11515 seconds or 767 items
#
# Days : 21 : Wed
# time to turn-on appliacne on 21 : 32 : 57 equal to 5171 items
# consuming the appliance 3 hours 32 minutes 59 seconds that equal to 12779 seconds or 851 items
#
# Days : 22 : Thu
# time to turn-on appliacne on 21 : 28 : 43 equal to 5154 items
# consuming the appliance 2 hours 33 minutes 12 seconds that equal to 9192 seconds or 612 items
#
# Days : 23 : Fri
# time to turn-on appliacne on 21 : 18 : 35 equal to 5114 items
# consuming the appliance 2 hours 18 minutes 19 seconds that equal to 8299 seconds or 553 items
#
# Days : 24 : Fri
# time to turn-on appliacne on 21 : 33 : 10 equal to 5172 items
# consuming the appliance 2 hours 21 minutes 17 seconds that equal to 8477 seconds or 565 items
#
# Days : 25 : Sat
# time to turn-on appliacne on 20 : 53 : 58 equal to 5015 items
# consuming the appliance 2 hours 48 minutes 40 seconds that equal to 10120 seconds or 674 items
#
# Days : 26 : Sun
# time to turn-on appliacne on 21 : 37 : 14 equal to 5188 items
# consuming the appliance 2 hours 57 minutes 22 seconds that equal to 10642 seconds or 709 items
#
# Days : 27 : Tue
# time to turn-on appliacne on 20 : 12 : 58 equal to 4851 items
# consuming the appliance 2 hours 56 minutes 43 seconds that equal to 10603 seconds or 706 items
#
# Days : 28 : Tue
# time to turn-on appliacne on 20 : 41 : 34 equal to 4966 items
# consuming the appliance 3 hours 58 minutes 19 seconds that equal to 14299 seconds or 953 items
# IndexErrorTraceback (most recent call last)
# <ipython-input-1-abdcfa9f915e> in <module>()
#      69
#      70     while (off_item+(5760*(days)) <= j <= (no_item+off_item)+(5760*(days))):
# ---> 71         c.execute("INSERT INTO data_month5.Computer (Timestamp, watt) VALUES (%s, %s)",(time_b[j],df.watt[i]))
#      72         conn.commit()
#      73         i += 1
#
# /usr/local/lib/python2.7/dist-packages/pandas/tseries/base.pyc in __getitem__(self, key)
#     249         getitem = self._data.__getitem__
#     250         if is_int:
# --> 251             val = getitem(key)
#     252             return self._box_func(val)
#     253         else:
#
# IndexError: index 167040 is out of bounds for axis 0 with size 167040

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
# %matplotlib inline  


d = 31
time_a = pd.date_range('2016-12-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-12-01 00:00:14', periods=5760*d, freq='15S')
# print time_b
# query = "SELECT watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
query = "SELECT Timestamp,watt FROM data_month3.Computer WHERE Timestamp >= '%s' AND Timestamp <= '%s'; "% (time_a[0],time_b[5760*10])
df = pd.read_sql(query, conn, index_col=['Timestamp'])
fig,ax = plt.subplots()
ax.set_title('data_month3.Computer ')
df.plot(ax=ax )
plt.show()
