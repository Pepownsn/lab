# %% [markdown]
# ## data_month5
# #### TV | LCD ขนาด 49 นิ้ว |

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random


d = 29

time_a = pd.date_range('2017-02-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2017-02-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####### set databases to empty #########
query_empty = """truncate table data_month5.TV""" 
c.execute(query_empty)
print "data_month5.TV are Empty!!! \n"

query = "SELECT watt FROM collected_info.3_TV WHERE no >= '%s'   AND no <= '%s'; "% (0,1200)
df = pd.read_sql(query, conn)
# print df.watt[5]

#### Random the number of turnon-time per day
def manytime():
    many  = ['1'] * 50 + ['2'] * 44 + ['3'] * 6  ## The number of turn-on time of this appliance 
    manytime = random.choice(many)
    print "\nDays :",days ,":",time_b[j].strftime('%a')
    print "in recent day turn on TV",manytime,"times\n"
    if (int(manytime) == 1):
        x,y,endx,endy = 18,20,2,4  # fix turn on only in evening      
        open_hour =  random.randint(x, y)
        open_min =  random.randint(0, 59)
        open_sec =  random.randint(0, 59)
        if 0 < open_sec  <= 15:
            k = 0
        elif 15 < open_sec  <= 30:
            k = 1
        elif 30 < open_sec  <= 45:
            k = 2
        else:
            k = 3
        off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
        print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
        
        duration_hour =  random.randint(endx, endy)
        duration_min =  random.randint(0, 59)
        duration_sec =  random.randint(0, 59)
        seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
        no_item = seconds/15
        print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"
        return (off_item,no_item)

        
    elif (int(manytime) == 2):
        turn_duratrion  = ['1'] * 70 + ['2'] * 30       #### '1' turn-on morning and evening   OR  '2' turn-on 2 times in evening 
        howturn = random.choice(turn_duratrion)
#         print howturn
        if (int(howturn)== 1 ):
            x,y,endx,endy = 6,7,1,59
            open_hour =  random.randint(x, y)
            open_min =  random.randint(0, 59)
            open_sec =  random.randint(0, 59)
            if 0 < open_sec  <= 15:
                k = 0
            elif 15 < open_sec  <= 30:
                k = 1
            elif 30 < open_sec  <= 45:
                k = 2
            else:
                k = 3
            off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
            print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
            
            duration_hour =  random.randint(0, 0)
            duration_min =  random.randint(endx, endy)
            duration_sec =  random.randint(0, 59)
            seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
            no_item = seconds/15
            print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"

        
            
            x1,y1,endx1,endy1 = 18,20,2,4
            open_hour1 =  random.randint(x1, y1)
            open_min1 =  random.randint(0, 59)
            open_sec1 =  random.randint(0, 59)
            if 0 < open_sec1  <= 15:
                k = 0
            elif 15 < open_sec1  <= 30:
                k = 1
            elif 30 < open_sec1  <= 45:
                k = 2
            else:
                k = 3
            off_item1 = (int(open_hour1)*240) + (int(open_min1)*4)+ k 
            print "time to turn-on appliacne on",open_hour1,":",open_min1,":",open_sec1,"equal to",off_item1,"items"     
            
            duration_hour1 =  random.randint(endx1, endy1)
            duration_min1 =  random.randint(0, 59)
            duration_sec1 =  random.randint(0, 59)
            seconds1 = (duration_hour1*3600)+(duration_min1*60)+duration_sec1
            no_item1 = seconds1/15
            print "consuming the appliance", duration_hour1,"hours",duration_min1,"minutes",duration_sec1,"seconds that equal to",seconds1,"seconds or",no_item1,"items\n"

        else :
            x,y,endx,endy = 18,19,1,59
            open_hour =  random.randint(x, y)
            open_min =  random.randint(0, 59)
            open_sec =  random.randint(0, 59)
            if 0 < open_sec  <= 15:
                k = 0
            elif 15 < open_sec  <= 30:
                k = 1
            elif 30 < open_sec  <= 45:
                k = 2
            else:
                k = 3
            off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
            print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
            
            duration_hour =  random.randint(0, 0)
            duration_min =  random.randint(endx, endy)
            duration_sec =  random.randint(0, 59)
            seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
            no_item = seconds/15
            print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"

        
            x1,y1,endx1,endy1 = 20,22,1,4
            open_hour1 =  random.randint(x1, y1)
            open_min1 =  random.randint(0, 59)
            open_sec1 =  random.randint(0, 59)
            if 0 < open_sec1  <= 15:
                k = 0
            elif 15 < open_sec1  <= 30:
                k = 1
            elif 30 < open_sec1  <= 45:
                k = 2
            else:
                k = 3
            off_item1 = (int(open_hour1)*240) + (int(open_min1)*4)+ k 
            print "time to turn-on appliacne on",open_hour1,":",open_min1,":",open_sec1,"equal to",off_item1,"items"   
            
            duration_hour1 =  random.randint(endx1, endy1)
            duration_min1 =  random.randint(0, 59)
            duration_sec1 =  random.randint(0, 59)
            seconds1 = (duration_hour1*3600)+(duration_min1*60)+duration_sec1
            no_item1 = seconds1/15
            print "consuming the appliance", duration_hour1,"hours",duration_min1,"minutes",duration_sec1,"seconds that equal to",seconds1,"seconds or",no_item1,"items\n"

        return (off_item,no_item,off_item1,no_item1)        
    else:
        x,y,endx,endy = 6,7,30,60
        open_hour =  random.randint(x, y)
        open_min =  random.randint(0, 59)
        open_sec =  random.randint(0, 59)
        if 0 < open_sec  <= 15:
            k = 0
        elif 15 < open_sec  <= 30:
            k = 1
        elif 30 < open_sec  <= 45:
            k = 2
        else:
            k = 3
        off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
        print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
        
        duration_hour =  random.randint(0,0)
        duration_min =  random.randint(endx, endy)
        duration_sec =  random.randint(0, 59)
        seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
        no_item = seconds/15
        print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"

    
    
        x1,y1,endx1,endy1 = 18,19,1,59
        open_hour1 =  random.randint(x1, y1)
        open_min1 =  random.randint(0, 59)
        open_sec1 =  random.randint(0, 59)
        if 0 < open_sec1  <= 15:
            k = 0
        elif 15 < open_sec1  <= 30:
            k = 1
        elif 30 < open_sec1  <= 45:
            k = 2
        else:
            k = 3
        off_item1 = (int(open_hour1)*240) + (int(open_min1)*4)+ k 
        print "time to turn-on appliacne on",open_hour1,":",open_min1,":",open_sec1,"equal to",off_item1,"items" 
        duration_hour1 =  random.randint(0, 0)
        duration_min1 =  random.randint(endx1, endy1)
        duration_sec1 =  random.randint(0, 59)
        seconds1 = (duration_hour1*3600)+(duration_min1*60)+duration_sec1
        no_item1 = seconds1/15
        print "consuming the appliance", duration_hour1,"hours",duration_min1,"minutes",duration_sec1,"seconds that equal to",seconds1,"seconds or",no_item1,"items\n"
    
    
        x2,y2,endx2,endy2 = 20,22,1,4
        open_hour2 =  random.randint(x2, y2)
        open_min2 =  random.randint(0, 59)
        open_sec2 =  random.randint(0, 59)
        if 0 < open_sec2  <= 15:
            k = 0
        elif 15 < open_sec2  <= 30:
            k = 1
        elif 30 < open_sec2  <= 45:
            k = 2
        else:
            k = 3
        off_item2 = (int(open_hour2)*240) + (int(open_min2)*4)+ k 
        print "time to turn-on appliacne on",open_hour2,":",open_min2,":",open_sec2,"equal to",off_item2,"items" 
        duration_hour2 =  random.randint(endx2, endy2)
        duration_min2 =  random.randint(0, 59)
        duration_sec2 =  random.randint(0, 59)
        seconds2 = (duration_hour2*3600)+(duration_min2*60)+duration_sec2
        no_item2 = seconds2/15
        print "consuming the appliance", duration_hour2,"hours",duration_min2,"minutes",duration_sec2,"seconds that equal to",seconds2,"seconds or",no_item2,"items\n"
        return (off_item,no_item,off_item1,no_item1,off_item2,no_item2)    
    
    
        
days = 1
j = 0

## (off_item,no_item,off_item1,no_item1,off_item2,no_item2)    

turn = manytime()
while (j <= (5760*d)-1):   
    if (j == 5760+(5760*(days-1))):
        days +=1
        print "-------------------------ENd-----------------------------\n"
        turn = manytime()          
        
    if len(turn)==2:
        off_item = turn[0] 
        no_item = turn[1]
        if (off_item+(5760*(days-1)) <= j <= (no_item+off_item)+(5760*(days-1))):
            c.execute("INSERT INTO data_month5.TV (Timestamp, watt) VALUES (%s, %s)",(time_b[j],random.randint(64, 68)))
            conn.commit()
            j += 1
        else:
            c.execute("INSERT INTO data_month5.TV (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
            conn.commit()
            j += 1
        
    elif len(turn)==4:
        off_item = turn[0] 
        no_item = turn[1]
        off_item1 = turn[2] 
        no_item1 = turn[3]
        if (off_item+(5760*(days-1)) <= j <= (no_item+off_item)+(5760*(days-1)) or off_item1+(5760*(days-1)) <= j <= (no_item1+off_item1)+(5760*(days-1))):
            c.execute("INSERT INTO data_month5.TV (Timestamp, watt) VALUES (%s, %s)",(time_b[j],random.randint(64, 68)))
            conn.commit()
            j += 1
        else:
            c.execute("INSERT INTO data_month5.TV (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
            conn.commit()
            j += 1
             
    else:
        off_item = turn[0] 
        no_item = turn[1]
        off_item1 = turn[2] 
        no_item1 = turn[3]
        off_item2 = turn[4] 
        no_item2 = turn[5]
        
        if (off_item+(5760*(days-1)) <= j <= (no_item+off_item)+(5760*(days-1)) or off_item1+(5760*(days-1)) <= j <= (no_item1+off_item1)+(5760*(days-1)) or off_item2+(5760*(days-1)) <= j <= (no_item2+off_item2)+(5760*(days-1)))  :
            c.execute("INSERT INTO data_month5.TV (Timestamp, watt) VALUES (%s, %s)",(time_b[j],random.randint(64, 68)))
            conn.commit()
            j += 1
        else:
            c.execute("INSERT INTO data_month5.TV (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
            conn.commit()
            j += 1
 
           
print "DONE!"
# Out:
# data_month5.TV are Empty!!!
#
#
# Days : 1 : Wed
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 18 : 55 : 18 equal to 4541 items
# consuming the appliance 0 hours 38 minutes 29 seconds that equal to 2309 seconds or 153 items
#
# time to turn-on appliacne on 20 : 52 : 43 equal to 5010 items
# consuming the appliance 3 hours 42 minutes 5 seconds that equal to 13325 seconds or 888 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 2 : Thu
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 19 : 8 : 3 equal to 4592 items
# consuming the appliance 4 hours 51 minutes 58 seconds that equal to 17518 seconds or 1167 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 3 : Fri
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 19 : 25 : 45 equal to 4662 items
# consuming the appliance 3 hours 26 minutes 39 seconds that equal to 12399 seconds or 826 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 4 : Sat
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 19 : 39 : 38 equal to 4718 items
# consuming the appliance 2 hours 13 minutes 30 seconds that equal to 8010 seconds or 534 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 5 : Sun
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 7 : 7 : 13 equal to 1708 items
# consuming the appliance 0 hours 42 minutes 31 seconds that equal to 2551 seconds or 170 items
#
# time to turn-on appliacne on 20 : 17 : 20 equal to 4869 items
# consuming the appliance 3 hours 28 minutes 28 seconds that equal to 12508 seconds or 833 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 6 : Mon
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 18 : 27 : 17 equal to 4429 items
# consuming the appliance 2 hours 28 minutes 24 seconds that equal to 8904 seconds or 593 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 7 : Tue
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 18 : 13 : 55 equal to 4375 items
# consuming the appliance 3 hours 10 minutes 38 seconds that equal to 11438 seconds or 762 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 8 : Wed
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 18 : 22 : 11 equal to 4408 items
# consuming the appliance 4 hours 41 minutes 40 seconds that equal to 16900 seconds or 1126 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 9 : Thu
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 6 : 24 : 31 equal to 1538 items
# consuming the appliance 0 hours 24 minutes 33 seconds that equal to 1473 seconds or 98 items
#
# time to turn-on appliacne on 20 : 0 : 48 equal to 4803 items
# consuming the appliance 2 hours 30 minutes 14 seconds that equal to 9014 seconds or 600 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 10 : Fri
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 7 : 5 : 58 equal to 1703 items
# consuming the appliance 0 hours 4 minutes 46 seconds that equal to 286 seconds or 19 items
#
# time to turn-on appliacne on 18 : 23 : 45 equal to 4414 items
# consuming the appliance 4 hours 21 minutes 32 seconds that equal to 15692 seconds or 1046 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 11 : Sat
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 20 : 2 : 44 equal to 4810 items
# consuming the appliance 3 hours 19 minutes 44 seconds that equal to 11984 seconds or 798 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 12 : Sun
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 18 : 26 : 52 equal to 4427 items
# consuming the appliance 2 hours 26 minutes 8 seconds that equal to 8768 seconds or 584 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 13 : Mon
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 19 : 25 : 42 equal to 4662 items
# consuming the appliance 0 hours 11 minutes 27 seconds that equal to 687 seconds or 45 items
#
# time to turn-on appliacne on 21 : 29 : 35 equal to 5158 items
# consuming the appliance 1 hours 57 minutes 34 seconds that equal to 7054 seconds or 470 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 14 : Tue
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 20 : 21 : 46 equal to 4887 items
# consuming the appliance 2 hours 19 minutes 26 seconds that equal to 8366 seconds or 557 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 15 : Wed
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 6 : 40 : 23 equal to 1601 items
# consuming the appliance 0 hours 30 minutes 52 seconds that equal to 1852 seconds or 123 items
#
# time to turn-on appliacne on 19 : 12 : 57 equal to 4611 items
# consuming the appliance 4 hours 0 minutes 30 seconds that equal to 14430 seconds or 962 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 16 : Thu
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 18 : 53 : 19 equal to 4533 items
# consuming the appliance 4 hours 51 minutes 53 seconds that equal to 17513 seconds or 1167 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 17 : Fri
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 19 : 51 : 13 equal to 4764 items
# consuming the appliance 3 hours 0 minutes 15 seconds that equal to 10815 seconds or 721 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 18 : Sat
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 18 : 52 : 54 equal to 4531 items
# consuming the appliance 3 hours 10 minutes 37 seconds that equal to 11437 seconds or 762 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 19 : Sun
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 6 : 29 : 51 equal to 1559 items
# consuming the appliance 0 hours 42 minutes 23 seconds that equal to 2543 seconds or 169 items
#
# time to turn-on appliacne on 19 : 12 : 47 equal to 4611 items
# consuming the appliance 4 hours 26 minutes 46 seconds that equal to 16006 seconds or 1067 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 20 : Mon
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 18 : 36 : 18 equal to 4465 items
# consuming the appliance 0 hours 42 minutes 48 seconds that equal to 2568 seconds or 171 items
#
# time to turn-on appliacne on 20 : 22 : 19 equal to 4889 items
# consuming the appliance 3 hours 36 minutes 28 seconds that equal to 12988 seconds or 865 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 21 : Tue
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 19 : 12 : 20 equal to 4609 items
# consuming the appliance 2 hours 14 minutes 54 seconds that equal to 8094 seconds or 539 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 22 : Wed
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 19 : 41 : 54 equal to 4727 items
# consuming the appliance 3 hours 59 minutes 26 seconds that equal to 14366 seconds or 957 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 23 : Thu
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 20 : 40 : 58 equal to 4963 items
# consuming the appliance 2 hours 21 minutes 1 seconds that equal to 8461 seconds or 564 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 24 : Fri
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 19 : 25 : 35 equal to 4662 items
# consuming the appliance 2 hours 24 minutes 45 seconds that equal to 8685 seconds or 579 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 25 : Sat
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 6 : 8 : 29 equal to 1473 items
# consuming the appliance 0 hours 24 minutes 27 seconds that equal to 1467 seconds or 97 items
#
# time to turn-on appliacne on 20 : 39 : 25 equal to 4957 items
# consuming the appliance 3 hours 59 minutes 0 seconds that equal to 14340 seconds or 956 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 26 : Sun
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 18 : 33 : 22 equal to 4453 items
# consuming the appliance 0 hours 20 minutes 53 seconds that equal to 1253 seconds or 83 items
#
# time to turn-on appliacne on 21 : 57 : 53 equal to 5271 items
# consuming the appliance 1 hours 30 minutes 35 seconds that equal to 5435 seconds or 362 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 27 : Mon
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 20 : 15 : 47 equal to 4863 items
# consuming the appliance 4 hours 40 minutes 40 seconds that equal to 16840 seconds or 1122 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 28 : Tue
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 20 : 35 : 56 equal to 4943 items
# consuming the appliance 3 hours 30 minutes 19 seconds that equal to 12619 seconds or 841 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 29 : Wed
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 18 : 19 : 20 equal to 4397 items
# consuming the appliance 3 hours 27 minutes 15 seconds that equal to 12435 seconds or 829 items
#
# DONE!

# %%
import matplotlib.pyplot as plt
# %matplotlib inline  


# query = "SELECT watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
query = "SELECT Timestamp,watt FROM data_month3.TV WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[3000],time_b[5760*4])
df = pd.read_sql(query, conn, index_col=['Timestamp'])

fig, ax = plt.subplots()
ax.set_title('data_month3.TV')
ax.set_ylim(64,68)
df.plot(ax=ax )
plt.show()
# df.to_csv('file.csv')
# len(time_b)
