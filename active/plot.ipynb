# %%
import pandas as pd
import MySQLdb
import time
import sys
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error,mean_squared_error
import statistics 
# %matplotlib inline

# %%
d = 30
time_a = pd.date_range('2016-10-01 00:00:00', periods=96*d, freq='15T')
time_b = pd.date_range('2016-10-01 00:14:59', periods=96*d, freq='15T')

conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

query1 = "SELECT Timestamp,watt  FROM active.target_all WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a[(96*7)-50],time_b[(96*10)-1])
df1 = pd.read_sql(query1, conn)

query2 = "SELECT Timestamp,new_watt  FROM active.discount10active5 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " %(time_a[(96*7)-50],time_b[(96*10)-1])
df2 = pd.read_sql(query2, conn)
df1['discount10active5']=df2.new_watt

query3 = "SELECT Timestamp,new_watt  FROM active.discount10active10 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a[(96*7)-50],time_b[(96*10)-1])
df3 = pd.read_sql(query3, conn)
df1['discount10active10']=df3.new_watt

query4 = "SELECT Timestamp,new_watt  FROM active.discount10active15 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a[(96*7)-50],time_b[(96*10)-1])
df4 = pd.read_sql(query4, conn)
df1['discount10active15']=df4.new_watt

query5 = "SELECT Timestamp,watt  FROM active.target_all WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a[(96*7)-50],time_b[(96*10)-1])
df5 = pd.read_sql(query5, conn)

query6 = "SELECT Timestamp,new_watt  FROM active.discount15active5 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " %(time_a[(96*7)-50],time_b[(96*10)-1])
df6 = pd.read_sql(query6, conn)
df5['discount15active5']=df6.new_watt

query7 = "SELECT Timestamp,new_watt  FROM active.discount15active10 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a[(96*7)-50],time_b[(96*10)-1])
df7 = pd.read_sql(query7, conn)
df5['discount15active10']=df7.new_watt

query8 = "SELECT Timestamp,new_watt  FROM active.discount15active15 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a[(96*7)-50],time_b[(96*10)-1])
df8 = pd.read_sql(query8, conn)
df5['discount15active15']=df8.new_watt

query9 = "SELECT Timestamp,watt  FROM active.target_all WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a[(96*7)-50],time_b[(96*10)-1])
df9 = pd.read_sql(query9, conn)

query10 = "SELECT Timestamp,new_watt  FROM active.discount20active5 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " %(time_a[(96*7)-50],time_b[(96*10)-1])
df10 = pd.read_sql(query10, conn)
df9['discount20active5']=df10.new_watt

query11 = "SELECT Timestamp,new_watt  FROM active.discount20active10 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a[(96*7)-50],time_b[(96*10)-1])
df11 = pd.read_sql(query11, conn)
df9['discount20active10']=df11.new_watt

query12 = "SELECT Timestamp,new_watt  FROM active.discount20active15 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a[(96*7)-50],time_b[(96*10)-1])
df12 = pd.read_sql(query12, conn)
df9['discount20active15']=df12.new_watt

fig,(ax1,ax2,ax3) = plt.subplots(nrows=3,figsize=(9*1.5, 4*7))
df1.plot(ax=ax1)
df5.plot(ax=ax2)
df9.plot(ax=ax3)
ax1.set_title('Discount 10%')
ax2.set_title('Discount 15%')
ax3.set_title('Discount 20%')
plt.show()

# %%
query1 = "SELECT Timestamp,watt  FROM active.target_all WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a[(96*7)-50],time_b[(96*10)-1])
df1 = pd.read_sql(query1, conn)

query2 = "SELECT Timestamp,new_watt  FROM active.discount10active5 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " %(time_a[(96*7)-50],time_b[(96*10)-1])
df2 = pd.read_sql(query2, conn)

query3 = "SELECT Timestamp,new_watt  FROM active.discount10active10 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a[(96*7)-50],time_b[(96*10)-1])
df3 = pd.read_sql(query3, conn)


query4 = "SELECT Timestamp,new_watt  FROM active.discount10active15 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a[(96*7)-50],time_b[(96*10)-1])
df4 = pd.read_sql(query4, conn)


query5 = "SELECT Timestamp,watt  FROM active.target_all WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a[(96*7)-50],time_b[(96*10)-1])
df5 = pd.read_sql(query5, conn)

query6 = "SELECT Timestamp,new_watt  FROM active.discount15active5 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " %(time_a[(96*7)-50],time_b[(96*10)-1])
df6 = pd.read_sql(query6, conn)


query7 = "SELECT Timestamp,new_watt  FROM active.discount15active10 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a[(96*7)-50],time_b[(96*10)-1])
df7 = pd.read_sql(query7, conn)


query8 = "SELECT Timestamp,new_watt  FROM active.discount15active15 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a[(96*7)-50],time_b[(96*10)-1])
df8 = pd.read_sql(query8, conn)


query9 = "SELECT Timestamp,watt  FROM active.target_all WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a[(96*7)-50],time_b[(96*10)-1])
df9 = pd.read_sql(query9, conn)

query10 = "SELECT Timestamp,new_watt  FROM active.discount20active5 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " %(time_a[(96*7)-50],time_b[(96*10)-1])
df10 = pd.read_sql(query10, conn)


query11 = "SELECT Timestamp,new_watt  FROM active.discount20active10 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a[(96*7)-50],time_b[(96*10)-1])
df11 = pd.read_sql(query11, conn)


query12 = "SELECT Timestamp,new_watt  FROM active.discount20active15 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a[(96*7)-50],time_b[(96*10)-1])
df12 = pd.read_sql(query12, conn)


i = 0
u1 = 0
u2 = 0
u3 = 0
u4 = 0
u5 = 0
u6 = 0
u7 = 0
u8= 0
u9 =0
u10 = 0
u11 = 0
u12 = 0
sumsum1 = []
sumsum2 = []
sumsum3 = []
sumsum4 = []
sumsum5 = []
sumsum6 = []
sumsum7 = []
sumsum8 = []
sumsum9 = []
sumsum10 = []
sumsum11 = []
sumsum12 = []

while i <= len(df1)-1:
    u1 += df1.watt[i]
    u2 += df2.new_watt[i]
    u3 += df3.new_watt[i]
    u4 += df4.new_watt[i]
    u5 += df5.watt[i]
    u6 += df6.new_watt[i]
    u7 += df7.new_watt[i]
    u8 += df8.new_watt[i]
    u9 += df9.watt[i]
    u10 += df10.new_watt[i]
    u11 += df11.new_watt[i]
    u12 += df12.new_watt[i]
    sumsum1.append(u1/1000)
    sumsum2.append(u2/1000)
    sumsum3.append(u3/1000)
    sumsum4.append(u4/1000)
    sumsum5.append(u5/1000)
    sumsum6.append(u6/1000)
    sumsum7.append(u7/1000)
    sumsum8.append(u8/1000)
    sumsum9.append(u9/1000)
    sumsum10.append(u10/1000)
    sumsum11.append(u11/1000)
    sumsum12.append(u12/1000)                                       
    i+=1
print "DONE"
# Out:
# DONE

# %%
df_plot1 = df1.copy()
del df_plot1["watt"]
df_plot1['watt_sum']=sumsum1
df_plot1['watt_sum_discount10active5']=sumsum2
df_plot1['watt_sum_discount10active10']=sumsum3
df_plot1['watt_sum_discount10active15']=sumsum4


df_plot2 = df5.copy()
del df_plot2["watt"]
df_plot2['watt_sum']=sumsum5
df_plot2['watt_sum_discount15active5']=sumsum6
df_plot2['watt_sum_discount15active10']=sumsum7
df_plot2['watt_sum_discount15active15']=sumsum8

df_plot3 = df9.copy()
del df_plot3["watt"]
df_plot3['watt_sum']=sumsum9
df_plot3['watt_sum_discount20active5']=sumsum10
df_plot3['watt_sum_discount20active10']=sumsum11
df_plot3['watt_sum_discount20active15']=sumsum12

fig,(ax1,ax2,ax3) = plt.subplots(nrows=3,figsize=(9*1.5, 4*4))
df_plot1.plot(ax=ax1)
df_plot2.plot(ax=ax2)
df_plot3.plot(ax=ax3)
ax1.set_title('Discount 10%')
ax2.set_title('Discount 15%')
ax3.set_title('Discount 20%')
plt.show()
