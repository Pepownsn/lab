# %% [markdown]
# ## code discount10active5

# %%
import pandas as pd
import MySQLdb
import time
import sys
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt

# %%
## ______________________________ SET PARAMETER ______________________________________
k = 0
z = 0
m1 = 0
m2 = 0
m3 = 0
m4 = 0
m5 = 0
m6 = 0
m7 = 0
m8 = 0
m9 = 0  

j = 0
d = 30
time_a = pd.date_range('2016-10-01 00:00:00', periods=96*d, freq='15T')
time_b = pd.date_range('2016-10-01 00:14:59', periods=96*d, freq='15T')

conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()


query_empty = """truncate table active.discount10active5""" 
c.execute(query_empty)
print "active.discount10active5 are Empty!!! \n"


###  _________________ SELECT ONLY ACTIVE10%
query = "SELECT no,active5  FROM check_event.active WHERE no >= '%s'   AND no <= '%s'; " % (0,2700)
df = pd.read_sql(query, conn)


query1 = "SELECT *  FROM active.consum_load WHERE  Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a[0],time_b[(96*d)-1])
df1 = pd.read_sql(query1, conn)


query2 = "SELECT *  FROM active.target_all WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a[0],time_b[(96*d)-1])
df2 = pd.read_sql(query2, conn)

# df1['Computer'] = df1['Computer'].astype(float)
# df1['TV'] = df1['TV'].astype(float)
# df1['Computer'] = df1['Computer'].astype(float)

def end(j):
    check =1
    m1 = j+1
    m2 = j+1
    m3 = j+1
    m4 = j+1
    m5 = j+1
    m6 = j+1
    m7 = j+1
    m8 = j+1
    m9 = j+1
    while (check == 1):
        while df1.Computer[m1] > 0:
            m1 += 1
        while df1.TV[m2] > 0:
            m2 += 1
        while  df1.Fan[m3] > 0:
            m3 += 1
        while df1.kitchen_light[m4] > 0:
            m4 += 1
        while df1.bedroom_light[m5] > 0:
            m5 += 1
        while df1.hair_dryer[m6] > 0:
            m6 += 1
        while df1.elec_thermos[m7] > 0:
            m7 += 1
        while df1.water_heater[m8] > 0:
            m8 += 1
        while df1.air[m9] > 0:
            m9 += 1
        check = 0
        print "\ncheck_end position processing done!"
        print m1,m2,m3,m4,m5,m6,m7,m8,m9
        return (m1,m2,m3,m4,m5,m6,m7,m8,m9)
    
    
def state(j,m1,m2,m3,m4,m5,m6,m7,m8,m9):
    if j <= m1:
        ans1 = df1.Computer[j]
    else:
        ans1 = 0
    if j <= m2:
        ans2 = df1.TV[j]
    else:
        ans2 = 0
    if j <= m3:
        ans3 = df1.Fan[j]
    else:
        ans3 = 0
    if j <= m4:
        ans4 = df1.kitchen_light[j]
    else:
        ans4 = 0
    if j <= m5:
        ans5 = df1.bedroom_light[j]
    else:
        ans5 = 0
    if j <= m6:
        ans6 = df1.hair_dryer[j]
    else:
        ans6 = 0
    if j <= m7:
        ans7 = df1.elec_thermos[j]
    else:
        ans7 = 0
    if j <= m8:
        ans8 = df1.water_heater[j]
    else:
        ans8 = 0
    if j <= m9:
        ans9 = df1.air[j]
    else:
        ans9 = 0
    k = ans1+ans2+ans3+ans4+ans5+ans6+ans7+ans8+ans9
    print "take k =",k,"out"
    return k 
              

while ( j <= (96*d)-1):
    newwatt = df2.watt[j] - k
    sub = df2.p10[j] - newwatt
    if j == 0:
        sum_sub = sub
       
    else :
        sum_sub = sum_sub + sub
     
    c.execute("INSERT INTO active.discount10active5 (Timestamp,target,new_watt,sub,sum_sub) VALUES( %s,%s,%s,%s,%s)",(time_b[j],df2.p10[j],newwatt,sub,sum_sub))
    conn.commit()
    print  "\nat items |||||||||||||||",j,          " target =",df2.p10[j],"watt now at",newwatt," |||||  ",sub,"______",sum_sub,"\n"
    if sum_sub < 0:
        print "\n______________________________ HEAD AND TAIL PROCESS______________________________  "
        HT = df.active5[z]
        z +=1
        if   HT == 1:
            print "  |||||||| HEAD OCCUR = USER ACTIVE for GUIDANCE |||||||| "
            m = end(j)
            m1= m[0]
            m1 -= 1
            m2= m[1]
            m2 -= 1
            m3= m[2]
            m3 -= 1
            m4= m[3]
            m4 -= 1
            m5= m[4]
            m5 -= 1
            m6= m[5]
            m6 -= 1
            m7= m[6]
            m7 -= 1 
            m8= m[7]
            m8 -= 1
            m9= m[8]
            m9 -= 1
            j += 1
            k = state(j,m1,m2,m3,m4,m5,m6,m7,m8,m9)
        else:
            print " |||||||| TAIL OCCUR = USER NONACTIVE for GUIDANCE |||||||| "
            j +=1
            k = state(j,m1,m2,m3,m4,m5,m6,m7,m8,m9)
                       
    else:
        print "______________________________ sum_substract is still POSITIVE______________________________ "
        j += 1
        k = state(j,m1,m2,m3,m4,m5,m6,m7,m8,m9)
    
          
    
print "...............................................End.................................................."
# Out:
# active.discount10active5 are Empty!!!
#
#
# at items ||||||||||||||| 0  target = 268.785 watt now at 34.2875  |||||   234.4975 ______ 234.4975
#
# ______________________________ sum_substract is still POSITIVE______________________________
# take k = 0 out
#
# at items ||||||||||||||| 1  target = 267.614 watt now at 32.9875  |||||   234.6265 ______ 469.124
#
# ______________________________ sum_substract is still POSITIVE______________________________
# take k = 0 out
#
# at items ||||||||||||||| 2  target = 270.647 watt now at 29.725  |||||   240.922 ______ 710.046
#
# ______________________________ sum_substract is still POSITIVE______________________________
# take k = 0 out
#
# at items ||||||||||||||| 3  target = 270.086 watt now at 33.3958  |||||   236.6902 ______ 946.7362
#
# ______________________________ sum_substract is still POSITIVE______________________________
# take k = 0 out
#
# at items ||||||||||||||| 4  target = 227.123 watt now at 29.625  |||||   197.498 ______ 1144.2342
#
# ______________________________ sum_substract is still POSITIVE______________________________
# take k = 0 out
#
# at items ||||||||||||||| 5  target = 216.577 watt now at 29.1042  |||||   187.4728 ______ 1331.707
#
# ______________________________ sum_substract is still POSITIVE______________________________
# take k = 0 out
#
# at items ||||||||||||||| 6  target = 271.086 watt now at 33.0417  |||||   238.0443 ______ 1569.7513
#
# ______________________________ sum_substract is still POSITIVE______________________________
# take k = 0 out
#
# at items ||||||||||||||| 7  target = 157.5 watt now at 28.3208  |||||   129.1792 ______ 1698.9305
#
# ______________________________ sum_substract is still POSITIVE______________________________
# take k = 0 out
#
# at items ||||||||||||||| 8  target = 268.018 watt now at 26.8208  |||||   241.1972 ______ 1940.1277
#
# ______________________________ sum_substract is still POSITIVE______________________________
# take k = 0 out
#
# at items ||||||||||||||| 9  target = 216.348 watt now at 27.5917  |||||   188.7563 ______ 2128.884
#
# ______________________________ sum_substract is still POSITIVE______________________________
# take k = 0 out
#
# at items ||||||||||||||| 10  target = 216.706 watt now at 33.6375  |||||   183.0685 ______ 2311.9525
#
# ______________________________ sum_substract is still POSITIVE______________________________
# take k = 0 out
#
# at items ||||||||||||||| 11  target = 159.831 watt now at 34.1875  |||||   125.6435 ______ 2437.596
#
# ______________________________ sum_substract is still POSITIVE______________________________
# take k = 0 out
#
# at items ||||||||||||||| 12  target = 268.331 watt now at 32.2625  |||||   236.0685 ______ 2673.6645
#
# ______________________________ sum_substract is still POSITIVE______________________________
# take k = 0 out
#
# at items ||||||||||||||| 13  target = 146.244 watt now at 30.2833  |||||   115.9607 ______ 2789.6252
#
# ______________________________ sum_substract is still POSITIVE______________________________
# take k = 0 out
#
# at items ||||||||||||||| 14  target = 167.462 watt now at 33.2792  |||||   134.1828 ______ 2923.808
#
# ______________________________ sum_substract is still POSITIVE______________________________
# take k = 0 out
#
# at items ||||||||||||||| 15  target = 239.131 watt now at 28.7875  |||||   210.3435 ______ 3134.1515
#
# ______________________________ sum_substract is still POSITIVE______________________________
# take k = 0 out
#
# at items ||||||||||||||| 16  target = 152.391 watt now at 30.0542  |||||   122.3368 ______ 3256.4883
#
# ______________________________ sum_substract is still POSITIVE______________________________
# take k = 0 out
#
# at items ||||||||||||||| 17  target = 135.228 watt now at 32.425  |||||   102.803 ______ 3359.2913
#
# ______________________________ sum_substract is still POSITIVE______________________________
# take k = 0 out
#
# at items ||||||||||||||| 18  target = 177.49 watt now at 27.75  |||||   149.74 ______ 3509.0313
#
# ______________________________ sum_substract is still POSITIVE______________________________
# take k = 0 out
#
# at items ||||||||||||||| 19  target = 164.345 watt now at 26.8375  |||||   137.5075 ______ 3646.5388
#
# ______________________________ sum_substract is still POSITIVE______________________________
# take k = 0 out
#
# at items ||||||||||||||| 20  target = 163.471 watt now at 28.975  |||||   134.496 ______ 3781.0348
#
# ______________________________ sum_substract is still POSITIVE______________________________
# take k = 0 out
#
# at items ||||||||||||||| 21  target = 99.4762 watt now at 33.7  |||||   65.7762 ______ 3846.811
#
# ______________________________ sum_substract is still POSITIVE______________________________
# take k = 0 out
#
# at items ||||||||||||||| 22  target = 24.3244 watt now at 34.0958  |||||   -9.7714 ______ 3837.0396
#
# ______________________________ sum_substract is still POSITIVE______________________________
# take k = 0 out
#
# at items ||||||||||||||| 23  target = 28.5139 watt now at 31.2917  |||||   -2.7778 ______ 3834.2618
#
# ______________________________ sum_substract is still POSITIVE______________________________
# take k = 0 out
#
# at items |||||||||||||||
#
#
# ______________________________ HEAD AND TAIL PROCESS______________________________
#  |||||||| TAIL OCCUR = USER NONACTIVE for GUIDANCE ||||||||
# take k = 0 out
#
# at items ||||||||||||||| 2864  target = 41.319 watt now at 117.213  |||||   -75.894 ______ -17237.72958
#
#
# ______________________________ HEAD AND TAIL PROCESS______________________________
#  |||||||| TAIL OCCUR = USER NONACTIVE for GUIDANCE ||||||||
# take k = 0 out
#
# at items ||||||||||||||| 2865  target = 39.5562 watt now at 117.363  |||||   -77.8068 ______ -17315.53638
#
#
# ______________________________ HEAD AND TAIL PROCESS______________________________
#  |||||||| TAIL OCCUR = USER NONACTIVE for GUIDANCE ||||||||
# take k = 0 out
#
# at items ||||||||||||||| 2866  target = 41.4945 watt now at 294.288  |||||   -252.7935 ______ -17568.32988
#
#
# ______________________________ HEAD AND TAIL PROCESS______________________________
#  |||||||| TAIL OCCUR = USER NONACTIVE for GUIDANCE ||||||||
# take k = 0 out
#
# at items ||||||||||||||| 2867  target = 65.2199 watt now at 404.55  |||||   -339.3301 ______ -17907.65998
#
#
# ______________________________ HEAD AND TAIL PROCESS______________________________
#  |||||||| TAIL OCCUR = USER NONACTIVE for GUIDANCE ||||||||
# take k = 0 out
#
# at items ||||||||||||||| 2868  target = 64.1858 watt now at 420.337  |||||   -356.1512 ______ -18263.81118
#
#
# ______________________________ HEAD AND TAIL PROCESS______________________________
#  |||||||| TAIL OCCUR = USER NONACTIVE for GUIDANCE ||||||||
# take k = 0 out
#
# at items ||||||||||||||| 2869  target = 66.3531 watt now at 401.45  |||||   -335.0969 ______ -18598.90808
#
#
# ______________________________ HEAD AND TAIL PROCESS______________________________
#  |||||||| TAIL OCCUR = USER NONACTIVE for GUIDANCE ||||||||
# take k = 0 out
#
# at items ||||||||||||||| 2870  target = 68.4288 watt now at 437.921  |||||   -369.4922 ______ -18968.40028
#
#
# ______________________________ HEAD AND TAIL PROCESS______________________________
#  |||||||| TAIL OCCUR = USER NONACTIVE for GUIDANCE ||||||||
# take k = 0 out
#
# at items ||||||||||||||| 2871  target = 197.239 watt now at 435.975  |||||   -238.736 ______ -19207.13628
#
#
# ______________________________ HEAD AND TAIL PROCESS______________________________
#  |||||||| TAIL OCCUR = USER NONACTIVE for GUIDANCE ||||||||
# take k = 0 out
#
# at items ||||||||||||||| 2872  target = 434.019 watt now at 422.392  |||||   11.627 ______ -19195.50928
#
#
# ______________________________ HEAD AND TAIL PROCESS______________________________
#  |||||||| TAIL OCCUR = USER NONACTIVE for GUIDANCE ||||||||
# take k = 0 out
#
# at items ||||||||||||||| 2873  target = 486.984 watt now at 434.879  |||||   52.105 ______ -19143.40428
#
#
# ______________________________ HEAD AND TAIL PROCESS______________________________
#  |||||||| TAIL OCCUR = USER NONACTIVE for GUIDANCE ||||||||
# take k = 0 out
#
# at items ||||||||||||||| 2874  target = 476.846 watt now at 299.571  |||||   177.275 ______ -18966.12928
#
#
# ______________________________ HEAD AND TAIL PROCESS______________________________
#  |||||||| TAIL OCCUR = USER NONACTIVE for GUIDANCE ||||||||
# take k = 0 out
#
# at items ||||||||||||||| 2875  target = 384.173 watt now at 342.504  |||||   41.669 ______ -18924.46028
#
#
# ______________________________ HEAD AND TAIL PROCESS______________________________
#  |||||||| TAIL OCCUR = USER NONACTIVE for GUIDANCE ||||||||
# take k = 0 out
#
# at items ||||||||||||||| 2876  target = 305.762 watt now at 334.254  |||||   -28.492 ______ -18952.95228
#
#
# ______________________________ HEAD AND TAIL PROCESS______________________________
#  |||||||| TAIL OCCUR = USER NONACTIVE for GUIDANCE ||||||||
# take k = 0 out
#
# at items ||||||||||||||| 2877  target = 293.468 watt now at 325.658  |||||   -32.19 ______ -18985.14228
#
#
# ______________________________ HEAD AND TAIL PROCESS______________________________
#  |||||||| TAIL OCCUR = USER NONACTIVE for GUIDANCE ||||||||
# take k = 0 out
#
# at items ||||||||||||||| 2878  target = 291.698 watt now at 424.379  |||||   -132.681 ______ -19117.82328
#
#
# ______________________________ HEAD AND TAIL PROCESS______________________________
#   |||||||| HEAD OCCUR = USER ACTIVE for GUIDANCE ||||||||
# KeyErrorTraceback (most recent call last)
# <ipython-input-2-2173a57c4feb> in <module>()
#     138         if   HT == 1:
#     139             print "  |||||||| HEAD OCCUR = USER ACTIVE for GUIDANCE |||||||| "
# --> 140             m = end(j)
#     141             m1= m[0]
#     142             m1 -= 1
#
# <ipython-input-2-2173a57c4feb> in end(j)
#      64         while df1.bedroom_light[m5] > 0:
#      65             m5 += 1
# ---> 66         while df1.hair_dryer[m6] > 0:
#      67             m6 += 1
#      68         while df1.elec_thermos[m7] > 0:
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/series.pyc in __getitem__(self, key)
#     599         key = com._apply_if_callable(key, self)
#     600         try:
# --> 601             result = self.index.get_value(self, key)
#     602
#     603             if not is_scalar(result):
#
# /usr/local/lib/python2.7/dist-packages/pandas/indexes/base.pyc in get_value(self, series, key)
#    2167         try:
#    2168             return self._engine.get_value(s, k,
# -> 2169                                           tz=getattr(series.dtype, 'tz', None))
#    2170         except KeyError as e1:
#    2171             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_value (pandas/index.c:3567)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_value (pandas/index.c:3250)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4289)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.Int64HashTable.get_item (pandas/hashtable.c:8555)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.Int64HashTable.get_item (pandas/hashtable.c:8499)()
#
# KeyError: 2880

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 

conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()
d = 30
time_a = pd.date_range('2016-10-01 00:00:00', periods=96*d, freq='15T')
time_b = pd.date_range('2016-10-01 00:14:59', periods=96*d, freq='15T')
# query = "SELECT Timestamp,watt FROM active.target_all WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "%(time_a[0],time_b[(96*d)-1])
query = "SELECT Timestamp,watt FROM active.target_all WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "%(time_a[(96*7)-50],time_b[(96*10)-1])
df = pd.read_sql(query, conn)

# query1 = "SELECT Timestamp,new_watt FROM active.discount10active5 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "%(time_a[0],time_b[(96*d)-1])
query1 = "SELECT Timestamp,new_watt FROM active.discount10active5 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "%(time_a[(96*7)-50],time_b[(96*10)-1])
df1 = pd.read_sql(query1, conn)

df['new_watt']=df1.new_watt
fig, ax = plt.subplots(nrows=1,figsize=(9*2, 4*2))
df.plot(ax=ax)
plt.show()

# %%
print df.watt.sum()
print df1.new_watt.sum()
print (df.watt.sum()- df1.new_watt.sum())/1000
# Out:
# 368613.2438
# 360086.9695
# 8.5262743
