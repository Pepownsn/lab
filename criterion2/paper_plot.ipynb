# %%
import matplotlib.pyplot as plt
import pandas as pd # v. 1.7
import MySQLdb
import numpy as np
import time
import sys
import datetime 
from datetime import datetime
from sympy import *
from sympy.solvers import solve
from sympy.parsing.sympy_parser import parse_expr
from sklearn.metrics import mean_absolute_error,mean_squared_error
import statistics 
# %matplotlib inline

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.collections import PolyCollection
import matplotlib.pyplot as plt
from matplotlib import colors as mcolors
import numpy as np


conn = MySQLdb.connect("localhost","conn","hems")
cursor = conn.cursor()
query = "SELECT Timestamp,Sub_metering_1,Sub_metering_2,Sub_metering_3,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '%s'   AND TimeStamp <= '%s';"% ("2007-01-01 00:14:59","2007-01-01 23:59:59")
df = pd.read_sql(query, conn , index_col=['Timestamp'])

fig, ax = plt.subplots(figsize=(14, 6))
ax.set_title('Power Consumption every 15 minutes of Meter1-Meter2-Meter3-Meter4', fontsize=18)
plt.xlabel('Timestamp', fontsize=18)
plt.ylabel('watt', fontsize=18)
df.plot(ax=ax)
plt.show()

# fig = plt.figure()
# fig.suptitle('Power Consumption every 15 minutes of Meter1-Meter2-Meter3-Meter4', fontsize=12, fontweight='regular')
# ax = fig.add_subplot(111)
# fig.subplots_adjust(top=0.85)
# ax.set_title('Power Consumption every 15 minutes of Meter1-Meter2-Meter3-Meter4')

# query = "SELECT Timestamp, active_power FROM prediction.data15min_4y WHERE Timestamp >= '%s'   AND TimeStamp <= '%s';"% ("2007-02-15 00:00:00","2007-02-15 23:59:59")
# fig = plt.figure()
# ax = Axes3D(fig)
# w = df.Sub_metering_1
# x = df.Sub_metering_2
# y = df.Sub_metering_3
# z = df.Sub_metering_4
# verts = [zip(w,x, y,z)]
# # print verts
# # ax.add_collection3d(PolyCollection(verts))
# # plt.show()
# def cc(arg):
#     return mcolors.to_rgba(arg, alpha=0.6)

# poly = PolyCollection(verts, facecolors=[cc('r'), cc('g'), cc('b'),
#                                          cc('y')])
# poly.set_alpha(0.7)
# ax.add_collection3d(poly, zs=zs, zdir='y')

# ax.set_xlabel('X')
# ax.set_xlim3d(0, 200)
# ax.set_ylabel('Y')
# ax.set_ylim3d(-1, 5)
# ax.set_zlabel('Z')
# ax.set_zlim3d(0, 1000)
# plt.show()
