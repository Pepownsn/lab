# %% [markdown]
# ## PREDICTION EXPANDING TOTALPOWER

# %%
#http://stackoverflow.com/questions/11845055/predicting-from-previous-datevalue-data
import matplotlib.pyplot as plt
import pandas as pd # v. 1.7
import MySQLdb
import numpy as np
import time
import sys
import datetime 
from datetime import datetime
from sympy import *
from sympy.solvers import solve
from sympy.parsing.sympy_parser import parse_expr
from sklearn.metrics import mean_absolute_error,mean_squared_error
import statistics 
# %matplotlib inline

import MySQLdb
def initial_trend(series, slen):
    sum = 0.0
    for i in range(slen):
        sum += float(series[i+slen] - series[i]) / slen
    return sum / slen

# >>> initial_trend(series, 12)
# -0.7847222222222222

def triple_exponential_smoothing(series, slen, alpha, beta, gamma, n_preds):
    result = []
    seasonals = initial_seasonal_components(series, slen)
    for i in range(len(series)+n_preds):
        if i == 0: # initial values
            smooth = series[0]
            trend = initial_trend(series, slen)
            result.append(series[0])
            continue
        if i >= len(series): # we are forecasting
            m = i - len(series) + 1
            result.append((smooth + m*trend) + seasonals[i%slen])
        else:
            val = series[i]
            last_smooth, smooth = smooth, alpha*(val-seasonals[i%slen]) + (1-alpha)*(smooth+trend)
            trend = beta * (smooth-last_smooth) + (1-beta)*trend
            seasonals[i%slen] = gamma*(val-smooth) + (1-gamma)*seasonals[i%slen]
            result.append(smooth+trend+seasonals[i%slen])
    return result

# # forecast 24 points (i.e. two seasons)
# >>> triple_exponential_smoothing(series, 12, 0.716, 0.029, 0.993, 24)
# [30, 20.34449316666667, 28.410051892109554, 30.438122252647577, 39.466817731253066, ...


def initial_seasonal_components(series, slen):
    seasonals = {}
    season_averages = []
    n_seasons = int(len(series)/slen)
    # compute season averages
    for j in range(n_seasons):
        season_averages.append(sum(series[slen*j:slen*j+slen])/float(slen))
    # compute initial values
    for i in range(slen):
        sum_of_vals_over_avg = 0.0
        for j in range(n_seasons):
            sum_of_vals_over_avg += series[slen*j+i]-season_averages[j]
        seasonals[i] = sum_of_vals_over_avg/n_seasons
    return seasonals
##-----------------------------------------------------------------------------------
from sklearn.metrics import mean_squared_error
def fittingparameter(data_y,j):
    count_alpha = 0
    count_beta = 0
    count_gamma = 0
    alpha = float(0)
    beta = float(0)
    gamma = float(0)
    index_alpha =[]
    index_beta =[]
    index_gamma = []
    act = j
    data = data_y
    pred_no = 1
    ramda = 0.1
    MSE_holtload = []
#     query1 = "SELECT active_power FROM prediction.data15min_4y WHERE Timestamp >= '%s' AND TimeStamp <= '%s';"% (time_b[act+1],time_b[act+96])
    query1 = "SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '%s' ;"% (time_b[act+1])
    print query1
    df1 = pd.read_sql(query1, conn)
    while (alpha <= float(1)):
        count_alpha += 1
        beta = float(0)
        while (beta <=float(1)):
            count_beta += 1 
            gamma = float(0)
            while (gamma <= float(1)):
                count_gamma += 1
                pred_h = triple_exponential_smoothing(data, 96*7,alpha,beta ,gamma, pred_no)
                pred_data = pred_h[len(pred_h)-(pred_no):]                                               
                MSE = mean_squared_error (df1.active_power, pred_data)   
#                 print MSE              
                MSE_holtload.append(MSE)
                index_alpha.append(alpha)
                index_beta.append(beta)
                index_gamma.append(gamma)     
#                 print index_alpha,index_beta,index_gamma
                gamma += ramda
            beta += ramda
        alpha += ramda  
#     print  count_gamma,count_beta,count_alpha    
    index_MSE = MSE_holtload.index(min(MSE_holtload))
#     print min(MSE_holtload)
#     print index_MSE
    MSE_min = MSE_holtload[index_MSE]
    alpha = index_alpha[index_MSE]
    beta = index_beta[index_MSE]
    gamma= index_gamma[index_MSE]
    print count_alpha,count_beta,count_gamma
    print MSE_min,alpha,beta,gamma
    return (alpha,beta,gamma)

# %%
conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()
query = "SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '%s'   AND TimeStamp <= '%s';"% ("2007-01-01 00:14:59","2007-03-31 23:59:59")
df = pd.read_sql(query, conn , index_col=['Timestamp'])

pred_no = 1 # power 1 Data/15min in 1Hr --> 60/15 = 4 and 1day = 4*24 = 96
j = 0
i = 0
d = len(df)/96 
day =0

conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

time_a = pd.date_range('2007-01-01 00:14:59', periods=d*96, freq='15T')
time_b = pd.date_range('2007-01-14 23:59:59', periods=(d*96)+1, freq='15T')

# set databases to empty 
query_empty = """truncate table prediction.pred_expand_totalpower""" 
c.execute(query_empty)

while (j < 96*d ) :    
    if (j%96 == 0):    
        day += 1
        print "________DAY:" , day
    
    print "\ndata at :" , j,">>>", time_b[j+1]
    query = "SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '%s'   AND TimeStamp <= '%s';"% (time_a[0],time_b[j])
    print query
    df = pd.read_sql(query, conn)
    conn.commit()
    data_y = df['active_power'].values.tolist()
    ans_fiting = fittingparameter(data_y,j)
    pred_h = triple_exponential_smoothing(data_y, 96*7, ans_fiting[0], ans_fiting[1], ans_fiting[2],1)
    pred_data = pred_h[len(pred_h)-(pred_no):]
    c.execute("INSERT INTO prediction.pred_expand_totalpower(Timestamp, watt) VALUES ( %s, %s)",(time_b[j+1],abs(pred_data[0])))
    conn.commit()
    j += 1
print "DONE!!"
# Out:
# ________DAY: 1
#
# data at : 0 >>> 2007-01-15 00:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-14 23:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 00:14:59' ;
# 11 121 1331
# 0.0006796498597 0.2 0.1 0.7
#
# data at : 1 >>> 2007-01-15 00:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 00:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 00:29:59' ;
# 11 121 1331
# 0.000151801010371 0.9 0.4 0.4
#
# data at : 2 >>> 2007-01-15 00:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 00:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 00:44:59' ;
# 11 121 1331
# 0.000103470647952 0.9 0.2 0.4
#
# data at : 3 >>> 2007-01-15 00:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 00:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 00:59:59' ;
# 11 121 1331
# 0.000311185376756 0.4 0.0 0.1
#
# data at : 4 >>> 2007-01-15 01:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 00:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 01:14:59' ;
# 11 121 1331
# 0.000108551983844 0.1 0.1 0.4
#
# data at : 5 >>> 2007-01-15 01:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 01:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 01:29:59' ;
# 11 121 1331
# 0.467219353225 0.3 0.0 0.3
#
# data at : 6 >>> 2007-01-15 01:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 01:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 01:44:59' ;
# 11 121 1331
# 0.000433567549199 0.7 0.4 0.7
#
# data at : 7 >>> 2007-01-15 01:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 01:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 01:59:59' ;
# 11 121 1331
# 0.000685117488379 0.6 0.3 0.2
#
# data at : 8 >>> 2007-01-15 02:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 01:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 02:14:59' ;
# 11 121 1331
# 3.43716749282 0.2 0.9 0.4
#
# data at : 9 >>> 2007-01-15 02:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 02:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 02:29:59' ;
# 11 121 1331
# 4769.11766338 0.2 0.6 1.0
#
# data at : 10 >>> 2007-01-15 02:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 02:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 02:44:59' ;
# 11 121 1331
# 0.0210344923389 0.4 0.8 1.0
#
# data at : 11 >>> 2007-01-15 02:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 02:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 02:59:59' ;
# 11 121 1331
# 0.145431385609 0.4 0.3 0.3
#
# data at : 12 >>> 2007-01-15 03:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 02:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 03:14:59' ;
# 11 121 1331
# 0.435297696225 0.2 0.8 0.5
#
# data at : 13 >>> 2007-01-15 03:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 03:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 03:29:59' ;
# 11 121 1331
# 0.0217399156794 0.2 0.8 0.6
#
# data at : 14 >>> 2007-01-15 03:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 03:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 03:44:59' ;
# 11 121 1331
# 0.00136270275513 0.5 0.9 0.2
#
# data at : 15 >>> 2007-01-15 03:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 03:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 03:59:59' ;
# 11 121 1331
# 0.0267734720488 0.4 1.0 0.0
#
# data at : 16 >>> 2007-01-15 04:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 03:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 04:14:59' ;
# 11 121 1331
# 0.0724706177933 0.4 0.7 0.8
#
# data at : 17 >>> 2007-01-15 04:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 04:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 04:29:59' ;
# 11 121 1331
# 6.98854420457e-06 0.5 0.0 0.2
#
# data at : 18 >>> 2007-01-15 04:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 04:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 04:44:59' ;
# 11 121 1331
# 0.0111051493238 0.5 0.6 0.4
#
# data at : 19 >>> 2007-01-15 04:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 04:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 04:59:59' ;
# 11 121 1331
# 6.34211492396e-05 0.9 0.2 1.0
#
# data at : 20 >>> 2007-01-15 05:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 04:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 05:14:59' ;
# 11 121 1331
# 0.0639882382364 0.5 0.1 0.8
#
# data at : 21 >>> 2007-01-15 05:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 05:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 05:29:59' ;
# 11 121 1331
# 0.0105706527544 0.3 1.0 0.2
#
# data at : 22 >>> 2007-01-15 05:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 05:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 05:44:59' ;
# 11 121 1331
# 8.14109350351e-05 0.6 0.7 0.7
#
# data at : 23 >>> 2007-01-15 05:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 05:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 05:59:59' ;
# 11 121 1331
# 23.9447993233 0.1 0.9 0.9
#
# data at : 24 >>> 2007-01-15 06:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 05:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 06:14:59' ;
# 11 121 1331
# 5.30339395469e-05 0.0 0.0 1.0
#
# data at : 25 >>> 2007-01-15 06:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 06:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 06:29:59' ;
# 11 121 1331
# 0.00289384238463 0.3 0.6 0.7
#
# data at : 26 >>> 2007-01-15 06:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 06:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 06:44:59' ;
# 11 121 1331
# 0.000226058411107 0.1 0.6 0.1
#
# data at : 27 >>> 2007-01-15 06:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 06:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 06:59:59' ;
# 11 121 1331
# 1.54599650794 0.1 0.4 0.7
#
# data at : 28 >>> 2007-01-15 07:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 06:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 07:14:59' ;
# 11 121 1331
# 0.00399562103813 0.1 0.5 0.6
#
# data at : 29 >>> 2007-01-15 07:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 07:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 07:29:59' ;
# 11 121 1331
# 0.220559813873 0.8 0.7 0.7
#
# data at : 30 >>> 2007-01-15 07:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 07:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 07:44:59' ;
# 11 121 1331
# 0.000112955858826 0.9 0.6 0.5
#
# data at : 31 >>> 2007-01-15 07:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 07:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 07:59:59' ;
# 11 121 1331
# 0.00130042058565 0.9 0.0 1.0
#
# data at : 32 >>> 2007-01-15 08:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 07:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 08:14:59' ;
# 11 121 1331
# 0.000679712542339 0.7 0.1 0.4
#
# data at : 33 >>> 2007-01-15 08:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 08:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 08:29:59' ;
# 11 121 1331
# 0.0129468570097 0.2 0.7 0.9
#
# data at : 34 >>> 2007-01-15 08:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 08:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 08:44:59' ;
# 11 121 1331
# 8.95728435889 0.1 0.0 1.0
#
# data at : 35 >>> 2007-01-15 08:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 08:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 08:59:59' ;
# 11 121 1331
# 0.000152441675895 0.4 0.9 0.4
#
# data at : 36 >>> 2007-01-15 09:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 08:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 09:14:59' ;
# 11 121 1331
# 0.0356078688545 0.3 0.6 0.5
#
# data at : 37 >>> 2007-01-15 09:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 09:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 09:29:59' ;
# 11 121 1331
# 20271.1279247 0.1 0.1 1.0
#
# data at : 38 >>> 2007-01-15 09:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 09:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 09:44:59' ;
# 11 121 1331
# 0.0194905372554 0.7 0.6 0.5
#
# data at : 39 >>> 2007-01-15 09:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 09:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 09:59:59' ;
# 11 121 1331
# 0.0013793370819 0.3 0.5 0.5
#
# data at : 40 >>> 2007-01-15 10:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 09:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 10:14:59' ;
# 11 121 1331
# 0.123462750812 0.2 0.4 0.8
#
# data at : 41 >>> 2007-01-15 10:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 10:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 10:29:59' ;
# 11 121 1331
# 18.6333145711 0.0 0.0 0.1
#
# data at : 42 >>> 2007-01-15 10:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 10:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 10:44:59' ;
# 11 121 1331
# 0.153508710861 0.3 0.4 0.9
#
# data at : 43 >>> 2007-01-15 10:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 10:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 10:59:59' ;
# 11 121 1331
# 0.110346237283 0.3 0.4 0.2
#
# data at : 44 >>> 2007-01-15 11:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 10:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 11:14:59' ;
# 11 121 1331
# 0.0284974663814 0.6 0.9 1.0
#
# data at : 45 >>> 2007-01-15 11:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 11:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 11:29:59' ;
# 11 121 1331
# 0.0129605551881 0.7 0.3 1.0
#
# data at : 46 >>> 2007-01-15 11:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 11:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 11:44:59' ;
# 11 121 1331
# 0.00226973560195 0.4 0.3 0.0
#
# data at : 47 >>> 2007-01-15 11:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 11:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 11:59:59' ;
# 11 121 1331
# 9.75695110373 0.2 1.0 0.4
#
# data at : 48 >>> 2007-01-15 12:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 11:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 12:14:59' ;
# 11 121 1331
# 0.114366917735 0.1 0.1 0.0
#
# data at : 49 >>> 2007-01-15 12:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 12:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 12:29:59' ;
# 11 121 1331
# 0.00726309699294 0.4 0.1 1.0
#
# data at : 50 >>> 2007-01-15 12:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 12:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 12:44:59' ;
# 11 121 1331
# 4.66881144533e-05 0.1 0.1 0.8
#
# data at : 51 >>> 2007-01-15 12:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 12:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 12:59:59' ;
# 11 121 1331
# 2.44560917955 0.1 0.4 0.1
#
# data at : 52 >>> 2007-01-15 13:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 12:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 13:14:59' ;
# 11 121 1331
# 0.146667727279 0.3 0.9 0.7
#
# data at : 53 >>> 2007-01-15 13:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 13:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 13:29:59' ;
# 11 121 1331
# 0.000716222547461 0.5 0.2 0.0
#
# data at : 54 >>> 2007-01-15 13:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 13:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 13:44:59' ;
# 11 121 1331
# 0.0244502938511 0.6 0.2 0.5
#
# data at : 55 >>> 2007-01-15 13:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 13:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 13:59:59' ;
# 11 121 1331
# 0.00904927498541 0.2 0.4 0.8
#
# data at : 56 >>> 2007-01-15 14:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 13:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 14:14:59' ;
# 11 121 1331
# 0.000498878999963 0.5 0.0 0.5
#
# data at : 57 >>> 2007-01-15 14:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 14:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 14:29:59' ;
# 11 121 1331
# 22.0029663168 0.1 0.0 1.0
#
# data at : 58 >>> 2007-01-15 14:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 14:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 14:44:59' ;
# 11 121 1331
# 0.00426600099393 0.8 0.0 1.0
#
# data at : 59 >>> 2007-01-15 14:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 14:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 14:59:59' ;
# 11 121 1331
# 4.13136138666 0.1 0.0 0.4
#
# data at : 60 >>> 2007-01-15 15:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 14:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 15:14:59' ;
# 11 121 1331
# 0.00232026190223 0.1 0.1 1.0
#
# data at : 61 >>> 2007-01-15 15:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 15:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 15:29:59' ;
# 11 121 1331
# 0.00901830194967 0.6 0.4 0.6
#
# data at : 62 >>> 2007-01-15 15:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 15:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 15:44:59' ;
# 11 121 1331
# 0.0302279532406 0.3 0.4 0.6
#
# data at : 63 >>> 2007-01-15 15:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 15:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 15:59:59' ;
# 11 121 1331
# 0.00070920231038 0.2 0.7 0.1
#
# data at : 64 >>> 2007-01-15 16:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 15:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 16:14:59' ;
# 11 121 1331
# 0.00174489371716 0.7 0.0 1.0
#
# data at : 65 >>> 2007-01-15 16:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 16:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 16:29:59' ;
# 11 121 1331
# 0.00900012268914 0.3 0.5 0.9
#
# data at : 66 >>> 2007-01-15 16:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 16:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 16:44:59' ;
# 11 121 1331
# 0.0327434892435 0.8 1.0 0.8
#
# data at : 67 >>> 2007-01-15 16:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 16:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 16:59:59' ;
# 11 121 1331
# 0.00141912607029 0.6 0.7 0.1
#
# data at : 68 >>> 2007-01-15 17:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 16:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 17:14:59' ;
# 11 121 1331
# 0.0138004474626 0.4 0.2 0.2
#
# data at : 69 >>> 2007-01-15 17:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 17:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 17:29:59' ;
# 11 121 1331
# 0.0003187156514 0.7 0.8 0.1
#
# data at : 70 >>> 2007-01-15 17:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 17:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 17:44:59' ;
# 11 121 1331
# 0.00975083258008 0.3 0.7 0.8
#
# data at : 71 >>> 2007-01-15 17:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 17:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 17:59:59' ;
# 11 121 1331
# 0.0113596671385 0.6 0.6 0.3
#
# data at : 72 >>> 2007-01-15 18:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 17:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 18:14:59' ;
# 11 121 1331
# 1.08602815192e-05 0.7 1.0 0.1
#
# data at : 73 >>> 2007-01-15 18:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 18:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 18:29:59' ;
# 11 121 1331
# 0.00554513994323 0.5 0.6 0.3
#
# data at : 74 >>> 2007-01-15 18:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 18:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 18:44:59' ;
# 11 121 1331
# 33.3492721624 0.3 0.9 0.9
#
# data at : 75 >>> 2007-01-15 18:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 18:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 18:59:59' ;
# 11 121 1331
# 0.126976714996 0.1 0.8 0.7
#
# data at : 76 >>> 2007-01-15 19:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 18:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 19:14:59' ;
# 11 121 1331
# 0.00095481740926 0.5 0.8 0.4
#
# data at : 77 >>> 2007-01-15 19:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 19:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 19:29:59' ;
# 11 121 1331
# 0.00491330339294 0.0 0.0 0.5
#
# data at : 78 >>> 2007-01-15 19:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 19:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 19:44:59' ;
# 11 121 1331
# 1918.13341225 1.0 1.0 0.7
#
# data at : 79 >>> 2007-01-15 19:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 19:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 19:59:59' ;
# 11 121 1331
# 0.0343193698534 0.5 0.6 0.0
#
# data at : 80 >>> 2007-01-15 20:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 19:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 20:14:59' ;
# 11 121 1331
# 0.00202034855819 0.3 0.6 0.8
#
# data at : 81 >>> 2007-01-15 20:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 20:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 20:29:59' ;
# 11 121 1331
# 5.1988149227 0.1 0.6 0.6
#
# data at : 82 >>> 2007-01-15 20:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 20:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 20:44:59' ;
# 11 121 1331
# 0.00648202756928 0.1 0.1 0.1
#
# data at : 83 >>> 2007-01-15 20:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 20:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 20:59:59' ;
# 11 121 1331
# 4.29169222652 0.5 0.9 0.9
#
# data at : 84 >>> 2007-01-15 21:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 20:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 21:14:59' ;
# 11 121 1331
# 0.300711879036 0.7 0.2 1.0
#
# data at : 85 >>> 2007-01-15 21:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 21:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 21:29:59' ;
# 11 121 1331
# 0.000251845607965 0.2 1.0 0.1
#
# data at : 86 >>> 2007-01-15 21:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 21:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 21:44:59' ;
# 11 121 1331
# 0.0657564261342 0.6 0.1 0.5
#
# data at : 87 >>> 2007-01-15 21:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 21:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 21:59:59' ;
# 11 121 1331
# 0.00028419157984 0.1 0.1 1.0
#
# data at : 88 >>> 2007-01-15 22:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 21:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 22:14:59' ;
# 11 121 1331
# 0.444242490925 0.1 0.5 0.3
#
# data at : 89 >>> 2007-01-15 22:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 22:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 22:29:59' ;
# 11 121 1331
# 0.000127523160069 0.4 0.9 0.1
#
# data at : 90 >>> 2007-01-15 22:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 22:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 22:44:59' ;
# 11 121 1331
# 1.73138068441e-05 0.8 0.2 0.3
#
# data at : 91 >>> 2007-01-15 22:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 22:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 22:59:59' ;
# 11 121 1331
# 0.00607119805616 0.8 1.0 0.5
#
# data at : 92 >>> 2007-01-15 23:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 22:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 23:14:59' ;
# 11 121 1331
# 0.352332254891 0.4 0.9 0.0
#
# data at : 93 >>> 2007-01-15 23:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 23:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 23:29:59' ;
# 11 121 1331
# 477.424718161 0.4 1.0 1.0
#
# data at : 94 >>> 2007-01-15 23:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 23:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 23:44:59' ;
# 11 121 1331
# 0.183943300442 0.3 0.2 0.8
#
# data at : 95 >>> 2007-01-15 23:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 23:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 23:59:59' ;
# 11 121 1331
# 1.24315679333 0.1 0.6 0.1
# ________DAY: 2
#
# data at : 96 >>> 2007-01-16 00:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 23:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 00:14:59' ;
# 11 121 1331
# 53.3537300833 0.1 0.7 0.9
#
# data at : 97 >>> 2007-01-16 00:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 00:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 00:29:59' ;
# 11 121 1331
# 0.00220256994726 0.7 0.5 0.7
#
# data at : 98 >>> 2007-01-16 00:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 00:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 00:44:59' ;
# 11 121 1331
# 1.35889298591 0.4 0.6 0.9
#
# data at : 99 >>> 2007-01-16 00:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 00:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 00:59:59' ;
# 11 121 1331
# 0.992914025007 0.3 0.5 0.8
#
# data at : 100 >>> 2007-01-16 01:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 00:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 01:14:59' ;
# 11 121 1331
# 0.0232941949825 0.6 1.0 0.5
#
# data at : 101 >>> 2007-01-16 01:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 01:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 01:29:59' ;
# 11 121 1331
# 0.0278856803575 0.5 0.9 0.3
#
# data at : 102 >>> 2007-01-16 01:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 01:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 01:44:59' ;
# 11 121 1331
# 0.0995025168666 0.6 0.0 0.0
#
# data at : 103 >>> 2007-01-16 01:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 01:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 01:59:59' ;
# 11 121 1331
# 0.000417083030338 0.7 0.1 0.4
#
# data at : 104 >>> 2007-01-16 02:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 01:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 02:14:59' ;
# 11 121 1331
# 0.00235026550432 0.6 0.7 0.5
#
# data at : 105 >>> 2007-01-16 02:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 02:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 02:29:59' ;
# 11 121 1331
# 0.00105561205174 0.1 0.3 0.1
#
# data at : 106 >>> 2007-01-16 02:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 02:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 02:44:59' ;
# 11 121 1331
# 0.00977091385125 0.8 0.4 0.0
#
# data at : 107 >>> 2007-01-16 02:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 02:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 02:59:59' ;
# 11 121 1331
# 2.53078487479e-05 0.7 0.2 0.4
#
# data at : 108 >>> 2007-01-16 03:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 02:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 03:14:59' ;
# 11 121 1331
# 3.27752617197e-05 0.2 0.9 0.8
#
# data at : 109 >>> 2007-01-16 03:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 03:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 03:29:59' ;
# 11 121 1331
# 0.00241969609973 0.4 1.0 0.9
#
# data at : 110 >>> 2007-01-16 03:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 03:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 03:44:59' ;
# 11 121 1331
# 0.00165025220333 0.8 1.0 1.0
#
# data at : 111 >>> 2007-01-16 03:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 03:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 03:59:59' ;
# 11 121 1331
# 0.0101718830576 0.6 1.0 1.0
#
# data at : 112 >>> 2007-01-16 04:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 03:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 04:14:59' ;
# 11 121 1331
# 0.0870968277571 0.1 0.2 0.4
#
# data at : 113 >>> 2007-01-16 04:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 04:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 04:29:59' ;
# 11 121 1331
# 0.221546595864 0.2 0.0 0.8
#
# data at : 114 >>> 2007-01-16 04:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 04:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 04:44:59' ;
# 11 121 1331
# 89.393857473 0.0 0.0 0.4
#
# data at : 115 >>> 2007-01-16 04:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 04:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 04:59:59' ;
# 11 121 1331
# 0.0038070892141 0.6 0.4 0.9
#
# data at : 116 >>> 2007-01-16 05:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 04:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 05:14:59' ;
# 11 121 1331
# 0.0432471548712 0.2 0.0 0.7
#
# data at : 117 >>> 2007-01-16 05:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 05:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 05:29:59' ;
# 11 121 1331
# 0.0834636540068 0.9 0.6 1.0
#
# data at : 118 >>> 2007-01-16 05:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 05:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 05:44:59' ;
# 11 121 1331
# 0.00163730017719 0.5 1.0 0.1
#
# data at : 119 >>> 2007-01-16 05:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 05:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 05:59:59' ;
# 11 121 1331
# 0.00152860215368 0.7 0.5 0.6
#
# data at : 120 >>> 2007-01-16 06:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 05:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 06:14:59' ;
# 11 121 1331
# 0.000313275460398 0.4 0.7 0.0
#
# data at : 121 >>> 2007-01-16 06:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 06:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 06:29:59' ;
# 11 121 1331
# 0.000546185447239 0.1 0.4 0.1
#
# data at : 122 >>> 2007-01-16 06:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 06:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 06:44:59' ;
# 11 121 1331
# 0.319421029358 0.1 0.1 0.1
#
# data at : 123 >>> 2007-01-16 06:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 06:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 06:59:59' ;
# 11 121 1331
# 0.25395568821 0.3 0.7 1.0
#
# data at : 124 >>> 2007-01-16 07:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 06:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 07:14:59' ;
# 11 121 1331
# 51.7899951752 0.0 0.0 0.2
#
# data at : 125 >>> 2007-01-16 07:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 07:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 07:29:59' ;
# 11 121 1331
# 0.0372124033003 0.5 1.0 0.1
#
# data at : 126 >>> 2007-01-16 07:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 07:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 07:44:59' ;
# 11 121 1331
# 0.00172830945041 0.7 0.2 0.0
#
# data at : 127 >>> 2007-01-16 07:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 07:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 07:59:59' ;
# 11 121 1331
# 0.00659487121717 0.6 0.2 0.1
#
# data at : 128 >>> 2007-01-16 08:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 07:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 08:14:59' ;
# 11 121 1331
# 442.629991314 0.1 0.5 0.7
#
# data at : 129 >>> 2007-01-16 08:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 08:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 08:29:59' ;
# 11 121 1331
# 0.0553164027148 0.4 0.0 0.0
#
# data at : 130 >>> 2007-01-16 08:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 08:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 08:44:59' ;
# 11 121 1331
# 0.00100570049137 0.4 1.0 0.7
#
# data at : 131 >>> 2007-01-16 08:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 08:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 08:59:59' ;
# 11 121 1331
# 0.00251221475969 0.9 0.8 0.2
#
# data at : 132 >>> 2007-01-16 09:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 08:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 09:14:59' ;
# 11 121 1331
# 0.0120704180706 0.7 0.1 0.5
#
# data at : 133 >>> 2007-01-16 09:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 09:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 09:29:59' ;
# 11 121 1331
# 0.133316857995 0.9 0.2 0.0
#
# data at : 134 >>> 2007-01-16 09:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 09:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 09:44:59' ;
# 11 121 1331
# 0.0272445697359 0.2 0.2 0.2
#
# data at : 135 >>> 2007-01-16 09:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 09:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 09:59:59' ;
# 11 121 1331
# 0.0167150891512 0.1 0.3 0.0
#
# data at : 136 >>> 2007-01-16 10:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 09:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 10:14:59' ;
# 11 121 1331
# 0.00580095456149 0.3 0.3 0.1
#
# data at : 137 >>> 2007-01-16 10:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 10:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 10:29:59' ;
# 11 121 1331
# 0.00121516378015 0.9 0.0 0.4
#
# data at : 138 >>> 2007-01-16 10:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 10:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 10:44:59' ;
# 11 121 1331
# 0.00153793834197 0.9 0.6 1.0
#
# data at : 139 >>> 2007-01-16 10:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 10:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 10:59:59' ;
# 11 121 1331
# 0.00192228820676 0.7 0.1 1.0
#
# data at : 140 >>> 2007-01-16 11:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 10:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 11:14:59' ;
# 11 121 1331
# 0.0042299239301 0.4 0.6 0.3
#
# data at : 141 >>> 2007-01-16 11:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 11:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 11:29:59' ;
# 11 121 1331
# 0.0252549243898 0.2 0.0 0.0
#
# data at : 142 >>> 2007-01-16 11:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 11:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 11:44:59' ;
# 11 121 1331
# 15.9505081774 0.2 1.0 0.5
#
# data at : 143 >>> 2007-01-16 11:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 11:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 11:59:59' ;
# 11 121 1331
# 0.0199146293872 0.8 0.6 0.8
#
# data at : 144 >>> 2007-01-16 12:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 11:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 12:14:59' ;
# 11 121 1331
# 0.0425956485906 0.5 0.6 0.1
#
# data at : 145 >>> 2007-01-16 12:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 12:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 12:29:59' ;
# 11 121 1331
# 49193.0727 0.2 0.7 1.0
#
# data at : 146 >>> 2007-01-16 12:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 12:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 12:44:59' ;
# 11 121 1331
# 0.00623888665612 0.3 0.3 0.7
#
# data at : 147 >>> 2007-01-16 12:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 12:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 12:59:59' ;
# 11 121 1331
# 13.75205716 0.1 0.1 0.9
#
# data at : 148 >>> 2007-01-16 13:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 12:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 13:14:59' ;
# 11 121 1331
# 3.92645413113 0.1 0.6 0.5
#
# data at : 149 >>> 2007-01-16 13:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 13:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 13:29:59' ;
# 11 121 1331
# 0.00541681246214 0.6 0.5 0.7
#
# data at : 150 >>> 2007-01-16 13:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 13:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 13:44:59' ;
# 11 121 1331
# 0.00710494663972 0.0 0.0 0.4
#
# data at : 151 >>> 2007-01-16 13:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 13:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 13:59:59' ;
# 11 121 1331
# 0.00610357952746 0.3 0.5 0.3
#
# data at : 152 >>> 2007-01-16 14:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 13:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 14:14:59' ;
# 11 121 1331
# 15.7332187261 0.2 0.4 0.5
#
# data at : 153 >>> 2007-01-16 14:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 14:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 14:29:59' ;
# 11 121 1331
# 0.70834618998 0.2 0.4 0.4
#
# ...
#
# data at : 8589 >>> 2007-04-14 11:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 11:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 11:29:59' ;
# 11 121 1331
# 0.239248545308 0.9 1.0 0.2
#
# data at : 8590 >>> 2007-04-14 11:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 11:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 11:44:59' ;
# 11 121 1331
# 0.0169601067454 0.8 0.5 0.6
#
# data at : 8591 >>> 2007-04-14 11:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 11:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 11:59:59' ;
# 11 121 1331
# 0.00408088197024 0.9 0.0 0.4
#
# data at : 8592 >>> 2007-04-14 12:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 11:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 12:14:59' ;
# 11 121 1331
# 0.116405748062 0.8 1.0 0.2
#
# data at : 8593 >>> 2007-04-14 12:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 12:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 12:29:59' ;
# 11 121 1331
# 0.0861994685072 0.4 0.3 0.1
#
# data at : 8594 >>> 2007-04-14 12:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 12:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 12:44:59' ;
# 11 121 1331
# 0.293302167975 0.3 0.7 0.0
#
# data at : 8595 >>> 2007-04-14 12:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 12:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 12:59:59' ;
# 11 121 1331
# 0.0617044084461 0.3 0.5 0.3
#
# data at : 8596 >>> 2007-04-14 13:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 12:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 13:14:59' ;
# 11 121 1331
# 0.000412347041133 0.2 0.4 0.0
#
# data at : 8597 >>> 2007-04-14 13:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 13:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 13:29:59' ;
# 11 121 1331
# 0.0767209880729 0.4 0.5 0.0
#
# data at : 8598 >>> 2007-04-14 13:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 13:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 13:44:59' ;
# 11 121 1331
# 0.0798496807475 0.8 0.5 0.7
#
# data at : 8599 >>> 2007-04-14 13:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 13:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 13:59:59' ;
# 11 121 1331
# 0.167041848213 0.4 0.5 0.2
#
# data at : 8600 >>> 2007-04-14 14:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 13:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 14:14:59' ;
# 11 121 1331
# 5.78820684741e-05 0.5 0.1 1.0
#
# data at : 8601 >>> 2007-04-14 14:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 14:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 14:29:59' ;
# 11 121 1331
# 0.0108856407712 1.0 0.3 0.5
#
# data at : 8602 >>> 2007-04-14 14:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 14:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 14:44:59' ;
# 11 121 1331
# 0.0015264285512 0.3 0.7 0.1
#
# data at : 8603 >>> 2007-04-14 14:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 14:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 14:59:59' ;
# 11 121 1331
# 0.00134429044751 0.7 0.0 0.7
#
# data at : 8604 >>> 2007-04-14 15:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 14:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 15:14:59' ;
# 11 121 1331
# 0.00924582296829 0.8 0.2 0.0
#
# data at : 8605 >>> 2007-04-14 15:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 15:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 15:29:59' ;
# 11 121 1331
# 0.00058896411378 0.8 1.0 0.1
#
# data at : 8606 >>> 2007-04-14 15:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 15:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 15:44:59' ;
# 11 121 1331
# 0.204739460518 0.1 0.4 0.0
#
# data at : 8607 >>> 2007-04-14 15:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 15:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 15:59:59' ;
# 11 121 1331
# 0.00129245020309 0.4 0.0 0.5
#
# data at : 8608 >>> 2007-04-14 16:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 15:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 16:14:59' ;
# 11 121 1331
# 0.0646123385839 0.3 0.0 0.6
#
# data at : 8609 >>> 2007-04-14 16:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 16:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 16:29:59' ;
# 11 121 1331
# 0.000521792987294 0.8 0.6 1.0
#
# data at : 8610 >>> 2007-04-14 16:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 16:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 16:44:59' ;
# 11 121 1331
# 0.00695994862115 0.2 0.0 1.0
#
# data at : 8611 >>> 2007-04-14 16:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 16:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 16:59:59' ;
# 11 121 1331
# 0.0116301387257 0.6 0.1 0.0
#
# data at : 8612 >>> 2007-04-14 17:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 16:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 17:14:59' ;
# 11 121 1331
# 0.0638031024086 0.4 0.4 0.4
#
# data at : 8613 >>> 2007-04-14 17:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 17:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 17:29:59' ;
# 11 121 1331
# 0.0397562591099 0.7 0.8 0.4
#
# data at : 8614 >>> 2007-04-14 17:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 17:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 17:44:59' ;
# 11 121 1331
# 0.0014630664744 0.2 0.2 0.2
#
# data at : 8615 >>> 2007-04-14 17:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 17:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 17:59:59' ;
# 11 121 1331
# 1.48960733018 0.5 0.6 0.3
#
# data at : 8616 >>> 2007-04-14 18:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 17:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 18:14:59' ;
# 11 121 1331
# 0.0994229005798 0.5 0.0 0.2
#
# data at : 8617 >>> 2007-04-14 18:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 18:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 18:29:59' ;
# 11 121 1331
# 0.001223785247 0.2 0.1 0.4
#
# data at : 8618 >>> 2007-04-14 18:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 18:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 18:44:59' ;
# 11 121 1331
# 5.12971219417 0.5 1.0 0.5
#
# data at : 8619 >>> 2007-04-14 18:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 18:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 18:59:59' ;
# 11 121 1331
# 0.00605075818854 0.9 0.9 0.2
#
# data at : 8620 >>> 2007-04-14 19:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 18:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 19:14:59' ;
# 11 121 1331
# 0.00433238466327 0.9 0.6 1.0
#
# data at : 8621 >>> 2007-04-14 19:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 19:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 19:29:59' ;
# 11 121 1331
# 0.000282227521139 0.4 0.4 0.4
#
# data at : 8622 >>> 2007-04-14 19:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 19:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 19:44:59' ;
# 11 121 1331
# 0.00829440081796 0.8 0.0 0.8
#
# data at : 8623 >>> 2007-04-14 19:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 19:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 19:59:59' ;
# 11 121 1331
# 0.0022706790516 0.3 0.0 0.1
#
# data at : 8624 >>> 2007-04-14 20:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 19:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 20:14:59' ;
# 11 121 1331
# 2.93904125644e-05 0.6 0.1 0.4
#
# data at : 8625 >>> 2007-04-14 20:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 20:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 20:29:59' ;
# 11 121 1331
# 0.0006925208174 0.9 0.6 0.0
#
# data at : 8626 >>> 2007-04-14 20:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 20:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 20:44:59' ;
# 11 121 1331
# 5.14256828424e-05 0.8 0.4 0.9
#
# data at : 8627 >>> 2007-04-14 20:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 20:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 20:59:59' ;
# 11 121 1331
# 0.117479419232 1.0 0.9 0.9
#
# data at : 8628 >>> 2007-04-14 21:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 20:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 21:14:59' ;
# 11 121 1331
# 0.00632141721511 0.9 0.9 0.0
#
# data at : 8629 >>> 2007-04-14 21:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 21:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 21:29:59' ;
# 11 121 1331
# 0.0162614128117 0.5 0.8 0.8
#
# data at : 8630 >>> 2007-04-14 21:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 21:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 21:44:59' ;
# 11 121 1331
# 0.0236745908126 0.8 0.7 0.1
#
# data at : 8631 >>> 2007-04-14 21:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 21:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 21:59:59' ;
# 11 121 1331
# 0.0729064910538 0.4 0.4 0.6
#
# data at : 8632 >>> 2007-04-14 22:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 21:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 22:14:59' ;
# 11 121 1331
# 0.0462717253592 0.4 0.5 0.4
#
# data at : 8633 >>> 2007-04-14 22:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 22:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 22:29:59' ;
# 11 121 1331
# 0.00245086664975 0.7 0.1 0.9
#
# data at : 8634 >>> 2007-04-14 22:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 22:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 22:44:59' ;
# 11 121 1331
# 0.0378533798601 0.7 0.0 0.8
#
# data at : 8635 >>> 2007-04-14 22:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 22:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 22:59:59' ;
# 11 121 1331
# 3.69853209306 0.1 0.7 0.1
#
# data at : 8636 >>> 2007-04-14 23:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 22:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 23:14:59' ;
# 11 121 1331
# 0.328369395686 0.6 0.8 0.0
#
# data at : 8637 >>> 2007-04-14 23:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 23:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 23:29:59' ;
# 11 121 1331
# 0.000357220131771 0.6 0.6 0.3
#
# data at : 8638 >>> 2007-04-14 23:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 23:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 23:44:59' ;
# 11 121 1331
# 0.00086141135151 0.9 0.7 0.8
#
# data at : 8639 >>> 2007-04-14 23:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 23:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 23:59:59' ;
# 11 121 1331
# 0.115633322618 0.1 0.1 0.1
# DONE!!
