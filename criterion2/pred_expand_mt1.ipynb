# %% [markdown]
# ## PREDICTION EXPANDING METER1

# %%
#http://stackoverflow.com/questions/11845055/predicting-from-previous-datevalue-data
import matplotlib.pyplot as plt
import pandas as pd # v. 1.7
import MySQLdb
import numpy as np
import time
import sys
import datetime 
from datetime import datetime
from sympy import *
from sympy.solvers import solve
from sympy.parsing.sympy_parser import parse_expr
from sklearn.metrics import mean_absolute_error,mean_squared_error
import statistics 
# %matplotlib inline

import MySQLdb
def initial_trend(series, slen):
    sum = 0.0
    for i in range(slen):
        sum += float(series[i+slen] - series[i]) / slen
    return sum / slen

def triple_exponential_smoothing(series, slen, alpha, beta, gamma, n_preds):
    result = []
    seasonals = initial_seasonal_components(series, slen)
    for i in range(len(series)+n_preds):
        if i == 0: # initial values
            smooth = series[0]
            trend = initial_trend(series, slen)
            result.append(series[0])
            continue
        if i >= len(series): # we are forecasting
            m = i - len(series) + 1
            result.append((smooth + m*trend) + seasonals[i%slen])
        else:
            val = series[i]
            last_smooth, smooth = smooth, alpha*(val-seasonals[i%slen]) + (1-alpha)*(smooth+trend)
            trend = beta * (smooth-last_smooth) + (1-beta)*trend
            seasonals[i%slen] = gamma*(val-smooth) + (1-gamma)*seasonals[i%slen]
            result.append(smooth+trend+seasonals[i%slen])
    return result

# # forecast 24 points (i.e. two seasons)
# >>> triple_exponential_smoothing(series, 12, 0.716, 0.029, 0.993, 24)
# [30, 20.34449316666667, 28.410051892109554, 30.438122252647577, 39.466817731253066, ...


def initial_seasonal_components(series, slen):
    seasonals = {}
    season_averages = []
    n_seasons = int(len(series)/slen)
    # compute season averages
    for j in range(n_seasons):
        season_averages.append(sum(series[slen*j:slen*j+slen])/float(slen))
    # compute initial values
    for i in range(slen):
        sum_of_vals_over_avg = 0.0
        for j in range(n_seasons):
            sum_of_vals_over_avg += series[slen*j+i]-season_averages[j]
        seasonals[i] = sum_of_vals_over_avg/n_seasons
    return seasonals
##-----------------------------------------------------------------------------------
from sklearn.metrics import mean_squared_error
def fittingparameter(data_y,j):
    count_alpha = 0
    count_beta = 0
    count_gamma = 0
    alpha = float(0)
    beta = float(0)
    gamma = float(0)
    index_alpha =[]
    index_beta =[]
    index_gamma = []
    act = j
    data = data_y
    pred_no = 1
    ramda = 0.1
    MSE_holtload = []
#     query1 = "SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '%s' AND TimeStamp <= '%s';"% (time_b[act+1],time_b[act+96])
    query1 = "SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '%s' ;"% (time_b[act+1])
    print query1
    df1 = pd.read_sql(query1, conn)
#     print len(df)
    while (alpha <= float(1)):
        count_alpha += 1
        beta = float(0)
        while (beta <=float(1)):
            count_beta += 1 
            gamma = float(0)
            while (gamma <= float(1)):
                count_gamma += 1
                pred_h = triple_exponential_smoothing(data, 96*7,alpha,beta ,gamma, pred_no)
                pred_data = pred_h[len(pred_h)-(pred_no):]                                               
                MSE = mean_squared_error (df1.Sub_metering_1, pred_data)   
#                 print MSE              
                MSE_holtload.append(MSE)
                index_alpha.append(alpha)
                index_beta.append(beta)
                index_gamma.append(gamma)     
#                 print index_alpha,index_beta,index_gamma
                gamma += ramda
            beta += ramda
        alpha += ramda  
#     print  count_gamma,count_beta,count_alpha    
    index_MSE = MSE_holtload.index(min(MSE_holtload))
#     print min(MSE_holtload)
#     print index_MSE
    MSE_min = MSE_holtload[index_MSE]
    alpha = index_alpha[index_MSE]
    beta = index_beta[index_MSE]
    gamma= index_gamma[index_MSE]
    print count_alpha,count_beta,count_gamma
    print MSE_min,alpha,beta,gamma
    return (alpha,beta,gamma)

# %%
conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()
query = "SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '%s'   AND TimeStamp <= '%s';"% ("2007-01-01 00:14:59","2007-03-31 23:59:59")
df = pd.read_sql(query, conn , index_col=['Timestamp'])

pred_no = 1 # power 1 Data/15min in 1Hr --> 60/15 = 4 and 1day = 4*24 = 96
j = 0
i = 0
d = len(df)/96 
day = 0

conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

time_a = pd.date_range('2007-01-01 00:14:59', periods=(d*96)+1,freq='15T')
time_b = pd.date_range('2007-01-14 23:59:59', periods=(d*96)+1, freq='15T')

# set databases to empty 
query_empty = """truncate table prediction.pred_expand_mt1""" 
c.execute(query_empty)

while (j < 96*d ) :    
    if (j%96 == 0):    
        day += 1
        print "DAY:" , day 
    
    print "data at :" , j,">>>", time_b[j+1], ans_fiting[0], ans_fiting[1], ans_fiting[2]
    query = "SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '%s'   AND TimeStamp <= '%s';"% (time_a[0],time_b[j])
    print query
    df = pd.read_sql(query, conn)
    conn.commit()
    data_y = df['Sub_metering_1'].values.tolist()   
    ans_fiting = fittingparameter(data_y,j)
    pred_h = triple_exponential_smoothing(data_y, 96*7, ans_fiting[0], ans_fiting[1], ans_fiting[2],1)
    pred_data = pred_h[len(pred_h)-(pred_no):]
    c.execute("INSERT INTO prediction.pred_expand_mt1 (Timestamp, watt_sub1) VALUES ( %s, %s)",(time_b[j+1],abs(pred_data[0])))
    conn.commit()
    j += 1
print "DONE!!"
# Out:
# DAY: 1
# data at : 0 >>> 2007-01-15 00:14:59 1.0 0.7 0.0
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-14 23:59:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 00:14:59' ;
# 11 121 1331
# 0.0 1.0 1.0 0.0
# data at : 1 >>> 2007-01-15 00:29:59 1.0 1.0 0.0
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 00:14:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 00:29:59' ;
# 11 121 1331
# 0.0 1.0 1.0 0.0
# data at : 2 >>> 2007-01-15 00:44:59 1.0 1.0 0.0
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 00:29:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 00:44:59' ;
# 11 121 1331
# 0.0 1.0 1.0 0.0
# data at : 3 >>> 2007-01-15 00:59:59 1.0 1.0 0.0
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 00:44:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 00:59:59' ;
# 11 121 1331
# 0.0 1.0 1.0 0.0
# data at : 4 >>> 2007-01-15 01:14:59 1.0 1.0 0.0
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 00:59:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 01:14:59' ;
# 11 121 1331
# 0.0 1.0 1.0 0.0
# data at : 5 >>> 2007-01-15 01:29:59 1.0 1.0 0.0
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 01:14:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 01:29:59' ;
# 11 121 1331
# 0.0 1.0 1.0 0.0
# data at : 6 >>> 2007-01-15 01:44:59 1.0 1.0 0.0
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 01:29:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 01:44:59' ;
# 11 121 1331
# 0.0 1.0 1.0 0.0
# data at : 7 >>> 2007-01-15 01:59:59 1.0 1.0 0.0
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 01:44:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 01:59:59' ;
# 11 121 1331
# 0.0 1.0 1.0 0.0
# data at : 8 >>> 2007-01-15 02:14:59 1.0 1.0 0.0
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 01:59:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 02:14:59' ;
# 11 121 1331
# 0.0 1.0 1.0 0.0
# data at : 9 >>> 2007-01-15 02:29:59 1.0 1.0 0.0
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 02:14:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 02:29:59' ;
# 11 121 1331
# 0.0 1.0 0.9 0.0
# data at : 10 >>> 2007-01-15 02:44:59 1.0 0.9 0.0
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 02:29:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 02:44:59' ;
# 11 121 1331
# 0.0 1.0 0.9 0.0
# data at : 11 >>> 2007-01-15 02:59:59 1.0 0.9 0.0
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 02:44:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 02:59:59' ;
# 11 121 1331
# 0.0 1.0 0.9 0.0
# data at : 12 >>> 2007-01-15 03:14:59 1.0 0.9 0.0
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 02:59:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 03:14:59' ;
# 11 121 1331
# 0.0 1.0 0.9 0.0
# data at : 13 >>> 2007-01-15 03:29:59 1.0 0.9 0.0
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 03:14:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 03:29:59' ;
# 11 121 1331
# 0.0 1.0 0.9 0.0
# data at : 14 >>> 2007-01-15 03:44:59 1.0 0.9 0.0
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 03:29:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 03:44:59' ;
# 11 121 1331
# 0.0 1.0 0.9 0.0
# data at : 15 >>> 2007-01-15 03:59:59 1.0 0.9 0.0
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 10:44:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 10:59:59' ;
# 11 121 1331
# 5.33269971929e-28 1.0 1.0 0.0
# data at : 140 >>> 2007-01-16 11:14:59 1.0 1.0 0.0
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 10:59:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 11:14:59' ;
# 11 121 1331
# 0.0 1.0 1.0 0.0
# data at : 141 >>> 2007-01-16 11:29:59 1.0 1.0 0.0
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 11:14:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 11:29:59' ;
# 11 121 1331
# 0.0 1.0 1.0 0.0
# data at : 142 >>> 2007-01-16 11:44:59 1.0 1.0 0.0
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 11:29:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 11:44:59' ;
# 11 121 1331
# 0.0 1.0 1.0 0.0
# data at : 143 >>> 2007-01-16 11:59:59 1.0 1.0 0.0
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 11:44:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 11:59:59' ;
# 11 121 1331
# 0.0 1.0 1.0 0.0
# data at : 144 >>> 2007-01-16 12:14:59 1.0 1.0 0.0
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 11:59:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 12:14:59' ;
# 11 121 1331
# 0.0038471127848 0.2 0.0 0.9
# data at : 145 >>> 2007-01-16 12:29:59 0.2 0.0 0.9
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 12:14:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 12:29:59' ;
# 11 121 1331
# 235955.396205 0.1 0.3 1.0
# data at : 146 >>> 2007-01-16 12:44:59 0.1 0.3 1.0
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 12:29:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 12:44:59' ;
# 11 121 1331
# 0.0165397670342 0.4 0.2 0.7
# data at : 147 >>> 2007-01-16 12:59:59 0.4 0.2 0.7
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 12:44:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 12:59:59' ;
# 11 121 1331
# 0.473838025105 0.1 0.7 0.5
# data at : 148 >>> 2007-01-16 13:14:59 0.1 0.7 0.5
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 12:59:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 13:14:59' ;
# 11 121 1331
# 0.42399547655 0.1 0.8 1.0
# data at : 149 >>> 2007-01-16 13:29:59 0.1 0.8 1.0
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 13:14:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 13:29:59' ;
# 11 121 1331
# 9.07721087869 1.0 0.1 0.0
# data at : 150 >>> 2007-01-16 13:44:59 1.0 0.1 0.0
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 13:29:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 13:44:59' ;
# 11 121 1331
# 0.000280485948037 1.0 0.0 0.0
# data at : 151 >>> 2007-01-16 13:59:59 1.0 0.0 0.0
# ...
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 11:59:59' ;
# 11 121 1331
# 0.00250697561035 0.9 0.9 0.5
# data at : 8592 >>> 2007-04-14 12:14:59 0.9 0.9 0.5
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 11:59:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 12:14:59' ;
# 11 121 1331
# 1.60711841505e-05 0.7 0.1 0.1
# data at : 8593 >>> 2007-04-14 12:29:59 0.7 0.1 0.1
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 12:14:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 12:29:59' ;
# 11 121 1331
# 0.302546036047 0.4 0.2 0.8
# data at : 8594 >>> 2007-04-14 12:44:59 0.4 0.2 0.8
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 12:29:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 12:44:59' ;
# 11 121 1331
# 4.74939794395e-05 0.9 0.0 0.8
# data at : 8595 >>> 2007-04-14 12:59:59 0.9 0.0 0.8
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 12:44:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 12:59:59' ;
# 11 121 1331
# 0.00295616937459 0.7 0.7 0.1
# data at : 8596 >>> 2007-04-14 13:14:59 0.7 0.7 0.1
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 12:59:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 13:14:59' ;
# 11 121 1331
# 0.000325149620115 0.5 0.3 0.5
# data at : 8597 >>> 2007-04-14 13:29:59 0.5 0.3 0.5
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 13:14:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 13:29:59' ;
# 11 121 1331
# 0.0142706995878 0.2 0.2 0.1
# data at : 8598 >>> 2007-04-14 13:44:59 0.2 0.2 0.1
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 13:29:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 13:44:59' ;
# 11 121 1331
# 0.000239403797925 0.6 1.0 1.0
# data at : 8599 >>> 2007-04-14 13:59:59 0.6 1.0 1.0
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 13:44:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 13:59:59' ;
# 11 121 1331
# 0.326024910469 0.5 0.9 0.2
# data at : 8600 >>> 2007-04-14 14:14:59 0.5 0.9 0.2
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 13:59:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 14:14:59' ;
# 11 121 1331
# 0.0333854399727 0.6 0.5 0.8
# data at : 8601 >>> 2007-04-14 14:29:59 0.6 0.5 0.8
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 14:14:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 14:29:59' ;
# 11 121 1331
# 0.0271752705328 0.5 0.5 0.4
# data at : 8602 >>> 2007-04-14 14:44:59 0.5 0.5 0.4
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 14:29:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 14:44:59' ;
# 11 121 1331
# 0.0178470916371 0.9 0.9 0.7
# data at : 8603 >>> 2007-04-14 14:59:59 0.9 0.9 0.7
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 14:44:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 14:59:59' ;
# 11 121 1331
# 0.249887285966 0.7 0.4 0.7
# data at : 8604 >>> 2007-04-14 15:14:59 0.7 0.4 0.7
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 14:59:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 15:14:59' ;
# 11 121 1331
# 0.000298945523108 0.1 0.0 0.7
# data at : 8605 >>> 2007-04-14 15:29:59 0.1 0.0 0.7
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 15:14:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 15:29:59' ;
# 11 121 1331
# 0.00770014061859 0.6 0.2 0.8
# data at : 8606 >>> 2007-04-14 15:44:59 0.6 0.2 0.8
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 15:29:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 15:44:59' ;
# 11 121 1331
# 0.00016322783289 0.8 1.0 0.4
# data at : 8607 >>> 2007-04-14 15:59:59 0.8 1.0 0.4
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 15:44:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 15:59:59' ;
# 11 121 1331
# 0.00695017402154 0.7 0.0 0.7
# data at : 8608 >>> 2007-04-14 16:14:59 0.7 0.0 0.7
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 15:59:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 16:14:59' ;
# 11 121 1331
# 0.0100305518969 0.4 0.6 0.7
# data at : 8609 >>> 2007-04-14 16:29:59 0.4 0.6 0.7
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 16:14:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 16:29:59' ;
# 11 121 1331
# 0.000676957149409 0.5 0.6 0.7
# data at : 8610 >>> 2007-04-14 16:44:59 0.5 0.6 0.7
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 16:29:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 16:44:59' ;
# 11 121 1331
# 0.014015916361 0.8 0.3 0.1
# data at : 8611 >>> 2007-04-14 16:59:59 0.8 0.3 0.1
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 16:44:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 16:59:59' ;
# 11 121 1331
# 0.000280485948037 1.0 0.0 0.0
# data at : 8612 >>> 2007-04-14 17:14:59 1.0 0.0 0.0
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 16:59:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 17:14:59' ;
# 11 121 1331
# 0.0 1.0 1.0 0.1
# data at : 8613 >>> 2007-04-14 17:29:59 1.0 1.0 0.1
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 17:14:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 17:29:59' ;
# 11 121 1331
# 0.00171384541876 0.6 0.8 0.3
# data at : 8614 >>> 2007-04-14 17:44:59 0.6 0.8 0.3
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 17:29:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 17:44:59' ;
# 11 121 1331
# 0.00192346031529 0.8 0.6 0.2
# data at : 8615 >>> 2007-04-14 17:59:59 0.8 0.6 0.2
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 17:44:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 17:59:59' ;
# 11 121 1331
# 0.00400829938152 0.5 0.1 0.1
# data at : 8616 >>> 2007-04-14 18:14:59 0.5 0.1 0.1
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 17:59:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 18:14:59' ;
# 11 121 1331
# 0.024802506735 0.5 0.6 0.5
# data at : 8617 >>> 2007-04-14 18:29:59 0.5 0.6 0.5
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 18:14:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 18:29:59' ;
# 11 121 1331
# 0.00139623246859 0.7 0.1 0.3
# data at : 8618 >>> 2007-04-14 18:44:59 0.7 0.1 0.3
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 18:29:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 18:44:59' ;
# 11 121 1331
# 0.000185772106024 0.5 0.1 0.5
# data at : 8619 >>> 2007-04-14 18:59:59 0.5 0.1 0.5
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 18:44:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 18:59:59' ;
# 11 121 1331
# 0.00802432820685 0.9 0.9 0.9
# data at : 8620 >>> 2007-04-14 19:14:59 0.9 0.9 0.9
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 18:59:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 19:14:59' ;
# 11 121 1331
# 0.0191606551202 0.8 0.2 0.7
# data at : 8621 >>> 2007-04-14 19:29:59 0.8 0.2 0.7
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 19:14:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 19:29:59' ;
# 11 121 1331
# 0.0182637172279 0.3 0.0 0.5
# data at : 8622 >>> 2007-04-14 19:44:59 0.3 0.0 0.5
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 19:29:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 19:44:59' ;
# 11 121 1331
# 0.00185421309676 0.4 0.6 0.3
# data at : 8623 >>> 2007-04-14 19:59:59 0.4 0.6 0.3
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 19:44:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 19:59:59' ;
# 11 121 1331
# 0.0014005346538 0.7 0.1 0.5
# data at : 8624 >>> 2007-04-14 20:14:59 0.7 0.1 0.5
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 19:59:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 20:14:59' ;
# 11 121 1331
# 0.0206430458251 0.1 0.9 0.1
# data at : 8625 >>> 2007-04-14 20:29:59 0.1 0.9 0.1
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 20:14:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 20:29:59' ;
# 11 121 1331
# 0.000544843474241 0.1 0.0 0.9
# data at : 8626 >>> 2007-04-14 20:44:59 0.1 0.0 0.9
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 20:29:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 20:44:59' ;
# 11 121 1331
# 0.0326201194689 0.5 0.1 1.0
# data at : 8627 >>> 2007-04-14 20:59:59 0.5 0.1 1.0
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 20:44:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 20:59:59' ;
# 11 121 1331
# 0.000336945260971 0.9 0.9 0.6
# data at : 8628 >>> 2007-04-14 21:14:59 0.9 0.9 0.6
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 20:59:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 21:14:59' ;
# 11 121 1331
# 1.3040860612e-05 0.7 0.0 0.5
# data at : 8629 >>> 2007-04-14 21:29:59 0.7 0.0 0.5
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 21:14:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 21:29:59' ;
# 11 121 1331
# 0.094510303866 0.1 0.5 0.0
# data at : 8630 >>> 2007-04-14 21:44:59 0.1 0.5 0.0
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 21:29:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 21:44:59' ;
# 11 121 1331
# 0.00289700507743 0.3 0.0 0.9
# data at : 8631 >>> 2007-04-14 21:59:59 0.3 0.0 0.9
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 21:44:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 21:59:59' ;
# 11 121 1331
# 0.0197396218013 0.2 0.1 0.1
# data at : 8632 >>> 2007-04-14 22:14:59 0.2 0.1 0.1
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 21:59:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 22:14:59' ;
# 11 121 1331
# 0.015623836424 0.8 0.0 0.7
# data at : 8633 >>> 2007-04-14 22:29:59 0.8 0.0 0.7
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 22:14:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 22:29:59' ;
# 11 121 1331
# 9.62070751477e-05 0.9 0.6 1.0
# data at : 8634 >>> 2007-04-14 22:44:59 0.9 0.6 1.0
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 22:29:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 22:44:59' ;
# 11 121 1331
# 0.0122909863235 0.7 0.5 0.9
# data at : 8635 >>> 2007-04-14 22:59:59 0.7 0.5 0.9
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 22:44:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 22:59:59' ;
# 11 121 1331
# 0.000961432803443 0.8 1.0 0.7
# data at : 8636 >>> 2007-04-14 23:14:59 0.8 1.0 0.7
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 22:59:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 23:14:59' ;
# 11 121 1331
# 0.0635868561146 0.4 0.2 0.7
# data at : 8637 >>> 2007-04-14 23:29:59 0.4 0.2 0.7
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 23:14:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 23:29:59' ;
# 11 121 1331
# 6.00204441622e-05 0.2 0.8 0.1
# data at : 8638 >>> 2007-04-14 23:44:59 0.2 0.8 0.1
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 23:29:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 23:44:59' ;
# 11 121 1331
# 0.00103667305238 0.9 0.4 0.3
# data at : 8639 >>> 2007-04-14 23:59:59 0.9 0.4 0.3
# SELECT Timestamp,Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 23:44:59';
# SELECT Sub_metering_1 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 23:59:59' ;
# 11 121 1331
# 0.00812826201188 0.7 0.2 0.8
# DONE!!
