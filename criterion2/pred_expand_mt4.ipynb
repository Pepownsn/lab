# %% [markdown]
# ## PREDICTION EXPANDING METER4

# %%
#http://stackoverflow.com/questions/11845055/predicting-from-previous-datevalue-data
import matplotlib.pyplot as plt
import pandas as pd # v. 1.7
import MySQLdb
import numpy as np
import time
import sys
import datetime 
from datetime import datetime
from sympy import *
from sympy.solvers import solve
from sympy.parsing.sympy_parser import parse_expr
from sklearn.metrics import mean_absolute_error,mean_squared_error
import statistics 
# %matplotlib inline

import MySQLdb
def initial_trend(series, slen):
    sum = 0.0
    for i in range(slen):
        sum += float(series[i+slen] - series[i]) / slen
    return sum / slen

# >>> initial_trend(series, 12)
# -0.7847222222222222

def triple_exponential_smoothing(series, slen, alpha, beta, gamma, n_preds):
    result = []
    seasonals = initial_seasonal_components(series, slen)
    for i in range(len(series)+n_preds):
        if i == 0: # initial values
            smooth = series[0]
            trend = initial_trend(series, slen)
            result.append(series[0])
            continue
        if i >= len(series): # we are forecasting
            m = i - len(series) + 1
            result.append((smooth + m*trend) + seasonals[i%slen])
        else:
            val = series[i]
            last_smooth, smooth = smooth, alpha*(val-seasonals[i%slen]) + (1-alpha)*(smooth+trend)
            trend = beta * (smooth-last_smooth) + (1-beta)*trend
            seasonals[i%slen] = gamma*(val-smooth) + (1-gamma)*seasonals[i%slen]
            result.append(smooth+trend+seasonals[i%slen])
    return result

# # forecast 24 points (i.e. two seasons)
# >>> triple_exponential_smoothing(series, 12, 0.716, 0.029, 0.993, 24)
# [30, 20.34449316666667, 28.410051892109554, 30.438122252647577, 39.466817731253066, ...


def initial_seasonal_components(series, slen):
    seasonals = {}
    season_averages = []
    n_seasons = int(len(series)/slen)
    # compute season averages
    for j in range(n_seasons):
        season_averages.append(sum(series[slen*j:slen*j+slen])/float(slen))
    # compute initial values
    for i in range(slen):
        sum_of_vals_over_avg = 0.0
        for j in range(n_seasons):
            sum_of_vals_over_avg += series[slen*j+i]-season_averages[j]
        seasonals[i] = sum_of_vals_over_avg/n_seasons
    return seasonals
##-----------------------------------------------------------------------------------
from sklearn.metrics import mean_squared_error
def fittingparameter(data_y,j):
    count_alpha = 0
    count_beta = 0
    count_gamma = 0
    alpha = float(0)
    beta = float(0)
    gamma = float(0)
    index_alpha =[]
    index_beta =[]
    index_gamma = []
    act = j
    data = data_y
    pred_no = 1
    ramda = 0.1
    MSE_holtload = []
#     query1 = "SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '%s' AND TimeStamp <= '%s';"% (time_b[act+1],time_b[act+96])
    query1 = "SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '%s' ;"% (time_b[act+1])
    print query1
    df1 = pd.read_sql(query1, conn)
#     print len(df)
    while (alpha <= float(1)):
        count_alpha += 1
        beta = float(0)
        while (beta <=float(1)):
            count_beta += 1 
            gamma = float(0)
            while (gamma <= float(1)):
                count_gamma += 1
                pred_h = triple_exponential_smoothing(data, 96*7,alpha,beta ,gamma, pred_no)
                pred_data = pred_h[len(pred_h)-(pred_no):]                                               
                MSE = mean_squared_error (df1.Sub_metering_4, pred_data)   
#                 print MSE              
                MSE_holtload.append(MSE)
                index_alpha.append(alpha)
                index_beta.append(beta)
                index_gamma.append(gamma)     
#                 print index_alpha,index_beta,index_gamma
                gamma += ramda
            beta += ramda
        alpha += ramda  
#     print  count_gamma,count_beta,count_alpha    
    index_MSE = MSE_holtload.index(min(MSE_holtload))
#     print min(MSE_holtload)
#     print index_MSE
    MSE_min = MSE_holtload[index_MSE]
    alpha = index_alpha[index_MSE]
    beta = index_beta[index_MSE]
    gamma= index_gamma[index_MSE]
    print count_alpha,count_beta,count_gamma
    print MSE_min,alpha,beta,gamma
    return (alpha,beta,gamma)

# %%
conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()
query = "SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '%s'   AND TimeStamp <= '%s';"% ("2007-01-01 00:14:59","2007-03-31 23:59:59")
df = pd.read_sql(query, conn , index_col=['Timestamp'])

pred_no = 1 # power 1 Data/15min in 1Hr --> 60/15 = 4 and 1day = 4*24 = 96
j = 0
i = 0
d = len(df)/96 
day =0

conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

time_a = pd.date_range('2007-01-01 00:14:59', periods=d*96, freq='15T')
time_b = pd.date_range('2007-01-14 23:59:59', periods=(d*96)+1, freq='15T')

# set databases to empty 
query_empty = """truncate table prediction.pred_expand_mt4""" 
c.execute(query_empty)

while (j < 96*d ) :    
    if (j%96 == 0):    
        day += 1
        print "DAY:" , day
 
    
    print "\ndata at :" , j,">>>", time_b[j+1]
    query = "SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '%s'   AND TimeStamp <= '%s';"% (time_a[0],time_b[j])
    print query
    df = pd.read_sql(query, conn)
    conn.commit()
    data_y = df['Sub_metering_4'].values.tolist()
    ans_fiting = fittingparameter(data_y,j)
    pred_h = triple_exponential_smoothing(data_y, 96*7, ans_fiting[0], ans_fiting[1], ans_fiting[2],1)
    pred_data = pred_h[len(pred_h)-(pred_no):]
    c.execute("INSERT INTO prediction.pred_expand_mt4 (Timestamp, watt_sub4) VALUES ( %s, %s)",(time_b[j+1],abs(pred_data[0])))
    conn.commit()
    j += 1
print "DONE!!"
# Out:
# DAY: 1
#
# data at : 0 >>> 2007-01-15 00:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-14 23:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 00:14:59' ;
# 11 121 1331
# 1.40913794941 0.1 0.6 0.9
#
# data at : 1 >>> 2007-01-15 00:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 00:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 00:29:59' ;
# 11 121 1331
# 0.0728565987414 0.8 0.5 0.4
#
# data at : 2 >>> 2007-01-15 00:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 00:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 00:44:59' ;
# 11 121 1331
# 0.115934100256 0.8 0.1 0.2
#
# data at : 3 >>> 2007-01-15 00:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 00:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 00:59:59' ;
# 11 121 1331
# 0.0403777416418 0.4 0.1 0.0
#
# data at : 4 >>> 2007-01-15 01:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 00:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 01:14:59' ;
# 11 121 1331
# 0.00535782692466 0.5 0.2 0.2
#
# data at : 5 >>> 2007-01-15 01:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 01:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 01:29:59' ;
# 11 121 1331
# 0.0524895784236 0.6 0.0 0.8
#
# data at : 6 >>> 2007-01-15 01:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 01:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 01:44:59' ;
# 11 121 1331
# 0.00026918911931 0.7 0.0 0.2
#
# data at : 7 >>> 2007-01-15 01:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 01:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 01:59:59' ;
# 11 121 1331
# 3.41275879121e-06 0.2 0.4 0.6
#
# data at : 8 >>> 2007-01-15 02:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 01:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 02:14:59' ;
# 11 121 1331
# 0.000212069378021 0.4 0.6 0.0
#
# data at : 9 >>> 2007-01-15 02:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 02:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 02:29:59' ;
# 11 121 1331
# 1.63715619083e-05 0.9 0.2 0.9
#
# data at : 10 >>> 2007-01-15 02:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 02:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 02:44:59' ;
# 11 121 1331
# 0.000170027405505 0.5 0.7 0.3
#
# data at : 11 >>> 2007-01-15 02:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 02:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 02:59:59' ;
# 11 121 1331
# 0.0565528006484 0.6 0.2 0.6
#
# data at : 12 >>> 2007-01-15 03:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 02:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 03:14:59' ;
# 11 121 1331
# 0.10560362379 0.2 0.1 0.7
#
# data at : 13 >>> 2007-01-15 03:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 03:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 03:29:59' ;
# 11 121 1331
# 2.73677258387e-05 0.3 0.5 0.9
#
# data at : 14 >>> 2007-01-15 03:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 03:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 03:44:59' ;
# 11 121 1331
# 1.63214937032e-05 0.6 0.7 0.8
#
# data at : 15 >>> 2007-01-15 03:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 03:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 03:59:59' ;
# 11 121 1331
# 0.00597812795504 0.3 0.6 0.0
#
# data at : 16 >>> 2007-01-15 04:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 03:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 04:14:59' ;
# 11 121 1331
# 0.00142788525533 0.5 0.0 0.9
#
# data at : 17 >>> 2007-01-15 04:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 04:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 04:29:59' ;
# 11 121 1331
# 1.03285200764e-05 0.7 0.6 0.4
#
# data at : 18 >>> 2007-01-15 04:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 04:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 04:44:59' ;
# 11 121 1331
# 0.000537405101828 0.3 0.3 0.7
#
# data at : 19 >>> 2007-01-15 04:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 04:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 04:59:59' ;
# 11 121 1331
# 0.000172255681258 0.2 0.0 0.1
#
# data at : 20 >>> 2007-01-15 05:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 04:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 05:14:59' ;
# 11 121 1331
# 0.120909532372 0.3 0.1 0.0
#
# data at : 21 >>> 2007-01-15 05:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 05:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 05:29:59' ;
# 11 121 1331
# 0.115439442267 0.2 0.3 0.0
#
# data at : 22 >>> 2007-01-15 05:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 05:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 05:44:59' ;
# 11 121 1331
# 0.00190470344211 0.4 0.9 0.2
#
# data at : 23 >>> 2007-01-15 05:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 05:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 05:59:59' ;
# 11 121 1331
# 0.00570725068032 0.3 0.5 0.2
#
# data at : 24 >>> 2007-01-15 06:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 05:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 06:14:59' ;
# 11 121 1331
# 0.00262184562361 0.3 0.3 0.8
#
# data at : 25 >>> 2007-01-15 06:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 06:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 06:29:59' ;
# 11 121 1331
# 0.100377442017 0.3 0.5 0.4
#
# data at : 26 >>> 2007-01-15 06:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 06:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 06:44:59' ;
# 11 121 1331
# 3.46308161118e-05 0.4 1.0 0.1
#
# data at : 27 >>> 2007-01-15 06:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 06:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 06:59:59' ;
# 11 121 1331
# 20.2584011654 0.1 0.2 0.7
#
# data at : 28 >>> 2007-01-15 07:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 06:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 07:14:59' ;
# 11 121 1331
# 0.0479581526081 0.0 0.0 0.6
#
# data at : 29 >>> 2007-01-15 07:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 07:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 07:29:59' ;
# 11 121 1331
# 0.00541396895767 0.4 0.9 0.9
#
# data at : 30 >>> 2007-01-15 07:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 07:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 07:44:59' ;
# 11 121 1331
# 0.00129435459728 0.7 0.3 1.0
#
# data at : 31 >>> 2007-01-15 07:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 07:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 07:59:59' ;
# 11 121 1331
# 0.000435989011661 0.4 0.8 0.1
#
# data at : 32 >>> 2007-01-15 08:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 07:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 08:14:59' ;
# 11 121 1331
# 0.00837703948937 0.0 0.0 0.5
#
# data at : 33 >>> 2007-01-15 08:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 08:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 08:29:59' ;
# 11 121 1331
# 4.49297524188e-06 0.4 0.4 0.9
#
# data at : 34 >>> 2007-01-15 08:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 08:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 08:44:59' ;
# 11 121 1331
# 0.582736529929 0.1 1.0 0.6
#
# data at : 35 >>> 2007-01-15 08:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 08:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 08:59:59' ;
# 11 121 1331
# 14.5278528204 0.9 0.9 1.0
#
# data at : 36 >>> 2007-01-15 09:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 08:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 09:14:59' ;
# 11 121 1331
# 1.25444109923 0.8 0.2 1.0
#
# data at : 37 >>> 2007-01-15 09:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 09:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 09:29:59' ;
# 11 121 1331
# 0.20110980063 0.3 0.7 0.9
#
# data at : 38 >>> 2007-01-15 09:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 09:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 09:44:59' ;
# 11 121 1331
# 0.28554784308 0.3 0.4 0.1
#
# data at : 39 >>> 2007-01-15 09:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 09:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 09:59:59' ;
# 11 121 1331
# 0.228154861896 0.1 0.7 0.2
#
# data at : 40 >>> 2007-01-15 10:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 09:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 10:14:59' ;
# 11 121 1331
# 0.0386110767677 0.9 0.6 0.9
#
# data at : 41 >>> 2007-01-15 10:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 10:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 10:29:59' ;
# 11 121 1331
# 0.00348919984694 0.5 0.6 0.0
#
# data at : 42 >>> 2007-01-15 10:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 10:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 10:44:59' ;
# 11 121 1331
# 0.00395158559439 0.3 0.1 0.0
#
# data at : 43 >>> 2007-01-15 10:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 10:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 10:59:59' ;
# 11 121 1331
# 0.00141188893519 0.7 0.7 0.8
#
# data at : 44 >>> 2007-01-15 11:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 10:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 11:14:59' ;
# 11 121 1331
# 0.000103684058373 0.4 0.3 0.2
#
# data at : 45 >>> 2007-01-15 11:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 11:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 11:29:59' ;
# 11 121 1331
# 3.25821226438e-05 1.0 0.4 0.6
#
# data at : 46 >>> 2007-01-15 11:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 11:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 11:44:59' ;
# 11 121 1331
# 0.00832441658933 0.5 0.4 0.7
#
# data at : 47 >>> 2007-01-15 11:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 11:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 11:59:59' ;
# 11 121 1331
# 0.00540152124223 0.3 0.6 0.7
#
# data at : 48 >>> 2007-01-15 12:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 11:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 12:14:59' ;
# 11 121 1331
# 0.0002220612296 0.6 0.2 0.5
#
# data at : 49 >>> 2007-01-15 12:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 12:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 12:29:59' ;
# 11 121 1331
# 0.0972473220723 0.4 0.1 0.8
#
# data at : 50 >>> 2007-01-15 12:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 12:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 12:44:59' ;
# 11 121 1331
# 0.000665571566195 0.3 0.9 1.0
#
# data at : 51 >>> 2007-01-15 12:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 12:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 12:59:59' ;
# 11 121 1331
# 0.00291745231877 0.4 1.0 0.0
#
# data at : 52 >>> 2007-01-15 13:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 12:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 13:14:59' ;
# 11 121 1331
# 0.000434509158278 0.3 0.4 0.7
#
# data at : 53 >>> 2007-01-15 13:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 13:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 13:29:59' ;
# 11 121 1331
# 4.38217685977e-05 0.9 0.6 0.3
#
# data at : 54 >>> 2007-01-15 13:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 13:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 13:44:59' ;
# 11 121 1331
# 0.00276386641941 0.3 0.1 0.3
#
# data at : 55 >>> 2007-01-15 13:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 13:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 13:59:59' ;
# 11 121 1331
# 0.0949359953136 0.1 0.1 0.9
#
# data at : 56 >>> 2007-01-15 14:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 13:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 14:14:59' ;
# 11 121 1331
# 0.0170704127469 0.8 0.6 0.3
#
# data at : 57 >>> 2007-01-15 14:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 14:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 14:29:59' ;
# 11 121 1331
# 0.21545309824 0.6 0.7 0.0
#
# data at : 58 >>> 2007-01-15 14:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 14:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 14:44:59' ;
# 11 121 1331
# 0.0160852516363 0.3 1.0 0.8
#
# data at : 59 >>> 2007-01-15 14:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 14:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 14:59:59' ;
# 11 121 1331
# 0.258238956109 0.1 0.8 0.8
#
# data at : 60 >>> 2007-01-15 15:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 14:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 15:14:59' ;
# 11 121 1331
# 0.0492629783043 0.1 0.0 0.5
#
# data at : 61 >>> 2007-01-15 15:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 15:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 15:29:59' ;
# 11 121 1331
# 0.0515170784115 0.1 0.1 0.0
#
# data at : 62 >>> 2007-01-15 15:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 15:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 15:44:59' ;
# 11 121 1331
# 0.0352312551137 0.1 0.4 0.3
#
# data at : 63 >>> 2007-01-15 15:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 15:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 15:59:59' ;
# 11 121 1331
# 0.141213938986 0.3 0.6 0.7
#
# data at : 64 >>> 2007-01-15 16:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 15:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 16:14:59' ;
# 11 121 1331
# 0.0321599830518 0.6 0.2 0.6
#
# data at : 65 >>> 2007-01-15 16:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 16:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 16:29:59' ;
# 11 121 1331
# 0.0365720979098 0.4 0.5 0.5
#
# data at : 66 >>> 2007-01-15 16:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 16:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 16:44:59' ;
# 11 121 1331
# 0.00193668441648 0.2 0.8 0.8
#
# data at : 67 >>> 2007-01-15 16:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 16:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 16:59:59' ;
# 11 121 1331
# 3.73357490908e-05 0.6 0.2 1.0
#
# data at : 68 >>> 2007-01-15 17:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 16:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 17:14:59' ;
# 11 121 1331
# 0.00145951830977 0.6 0.5 1.0
#
# data at : 69 >>> 2007-01-15 17:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 17:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 17:29:59' ;
# 11 121 1331
# 0.00351363097673 0.1 0.8 0.2
#
# data at : 70 >>> 2007-01-15 17:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 17:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 17:44:59' ;
# 11 121 1331
# 0.190071453396 0.1 0.3 0.1
#
# data at : 71 >>> 2007-01-15 17:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 17:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 17:59:59' ;
# 11 121 1331
# 0.0103260780688 0.6 0.7 1.0
#
# data at : 72 >>> 2007-01-15 18:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 17:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 18:14:59' ;
# 11 121 1331
# 0.116896311562 0.6 0.8 0.7
#
# data at : 73 >>> 2007-01-15 18:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 18:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 18:29:59' ;
# 11 121 1331
# 0.00806708955136 0.6 0.5 0.2
#
# data at : 74 >>> 2007-01-15 18:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 18:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 18:44:59' ;
# 11 121 1331
# 7.57302815044 0.1 0.6 0.5
#
# data at : 75 >>> 2007-01-15 18:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 18:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 18:59:59' ;
# 11 121 1331
# 0.75341213311 1.0 0.9 0.2
#
# data at : 76 >>> 2007-01-15 19:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 18:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 19:14:59' ;
# 11 121 1331
# 12.1373737941 0.5 0.8 1.0
#
# data at : 77 >>> 2007-01-15 19:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 19:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 19:29:59' ;
# 11 121 1331
# 0.00108147008766 0.1 0.8 0.4
#
# data at : 78 >>> 2007-01-15 19:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 19:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 19:44:59' ;
# 11 121 1331
# 879.313073742 0.0 0.0 0.0
#
# data at : 79 >>> 2007-01-15 19:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 19:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 19:59:59' ;
# 11 121 1331
# 0.00794306748213 0.7 0.7 0.5
#
# data at : 80 >>> 2007-01-15 20:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 19:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 20:14:59' ;
# 11 121 1331
# 0.115430896557 0.7 0.2 0.4
#
# data at : 81 >>> 2007-01-15 20:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 20:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 20:29:59' ;
# 11 121 1331
# 42.7586962904 0.1 0.5 0.5
#
# data at : 82 >>> 2007-01-15 20:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 20:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 20:44:59' ;
# 11 121 1331
# 0.0154535049999 0.8 0.2 0.2
#
# data at : 83 >>> 2007-01-15 20:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 20:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 20:59:59' ;
# 11 121 1331
# 60.0617560353 0.6 1.0 0.0
#
# data at : 84 >>> 2007-01-15 21:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 20:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 21:14:59' ;
# 11 121 1331
# 0.459968969255 0.3 0.6 0.3
#
# data at : 85 >>> 2007-01-15 21:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 21:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 21:29:59' ;
# 11 121 1331
# 0.0605913714488 0.1 0.1 0.6
#
# data at : 86 >>> 2007-01-15 21:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 21:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 21:44:59' ;
# 11 121 1331
# 0.122027984599 0.5 0.8 0.3
#
# data at : 87 >>> 2007-01-15 21:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 21:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 21:59:59' ;
# 11 121 1331
# 0.0298757600599 0.6 0.7 0.7
#
# data at : 88 >>> 2007-01-15 22:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 21:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 22:14:59' ;
# 11 121 1331
# 0.434352970746 0.1 0.7 0.5
#
# data at : 89 >>> 2007-01-15 22:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 22:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 22:29:59' ;
# 11 121 1331
# 0.197356953586 0.9 0.6 0.0
#
# data at : 90 >>> 2007-01-15 22:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 22:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 22:44:59' ;
# 11 121 1331
# 0.168092056241 0.4 0.6 0.6
#
# data at : 91 >>> 2007-01-15 22:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 22:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 22:59:59' ;
# 11 121 1331
# 0.00360362407766 0.5 0.4 0.9
#
# data at : 92 >>> 2007-01-15 23:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 22:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 23:14:59' ;
# 11 121 1331
# 0.146137429464 0.2 0.9 0.9
#
# data at : 93 >>> 2007-01-15 23:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 23:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 23:29:59' ;
# 11 121 1331
# 7.29025566347 0.1 0.0 0.0
#
# data at : 94 >>> 2007-01-15 23:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 23:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 23:44:59' ;
# 11 121 1331
# 41.2866894794 0.0 0.0 0.7
#
# data at : 95 >>> 2007-01-15 23:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 23:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 23:59:59' ;
# 11 121 1331
# 0.000157713855993 0.8 0.3 1.0
# DAY: 2
#
# data at : 96 >>> 2007-01-16 00:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-15 23:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 00:14:59' ;
# 11 121 1331
# 0.00103202292019 0.5 0.3 0.7
#
# data at : 97 >>> 2007-01-16 00:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 00:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 00:29:59' ;
# 11 121 1331
# 0.684507882303 0.2 0.9 0.3
#
# data at : 98 >>> 2007-01-16 00:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 00:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 00:44:59' ;
# 11 121 1331
# 0.000551719437624 0.4 0.2 0.7
#
# data at : 99 >>> 2007-01-16 00:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 00:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 00:59:59' ;
# 11 121 1331
# 1.05510921437 0.3 0.1 0.9
#
# data at : 100 >>> 2007-01-16 01:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 00:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 01:14:59' ;
# 11 121 1331
# 0.00245534558228 0.7 0.2 0.9
#
# data at : 101 >>> 2007-01-16 01:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 01:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 01:29:59' ;
# 11 121 1331
# 4.46725385193e-06 0.6 0.0 0.0
#
# data at : 102 >>> 2007-01-16 01:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 01:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 01:44:59' ;
# 11 121 1331
# 0.0942235510487 0.5 0.9 0.4
#
# data at : 103 >>> 2007-01-16 01:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 01:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 01:59:59' ;
# 11 121 1331
# 0.0100518206252 0.5 0.1 1.0
#
# data at : 104 >>> 2007-01-16 02:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 01:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 02:14:59' ;
# 11 121 1331
# 0.00100380441974 0.5 0.4 1.0
#
# data at : 105 >>> 2007-01-16 02:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 02:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 02:29:59' ;
# 11 121 1331
# 0.071380142341 0.3 0.5 0.9
#
# data at : 106 >>> 2007-01-16 02:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 02:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 02:44:59' ;
# 11 121 1331
# 0.00891186527667 0.4 0.3 1.0
#
# data at : 107 >>> 2007-01-16 02:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 02:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 02:59:59' ;
# 11 121 1331
# 0.0266779933625 0.4 0.9 0.9
#
# data at : 108 >>> 2007-01-16 03:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 02:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 03:14:59' ;
# 11 121 1331
# 0.0116450344343 0.1 0.1 0.8
#
# data at : 109 >>> 2007-01-16 03:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 03:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 03:29:59' ;
# 11 121 1331
# 0.00375187325887 0.1 0.9 0.4
#
# data at : 110 >>> 2007-01-16 03:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 03:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 03:44:59' ;
# 11 121 1331
# 0.02155733191 0.3 1.0 0.5
#
# data at : 111 >>> 2007-01-16 03:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 03:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 03:59:59' ;
# 11 121 1331
# 1.82355365395 0.0 0.0 0.7
#
# data at : 112 >>> 2007-01-16 04:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 03:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 04:14:59' ;
# 11 121 1331
# 0.000443498454536 0.3 0.7 0.4
#
# data at : 113 >>> 2007-01-16 04:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 04:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 04:29:59' ;
# 11 121 1331
# 0.000228785992582 0.2 0.5 0.7
#
# data at : 114 >>> 2007-01-16 04:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 04:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 04:44:59' ;
# 11 121 1331
# 0.000300332553009 0.9 0.7 0.9
#
# data at : 115 >>> 2007-01-16 04:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 04:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 04:59:59' ;
# 11 121 1331
# 0.102976754397 0.3 0.6 0.2
#
# data at : 116 >>> 2007-01-16 05:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 04:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 05:14:59' ;
# 11 121 1331
# 0.000109244953423 0.3 0.9 0.5
#
# data at : 117 >>> 2007-01-16 05:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 05:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 05:29:59' ;
# 11 121 1331
# 0.0152517731005 0.4 0.1 0.4
#
# data at : 118 >>> 2007-01-16 05:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 05:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 05:44:59' ;
# 11 121 1331
# 0.00373033126274 0.3 0.9 1.0
#
# data at : 119 >>> 2007-01-16 05:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 05:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 05:59:59' ;
# 11 121 1331
# 0.00200256979456 0.2 0.5 0.6
#
# data at : 120 >>> 2007-01-16 06:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 05:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 06:14:59' ;
# 11 121 1331
# 1.65623678757e-05 0.5 0.1 0.2
#
# data at : 121 >>> 2007-01-16 06:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 06:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 06:29:59' ;
# 11 121 1331
# 0.0176168656225 0.4 1.0 0.9
#
# data at : 122 >>> 2007-01-16 06:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 06:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 06:44:59' ;
# 11 121 1331
# 0.40331786874 0.2 0.9 0.9
#
# data at : 123 >>> 2007-01-16 06:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 06:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 06:59:59' ;
# 11 121 1331
# 3.17877929299 0.1 0.9 0.8
#
# data at : 124 >>> 2007-01-16 07:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 06:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 07:14:59' ;
# 11 121 1331
# 0.00160384200133 0.7 0.0 0.7
#
# data at : 125 >>> 2007-01-16 07:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 07:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 07:29:59' ;
# 11 121 1331
# 2.46683861321e-06 0.8 0.5 0.3
#
# data at : 126 >>> 2007-01-16 07:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 07:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 07:44:59' ;
# 11 121 1331
# 0.0102146879231 0.5 0.4 0.1
#
# data at : 127 >>> 2007-01-16 07:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 07:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 07:59:59' ;
# 11 121 1331
# 0.0410832698095 0.5 0.5 0.2
#
# data at : 128 >>> 2007-01-16 08:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 07:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 08:14:59' ;
# 11 121 1331
# 0.450104422628 0.1 0.1 0.8
#
# data at : 129 >>> 2007-01-16 08:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 08:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 08:29:59' ;
# 11 121 1331
# 0.00126454150907 0.7 0.4 1.0
#
# data at : 130 >>> 2007-01-16 08:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 08:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 08:44:59' ;
# 11 121 1331
# 0.000326298242191 0.6 0.2 0.6
#
# data at : 131 >>> 2007-01-16 08:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 08:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 08:59:59' ;
# 11 121 1331
# 0.029559407623 0.8 0.8 0.6
#
# data at : 132 >>> 2007-01-16 09:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 08:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 09:14:59' ;
# 11 121 1331
# 0.010925460734 0.8 1.0 0.3
#
# data at : 133 >>> 2007-01-16 09:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 09:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 09:29:59' ;
# 11 121 1331
# 0.00264395440612 0.4 0.1 0.6
#
# data at : 134 >>> 2007-01-16 09:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 09:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 09:44:59' ;
# 11 121 1331
# 0.000463946806562 0.9 0.6 0.7
#
# data at : 135 >>> 2007-01-16 09:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 09:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 09:59:59' ;
# 11 121 1331
# 0.0275933306344 0.7 1.0 0.9
#
# data at : 136 >>> 2007-01-16 10:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 09:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 10:14:59' ;
# 11 121 1331
# 0.00134399311564 0.5 0.1 0.2
#
# data at : 137 >>> 2007-01-16 10:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 10:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 10:29:59' ;
# 11 121 1331
# 0.00331401274565 0.6 0.8 0.2
#
# data at : 138 >>> 2007-01-16 10:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 10:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 10:44:59' ;
# 11 121 1331
# 0.129230075511 0.2 0.9 0.0
#
# data at : 139 >>> 2007-01-16 10:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 10:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 10:59:59' ;
# 11 121 1331
# 5.03456200654e-05 0.7 1.0 0.6
#
# data at : 140 >>> 2007-01-16 11:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 10:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 11:14:59' ;
# 11 121 1331
# 0.00179652220089 0.5 0.4 0.3
#
# data at : 141 >>> 2007-01-16 11:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 11:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 11:29:59' ;
# 11 121 1331
# 0.00806605190101 0.3 0.5 0.4
#
# data at : 142 >>> 2007-01-16 11:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 11:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 11:44:59' ;
# 11 121 1331
# 0.881630744824 0.2 0.9 0.4
#
# data at : 143 >>> 2007-01-16 11:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 11:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 11:59:59' ;
# 11 121 1331
# 0.00517178759077 0.5 0.5 0.1
#
# data at : 144 >>> 2007-01-16 12:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 11:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 12:14:59' ;
# 11 121 1331
# 2.39522364657e-05 0.6 0.1 0.5
#
# data at : 145 >>> 2007-01-16 12:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 12:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 12:29:59' ;
# 11 121 1331
# 0.00115432707194 0.3 0.3 0.1
#
# data at : 146 >>> 2007-01-16 12:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 12:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 12:44:59' ;
# 11 121 1331
# 0.000171615509719 0.8 0.5 0.9
#
# data at : 147 >>> 2007-01-16 12:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 12:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 12:59:59' ;
# 11 121 1331
# 0.000692955867341 0.4 0.8 0.3
#
# data at : 148 >>> 2007-01-16 13:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 12:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 13:14:59' ;
# 11 121 1331
# 0.00549818538508 0.2 0.0 0.6
#
# data at : 149 >>> 2007-01-16 13:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 13:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 13:29:59' ;
# 11 121 1331
# 0.0111160340874 0.7 0.1 1.0
#
# data at : 150 >>> 2007-01-16 13:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 13:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 13:44:59' ;
# 11 121 1331
# 0.00142569887937 0.6 0.9 0.1
#
# data at : 151 >>> 2007-01-16 13:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-16 13:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 13:59:59' ;
# 11 121 1331
# 0.00152738915576 0.7 0.1 0.3
#
# ...
# 11 121 1331
# 0.0262502429482 0.7 1.0 0.4
#
# data at : 8590 >>> 2007-04-14 11:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 11:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 11:44:59' ;
# 11 121 1331
# 0.0656346208738 0.4 0.4 0.7
#
# data at : 8591 >>> 2007-04-14 11:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 11:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 11:59:59' ;
# 11 121 1331
# 8.41087833178e-09 0.7 0.0 0.1
#
# data at : 8592 >>> 2007-04-14 12:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 11:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 12:14:59' ;
# 11 121 1331
# 8.49684147064e-07 0.9 0.9 0.2
#
# data at : 8593 >>> 2007-04-14 12:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 12:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 12:29:59' ;
# 11 121 1331
# 6.5712466924e-05 0.8 0.6 0.2
#
# data at : 8594 >>> 2007-04-14 12:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 12:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 12:44:59' ;
# 11 121 1331
# 0.386968239457 0.0 0.0 0.6
#
# data at : 8595 >>> 2007-04-14 12:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 12:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 12:59:59' ;
# 11 121 1331
# 0.00458006255873 0.2 0.0 0.2
#
# data at : 8596 >>> 2007-04-14 13:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 12:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 13:14:59' ;
# 11 121 1331
# 0.492127186437 0.7 0.3 1.0
#
# data at : 8597 >>> 2007-04-14 13:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 13:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 13:29:59' ;
# 11 121 1331
# 0.0468643027172 0.3 0.1 0.8
#
# data at : 8598 >>> 2007-04-14 13:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 13:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 13:44:59' ;
# 11 121 1331
# 5.400653681e-05 0.8 0.8 0.5
#
# data at : 8599 >>> 2007-04-14 13:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 13:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 13:59:59' ;
# 11 121 1331
# 0.813297021311 0.2 0.0 0.6
#
# data at : 8600 >>> 2007-04-14 14:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 13:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 14:14:59' ;
# 11 121 1331
# 0.0144435787958 0.4 0.8 0.1
#
# data at : 8601 >>> 2007-04-14 14:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 14:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 14:29:59' ;
# 11 121 1331
# 0.00218519086752 0.7 0.5 0.6
#
# data at : 8602 >>> 2007-04-14 14:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 14:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 14:44:59' ;
# 11 121 1331
# 2.42418570463 0.1 0.0 0.9
#
# data at : 8603 >>> 2007-04-14 14:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 14:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 14:59:59' ;
# 11 121 1331
# 1.64113984291e-05 0.4 0.1 0.2
#
# data at : 8604 >>> 2007-04-14 15:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 14:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 15:14:59' ;
# 11 121 1331
# 0.000214666707155 0.9 1.0 0.5
#
# data at : 8605 >>> 2007-04-14 15:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 15:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 15:29:59' ;
# 11 121 1331
# 0.000796325376724 0.5 0.5 0.4
#
# data at : 8606 >>> 2007-04-14 15:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 15:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 15:44:59' ;
# 11 121 1331
# 0.0286029328978 0.7 0.6 0.8
#
# data at : 8607 >>> 2007-04-14 15:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 15:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 15:59:59' ;
# 11 121 1331
# 0.00510962894367 0.7 0.3 0.7
#
# data at : 8608 >>> 2007-04-14 16:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 15:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 16:14:59' ;
# 11 121 1331
# 0.213957927532 0.0 0.0 0.6
#
# data at : 8609 >>> 2007-04-14 16:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 16:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 16:29:59' ;
# 11 121 1331
# 0.000419070490584 0.3 0.0 0.6
#
# data at : 8610 >>> 2007-04-14 16:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 16:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 16:44:59' ;
# 11 121 1331
# 6.98603341105e-05 0.4 0.0 0.8
#
# data at : 8611 >>> 2007-04-14 16:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 16:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 16:59:59' ;
# 11 121 1331
# 0.0435021147892 0.8 0.5 1.0
#
# data at : 8612 >>> 2007-04-14 17:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 16:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 17:14:59' ;
# 11 121 1331
# 0.00103566166903 0.9 0.4 0.4
#
# data at : 8613 >>> 2007-04-14 17:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 17:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 17:29:59' ;
# 11 121 1331
# 0.00219633557358 0.0 0.0 0.1
#
# data at : 8614 >>> 2007-04-14 17:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 17:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 17:44:59' ;
# 11 121 1331
# 4.98978531823e-05 0.6 0.0 0.7
#
# data at : 8615 >>> 2007-04-14 17:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 17:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 17:59:59' ;
# 11 121 1331
# 0.0211478205122 0.2 0.2 0.4
#
# data at : 8616 >>> 2007-04-14 18:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 17:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 18:14:59' ;
# 11 121 1331
# 0.000445619022095 0.7 0.6 0.8
#
# data at : 8617 >>> 2007-04-14 18:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 18:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 18:29:59' ;
# 11 121 1331
# 2.22660746706 0.2 0.7 0.2
#
# data at : 8618 >>> 2007-04-14 18:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 18:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 18:44:59' ;
# 11 121 1331
# 0.00155929434572 0.7 0.8 0.4
#
# data at : 8619 >>> 2007-04-14 18:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 18:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 18:59:59' ;
# 11 121 1331
# 0.00030950716489 0.9 0.4 0.1
#
# data at : 8620 >>> 2007-04-14 19:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 18:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 19:14:59' ;
# 11 121 1331
# 0.000622820833926 0.7 0.4 0.6
#
# data at : 8621 >>> 2007-04-14 19:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 19:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 19:29:59' ;
# 11 121 1331
# 0.00745887611988 0.8 0.0 0.2
#
# data at : 8622 >>> 2007-04-14 19:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 19:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 19:44:59' ;
# 11 121 1331
# 1.78542523951e-05 0.8 0.5 0.3
#
# data at : 8623 >>> 2007-04-14 19:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 19:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 19:59:59' ;
# 11 121 1331
# 0.196947760866 0.6 0.1 0.7
#
# data at : 8624 >>> 2007-04-14 20:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 19:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 20:14:59' ;
# 11 121 1331
# 0.0801804867795 0.3 0.0 0.1
#
# data at : 8625 >>> 2007-04-14 20:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 20:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 20:29:59' ;
# 11 121 1331
# 0.0522313526591 1.0 0.7 0.2
#
# data at : 8626 >>> 2007-04-14 20:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 20:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 20:44:59' ;
# 11 121 1331
# 3.63487824735e-05 0.7 0.0 0.1
#
# data at : 8627 >>> 2007-04-14 20:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 20:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 20:59:59' ;
# 11 121 1331
# 0.0440858551977 0.7 0.2 0.7
#
# data at : 8628 >>> 2007-04-14 21:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 20:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 21:14:59' ;
# 11 121 1331
# 0.00663172560165 0.9 0.6 0.1
#
# data at : 8629 >>> 2007-04-14 21:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 21:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 21:29:59' ;
# 11 121 1331
# 0.0401925495996 0.4 0.2 0.1
#
# data at : 8630 >>> 2007-04-14 21:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 21:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 21:44:59' ;
# 11 121 1331
# 0.0384372437813 0.9 1.0 0.5
#
# data at : 8631 >>> 2007-04-14 21:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 21:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 21:59:59' ;
# 11 121 1331
# 0.0437626856468 0.3 0.8 0.4
#
# data at : 8632 >>> 2007-04-14 22:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 21:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 22:14:59' ;
# 11 121 1331
# 0.00394788268309 0.5 0.4 0.4
#
# data at : 8633 >>> 2007-04-14 22:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 22:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 22:29:59' ;
# 11 121 1331
# 0.00576303995243 0.5 1.0 0.0
#
# data at : 8634 >>> 2007-04-14 22:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 22:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 22:44:59' ;
# 11 121 1331
# 0.00137569836177 0.6 0.2 0.2
#
# data at : 8635 >>> 2007-04-14 22:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 22:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 22:59:59' ;
# 11 121 1331
# 0.0256428745083 0.9 0.8 0.9
#
# data at : 8636 >>> 2007-04-14 23:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 22:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 23:14:59' ;
# 11 121 1331
# 8.23905547299e-05 0.4 0.1 0.3
#
# data at : 8637 >>> 2007-04-14 23:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 23:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 23:29:59' ;
# 11 121 1331
# 0.000199587786699 0.8 0.0 1.0
#
# data at : 8638 >>> 2007-04-14 23:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 23:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 23:44:59' ;
# 11 121 1331
# 0.000268439204819 0.6 0.4 0.0
#
# data at : 8639 >>> 2007-04-14 23:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-04-14 23:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 23:59:59' ;
# 11 121 1331
# 0.029526575101 0.5 0.2 0.7
# DONE!!
