# %% [markdown]
# ## PREDICTION MOVING TOTALPOWER

# %%
#http://stackoverflow.com/questions/11845055/predicting-from-previous-datevalue-data
import matplotlib.pyplot as plt
import pandas as pd # v. 1.7
import MySQLdb
import numpy as np
import time
import sys
import datetime 
from datetime import datetime
from sympy import *
from sympy.solvers import solve
from sympy.parsing.sympy_parser import parse_expr
from sklearn.metrics import mean_absolute_error,mean_squared_error
import statistics 
# %matplotlib inline

import MySQLdb
def initial_trend(series, slen):
    sum = 0.0
    for i in range(slen):
        sum += float(series[i+slen] - series[i]) / slen
    return sum / slen

# >>> initial_trend(series, 12)
# -0.7847222222222222

def triple_exponential_smoothing(series, slen, alpha, beta, gamma, n_preds):
    result = []
    seasonals = initial_seasonal_components(series, slen)
    for i in range(len(series)+n_preds):
        if i == 0: # initial values
            smooth = series[0]
            trend = initial_trend(series, slen)
            result.append(series[0])
            continue
        if i >= len(series): # we are forecasting
            m = i - len(series) + 1
            result.append((smooth + m*trend) + seasonals[i%slen])
        else:
            val = series[i]
            last_smooth, smooth = smooth, alpha*(val-seasonals[i%slen]) + (1-alpha)*(smooth+trend)
            trend = beta * (smooth-last_smooth) + (1-beta)*trend
            seasonals[i%slen] = gamma*(val-smooth) + (1-gamma)*seasonals[i%slen]
            result.append(smooth+trend+seasonals[i%slen])
    return result

# # forecast 24 points (i.e. two seasons)
# >>> triple_exponential_smoothing(series, 12, 0.716, 0.029, 0.993, 24)
# [30, 20.34449316666667, 28.410051892109554, 30.438122252647577, 39.466817731253066, ...


def initial_seasonal_components(series, slen):
    seasonals = {}
    season_averages = []
    n_seasons = int(len(series)/slen)
    # compute season averages
    for j in range(n_seasons):
        season_averages.append(sum(series[slen*j:slen*j+slen])/float(slen))
    # compute initial values
    for i in range(slen):
        sum_of_vals_over_avg = 0.0
        for j in range(n_seasons):
            sum_of_vals_over_avg += series[slen*j+i]-season_averages[j]
        seasonals[i] = sum_of_vals_over_avg/n_seasons
    return seasonals
##-----------------------------------------------------------------------------------
from sklearn.metrics import mean_squared_error
def fittingparameter(data_y,j):
    count_alpha = 0
    count_beta = 0
    count_gamma = 0
    alpha = float(0)
    beta = float(0)
    gamma = float(0)
    index_alpha =[]
    index_beta =[]
    index_gamma = []
    act = j
    data = data_y
    pred_no = 1
    ramda = 0.1
    MSE_holtload = []
#     query1 = "SELECT active_power FROM prediction.data15min_4y WHERE Timestamp >= '%s' AND TimeStamp <= '%s';"% (time_b[act+1],time_b[act+96])
    query1 = "SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '%s' ;"% (time_b[act+1])
    print query1
    df1 = pd.read_sql(query1, conn)
    while (alpha <= float(1)):
        count_alpha += 1
        beta = float(0)
        while (beta <=float(1)):
            count_beta += 1 
            gamma = float(0)
            while (gamma <= float(1)):
                count_gamma += 1
                pred_h = triple_exponential_smoothing(data, 96*7,alpha,beta ,gamma, pred_no)
                pred_data = pred_h[len(pred_h)-(pred_no):]                                               
                MSE = mean_squared_error (df1.active_power, pred_data)   
#                 print MSE              
                MSE_holtload.append(MSE)
                index_alpha.append(alpha)
                index_beta.append(beta)
                index_gamma.append(gamma)     
#                 print index_alpha,index_beta,index_gamma
                gamma += ramda
            beta += ramda
        alpha += ramda  
#     print  count_gamma,count_beta,count_alpha    
    index_MSE = MSE_holtload.index(min(MSE_holtload))
#     print min(MSE_holtload)
#     print index_MSE
    MSE_min = MSE_holtload[index_MSE]
    alpha = index_alpha[index_MSE]
    beta = index_beta[index_MSE]
    gamma= index_gamma[index_MSE]
    print count_alpha,count_beta,count_gamma
    print MSE_min,alpha,beta,gamma
    return (alpha,beta,gamma)

# %%
conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()
query = "SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '%s'   AND TimeStamp <= '%s';"% ("2007-01-01 00:14:59","2007-03-31 23:59:59")
df = pd.read_sql(query, conn , index_col=['Timestamp'])

pred_no = 1 # power 1 Data/15min in 1Hr --> 60/15 = 4 and 1day = 4*24 = 96
j = 0
i = 0
d = len(df)/96 
day =0

conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

time_a = pd.date_range('2007-01-01 00:14:59', periods=d*96, freq='15T')
time_b = pd.date_range('2007-01-14 23:59:59', periods=(d*96)+1, freq='15T')

# set databases to empty 
query_empty = """truncate table prediction.pred_moving_totalpower""" 
c.execute(query_empty)

while (j < 96*d ) :    
    if (j%96 == 0):    
        day += 1
        print "__________________DAY:" , day
    
    print "\ndata at :" , j,">>>", time_b[j+1]
    query = "SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '%s'   AND TimeStamp <= '%s';"% (time_a[j],time_b[j])
    print query
    df = pd.read_sql(query, conn)
    conn.commit()
    data_y = df['active_power'].values.tolist()   
    ans_fiting = fittingparameter(data_y,j)
    pred_h = triple_exponential_smoothing(data_y, 96*7, ans_fiting[0], ans_fiting[1], ans_fiting[2],1)
    pred_data = pred_h[len(pred_h)-(pred_no):]
    c.execute("INSERT INTO prediction.pred_moving_totalpower (Timestamp, watt) VALUES ( %s, %s)",(time_b[j+1],abs(pred_data[0])))
    conn.commit()
    j += 1
print "DONE!!"
# Out:
# __________________DAY: 1
#
# data at : 0 >>> 2007-01-15 00:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-14 23:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 00:14:59' ;
# 11 121 1331
# 0.0006796498597 0.2 0.1 0.7
#
# data at : 1 >>> 2007-01-15 00:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:29:59'   AND TimeStamp <= '2007-01-15 00:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 00:29:59' ;
# 11 121 1331
# 0.316635767787 0.4 0.6 1.0
#
# data at : 2 >>> 2007-01-15 00:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:44:59'   AND TimeStamp <= '2007-01-15 00:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 00:44:59' ;
# 11 121 1331
# 1.29236349558 0.1 0.0 0.6
#
# data at : 3 >>> 2007-01-15 00:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:59:59'   AND TimeStamp <= '2007-01-15 00:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 00:59:59' ;
# 11 121 1331
# 0.00352209937255 0.3 0.5 0.7
#
# data at : 4 >>> 2007-01-15 01:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 01:14:59'   AND TimeStamp <= '2007-01-15 00:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 01:14:59' ;
# 11 121 1331
# 0.00530768090844 0.2 0.7 0.7
#
# data at : 5 >>> 2007-01-15 01:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 01:29:59'   AND TimeStamp <= '2007-01-15 01:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 01:29:59' ;
# 11 121 1331
# 0.0724516490547 0.4 1.0 1.0
#
# data at : 6 >>> 2007-01-15 01:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 01:44:59'   AND TimeStamp <= '2007-01-15 01:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 01:44:59' ;
# 11 121 1331
# 8.63699273671 0.2 1.0 0.3
#
# data at : 7 >>> 2007-01-15 01:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 01:59:59'   AND TimeStamp <= '2007-01-15 01:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 01:59:59' ;
# 11 121 1331
# 0.090251945758 0.1 0.7 0.8
#
# data at : 8 >>> 2007-01-15 02:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 02:14:59'   AND TimeStamp <= '2007-01-15 01:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 02:14:59' ;
# 11 121 1331
# 2.93009310041 0.2 0.6 0.8
#
# data at : 9 >>> 2007-01-15 02:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 02:29:59'   AND TimeStamp <= '2007-01-15 02:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 02:29:59' ;
# 11 121 1331
# 3746.71946529 0.1 0.6 1.0
#
# data at : 10 >>> 2007-01-15 02:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 02:44:59'   AND TimeStamp <= '2007-01-15 02:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 02:44:59' ;
# 11 121 1331
# 0.59325643089 0.1 0.6 0.8
#
# data at : 11 >>> 2007-01-15 02:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 02:59:59'   AND TimeStamp <= '2007-01-15 02:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 02:59:59' ;
# 11 121 1331
# 1.78704060739 0.4 0.7 1.0
#
# data at : 12 >>> 2007-01-15 03:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 03:14:59'   AND TimeStamp <= '2007-01-15 02:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 03:14:59' ;
# 11 121 1331
# 0.551019382528 0.3 0.9 0.6
#
# data at : 13 >>> 2007-01-15 03:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 03:29:59'   AND TimeStamp <= '2007-01-15 03:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 03:29:59' ;
# 11 121 1331
# 0.0413018147741 0.2 0.6 1.0
#
# data at : 14 >>> 2007-01-15 03:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 03:44:59'   AND TimeStamp <= '2007-01-15 03:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 03:44:59' ;
# 11 121 1331
# 1.96803198769 0.1 0.8 0.5
#
# data at : 15 >>> 2007-01-15 03:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 03:59:59'   AND TimeStamp <= '2007-01-15 03:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 03:59:59' ;
# 11 121 1331
# 0.117060479912 0.2 0.5 0.9
#
# data at : 16 >>> 2007-01-15 04:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 04:14:59'   AND TimeStamp <= '2007-01-15 03:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 04:14:59' ;
# 11 121 1331
# 1.6162228955e-05 0.1 0.9 0.5
#
# data at : 17 >>> 2007-01-15 04:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 04:29:59'   AND TimeStamp <= '2007-01-15 04:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 04:29:59' ;
# 11 121 1331
# 0.039625862726 0.1 1.0 0.9
#
# data at : 18 >>> 2007-01-15 04:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 04:44:59'   AND TimeStamp <= '2007-01-15 04:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 04:44:59' ;
# 11 121 1331
# 0.992920587036 0.2 0.1 1.0
#
# data at : 19 >>> 2007-01-15 04:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 04:59:59'   AND TimeStamp <= '2007-01-15 04:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 04:59:59' ;
# 11 121 1331
# 0.868108423946 0.2 0.8 1.0
#
# data at : 20 >>> 2007-01-15 05:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 05:14:59'   AND TimeStamp <= '2007-01-15 04:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 05:14:59' ;
# 11 121 1331
# 86.872671708 0.1 0.4 0.3
#
# data at : 21 >>> 2007-01-15 05:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 05:29:59'   AND TimeStamp <= '2007-01-15 05:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 05:29:59' ;
# 11 121 1331
# 0.126909570724 0.3 0.9 1.0
#
# data at : 22 >>> 2007-01-15 05:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 05:44:59'   AND TimeStamp <= '2007-01-15 05:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 05:44:59' ;
# 11 121 1331
# 0.0337363493577 0.1 0.4 0.3
#
# data at : 23 >>> 2007-01-15 05:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 05:59:59'   AND TimeStamp <= '2007-01-15 05:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 05:59:59' ;
# 11 121 1331
# 0.0452136323874 0.3 0.4 0.7
#
# data at : 24 >>> 2007-01-15 06:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 06:14:59'   AND TimeStamp <= '2007-01-15 05:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 06:14:59' ;
# 11 121 1331
# 0.173785401368 0.3 1.0 1.0
#
# data at : 25 >>> 2007-01-15 06:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 06:29:59'   AND TimeStamp <= '2007-01-15 06:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 06:29:59' ;
# 11 121 1331
# 0.783344989552 0.2 0.7 1.0
#
# data at : 26 >>> 2007-01-15 06:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 06:44:59'   AND TimeStamp <= '2007-01-15 06:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 06:44:59' ;
# 11 121 1331
# 4.85536945397 0.2 0.0 0.8
#
# data at : 27 >>> 2007-01-15 06:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 06:59:59'   AND TimeStamp <= '2007-01-15 06:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 06:59:59' ;
# 11 121 1331
# 176.873208304 0.1 0.3 0.8
#
# data at : 28 >>> 2007-01-15 07:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 07:14:59'   AND TimeStamp <= '2007-01-15 06:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 07:14:59' ;
# 11 121 1331
# 0.0171203768051 0.1 0.4 0.9
#
# data at : 29 >>> 2007-01-15 07:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 07:29:59'   AND TimeStamp <= '2007-01-15 07:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 07:29:59' ;
# 11 121 1331
# 0.000278672504807 0.3 0.6 0.2
#
# data at : 30 >>> 2007-01-15 07:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 07:44:59'   AND TimeStamp <= '2007-01-15 07:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 07:44:59' ;
# 11 121 1331
# 0.060307575749 0.6 0.5 0.4
#
# data at : 31 >>> 2007-01-15 07:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 07:59:59'   AND TimeStamp <= '2007-01-15 07:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 07:59:59' ;
# 11 121 1331
# 0.0189180336536 0.1 1.0 0.1
#
# data at : 32 >>> 2007-01-15 08:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 08:14:59'   AND TimeStamp <= '2007-01-15 07:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 08:14:59' ;
# 11 121 1331
# 0.000649280025059 0.8 0.2 1.0
#
# data at : 33 >>> 2007-01-15 08:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 08:29:59'   AND TimeStamp <= '2007-01-15 08:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 08:29:59' ;
# 11 121 1331
# 0.000450749894278 0.5 0.3 0.9
#
# data at : 34 >>> 2007-01-15 08:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 08:44:59'   AND TimeStamp <= '2007-01-15 08:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 08:44:59' ;
# 11 121 1331
# 1884.53237588 0.0 0.0 1.0
#
# data at : 35 >>> 2007-01-15 08:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 08:59:59'   AND TimeStamp <= '2007-01-15 08:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 08:59:59' ;
# 11 121 1331
# 0.00047831039904 0.6 0.0 0.1
#
# data at : 36 >>> 2007-01-15 09:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 09:14:59'   AND TimeStamp <= '2007-01-15 08:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 09:14:59' ;
# 11 121 1331
# 0.180955215395 0.2 0.3 0.1
#
# data at : 37 >>> 2007-01-15 09:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 09:29:59'   AND TimeStamp <= '2007-01-15 09:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 09:29:59' ;
# 11 121 1331
# 31050.7949821 0.1 0.6 1.0
#
# data at : 38 >>> 2007-01-15 09:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 09:44:59'   AND TimeStamp <= '2007-01-15 09:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 09:44:59' ;
# 11 121 1331
# 1.47541709199 0.8 1.0 1.0
#
# data at : 39 >>> 2007-01-15 09:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 09:59:59'   AND TimeStamp <= '2007-01-15 09:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 09:59:59' ;
# 11 121 1331
# 5.11745933679e-05 0.8 0.9 1.0
#
# data at : 40 >>> 2007-01-15 10:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 10:14:59'   AND TimeStamp <= '2007-01-15 09:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 10:14:59' ;
# 11 121 1331
# 0.00405997160268 0.7 0.4 0.0
#
# data at : 41 >>> 2007-01-15 10:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 10:29:59'   AND TimeStamp <= '2007-01-15 10:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 10:29:59' ;
# 11 121 1331
# 1.39379755667 0.7 1.0 1.0
#
# data at : 42 >>> 2007-01-15 10:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 10:44:59'   AND TimeStamp <= '2007-01-15 10:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 10:44:59' ;
# 11 121 1331
# 1.38013761834 0.1 0.9 0.9
#
# data at : 43 >>> 2007-01-15 10:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 10:59:59'   AND TimeStamp <= '2007-01-15 10:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 10:59:59' ;
# 11 121 1331
# 0.646154814552 0.1 0.7 0.6
#
# data at : 44 >>> 2007-01-15 11:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 11:14:59'   AND TimeStamp <= '2007-01-15 10:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 11:14:59' ;
# 11 121 1331
# 0.173732656136 0.6 0.9 0.7
#
# data at : 45 >>> 2007-01-15 11:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 11:29:59'   AND TimeStamp <= '2007-01-15 11:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 11:29:59' ;
# 11 121 1331
# 0.35644680178 0.1 0.6 0.6
#
# data at : 46 >>> 2007-01-15 11:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 11:44:59'   AND TimeStamp <= '2007-01-15 11:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 11:44:59' ;
# 11 121 1331
# 0.00751261245486 0.5 0.7 0.7
#
# data at : 47 >>> 2007-01-15 11:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 11:59:59'   AND TimeStamp <= '2007-01-15 11:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 11:59:59' ;
# 11 121 1331
# 0.150338792309 0.7 1.0 0.0
#
# data at : 48 >>> 2007-01-15 12:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 12:14:59'   AND TimeStamp <= '2007-01-15 11:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 12:14:59' ;
# 11 121 1331
# 0.0185710725187 0.2 0.4 0.2
#
# data at : 49 >>> 2007-01-15 12:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 12:29:59'   AND TimeStamp <= '2007-01-15 12:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 12:29:59' ;
# 11 121 1331
# 1.45458832316 0.1 0.6 0.3
#
# data at : 50 >>> 2007-01-15 12:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 12:44:59'   AND TimeStamp <= '2007-01-15 12:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 12:44:59' ;
# 11 121 1331
# 0.0605371131717 0.0 0.0 0.7
#
# data at : 51 >>> 2007-01-15 12:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 12:59:59'   AND TimeStamp <= '2007-01-15 12:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 12:59:59' ;
# 11 121 1331
# 69.1643479853 0.0 0.0 1.0
#
# data at : 52 >>> 2007-01-15 13:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 13:14:59'   AND TimeStamp <= '2007-01-15 12:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 13:14:59' ;
# 11 121 1331
# 0.424722394018 0.0 0.0 1.0
#
# data at : 53 >>> 2007-01-15 13:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 13:29:59'   AND TimeStamp <= '2007-01-15 13:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 13:29:59' ;
# 11 121 1331
# 7.42741193817 0.4 1.0 0.7
#
# data at : 54 >>> 2007-01-15 13:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 13:44:59'   AND TimeStamp <= '2007-01-15 13:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 13:44:59' ;
# 11 121 1331
# 1.83861361724 0.3 0.7 1.0
#
# data at : 55 >>> 2007-01-15 13:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 13:59:59'   AND TimeStamp <= '2007-01-15 13:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 13:59:59' ;
# 11 121 1331
# 0.0271489882297 0.3 0.6 0.6
#
# data at : 56 >>> 2007-01-15 14:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 14:14:59'   AND TimeStamp <= '2007-01-15 13:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 14:14:59' ;
# 11 121 1331
# 679.106447225 0.3 1.0 1.0
#
# data at : 57 >>> 2007-01-15 14:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 14:29:59'   AND TimeStamp <= '2007-01-15 14:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 14:29:59' ;
# 11 121 1331
# 0.34191656671 0.1 0.1 0.4
#
# data at : 58 >>> 2007-01-15 14:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 14:44:59'   AND TimeStamp <= '2007-01-15 14:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 14:44:59' ;
# 11 121 1331
# 0.0655624693783 0.9 1.0 0.9
#
# data at : 59 >>> 2007-01-15 14:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 14:59:59'   AND TimeStamp <= '2007-01-15 14:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 14:59:59' ;
# 11 121 1331
# 0.036670467226 0.3 0.8 0.7
#
# data at : 60 >>> 2007-01-15 15:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 15:14:59'   AND TimeStamp <= '2007-01-15 14:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 15:14:59' ;
# 11 121 1331
# 0.00171830642253 0.2 0.2 1.0
#
# data at : 61 >>> 2007-01-15 15:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 15:29:59'   AND TimeStamp <= '2007-01-15 15:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 15:29:59' ;
# 11 121 1331
# 0.00760546089775 0.1 0.6 0.3
#
# data at : 62 >>> 2007-01-15 15:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 15:44:59'   AND TimeStamp <= '2007-01-15 15:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 15:44:59' ;
# 11 121 1331
# 2.31960604666e-05 0.3 1.0 0.3
#
# data at : 63 >>> 2007-01-15 15:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 15:59:59'   AND TimeStamp <= '2007-01-15 15:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 15:59:59' ;
# 11 121 1331
# 0.0132539183044 0.3 1.0 0.2
#
# data at : 64 >>> 2007-01-15 16:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 16:14:59'   AND TimeStamp <= '2007-01-15 15:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 16:14:59' ;
# 11 121 1331
# 0.0523076780296 0.4 0.5 0.9
#
# data at : 65 >>> 2007-01-15 16:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 16:29:59'   AND TimeStamp <= '2007-01-15 16:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 16:29:59' ;
# 11 121 1331
# 0.000160683400607 0.9 0.4 0.0
#
# data at : 66 >>> 2007-01-15 16:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 16:44:59'   AND TimeStamp <= '2007-01-15 16:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 16:44:59' ;
# 11 121 1331
# 6.0067226808e-05 0.1 0.8 0.2
#
# data at : 67 >>> 2007-01-15 16:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 16:59:59'   AND TimeStamp <= '2007-01-15 16:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 16:59:59' ;
# 11 121 1331
# 0.0135723278886 0.3 0.1 0.1
#
# data at : 68 >>> 2007-01-15 17:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 17:14:59'   AND TimeStamp <= '2007-01-15 16:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 17:14:59' ;
# 11 121 1331
# 0.00324890575401 0.9 0.5 0.6
#
# data at : 69 >>> 2007-01-15 17:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 17:29:59'   AND TimeStamp <= '2007-01-15 17:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 17:29:59' ;
# 11 121 1331
# 3.50550934738e-05 0.3 0.9 1.0
#
# data at : 70 >>> 2007-01-15 17:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 17:44:59'   AND TimeStamp <= '2007-01-15 17:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 17:44:59' ;
# 11 121 1331
# 6.6657627008 0.0 0.0 1.0
#
# data at : 71 >>> 2007-01-15 17:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 17:59:59'   AND TimeStamp <= '2007-01-15 17:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 17:59:59' ;
# 11 121 1331
# 0.00540036489887 0.6 0.8 0.5
#
# data at : 72 >>> 2007-01-15 18:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 18:14:59'   AND TimeStamp <= '2007-01-15 17:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 18:14:59' ;
# 11 121 1331
# 0.00148939831263 0.3 0.5 0.8
#
# data at : 73 >>> 2007-01-15 18:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 18:29:59'   AND TimeStamp <= '2007-01-15 18:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 18:29:59' ;
# 11 121 1331
# 11.4810175201 0.1 0.7 0.6
#
# data at : 74 >>> 2007-01-15 18:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 18:44:59'   AND TimeStamp <= '2007-01-15 18:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 18:44:59' ;
# 11 121 1331
# 19.4341557673 0.1 0.1 0.1
#
# data at : 75 >>> 2007-01-15 18:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 18:59:59'   AND TimeStamp <= '2007-01-15 18:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 18:59:59' ;
# 11 121 1331
# 0.102331980126 0.9 0.9 0.5
#
# data at : 76 >>> 2007-01-15 19:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 19:14:59'   AND TimeStamp <= '2007-01-15 18:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 19:14:59' ;
# 11 121 1331
# 0.0138156306897 0.8 0.3 0.2
#
# data at : 77 >>> 2007-01-15 19:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 19:29:59'   AND TimeStamp <= '2007-01-15 19:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 19:29:59' ;
# 11 121 1331
# 12.8926837909 0.1 0.5 1.0
#
# data at : 78 >>> 2007-01-15 19:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 19:44:59'   AND TimeStamp <= '2007-01-15 19:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 19:44:59' ;
# 11 121 1331
# 153541.952527 0.0 0.0 1.0
#
# data at : 79 >>> 2007-01-15 19:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 19:59:59'   AND TimeStamp <= '2007-01-15 19:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 19:59:59' ;
# 11 121 1331
# 1.01092381273 0.5 0.9 0.7
#
# data at : 80 >>> 2007-01-15 20:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 20:14:59'   AND TimeStamp <= '2007-01-15 19:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 20:14:59' ;
# 11 121 1331
# 0.00369923583334 0.6 0.8 0.6
#
# data at : 81 >>> 2007-01-15 20:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 20:29:59'   AND TimeStamp <= '2007-01-15 20:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 20:29:59' ;
# 11 121 1331
# 4.62892092099 0.4 0.0 0.0
#
# data at : 82 >>> 2007-01-15 20:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 20:44:59'   AND TimeStamp <= '2007-01-15 20:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 20:44:59' ;
# 11 121 1331
# 0.0833025791699 0.4 0.8 0.8
#
# data at : 83 >>> 2007-01-15 20:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 20:59:59'   AND TimeStamp <= '2007-01-15 20:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 20:59:59' ;
# 11 121 1331
# 0.0291902599507 0.6 0.2 0.1
#
# data at : 84 >>> 2007-01-15 21:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 21:14:59'   AND TimeStamp <= '2007-01-15 20:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 21:14:59' ;
# 11 121 1331
# 0.0026070233325 0.1 0.9 0.0
#
# data at : 85 >>> 2007-01-15 21:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 21:29:59'   AND TimeStamp <= '2007-01-15 21:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 21:29:59' ;
# 11 121 1331
# 0.489844444751 0.1 0.2 0.6
#
# data at : 86 >>> 2007-01-15 21:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 21:44:59'   AND TimeStamp <= '2007-01-15 21:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 21:44:59' ;
# 11 121 1331
# 0.365610856279 0.6 0.8 0.8
#
# data at : 87 >>> 2007-01-15 21:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 21:59:59'   AND TimeStamp <= '2007-01-15 21:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 21:59:59' ;
# 11 121 1331
# 0.0497030344626 0.6 0.6 1.0
#
# data at : 88 >>> 2007-01-15 22:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 22:14:59'   AND TimeStamp <= '2007-01-15 21:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 22:14:59' ;
# 11 121 1331
# 0.926822649378 0.4 1.0 0.5
#
# data at : 89 >>> 2007-01-15 22:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 22:29:59'   AND TimeStamp <= '2007-01-15 22:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 22:29:59' ;
# 11 121 1331
# 0.148974979642 0.3 1.0 0.4
#
# data at : 90 >>> 2007-01-15 22:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 22:44:59'   AND TimeStamp <= '2007-01-15 22:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 22:44:59' ;
# 11 121 1331
# 6.46030661725 0.5 0.7 0.8
#
# data at : 91 >>> 2007-01-15 22:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 22:59:59'   AND TimeStamp <= '2007-01-15 22:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 22:59:59' ;
# 11 121 1331
# 3.0042375394 0.4 0.4 0.8
#
# data at : 92 >>> 2007-01-15 23:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 23:14:59'   AND TimeStamp <= '2007-01-15 22:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 23:14:59' ;
# 11 121 1331
# 5.92851426589 0.3 0.6 0.8
#
# data at : 93 >>> 2007-01-15 23:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 23:29:59'   AND TimeStamp <= '2007-01-15 23:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 23:29:59' ;
# 11 121 1331
# 0.255843549441 0.2 0.9 0.7
#
# data at : 94 >>> 2007-01-15 23:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 23:44:59'   AND TimeStamp <= '2007-01-15 23:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 23:44:59' ;
# 11 121 1331
# 0.00675077388517 0.8 0.8 0.5
#
# data at : 95 >>> 2007-01-15 23:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 23:59:59'   AND TimeStamp <= '2007-01-15 23:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 23:59:59' ;
# 11 121 1331
# 0.0112201822396 0.6 1.0 0.6
# __________________DAY: 2
#
# data at : 96 >>> 2007-01-16 00:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 00:14:59'   AND TimeStamp <= '2007-01-15 23:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 00:14:59' ;
# 11 121 1331
# 575.04083071 0.1 0.0 0.0
#
# data at : 97 >>> 2007-01-16 00:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 00:29:59'   AND TimeStamp <= '2007-01-16 00:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 00:29:59' ;
# 11 121 1331
# 0.00460549576777 0.7 0.4 0.7
#
# data at : 98 >>> 2007-01-16 00:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 00:44:59'   AND TimeStamp <= '2007-01-16 00:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 00:44:59' ;
# 11 121 1331
# 0.00567287099756 1.0 0.9 0.0
#
# data at : 99 >>> 2007-01-16 00:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 00:59:59'   AND TimeStamp <= '2007-01-16 00:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 00:59:59' ;
# 11 121 1331
# 0.00316461454837 0.5 0.0 0.2
#
# data at : 100 >>> 2007-01-16 01:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 01:14:59'   AND TimeStamp <= '2007-01-16 00:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 01:14:59' ;
# 11 121 1331
# 0.015989945394 0.5 0.8 0.8
#
# data at : 101 >>> 2007-01-16 01:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 01:29:59'   AND TimeStamp <= '2007-01-16 01:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 01:29:59' ;
# 11 121 1331
# 0.00115465786252 0.6 0.6 0.0
#
# data at : 102 >>> 2007-01-16 01:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 01:44:59'   AND TimeStamp <= '2007-01-16 01:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 01:44:59' ;
# 11 121 1331
# 1.47624808841e-06 0.9 0.1 0.6
#
# data at : 103 >>> 2007-01-16 01:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 01:59:59'   AND TimeStamp <= '2007-01-16 01:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 01:59:59' ;
# 11 121 1331
# 0.000767627630883 0.4 0.4 0.8
#
# data at : 104 >>> 2007-01-16 02:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 02:14:59'   AND TimeStamp <= '2007-01-16 01:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 02:14:59' ;
# 11 121 1331
# 5.24580504152e-05 0.9 0.4 0.7
#
# data at : 105 >>> 2007-01-16 02:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 02:29:59'   AND TimeStamp <= '2007-01-16 02:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 02:29:59' ;
# 11 121 1331
# 0.000229380055474 0.7 0.7 0.4
#
# data at : 106 >>> 2007-01-16 02:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 02:44:59'   AND TimeStamp <= '2007-01-16 02:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 02:44:59' ;
# 11 121 1331
# 0.0411671055866 0.6 0.1 0.2
#
# data at : 107 >>> 2007-01-16 02:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 02:59:59'   AND TimeStamp <= '2007-01-16 02:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 02:59:59' ;
# 11 121 1331
# 0.012619915134 0.3 0.9 0.6
#
# data at : 108 >>> 2007-01-16 03:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 03:14:59'   AND TimeStamp <= '2007-01-16 02:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 03:14:59' ;
# 11 121 1331
# 0.000348070529317 0.5 0.7 0.5
#
# data at : 109 >>> 2007-01-16 03:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 03:29:59'   AND TimeStamp <= '2007-01-16 03:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 03:29:59' ;
# 11 121 1331
# 0.11639758138 0.2 0.4 0.6
#
# data at : 110 >>> 2007-01-16 03:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 03:44:59'   AND TimeStamp <= '2007-01-16 03:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 03:44:59' ;
# 11 121 1331
# 0.000466377144406 0.3 0.7 0.7
#
# data at : 111 >>> 2007-01-16 03:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 03:59:59'   AND TimeStamp <= '2007-01-16 03:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 03:59:59' ;
# 11 121 1331
# 0.201057544281 0.1 0.8 0.2
#
# data at : 112 >>> 2007-01-16 04:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 04:14:59'   AND TimeStamp <= '2007-01-16 03:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 04:14:59' ;
# 11 121 1331
# 1.49538013773 0.0 0.0 0.0
#
# data at : 113 >>> 2007-01-16 04:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 04:29:59'   AND TimeStamp <= '2007-01-16 04:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 04:29:59' ;
# 11 121 1331
# 0.0159812112713 0.2 0.0 0.8
#
# data at : 114 >>> 2007-01-16 04:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 04:44:59'   AND TimeStamp <= '2007-01-16 04:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 04:44:59' ;
# 11 121 1331
# 1.17197240235 0.1 1.0 0.3
#
# data at : 115 >>> 2007-01-16 04:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 04:59:59'   AND TimeStamp <= '2007-01-16 04:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 04:59:59' ;
# 11 121 1331
# 2.21632765598e-06 0.1 0.8 0.3
#
# data at : 116 >>> 2007-01-16 05:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 05:14:59'   AND TimeStamp <= '2007-01-16 04:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 05:14:59' ;
# 11 121 1331
# 0.259427087129 0.2 0.9 0.6
#
# data at : 117 >>> 2007-01-16 05:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 05:29:59'   AND TimeStamp <= '2007-01-16 05:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 05:29:59' ;
# 11 121 1331
# 1.17742442793 0.1 0.4 0.9
#
# data at : 118 >>> 2007-01-16 05:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 05:44:59'   AND TimeStamp <= '2007-01-16 05:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 05:44:59' ;
# 11 121 1331
# 0.0046942495289 0.8 0.4 0.7
#
# data at : 119 >>> 2007-01-16 05:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 05:59:59'   AND TimeStamp <= '2007-01-16 05:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 05:59:59' ;
# 11 121 1331
# 0.00139305958828 0.6 0.7 0.0
#
# data at : 120 >>> 2007-01-16 06:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 06:14:59'   AND TimeStamp <= '2007-01-16 05:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 06:14:59' ;
# 11 121 1331
# 0.00018743402243 0.7 0.8 0.6
#
# data at : 121 >>> 2007-01-16 06:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 06:29:59'   AND TimeStamp <= '2007-01-16 06:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 06:29:59' ;
# 11 121 1331
# 0.000216043839788 0.4 0.0 0.4
#
# data at : 122 >>> 2007-01-16 06:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 06:44:59'   AND TimeStamp <= '2007-01-16 06:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 06:44:59' ;
# 11 121 1331
# 0.307885299509 0.3 0.8 0.7
#
# data at : 123 >>> 2007-01-16 06:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 06:59:59'   AND TimeStamp <= '2007-01-16 06:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 06:59:59' ;
# 11 121 1331
# 0.0374053346667 0.2 0.6 0.5
#
# data at : 124 >>> 2007-01-16 07:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 07:14:59'   AND TimeStamp <= '2007-01-16 06:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 07:14:59' ;
# 11 121 1331
# 0.0285116888821 0.1 0.6 0.6
#
# data at : 125 >>> 2007-01-16 07:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 07:29:59'   AND TimeStamp <= '2007-01-16 07:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 07:29:59' ;
# 11 121 1331
# 179.92030033 0.1 0.4 0.8
#
# data at : 126 >>> 2007-01-16 07:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 07:44:59'   AND TimeStamp <= '2007-01-16 07:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 07:44:59' ;
# 11 121 1331
# 0.67532768763 0.1 0.4 0.9
#
# data at : 127 >>> 2007-01-16 07:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 07:59:59'   AND TimeStamp <= '2007-01-16 07:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 07:59:59' ;
# 11 121 1331
# 0.0124239371327 0.4 0.5 1.0
#
# data at : 128 >>> 2007-01-16 08:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 08:14:59'   AND TimeStamp <= '2007-01-16 07:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 08:14:59' ;
# 11 121 1331
# 2.18122987794 0.1 0.9 0.2
#
# data at : 129 >>> 2007-01-16 08:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 08:29:59'   AND TimeStamp <= '2007-01-16 08:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 08:29:59' ;
# 11 121 1331
# 7.89461800421 0.1 1.0 0.6
#
# data at : 130 >>> 2007-01-16 08:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 08:44:59'   AND TimeStamp <= '2007-01-16 08:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 08:44:59' ;
# 11 121 1331
# 4.73496739918e-05 0.5 0.0 0.3
#
# data at : 131 >>> 2007-01-16 08:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 08:59:59'   AND TimeStamp <= '2007-01-16 08:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 08:59:59' ;
# 11 121 1331
# 0.00637858237057 0.5 0.5 0.5
#
# data at : 132 >>> 2007-01-16 09:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 09:14:59'   AND TimeStamp <= '2007-01-16 08:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 09:14:59' ;
# 11 121 1331
# 0.000226426567907 0.2 0.4 0.5
#
# data at : 133 >>> 2007-01-16 09:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 09:29:59'   AND TimeStamp <= '2007-01-16 09:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 09:29:59' ;
# 11 121 1331
# 0.00421955275656 0.1 0.8 0.1
#
# data at : 134 >>> 2007-01-16 09:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 09:44:59'   AND TimeStamp <= '2007-01-16 09:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 09:44:59' ;
# 11 121 1331
# 0.357125178733 0.1 0.2 0.4
#
# data at : 135 >>> 2007-01-16 09:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 09:59:59'   AND TimeStamp <= '2007-01-16 09:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 09:59:59' ;
# 11 121 1331
# 165.056544426 0.1 0.9 1.0
#
# data at : 136 >>> 2007-01-16 10:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 10:14:59'   AND TimeStamp <= '2007-01-16 09:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 10:14:59' ;
# 11 121 1331
# 0.00107485439015 0.3 0.1 0.8
#
# data at : 137 >>> 2007-01-16 10:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 10:29:59'   AND TimeStamp <= '2007-01-16 10:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 10:29:59' ;
# 11 121 1331
# 0.000272386087238 0.8 0.4 0.6
#
# data at : 138 >>> 2007-01-16 10:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 10:44:59'   AND TimeStamp <= '2007-01-16 10:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 10:44:59' ;
# 11 121 1331
# 0.00105775209552 0.7 1.0 0.5
#
# data at : 139 >>> 2007-01-16 10:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 10:59:59'   AND TimeStamp <= '2007-01-16 10:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 10:59:59' ;
# 11 121 1331
# 0.00537411790949 0.1 0.1 0.1
#
# data at : 140 >>> 2007-01-16 11:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 11:14:59'   AND TimeStamp <= '2007-01-16 10:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 11:14:59' ;
# 11 121 1331
# 0.00351024673438 0.2 0.0 0.4
#
# data at : 141 >>> 2007-01-16 11:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 11:29:59'   AND TimeStamp <= '2007-01-16 11:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 11:29:59' ;
# 11 121 1331
# 0.052086447988 0.2 0.6 0.4
#
# data at : 142 >>> 2007-01-16 11:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 11:44:59'   AND TimeStamp <= '2007-01-16 11:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 11:44:59' ;
# 11 121 1331
# 0.521320023872 0.1 0.7 0.7
#
# data at : 143 >>> 2007-01-16 11:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 11:59:59'   AND TimeStamp <= '2007-01-16 11:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 11:59:59' ;
# 11 121 1331
# 58.6525070398 0.9 1.0 1.0
#
# data at : 144 >>> 2007-01-16 12:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 12:14:59'   AND TimeStamp <= '2007-01-16 11:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 12:14:59' ;
# 11 121 1331
# 0.00201486451975 0.7 0.6 0.4
#
# data at : 145 >>> 2007-01-16 12:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 12:29:59'   AND TimeStamp <= '2007-01-16 12:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 12:29:59' ;
# 11 121 1331
# 152436.362369 0.3 1.0 1.0
#
# data at : 146 >>> 2007-01-16 12:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 12:44:59'   AND TimeStamp <= '2007-01-16 12:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 12:44:59' ;
# 11 121 1331
# 0.102867219249 0.9 0.1 0.4
#
# data at : 147 >>> 2007-01-16 12:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 12:59:59'   AND TimeStamp <= '2007-01-16 12:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 12:59:59' ;
# 11 121 1331
# 0.117062168915 0.9 0.1 0.9
#
# data at : 148 >>> 2007-01-16 13:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 13:14:59'   AND TimeStamp <= '2007-01-16 12:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 13:14:59' ;
# 11 121 1331
# 0.0146731946246 0.6 0.9 0.7
#
# data at : 149 >>> 2007-01-16 13:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 13:29:59'   AND TimeStamp <= '2007-01-16 13:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 13:29:59' ;
# 11 121 1331
# 0.303759700891 0.6 0.1 0.0
#
# data at : 150 >>> 2007-01-16 13:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 13:44:59'   AND TimeStamp <= '2007-01-16 13:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 13:44:59' ;
# 11 121 1331
# 0.351200518738 0.3 0.7 0.1
#
# data at : 151 >>> 2007-01-16 13:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 13:59:59'   AND TimeStamp <= '2007-01-16 13:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 13:59:59' ;
# 11 121 1331
# 4.08888143705 0.2 0.6 0.1
#
# data at : 152 >>> 2007-01-16 14:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 14:14:59'   AND TimeStamp <= '2007-01-16 13:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 14:14:59' ;
# 11 121 1331
# 0.481240968686 0.1 0.9 0.6
#
# data at : 153 >>> 2007-01-16 14:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 14:29:59'   AND TimeStamp <= '2007-01-16 14:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 14:29:59' ;
# 11 121 1331
# 1.04119381055 0.1 0.2 0.8
#
# data at : 154 >>> 2007-01-16 14:44:59
# ...
# 11 121 1331
# 7.51539556777 0.2 0.3 0.9
#
# data at : 8589 >>> 2007-04-14 11:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 11:29:59'   AND TimeStamp <= '2007-04-14 11:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 11:29:59' ;
# 11 121 1331
# 1.63286079017 0.1 0.6 0.5
#
# data at : 8590 >>> 2007-04-14 11:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 11:44:59'   AND TimeStamp <= '2007-04-14 11:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 11:44:59' ;
# 11 121 1331
# 3210.39619151 0.6 1.0 1.0
#
# data at : 8591 >>> 2007-04-14 11:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 11:59:59'   AND TimeStamp <= '2007-04-14 11:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 11:59:59' ;
# 11 121 1331
# 0.00237256157663 0.7 0.1 0.7
#
# data at : 8592 >>> 2007-04-14 12:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 12:14:59'   AND TimeStamp <= '2007-04-14 11:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 12:14:59' ;
# 11 121 1331
# 0.00269593926254 0.9 1.0 0.0
#
# data at : 8593 >>> 2007-04-14 12:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 12:29:59'   AND TimeStamp <= '2007-04-14 12:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 12:29:59' ;
# 11 121 1331
# 0.0196255981025 0.7 0.0 0.1
#
# data at : 8594 >>> 2007-04-14 12:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 12:44:59'   AND TimeStamp <= '2007-04-14 12:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 12:44:59' ;
# 11 121 1331
# 0.0682404453846 0.3 0.3 0.5
#
# data at : 8595 >>> 2007-04-14 12:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 12:59:59'   AND TimeStamp <= '2007-04-14 12:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 12:59:59' ;
# 11 121 1331
# 3.79759459091 0.3 0.0 0.6
#
# data at : 8596 >>> 2007-04-14 13:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 13:14:59'   AND TimeStamp <= '2007-04-14 12:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 13:14:59' ;
# 11 121 1331
# 0.022342042549 0.7 1.0 0.9
#
# data at : 8597 >>> 2007-04-14 13:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 13:29:59'   AND TimeStamp <= '2007-04-14 13:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 13:29:59' ;
# 11 121 1331
# 2.9128572264 0.2 0.0 0.8
#
# data at : 8598 >>> 2007-04-14 13:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 13:44:59'   AND TimeStamp <= '2007-04-14 13:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 13:44:59' ;
# 11 121 1331
# 0.340853257762 0.2 0.0 0.9
#
# data at : 8599 >>> 2007-04-14 13:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 13:59:59'   AND TimeStamp <= '2007-04-14 13:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 13:59:59' ;
# 11 121 1331
# 0.9376473977 0.0 0.0 0.0
#
# data at : 8600 >>> 2007-04-14 14:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 14:14:59'   AND TimeStamp <= '2007-04-14 13:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 14:14:59' ;
# 11 121 1331
# 1.5505230197 0.1 0.0 0.6
#
# data at : 8601 >>> 2007-04-14 14:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 14:29:59'   AND TimeStamp <= '2007-04-14 14:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 14:29:59' ;
# 11 121 1331
# 4.93658916147 0.3 1.0 0.6
#
# data at : 8602 >>> 2007-04-14 14:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 14:44:59'   AND TimeStamp <= '2007-04-14 14:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 14:44:59' ;
# 11 121 1331
# 3.72543140464 0.1 0.1 0.7
#
# data at : 8603 >>> 2007-04-14 14:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 14:59:59'   AND TimeStamp <= '2007-04-14 14:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 14:59:59' ;
# 11 121 1331
# 5.26086693538 0.2 0.8 1.0
#
# data at : 8604 >>> 2007-04-14 15:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 15:14:59'   AND TimeStamp <= '2007-04-14 14:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 15:14:59' ;
# 11 121 1331
# 0.72638628754 0.2 0.7 0.8
#
# data at : 8605 >>> 2007-04-14 15:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 15:29:59'   AND TimeStamp <= '2007-04-14 15:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 15:29:59' ;
# 11 121 1331
# 3.39775760238 0.1 0.8 0.7
#
# data at : 8606 >>> 2007-04-14 15:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 15:44:59'   AND TimeStamp <= '2007-04-14 15:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 15:44:59' ;
# 11 121 1331
# 50.5001478113 0.1 1.0 0.9
#
# data at : 8607 >>> 2007-04-14 15:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 15:59:59'   AND TimeStamp <= '2007-04-14 15:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 15:59:59' ;
# 11 121 1331
# 4.42380070648 0.1 1.0 0.8
#
# data at : 8608 >>> 2007-04-14 16:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 16:14:59'   AND TimeStamp <= '2007-04-14 15:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 16:14:59' ;
# 11 121 1331
# 0.0171792125193 0.2 0.6 1.0
#
# data at : 8609 >>> 2007-04-14 16:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 16:29:59'   AND TimeStamp <= '2007-04-14 16:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 16:29:59' ;
# 11 121 1331
# 1.9008111746 0.1 0.5 1.0
#
# data at : 8610 >>> 2007-04-14 16:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 16:44:59'   AND TimeStamp <= '2007-04-14 16:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 16:44:59' ;
# 11 121 1331
# 0.0496538526377 0.2 0.5 0.8
#
# data at : 8611 >>> 2007-04-14 16:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 16:59:59'   AND TimeStamp <= '2007-04-14 16:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 16:59:59' ;
# 11 121 1331
# 0.780706803828 0.1 0.8 0.4
#
# data at : 8612 >>> 2007-04-14 17:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 17:14:59'   AND TimeStamp <= '2007-04-14 16:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 17:14:59' ;
# 11 121 1331
# 0.0319749864389 0.1 0.7 0.2
#
# data at : 8613 >>> 2007-04-14 17:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 17:29:59'   AND TimeStamp <= '2007-04-14 17:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 17:29:59' ;
# 11 121 1331
# 0.0849844891646 0.2 0.2 0.6
#
# data at : 8614 >>> 2007-04-14 17:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 17:44:59'   AND TimeStamp <= '2007-04-14 17:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 17:44:59' ;
# 11 121 1331
# 0.000264589831073 0.1 0.8 0.5
#
# data at : 8615 >>> 2007-04-14 17:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 17:59:59'   AND TimeStamp <= '2007-04-14 17:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 17:59:59' ;
# 11 121 1331
# 4.70976743379 0.1 0.4 0.6
#
# data at : 8616 >>> 2007-04-14 18:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 18:14:59'   AND TimeStamp <= '2007-04-14 17:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 18:14:59' ;
# 11 121 1331
# 158.957808792 0.1 0.5 0.6
#
# data at : 8617 >>> 2007-04-14 18:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 18:29:59'   AND TimeStamp <= '2007-04-14 18:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 18:29:59' ;
# 11 121 1331
# 3.16240390607 0.1 0.5 0.8
#
# data at : 8618 >>> 2007-04-14 18:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 18:44:59'   AND TimeStamp <= '2007-04-14 18:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 18:44:59' ;
# 11 121 1331
# 8691.02884206 0.1 0.4 1.0
#
# data at : 8619 >>> 2007-04-14 18:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 18:59:59'   AND TimeStamp <= '2007-04-14 18:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 18:59:59' ;
# 11 121 1331
# 1948.72825102 0.1 0.4 1.0
#
# data at : 8620 >>> 2007-04-14 19:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 19:14:59'   AND TimeStamp <= '2007-04-14 18:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 19:14:59' ;
# 11 121 1331
# 0.0439974751808 0.3 0.2 0.9
#
# data at : 8621 >>> 2007-04-14 19:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 19:29:59'   AND TimeStamp <= '2007-04-14 19:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 19:29:59' ;
# 11 121 1331
# 0.0632222137042 0.2 0.9 0.6
#
# data at : 8622 >>> 2007-04-14 19:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 19:44:59'   AND TimeStamp <= '2007-04-14 19:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 19:44:59' ;
# 11 121 1331
# 0.0511425349056 0.3 0.4 0.9
#
# data at : 8623 >>> 2007-04-14 19:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 19:59:59'   AND TimeStamp <= '2007-04-14 19:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 19:59:59' ;
# 11 121 1331
# 2.77623546774 0.1 0.0 1.0
#
# data at : 8624 >>> 2007-04-14 20:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 20:14:59'   AND TimeStamp <= '2007-04-14 19:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 20:14:59' ;
# 11 121 1331
# 0.0679088155913 0.0 0.0 0.9
#
# data at : 8625 >>> 2007-04-14 20:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 20:29:59'   AND TimeStamp <= '2007-04-14 20:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 20:29:59' ;
# 11 121 1331
# 3.06496893863 0.1 0.4 1.0
#
# data at : 8626 >>> 2007-04-14 20:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 20:44:59'   AND TimeStamp <= '2007-04-14 20:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 20:44:59' ;
# 11 121 1331
# 39.7659253929 0.1 0.2 0.8
#
# data at : 8627 >>> 2007-04-14 20:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 20:59:59'   AND TimeStamp <= '2007-04-14 20:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 20:59:59' ;
# 11 121 1331
# 1.49621594589 0.1 0.9 0.7
#
# data at : 8628 >>> 2007-04-14 21:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 21:14:59'   AND TimeStamp <= '2007-04-14 20:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 21:14:59' ;
# 11 121 1331
# 0.155574132721 0.0 0.1 1.0
#
# data at : 8629 >>> 2007-04-14 21:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 21:29:59'   AND TimeStamp <= '2007-04-14 21:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 21:29:59' ;
# 11 121 1331
# 368186.397907 1.0 1.0 0.3
#
# data at : 8630 >>> 2007-04-14 21:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 21:44:59'   AND TimeStamp <= '2007-04-14 21:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 21:44:59' ;
# 11 121 1331
# 2.4166555353 0.8 0.5 0.8
#
# data at : 8631 >>> 2007-04-14 21:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 21:59:59'   AND TimeStamp <= '2007-04-14 21:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 21:59:59' ;
# 11 121 1331
# 0.00852369069314 0.7 0.4 0.2
#
# data at : 8632 >>> 2007-04-14 22:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 22:14:59'   AND TimeStamp <= '2007-04-14 21:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 22:14:59' ;
# 11 121 1331
# 0.122124254152 0.5 0.4 0.4
#
# data at : 8633 >>> 2007-04-14 22:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 22:29:59'   AND TimeStamp <= '2007-04-14 22:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 22:29:59' ;
# 11 121 1331
# 0.00368639207958 0.5 0.4 0.8
#
# data at : 8634 >>> 2007-04-14 22:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 22:44:59'   AND TimeStamp <= '2007-04-14 22:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 22:44:59' ;
# 11 121 1331
# 0.234943388571 0.2 0.4 0.3
#
# data at : 8635 >>> 2007-04-14 22:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 22:59:59'   AND TimeStamp <= '2007-04-14 22:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 22:59:59' ;
# 11 121 1331
# 0.00636393506319 0.9 0.7 0.3
#
# data at : 8636 >>> 2007-04-14 23:14:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 23:14:59'   AND TimeStamp <= '2007-04-14 22:59:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 23:14:59' ;
# 11 121 1331
# 0.000213999672836 0.3 0.6 0.9
#
# data at : 8637 >>> 2007-04-14 23:29:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 23:29:59'   AND TimeStamp <= '2007-04-14 23:14:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 23:29:59' ;
# 11 121 1331
# 0.0785234937046 0.2 0.0 0.3
#
# data at : 8638 >>> 2007-04-14 23:44:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 23:44:59'   AND TimeStamp <= '2007-04-14 23:29:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 23:44:59' ;
# 11 121 1331
# 0.000992036591836 0.1 0.0 0.7
#
# data at : 8639 >>> 2007-04-14 23:59:59
# SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 23:59:59'   AND TimeStamp <= '2007-04-14 23:44:59';
# SELECT active_power FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 23:59:59' ;
# 11 121 1331
# 1.39954909355 0.1 0.1 1.0
# DONE!!
