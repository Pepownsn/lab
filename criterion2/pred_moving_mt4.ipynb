# %% [markdown]
# ## PREDICTION MOVING METER4

# %%
#http://stackoverflow.com/questions/11845055/predicting-from-previous-datevalue-data
import matplotlib.pyplot as plt
import pandas as pd # v. 1.7
import MySQLdb
import numpy as np
import time
import sys
import datetime 
from datetime import datetime
from sympy import *
from sympy.solvers import solve
from sympy.parsing.sympy_parser import parse_expr
from sklearn.metrics import mean_absolute_error,mean_squared_error
import statistics 
# %matplotlib inline

import MySQLdb
def initial_trend(series, slen):
    sum = 0.0
    for i in range(slen):
        sum += float(series[i+slen] - series[i]) / slen
    return sum / slen

# >>> initial_trend(series, 12)
# -0.7847222222222222

def triple_exponential_smoothing(series, slen, alpha, beta, gamma, n_preds):
    result = []
    seasonals = initial_seasonal_components(series, slen)
    for i in range(len(series)+n_preds):
        if i == 0: # initial values
            smooth = series[0]
            trend = initial_trend(series, slen)
            result.append(series[0])
            continue
        if i >= len(series): # we are forecasting
            m = i - len(series) + 1
            result.append((smooth + m*trend) + seasonals[i%slen])
        else:
            val = series[i]
            last_smooth, smooth = smooth, alpha*(val-seasonals[i%slen]) + (1-alpha)*(smooth+trend)
            trend = beta * (smooth-last_smooth) + (1-beta)*trend
            seasonals[i%slen] = gamma*(val-smooth) + (1-gamma)*seasonals[i%slen]
            result.append(smooth+trend+seasonals[i%slen])
    return result

# # forecast 24 points (i.e. two seasons)
# >>> triple_exponential_smoothing(series, 12, 0.716, 0.029, 0.993, 24)
# [30, 20.34449316666667, 28.410051892109554, 30.438122252647577, 39.466817731253066, ...


def initial_seasonal_components(series, slen):
    seasonals = {}
    season_averages = []
    n_seasons = int(len(series)/slen)
    # compute season averages
    for j in range(n_seasons):
        season_averages.append(sum(series[slen*j:slen*j+slen])/float(slen))
    # compute initial values
    for i in range(slen):
        sum_of_vals_over_avg = 0.0
        for j in range(n_seasons):
            sum_of_vals_over_avg += series[slen*j+i]-season_averages[j]
        seasonals[i] = sum_of_vals_over_avg/n_seasons
    return seasonals
##-----------------------------------------------------------------------------------
from sklearn.metrics import mean_squared_error
def fittingparameter(data_y,j):
    count_alpha = 0
    count_beta = 0
    count_gamma = 0
    alpha = float(0)
    beta = float(0)
    gamma = float(0)
    index_alpha =[]
    index_beta =[]
    index_gamma = []
    act = j
    data = data_y
    pred_no = 1
    ramda = 0.1
    MSE_holtload = []
#     query1 = "SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '%s' AND TimeStamp <= '%s';"% (time_b[act+1],time_b[act+96])
    query1 = "SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '%s' ;"% (time_b[act+1])
    print query1
    df1 = pd.read_sql(query1, conn)
#     print len(df)
    while (alpha <= float(1)):
        count_alpha += 1
        beta = float(0)
        while (beta <=float(1)):
            count_beta += 1 
            gamma = float(0)
            while (gamma <= float(1)):
                count_gamma += 1
                pred_h = triple_exponential_smoothing(data, 96*7,alpha,beta ,gamma, pred_no)
                pred_data = pred_h[len(pred_h)-(pred_no):]                                               
                MSE = mean_squared_error (df1.Sub_metering_4, pred_data)   
#                 print MSE              
                MSE_holtload.append(MSE)
                index_alpha.append(alpha)
                index_beta.append(beta)
                index_gamma.append(gamma)     
#                 print index_alpha,index_beta,index_gamma
                gamma += ramda
            beta += ramda
        alpha += ramda  
#     print  count_gamma,count_beta,count_alpha    
    index_MSE = MSE_holtload.index(min(MSE_holtload))
#     print min(MSE_holtload)
#     print index_MSE
    MSE_min = MSE_holtload[index_MSE]
    alpha = index_alpha[index_MSE]
    beta = index_beta[index_MSE]
    gamma= index_gamma[index_MSE]
    print count_alpha,count_beta,count_gamma
    print MSE_min,alpha,beta,gamma
    return (alpha,beta,gamma)

# %%
conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()
query = "SELECT Timestamp,active_power FROM prediction.data15min_4y WHERE Timestamp >= '%s'   AND TimeStamp <= '%s';"% ("2007-01-01 00:14:59","2007-03-31 23:59:59")
df = pd.read_sql(query, conn , index_col=['Timestamp'])

pred_no = 1 # power 1 Data/15min in 1Hr --> 60/15 = 4 and 1day = 4*24 = 96
j = 0
i = 0
d = len(df)/96 
day =0

conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

time_a = pd.date_range('2007-01-01 00:14:59', periods=d*96, freq='15T')
time_b = pd.date_range('2007-01-14 23:59:59', periods=(d*96)+1, freq='15T')

# set databases to empty 
query_empty = """truncate table prediction.pred_moving_mt4""" 
c.execute(query_empty)

while (j < 96*d ) :    
    if (j%96 == 0):    
        day += 1
        print "_____________DAY:" , day
   
    
    print "\ndata at :" , j,">>>", time_b[j+1]
    query = "SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '%s'   AND TimeStamp <= '%s';"% (time_a[j],time_b[j])
    print query
    df = pd.read_sql(query, conn)
    conn.commit()
    data_y = df['Sub_metering_4'].values.tolist()   
    ans_fiting = fittingparameter(data_y,j)
    pred_h = triple_exponential_smoothing(data_y, 96*7, ans_fiting[0], ans_fiting[1], ans_fiting[2],1)
    pred_data = pred_h[len(pred_h)-(pred_no):]
    c.execute("INSERT INTO prediction.pred_moving_mt4 (Timestamp, watt_sub4) VALUES ( %s, %s)",(time_b[j+1],abs(pred_data[0])))
    conn.commit()
    j += 1
print "DONE!!"
# Out:
# _____________DAY: 1
#
# data at : 0 >>> 2007-01-15 00:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:14:59'   AND TimeStamp <= '2007-01-14 23:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 00:14:59' ;
# 11 121 1331
# 1.40913794941 0.1 0.6 0.9
#
# data at : 1 >>> 2007-01-15 00:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:29:59'   AND TimeStamp <= '2007-01-15 00:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 00:29:59' ;
# 11 121 1331
# 6.14008337399 0.1 0.2 0.6
#
# data at : 2 >>> 2007-01-15 00:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:44:59'   AND TimeStamp <= '2007-01-15 00:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 00:44:59' ;
# 11 121 1331
# 0.232748795212 0.1 0.1 0.8
#
# data at : 3 >>> 2007-01-15 00:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 00:59:59'   AND TimeStamp <= '2007-01-15 00:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 00:59:59' ;
# 11 121 1331
# 9.54973203858 0.1 0.2 0.6
#
# data at : 4 >>> 2007-01-15 01:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 01:14:59'   AND TimeStamp <= '2007-01-15 00:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 01:14:59' ;
# 11 121 1331
# 2.99788936751 0.1 0.1 0.9
#
# data at : 5 >>> 2007-01-15 01:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 01:29:59'   AND TimeStamp <= '2007-01-15 01:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 01:29:59' ;
# 11 121 1331
# 0.104343496324 0.2 1.0 0.6
#
# data at : 6 >>> 2007-01-15 01:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 01:44:59'   AND TimeStamp <= '2007-01-15 01:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 01:44:59' ;
# 11 121 1331
# 3.97550454147 0.1 0.0 1.0
#
# data at : 7 >>> 2007-01-15 01:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 01:59:59'   AND TimeStamp <= '2007-01-15 01:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 01:59:59' ;
# 11 121 1331
# 0.602636269298 0.2 1.0 0.9
#
# data at : 8 >>> 2007-01-15 02:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 02:14:59'   AND TimeStamp <= '2007-01-15 01:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 02:14:59' ;
# 11 121 1331
# 20.8449752709 0.1 1.0 0.6
#
# data at : 9 >>> 2007-01-15 02:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 02:29:59'   AND TimeStamp <= '2007-01-15 02:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 02:29:59' ;
# 11 121 1331
# 2.67805734175 0.1 0.8 0.9
#
# data at : 10 >>> 2007-01-15 02:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 02:44:59'   AND TimeStamp <= '2007-01-15 02:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 02:44:59' ;
# 11 121 1331
# 0.462688388074 0.2 0.6 0.9
#
# data at : 11 >>> 2007-01-15 02:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 02:59:59'   AND TimeStamp <= '2007-01-15 02:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 02:59:59' ;
# 11 121 1331
# 3.34099361437 0.2 0.5 1.0
#
# data at : 12 >>> 2007-01-15 03:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 03:14:59'   AND TimeStamp <= '2007-01-15 02:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 03:14:59' ;
# 11 121 1331
# 0.505066271642 0.1 0.6 0.9
#
# data at : 13 >>> 2007-01-15 03:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 03:29:59'   AND TimeStamp <= '2007-01-15 03:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 03:29:59' ;
# 11 121 1331
# 0.178165416618 0.1 0.9 0.5
#
# data at : 14 >>> 2007-01-15 03:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 03:44:59'   AND TimeStamp <= '2007-01-15 03:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 03:44:59' ;
# 11 121 1331
# 1.42607044919 0.1 0.5 1.0
#
# data at : 15 >>> 2007-01-15 03:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 03:59:59'   AND TimeStamp <= '2007-01-15 03:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 03:59:59' ;
# 11 121 1331
# 43.3074678271 0.2 0.3 1.0
#
# data at : 16 >>> 2007-01-15 04:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 04:14:59'   AND TimeStamp <= '2007-01-15 03:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 04:14:59' ;
# 11 121 1331
# 18.8697155391 0.1 0.5 0.8
#
# data at : 17 >>> 2007-01-15 04:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 04:29:59'   AND TimeStamp <= '2007-01-15 04:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 04:29:59' ;
# 11 121 1331
# 0.0473048453773 0.1 0.8 0.8
#
# data at : 18 >>> 2007-01-15 04:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 04:44:59'   AND TimeStamp <= '2007-01-15 04:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 04:44:59' ;
# 11 121 1331
# 0.377909443349 0.1 0.8 1.0
#
# data at : 19 >>> 2007-01-15 04:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 04:59:59'   AND TimeStamp <= '2007-01-15 04:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 04:59:59' ;
# 11 121 1331
# 2.50552815541 0.2 0.9 0.9
#
# data at : 20 >>> 2007-01-15 05:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 05:14:59'   AND TimeStamp <= '2007-01-15 04:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 05:14:59' ;
# 11 121 1331
# 0.430789245226 0.1 0.6 0.8
#
# data at : 21 >>> 2007-01-15 05:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 05:29:59'   AND TimeStamp <= '2007-01-15 05:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 05:29:59' ;
# 11 121 1331
# 5.72769718775 0.1 0.4 0.7
#
# data at : 22 >>> 2007-01-15 05:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 05:44:59'   AND TimeStamp <= '2007-01-15 05:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 05:44:59' ;
# 11 121 1331
# 0.161884907861 0.1 0.3 0.9
#
# data at : 23 >>> 2007-01-15 05:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 05:59:59'   AND TimeStamp <= '2007-01-15 05:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 05:59:59' ;
# 11 121 1331
# 0.744773432061 0.1 0.4 0.8
#
# data at : 24 >>> 2007-01-15 06:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 06:14:59'   AND TimeStamp <= '2007-01-15 05:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 06:14:59' ;
# 11 121 1331
# 9.30914333846 0.1 0.5 0.8
#
# data at : 25 >>> 2007-01-15 06:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 06:29:59'   AND TimeStamp <= '2007-01-15 06:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 06:29:59' ;
# 11 121 1331
# 67.421282976 0.1 0.4 0.9
#
# data at : 26 >>> 2007-01-15 06:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 06:44:59'   AND TimeStamp <= '2007-01-15 06:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 06:44:59' ;
# 11 121 1331
# 68.2279576392 0.1 1.0 0.7
#
# data at : 27 >>> 2007-01-15 06:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 06:59:59'   AND TimeStamp <= '2007-01-15 06:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 06:59:59' ;
# 11 121 1331
# 452.661282783 0.1 1.0 1.0
#
# data at : 28 >>> 2007-01-15 07:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 07:14:59'   AND TimeStamp <= '2007-01-15 06:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 07:14:59' ;
# 11 121 1331
# 0.116602242335 0.3 0.0 0.1
#
# data at : 29 >>> 2007-01-15 07:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 07:29:59'   AND TimeStamp <= '2007-01-15 07:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 07:29:59' ;
# 11 121 1331
# 1.05909705552 0.2 0.2 1.0
#
# data at : 30 >>> 2007-01-15 07:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 07:44:59'   AND TimeStamp <= '2007-01-15 07:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 07:44:59' ;
# 11 121 1331
# 0.0034750542814 0.1 1.0 0.3
#
# data at : 31 >>> 2007-01-15 07:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 07:59:59'   AND TimeStamp <= '2007-01-15 07:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 07:59:59' ;
# 11 121 1331
# 0.0506628275171 0.1 0.3 0.3
#
# data at : 32 >>> 2007-01-15 08:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 08:14:59'   AND TimeStamp <= '2007-01-15 07:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 08:14:59' ;
# 11 121 1331
# 8.01319540133e-06 0.7 0.0 0.8
#
# data at : 33 >>> 2007-01-15 08:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 08:29:59'   AND TimeStamp <= '2007-01-15 08:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 08:29:59' ;
# 11 121 1331
# 0.00849287455158 0.1 1.0 0.0
#
# data at : 34 >>> 2007-01-15 08:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 08:44:59'   AND TimeStamp <= '2007-01-15 08:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 08:44:59' ;
# 11 121 1331
# 318.627961274 0.0 0.0 1.0
#
# data at : 35 >>> 2007-01-15 08:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 08:59:59'   AND TimeStamp <= '2007-01-15 08:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 08:59:59' ;
# 11 121 1331
# 41538.0855525 0.0 0.0 1.0
#
# data at : 36 >>> 2007-01-15 09:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 09:14:59'   AND TimeStamp <= '2007-01-15 08:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 09:14:59' ;
# 11 121 1331
# 18.5087554188 0.6 1.0 1.0
#
# data at : 37 >>> 2007-01-15 09:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 09:29:59'   AND TimeStamp <= '2007-01-15 09:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 09:29:59' ;
# 11 121 1331
# 2.08769516248 0.4 0.5 1.0
#
# data at : 38 >>> 2007-01-15 09:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 09:44:59'   AND TimeStamp <= '2007-01-15 09:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 09:44:59' ;
# 11 121 1331
# 0.546521318551 0.2 0.8 0.7
#
# data at : 39 >>> 2007-01-15 09:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 09:59:59'   AND TimeStamp <= '2007-01-15 09:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 09:59:59' ;
# 11 121 1331
# 0.518309594915 0.1 0.5 0.8
#
# data at : 40 >>> 2007-01-15 10:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 10:14:59'   AND TimeStamp <= '2007-01-15 09:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 10:14:59' ;
# 11 121 1331
# 0.672146016249 0.1 0.4 0.8
#
# data at : 41 >>> 2007-01-15 10:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 10:29:59'   AND TimeStamp <= '2007-01-15 10:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 10:29:59' ;
# 11 121 1331
# 0.407556981843 0.1 0.8 0.5
#
# data at : 42 >>> 2007-01-15 10:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 10:44:59'   AND TimeStamp <= '2007-01-15 10:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 10:44:59' ;
# 11 121 1331
# 0.0199165632026 0.2 0.3 0.8
#
# data at : 43 >>> 2007-01-15 10:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 10:59:59'   AND TimeStamp <= '2007-01-15 10:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 10:59:59' ;
# 11 121 1331
# 0.804247530184 0.2 0.2 0.9
#
# data at : 44 >>> 2007-01-15 11:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 11:14:59'   AND TimeStamp <= '2007-01-15 10:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 11:14:59' ;
# 11 121 1331
# 18.0908062367 0.1 0.4 0.8
#
# data at : 45 >>> 2007-01-15 11:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 11:29:59'   AND TimeStamp <= '2007-01-15 11:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 11:29:59' ;
# 11 121 1331
# 0.00110366039709 0.1 1.0 1.0
#
# data at : 46 >>> 2007-01-15 11:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 11:44:59'   AND TimeStamp <= '2007-01-15 11:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 11:44:59' ;
# 11 121 1331
# 0.000107381565354 0.1 0.2 0.9
#
# data at : 47 >>> 2007-01-15 11:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 11:59:59'   AND TimeStamp <= '2007-01-15 11:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 11:59:59' ;
# 11 121 1331
# 0.0572845414492 0.1 0.2 0.8
#
# data at : 48 >>> 2007-01-15 12:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 12:14:59'   AND TimeStamp <= '2007-01-15 11:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 12:14:59' ;
# 11 121 1331
# 2.08144171948 0.3 0.8 0.9
#
# data at : 49 >>> 2007-01-15 12:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 12:29:59'   AND TimeStamp <= '2007-01-15 12:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 12:29:59' ;
# 11 121 1331
# 0.0407473504434 0.1 0.1 1.0
#
# data at : 50 >>> 2007-01-15 12:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 12:44:59'   AND TimeStamp <= '2007-01-15 12:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 12:44:59' ;
# 11 121 1331
# 0.361507366421 0.1 0.1 0.9
#
# data at : 51 >>> 2007-01-15 12:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 12:59:59'   AND TimeStamp <= '2007-01-15 12:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 12:59:59' ;
# 11 121 1331
# 13.6055683818 0.1 0.0 0.9
#
# data at : 52 >>> 2007-01-15 13:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 13:14:59'   AND TimeStamp <= '2007-01-15 12:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 13:14:59' ;
# 11 121 1331
# 0.634918761102 0.2 0.9 0.7
#
# data at : 53 >>> 2007-01-15 13:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 13:29:59'   AND TimeStamp <= '2007-01-15 13:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 13:29:59' ;
# 11 121 1331
# 6.56356651285 0.2 0.8 1.0
#
# data at : 54 >>> 2007-01-15 13:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 13:44:59'   AND TimeStamp <= '2007-01-15 13:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 13:44:59' ;
# 11 121 1331
# 5.3354866658 0.2 0.6 1.0
#
# data at : 55 >>> 2007-01-15 13:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 13:59:59'   AND TimeStamp <= '2007-01-15 13:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 13:59:59' ;
# 11 121 1331
# 1951.58509594 0.2 0.6 1.0
#
# data at : 56 >>> 2007-01-15 14:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 14:14:59'   AND TimeStamp <= '2007-01-15 13:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 14:14:59' ;
# 11 121 1331
# 0.0190233796559 0.9 0.3 0.1
#
# data at : 57 >>> 2007-01-15 14:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 14:29:59'   AND TimeStamp <= '2007-01-15 14:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 14:29:59' ;
# 11 121 1331
# 0.0966730087834 0.1 0.3 0.1
#
# data at : 58 >>> 2007-01-15 14:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 14:44:59'   AND TimeStamp <= '2007-01-15 14:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 14:44:59' ;
# 11 121 1331
# 0.0130011615916 0.1 0.3 0.8
#
# data at : 59 >>> 2007-01-15 14:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 14:59:59'   AND TimeStamp <= '2007-01-15 14:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 14:59:59' ;
# 11 121 1331
# 0.296509319442 0.2 0.6 1.0
#
# data at : 60 >>> 2007-01-15 15:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 15:14:59'   AND TimeStamp <= '2007-01-15 14:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 15:14:59' ;
# 11 121 1331
# 8.35746077465 0.1 1.0 0.7
#
# data at : 61 >>> 2007-01-15 15:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 15:29:59'   AND TimeStamp <= '2007-01-15 15:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 15:29:59' ;
# 11 121 1331
# 6.102122131 0.2 0.4 1.0
#
# data at : 62 >>> 2007-01-15 15:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 15:44:59'   AND TimeStamp <= '2007-01-15 15:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 15:44:59' ;
# 11 121 1331
# 0.469006816691 0.1 0.3 0.9
#
# data at : 63 >>> 2007-01-15 15:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 15:59:59'   AND TimeStamp <= '2007-01-15 15:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 15:59:59' ;
# 11 121 1331
# 0.000997210945242 0.4 0.6 0.8
#
# data at : 64 >>> 2007-01-15 16:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 16:14:59'   AND TimeStamp <= '2007-01-15 15:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 16:14:59' ;
# 11 121 1331
# 0.00632394898768 0.2 0.6 0.8
#
# data at : 65 >>> 2007-01-15 16:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 16:29:59'   AND TimeStamp <= '2007-01-15 16:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 16:29:59' ;
# 11 121 1331
# 0.000468871277422 0.3 0.5 0.0
#
# data at : 66 >>> 2007-01-15 16:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 16:44:59'   AND TimeStamp <= '2007-01-15 16:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 16:44:59' ;
# 11 121 1331
# 0.000108544093478 0.7 0.3 0.0
#
# data at : 67 >>> 2007-01-15 16:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 16:59:59'   AND TimeStamp <= '2007-01-15 16:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 16:59:59' ;
# 11 121 1331
# 0.112239080016 0.1 0.9 0.3
#
# data at : 68 >>> 2007-01-15 17:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 17:14:59'   AND TimeStamp <= '2007-01-15 16:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 17:14:59' ;
# 11 121 1331
# 0.000419707044405 0.8 0.5 0.5
#
# data at : 69 >>> 2007-01-15 17:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 17:29:59'   AND TimeStamp <= '2007-01-15 17:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 17:29:59' ;
# 11 121 1331
# 3.42442596535e-05 0.3 0.1 0.3
#
# data at : 70 >>> 2007-01-15 17:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 17:44:59'   AND TimeStamp <= '2007-01-15 17:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 17:44:59' ;
# 11 121 1331
# 494.337495096 0.0 0.0 1.0
#
# data at : 71 >>> 2007-01-15 17:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 17:59:59'   AND TimeStamp <= '2007-01-15 17:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 17:59:59' ;
# 11 121 1331
# 0.00659433490524 0.4 0.4 1.0
#
# data at : 72 >>> 2007-01-15 18:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 18:14:59'   AND TimeStamp <= '2007-01-15 17:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 18:14:59' ;
# 11 121 1331
# 0.0214007948105 0.3 0.6 0.7
#
# data at : 73 >>> 2007-01-15 18:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 18:29:59'   AND TimeStamp <= '2007-01-15 18:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 18:29:59' ;
# 11 121 1331
# 33.5572104005 0.1 0.7 1.0
#
# data at : 74 >>> 2007-01-15 18:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 18:44:59'   AND TimeStamp <= '2007-01-15 18:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 18:44:59' ;
# 11 121 1331
# 6.46591629757 0.0 0.0 0.2
#
# data at : 75 >>> 2007-01-15 18:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 18:59:59'   AND TimeStamp <= '2007-01-15 18:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 18:59:59' ;
# 11 121 1331
# 0.000487092798164 0.9 1.0 0.0
#
# data at : 76 >>> 2007-01-15 19:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 19:14:59'   AND TimeStamp <= '2007-01-15 18:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 19:14:59' ;
# 11 121 1331
# 0.0485363204691 0.3 0.8 0.9
#
# data at : 77 >>> 2007-01-15 19:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 19:29:59'   AND TimeStamp <= '2007-01-15 19:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 19:29:59' ;
# 11 121 1331
# 0.0590713974278 0.1 0.9 0.2
#
# data at : 78 >>> 2007-01-15 19:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 19:44:59'   AND TimeStamp <= '2007-01-15 19:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 19:44:59' ;
# 11 121 1331
# 25163.0282057 0.0 0.0 1.0
#
# data at : 79 >>> 2007-01-15 19:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 19:59:59'   AND TimeStamp <= '2007-01-15 19:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 19:59:59' ;
# 11 121 1331
# 2.07406361833 0.7 1.0 1.0
#
# data at : 80 >>> 2007-01-15 20:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 20:14:59'   AND TimeStamp <= '2007-01-15 19:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 20:14:59' ;
# 11 121 1331
# 1.02471459933 0.7 0.9 0.6
#
# data at : 81 >>> 2007-01-15 20:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 20:29:59'   AND TimeStamp <= '2007-01-15 20:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 20:29:59' ;
# 11 121 1331
# 0.748038257067 0.1 0.3 0.1
#
# data at : 82 >>> 2007-01-15 20:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 20:44:59'   AND TimeStamp <= '2007-01-15 20:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 20:44:59' ;
# 11 121 1331
# 0.12865881444 0.5 0.5 0.3
#
# data at : 83 >>> 2007-01-15 20:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 20:59:59'   AND TimeStamp <= '2007-01-15 20:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 20:59:59' ;
# 11 121 1331
# 0.0113134509879 0.6 0.6 0.5
#
# data at : 84 >>> 2007-01-15 21:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 21:14:59'   AND TimeStamp <= '2007-01-15 20:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 21:14:59' ;
# 11 121 1331
# 0.196616249875 0.2 0.7 0.8
#
# data at : 85 >>> 2007-01-15 21:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 21:29:59'   AND TimeStamp <= '2007-01-15 21:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 21:29:59' ;
# 11 121 1331
# 226.321385283 0.0 0.0 0.8
#
# data at : 86 >>> 2007-01-15 21:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 21:44:59'   AND TimeStamp <= '2007-01-15 21:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 21:44:59' ;
# 11 121 1331
# 0.0224685215151 0.8 0.6 0.0
#
# data at : 87 >>> 2007-01-15 21:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 21:59:59'   AND TimeStamp <= '2007-01-15 21:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 21:59:59' ;
# 11 121 1331
# 1.6128170477 0.5 0.8 0.5
#
# data at : 88 >>> 2007-01-15 22:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 22:14:59'   AND TimeStamp <= '2007-01-15 21:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 22:14:59' ;
# 11 121 1331
# 12.4995720668 0.4 1.0 0.7
#
# data at : 89 >>> 2007-01-15 22:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 22:29:59'   AND TimeStamp <= '2007-01-15 22:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 22:29:59' ;
# 11 121 1331
# 0.703991903958 0.4 0.8 0.8
#
# data at : 90 >>> 2007-01-15 22:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 22:44:59'   AND TimeStamp <= '2007-01-15 22:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 22:44:59' ;
# 11 121 1331
# 0.206178567298 0.4 1.0 1.0
#
# data at : 91 >>> 2007-01-15 22:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 22:59:59'   AND TimeStamp <= '2007-01-15 22:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 22:59:59' ;
# 11 121 1331
# 0.556985829578 0.4 0.4 1.0
#
# data at : 92 >>> 2007-01-15 23:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 23:14:59'   AND TimeStamp <= '2007-01-15 22:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 23:14:59' ;
# 11 121 1331
# 0.110380733581 0.2 0.9 0.8
#
# data at : 93 >>> 2007-01-15 23:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 23:29:59'   AND TimeStamp <= '2007-01-15 23:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 23:29:59' ;
# 11 121 1331
# 0.189801289366 0.2 0.0 0.6
#
# data at : 94 >>> 2007-01-15 23:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 23:44:59'   AND TimeStamp <= '2007-01-15 23:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 23:44:59' ;
# 11 121 1331
# 0.638187372475 1.0 0.7 0.4
#
# data at : 95 >>> 2007-01-15 23:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-01 23:59:59'   AND TimeStamp <= '2007-01-15 23:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-15 23:59:59' ;
# 11 121 1331
# 0.17916308705 0.7 0.3 1.0
# _____________DAY: 2
#
# data at : 96 >>> 2007-01-16 00:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 00:14:59'   AND TimeStamp <= '2007-01-15 23:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 00:14:59' ;
# 11 121 1331
# 0.00909282240914 0.4 0.4 0.5
#
# data at : 97 >>> 2007-01-16 00:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 00:29:59'   AND TimeStamp <= '2007-01-16 00:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 00:29:59' ;
# 11 121 1331
# 0.00688492004887 0.8 0.7 0.6
#
# data at : 98 >>> 2007-01-16 00:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 00:44:59'   AND TimeStamp <= '2007-01-16 00:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 00:44:59' ;
# 11 121 1331
# 0.221600309384 0.5 0.2 0.7
#
# data at : 99 >>> 2007-01-16 00:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 00:59:59'   AND TimeStamp <= '2007-01-16 00:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 00:59:59' ;
# 11 121 1331
# 0.000228356389591 0.6 0.8 0.7
#
# data at : 100 >>> 2007-01-16 01:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 01:14:59'   AND TimeStamp <= '2007-01-16 00:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 01:14:59' ;
# 11 121 1331
# 0.0094237124257 0.2 0.5 0.1
#
# data at : 101 >>> 2007-01-16 01:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 01:29:59'   AND TimeStamp <= '2007-01-16 01:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 01:29:59' ;
# 11 121 1331
# 0.000128424109905 0.7 0.8 1.0
#
# data at : 102 >>> 2007-01-16 01:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 01:44:59'   AND TimeStamp <= '2007-01-16 01:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 01:44:59' ;
# 11 121 1331
# 0.00258600118572 0.1 0.4 1.0
#
# data at : 103 >>> 2007-01-16 01:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 01:59:59'   AND TimeStamp <= '2007-01-16 01:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 01:59:59' ;
# 11 121 1331
# 0.012714834351 0.3 0.2 0.4
#
# data at : 104 >>> 2007-01-16 02:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 02:14:59'   AND TimeStamp <= '2007-01-16 01:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 02:14:59' ;
# 11 121 1331
# 0.000286591269201 0.1 0.3 0.9
#
# data at : 105 >>> 2007-01-16 02:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 02:29:59'   AND TimeStamp <= '2007-01-16 02:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 02:29:59' ;
# 11 121 1331
# 0.000123431339326 0.8 0.4 0.7
#
# data at : 106 >>> 2007-01-16 02:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 02:44:59'   AND TimeStamp <= '2007-01-16 02:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 02:44:59' ;
# 11 121 1331
# 0.000463337671984 0.2 0.1 0.7
#
# data at : 107 >>> 2007-01-16 02:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 02:59:59'   AND TimeStamp <= '2007-01-16 02:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 02:59:59' ;
# 11 121 1331
# 0.00114522839468 0.3 0.8 0.5
#
# data at : 108 >>> 2007-01-16 03:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 03:14:59'   AND TimeStamp <= '2007-01-16 02:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 03:14:59' ;
# 11 121 1331
# 0.000166326936025 0.1 0.0 0.8
#
# data at : 109 >>> 2007-01-16 03:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 03:29:59'   AND TimeStamp <= '2007-01-16 03:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 03:29:59' ;
# 11 121 1331
# 0.000425992882265 0.3 0.8 0.3
#
# data at : 110 >>> 2007-01-16 03:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 03:44:59'   AND TimeStamp <= '2007-01-16 03:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 03:44:59' ;
# 11 121 1331
# 0.0389782946253 0.1 0.3 0.2
#
# data at : 111 >>> 2007-01-16 03:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 03:59:59'   AND TimeStamp <= '2007-01-16 03:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 03:59:59' ;
# 11 121 1331
# 1.99944382474e-05 0.3 1.0 0.3
#
# data at : 112 >>> 2007-01-16 04:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 04:14:59'   AND TimeStamp <= '2007-01-16 03:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 04:14:59' ;
# 11 121 1331
# 0.0772541954049 0.1 0.6 0.6
#
# data at : 113 >>> 2007-01-16 04:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 04:29:59'   AND TimeStamp <= '2007-01-16 04:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 04:29:59' ;
# 11 121 1331
# 3.29457787597e-06 0.3 0.3 1.0
#
# data at : 114 >>> 2007-01-16 04:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 04:44:59'   AND TimeStamp <= '2007-01-16 04:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 04:44:59' ;
# 11 121 1331
# 0.000872006853214 0.7 0.1 0.9
#
# data at : 115 >>> 2007-01-16 04:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 04:59:59'   AND TimeStamp <= '2007-01-16 04:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 04:59:59' ;
# 11 121 1331
# 0.112911079936 0.2 0.1 1.0
#
# data at : 116 >>> 2007-01-16 05:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 05:14:59'   AND TimeStamp <= '2007-01-16 04:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 05:14:59' ;
# 11 121 1331
# 0.000106847641039 0.9 0.5 0.7
#
# data at : 117 >>> 2007-01-16 05:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 05:29:59'   AND TimeStamp <= '2007-01-16 05:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 05:29:59' ;
# 11 121 1331
# 0.0084827922569 0.3 1.0 0.6
#
# data at : 118 >>> 2007-01-16 05:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 05:44:59'   AND TimeStamp <= '2007-01-16 05:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 05:44:59' ;
# 11 121 1331
# 0.0214987191627 0.4 0.7 1.0
#
# data at : 119 >>> 2007-01-16 05:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 05:59:59'   AND TimeStamp <= '2007-01-16 05:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 05:59:59' ;
# 11 121 1331
# 0.165949510515 0.2 0.5 0.5
#
# data at : 120 >>> 2007-01-16 06:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 06:14:59'   AND TimeStamp <= '2007-01-16 05:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 06:14:59' ;
# 11 121 1331
# 0.000251532568894 0.8 0.8 1.0
#
# data at : 121 >>> 2007-01-16 06:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 06:29:59'   AND TimeStamp <= '2007-01-16 06:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 06:29:59' ;
# 11 121 1331
# 1.98820596312e-05 0.3 0.9 0.5
#
# data at : 122 >>> 2007-01-16 06:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 06:44:59'   AND TimeStamp <= '2007-01-16 06:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 06:44:59' ;
# 11 121 1331
# 0.246960714213 0.1 0.9 0.3
#
# data at : 123 >>> 2007-01-16 06:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 06:59:59'   AND TimeStamp <= '2007-01-16 06:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 06:59:59' ;
# 11 121 1331
# 3.24652635918 0.1 0.6 1.0
#
# data at : 124 >>> 2007-01-16 07:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 07:14:59'   AND TimeStamp <= '2007-01-16 06:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 07:14:59' ;
# 11 121 1331
# 0.00117872024636 0.2 0.1 0.8
#
# data at : 125 >>> 2007-01-16 07:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 07:29:59'   AND TimeStamp <= '2007-01-16 07:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 07:29:59' ;
# 11 121 1331
# 817.179786787 0.1 0.4 1.0
#
# data at : 126 >>> 2007-01-16 07:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 07:44:59'   AND TimeStamp <= '2007-01-16 07:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 07:44:59' ;
# 11 121 1331
# 106.655620479 0.6 1.0 1.0
#
# data at : 127 >>> 2007-01-16 07:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 07:59:59'   AND TimeStamp <= '2007-01-16 07:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 07:59:59' ;
# 11 121 1331
# 0.227621603093 0.4 0.5 1.0
#
# data at : 128 >>> 2007-01-16 08:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 08:14:59'   AND TimeStamp <= '2007-01-16 07:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 08:14:59' ;
# 11 121 1331
# 8.20546692307 0.1 0.7 0.8
#
# data at : 129 >>> 2007-01-16 08:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 08:29:59'   AND TimeStamp <= '2007-01-16 08:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 08:29:59' ;
# 11 121 1331
# 0.00877472192139 0.2 0.4 0.5
#
# data at : 130 >>> 2007-01-16 08:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 08:44:59'   AND TimeStamp <= '2007-01-16 08:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 08:44:59' ;
# 11 121 1331
# 0.000116035759652 0.9 0.2 0.2
#
# data at : 131 >>> 2007-01-16 08:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 08:59:59'   AND TimeStamp <= '2007-01-16 08:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 08:59:59' ;
# 11 121 1331
# 0.000146768734456 0.1 0.0 1.0
#
# data at : 132 >>> 2007-01-16 09:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 09:14:59'   AND TimeStamp <= '2007-01-16 08:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 09:14:59' ;
# 11 121 1331
# 3.01826750383e-05 0.5 0.2 0.7
#
# data at : 133 >>> 2007-01-16 09:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 09:29:59'   AND TimeStamp <= '2007-01-16 09:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 09:29:59' ;
# 11 121 1331
# 0.000758444798546 0.2 1.0 0.1
#
# data at : 134 >>> 2007-01-16 09:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 09:44:59'   AND TimeStamp <= '2007-01-16 09:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 09:44:59' ;
# 11 121 1331
# 7.92437987087e-05 0.1 0.2 0.5
#
# data at : 135 >>> 2007-01-16 09:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 09:59:59'   AND TimeStamp <= '2007-01-16 09:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 09:59:59' ;
# 11 121 1331
# 6.47030182321e-05 0.8 0.9 0.5
#
# data at : 136 >>> 2007-01-16 10:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 10:14:59'   AND TimeStamp <= '2007-01-16 09:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 10:14:59' ;
# 11 121 1331
# 0.184597825789 0.2 0.0 0.0
#
# data at : 137 >>> 2007-01-16 10:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 10:29:59'   AND TimeStamp <= '2007-01-16 10:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 10:29:59' ;
# 11 121 1331
# 4.29518532787e-05 0.2 0.7 0.0
#
# data at : 138 >>> 2007-01-16 10:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 10:44:59'   AND TimeStamp <= '2007-01-16 10:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 10:44:59' ;
# 11 121 1331
# 0.197434134656 0.2 0.0 1.0
#
# data at : 139 >>> 2007-01-16 10:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 10:59:59'   AND TimeStamp <= '2007-01-16 10:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 10:59:59' ;
# 11 121 1331
# 1.21286866995e-05 0.9 1.0 1.0
#
# data at : 140 >>> 2007-01-16 11:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 11:14:59'   AND TimeStamp <= '2007-01-16 10:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 11:14:59' ;
# 11 121 1331
# 2.35037076095e-05 0.5 0.3 0.0
#
# data at : 141 >>> 2007-01-16 11:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 11:29:59'   AND TimeStamp <= '2007-01-16 11:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 11:29:59' ;
# 11 121 1331
# 0.332339186301 0.1 0.2 0.7
#
# data at : 142 >>> 2007-01-16 11:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 11:44:59'   AND TimeStamp <= '2007-01-16 11:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 11:44:59' ;
# 11 121 1331
# 15.723673507 0.1 0.6 1.0
#
# data at : 143 >>> 2007-01-16 11:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 11:59:59'   AND TimeStamp <= '2007-01-16 11:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 11:59:59' ;
# 11 121 1331
# 0.00084094759596 0.9 0.7 0.7
#
# data at : 144 >>> 2007-01-16 12:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 12:14:59'   AND TimeStamp <= '2007-01-16 11:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 12:14:59' ;
# 11 121 1331
# 0.00380163833888 0.5 0.3 0.9
#
# data at : 145 >>> 2007-01-16 12:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 12:29:59'   AND TimeStamp <= '2007-01-16 12:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 12:29:59' ;
# 11 121 1331
# 0.00180037280826 0.4 0.5 0.9
#
# data at : 146 >>> 2007-01-16 12:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 12:44:59'   AND TimeStamp <= '2007-01-16 12:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 12:44:59' ;
# 11 121 1331
# 0.00248081932197 0.2 0.5 0.9
#
# data at : 147 >>> 2007-01-16 12:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 12:59:59'   AND TimeStamp <= '2007-01-16 12:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 12:59:59' ;
# 11 121 1331
# 0.110692258423 0.2 0.7 1.0
#
# data at : 148 >>> 2007-01-16 13:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 13:14:59'   AND TimeStamp <= '2007-01-16 12:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 13:14:59' ;
# 11 121 1331
# 2.74948406172e-05 0.7 0.4 0.3
#
# data at : 149 >>> 2007-01-16 13:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 13:29:59'   AND TimeStamp <= '2007-01-16 13:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 13:29:59' ;
# 11 121 1331
# 0.00864438049575 0.3 0.1 1.0
#
# data at : 150 >>> 2007-01-16 13:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 13:44:59'   AND TimeStamp <= '2007-01-16 13:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 13:44:59' ;
# 11 121 1331
# 3.49621838411e-05 0.2 0.0 0.8
#
# data at : 151 >>> 2007-01-16 13:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-01-02 13:59:59'   AND TimeStamp <= '2007-01-16 13:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-01-16 13:59:59' ;
# 11 121 1331
# 0.000836374575413 0.1 0.4 0.2
#
# data at : 152 >>> 2007-01-16 14:14:59
# ...
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 11:29:59' ;
# 11 121 1331
# 0.000341441249459 0.1 0.5 0.9
#
# data at : 8590 >>> 2007-04-14 11:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 11:44:59'   AND TimeStamp <= '2007-04-14 11:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 11:44:59' ;
# 11 121 1331
# 0.0165174516744 0.3 0.4 0.3
#
# data at : 8591 >>> 2007-04-14 11:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 11:59:59'   AND TimeStamp <= '2007-04-14 11:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 11:59:59' ;
# 11 121 1331
# 0.371331005126 0.2 0.8 1.0
#
# data at : 8592 >>> 2007-04-14 12:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 12:14:59'   AND TimeStamp <= '2007-04-14 11:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 12:14:59' ;
# 11 121 1331
# 0.000293917760312 0.1 0.2 0.7
#
# data at : 8593 >>> 2007-04-14 12:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 12:29:59'   AND TimeStamp <= '2007-04-14 12:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 12:29:59' ;
# 11 121 1331
# 0.00164997694253 0.3 0.2 0.1
#
# data at : 8594 >>> 2007-04-14 12:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 12:44:59'   AND TimeStamp <= '2007-04-14 12:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 12:44:59' ;
# 11 121 1331
# 0.120667028742 0.1 0.1 0.6
#
# data at : 8595 >>> 2007-04-14 12:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 12:59:59'   AND TimeStamp <= '2007-04-14 12:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 12:59:59' ;
# 11 121 1331
# 0.000180789746952 0.8 1.0 0.3
#
# data at : 8596 >>> 2007-04-14 13:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 13:14:59'   AND TimeStamp <= '2007-04-14 12:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 13:14:59' ;
# 11 121 1331
# 0.00392429332201 0.1 0.2 0.5
#
# data at : 8597 >>> 2007-04-14 13:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 13:29:59'   AND TimeStamp <= '2007-04-14 13:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 13:29:59' ;
# 11 121 1331
# 0.200827075918 0.1 0.8 1.0
#
# data at : 8598 >>> 2007-04-14 13:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 13:44:59'   AND TimeStamp <= '2007-04-14 13:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 13:44:59' ;
# 11 121 1331
# 0.680320594303 0.0 0.0 0.8
#
# data at : 8599 >>> 2007-04-14 13:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 13:59:59'   AND TimeStamp <= '2007-04-14 13:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 13:59:59' ;
# 11 121 1331
# 0.00513013732315 0.3 0.0 0.7
#
# data at : 8600 >>> 2007-04-14 14:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 14:14:59'   AND TimeStamp <= '2007-04-14 13:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 14:14:59' ;
# 11 121 1331
# 2.19775434766 0.1 0.7 0.8
#
# data at : 8601 >>> 2007-04-14 14:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 14:29:59'   AND TimeStamp <= '2007-04-14 14:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 14:29:59' ;
# 11 121 1331
# 0.237128135798 0.0 0.0 0.7
#
# data at : 8602 >>> 2007-04-14 14:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 14:44:59'   AND TimeStamp <= '2007-04-14 14:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 14:44:59' ;
# 11 121 1331
# 0.00517302022957 0.6 0.8 1.0
#
# data at : 8603 >>> 2007-04-14 14:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 14:59:59'   AND TimeStamp <= '2007-04-14 14:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 14:59:59' ;
# 11 121 1331
# 2.83178281878 0.1 0.7 0.4
#
# data at : 8604 >>> 2007-04-14 15:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 15:14:59'   AND TimeStamp <= '2007-04-14 14:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 15:14:59' ;
# 11 121 1331
# 1.7593620612e-05 0.2 0.3 0.8
#
# data at : 8605 >>> 2007-04-14 15:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 15:29:59'   AND TimeStamp <= '2007-04-14 15:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 15:29:59' ;
# 11 121 1331
# 0.733160559069 0.1 0.8 0.5
#
# data at : 8606 >>> 2007-04-14 15:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 15:44:59'   AND TimeStamp <= '2007-04-14 15:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 15:44:59' ;
# 11 121 1331
# 3.42803566623 0.1 0.4 1.0
#
# data at : 8607 >>> 2007-04-14 15:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 15:59:59'   AND TimeStamp <= '2007-04-14 15:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 15:59:59' ;
# 11 121 1331
# 0.000165501608892 0.1 0.7 1.0
#
# data at : 8608 >>> 2007-04-14 16:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 16:14:59'   AND TimeStamp <= '2007-04-14 15:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 16:14:59' ;
# 11 121 1331
# 0.00229476873061 0.6 0.5 0.9
#
# data at : 8609 >>> 2007-04-14 16:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 16:29:59'   AND TimeStamp <= '2007-04-14 16:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 16:29:59' ;
# 11 121 1331
# 0.0253651157743 0.3 0.6 0.9
#
# data at : 8610 >>> 2007-04-14 16:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 16:44:59'   AND TimeStamp <= '2007-04-14 16:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 16:44:59' ;
# 11 121 1331
# 9.21343562148e-07 0.4 0.3 0.9
#
# data at : 8611 >>> 2007-04-14 16:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 16:59:59'   AND TimeStamp <= '2007-04-14 16:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 16:59:59' ;
# 11 121 1331
# 0.110192729179 0.1 0.3 0.9
#
# data at : 8612 >>> 2007-04-14 17:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 17:14:59'   AND TimeStamp <= '2007-04-14 16:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 17:14:59' ;
# 11 121 1331
# 0.000829380183499 0.9 0.4 0.1
#
# data at : 8613 >>> 2007-04-14 17:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 17:29:59'   AND TimeStamp <= '2007-04-14 17:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 17:29:59' ;
# 11 121 1331
# 0.000211161276542 0.7 0.6 0.5
#
# data at : 8614 >>> 2007-04-14 17:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 17:44:59'   AND TimeStamp <= '2007-04-14 17:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 17:44:59' ;
# 11 121 1331
# 6.53089861149e-05 0.2 0.7 0.2
#
# data at : 8615 >>> 2007-04-14 17:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 17:59:59'   AND TimeStamp <= '2007-04-14 17:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 17:59:59' ;
# 11 121 1331
# 0.0041741992255 0.3 0.0 1.0
#
# data at : 8616 >>> 2007-04-14 18:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 18:14:59'   AND TimeStamp <= '2007-04-14 17:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 18:14:59' ;
# 11 121 1331
# 0.000949156034271 0.1 0.6 0.6
#
# data at : 8617 >>> 2007-04-14 18:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 18:29:59'   AND TimeStamp <= '2007-04-14 18:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 18:29:59' ;
# 11 121 1331
# 4.95326896553 0.1 0.9 0.8
#
# data at : 8618 >>> 2007-04-14 18:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 18:44:59'   AND TimeStamp <= '2007-04-14 18:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 18:44:59' ;
# 11 121 1331
# 0.194033515108 0.1 0.0 1.0
#
# data at : 8619 >>> 2007-04-14 18:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 18:59:59'   AND TimeStamp <= '2007-04-14 18:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 18:59:59' ;
# 11 121 1331
# 12.9292868811 0.1 0.3 0.9
#
# data at : 8620 >>> 2007-04-14 19:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 19:14:59'   AND TimeStamp <= '2007-04-14 18:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 19:14:59' ;
# 11 121 1331
# 52.3437891866 0.1 0.9 1.0
#
# data at : 8621 >>> 2007-04-14 19:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 19:29:59'   AND TimeStamp <= '2007-04-14 19:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 19:29:59' ;
# 11 121 1331
# 0.326948615029 0.3 0.9 0.9
#
# data at : 8622 >>> 2007-04-14 19:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 19:44:59'   AND TimeStamp <= '2007-04-14 19:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 19:44:59' ;
# 11 121 1331
# 1.39750275463 0.2 1.0 1.0
#
# data at : 8623 >>> 2007-04-14 19:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 19:59:59'   AND TimeStamp <= '2007-04-14 19:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 19:59:59' ;
# 11 121 1331
# 2.48604048267 0.1 0.2 1.0
#
# data at : 8624 >>> 2007-04-14 20:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 20:14:59'   AND TimeStamp <= '2007-04-14 19:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 20:14:59' ;
# 11 121 1331
# 0.139549966483 0.1 0.8 1.0
#
# data at : 8625 >>> 2007-04-14 20:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 20:29:59'   AND TimeStamp <= '2007-04-14 20:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 20:29:59' ;
# 11 121 1331
# 6.75448233286 0.1 0.2 1.0
#
# data at : 8626 >>> 2007-04-14 20:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 20:44:59'   AND TimeStamp <= '2007-04-14 20:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 20:44:59' ;
# 11 121 1331
# 110.062354911 0.0 0.0 1.0
#
# data at : 8627 >>> 2007-04-14 20:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 20:59:59'   AND TimeStamp <= '2007-04-14 20:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 20:59:59' ;
# 11 121 1331
# 1.19702840194 0.1 0.7 0.9
#
# data at : 8628 >>> 2007-04-14 21:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 21:14:59'   AND TimeStamp <= '2007-04-14 20:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 21:14:59' ;
# 11 121 1331
# 13721.8973402 0.1 0.7 1.0
#
# data at : 8629 >>> 2007-04-14 21:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 21:29:59'   AND TimeStamp <= '2007-04-14 21:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 21:29:59' ;
# 11 121 1331
# 119566.332607 1.0 1.0 0.3
#
# data at : 8630 >>> 2007-04-14 21:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 21:44:59'   AND TimeStamp <= '2007-04-14 21:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 21:44:59' ;
# 11 121 1331
# 0.0127055152076 0.8 0.3 1.0
#
# data at : 8631 >>> 2007-04-14 21:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 21:59:59'   AND TimeStamp <= '2007-04-14 21:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 21:59:59' ;
# 11 121 1331
# 0.00595779252261 0.3 0.9 0.0
#
# data at : 8632 >>> 2007-04-14 22:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 22:14:59'   AND TimeStamp <= '2007-04-14 21:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 22:14:59' ;
# 11 121 1331
# 0.0163875839253 0.6 0.1 0.9
#
# data at : 8633 >>> 2007-04-14 22:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 22:29:59'   AND TimeStamp <= '2007-04-14 22:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 22:29:59' ;
# 11 121 1331
# 0.0368433919294 0.5 0.3 0.2
#
# data at : 8634 >>> 2007-04-14 22:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 22:44:59'   AND TimeStamp <= '2007-04-14 22:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 22:44:59' ;
# 11 121 1331
# 0.113878435532 0.4 0.2 0.6
#
# data at : 8635 >>> 2007-04-14 22:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 22:59:59'   AND TimeStamp <= '2007-04-14 22:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 22:59:59' ;
# 11 121 1331
# 0.0395015210455 0.1 0.2 0.7
#
# data at : 8636 >>> 2007-04-14 23:14:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 23:14:59'   AND TimeStamp <= '2007-04-14 22:59:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 23:14:59' ;
# 11 121 1331
# 0.000170982692704 0.4 0.1 0.7
#
# data at : 8637 >>> 2007-04-14 23:29:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 23:29:59'   AND TimeStamp <= '2007-04-14 23:14:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 23:29:59' ;
# 11 121 1331
# 0.000217719220452 0.3 0.2 0.7
#
# data at : 8638 >>> 2007-04-14 23:44:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 23:44:59'   AND TimeStamp <= '2007-04-14 23:29:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 23:44:59' ;
# 11 121 1331
# 2.21962332727 0.4 0.8 1.0
#
# data at : 8639 >>> 2007-04-14 23:59:59
# SELECT Timestamp,Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp >= '2007-03-31 23:59:59'   AND TimeStamp <= '2007-04-14 23:44:59';
# SELECT Sub_metering_4 FROM prediction.data15min_4y WHERE Timestamp = '2007-04-14 23:59:59' ;
# 11 121 1331
# 0.353359990467 0.1 0.6 0.2
# DONE!!
