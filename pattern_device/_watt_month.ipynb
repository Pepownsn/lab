# %% [markdown]
# ## 15 SECONDs in 1 WEEK

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

d = 31
time_a = pd.date_range('2016-09-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-09-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()



query = "SELECT Timestamp,watt FROM device.light_system WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "%(time_a[0],time_b[(5760*d)-1])
df_plot = pd.read_sql(query, conn)

query1 = "SELECT Timestamp,watt FROM device.water_heater WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "%(time_a[0],time_b[(5760*d)-1])
df_plot1 = pd.read_sql(query1, conn, index_col=['Timestamp'])

query2 = "SELECT Timestamp,watt FROM device.refrigurator WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "%(time_a[0],time_b[(5760*d)-1])
df_plot2 = pd.read_sql(query2, conn, index_col=['Timestamp'])

query3 = "SELECT Timestamp,watt FROM device.wireless_router WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "%(time_a[0],time_b[(5760*d)-1])
df_plot3 = pd.read_sql(query3, conn, index_col=['Timestamp'])

query4 = "SELECT Timestamp,watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "%(time_a[0],time_b[(5760*d)-1])
df_plot4 = pd.read_sql(query4, conn, index_col=['Timestamp'])

query5 = "SELECT Timestamp,watt FROM device.Computer WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "%(time_a[0],time_b[(5760*d)-1])
df_plot5 = pd.read_sql(query5, conn, index_col=['Timestamp'])

query6= "SELECT Timestamp,watt FROM device.elec_thermos WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "%(time_a[0],time_b[(5760*d)-1])
df_plot6 = pd.read_sql(query6, conn, index_col=['Timestamp'])

query7 = "SELECT Timestamp,watt FROM device.hair_dryer WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "%(time_a[0],time_b[(5760*d)-1])
df_plot7 = pd.read_sql(query7, conn, index_col=['Timestamp'])

query8 = "SELECT Timestamp,watt FROM device.Microwave WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "%(time_a[0],time_b[(5760*d)-1])
df_plot8 = pd.read_sql(query8, conn, index_col=['Timestamp'])

query9 = "SELECT Timestamp,watt FROM device.fan WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "%(time_a[0],time_b[(5760*d)-1])
df_plot9 = pd.read_sql(query9, conn, index_col=['Timestamp'])

query10 = "SELECT Timestamp,watt FROM device.TV WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "%(time_a[0],time_b[(5760*d)-1])
df_plot10 = pd.read_sql(query10, conn, index_col=['Timestamp'])

query11 = "SELECT Timestamp,watt FROM device.watching_meachine WHERE Timestamp >= '%s' AND Timestamp <= '%s'; "%(time_a[0],time_b[(5760*d)-1])
df_plot11 = pd.read_sql(query11, conn, index_col=['Timestamp'])

query12 = "SELECT Timestamp,watt FROM device.IRON WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "%(time_a[0],time_b[(5760*d)-1])
df_plot12 = pd.read_sql(query12, conn, index_col=['Timestamp'])

query13 = "SELECT Timestamp,watt FROM device.rice_cooker WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "%(time_a[0],time_b[(5760*d)-1])
df_plot13 = pd.read_sql(query13, conn, index_col=['Timestamp'])

query14 = "SELECT Timestamp,watt FROM device.iphonecharger WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "%(time_a[0],time_b[(5760*d)-1])
df_plot14 = pd.read_sql(query14, conn, index_col=['Timestamp'])


fig, (ax0, ax1 ,ax2,ax3,ax4,ax5,ax6,ax7,ax8,ax9,ax10,ax11,ax12,ax13,ax14) = plt.subplots(nrows=15,figsize=(9*2, 4*15))

# ax0.set_ylim(-0.5,2.5);
ax0.set_title('Data of light_system')
df_plot.plot(ax=ax0)

ax1.set_title('Data of Water_heater')
df_plot1.plot(ax=ax1)

ax2.set_title('Data of refrigurator')
df_plot2.plot(ax=ax2)

ax3.set_ylim(6,11);
ax3.set_title('Data of wireless_router')
df_plot3.plot(ax=ax3)

ax4.set_title('Data of aircont')
df_plot4.plot(ax=ax4)

ax5.set_title('Data of Computer')
df_plot5.plot(ax=ax5)

ax6.set_title('Data of elec_thermos')
df_plot6.plot(ax=ax6)

ax7.set_title('Data of hair_dryer')
df_plot7.plot(ax=ax7)

ax8.set_title('Data of Microwave')
df_plot8.plot(ax=ax8)

ax9.set_title('Data of fan')
df_plot9.plot(ax=ax9)

ax10.set_title('Data of TV')
df_plot10.plot(ax=ax10)

ax11.set_title('Data of watching_meachine')
df_plot11.plot(ax=ax11)

ax12.set_title('Data of IRON')
df_plot12.plot(ax=ax12)

ax13.set_title('Data of rice_cooker')
df_plot13.plot(ax=ax13)

ax14.set_title('Data of iphonecharger')
df_plot14.plot(ax=ax14)


plt.show()

# %%
i = 0
conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()
query_empty = """truncate table device.load_MONTH  """ 
c.execute(query_empty)
print "device.load_MONTH  are Empty!!! \n"
while (i <= (len(df_plot14)-1)):
    watt = df_plot.watt[i]+df_plot1.watt[i]+df_plot2.watt[i]+df_plot3.watt[i]+df_plot4.watt[i]+df_plot5.watt[i]+df_plot6.watt[i]+df_plot7.watt[i]+df_plot8.watt[i]+df_plot9.watt[i]+df_plot10.watt[i]+df_plot11.watt[i]+df_plot12.watt[i]+df_plot13.watt[i]+df_plot14.watt[i]
    c.execute("INSERT INTO device.load_MONTH (Timestamp, watt) VALUES (%s, %s)",(time_a[i],watt))
    conn.commit()
    i+=1
print "DONE!!!"
# Out:
# device.load_MONTH  are Empty!!!
# KeyErrorTraceback (most recent call last)
# <ipython-input-13-d3ddd9556366> in <module>()
#       6 print "device.load_MONTH  are Empty!!! \n"
#       7 while (i <=len(df_plot14)-1):
# ----> 8     watt = df_plot.watt[i]+df_plot1.watt[i]+df_plot2.watt[i]+df_plot3.watt[i]+df_plot4.watt[i]+df_plot5.watt[i]+df_plot6.watt[i]+df_plot7.watt[i]+df_plot8.watt[i]+df_plot9.watt[i]+df_plot10.watt[i]+df_plot11.watt[i]+df_plot12.watt[i]+df_plot13.watt[i]+df_plot14.watt[i]
#       9     c.execute("INSERT INTO device.load_MONTH (Timestamp, watt) VALUES (%s, %s)",(time_a[i],watt))
#      10     conn.commit()
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/series.pyc in __getitem__(self, key)
#     599         key = com._apply_if_callable(key, self)
#     600         try:
# --> 601             result = self.index.get_value(self, key)
#     602
#     603             if not is_scalar(result):
#
# ...

# %%
# query = "SELECT watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
query16 = "SELECT Timestamp,watt FROM device.load_MONTH WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_a[(5760*d)-1])
df = pd.read_sql(query16, conn, index_col=['Timestamp'])
fig, ax = plt.subplots()
ax.set_title('device.load_MONTH')
df.plot(ax=ax )
plt.show()
# Out:
# DatabaseErrorTraceback (most recent call last)
# <ipython-input-12-81b5b9763971> in <module>()
#       2 # query = "SELECT watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
#       3 query16 = "SELECT Timestamp,watt FROM device.load_MONTH WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_a[(5760*d)-1])
# ----> 4 df = pd.read_sql(query16, conn, index_col=['Timestamp'])
#       5 fig, ax = plt.subplots()
#       6 ax.set_title('device.load_MONTH')
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/sql.pyc in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     397             sql, index_col=index_col, params=params,
#     398             coerce_float=coerce_float, parse_dates=parse_dates,
# --> 399             chunksize=chunksize)
#     400
#     401     try:
#
# ...
