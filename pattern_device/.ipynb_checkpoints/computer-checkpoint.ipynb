# %% [markdown]
# ### COMPUTER | psu 600W + LED 23" |
# ##### TYPE 2 " TURN ON EVERYDAY//ONCE TIME

# %% [markdown]
# ## NO. 4 (คอมพิวเตอร์)
# ![image](https://raw.githubusercontent.com/skyfighter/iHEMS/master/Device/pic/PC-1.png)
#
# ![image](https://raw.githubusercontent.com/skyfighter/iHEMS/master/Device/pic/PC-all.png)

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random


d = 31
time_a = pd.date_range('2016-09-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-09-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()


####### set databases to empty #########
query_empty = """truncate table device.Computer""" 
c.execute(query_empty)
print "device.Computer are Empty!!! \n"

query = "SELECT watt FROM collected_info.4_Computer WHERE no >= '%s'   AND no <= '%s'; "% (0,1240)
df = pd.read_sql(query, conn)
# print df.watt[5]

#### Random the turning-on time appliances
def rand_turnon():
    duration_sec =  random.randint(10, 59)
    duration_min =  random.randint(10, 59)
    duration_hour1 = ['18'] * 4+['19'] * 6 + ['20'] * 46 + ['21'] * 41 +['22'] * 3     #SET Start 7-10 pm.
    duration_hour = random.choice(duration_hour1)     
    if 0 < duration_sec <= 15:
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
    off_item = (int(duration_hour)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on appliacne on",duration_hour,":",duration_min,":",duration_sec,"equal to",off_item,"items"
    return off_item

 
#### Random the off-duration appliances 
def rand_duration():
    duration_sec =  random.randint(10, 59)
    duration_min =  random.randint(10, 59)
    duration_hour1 = ['1'] * 9 + ['2'] * 59 + ['3'] * 30 +['4'] * 1+['5'] * 1   
    duration_hour = random.choice(duration_hour1)   
    seconds = (int(duration_hour)*3600)+(duration_min*60)+duration_sec
    no_item = seconds/15
    print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items"
    return no_item

days = 0
j = 0
i = 0
print "\nDays :",days ,":",time_b[j].strftime('%a')
off_item = rand_turnon()  
no_item = rand_duration()  

while (j <= (5760*d)-1):  
    c.execute("INSERT INTO device.Computer (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
    conn.commit()
    j += 1 
    
    while (off_item+(5760*(days)) <= j <= (no_item+off_item)+(5760*(days))):                   
        c.execute("INSERT INTO device.Computer (Timestamp, watt) VALUES (%s, %s)",(time_b[j],df.watt[i]))
        conn.commit()
        i += 1 
        j += 1
        if (j == (no_item+off_item)+(5760*(days))):
            days +=1
            print "\nDays :",days ,":",time_b[j].strftime('%a')
            off_item = rand_turnon()  
            no_item = rand_duration() 
            i= 0   

                    
print "DONE!"
# Out:
# device.Computer are Empty!!!
#
#
# Days : 0 : Thu
# time to turn-on appliacne on 19 : 54 : 15 equal to 4776 items
# consuming the appliance 2 hours 49 minutes 14 seconds that equal to 10154 seconds or 676 items
#
# Days : 1 : Thu
# time to turn-on appliacne on 21 : 20 : 54 equal to 5123 items
# consuming the appliance 2 hours 18 minutes 37 seconds that equal to 8317 seconds or 554 items
#
# Days : 2 : Fri
# time to turn-on appliacne on 20 : 23 : 59 equal to 4895 items
# consuming the appliance 3 hours 29 minutes 60 seconds that equal to 12600 seconds or 840 items
#
# Days : 3 : Sat
# time to turn-on appliacne on 21 : 10 : 41 equal to 5082 items
# consuming the appliance 1 hours 41 minutes 51 seconds that equal to 6111 seconds or 407 items
#
# Days : 4 : Sun
# time to turn-on appliacne on 20 : 58 : 24 equal to 5033 items
# consuming the appliance 3 hours 32 minutes 50 seconds that equal to 12770 seconds or 851 items
#
# Days : 5 : Tue
# time to turn-on appliacne on 20 : 32 : 25 equal to 4929 items
# consuming the appliance 2 hours 29 minutes 13 seconds that equal to 8953 seconds or 596 items
#
# Days : 6 : Tue
# time to turn-on appliacne on 21 : 40 : 60 equal to 5203 items
# consuming the appliance 2 hours 33 minutes 21 seconds that equal to 9201 seconds or 613 items
#
# Days : 7 : Thu
# time to turn-on appliacne on 21 : 37 : 21 equal to 5189 items
# consuming the appliance 3 hours 36 minutes 18 seconds that equal to 12978 seconds or 865 items
#
# Days : 8 : Fri
# time to turn-on appliacne on 21 : 53 : 48 equal to 5255 items
# consuming the appliance 3 hours 20 minutes 11 seconds that equal to 12011 seconds or 800 items
#
# Days : 9 : Sat
# time to turn-on appliacne on 19 : 23 : 55 equal to 4655 items
# consuming the appliance 1 hours 45 minutes 12 seconds that equal to 6312 seconds or 420 items
#
# Days : 10 : Sat
# time to turn-on appliacne on 21 : 25 : 15 equal to 5140 items
# consuming the appliance 3 hours 48 minutes 54 seconds that equal to 13734 seconds or 915 items
#
# Days : 11 : Mon
# time to turn-on appliacne on 18 : 15 : 32 equal to 4382 items
# consuming the appliance 2 hours 21 minutes 39 seconds that equal to 8499 seconds or 566 items
#
# Days : 12 : Mon
# time to turn-on appliacne on 21 : 20 : 31 equal to 5122 items
# consuming the appliance 3 hours 52 minutes 47 seconds that equal to 13967 seconds or 931 items
#
# Days : 13 : Wed
# time to turn-on appliacne on 21 : 53 : 19 equal to 5253 items
# consuming the appliance 2 hours 57 minutes 32 seconds that equal to 10652 seconds or 710 items
#
# Days : 14 : Thu
# time to turn-on appliacne on 21 : 27 : 28 equal to 5149 items
# consuming the appliance 2 hours 29 minutes 49 seconds that equal to 8989 seconds or 599 items
#
# Days : 15 : Thu
# time to turn-on appliacne on 20 : 56 : 37 equal to 5026 items
# consuming the appliance 2 hours 22 minutes 42 seconds that equal to 8562 seconds or 570 items
#
# Days : 16 : Fri
# time to turn-on appliacne on 21 : 10 : 32 equal to 5082 items
# consuming the appliance 1 hours 56 minutes 18 seconds that equal to 6978 seconds or 465 items
#
# Days : 17 : Sat
# time to turn-on appliacne on 21 : 24 : 16 equal to 5137 items
# consuming the appliance 2 hours 30 minutes 13 seconds that equal to 9013 seconds or 600 items
#
# Days : 18 : Sun
# time to turn-on appliacne on 21 : 40 : 54 equal to 5203 items
# consuming the appliance 3 hours 31 minutes 14 seconds that equal to 12674 seconds or 844 items
#
# Days : 19 : Tue
# time to turn-on appliacne on 18 : 21 : 13 equal to 4404 items
# consuming the appliance 2 hours 53 minutes 46 seconds that equal to 10426 seconds or 695 items
#
# Days : 20 : Tue
# time to turn-on appliacne on 21 : 18 : 16 equal to 5113 items
# consuming the appliance 2 hours 46 minutes 10 seconds that equal to 9970 seconds or 664 items
#
# Days : 21 : Thu
# time to turn-on appliacne on 21 : 18 : 22 equal to 5113 items
# consuming the appliance 3 hours 22 minutes 32 seconds that equal to 12152 seconds or 810 items
#
# Days : 22 : Fri
# time to turn-on appliacne on 20 : 16 : 32 equal to 4866 items
# consuming the appliance 1 hours 25 minutes 59 seconds that equal to 5159 seconds or 343 items
#
# Days : 23 : Fri
# time to turn-on appliacne on 21 : 40 : 10 equal to 5200 items
# consuming the appliance 2 hours 19 minutes 40 seconds that equal to 8380 seconds or 558 items
#
# Days : 24 : Sat
# time to turn-on appliacne on 20 : 40 : 36 equal to 4962 items
# consuming the appliance 3 hours 32 minutes 22 seconds that equal to 12742 seconds or 849 items
#
# Days : 25 : Mon
# time to turn-on appliacne on 21 : 53 : 13 equal to 5252 items
# consuming the appliance 3 hours 51 minutes 35 seconds that equal to 13895 seconds or 926 items
#
# Days : 26 : Tue
# time to turn-on appliacne on 20 : 20 : 37 equal to 4882 items
# consuming the appliance 2 hours 16 minutes 52 seconds that equal to 8212 seconds or 547 items
#
# Days : 27 : Tue
# time to turn-on appliacne on 21 : 19 : 26 equal to 5117 items
# consuming the appliance 2 hours 34 minutes 18 seconds that equal to 9258 seconds or 617 items
#
# Days : 28 : Wed
# time to turn-on appliacne on 21 : 38 : 49 equal to 5195 items
# consuming the appliance 2 hours 51 minutes 18 seconds that equal to 10278 seconds or 685 items
#
# Days : 29 : Fri
# time to turn-on appliacne on 20 : 42 : 38 equal to 4970 items
# consuming the appliance 3 hours 26 minutes 57 seconds that equal to 12417 seconds or 827 items
#
# Days : 30 : Sat
# time to turn-on appliacne on 20 : 26 : 26 equal to 4905 items
# consuming the appliance 2 hours 55 minutes 38 seconds that equal to 10538 seconds or 702 items
#
# Days : 31 : Sat
# time to turn-on appliacne on 18 : 33 : 42 equal to 4454 items
# consuming the appliance 1 hours 54 minutes 40 seconds that equal to 6880 seconds or 458 items
# DONE!

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
# %matplotlib inline  


# query = "SELECT watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
query = "SELECT Timestamp,watt FROM device.Computer WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[5760*10])
df = pd.read_sql(query, conn, index_col=['Timestamp'])
fig, ax = plt.subplots()
ax.set_title('device.Computer ')
df.plot(ax=ax )
plt.show()
