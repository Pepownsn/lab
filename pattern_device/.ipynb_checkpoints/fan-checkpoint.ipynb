# %% [markdown]
# ### FAN | พัดลมตั้งพื้น 16 นิ้ว |
# ##### TYPE 3 " TURN ON EVERYDAY // 1-3 TIMES

# %% [markdown]
# ## NO. 2 (พัดลม)
# ![image](https://raw.githubusercontent.com/skyfighter/iHEMS/master/Device/pic/fan.png)

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random


d = 31

time_a = pd.date_range('2016-09-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-09-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####### set databases to empty #########
query_empty = """truncate table device.fan""" 
c.execute(query_empty)
print "device.fan are Empty!!! \n"

query = "SELECT watt FROM collected_info.2_fan WHERE no >= '%s'   AND no <= '%s'; "% (0,1016)
df = pd.read_sql(query, conn)
# print df.watt[5]

#### Random the number of turnon-time per day
def manytime():
    many  = ['1'] * 50 + ['2'] * 44 + ['3'] * 6  ## The number of turn-on time of this appliance 
    manytime = random.choice(many)
    print "\nDays :",days-1 ,":",time_b[j].strftime('%a')
    print "in recent day turn on fan",manytime,"times\n"
    if (int(manytime) == 1):
        x,y,endx,endy = 18,20,2,4  # fix turn on only in evening      
        open_hour =  random.randint(x, y)
        open_min =  random.randint(0, 59)
        open_sec =  random.randint(0, 59)
        if 0 < open_sec  <= 15:
            k = 0
        elif 15 < open_sec  <= 30:
            k = 1
        elif 30 < open_sec  <= 45:
            k = 2
        else:
            k = 3
        off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
        print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
        
        duration_hour =  random.randint(endx, endy)
        duration_min =  random.randint(0, 59)
        duration_sec =  random.randint(0, 59)
        seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
        no_item = seconds/15
        print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"
        return (off_item,no_item)

        
    elif (int(manytime) == 2):
        turn_duratrion  = ['1'] * 70 + ['2'] * 30       #### '1' turn-on morning and evening   OR  '2' turn-on 2 times in evening 
        howturn = random.choice(turn_duratrion)
#         print howturn
        if (int(howturn)== 1 ):
            x,y,endx,endy = 6,7,1,59
            open_hour =  random.randint(x, y)
            open_min =  random.randint(0, 59)
            open_sec =  random.randint(0, 59)
            if 0 < open_sec  <= 15:
                k = 0
            elif 15 < open_sec  <= 30:
                k = 1
            elif 30 < open_sec  <= 45:
                k = 2
            else:
                k = 3
            off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
            print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
            
            duration_hour =  random.randint(0, 0)
            duration_min =  random.randint(endx, endy)
            duration_sec =  random.randint(0, 59)
            seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
            no_item = seconds/15
            print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"

        
            
            x1,y1,endx1,endy1 = 18,20,2,4
            open_hour1 =  random.randint(x1, y1)
            open_min1 =  random.randint(0, 59)
            open_sec1 =  random.randint(0, 59)
            if 0 < open_sec1  <= 15:
                k = 0
            elif 15 < open_sec1  <= 30:
                k = 1
            elif 30 < open_sec1  <= 45:
                k = 2
            else:
                k = 3
            off_item1 = (int(open_hour1)*240) + (int(open_min1)*4)+ k 
            print "time to turn-on appliacne on",open_hour1,":",open_min1,":",open_sec1,"equal to",off_item1,"items"     
            
            duration_hour1 =  random.randint(endx1, endy1)
            duration_min1 =  random.randint(0, 59)
            duration_sec1 =  random.randint(0, 59)
            seconds1 = (duration_hour1*3600)+(duration_min1*60)+duration_sec1
            no_item1 = seconds1/15
            print "consuming the appliance", duration_hour1,"hours",duration_min1,"minutes",duration_sec1,"seconds that equal to",seconds1,"seconds or",no_item1,"items\n"

        else :
            x,y,endx,endy = 18,19,1,59
            open_hour =  random.randint(x, y)
            open_min =  random.randint(0, 59)
            open_sec =  random.randint(0, 59)
            if 0 < open_sec  <= 15:
                k = 0
            elif 15 < open_sec  <= 30:
                k = 1
            elif 30 < open_sec  <= 45:
                k = 2
            else:
                k = 3
            off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
            print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
            
            duration_hour =  random.randint(0, 0)
            duration_min =  random.randint(endx, endy)
            duration_sec =  random.randint(0, 59)
            seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
            no_item = seconds/15
            print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"

        
            x1,y1,endx1,endy1 = 20,22,1,4
            open_hour1 =  random.randint(x1, y1)
            open_min1 =  random.randint(0, 59)
            open_sec1 =  random.randint(0, 59)
            if 0 < open_sec1  <= 15:
                k = 0
            elif 15 < open_sec1  <= 30:
                k = 1
            elif 30 < open_sec1  <= 45:
                k = 2
            else:
                k = 3
            off_item1 = (int(open_hour1)*240) + (int(open_min1)*4)+ k 
            print "time to turn-on appliacne on",open_hour1,":",open_min1,":",open_sec1,"equal to",off_item1,"items"   
            
            duration_hour1 =  random.randint(endx1, endy1)
            duration_min1 =  random.randint(0, 59)
            duration_sec1 =  random.randint(0, 59)
            seconds1 = (duration_hour1*3600)+(duration_min1*60)+duration_sec1
            no_item1 = seconds1/15
            print "consuming the appliance", duration_hour1,"hours",duration_min1,"minutes",duration_sec1,"seconds that equal to",seconds1,"seconds or",no_item1,"items\n"

        return (off_item,no_item,off_item1,no_item1)        
    else:
        x,y,endx,endy = 6,7,30,60
        open_hour =  random.randint(x, y)
        open_min =  random.randint(0, 59)
        open_sec =  random.randint(0, 59)
        if 0 < open_sec  <= 15:
            k = 0
        elif 15 < open_sec  <= 30:
            k = 1
        elif 30 < open_sec  <= 45:
            k = 2
        else:
            k = 3
        off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
        print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
        
        duration_hour =  random.randint(0,0)
        duration_min =  random.randint(endx, endy)
        duration_sec =  random.randint(0, 59)
        seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
        no_item = seconds/15
        print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"

    
    
        x1,y1,endx1,endy1 = 18,19,1,59
        open_hour1 =  random.randint(x1, y1)
        open_min1 =  random.randint(0, 59)
        open_sec1 =  random.randint(0, 59)
        if 0 < open_sec1  <= 15:
            k = 0
        elif 15 < open_sec1  <= 30:
            k = 1
        elif 30 < open_sec1  <= 45:
            k = 2
        else:
            k = 3
        off_item1 = (int(open_hour1)*240) + (int(open_min1)*4)+ k 
        print "time to turn-on appliacne on",open_hour1,":",open_min1,":",open_sec1,"equal to",off_item1,"items" 
        duration_hour1 =  random.randint(0, 0)
        duration_min1 =  random.randint(endx1, endy1)
        duration_sec1 =  random.randint(0, 59)
        seconds1 = (duration_hour1*3600)+(duration_min1*60)+duration_sec1
        no_item1 = seconds1/15
        print "consuming the appliance", duration_hour1,"hours",duration_min1,"minutes",duration_sec1,"seconds that equal to",seconds1,"seconds or",no_item1,"items\n"
    
    
        x2,y2,endx2,endy2 = 20,22,1,4
        open_hour2 =  random.randint(x2, y2)
        open_min2 =  random.randint(0, 59)
        open_sec2 =  random.randint(0, 59)
        if 0 < open_sec2  <= 15:
            k = 0
        elif 15 < open_sec2  <= 30:
            k = 1
        elif 30 < open_sec2  <= 45:
            k = 2
        else:
            k = 3
        off_item2 = (int(open_hour2)*240) + (int(open_min2)*4)+ k 
        print "time to turn-on appliacne on",open_hour2,":",open_min2,":",open_sec2,"equal to",off_item2,"items" 
        duration_hour2 =  random.randint(endx2, endy2)
        duration_min2 =  random.randint(0, 59)
        duration_sec2 =  random.randint(0, 59)
        seconds2 = (duration_hour2*3600)+(duration_min2*60)+duration_sec2
        no_item2 = seconds2/15
        print "consuming the appliance", duration_hour2,"hours",duration_min2,"minutes",duration_sec2,"seconds that equal to",seconds2,"seconds or",no_item2,"items\n"
        return (off_item,no_item,off_item1,no_item1,off_item2,no_item2)    
    
    
        
days = 1
j = 0

## (off_item,no_item,off_item1,no_item1,off_item2,no_item2)    

turn = manytime()
while (j <= (5760*d)-1):   
    if (j == 5760+(5760*(days-1))):
        days +=1
        print "-------------------------ENd-----------------------------\n"
        turn = manytime()          
        
    if len(turn)==2:
        off_item = turn[0] 
        no_item = turn[1]
        if (off_item+(5760*(days-1)) <= j <= (no_item+off_item)+(5760*(days-1))):
            c.execute("INSERT INTO device.fan (Timestamp, watt) VALUES (%s, %s)",(time_b[j],random.randint(64, 68)))
            conn.commit()
            j += 1
        else:
            c.execute("INSERT INTO device.fan (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
            conn.commit()
            j += 1
        
    elif len(turn)==4:
        off_item = turn[0] 
        no_item = turn[1]
        off_item1 = turn[2] 
        no_item1 = turn[3]
        if (off_item+(5760*(days-1)) <= j <= (no_item+off_item)+(5760*(days-1)) or off_item1+(5760*(days-1)) <= j <= (no_item1+off_item1)+(5760*(days-1))):
            c.execute("INSERT INTO device.fan (Timestamp, watt) VALUES (%s, %s)",(time_b[j],random.randint(64, 68)))
            conn.commit()
            j += 1
        else:
            c.execute("INSERT INTO device.fan (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
            conn.commit()
            j += 1
             
    else:
        off_item = turn[0] 
        no_item = turn[1]
        off_item1 = turn[2] 
        no_item1 = turn[3]
        off_item2 = turn[4] 
        no_item2 = turn[5]
        
        if (off_item+(5760*(days-1)) <= j <= (no_item+off_item)+(5760*(days-1)) or off_item1+(5760*(days-1)) <= j <= (no_item1+off_item1)+(5760*(days-1)) or off_item2+(5760*(days-1)) <= j <= (no_item2+off_item2)+(5760*(days-1)))  :
            c.execute("INSERT INTO device.fan (Timestamp, watt) VALUES (%s, %s)",(time_b[j],random.randint(64, 68)))
            conn.commit()
            j += 1
        else:
            c.execute("INSERT INTO device.fan (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
            conn.commit()
            j += 1
 
           
print "DONE!"
# Out:
# device.fanare Empty!!!
#
#
# Days : 0 : Thu
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 6 : 53 : 9 equal to 1652 items
# consuming the appliance 0 hours 13 minutes 52 seconds that equal to 832 seconds or 55 items
#
# time to turn-on appliacne on 18 : 43 : 5 equal to 4492 items
# consuming the appliance 4 hours 40 minutes 43 seconds that equal to 16843 seconds or 1122 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 1 : Fri
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 6 : 40 : 23 equal to 1601 items
# consuming the appliance 0 hours 22 minutes 28 seconds that equal to 1348 seconds or 89 items
#
# time to turn-on appliacne on 20 : 46 : 20 equal to 4985 items
# consuming the appliance 4 hours 49 minutes 0 seconds that equal to 17340 seconds or 1156 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 2 : Sat
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 19 : 58 : 29 equal to 4793 items
# consuming the appliance 0 hours 28 minutes 8 seconds that equal to 1688 seconds or 112 items
#
# time to turn-on appliacne on 22 : 38 : 58 equal to 5435 items
# consuming the appliance 3 hours 51 minutes 46 seconds that equal to 13906 seconds or 927 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 3 : Sun
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 19 : 19 : 28 equal to 4637 items
# consuming the appliance 0 hours 56 minutes 42 seconds that equal to 3402 seconds or 226 items
#
# time to turn-on appliacne on 20 : 37 : 46 equal to 4951 items
# consuming the appliance 3 hours 21 minutes 42 seconds that equal to 12102 seconds or 806 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 4 : Mon
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 20 : 18 : 46 equal to 4875 items
# consuming the appliance 3 hours 40 minutes 39 seconds that equal to 13239 seconds or 882 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 5 : Tue
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 20 : 15 : 13 equal to 4860 items
# consuming the appliance 3 hours 13 minutes 29 seconds that equal to 11609 seconds or 773 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 6 : Wed
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 6 : 58 : 30 equal to 1673 items
# consuming the appliance 0 hours 24 minutes 31 seconds that equal to 1471 seconds or 98 items
#
# time to turn-on appliacne on 20 : 43 : 28 equal to 4973 items
# consuming the appliance 2 hours 17 minutes 20 seconds that equal to 8240 seconds or 549 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 7 : Thu
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 20 : 29 : 35 equal to 4918 items
# consuming the appliance 4 hours 32 minutes 6 seconds that equal to 16326 seconds or 1088 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 8 : Fri
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 7 : 43 : 1 equal to 1852 items
# consuming the appliance 0 hours 9 minutes 59 seconds that equal to 599 seconds or 39 items
#
# time to turn-on appliacne on 19 : 47 : 27 equal to 4749 items
# consuming the appliance 3 hours 3 minutes 17 seconds that equal to 10997 seconds or 733 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 9 : Sat
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 6 : 3 : 26 equal to 1453 items
# consuming the appliance 0 hours 13 minutes 1 seconds that equal to 781 seconds or 52 items
#
# time to turn-on appliacne on 19 : 46 : 27 equal to 4745 items
# consuming the appliance 4 hours 31 minutes 38 seconds that equal to 16298 seconds or 1086 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 10 : Sun
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 19 : 28 : 43 equal to 4674 items
# consuming the appliance 0 hours 59 minutes 21 seconds that equal to 3561 seconds or 237 items
#
# time to turn-on appliacne on 21 : 21 : 46 equal to 5127 items
# consuming the appliance 2 hours 53 minutes 0 seconds that equal to 10380 seconds or 692 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 11 : Mon
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 20 : 15 : 43 equal to 4862 items
# consuming the appliance 2 hours 1 minutes 25 seconds that equal to 7285 seconds or 485 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 12 : Tue
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 20 : 32 : 2 equal to 4928 items
# consuming the appliance 3 hours 58 minutes 18 seconds that equal to 14298 seconds or 953 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 13 : Wed
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 18 : 5 : 31 equal to 4342 items
# consuming the appliance 0 hours 9 minutes 14 seconds that equal to 554 seconds or 36 items
#
# time to turn-on appliacne on 22 : 46 : 24 equal to 5465 items
# consuming the appliance 2 hours 10 minutes 56 seconds that equal to 7856 seconds or 523 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 14 : Thu
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 18 : 45 : 46 equal to 4503 items
# consuming the appliance 4 hours 21 minutes 51 seconds that equal to 15711 seconds or 1047 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 15 : Fri
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 6 : 56 : 52 equal to 1667 items
# consuming the appliance 0 hours 18 minutes 42 seconds that equal to 1122 seconds or 74 items
#
# time to turn-on appliacne on 20 : 22 : 30 equal to 4889 items
# consuming the appliance 3 hours 28 minutes 12 seconds that equal to 12492 seconds or 832 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 16 : Sat
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 18 : 53 : 36 equal to 4534 items
# consuming the appliance 4 hours 33 minutes 50 seconds that equal to 16430 seconds or 1095 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 17 : Sun
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 7 : 39 : 50 equal to 1839 items
# consuming the appliance 0 hours 8 minutes 20 seconds that equal to 500 seconds or 33 items
#
# time to turn-on appliacne on 20 : 23 : 56 equal to 4895 items
# consuming the appliance 4 hours 41 minutes 39 seconds that equal to 16899 seconds or 1126 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 18 : Mon
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 18 : 30 : 22 equal to 4441 items
# consuming the appliance 0 hours 42 minutes 48 seconds that equal to 2568 seconds or 171 items
#
# time to turn-on appliacne on 21 : 4 : 56 equal to 5059 items
# consuming the appliance 4 hours 10 minutes 21 seconds that equal to 15021 seconds or 1001 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 19 : Tue
# in recent day turn on fan 3 times
#
# time to turn-on appliacne on 6 : 6 : 40 equal to 1466 items
# consuming the appliance 0 hours 52 minutes 59 seconds that equal to 3179 seconds or 211 items
#
# time to turn-on appliacne on 18 : 4 : 17 equal to 4337 items
# consuming the appliance 0 hours 58 minutes 44 seconds that equal to 3524 seconds or 234 items
#
# time to turn-on appliacne on 20 : 35 : 49 equal to 4943 items
# consuming the appliance 1 hours 21 minutes 22 seconds that equal to 4882 seconds or 325 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 20 : Wed
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 19 : 35 : 29 equal to 4701 items
# consuming the appliance 4 hours 11 minutes 7 seconds that equal to 15067 seconds or 1004 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 21 : Thu
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 7 : 3 : 54 equal to 1695 items
# consuming the appliance 0 hours 28 minutes 29 seconds that equal to 1709 seconds or 113 items
#
# time to turn-on appliacne on 19 : 23 : 24 equal to 4653 items
# consuming the appliance 4 hours 51 minutes 25 seconds that equal to 17485 seconds or 1165 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 22 : Fri
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 20 : 21 : 31 equal to 4886 items
# consuming the appliance 4 hours 17 minutes 28 seconds that equal to 15448 seconds or 1029 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 23 : Sat
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 20 : 2 : 19 equal to 4809 items
# consuming the appliance 2 hours 54 minutes 38 seconds that equal to 10478 seconds or 698 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 24 : Sun
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 6 : 37 : 31 equal to 1590 items
# consuming the appliance 0 hours 27 minutes 30 seconds that equal to 1650 seconds or 110 items
#
# time to turn-on appliacne on 19 : 4 : 21 equal to 4577 items
# consuming the appliance 4 hours 55 minutes 0 seconds that equal to 17700 seconds or 1180 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 25 : Mon
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 19 : 50 : 43 equal to 4762 items
# consuming the appliance 4 hours 4 minutes 52 seconds that equal to 14692 seconds or 979 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 26 : Tue
# in recent day turn on fan 3 times
#
# time to turn-on appliacne on 6 : 12 : 1 equal to 1488 items
# consuming the appliance 0 hours 47 minutes 38 seconds that equal to 2858 seconds or 190 items
#
# time to turn-on appliacne on 19 : 52 : 1 equal to 4768 items
# consuming the appliance 0 hours 13 minutes 5 seconds that equal to 785 seconds or 52 items
#
# time to turn-on appliacne on 21 : 41 : 35 equal to 5206 items
# consuming the appliance 1 hours 0 minutes 35 seconds that equal to 3635 seconds or 242 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 27 : Wed
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 7 : 22 : 34 equal to 1770 items
# consuming the appliance 0 hours 3 minutes 15 seconds that equal to 195 seconds or 13 items
#
# time to turn-on appliacne on 20 : 59 : 41 equal to 5038 items
# consuming the appliance 2 hours 50 minutes 8 seconds that equal to 10208 seconds or 680 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 28 : Thu
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 19 : 8 : 56 equal to 4595 items
# consuming the appliance 2 hours 8 minutes 49 seconds that equal to 7729 seconds or 515 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 29 : Fri
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 19 : 22 : 23 equal to 4649 items
# consuming the appliance 0 hours 7 minutes 50 seconds that equal to 470 seconds or 31 items
#
# time to turn-on appliacne on 20 : 4 : 48 equal to 4819 items
# consuming the appliance 3 hours 20 minutes 48 seconds that equal to 12048 seconds or 803 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 30 : Sat
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 7 : 47 : 10 equal to 1868 items
# consuming the appliance 0 hours 48 minutes 18 seconds that equal to 2898 seconds or 193 items
#
# time to turn-on appliacne on 18 : 58 : 41 equal to 4554 items
# consuming the appliance 2 hours 56 minutes 3 seconds that equal to 10563 seconds or 704 items
#
# DONE!

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
# %matplotlib inline  


query = "SELECT Timestamp,watt FROM device.fan WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[5760*5])
df = pd.read_sql(query, conn, index_col=['Timestamp'])
fig, ax = plt.subplots()
ax.set_title('device.fan ')
df.plot(ax=ax )
plt.show()
