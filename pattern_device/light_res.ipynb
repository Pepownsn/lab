# %% [markdown]
# ### ระบบหลอดไฟส่องสว่าง | LED 7 Watt |
# ##### TYPE 3 " TURN ON EVERYDAY//1-3 TIMES

# %% [markdown]
# ## NO. 15 (หลอดไฟ)
# ** LED 7 Watt **
# ![image](https://raw.githubusercontent.com/skyfighter/iHEMS/master/Device/pic/led.png)

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random

d = 1
time_a = pd.date_range('2016-09-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-09-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####### set databases to empty #########
query_empty = """truncate table device.light_res""" 
c.execute(query_empty)
print "device.light_res are Empty!!! \n"

query = "SELECT watt FROM device.water_heater WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[(5760*d)-1])
df = pd.read_sql(query, conn)


def manytime():
    many  =  ['2'] * 40 + ['3'] * 50 + ['4'] *5  ## The number of turn-on time of this appliance 
    manytime = random.choice(many)
    print "in recent day turn on light on restroom",manytime,"times\n"
    if (int(manytime) == 2):
        open_hour =  random.randint(7, 9)
        open_min =  random.randint(0, 59)
        open_sec =  random.randint(0, 59)
        if 0 < open_sec  <= 15:
            k = 0
        elif 15 < open_sec  <= 30:
            k = 1
        elif 30 < open_sec  <= 45:
            k = 2
        else:
            k = 3
        off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
        print "time to turn-on light on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
        
        duration_hour =  random.randint(0,1)
        duration_min =  random.randint(30, 59)
        duration_sec =  random.randint(0, 59)
        seconds = (int(duration_hour)*3600)+(duration_min*60)+duration_sec
        no_item = seconds/15
        print "consuming the appliance", int(duration_hour),"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"
        
        
        open_hour =  random.randint(22,23)
        open_min =  random.randint(0, 59)
        open_sec =  random.randint(0, 59)
        if 0 < open_sec  <= 15:
            k = 0
        elif 15 < open_sec  <= 30:
            k = 1
        elif 30 < open_sec  <= 45:
            k = 2
        else:
            k = 3
        off_item1 = (int(open_hour)*240) + (int(open_min)*4)+ k 
        print "time to turn-on light on",open_hour,":",open_min,":",open_sec,"equal to",off_item1,"items"
        
        duration_hour =  random.randint(0,1)
        duration_min =  random.randint(0, 59)
        duration_sec =  random.randint(0, 59)
        seconds1 = (duration_hour*3600)+(duration_min*60)+duration_sec
        no_item1 = seconds1/15
        print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds1,"seconds or",no_item1,"items\n"
       
        return (off_item,no_item,off_item1,no_item1)

        
    elif (int(manytime) == 3):
        open_hour =  random.randint(7, 9)
        open_min =  random.randint(0, 59)
        open_sec =  random.randint(0, 59)
        if 0 < open_sec  <= 15:
            k = 0
        elif 15 < open_sec  <= 30:
            k = 1
        elif 30 < open_sec  <= 45:
            k = 2
        else:
            k = 3
        off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
        print "time to turn-on light on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
        
        duration_hour =  random.randint(0,1)
        duration_min =  random.randint(0, 59)
        duration_sec =  random.randint(0, 59)
        seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
        no_item = seconds/15
        print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"
        
        
        open_hour =  random.randint(18,18)
        open_min =  random.randint(0, 59)
        open_sec =  random.randint(0, 59)
        if 0 < open_sec  <= 15:
            k = 0
        elif 15 < open_sec  <= 30:
            k = 1
        elif 30 < open_sec  <= 45:
            k = 2
        else:
            k = 3
        off_item1 = (int(open_hour)*240) + (int(open_min)*4)+ k 
        print "time to turn-on light on",open_hour,":",open_min,":",open_sec,"equal to",off_item1,"items"
        
        duration_hour =  random.randint(0,1)
        duration_min =  random.randint(0, 59)
        duration_sec =  random.randint(0, 59)
        seconds1 = (duration_hour*3600)+(duration_min*60)+duration_sec
        no_item1 = seconds1/15
        print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds1,"seconds or",no_item1,"items\n"
       
    
        open_hour =  random.randint(22,23)
        open_min =  random.randint(0, 59)
        open_sec =  random.randint(0, 59)
        if 0 < open_sec  <= 15:
            k = 0
        elif 15 < open_sec  <= 30:
            k = 1
        elif 30 < open_sec  <= 45:
            k = 2
        else:
            k = 3
        off_item2 = (int(open_hour)*240) + (int(open_min)*4)+ k 
        print "time to turn-on light on",open_hour,":",open_min,":",open_sec,"equal to",off_item2,"items"
        
        duration_hour =  random.randint(0,1)
        duration_min =  random.randint(0, 59)
        duration_sec =  random.randint(0, 59)
        seconds2 = (duration_hour*3600)+(duration_min*60)+duration_sec
        no_item2 = seconds1/15
        print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds2,"seconds or",no_item2,"items\n"
       
        return (off_item,no_item,off_item1,no_item1,off_item2,no_item2)
    
    else:
        
        open_hour =  random.randint(7, 9)
        open_min =  random.randint(0, 59)
        open_sec =  random.randint(0, 59)
        if 0 < open_sec  <= 15:
            k = 0
        elif 15 < open_sec  <= 30:
            k = 1
        elif 30 < open_sec  <= 45:
            k = 2
        else:
            k = 3
        off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
        print "time to turn-on light on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
        
        duration_hour =  random.randint(0,1)
        duration_min =  random.randint(0, 59)
        duration_sec =  random.randint(0, 59)
        seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
        no_item = seconds/15
        print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"
        
        
        open_hour =  random.randint(18,18)
        open_min =  random.randint(0, 59)
        open_sec =  random.randint(0, 59)
        if 0 < open_sec  <= 15:
            k = 0
        elif 15 < open_sec  <= 30:
            k = 1
        elif 30 < open_sec  <= 45:
            k = 2
        else:
            k = 3
        off_item1 = (int(open_hour)*240) + (int(open_min)*4)+ k 
        print "time to turn-on light on",open_hour,":",open_min,":",open_sec,"equal to",off_item1,"items"
        
       
        duration_hour =  random.randint(0,1)
        duration_min =  random.randint(0, 59)
        duration_sec =  random.randint(0, 59)
        seconds1 = (int(duration_hour)*3600)+(duration_min*60)+duration_sec
        no_item1 = seconds1/15
        print "consuming the appliance", int(duration_hour),"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds1,"seconds or",no_item1,"items\n"
       
    
        open_hour =  random.randint(22,23)
        open_min =  random.randint(0, 59)
        open_sec =  random.randint(0, 59)
        if 0 < open_sec  <= 15:
            k = 0
        elif 15 < open_sec  <= 30:
            k = 1
        elif 30 < open_sec  <= 45:
            k = 2
        else:
            k = 3
        off_item2 = (int(open_hour)*240) + (int(open_min)*4)+ k 
        print "time to turn-on light on",open_hour,":",open_min,":",open_sec,"equal to",off_item2,"items"
        
        duration_hour =  random.randint(0,1)
        duration_min =  random.randint(0, 59)
        duration_sec =  random.randint(0, 59)
        seconds2 = (duration_hour*3600)+(duration_min*60)+duration_sec
        no_item2 = seconds1/15
        print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds2,"seconds or",no_item2,"items\n"
        
        
        open_hour = random.randint(23,23)
        open_min =  random.randint(0, 59)
        open_sec =  random.randint(0, 59)
        if 0 < open_sec  <= 15:
            k = 0
        elif 15 < open_sec  <= 30:
            k = 1
        elif 30 < open_sec  <= 45:
            k = 2
        else:
            k = 3
        off_item3 = (int(open_hour)*240) + (int(open_min)*4)+ k 
        print "time to turn-on light on",open_hour,":",open_min,":",open_sec,"equal to",off_item3,"items"
       
        duration_hour = random.randint(0,0)
        duration_min =  random.randint(0, 10)
        duration_sec =  random.randint(0, 59)
        seconds3 = (duration_hour*3600)+(duration_min*60)+duration_sec
        no_item3 = seconds1/15
        print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds3,"seconds or",no_item3,"items\n"
        return (off_item,no_item,off_item1,no_item1,off_item2,no_item2,off_item3,no_item3)
days=0
j =0    



while  (j <= (5760*d)-1):
     
    if (j%5760 == 0):
        print "\nDays :",days ,":",time_b[j].strftime('%a')
        days +=1
        turn = manytime()  
        x= df.watt[5760*(days-1):5760+(5760*(days-1))]
        k =0
        sm =[]
        potsi = 0
        for  i in x  :
            if i == 0 :
                k += 1
                potsi +=1
            else:     
                sm.append(potsi)
                potsi +=1 
        print k,sm
               
       
    if ( k == 5760 ):    ##in this days not use water_heater
        if len(turn)== 4:
            off_item = turn[0] 
            no_item = turn[1]
            off_item1 = turn[2] 
            no_item1 = turn[3]
            if (off_item+(5760*(days-1)) <= j <= (no_item+off_item)+(5760*(days-1)) or off_item1+(5760*(days-1)) <= j <= (no_item1+off_item1)+(5760*(days-1))):
                c.execute("INSERT INTO device.light_res (Timestamp, watt) VALUES (%s, %s)",(time_b[j],2))
                conn.commit()
                j += 1
                print "|",
            else:
                c.execute("INSERT INTO device.light_res(Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
                conn.commit()
                j += 1
                
        elif len(turn)== 6:
            off_item = turn[0] 
            no_item = turn[1]
            off_item1 = turn[2] 
            no_item1 = turn[3]
            off_item2 = turn[4] 
            no_item2 = turn[5]     
            if (off_item+(5760*(days-1)) <= j <= (no_item+off_item)+(5760*(days-1)) or off_item1+(5760*(days-1)) <= j <= (no_item1+off_item1)+(5760*(days-1)) or off_item2+(5760*(days-1)) <= j <= (no_item2+off_item2)+(5760*(days-1)))  :
                c.execute("INSERT INTO device.light_res(Timestamp, watt) VALUES (%s, %s)",(time_b[j],2))
                conn.commit()
                j += 1
                print "|2",
            else:
                c.execute("INSERT INTO device.light_res (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
                conn.commit()
                j += 1
       
        elif len(turn)== 8:
            off_item = turn[0] 
            no_item = turn[1]
            off_item1 = turn[2] 
            no_item1 = turn[3]
            off_item2 = turn[4] 
            no_item2 = turn[5]  
            off_item3 = turn[6] 
            no_item3 = turn[7] 
            if (off_item+(5760*(days-1)) <= j <= (no_item+off_item)+(5760*(days-1)) or off_item1+(5760*(days-1)) <= j <= (no_item1+off_item1)+(5760*(days-1)) or off_item2+(5760*(days-1)) <= j <= (no_item2+off_item2)+(5760*(days-1)) or off_item3+(5760*(days-1)) <= j <= (no_item3+off_item3)+(5760*(days-1))):
                c.execute("INSERT INTO device.light_res (Timestamp, watt) VALUES (%s, %s)",(time_b[j],2))
                conn.commit()
                j += 1
                print "|3",
            else:
                c.execute("INSERT INTO device.light_res(Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
                conn.commit()
                j += 1        
      
#     else:
       
        
    j += 1                
print "DONE!"
# Out:
# device.light_res are Empty!!!
#
#
# Days : 0 : Thu
# in recent day turn on light on restroom 2 times
#
# time to turn-on light on 9 : 53 : 49 equal to 2375 items
# consuming the appliance 0 hours 55 minutes 4 seconds that equal to 3304 seconds or 220 items
#
# time to turn-on light on 23 : 13 : 18 equal to 5573 items
# consuming the appliance 1 hours 46 minutes 20 seconds that equal to 6380 seconds or 425 items
#
# 5711 [1831, 1832, 1833, 1834, 1835, 1836, 1837, 1838, 1839, 1840, 1841, 1842, 1843, 1844, 1845, 1846, 1847, 1848, 1849, 1850, 1851, 1852, 1853, 1854, 1855, 1856, 1857, 1858, 1859, 1860, 1861, 1862, 1863, 1864, 1865, 1866, 1867, 5715, 5716, 5717, 5718, 5719, 5720, 5721, 5722, 5723, 5724, 5725, 5726]
# DONE!

# %%
sm[1]-sm[0]
# Out:
# 1

# %%
import matplotlib.pyplot as plt
# %matplotlib inline  


# query = "SELECT watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
query = "SELECT Timestamp,watt FROM device.light_res WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "%(time_a[0],time_b[j-1])
df = pd.read_sql(query, conn, index_col=['Timestamp'])
fig, ax = plt.subplots()
ax.set_title('device.light_res')
df.plot(ax=ax )
plt.show()
df.to_csv('file.csv')
print len(df)

# %%
print len(sm)
print sm

i =0
count = 0
while i<= len(sm)-1:
    if sm[i]-sm[i-1] ==1 :
        i+=1
    else:
        count +=1
        i+=1
print "done"
print count
# Out:
# 49
# [1831, 1832, 1833, 1834, 1835, 1836, 1837, 1838, 1839, 1840, 1841, 1842, 1843, 1844, 1845, 1846, 1847, 1848, 1849, 1850, 1851, 1852, 1853, 1854, 1855, 1856, 1857, 1858, 1859, 1860, 1861, 1862, 1863, 1864, 1865, 1866, 1867, 5715, 5716, 5717, 5718, 5719, 5720, 5721, 5722, 5723, 5724, 5725, 5726]
# done
# 2
