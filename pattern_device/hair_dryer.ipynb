# %% [markdown]
# ### Hair_dryer | ขนาด ??? |
# ##### TYPE 2 " TURN ON EVERYDAY//ONCE TIME

# %% [markdown]
# ## NO. 11 (ไดร์ฟเป่าผม)
# * **เปิดเบอร์ 2 จากทั้งหมด 4 เบอร์ (เบอร์ 1 มีลมอย่างเดียวไม่ร้อน)**
# ![image](https://raw.githubusercontent.com/skyfighter/iHEMS/master/Device/pic/hairdryers.png)

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random


d = 31
time_a = pd.date_range('2016-09-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-09-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####### set databases to empty #########
query_empty = """truncate table device.hair_dryer""" 
c.execute(query_empty)
print "device.elec_thermos are Empty!!! \n"

query = "SELECT watt FROM collected_info.11_hair_dryer WHERE no >= '%s'   AND no <= '%s'; "% (0,1200)
df = pd.read_sql(query, conn)
# print df.watt[5]

#### Random the turning-on time appliances
def rand_turnon():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(0, 59)
    duration_hour1 = ['21'] * 40 + ['22'] *45 + ['23'] * 15
    duration_hour = random.choice(duration_hour1)     
    if 0 < duration_sec <= 15:
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
    off_item = (int(duration_hour)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on appliacne on",duration_hour,":",duration_min,":",duration_sec,"equal to",off_item,"items"
    return off_item

 
#### Random the off-duration appliances 
def rand_duration():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(30, 59)
    duration_hour1 = ['0'] * 50 + ['1'] * 1+ ['0'] * 49
    duration_hour = random.choice(duration_hour1)   
    seconds = (int(duration_hour)*3600)+(duration_min*60)+duration_sec
    no_item = seconds/15
    print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items"
    return no_item

days = 0
j = 0
i = 0
print "\nDays :",days ,":",time_b[j].strftime('%a')
off_item = rand_turnon()  
no_item = rand_duration()  

while (j <= (5760*d)-1):  
    c.execute("INSERT INTO device.hair_dryer (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
    conn.commit()
    j += 1 
    
    while (off_item+(5760*(days)) <= j <= (no_item+off_item)+(5760*(days))):                   
        c.execute("INSERT INTO device.hair_dryer (Timestamp, watt) VALUES (%s, %s)",(time_b[j],df.watt[i]))
        conn.commit()
        i += 1 
        j += 1
        if (j == (no_item+off_item)+(5760*(days))):
            days +=1
            print "\nDays :",days ,":",time_b[j].strftime('%a')
            off_item = rand_turnon()  
            no_item = rand_duration() 
            i= 0   

                    
print "DONE!"
# Out:
# device.elec_thermos are Empty!!!
#
#
# Days : 0 : Thu
# time to turn-on appliacne on 22 : 9 : 18 equal to 5317 items
# consuming the appliance 0 hours 47 minutes 9 seconds that equal to 2829 seconds or 188 items
#
# Days : 1 : Thu
# time to turn-on appliacne on 22 : 15 : 2 equal to 5340 items
# consuming the appliance 0 hours 54 minutes 18 seconds that equal to 3258 seconds or 217 items
#
# Days : 2 : Fri
# time to turn-on appliacne on 23 : 9 : 17 equal to 5557 items
# consuming the appliance 0 hours 37 minutes 14 seconds that equal to 2234 seconds or 148 items
#
# Days : 3 : Sat
# time to turn-on appliacne on 23 : 37 : 48 equal to 5671 items
# consuming the appliance 0 hours 30 minutes 51 seconds that equal to 1851 seconds or 123 items
#
# Days : 4 : Mon
# time to turn-on appliacne on 22 : 46 : 35 equal to 5466 items
# consuming the appliance 0 hours 57 minutes 12 seconds that equal to 3432 seconds or 228 items
#
# Days : 5 : Mon
# time to turn-on appliacne on 21 : 33 : 38 equal to 5174 items
# consuming the appliance 0 hours 38 minutes 38 seconds that equal to 2318 seconds or 154 items
#
# Days : 6 : Tue
# time to turn-on appliacne on 22 : 27 : 5 equal to 5388 items
# consuming the appliance 0 hours 58 minutes 17 seconds that equal to 3497 seconds or 233 items
#
# Days : 7 : Wed
# time to turn-on appliacne on 22 : 58 : 49 equal to 5515 items
# consuming the appliance 0 hours 50 minutes 25 seconds that equal to 3025 seconds or 201 items
#
# Days : 8 : Thu
# time to turn-on appliacne on 21 : 54 : 7 equal to 5256 items
# consuming the appliance 0 hours 52 minutes 31 seconds that equal to 3151 seconds or 210 items
#
# Days : 9 : Fri
# time to turn-on appliacne on 21 : 20 : 45 equal to 5122 items
# consuming the appliance 0 hours 40 minutes 34 seconds that equal to 2434 seconds or 162 items
#
# Days : 10 : Sat
# time to turn-on appliacne on 22 : 52 : 3 equal to 5488 items
# consuming the appliance 0 hours 31 minutes 40 seconds that equal to 1900 seconds or 126 items
#
# Days : 11 : Sun
# time to turn-on appliacne on 22 : 45 : 57 equal to 5463 items
# consuming the appliance 0 hours 58 minutes 31 seconds that equal to 3511 seconds or 234 items
#
# Days : 12 : Mon
# time to turn-on appliacne on 22 : 31 : 23 equal to 5405 items
# consuming the appliance 0 hours 40 minutes 56 seconds that equal to 2456 seconds or 163 items
#
# Days : 13 : Tue
# time to turn-on appliacne on 22 : 59 : 23 equal to 5517 items
# consuming the appliance 0 hours 33 minutes 45 seconds that equal to 2025 seconds or 135 items
#
# Days : 14 : Wed
# time to turn-on appliacne on 21 : 15 : 1 equal to 5100 items
# consuming the appliance 0 hours 34 minutes 16 seconds that equal to 2056 seconds or 137 items
#
# Days : 15 : Thu
# time to turn-on appliacne on 22 : 30 : 2 equal to 5400 items
# consuming the appliance 0 hours 54 minutes 3 seconds that equal to 3243 seconds or 216 items
#
# Days : 16 : Fri
# time to turn-on appliacne on 22 : 11 : 25 equal to 5325 items
# consuming the appliance 0 hours 46 minutes 58 seconds that equal to 2818 seconds or 187 items
#
# Days : 17 : Sat
# time to turn-on appliacne on 23 : 17 : 9 equal to 5588 items
# consuming the appliance 0 hours 47 minutes 33 seconds that equal to 2853 seconds or 190 items
#
# Days : 18 : Mon
# time to turn-on appliacne on 21 : 22 : 3 equal to 5128 items
# consuming the appliance 0 hours 39 minutes 1 seconds that equal to 2341 seconds or 156 items
#
# Days : 19 : Mon
# time to turn-on appliacne on 21 : 28 : 22 equal to 5153 items
# consuming the appliance 0 hours 32 minutes 48 seconds that equal to 1968 seconds or 131 items
#
# Days : 20 : Tue
# time to turn-on appliacne on 22 : 30 : 23 equal to 5401 items
# consuming the appliance 0 hours 53 minutes 30 seconds that equal to 3210 seconds or 214 items
#
# Days : 21 : Wed
# time to turn-on appliacne on 21 : 50 : 15 equal to 5240 items
# consuming the appliance 0 hours 52 minutes 23 seconds that equal to 3143 seconds or 209 items
#
# Days : 22 : Thu
# time to turn-on appliacne on 22 : 47 : 39 equal to 5470 items
# consuming the appliance 0 hours 44 minutes 30 seconds that equal to 2670 seconds or 178 items
#
# Days : 23 : Fri
# time to turn-on appliacne on 22 : 30 : 29 equal to 5401 items
# consuming the appliance 0 hours 41 minutes 56 seconds that equal to 2516 seconds or 167 items
#
# Days : 24 : Sat
# time to turn-on appliacne on 22 : 22 : 8 equal to 5368 items
# consuming the appliance 0 hours 46 minutes 44 seconds that equal to 2804 seconds or 186 items
#
# Days : 25 : Sun
# time to turn-on appliacne on 22 : 22 : 12 equal to 5368 items
# consuming the appliance 0 hours 54 minutes 37 seconds that equal to 3277 seconds or 218 items
#
# Days : 26 : Mon
# time to turn-on appliacne on 21 : 55 : 5 equal to 5260 items
# consuming the appliance 0 hours 53 minutes 37 seconds that equal to 3217 seconds or 214 items
#
# Days : 27 : Tue
# time to turn-on appliacne on 22 : 50 : 13 equal to 5480 items
# consuming the appliance 0 hours 34 minutes 26 seconds that equal to 2066 seconds or 137 items
#
# Days : 28 : Wed
# time to turn-on appliacne on 22 : 8 : 37 equal to 5314 items
# consuming the appliance 0 hours 52 minutes 54 seconds that equal to 3174 seconds or 211 items
#
# Days : 29 : Thu
# time to turn-on appliacne on 21 : 16 : 40 equal to 5106 items
# consuming the appliance 0 hours 47 minutes 44 seconds that equal to 2864 seconds or 190 items
#
# Days : 30 : Fri
# time to turn-on appliacne on 21 : 37 : 47 equal to 5191 items
# consuming the appliance 0 hours 36 minutes 30 seconds that equal to 2190 seconds or 146 items
#
# Days : 31 : Sat
# time to turn-on appliacne on 23 : 1 : 27 equal to 5525 items
# consuming the appliance 0 hours 45 minutes 8 seconds that equal to 2708 seconds or 180 items
# DONE!

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
# %matplotlib inline  


# query = "SELECT watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
query = "SELECT Timestamp,watt FROM device.hair_dryer WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[5000],time_b[5760])
df = pd.read_sql(query, conn, index_col=['Timestamp'])
fig, ax = plt.subplots()
ax.set_title('device.hair_dryer')
df.plot(ax=ax )
plt.show()
