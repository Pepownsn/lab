# %% [markdown]
# ## data_month2
# #### Microwave | ขนาด 400W |

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random


d = 31
time_a = pd.date_range('2016-11-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-11-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####### set databases to empty #########
query_empty = """truncate table data_month2.Microwave""" 
c.execute(query_empty)
print "data_month2.Microwave are Empty!!! \n"

query = "SELECT watt FROM collected_info.12_Microwave WHERE no >= '%s'   AND no <= '%s'; "% (0,1300)
df = pd.read_sql(query, conn)
# print df.watt[5]

#### Random the turning-on time appliances
def rand_turnon():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(0, 59)
    duration_hour1 = ['18'] * 40 + ['19'] * 45 + ['20'] * 12 + ['21'] * 3
    duration_hour = random.choice(duration_hour1)     
    if 0 < duration_sec <= 15:
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
    off_item = (int(duration_hour)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on appliacne on",duration_hour,":",duration_min,":",duration_sec,"equal to",off_item,"items"
    return off_item

 
#### Random the off-duration appliances 
def rand_duration():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(10, 40)
    duration_hour1 = ['0'] * 50 + ['0'] * 1+ ['0'] * 49
    duration_hour = random.choice(duration_hour1)   
    seconds = (int(duration_hour)*3600)+(duration_min*60)+duration_sec
    no_item = seconds/15
    print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items"
    return no_item

days = 0
j = 0
i = 0
print "\nDays :",days ,":",time_b[j].strftime('%a')
off_item = rand_turnon()  
no_item = rand_duration()  

while (j <= (5760*d)-1):  
    c.execute("INSERT INTO data_month2.Microwave (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
    conn.commit()
    j += 1 
    
    while (off_item+(5760*(days)) <= j <= (no_item+off_item)+(5760*(days))):                   
        c.execute("INSERT INTO data_month2.Microwave (Timestamp, watt) VALUES (%s, %s)",(time_b[j],df.watt[i]))
        conn.commit()
        i += 1 
        j += 1
        if (j == (no_item+off_item)+(5760*(days))):
            days +=1
            print "\nDays :",days ,":",time_b[j].strftime('%a')
            off_item = rand_turnon()  
            no_item = rand_duration() 
            i= 0   

                    
print "DONE!"
# Out:
# data_month2.Microwave are Empty!!!
#
#
# Days : 0 : Tue
# time to turn-on appliacne on 18 : 38 : 9 equal to 4472 items
# consuming the appliance 0 hours 39 minutes 49 seconds that equal to 2389 seconds or 159 items
#
# Days : 1 : Tue
# time to turn-on appliacne on 18 : 44 : 17 equal to 4497 items
# consuming the appliance 0 hours 37 minutes 30 seconds that equal to 2250 seconds or 150 items
#
# Days : 2 : Wed
# time to turn-on appliacne on 19 : 56 : 14 equal to 4784 items
# consuming the appliance 0 hours 17 minutes 37 seconds that equal to 1057 seconds or 70 items
#
# Days : 3 : Thu
# time to turn-on appliacne on 20 : 34 : 58 equal to 4939 items
# consuming the appliance 0 hours 40 minutes 41 seconds that equal to 2441 seconds or 162 items
#
# Days : 4 : Fri
# time to turn-on appliacne on 20 : 19 : 15 equal to 4876 items
# consuming the appliance 0 hours 40 minutes 13 seconds that equal to 2413 seconds or 160 items
#
# Days : 5 : Sat
# time to turn-on appliacne on 19 : 18 : 29 equal to 4633 items
# consuming the appliance 0 hours 14 minutes 30 seconds that equal to 870 seconds or 58 items
#
# Days : 6 : Sun
# time to turn-on appliacne on 19 : 40 : 50 equal to 4723 items
# consuming the appliance 0 hours 40 minutes 42 seconds that equal to 2442 seconds or 162 items
#
# Days : 7 : Mon
# time to turn-on appliacne on 18 : 0 : 4 equal to 4320 items
# consuming the appliance 0 hours 15 minutes 11 seconds that equal to 911 seconds or 60 items
#
# Days : 8 : Tue
# time to turn-on appliacne on 19 : 27 : 38 equal to 4670 items
# consuming the appliance 0 hours 18 minutes 11 seconds that equal to 1091 seconds or 72 items
#
# Days : 9 : Wed
# time to turn-on appliacne on 18 : 56 : 46 equal to 4547 items
# consuming the appliance 0 hours 28 minutes 49 seconds that equal to 1729 seconds or 115 items
#
# Days : 10 : Thu
# time to turn-on appliacne on 20 : 51 : 29 equal to 5005 items
# consuming the appliance 0 hours 13 minutes 6 seconds that equal to 786 seconds or 52 items
#
# Days : 11 : Fri
# time to turn-on appliacne on 20 : 17 : 15 equal to 4868 items
# consuming the appliance 0 hours 15 minutes 30 seconds that equal to 930 seconds or 62 items
#
# Days : 12 : Sat
# time to turn-on appliacne on 18 : 51 : 26 equal to 4525 items
# consuming the appliance 0 hours 32 minutes 30 seconds that equal to 1950 seconds or 130 items
#
# Days : 13 : Sun
# time to turn-on appliacne on 18 : 24 : 4 equal to 4416 items
# consuming the appliance 0 hours 10 minutes 11 seconds that equal to 611 seconds or 40 items
#
# Days : 14 : Mon
# time to turn-on appliacne on 19 : 56 : 5 equal to 4784 items
# consuming the appliance 0 hours 40 minutes 33 seconds that equal to 2433 seconds or 162 items
#
# Days : 15 : Tue
# time to turn-on appliacne on 18 : 26 : 3 equal to 4424 items
# consuming the appliance 0 hours 25 minutes 41 seconds that equal to 1541 seconds or 102 items
#
# Days : 16 : Wed
# time to turn-on appliacne on 19 : 21 : 58 equal to 4647 items
# consuming the appliance 0 hours 21 minutes 3 seconds that equal to 1263 seconds or 84 items
#
# Days : 17 : Thu
# time to turn-on appliacne on 20 : 33 : 48 equal to 4935 items
# consuming the appliance 0 hours 35 minutes 44 seconds that equal to 2144 seconds or 142 items
#
# Days : 18 : Fri
# time to turn-on appliacne on 19 : 52 : 51 equal to 4771 items
# consuming the appliance 0 hours 20 minutes 9 seconds that equal to 1209 seconds or 80 items
#
# Days : 19 : Sat
# time to turn-on appliacne on 18 : 5 : 3 equal to 4340 items
# consuming the appliance 0 hours 24 minutes 54 seconds that equal to 1494 seconds or 99 items
#
# Days : 20 : Sun
# time to turn-on appliacne on 18 : 17 : 7 equal to 4388 items
# consuming the appliance 0 hours 21 minutes 29 seconds that equal to 1289 seconds or 85 items
#
# Days : 21 : Mon
# time to turn-on appliacne on 20 : 12 : 54 equal to 4851 items
# consuming the appliance 0 hours 38 minutes 54 seconds that equal to 2334 seconds or 155 items
#
# Days : 22 : Tue
# time to turn-on appliacne on 20 : 33 : 17 equal to 4933 items
# consuming the appliance 0 hours 23 minutes 32 seconds that equal to 1412 seconds or 94 items
#
# Days : 23 : Wed
# time to turn-on appliacne on 19 : 50 : 12 equal to 4760 items
# consuming the appliance 0 hours 19 minutes 4 seconds that equal to 1144 seconds or 76 items
#
# Days : 24 : Thu
# time to turn-on appliacne on 18 : 33 : 58 equal to 4455 items
# consuming the appliance 0 hours 18 minutes 8 seconds that equal to 1088 seconds or 72 items
#
# Days : 25 : Fri
# time to turn-on appliacne on 19 : 4 : 55 equal to 4579 items
# consuming the appliance 0 hours 40 minutes 49 seconds that equal to 2449 seconds or 163 items
#
# Days : 26 : Sat
# time to turn-on appliacne on 19 : 15 : 23 equal to 4621 items
# consuming the appliance 0 hours 10 minutes 4 seconds that equal to 604 seconds or 40 items
#
# Days : 27 : Sun
# time to turn-on appliacne on 20 : 18 : 53 equal to 4875 items
# consuming the appliance 0 hours 10 minutes 46 seconds that equal to 646 seconds or 43 items
#
# Days : 28 : Mon
# time to turn-on appliacne on 18 : 58 : 42 equal to 4554 items
# consuming the appliance 0 hours 16 minutes 35 seconds that equal to 995 seconds or 66 items
#
# Days : 29 : Tue
# time to turn-on appliacne on 19 : 50 : 21 equal to 4761 items
# consuming the appliance 0 hours 35 minutes 6 seconds that equal to 2106 seconds or 140 items
#
# Days : 30 : Wed
# time to turn-on appliacne on 19 : 37 : 48 equal to 4711 items
# consuming the appliance 0 hours 11 minutes 36 seconds that equal to 696 seconds or 46 items
#
# Days : 31 : Thu
# time to turn-on appliacne on 19 : 57 : 26 equal to 4789 items
# consuming the appliance 0 hours 17 minutes 48 seconds that equal to 1068 seconds or 71 items
# DONE!

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
# %matplotlib inline  


# query = "SELECT watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
query = "SELECT Timestamp,watt FROM data_month2.Microwave WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
df = pd.read_sql(query, conn, index_col=['Timestamp'])
fig, ax = plt.subplots()
ax.set_title('data_month2.Microwave')
df.plot(ax=ax )
plt.show()
