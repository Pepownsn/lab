# %% [markdown]
# ## data_month2
# #### Hair_dryer | ขนาด ??? |

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random


d = 31
time_a = pd.date_range('2016-11-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-11-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####### set databases to empty #########
query_empty = """truncate table data_month2.hair_dryer""" 
c.execute(query_empty)
print "data_month2.elec_thermos are Empty!!! \n"

query = "SELECT watt FROM collected_info.11_hair_dryer WHERE no >= '%s'   AND no <= '%s'; "% (0,1200)
df = pd.read_sql(query, conn)
# print df.watt[5]

#### Random the turning-on time appliances
def rand_turnon():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(0, 59)
    duration_hour1 = ['21'] * 40 + ['22'] *45 + ['23'] * 15
    duration_hour = random.choice(duration_hour1)     
    if 0 < duration_sec <= 15:
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
    off_item = (int(duration_hour)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on appliacne on",duration_hour,":",duration_min,":",duration_sec,"equal to",off_item,"items"
    return off_item

 
#### Random the off-duration appliances 
def rand_duration():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(30, 59)
    duration_hour1 = ['0'] * 50 + ['1'] * 1+ ['0'] * 49
    duration_hour = random.choice(duration_hour1)   
    seconds = (int(duration_hour)*3600)+(duration_min*60)+duration_sec
    no_item = seconds/15
    print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items"
    return no_item

days = 0
j = 0
i = 0
print "\nDays :",days ,":",time_b[j].strftime('%a')
off_item = rand_turnon()  
no_item = rand_duration()  

while (j <= (5760*d)-1):  
    c.execute("INSERT INTO data_month2.hair_dryer (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
    conn.commit()
    j += 1 
    
    while (off_item+(5760*(days)) <= j <= (no_item+off_item)+(5760*(days))):                   
        c.execute("INSERT INTO data_month2.hair_dryer (Timestamp, watt) VALUES (%s, %s)",(time_b[j],df.watt[i]))
        conn.commit()
        i += 1 
        j += 1
        if (j == (no_item+off_item)+(5760*(days))):
            days +=1
            print "\nDays :",days ,":",time_b[j].strftime('%a')
            off_item = rand_turnon()  
            no_item = rand_duration() 
            i= 0   

                    
print "DONE!"
# Out:
# data_month2.elec_thermos are Empty!!!
#
#
# Days : 0 : Tue
# time to turn-on appliacne on 23 : 7 : 28 equal to 5549 items
# consuming the appliance 0 hours 30 minutes 32 seconds that equal to 1832 seconds or 122 items
#
# Days : 1 : Tue
# time to turn-on appliacne on 23 : 47 : 56 equal to 5711 items
# consuming the appliance 0 hours 55 minutes 56 seconds that equal to 3356 seconds or 223 items
#
# Days : 2 : Thu
# time to turn-on appliacne on 22 : 48 : 0 equal to 5475 items
# consuming the appliance 0 hours 48 minutes 53 seconds that equal to 2933 seconds or 195 items
#
# Days : 3 : Thu
# time to turn-on appliacne on 21 : 21 : 32 equal to 5126 items
# consuming the appliance 0 hours 31 minutes 35 seconds that equal to 1895 seconds or 126 items
#
# Days : 4 : Fri
# time to turn-on appliacne on 22 : 19 : 21 equal to 5357 items
# consuming the appliance 0 hours 58 minutes 39 seconds that equal to 3519 seconds or 234 items
#
# Days : 5 : Sat
# time to turn-on appliacne on 22 : 23 : 4 equal to 5372 items
# consuming the appliance 0 hours 30 minutes 57 seconds that equal to 1857 seconds or 123 items
#
# Days : 6 : Sun
# time to turn-on appliacne on 22 : 31 : 38 equal to 5406 items
# consuming the appliance 0 hours 42 minutes 49 seconds that equal to 2569 seconds or 171 items
#
# Days : 7 : Mon
# time to turn-on appliacne on 22 : 13 : 41 equal to 5334 items
# consuming the appliance 0 hours 49 minutes 34 seconds that equal to 2974 seconds or 198 items
#
# Days : 8 : Tue
# time to turn-on appliacne on 23 : 54 : 36 equal to 5738 items
# consuming the appliance 0 hours 46 minutes 25 seconds that equal to 2785 seconds or 185 items
#
# Days : 9 : Thu
# time to turn-on appliacne on 21 : 30 : 51 equal to 5163 items
# consuming the appliance 0 hours 46 minutes 9 seconds that equal to 2769 seconds or 184 items
#
# Days : 10 : Thu
# time to turn-on appliacne on 21 : 48 : 57 equal to 5235 items
# consuming the appliance 0 hours 58 minutes 26 seconds that equal to 3506 seconds or 233 items
#
# Days : 11 : Fri
# time to turn-on appliacne on 21 : 41 : 44 equal to 5206 items
# consuming the appliance 0 hours 59 minutes 36 seconds that equal to 3576 seconds or 238 items
#
# Days : 12 : Sat
# time to turn-on appliacne on 21 : 4 : 14 equal to 5056 items
# consuming the appliance 0 hours 51 minutes 14 seconds that equal to 3074 seconds or 204 items
#
# Days : 13 : Sun
# time to turn-on appliacne on 21 : 58 : 25 equal to 5273 items
# consuming the appliance 0 hours 49 minutes 16 seconds that equal to 2956 seconds or 197 items
#
# Days : 14 : Mon
# time to turn-on appliacne on 21 : 1 : 35 equal to 5046 items
# consuming the appliance 0 hours 57 minutes 35 seconds that equal to 3455 seconds or 230 items
#
# Days : 15 : Tue
# time to turn-on appliacne on 22 : 42 : 34 equal to 5450 items
# consuming the appliance 0 hours 40 minutes 57 seconds that equal to 2457 seconds or 163 items
#
# Days : 16 : Wed
# time to turn-on appliacne on 21 : 37 : 17 equal to 5189 items
# consuming the appliance 0 hours 55 minutes 48 seconds that equal to 3348 seconds or 223 items
#
# Days : 17 : Thu
# time to turn-on appliacne on 21 : 47 : 37 equal to 5230 items
# consuming the appliance 0 hours 41 minutes 9 seconds that equal to 2469 seconds or 164 items
#
# Days : 18 : Fri
# time to turn-on appliacne on 23 : 38 : 1 equal to 5672 items
# consuming the appliance 0 hours 51 minutes 3 seconds that equal to 3063 seconds or 204 items
#
# Days : 19 : Sun
# time to turn-on appliacne on 22 : 12 : 48 equal to 5331 items
# consuming the appliance 0 hours 35 minutes 43 seconds that equal to 2143 seconds or 142 items
#
# Days : 20 : Sun
# time to turn-on appliacne on 23 : 56 : 15 equal to 5744 items
# consuming the appliance 0 hours 56 minutes 12 seconds that equal to 3372 seconds or 224 items
#
# Days : 21 : Tue
# time to turn-on appliacne on 21 : 2 : 53 equal to 5051 items
# consuming the appliance 0 hours 49 minutes 19 seconds that equal to 2959 seconds or 197 items
#
# Days : 22 : Tue
# time to turn-on appliacne on 21 : 58 : 10 equal to 5272 items
# consuming the appliance 0 hours 36 minutes 40 seconds that equal to 2200 seconds or 146 items
#
# Days : 23 : Wed
# time to turn-on appliacne on 21 : 11 : 47 equal to 5087 items
# consuming the appliance 0 hours 41 minutes 46 seconds that equal to 2506 seconds or 167 items
#
# Days : 24 : Thu
# time to turn-on appliacne on 21 : 25 : 27 equal to 5141 items
# consuming the appliance 0 hours 56 minutes 40 seconds that equal to 3400 seconds or 226 items
#
# Days : 25 : Fri
# time to turn-on appliacne on 21 : 38 : 56 equal to 5195 items
# consuming the appliance 0 hours 33 minutes 22 seconds that equal to 2002 seconds or 133 items
#
# Days : 26 : Sat
# time to turn-on appliacne on 23 : 20 : 45 equal to 5602 items
# consuming the appliance 0 hours 53 minutes 12 seconds that equal to 3192 seconds or 212 items
#
# Days : 27 : Mon
# time to turn-on appliacne on 21 : 26 : 22 equal to 5145 items
# consuming the appliance 0 hours 51 minutes 24 seconds that equal to 3084 seconds or 205 items
#
# Days : 28 : Mon
# time to turn-on appliacne on 22 : 28 : 12 equal to 5392 items
# consuming the appliance 0 hours 35 minutes 42 seconds that equal to 2142 seconds or 142 items
#
# Days : 29 : Tue
# time to turn-on appliacne on 21 : 41 : 42 equal to 5206 items
# consuming the appliance 0 hours 57 minutes 4 seconds that equal to 3424 seconds or 228 items
#
# Days : 30 : Wed
# time to turn-on appliacne on 21 : 47 : 22 equal to 5229 items
# consuming the appliance 0 hours 59 minutes 58 seconds that equal to 3598 seconds or 239 items
#
# Days : 31 : Thu
# time to turn-on appliacne on 21 : 25 : 48 equal to 5143 items
# consuming the appliance 0 hours 38 minutes 7 seconds that equal to 2287 seconds or 152 items
# DONE!

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
# %matplotlib inline  


# query = "SELECT watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
query = "SELECT Timestamp,watt FROM data_month2.hair_dryer WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[5000],time_b[5760*3])
df = pd.read_sql(query, conn, index_col=['Timestamp'])
fig, ax = plt.subplots()
ax.set_title('data_month2.hair_dryer')
df.plot(ax=ax )
plt.show()
