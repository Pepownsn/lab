# %% [markdown]
# ## data_month2
# #### เครื่องปรับอากาศ | 9000btu |

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random


d = 31
time_a = pd.date_range('2016-11-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-11-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####### set databases to empty #########
query_empty = """truncate table data_month2.aircont""" 
c.execute(query_empty)
print "data_month2.aircont are Empty!!! \n"

query = "SELECT watt FROM collected_info.1_aircont WHERE no >= '%s'   AND no <= '%s'; "% (0,3276)
df = pd.read_sql(query, conn)
# print df.watt[5]

#### Random the turning-on time appliances
def rand_turnon():
    duration_sec =  random.randint(10, 59)
    duration_min =  random.randint(10, 59)
    duration_hour1 = ['19'] * 5 + ['20'] * 50 + ['21'] * 43 +['22'] * 2     #SET Start 7-10 pm.
    duration_hour = random.choice(duration_hour1)     
    if 0 < duration_sec <= 15:
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
    off_item = (int(duration_hour)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on appliacne on",duration_hour,":",duration_min,":",duration_sec,"equal to",off_item,"items"
    return off_item

 
#### Random the off-duration appliances 
def rand_duration():
    duration_sec =  random.randint(10,59)
    duration_min =  random.randint(10, 59)
    duration_hour =  random.randint(6, 8)     #SET 6-8 Hours
    seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
    no_item = seconds/15
    print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items"
    return no_item

days = 0
j = 0
i = 0
print "\nDays :",days ,":",time_b[j].strftime('%a')
off_item = rand_turnon()  
no_item = rand_duration()  

while (j <= (5760*d)-1):    
    c.execute("INSERT INTO data_month2.aircont (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
    conn.commit()
    j += 1 
    
    while (off_item+(5760*(days)) <= j <= (no_item+off_item)+(5760*(days))):                   
        c.execute("INSERT INTO data_month2.aircont (Timestamp, watt) VALUES (%s, %s)",(time_b[j],df.watt[i]))
        conn.commit()
        i += 1 
        j += 1
        if (j == (no_item+off_item)+(5760*(days))):
            days +=1
            print "\nDays :",days ,":",time_b[j].strftime('%a')
            off_item = rand_turnon()  
            no_item = rand_duration() 
            i= 0   
                    
print "DONE!"
# Out:
# data_month2.aircont are Empty!!!
#
#
# Days : 0 : Tue
# time to turn-on appliacne on 21 : 52 : 22 equal to 5249 items
# consuming the appliance 8 hours 33 minutes 29 seconds that equal to 30809 seconds or 2053 items
#
# Days : 1 : Wed
# time to turn-on appliacne on 21 : 19 : 17 equal to 5117 items
# consuming the appliance 8 hours 20 minutes 39 seconds that equal to 30039 seconds or 2002 items
#
# Days : 2 : Thu
# time to turn-on appliacne on 20 : 35 : 39 equal to 4942 items
# consuming the appliance 7 hours 44 minutes 35 seconds that equal to 27875 seconds or 1858 items
#
# Days : 3 : Fri
# time to turn-on appliacne on 20 : 14 : 58 equal to 4859 items
# consuming the appliance 6 hours 26 minutes 16 seconds that equal to 23176 seconds or 1545 items
#
# Days : 4 : Sat
# time to turn-on appliacne on 20 : 53 : 26 equal to 5013 items
# consuming the appliance 7 hours 33 minutes 38 seconds that equal to 27218 seconds or 1814 items
#
# Days : 5 : Sun
# time to turn-on appliacne on 21 : 14 : 34 equal to 5098 items
# consuming the appliance 7 hours 54 minutes 52 seconds that equal to 28492 seconds or 1899 items
#
# Days : 6 : Mon
# time to turn-on appliacne on 21 : 17 : 56 equal to 5111 items
# consuming the appliance 6 hours 30 minutes 11 seconds that equal to 23411 seconds or 1560 items
#
# Days : 7 : Tue
# time to turn-on appliacne on 21 : 29 : 42 equal to 5158 items
# consuming the appliance 6 hours 32 minutes 44 seconds that equal to 23564 seconds or 1570 items
#
# Days : 8 : Wed
# time to turn-on appliacne on 21 : 27 : 42 equal to 5150 items
# consuming the appliance 7 hours 23 minutes 46 seconds that equal to 26626 seconds or 1775 items
#
# Days : 9 : Thu
# time to turn-on appliacne on 21 : 40 : 42 equal to 5202 items
# consuming the appliance 8 hours 29 minutes 40 seconds that equal to 30580 seconds or 2038 items
#
# Days : 10 : Fri
# time to turn-on appliacne on 20 : 49 : 37 equal to 4998 items
# consuming the appliance 7 hours 43 minutes 50 seconds that equal to 27830 seconds or 1855 items
#
# Days : 11 : Sat
# time to turn-on appliacne on 20 : 47 : 22 equal to 4989 items
# consuming the appliance 6 hours 16 minutes 41 seconds that equal to 22601 seconds or 1506 items
#
# Days : 12 : Sun
# time to turn-on appliacne on 20 : 47 : 16 equal to 4989 items
# consuming the appliance 6 hours 22 minutes 49 seconds that equal to 22969 seconds or 1531 items
#
# Days : 13 : Mon
# time to turn-on appliacne on 21 : 30 : 13 equal to 5160 items
# consuming the appliance 7 hours 10 minutes 43 seconds that equal to 25843 seconds or 1722 items
#
# Days : 14 : Tue
# time to turn-on appliacne on 21 : 35 : 15 equal to 5180 items
# consuming the appliance 6 hours 19 minutes 46 seconds that equal to 22786 seconds or 1519 items
#
# Days : 15 : Wed
# time to turn-on appliacne on 20 : 27 : 34 equal to 4910 items
# consuming the appliance 6 hours 14 minutes 56 seconds that equal to 22496 seconds or 1499 items
#
# Days : 16 : Thu
# time to turn-on appliacne on 21 : 12 : 12 equal to 5088 items
# consuming the appliance 7 hours 42 minutes 48 seconds that equal to 27768 seconds or 1851 items
#
# Days : 17 : Fri
# time to turn-on appliacne on 21 : 58 : 29 equal to 5273 items
# consuming the appliance 8 hours 55 minutes 31 seconds that equal to 32131 seconds or 2142 items
#
# Days : 18 : Sat
# time to turn-on appliacne on 21 : 59 : 49 equal to 5279 items
# consuming the appliance 8 hours 19 minutes 45 seconds that equal to 29985 seconds or 1999 items
#
# Days : 19 : Sun
# time to turn-on appliacne on 21 : 36 : 43 equal to 5186 items
# consuming the appliance 8 hours 49 minutes 59 seconds that equal to 31799 seconds or 2119 items
#
# Days : 20 : Mon
# time to turn-on appliacne on 20 : 36 : 16 equal to 4945 items
# consuming the appliance 6 hours 42 minutes 47 seconds that equal to 24167 seconds or 1611 items
#
# Days : 21 : Tue
# time to turn-on appliacne on 20 : 11 : 25 equal to 4845 items
# consuming the appliance 6 hours 53 minutes 49 seconds that equal to 24829 seconds or 1655 items
#
# Days : 22 : Wed
# time to turn-on appliacne on 22 : 40 : 56 equal to 5443 items
# consuming the appliance 7 hours 43 minutes 40 seconds that equal to 27820 seconds or 1854 items
#
# Days : 23 : Thu
# time to turn-on appliacne on 21 : 53 : 40 equal to 5254 items
# consuming the appliance 8 hours 57 minutes 59 seconds that equal to 32279 seconds or 2151 items
#
# Days : 24 : Fri
# time to turn-on appliacne on 21 : 13 : 12 equal to 5092 items
# consuming the appliance 8 hours 12 minutes 31 seconds that equal to 29551 seconds or 1970 items
#
# Days : 25 : Sat
# time to turn-on appliacne on 20 : 23 : 48 equal to 4895 items
# consuming the appliance 6 hours 23 minutes 55 seconds that equal to 23035 seconds or 1535 items
#
# Days : 26 : Sun
# time to turn-on appliacne on 20 : 32 : 37 equal to 4930 items
# consuming the appliance 7 hours 50 minutes 17 seconds that equal to 28217 seconds or 1881 items
#
# Days : 27 : Mon
# time to turn-on appliacne on 20 : 24 : 51 equal to 4899 items
# consuming the appliance 8 hours 16 minutes 49 seconds that equal to 29809 seconds or 1987 items
#
# Days : 28 : Tue
# time to turn-on appliacne on 20 : 41 : 56 equal to 4967 items
# consuming the appliance 6 hours 22 minutes 54 seconds that equal to 22974 seconds or 1531 items
#
# Days : 29 : Wed
# time to turn-on appliacne on 21 : 39 : 11 equal to 5196 items
# consuming the appliance 6 hours 57 minutes 19 seconds that equal to 25039 seconds or 1669 items
#
# Days : 30 : Thu
# time to turn-on appliacne on 20 : 38 : 19 equal to 4953 items
# consuming the appliance 7 hours 57 minutes 30 seconds that equal to 28650 seconds or 1910 items
# IndexErrorTraceback (most recent call last)
# <ipython-input-1-64b9715c4b04> in <module>()
#      67
#      68     while (off_item+(5760*(days)) <= j <= (no_item+off_item)+(5760*(days))):
# ---> 69         c.execute("INSERT INTO data_month2.aircont (Timestamp, watt) VALUES (%s, %s)",(time_b[j],df.watt[i]))
#      70         conn.commit()
#      71         i += 1
#
# /usr/local/lib/python2.7/dist-packages/pandas/tseries/base.pyc in __getitem__(self, key)
#     249         getitem = self._data.__getitem__
#     250         if is_int:
# --> 251             val = getitem(key)
#     252             return self._box_func(val)
#     253         else:
#
# IndexError: index 178560 is out of bounds for axis 0 with size 178560

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
# %matplotlib inline  

d = 31
time_a = pd.date_range('2016-11-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-11-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

# print time_b
# query = "SELECT watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
query = "SELECT Timestamp,watt FROM data_month2.Computer WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[5760*10])
df = pd.read_sql(query, conn, index_col=['Timestamp'])
fig, ax = plt.subplots()
ax.set_title(' data_month2.Computer ')
df.plot(ax=ax )
plt.show()
