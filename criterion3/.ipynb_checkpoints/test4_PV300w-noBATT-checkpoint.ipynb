# %% [markdown]
# ## TESTING 4 __  PV 300 W + no BATT

# %% [markdown]
# ##### RESTART KERNAL EVERY TIME  && RESET DATABASE

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
z = 0
m1 = 0
m2 = 0
m3 = 0
m4 = 0
m5 = 0
m6 = 0
m7 = 0
m8 = 0
m9 = 0  

def end(j):
    check =1
    m1 = j+1
    m2 = j+1
    m3 = j+1
    m4 = j+1
    m5 = j+1
    m6 = j+1
    m7 = j+1
    m8 = j+1
    m9 = j+1
    while (check == 1):
        while df1.Computer[m1] > 0:
            m1 += 1
        while df1.TV[m2] > 0:
            m2 += 1
        while  df1.Fan[m3] > 0:
            m3 += 1
        while df1.kitchen_light[m4] > 0:
            m4 += 1
        while df1.bedroom_light[m5] > 0:
            m5 += 1
        while df1.hair_dryer[m6] > 0:
            m6 += 1
        while df1.elec_thermos[m7] > 0:
            m7 += 1
        while df1.water_heater[m8] > 0:
            m8 += 1
        while df1.air[m9] > 0:
            m9 += 1
        check = 0
        print "\ncheck_end position processing done!"
        print m1,m2,m3,m4,m5,m6,m7,m8,m9
        return (m1,m2,m3,m4,m5,m6,m7,m8,m9)
    
    
def state(j,m1,m2,m3,m4,m5,m6,m7,m8,m9):
    if j <= m1:
        ans1 = df1.Computer[j]
    else:
        ans1 = 0
    if j <= m2:
        ans2 = df1.TV[j]
    else:
        ans2 = 0
    if j <= m3:
        ans3 = df1.Fan[j]
    else:
        ans3 = 0
    if j <= m4:
        ans4 = df1.kitchen_light[j]
    else:
        ans4 = 0
    if j <= m5:
        ans5 = df1.bedroom_light[j]
    else:
        ans5 = 0
    if j <= m6:
        ans6 = df1.hair_dryer[j]
    else:
        ans6 = 0
    if j <= m7:
        ans7 = df1.elec_thermos[j]
    else:
        ans7 = 0
    if j <= m8:
        ans8 = df1.water_heater[j]
    else:
        ans8 = 0
    if j <= m9:
        ans9 = df1.air[j]
    else:
        ans9 = 0
    k = ans1+ans2+ans3+ans4+ans5+ans6+ans7+ans8+ans9
    print "substact k watt out from watt = ",k,"watt"
    return k 

def initial_trend(series, slen):
    sum = 0.0
    for i in range(slen):
        sum += float(series[i+slen] - series[i]) / slen
    return sum / slen

def triple_exponential_smoothing(series, slen, alpha, beta, gamma, n_preds):
    result = []
    seasonals = initial_seasonal_components(series, slen)
    for i in range(len(series)+n_preds):
        if i == 0: # initial values
            smooth = series[0]
            trend = initial_trend(series, slen)
            result.append(series[0])
            continue
        if i >= len(series): # we are forecasting
            m = i - len(series) + 1
            result.append((smooth + m*trend) + seasonals[i%slen])
        else:
            val = series[i]
            last_smooth, smooth = smooth, alpha*(val-seasonals[i%slen]) + (1-alpha)*(smooth+trend)
            trend = beta * (smooth-last_smooth) + (1-beta)*trend
            seasonals[i%slen] = gamma*(val-smooth) + (1-gamma)*seasonals[i%slen]
            result.append(smooth+trend+seasonals[i%slen])
    return result


def initial_seasonal_components(series, slen):
    seasonals = {}
    season_averages = []
    n_seasons = int(len(series)/slen)
    # compute season averages
    for j in range(n_seasons):
        season_averages.append(sum(series[slen*j:slen*j+slen])/float(slen))
    # compute initial values
    for i in range(slen):
        sum_of_vals_over_avg = 0.0
        for j in range(n_seasons):
            sum_of_vals_over_avg += series[slen*j+i]-season_averages[j]
        seasonals[i] = sum_of_vals_over_avg/n_seasons
    return seasonals
##-----------------------------------------------------------------------------------

from sklearn.metrics import mean_squared_error
def fittingparameter(data_y,j):
    count_alpha = 0
    count_beta = 0
    count_gamma = 0
    alpha = float(0)
    beta = float(0)
    gamma = float(0)
    index_alpha =[]
    index_beta =[]
    index_gamma = []
    act = j
    data = data_y
    pred_no = 1
    ramda = 0.1
    MSE_holtload = []    
#     query1 = "SELECT Timestamp,watt FROM PVBATT.P15min_prediction_data WHERE Timestamp >= '%s' AND TimeStamp <= '%s';"% (time_b[act+1],time_b[act+96])
    query_last = "SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '%s' ;"% (time_b_last[act+1])
    print query_last
    df1 = pd.read_sql(query_last, conn)
    while (alpha <= float(1)):
        count_alpha += 1
        beta = float(0)
        while (beta <=float(1)):
            count_beta += 1 
            gamma = float(0)
            while (gamma <= float(1)):
                count_gamma += 1
                pred_h = triple_exponential_smoothing(data, 96*7,alpha,beta ,gamma, pred_no)
                pred_data = pred_h[len(pred_h)-(pred_no):]                                               
                MSE = mean_squared_error (df1.watt, pred_data)   
#                 print MSE              
                MSE_holtload.append(MSE)
                index_alpha.append(alpha)
                index_beta.append(beta)
                index_gamma.append(gamma)     
#                 print index_alpha,index_beta,index_gamma
                gamma += ramda
            beta += ramda
        alpha += ramda  
#     print  count_gamma,count_beta,count_alpha    
    index_MSE = MSE_holtload.index(min(MSE_holtload))
#     print min(MSE_holtload)
#     print index_MSE
    MSE_min = MSE_holtload[index_MSE]
    alpha = index_alpha[index_MSE]
    beta = index_beta[index_MSE]
    gamma= index_gamma[index_MSE]
#     print count_alpha,count_beta,count_gamma
    print "the minimum MSE of prediction =",MSE_min,"by alpha =",alpha,"beta =",beta,"gamma =",gamma
    return (alpha,beta,gamma)

## __________________________________________________________________________________________________________
pred_no = 1 # power 1 Data/15min in 1Hr --> 60/15 = 4 and 1day = 4*24 = 96
j = 0
d = 30

time_a_last = pd.date_range('2016-09-03 00:00:00', periods=96*58, freq='15T')
time_b_last = pd.date_range('2016-09-30 23:44:59', periods=96*58, freq='15T')

time_a = pd.date_range('2016-10-01 00:00:00', periods=96*d, freq='15T')
time_b = pd.date_range('2016-10-01 00:14:59', periods=96*d, freq='15T')

conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

query_empty = """truncate table PVBATT.test4_PV300noBATT""" 
c.execute(query_empty)
print "PVBATT.test4_PV300noBATT are Empty!!! \n"\


query1 = "SELECT *  FROM active.consum_load WHERE  Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a[0],time_b[(96*d)-1])
df1 = pd.read_sql(query1, conn)

query = "SELECT Timestamp,watt,PV FROM PVBATT.concluded_p15min WHERE Timestamp>='%s'AND Timestamp<='%s'; "%('2016-10-01 00:00:00','2016-10-30 23:59:59')
df = pd.read_sql(query, conn)
df['PV'] = ((df.PV/10)*1)

A = float(20)
discount = (100-A)/100
batt = float(0*1000)
k = 0
minbatt = batt * 0.2
maxbatt = batt
levelbatt = []
levelbatt.append(float(batt))
pv_watt = []
batt_watt = []
grid_watt = []
effi = float(1)
overpv = float(0)
sum_overpv = float(0)
charging_watt = float(0)
count_active = 0 

while ( j <= (96*d)-1 ):
    print "data at :" , j 
    print "______________________________________________________________________________________________\n",
    query_last = "\nSELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='%s'AND Timestamp<='%s'; "%(time_a_last[0],time_b_last[j])
    print query_last
    df_last = pd.read_sql(query_last, conn)
    conn.commit()
    data_y = df_last['watt'].values.tolist()   
    ans_fiting = fittingparameter(data_y,j)
    
    query_last_new = "SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='%s'AND Timestamp<='%s';"%(time_a_last[0],time_b_last[j+1])
    query_last_new_1 = "SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '%s' ;"% (time_b_last[j+2])
    print "______________________________________________________________________________________________"
    print "\n",query_last_new  
    print query_last_new_1
    print "BY USE alpha =",ans_fiting[0],"beta =",ans_fiting[1],"gamma =",ans_fiting[2]
    df_last_new = pd.read_sql(query_last_new, conn)
    conn.commit()
    data_y = df_last_new['watt'].values.tolist()     
    pred_h = triple_exponential_smoothing(data_y, 96*7, ans_fiting[0], ans_fiting[1], ans_fiting[2],1)
    pred_data = pred_h[len(pred_h)-(pred_no):]
#     c.execute("INSERT INTO PVBATT.P15min_prediction (Timestamp, watt) VALUES ( %s, %s)",(time_b[j+1],abs(pred_data[0])))
#     conn.commit()
    pred_watt = abs(pred_data[0])
    target = pred_watt*discount
    print "predicted watt is ",pred_watt ," |||||   targeted watt at t is ",target
    print "______________________________________________________________________________________________\n"
    
    if (df.PV[j] != 0):
        if (levelbatt[j] == maxbatt):
            batt_t = levelbatt[j] - minbatt
            watt = df.watt[j] - k
            if (df.PV[j] > watt):
                pv_watt.append(float(watt))
                batt_watt.append(float(0))
                grid_watt.append(float(0))
                levelbatt.append(float(levelbatt[j]))
                sub = target - float(0)
                overpv = df.PV[j] - watt
                sum_overpv += overpv
            else:
                lefted_pv = watt-df.PV[j]
                pv_watt.append(float(df.PV[j]))
                if (batt_t > lefted_pv):
                    batt_watt.append(float(lefted_pv))
                    grid_watt.append(float(0))
                    levelbatt.append(float(levelbatt[j]-lefted_pv))
                    sub = target - float(0)
                else:
                    lefted_batt = lefted_pv - batt_t
                    batt_watt.append(float(batt_t))
                    grid_watt.append(float(lefted_batt))
                    levelbatt.append(float(levelbatt[j]-batt_t))
                    sub = target - lefted_batt               
        else:
            batt_t = levelbatt[j] - minbatt
            watt = df.watt[j] - k
            if (df.PV[j] > watt):
                pv_watt.append(float(watt))
                batt_watt.append(float(0))
                grid_watt.append(float(0))
                charging_watt = df.PV[j] - watt
                missing_watt = maxbatt - levelbatt[j]
                if (charging_watt > missing_watt):
                    charging_watt = missing_watt
                else:
                    charging_watt = charging_watt
                levelbatt.append(float(levelbatt[j]+(charging_watt*effi)))
                sub = target - float(0)
                overpv = df.PV[j] - watt - charging_watt
                sum_overpv += overpv   
            else:
                lefted_pv = watt-df.PV[j]
                pv_watt.append(float(df.PV[j]))
                if (batt_t > lefted_pv):
                    batt_watt.append(float(lefted_pv))
                    grid_watt.append(float(0))
                    levelbatt.append(float(levelbatt[j]-lefted_pv))
                    sub = target - float(0)
                else:
                    lefted_batt = lefted_pv - batt_t
                    batt_watt.append(float(batt_t))
                    grid_watt.append(float(lefted_batt))
                    levelbatt.append(float(levelbatt[j]-batt_t))
                    sub = target - lefted_batt              
            
    else :
        if (levelbatt[j] > minbatt):
            batt_t = levelbatt[j] - minbatt
            watt = df.watt[j] - k 
            if (batt_t > watt):
                pv_watt.append(float(0))
                batt_watt.append(float(watt))
                grid_watt.append(float(0))
                levelbatt.append(float(levelbatt[j]-watt))
                sub = target - float(0)
            else:
                lefted_batt = watt - batt_t
                pv_watt.append(float(0))
                batt_watt.append(float(batt_t))
                grid_watt.append(float(lefted_batt))
                levelbatt.append(float(levelbatt[j]-batt_t))
                sub = target - float(lefted_batt)                
        else:
            watt = df.watt[j] - k 
            pv_watt.append(float(0))
            batt_watt.append(float(0))
            grid_watt.append(float(watt))
            levelbatt.append(float(levelbatt[j]))
            sub = target -  watt
            
    print "Consuming watt =",watt       
    print "PV_CONSUMPTION =",pv_watt[j]
    print "BATT_CONSUMPTION =",batt_watt[j]
    print "GRID_CONSUMPTION =",grid_watt[j]
    print "PREVIOUS LEVELBATT =",levelbatt[j],"||| LEFTED LEVELBATT =",levelbatt[j+1]   
    print "PV GENERATION =",df.PV[j],"||| BATT_CHARGING =",charging_watt
    
    

    
    c.execute("INSERT INTO PVBATT.test4_totalwatt (Timestamp, watt) VALUES ( %s, %s)",(time_b[j],watt))               
    conn.commit()   
    c.execute("INSERT INTO PVBATT.test4_PV300noBATT (Timestamp, load_watt,watt, predicted_watt, target,PV,charging_watt, levelbatt ,pv_watt , batt_watt,grid_watt,sum_load_watt) VALUES (%s, %s,%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)",
              (time_b[j],df.watt[j],watt,pred_watt,target,df.PV[j],charging_watt,levelbatt[j],pv_watt[j],batt_watt[j],grid_watt[j],pv_watt[j]+batt_watt[j]+grid_watt[j]))
    conn.commit()   
    
    if j == 0:
        sum_sub = sub
       
    else :
        sum_sub = sum_sub + sub   
    
    if sum_sub < 0:
        print "\n______________________________ sum_substract is NEGATIVE_NOW________________________________ "
        count_active += 1
        m = end(j)
        m1 = m[0]
        m1 -= 1
        m2 = m[1]
        m2 -= 1
        m3 = m[2]
        m3 -= 1
        m4 = m[3]
        m4 -= 1
        m5 = m[4]
        m5 -= 1
        m6 = m[5]
        m6 -= 1
        m7 = m[6]
        m7 -= 1 
        m8 = m[7]
        m8 -= 1
        m9 = m[8]
        m9 -= 1
        j += 1
        k = state(j,m1,m2,m3,m4,m5,m6,m7,m8,m9)                      
    else: 
        print "\n______________________________ sum_substract is still POSITIVE_________________________________ "
        j += 1
        k = state(j,m1,m2,m3,m4,m5,m6,m7,m8,m9)  
    print "\n" 
    charging_watt = float(0)
    print "############################################END##################################################\n"
print "DONE!!"
# Out:
# PVBATT.test4_PV300noBATT are Empty!!!
#
# data at : 0
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-09-30 23:44:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-09-30 23:59:59' ;
# the minimum MSE of prediction = 0.0214982876656 by alpha = 0.7 beta = 0.4 gamma = 0.3
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-09-30 23:59:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 00:14:59' ;
# BY USE alpha = 0.7 beta = 0.4 gamma = 0.3
# predicted watt is  361.871487209  |||||   targeted watt at t is  289.497189767
# ______________________________________________________________________________________________
#
# Consuming watt = 304.675
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 304.675
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 1 1 1 1 1 1 1 1 1
# substact k watt out from watt =  0 watt
#
#
# ############################################END##################################################
#
# data at : 1
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-09-30 23:59:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 00:14:59' ;
# the minimum MSE of prediction = 0.255303434627 by alpha = 0.5 beta = 0.0 gamma = 0.6
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 00:14:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 00:29:59' ;
# BY USE alpha = 0.5 beta = 0.0 gamma = 0.6
# predicted watt is  270.268302536  |||||   targeted watt at t is  216.214642029
# ______________________________________________________________________________________________
#
# Consuming watt = 291.246
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 291.246
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 2 2 2 2 2 2 2 2 2
# substact k watt out from watt =  0 watt
#
#
# ############################################END##################################################
#
# data at : 2
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 00:14:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 00:29:59' ;
# the minimum MSE of prediction = 0.00428445696558 by alpha = 0.8 beta = 0.4 gamma = 0.6
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 00:29:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 00:44:59' ;
# BY USE alpha = 0.8 beta = 0.4 gamma = 0.6
# predicted watt is  294.985660208  |||||   targeted watt at t is  235.988528166
# ______________________________________________________________________________________________
#
# Consuming watt = 188.325
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 188.325
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 3 3 3 3 3 3 3 3 3
# substact k watt out from watt =  0 watt
#
#
# ############################################END##################################################
#
# data at : 3
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 00:29:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 00:44:59' ;
# the minimum MSE of prediction = 0.0556209125957 by alpha = 0.1 beta = 0.5 gamma = 0.4
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 00:44:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 00:59:59' ;
# BY USE alpha = 0.1 beta = 0.5 gamma = 0.4
# predicted watt is  230.243392381  |||||   targeted watt at t is  184.194713905
# ______________________________________________________________________________________________
#
# Consuming watt = 296.513
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 296.513
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 4 4 4 4 4 4 4 4 4
# substact k watt out from watt =  0 watt
#
#
# ############################################END##################################################
#
# data at : 4
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 00:44:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 00:59:59' ;
# the minimum MSE of prediction = 0.232768848051 by alpha = 0.4 beta = 0.3 gamma = 0.5
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 00:59:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 01:14:59' ;
# BY USE alpha = 0.4 beta = 0.3 gamma = 0.5
# predicted watt is  220.46625611  |||||   targeted watt at t is  176.373004888
# ______________________________________________________________________________________________
#
# Consuming watt = 287.558
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 287.558
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 5 5 5 5 5 5 5 5 5
# substact k watt out from watt =  0 watt
#
#
# ############################################END##################################################
#
# data at : 5
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 00:59:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 01:14:59' ;
# the minimum MSE of prediction = 0.0238479816887 by alpha = 0.1 beta = 0.7 gamma = 0.7
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 01:14:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 01:29:59' ;
# BY USE alpha = 0.1 beta = 0.7 gamma = 0.7
# predicted watt is  484.368029006  |||||   targeted watt at t is  387.494423205
# ______________________________________________________________________________________________
#
# Consuming watt = 174.896
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 174.896
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 6 6 6 6 6 6 6 6 6
# substact k watt out from watt =  0 watt
#
#
# ############################################END##################################################
#
# data at : 6
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 01:14:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 01:29:59' ;
# the minimum MSE of prediction = 1.58519890871 by alpha = 0.1 beta = 0.1 gamma = 0.8
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 01:29:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 01:44:59' ;
# BY USE alpha = 0.1 beta = 0.1 gamma = 0.8
# predicted watt is  82.7867045356  |||||   targeted watt at t is  66.2293636285
# ______________________________________________________________________________________________
#
# Consuming watt = 289.333
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 289.333
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 7 7 7 7 7 7 7 7 7
# substact k watt out from watt =  0 watt
#
#
# ############################################END##################################################
#
# data at : 7
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 01:29:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 01:44:59' ;
# the minimum MSE of prediction = 0.00313141443652 by alpha = 0.2 beta = 0.5 gamma = 0.1
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 01:44:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 01:59:59' ;
# BY USE alpha = 0.2 beta = 0.5 gamma = 0.1
# predicted watt is  270.369319652  |||||   targeted watt at t is  216.295455722
# ______________________________________________________________________________________________
#
# Consuming watt = 182.788
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 182.788
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 8 8 8 8 8 8 8 8 8
# substact k watt out from watt =  0 watt
#
#
# ############################################END##################################################
#
# data at : 8
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 01:44:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 01:59:59' ;
# the minimum MSE of prediction = 0.0350736704722 by alpha = 0.3 beta = 0.9 gamma = 0.2
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 01:59:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 02:14:59' ;
# BY USE alpha = 0.3 beta = 0.9 gamma = 0.2
# predicted watt is  227.798945847  |||||   targeted watt at t is  182.239156678
# ______________________________________________________________________________________________
#
# Consuming watt = 297.142
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 297.142
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 9 9 9 9 9 9 9 9 9
# substact k watt out from watt =  0 watt
#
#
# ############################################END##################################################
#
# data at : 9
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 01:59:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 02:14:59' ;
# the minimum MSE of prediction = 0.0387236915858 by alpha = 0.2 beta = 0.4 gamma = 0.0
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 02:14:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 02:29:59' ;
# BY USE alpha = 0.2 beta = 0.4 gamma = 0.0
# predicted watt is  241.190512635  |||||   targeted watt at t is  192.952410108
# ______________________________________________________________________________________________
#
# Consuming watt = 180.125
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 180.125
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 10 10 10 10 10 10 10 10 10
# substact k watt out from watt =  0 watt
#
#
# ############################################END##################################################
#
# data at : 10
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 02:14:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 02:29:59' ;
# the minimum MSE of prediction = 0.0326091452934 by alpha = 0.1 beta = 0.0 gamma = 0.3
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 02:29:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 02:44:59' ;
# BY USE alpha = 0.1 beta = 0.0 gamma = 0.3
# predicted watt is  166.877315396  |||||   targeted watt at t is  133.501852317
# ______________________________________________________________________________________________
#
# Consuming watt = 262.6
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 262.6
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 11 11 11 11 11 11 11 11 11
# substact k watt out from watt =  0 watt
#
#
# ############################################END##################################################
#
# data at : 11
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 02:29:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 02:44:59' ;
# the minimum MSE of prediction = 0.00643042228791 by alpha = 0.1 beta = 0.8 gamma = 0.1
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 02:44:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 02:59:59' ;
# BY USE alpha = 0.1 beta = 0.8 gamma = 0.1
# predicted watt is  314.333794525  |||||   targeted watt at t is  251.46703562
# ______________________________________________________________________________________________
#
# Consuming watt = 190.262
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 190.262
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 12 12 12 12 12 12 12 12 12
# substact k watt out from watt =  0 watt
#
#
# ############################################END##################################################
#
# data at : 12
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 02:44:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 02:59:59' ;
# the minimum MSE of prediction = 5.26606902757 by alpha = 0.3 beta = 0.9 gamma = 0.9
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 02:59:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 03:14:59' ;
# BY USE alpha = 0.3 beta = 0.9 gamma = 0.9
# predicted watt is  3.26311899039  |||||   targeted watt at t is  2.61049519231
# ______________________________________________________________________________________________
#
# Consuming watt = 177.167
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 177.167
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 13 13 13 13 13 13 13 13 13
# substact k watt out from watt =  0 watt
#
#
# ############################################END##################################################
#
# data at : 13
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 02:59:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 03:14:59' ;
# the minimum MSE of prediction = 0.000176299683117 by alpha = 0.3 beta = 0.3 gamma = 0.6
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 03:14:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 03:29:59' ;
# BY USE alpha = 0.3 beta = 0.3 gamma = 0.6
# predicted watt is  159.95740676  |||||   targeted watt at t is  127.965925408
# ______________________________________________________________________________________________
#
# Consuming watt = 196.067
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 196.067
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 14 14 14 14 14 14 14 14 14
# substact k watt out from watt =  0 watt
#
#
# ############################################END##################################################
#
# data at : 14
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 03:14:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 03:29:59' ;
# the minimum MSE of prediction = 0.205423693566 by alpha = 0.3 beta = 0.4 gamma = 0.8
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 03:29:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 03:44:59' ;
# BY USE alpha = 0.3 beta = 0.4 gamma = 0.8
# predicted watt is  252.477559488  |||||   targeted watt at t is  201.98204759
# ______________________________________________________________________________________________
#
# Consuming watt = 230.796
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 230.796
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 15 15 15 15 15 15 15 15 15
# substact k watt out from watt =  0 watt
#
#
# ############################################END##################################################
#
# data at : 15
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 03:29:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 03:44:59' ;
# the minimum MSE of prediction = 7.61814640417e-05 by alpha = 0.7 beta = 0.6 gamma = 0.7
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 03:44:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 03:59:59' ;
# BY USE alpha = 0.7 beta = 0.6 gamma = 0.7
# predicted watt is  196.245314032  |||||   targeted watt at t is  156.996251226
# ______________________________________________________________________________________________
#
# Consuming watt = 144.562
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 144.562
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 16 16 16 16 16 16 16 16 16
# substact k watt out from watt =  0 watt
#
#
# ############################################END##################################################
#
# data at : 16
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 03:44:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 03:59:59' ;
# the minimum MSE of prediction = 0.0888261214249 by alpha = 0.2 beta = 1.0 gamma = 0.4
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 03:59:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 04:14:59' ;
# BY USE alpha = 0.2 beta = 1.0 gamma = 0.4
# predicted watt is  104.444001712  |||||   targeted watt at t is  83.55520137
# ______________________________________________________________________________________________
#
# Consuming watt = 136.346
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 136.346
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 17 17 17 17 17 17 17 17 17
# substact k watt out from watt =  0 watt
#
#
# ############################################END##################################################
#
# data at : 17
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 03:59:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 04:14:59' ;
# the minimum MSE of prediction = 1.44436453265e-05 by alpha = 0.6 beta = 0.6 gamma = 0.0
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 04:14:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 04:29:59' ;
# BY USE alpha = 0.6 beta = 0.6 gamma = 0.0
# predicted watt is  132.115741957  |||||   targeted watt at t is  105.692593565
# ______________________________________________________________________________________________
#
# Consuming watt = 167.533
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 167.533
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 18 18 18 18 18 18 18 18 18
# substact k watt out from watt =  0 watt
#
#
# ############################################END##################################################
#
# data at : 18
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 04:14:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 04:29:59' ;
# the minimum MSE of prediction = 0.000331544383869 by alpha = 0.2 beta = 0.1 gamma = 0.0
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 04:29:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 04:44:59' ;
# BY USE alpha = 0.2 beta = 0.1 gamma = 0.0
# predicted watt is  144.618877067  |||||   targeted watt at t is  115.695101654
# ______________________________________________________________________________________________
#
# Consuming watt = 180.913
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 180.913
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 19 19 19 19 19 19 19 19 19
# substact k watt out from watt =  0 watt
#
#
# ############################################END##################################################
#
# data at : 19
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 04:29:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 04:44:59' ;
# the minimum MSE of prediction = 0.168624325782 by alpha = 0.1 beta = 0.2 gamma = 0.2
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 04:44:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 04:59:59' ;
# BY USE alpha = 0.1 beta = 0.2 gamma = 0.2
# predicted watt is  164.656803765  |||||   targeted watt at t is  131.725443012
# ______________________________________________________________________________________________
#
# Consuming watt = 178.233
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 178.233
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 20 20 20 20 20 20 20 20 20
# substact k watt out from watt =  0 watt
#
#
# ############################################END##################################################
#
# data at : 20
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 04:44:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 04:59:59' ;
# the minimum MSE of prediction = 0.0027059512767 by alpha = 0.8 beta = 0.4 gamma = 0.7
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 04:59:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 05:14:59' ;
# BY USE alpha = 0.8 beta = 0.4 gamma = 0.7
# predicted watt is  201.695213636  |||||   targeted watt at t is  161.356170909
# ______________________________________________________________________________________________
#
# Consuming watt = 174.921
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 174.921
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 21 21 21 21 21 21 21 21 21
# substact k watt out from watt =  0 watt
#
#
# ############################################END##################################################
#
# data at : 21
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 04:59:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 05:14:59' ;
# the minimum MSE of prediction = 0.00648790625258 by alpha = 0.5 beta = 0.3 gamma = 0.1
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 05:14:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 05:29:59' ;
# BY USE alpha = 0.5 beta = 0.3 gamma = 0.1
# predicted watt is  138.307635682  |||||   targeted watt at t is  110.646108546
# ______________________________________________________________________________________________
#
# Consuming watt = 151.058
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 151.058
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 22 22 22 22 22 22 22 22 22
# substact k watt out from watt =  0 watt
#
#
# ############################################END##################################################
#
# data at : 22
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 05:14:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 05:29:59' ;
# the minimum MSE of prediction = 0.00562878406304 by alpha = 0.3 beta = 0.9 gamma = 0.6
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 05:29:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 05:44:59' ;
# BY USE alpha = 0.3 beta = 0.9 gamma = 0.6
# predicted watt is  136.778296397  |||||   targeted watt at t is  109.422637118
# ______________________________________________________________________________________________
#
# Consuming watt = 140.133
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 140.133
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 23 23 23 23 23 23 23 23 23
# substact k watt out from watt =  0 watt
#
#
# ############################################END##################################################
#
# data at : 23
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 05:29:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 05:44:59' ;
# the minimum MSE of prediction = 8.93644174074e-05 by alpha = 0.8 beta = 0.3 gamma = 0.8
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 05:44:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 05:59:59' ;
# BY USE alpha = 0.8 beta = 0.3 gamma = 0.8
# predicted watt is  154.810831973  |||||   targeted watt at t is  123.848665578
# ______________________________________________________________________________________________
#
# Consuming watt = 137.637
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 137.637
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 24 24 24 24 24 24 24 24 24
# substact k watt out from watt =  0 watt
#
#
# ############################################END##################################################
#
# data at : 24
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 05:44:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 05:59:59' ;
# the minimum MSE of prediction = 7.02741829991e-05 by alpha = 0.3 beta = 0.3 gamma = 0.8
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 05:59:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 06:14:59' ;
# BY USE alpha = 0.3 beta = 0.3 gamma = 0.8
# predicted watt is  139.331633332  |||||   targeted watt at t is  111.465306666
# ______________________________________________________________________________________________
#
# Consuming watt = 85.4292
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 85.4292
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 25 25 25 25 25 25 25 25 25
# substact k watt out from watt =  0 watt
#
#
# ############################################END##################################################
#
# data at : 25
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 05:59:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 06:14:59' ;
# the minimum MSE of prediction = 2.02281984542 by alpha = 0.1 beta = 0.4 gamma = 0.2
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 06:14:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 06:29:59' ;
# BY USE alpha = 0.1 beta = 0.4 gamma = 0.2
# predicted watt is  46.4720928484  |||||   targeted watt at t is  37.1776742787
# ______________________________________________________________________________________________
#
# Consuming watt = 32.6
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 32.6
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 26 26 26 26 26 26 26 26 26
# substact k watt out from watt =  0 watt
#
#
# ############################################END##################################################
#
# data at : 26
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 06:14:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 06:29:59' ;
# the minimum MSE of prediction = 0.00107123038041 by alpha = 0.5 beta = 0.8 gamma = 0.7
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 06:29:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 06:44:59' ;
# BY USE alpha = 0.5 beta = 0.8 gamma = 0.7
# predicted watt is  49.5094743289  |||||   targeted watt at t is  39.6075794631
# ______________________________________________________________________________________________
#
# Consuming watt = 27.9208
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 27.9208
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 27 27 27 27 27 27 27 27 27
# substact k watt out from watt =  0 watt
#
#
# ############################################END##################################################
#
# data at : 27
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 06:29:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 06:44:59' ;
# the minimum MSE of prediction = 0.000701860257186 by alpha = 0.5 beta = 0.9 gamma = 0.4
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 06:44:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 06:59:59' ;
# BY USE alpha = 0.5 beta = 0.9 gamma = 0.4
# predicted watt is  0.153300999289  |||||   targeted watt at t is  0.122640799431
# ______________________________________________________________________________________________
#
# Consuming watt = 31.0583
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 31.0583
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 28 28 28 28 28 28 28 28 28
# substact k watt out from watt =  0 watt
#
#
# ############################################END##################################################
#
# data at : 28
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 06:44:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 06:59:59' ;
# the minimum MSE of prediction = 0.00335673448351 by alpha = 0.8 beta = 0.0 gamma = 1.0
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 06:59:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 07:14:59' ;
# BY USE alpha = 0.8 beta = 0.0 gamma = 1.0
# predicted watt is  64.0547653166  |||||   targeted watt at t is  51.2438122533
# ______________________________________________________________________________________________
#
# Consuming watt = 31.6792
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 31.6792
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 29 29 29 29 29 29 29 29 29
# substact k watt out from watt =  0 watt
#
#
# ############################################END##################################################
#
# data at : 29
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 06:59:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 07:14:59' ;
# the minimum MSE of prediction = 0.000116167304908 by alpha = 0.5 beta = 1.0 gamma = 0.2
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 07:14:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 07:29:59' ;
# BY USE alpha = 0.5 beta = 1.0 gamma = 0.2
# predicted watt is  14.1092016493  |||||   targeted watt at t is  11.2873613195
# ______________________________________________________________________________________________
#
# Consuming watt = 27.4417
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 27.4417
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 30 30 30 30 30 30 30 30 30
# substact k watt out from watt =  0 watt
#
#
# ############################################END##################################################
#
# data at : 30
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 07:14:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 07:29:59' ;
# the minimum MSE of prediction = 0.00107738797182 by alpha = 0.3 beta = 0.2 gamma = 0.0
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 07:29:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 07:44:59' ;
# BY USE alpha = 0.3 beta = 0.2 gamma = 0.0
# predicted watt is  19.9298744034  |||||   targeted watt at t is  15.9438995227
# ______________________________________________________________________________________________
#
# Consuming watt = 26.7208
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 26.7208
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 31 31 31 31 31 31 31 31 31
# substact k watt out from watt =  0 watt
#
#
# ############################################END##################################################
#
# data at : 31
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 07:29:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 07:44:59' ;
# the minimum MSE of prediction = 0.000975358665525 by alpha = 0.4 beta = 0.0 gamma = 0.4
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 07:44:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 07:59:59' ;
# BY USE alpha = 0.4 beta = 0.0 gamma = 0.4
# predicted watt is  24.4606511358  |||||   targeted watt at t is  19.5685209087
# ______________________________________________________________________________________________
#
# Consuming watt = 30.3167
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 30.3167
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 32 32 32 32 32 32 32 32 32
# substact k watt out from watt =  0 watt
#
#
# ############################################END##################################################
#
# data at : 32
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 07:44:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 07:59:59' ;
# the minimum MSE of prediction = 5.88892183354e-06 by alpha = 0.9 beta = 0.6 gamma = 0.2
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 07:59:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 08:14:59' ;
# BY USE alpha = 0.9 beta = 0.6 gamma = 0.2
# predicted watt is  37.2385159836  |||||   targeted watt at t is  29.7908127868
# ______________________________________________________________________________________________
#
# Consuming watt = 33.7208
# PV_CONSUMPTION = 13.249
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 20.4718
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 13.249 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 33 33 33 33 33 33 33 33 33
# substact k watt out from watt =  0 watt
#
#
# ############################################END##################################################
#
# data at : 33
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-01 07:59:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-01 08:14:59' ;
# the minimum MSE of prediction = 0.000735235777103 by alpha = 0.8 beta = 0.9 gamma = 0.8
# ...
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-11 21:59:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-11 22:14:59' ;
# BY USE alpha = 0.1 beta = 0.0 gamma = 0.2
# predicted watt is  294.455493954  |||||   targeted watt at t is  235.564395163
# ______________________________________________________________________________________________
#
# Consuming watt = 309.004
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 309.004
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 1049 1049 1050 1049 1049 1054 1049 1049 1091
# substact k watt out from watt =  57.09277 watt
#
#
# ############################################END##################################################
#
# data at : 1049
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-11 21:59:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-11 22:14:59' ;
# the minimum MSE of prediction = 0.00119797365082 by alpha = 0.0 beta = 0.0 gamma = 1.0
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-11 22:14:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-11 22:29:59' ;
# BY USE alpha = 0.0 beta = 0.0 gamma = 1.0
# predicted watt is  313.928388244  |||||   targeted watt at t is  251.142710595
# ______________________________________________________________________________________________
#
# Consuming watt = 321.21123
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 321.21123
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 1050 1050 1050 1050 1050 1054 1050 1050 1091
# substact k watt out from watt =  181.6446 watt
#
#
# ############################################END##################################################
#
# data at : 1050
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-11 22:14:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-11 22:29:59' ;
# the minimum MSE of prediction = 0.000552032748704 by alpha = 0.6 beta = 0.4 gamma = 1.0
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-11 22:29:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-11 22:44:59' ;
# BY USE alpha = 0.6 beta = 0.4 gamma = 1.0
# predicted watt is  248.879716618  |||||   targeted watt at t is  199.103773294
# ______________________________________________________________________________________________
#
# Consuming watt = 292.3514
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 292.3514
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 1051 1051 1051 1051 1051 1054 1051 1051 1091
# substact k watt out from watt =  181.1285 watt
#
#
# ############################################END##################################################
#
# data at : 1051
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-11 22:29:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-11 22:44:59' ;
# the minimum MSE of prediction = 0.00902312891907 by alpha = 0.6 beta = 0.4 gamma = 0.8
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-11 22:44:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-11 22:59:59' ;
# BY USE alpha = 0.6 beta = 0.4 gamma = 0.8
# predicted watt is  478.096994786  |||||   targeted watt at t is  382.477595829
# ______________________________________________________________________________________________
#
# Consuming watt = 285.7845
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 285.7845
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 1052 1052 1052 1052 1052 1054 1052 1052 1091
# substact k watt out from watt =  181.5924 watt
#
#
# ############################################END##################################################
#
# data at : 1052
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-11 22:44:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-11 22:59:59' ;
# the minimum MSE of prediction = 0.250171483255 by alpha = 0.1 beta = 0.6 gamma = 0.2
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-11 22:59:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-11 23:14:59' ;
# BY USE alpha = 0.1 beta = 0.6 gamma = 0.2
# predicted watt is  295.931621823  |||||   targeted watt at t is  236.745297458
# ______________________________________________________________________________________________
#
# Consuming watt = 292.1576
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 292.1576
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 1053 1053 1053 1053 1053 1054 1053 1053 1091
# substact k watt out from watt =  41.3295 watt
#
#
# ############################################END##################################################
#
# data at : 1053
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-11 22:59:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-11 23:14:59' ;
# the minimum MSE of prediction = 0.0090789759677 by alpha = 0.7 beta = 0.7 gamma = 0.6
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-11 23:14:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-11 23:29:59' ;
# BY USE alpha = 0.7 beta = 0.7 gamma = 0.6
# predicted watt is  15.378739412  |||||   targeted watt at t is  12.3029915296
# ______________________________________________________________________________________________
#
# Consuming watt = 240.6745
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 240.6745
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 1054 1054 1054 1054 1054 1054 1054 1054 1091
# substact k watt out from watt =  17.4282 watt
#
#
# ############################################END##################################################
#
# data at : 1054
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-11 23:14:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-11 23:29:59' ;
# the minimum MSE of prediction = 0.000792159912919 by alpha = 0.3 beta = 0.5 gamma = 0.2
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-11 23:29:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-11 23:44:59' ;
# BY USE alpha = 0.3 beta = 0.5 gamma = 0.2
# predicted watt is  66.7277597777  |||||   targeted watt at t is  53.3822078222
# ______________________________________________________________________________________________
#
# Consuming watt = 287.1388
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 287.1388
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 1055 1055 1055 1055 1055 1055 1055 1055 1091
# substact k watt out from watt =  17.7149 watt
#
#
# ############################################END##################################################
#
# data at : 1055
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-11 23:29:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-11 23:44:59' ;
# the minimum MSE of prediction = 0.27027683962 by alpha = 0.2 beta = 0.2 gamma = 0.7
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-11 23:44:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-11 23:59:59' ;
# BY USE alpha = 0.2 beta = 0.2 gamma = 0.7
# predicted watt is  231.364175882  |||||   targeted watt at t is  185.091340705
# ______________________________________________________________________________________________
#
# Consuming watt = 290.0141
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 290.0141
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 1056 1056 1056 1056 1056 1056 1056 1056 1091
# substact k watt out from watt =  17.6936 watt
#
#
# ############################################END##################################################
#
# data at : 1056
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-11 23:44:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-11 23:59:59' ;
# the minimum MSE of prediction = 0.169591587387 by alpha = 0.7 beta = 0.3 gamma = 0.1
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-11 23:59:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-12 00:14:59' ;
# BY USE alpha = 0.7 beta = 0.3 gamma = 0.1
# predicted watt is  287.262032698  |||||   targeted watt at t is  229.809626158
# ______________________________________________________________________________________________
#
# Consuming watt = 273.8684
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 273.8684
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 1057 1057 1057 1057 1057 1057 1057 1057 1091
# substact k watt out from watt =  17.9482 watt
#
#
# ############################################END##################################################
#
# data at : 1057
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-11 23:59:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-12 00:14:59' ;
# the minimum MSE of prediction = 0.00592117674184 by alpha = 0.9 beta = 0.2 gamma = 0.0
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-12 00:14:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-12 00:29:59' ;
# BY USE alpha = 0.9 beta = 0.2 gamma = 0.0
# predicted watt is  280.887274371  |||||   targeted watt at t is  224.709819497
# ______________________________________________________________________________________________
#
# Consuming watt = 270.0018
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 270.0018
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 1058 1058 1058 1058 1058 1058 1058 1058 1091
# substact k watt out from watt =  17.5541 watt
#
#
# ############################################END##################################################
#
# data at : 1058
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-12 00:14:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-12 00:29:59' ;
# the minimum MSE of prediction = 0.0213758817281 by alpha = 0.9 beta = 0.6 gamma = 0.8
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-12 00:29:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-12 00:44:59' ;
# BY USE alpha = 0.9 beta = 0.6 gamma = 0.8
# predicted watt is  285.781182112  |||||   targeted watt at t is  228.62494569
# ______________________________________________________________________________________________
#
# Consuming watt = 268.3589
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 268.3589
# PREVIOUS LEVELBATT = 0.0 ||| LEFTED LEVELBATT = 0.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
#
# ______________________________ sum_substract is NEGATIVE_NOW________________________________
#
# check_end position processing done!
# 1059 1059 1059 1059 1059 1059 1059 1059 1091
# substact k watt out from watt =  10.8915 watt
#
#
# ############################################END##################################################
#
# data at : 1059
# ______________________________________________________________________________________________
#
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp>='2016-09-03 00:00:00'AND Timestamp<='2016-10-12 00:29:59';
# SELECT Timestamp,watt FROM  PVBATT.test4_totalwatt WHERE Timestamp = '2016-10-12 00:44:59' ;

# %%
import pandas as pd
import MySQLdb
import time
import sys
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error,mean_squared_error
import statistics 
# %matplotlib inline 


conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

query1 = "SELECT Timestamp,load_watt,watt,pv_watt,batt_watt,grid_watt FROM  PVBATT.test4_PV300noBATT WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % ('2016-10-01 00:00:00','2016-10-30 19:59:59')
df1 = pd.read_sql(query1, conn,index_col=['Timestamp'])
fig, ax = plt.subplots(figsize=(14, 6))
ax.set_title('Power Consumption every 15 minutes (PV 300 W & no-BATTERRY)', fontsize=14)
plt.xlabel('Timestamp', fontsize=14)
plt.ylabel('power(watt)', fontsize=14)
df1.plot(ax=ax)
plt.show()


print "Total-Real power Consumption", df1.load_watt.sum()/1000 ,"KW"
print "Total-Cut power Consumption", df1.watt.sum()/1000,"KW"
print "GRID-Consumption =", df1.grid_watt.sum()/1000,"KW"
print "PV+BATT-Consumption =", (df1.watt.sum()-df1.grid_watt.sum())/1000,"KW"
print "Over-PV power =", sum_overpv/1000,"KW"
# Out:
# 0.0
