# %% [markdown]
# ### ELECTRICAL BILL of LAST MONTH 2

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
# %matplotlib inline 


conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()
min_p = float(0)
j = 0
d = 2
time_a = pd.date_range('2016-10-01 00:00:00', periods=96*d, freq='15T')
# print time_a
time_b = pd.date_range('2016-10-01 00:14:59', periods=96*d, freq='15T')
# print time_b

conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

# query_empty = """truncate table PVBATT.P15min_lastmonth2""" 
# c.execute(query_empty)
# print "PVBATT.P15min_lastmonth2 are Empty!!! \n"
# print "Progress:",

while (j <= (96*d)-1) :   
    query = "SELECT Timestamp, watt FROM PVBATT.P15min_observedmonth WHERE Timestamp >= '%s'   AND TimeStamp <= '%s'; "% (time_a[j],time_b[j])
    df = pd.read_sql(query, conn)
    df['watt'] = df['watt'].astype(float)

#     if len(df) == 0 :
#         min_p = 0
#     else :
#         for i in range(len(df.cTime.dt.minute)):
#             min_p += df.watt[i]        
#         min_p = min_p/len(df)/4  
        
#         #df.to_csv('out.csv')
    print time_b[j] , "-->" ,df.watt[0] ," watt/15min"
    c.execute("INSERT INTO PVBATT.P15min_lastmonth2 (Timestamp, watt) VALUES ( %s, %s)",(time_b[j],df.watt[0]))  
    
    #print "|",
    conn.commit()
    min_p = 0
    j += 1
       
    print ".",
    print
print(".DONE!")
# Out:
# 2016-10-01 00:14:59 --> 304.675  watt/15min
# .
# 2016-10-01 00:29:59 --> 291.246  watt/15min
# .
# 2016-10-01 00:44:59 --> 188.325  watt/15min
# .
# 2016-10-01 00:59:59 --> 296.513  watt/15min
# .
# 2016-10-01 01:14:59 --> 287.558  watt/15min
# .
# 2016-10-01 01:29:59 --> 174.896  watt/15min
# .
# 2016-10-01 01:44:59 --> 289.333  watt/15min
# .
# 2016-10-01 01:59:59 --> 182.788  watt/15min
# .
# 2016-10-01 02:14:59 --> 297.142  watt/15min
# .
# 2016-10-01 02:29:59 --> 180.125  watt/15min
# .
# 2016-10-01 02:44:59 --> 262.6  watt/15min
# .
# 2016-10-01 02:59:59 --> 190.262  watt/15min
# .
# 2016-10-01 03:14:59 --> 177.167  watt/15min
# .
# 2016-10-01 03:29:59 --> 196.067  watt/15min
# .
# 2016-10-01 03:44:59 --> 230.796  watt/15min
# .
# 2016-10-01 03:59:59 --> 144.562  watt/15min
# .
# 2016-10-01 04:14:59 --> 136.346  watt/15min
# .
# 2016-10-01 04:29:59 --> 167.533  watt/15min
# .
# 2016-10-01 04:44:59 --> 180.913  watt/15min
# .
# 2016-10-01 04:59:59 --> 178.233  watt/15min
# .
# ...

# %%
df.watt[0]
# Out:
# 254.75
