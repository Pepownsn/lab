# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.collections import PolyCollection
from matplotlib.colors import colorConverter
import matplotlib.pyplot as plt
import pandas as pd # v. 1.7
import numpy as np
import MySQLdb
import matplotlib.pyplot as plt
import pandas as pd
import MySQLdb
# %matplotlib inline

# %%
import pandas as pd
import MySQLdb
import time
import sys
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error,mean_squared_error
import statistics 
# %matplotlib inline 


## docker main
conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

## docker 0 
conn0 = MySQLdb.connect("192.168.10.230",user="conn",passwd="hems", port = 32770)
c0 = conn0.cursor()

## docker 1
conn1 = MySQLdb.connect("192.168.10.231",user="conn",passwd="hems", port = 32768)
c1 = conn1.cursor()

d = 1
time_a = pd.date_range('2016-10-01 00:00:00', periods=96*d, freq='15T')
time_b = pd.date_range('2016-10-01 00:14:59', periods=96*d, freq='15T')

## FROM docker main
query1 = "SELECT Timestamp,watt FROM  PVBATT.test1_PV1200BATT3 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a[0],time_b[(96*d)-1])
df1 = pd.read_sql(query1, conn,index_col=['Timestamp'])
query2 = "SELECT Timestamp,watt FROM  PVBATT.test2_PV900BATT3 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a[0],time_b[(96*d)-1])
df2 = pd.read_sql(query2, conn,index_col=['Timestamp'])
query3 = "SELECT Timestamp,watt FROM  PVBATT.test3_PV600BATT3 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a[0],time_b[(96*d)-1])
df3 = pd.read_sql(query3, conn,index_col=['Timestamp'])
query4 = "SELECT Timestamp,watt FROM  PVBATT.test4_PV1200BATT6 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a[0],time_b[(96*d)-1])
df4 = pd.read_sql(query4, conn,index_col=['Timestamp'])

fig, ax = plt.subplots(figsize=(14, 6))
ax.set_title('Power Consumption every 15 minutes', fontsize=16)
plt.xlabel('Timestamp', fontsize=14)
plt.ylabel('watt', fontsize=14)
df1.plot(ax=ax)
plt.show()
# Out:
# OperationalErrorTraceback (most recent call last)
# <ipython-input-6-18513385885b> in <module>()
#      18
#      19 ## docker 0
# ---> 20 conn0 = MySQLdb.connect("192.168.10.230",user="conn",passwd="hems", port = 32770)
#      21 c0 = conn0.cursor()
#      22
#
# /usr/lib/python2.7/dist-packages/MySQLdb/__init__.pyc in Connect(*args, **kwargs)
#      79     """Factory function for connections.Connection."""
#      80     from connections import Connection
# ---> 81     return Connection(*args, **kwargs)
#      82
#      83 connect = Connection = Connect
#
# /usr/lib/python2.7/dist-packages/MySQLdb/connections.pyc in __init__(self, *args, **kwargs)
#     185         kwargs2['client_flag'] = client_flag
#     186
# --> 187         super(Connection, self).__init__(*args, **kwargs2)
#     188
#     189         self.encoders = dict([ (k, v) for k, v in conv.items()
#
# OperationalError: (2003, "Can't connect to MySQL server on '192.168.10.230' (111)")

# %%
import pandas as pd
import MySQLdb
import time
import sys
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error,mean_squared_error
import statistics 
# %matplotlib inline 

d = 1
time_a = pd.date_range('2016-10-01 00:00:00', periods=96*d, freq='15T')
time_b = pd.date_range('2016-10-01 00:14:59', periods=96*d, freq='15T')

conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

query1 = "SELECT Timestamp,load_watt,watt,pv_watt,batt_watt,grid_watt FROM  PVBATT.test1_PV1200BATT3 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a[0],time_b[(96*d)-1])
df1 = pd.read_sql(query1, conn,index_col=['Timestamp'])
fig, ax = plt.subplots(figsize=(14, 6))
ax.set_title('Power Consumption every 15 minutes', fontsize=16)
plt.xlabel('Timestamp', fontsize=14)
plt.ylabel('watt', fontsize=14)
df1.plot(ax=ax)
plt.show()

# %%
import pandas as pd
import MySQLdb
import time
import sys
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error,mean_squared_error
import statistics 
# %matplotlib inline 

d = 1
time_a = pd.date_range('2016-10-01 00:00:00', periods=96*d, freq='15T')
time_b = pd.date_range('2016-10-01 00:14:59', periods=96*d, freq='15T')

conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

query1 = "SELECT Timestamp,load_watt,watt,pv_watt,batt_watt,grid_watt FROM  PVBATT.test2_PV900BATT3 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a[0],time_b[(96*d)-1])
df1 = pd.read_sql(query1, conn,index_col=['Timestamp'])
fig, ax = plt.subplots(figsize=(14, 6))
ax.set_title('Power Consumption every 15 minutes', fontsize=16)
plt.xlabel('Timestamp', fontsize=14)
plt.ylabel('watt', fontsize=14)
df1.plot(ax=ax)
plt.show()

# %%
import pandas as pd
import MySQLdb
import time
import sys
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error,mean_squared_error
import statistics 
# %matplotlib inline 

d = 1
time_a = pd.date_range('2016-10-01 00:00:00', periods=96*d, freq='15T')
time_b = pd.date_range('2016-10-01 00:14:59', periods=96*d, freq='15T')

conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

query1 = "SELECT Timestamp,load_watt,watt,pv_watt,batt_watt,grid_watt FROM  PVBATT.test3_PV600BATT3 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a[0],time_b[(96*d)-1])
df1 = pd.read_sql(query1, conn,index_col=['Timestamp'])
fig, ax = plt.subplots(figsize=(14, 6))
ax.set_title('Power Consumption every 15 minutes', fontsize=16)
plt.xlabel('Timestamp', fontsize=14)
plt.ylabel('watt', fontsize=14)
df1.plot(ax=ax)
plt.show()

# %%
import pandas as pd
import MySQLdb
import time
import sys
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error,mean_squared_error
import statistics 
# %matplotlib inline 

d = 1
time_a = pd.date_range('2016-10-01 00:00:00', periods=96*d, freq='15T')
time_b = pd.date_range('2016-10-01 00:14:59', periods=96*d, freq='15T')

conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

query1 = "SELECT Timestamp,load_watt,watt,pv_watt,batt_watt,grid_watt FROM  PVBATT.test4_PV1200BATT6 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a[0],time_b[(96*d)-1])
df1 = pd.read_sql(query1, conn,index_col=['Timestamp'])
fig, ax = plt.subplots(figsize=(14, 6))
ax.set_title('Power Consumption every 15 minutes', fontsize=16)
plt.xlabel('Timestamp', fontsize=14)
plt.ylabel('watt', fontsize=14)
df1.plot(ax=ax)
plt.show()
