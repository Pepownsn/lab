# %% [markdown]
# ## data_month2
# #### เครื่องปรับอากาศ | 9000btu |

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random


d = 31
time_a = pd.date_range('2016-12-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-12-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####### set databases to empty #########
query_empty = """truncate table data_month3.aircont""" 
c.execute(query_empty)
print "data_month3.aircont are Empty!!! \n"

query = "SELECT watt FROM collected_info.1_aircont WHERE no >= '%s'   AND no <= '%s'; "% (0,3276)
df = pd.read_sql(query, conn)
# print df.watt[5]

#### Random the turning-on time appliances
def rand_turnon():
    duration_sec =  random.randint(10, 59)
    duration_min =  random.randint(10, 59)
    duration_hour1 = ['19'] * 5 + ['20'] * 50 + ['21'] * 43 +['22'] * 2     #SET Start 7-10 pm.
    duration_hour = random.choice(duration_hour1)     
    if 0 < duration_sec <= 15:
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
    off_item = (int(duration_hour)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on appliacne on",duration_hour,":",duration_min,":",duration_sec,"equal to",off_item,"items"
    return off_item

 
#### Random the off-duration appliances 
def rand_duration():
    duration_sec =  random.randint(10,59)
    duration_min =  random.randint(10, 59)
    duration_hour =  random.randint(6, 8)     #SET 6-8 Hours
    seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
    no_item = seconds/15
    print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items"
    return no_item

days = 0
j = 0
i = 0
print "\nDays :",days ,":",time_b[j].strftime('%a')
off_item = rand_turnon()  
no_item = rand_duration()  

while (j <= (5760*d)-1):    
    c.execute("INSERT INTO data_month3.aircont (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
    conn.commit()
    j += 1 
    
    while (off_item+(5760*(days)) <= j <= (no_item+off_item)+(5760*(days))):                   
        c.execute("INSERT INTO data_month3.aircont (Timestamp, watt) VALUES (%s, %s)",(time_b[j],df.watt[i]))
        conn.commit()
        i += 1 
        j += 1
        if (j == (no_item+off_item)+(5760*(days))):
            days +=1
            print "\nDays :",days ,":",time_b[j].strftime('%a')
            off_item = rand_turnon()  
            no_item = rand_duration() 
            i= 0   
                    
print "DONE!"
# Out:
# data_month3.aircont are Empty!!!
#
#
# Days : 0 : Thu
# time to turn-on appliacne on 20 : 24 : 59 equal to 4899 items
# consuming the appliance 8 hours 23 minutes 25 seconds that equal to 30205 seconds or 2013 items
#
# Days : 1 : Fri
# time to turn-on appliacne on 21 : 51 : 37 equal to 5246 items
# consuming the appliance 7 hours 15 minutes 32 seconds that equal to 26132 seconds or 1742 items
#
# Days : 2 : Sat
# time to turn-on appliacne on 20 : 50 : 33 equal to 5002 items
# consuming the appliance 6 hours 42 minutes 24 seconds that equal to 24144 seconds or 1609 items
#
# Days : 3 : Sun
# time to turn-on appliacne on 20 : 26 : 47 equal to 4907 items
# consuming the appliance 8 hours 14 minutes 49 seconds that equal to 29689 seconds or 1979 items
#
# Days : 4 : Mon
# time to turn-on appliacne on 20 : 29 : 20 equal to 4917 items
# consuming the appliance 7 hours 48 minutes 59 seconds that equal to 28139 seconds or 1875 items
#
# Days : 5 : Tue
# time to turn-on appliacne on 21 : 31 : 46 equal to 5167 items
# consuming the appliance 6 hours 52 minutes 37 seconds that equal to 24757 seconds or 1650 items
#
# Days : 6 : Wed
# time to turn-on appliacne on 20 : 29 : 21 equal to 4917 items
# consuming the appliance 6 hours 50 minutes 49 seconds that equal to 24649 seconds or 1643 items
#
# Days : 7 : Thu
# time to turn-on appliacne on 21 : 15 : 10 equal to 5100 items
# consuming the appliance 8 hours 17 minutes 24 seconds that equal to 29844 seconds or 1989 items
#
# Days : 8 : Fri
# time to turn-on appliacne on 20 : 23 : 49 equal to 4895 items
# consuming the appliance 7 hours 30 minutes 43 seconds that equal to 27043 seconds or 1802 items
#
# Days : 9 : Sat
# time to turn-on appliacne on 20 : 25 : 15 equal to 4900 items
# consuming the appliance 8 hours 48 minutes 27 seconds that equal to 31707 seconds or 2113 items
#
# Days : 10 : Sun
# time to turn-on appliacne on 20 : 33 : 48 equal to 4935 items
# consuming the appliance 6 hours 10 minutes 26 seconds that equal to 22226 seconds or 1481 items
#
# Days : 11 : Mon
# time to turn-on appliacne on 21 : 29 : 15 equal to 5156 items
# consuming the appliance 8 hours 44 minutes 44 seconds that equal to 31484 seconds or 2098 items
#
# Days : 12 : Tue
# time to turn-on appliacne on 21 : 40 : 30 equal to 5201 items
# consuming the appliance 7 hours 26 minutes 18 seconds that equal to 26778 seconds or 1785 items
#
# Days : 13 : Wed
# time to turn-on appliacne on 21 : 55 : 36 equal to 5262 items
# consuming the appliance 6 hours 57 minutes 57 seconds that equal to 25077 seconds or 1671 items
#
# Days : 14 : Thu
# time to turn-on appliacne on 21 : 25 : 22 equal to 5141 items
# consuming the appliance 8 hours 44 minutes 30 seconds that equal to 31470 seconds or 2098 items
#
# Days : 15 : Fri
# time to turn-on appliacne on 20 : 22 : 57 equal to 4891 items
# consuming the appliance 7 hours 27 minutes 47 seconds that equal to 26867 seconds or 1791 items
#
# Days : 16 : Sat
# time to turn-on appliacne on 21 : 36 : 24 equal to 5185 items
# consuming the appliance 6 hours 43 minutes 39 seconds that equal to 24219 seconds or 1614 items
#
# Days : 17 : Sun
# time to turn-on appliacne on 20 : 44 : 28 equal to 4977 items
# consuming the appliance 6 hours 23 minutes 48 seconds that equal to 23028 seconds or 1535 items
#
# Days : 18 : Mon
# time to turn-on appliacne on 21 : 52 : 59 equal to 5251 items
# consuming the appliance 6 hours 53 minutes 45 seconds that equal to 24825 seconds or 1655 items
#
# Days : 19 : Tue
# time to turn-on appliacne on 19 : 37 : 21 equal to 4709 items
# consuming the appliance 7 hours 42 minutes 20 seconds that equal to 27740 seconds or 1849 items
#
# Days : 20 : Wed
# time to turn-on appliacne on 20 : 41 : 15 equal to 4964 items
# consuming the appliance 7 hours 30 minutes 34 seconds that equal to 27034 seconds or 1802 items
#
# Days : 21 : Thu
# time to turn-on appliacne on 20 : 22 : 48 equal to 4891 items
# consuming the appliance 6 hours 27 minutes 33 seconds that equal to 23253 seconds or 1550 items
#
# Days : 22 : Fri
# time to turn-on appliacne on 21 : 45 : 43 equal to 5222 items
# consuming the appliance 8 hours 13 minutes 26 seconds that equal to 29606 seconds or 1973 items
#
# Days : 23 : Sat
# time to turn-on appliacne on 21 : 24 : 53 equal to 5139 items
# consuming the appliance 8 hours 23 minutes 10 seconds that equal to 30190 seconds or 2012 items
#
# Days : 24 : Sun
# time to turn-on appliacne on 20 : 23 : 20 equal to 4893 items
# consuming the appliance 8 hours 21 minutes 15 seconds that equal to 30075 seconds or 2005 items
#
# Days : 25 : Mon
# time to turn-on appliacne on 20 : 43 : 45 equal to 4974 items
# consuming the appliance 7 hours 12 minutes 47 seconds that equal to 25967 seconds or 1731 items
#
# Days : 26 : Tue
# time to turn-on appliacne on 20 : 53 : 49 equal to 5015 items
# consuming the appliance 6 hours 52 minutes 24 seconds that equal to 24744 seconds or 1649 items
#
# Days : 27 : Wed
# time to turn-on appliacne on 20 : 50 : 52 equal to 5003 items
# consuming the appliance 7 hours 50 minutes 12 seconds that equal to 28212 seconds or 1880 items
#
# Days : 28 : Thu
# time to turn-on appliacne on 20 : 23 : 52 equal to 4895 items
# consuming the appliance 8 hours 39 minutes 47 seconds that equal to 31187 seconds or 2079 items
#
# Days : 29 : Fri
# time to turn-on appliacne on 20 : 40 : 16 equal to 4961 items
# consuming the appliance 6 hours 17 minutes 28 seconds that equal to 22648 seconds or 1509 items
#
# Days : 30 : Sat
# time to turn-on appliacne on 20 : 41 : 32 equal to 4966 items
# consuming the appliance 8 hours 57 minutes 31 seconds that equal to 32251 seconds or 2150 items
# IndexErrorTraceback (most recent call last)
# <ipython-input-1-77af4cd76e74> in <module>()
#      67
#      68     while (off_item+(5760*(days)) <= j <= (no_item+off_item)+(5760*(days))):
# ---> 69         c.execute("INSERT INTO data_month3.aircont (Timestamp, watt) VALUES (%s, %s)",(time_b[j],df.watt[i]))
#      70         conn.commit()
#      71         i += 1
#
# /usr/local/lib/python2.7/dist-packages/pandas/tseries/base.pyc in __getitem__(self, key)
#     249         getitem = self._data.__getitem__
#     250         if is_int:
# --> 251             val = getitem(key)
#     252             return self._box_func(val)
#     253         else:
#
# IndexError: index 178560 is out of bounds for axis 0 with size 178560

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
# %matplotlib inline  

d = 31
time_a = pd.date_range('2016-12-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-12-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

# print time_b
# query = "SELECT watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
query = "SELECT Timestamp,watt FROM data_month3.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[5760*10])
df = pd.read_sql(query, conn, index_col=['Timestamp'])
fig, ax = plt.subplots()
ax.set_title(' data_month3.aircont ')
df.plot(ax=ax )
plt.show()
