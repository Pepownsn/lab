# %% [markdown]
# ## data_month2
# #### IPHONE charger | ipad 9.7 นิ้ว |

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random


d = 31
time_a = pd.date_range('2016-11-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-11-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####### set databases to empty #########
query_empty = """truncate table data_month2.iphonecharger""" 
c.execute(query_empty)
print "data_month2.iphonecharger are Empty!!! \n"

query = "SELECT watt FROM collected_info.13_iphonecharger WHERE no >= '%s'   AND no <= '%s'; "% (0,1200)
df = pd.read_sql(query, conn)
# print df.watt[5]

#### Random the turning-on time appliances
def rand_turnon():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(0, 59)
    duration_hour1 = ['18'] * 5 + ['19'] * 8 + ['20'] * 36 + ['21'] * 30 + ['22'] * 13 + ['23'] * 6 + ['0'] * 2
    duration_hour = random.choice(duration_hour1)     
    if 0 < duration_sec <= 15:
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
    off_item = (int(duration_hour)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on appliacne on",duration_hour,":",duration_min,":",duration_sec,"equal to",off_item,"items"
    return off_item

 
#### Random the off-duration appliances 
def rand_duration():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(10, 40)
    duration_hour1 = ['0'] * 2 + ['1'] * 25 + ['2'] * 35+ ['3'] * 20 + ['4'] * 10 + ['5'] * 8
    duration_hour = random.choice(duration_hour1)   
    seconds = (int(duration_hour)*3600)+(duration_min*60)+duration_sec
    no_item = seconds/15
    print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items"
    return no_item

days = 0
j = 0
i = 0
print "\nDays :",days ,":",time_b[j].strftime('%a')
off_item = rand_turnon()  
no_item = rand_duration()  

while (j <= (5760*d)-1):  
    c.execute("INSERT INTO data_month2.iphonecharger (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
    conn.commit()
    j += 1 
          
    while (off_item+(5760*(days)) <= j <= (no_item+off_item)+(5760*(days))):                   
        c.execute("INSERT INTO data_month2.iphonecharger (Timestamp, watt) VALUES (%s, %s)",(time_b[j],df.watt[i]))
        conn.commit()
        i += 1 
        j += 1
            
        if (i >= len(df)):
            i = 0  
        if (j == (no_item+off_item)+(5760*(days))):
            days +=1
            print "\nDays :",days ,":",time_b[j].strftime('%a')
            off_item = rand_turnon()  
            no_item = rand_duration() 
            i= 0   

                    
print "DONE!"
# Out:
# data_month2.iphonecharger are Empty!!!
#
#
# Days : 0 : Tue
# time to turn-on appliacne on 22 : 41 : 27 equal to 5445 items
# consuming the appliance 2 hours 33 minutes 14 seconds that equal to 9194 seconds or 612 items
#
# Days : 1 : Wed
# time to turn-on appliacne on 19 : 2 : 33 equal to 4570 items
# consuming the appliance 1 hours 20 minutes 29 seconds that equal to 4829 seconds or 321 items
#
# Days : 2 : Wed
# time to turn-on appliacne on 20 : 43 : 38 equal to 4974 items
# consuming the appliance 2 hours 29 minutes 38 seconds that equal to 8978 seconds or 598 items
#
# Days : 3 : Thu
# time to turn-on appliacne on 20 : 9 : 11 equal to 4836 items
# consuming the appliance 2 hours 35 minutes 43 seconds that equal to 9343 seconds or 622 items
#
# Days : 4 : Fri
# time to turn-on appliacne on 20 : 27 : 18 equal to 4909 items
# consuming the appliance 2 hours 35 minutes 58 seconds that equal to 9358 seconds or 623 items
#
# Days : 5 : Sat
# time to turn-on appliacne on 19 : 34 : 27 equal to 4697 items
# consuming the appliance 4 hours 22 minutes 3 seconds that equal to 15723 seconds or 1048 items
#
# Days : 6 : Sun
# time to turn-on appliacne on 20 : 6 : 26 equal to 4825 items
# consuming the appliance 1 hours 21 minutes 32 seconds that equal to 4892 seconds or 326 items
#
# Days : 7 : Mon
# time to turn-on appliacne on 23 : 5 : 53 equal to 5543 items
# consuming the appliance 0 hours 16 minutes 20 seconds that equal to 980 seconds or 65 items
#
# Days : 8 : Tue
# time to turn-on appliacne on 22 : 56 : 36 equal to 5506 items
# consuming the appliance 2 hours 23 minutes 56 seconds that equal to 8636 seconds or 575 items
#
# Days : 9 : Thu
# time to turn-on appliacne on 21 : 21 : 30 equal to 5125 items
# consuming the appliance 5 hours 33 minutes 57 seconds that equal to 20037 seconds or 1335 items
#
# Days : 10 : Fri
# time to turn-on appliacne on 19 : 58 : 6 equal to 4792 items
# consuming the appliance 2 hours 12 minutes 41 seconds that equal to 7961 seconds or 530 items
#
# Days : 11 : Fri
# time to turn-on appliacne on 21 : 11 : 21 equal to 5085 items
# consuming the appliance 3 hours 10 minutes 14 seconds that equal to 11414 seconds or 760 items
#
# Days : 12 : Sun
# time to turn-on appliacne on 18 : 10 : 15 equal to 4360 items
# consuming the appliance 5 hours 10 minutes 35 seconds that equal to 18635 seconds or 1242 items
#
# Days : 13 : Sun
# time to turn-on appliacne on 21 : 10 : 59 equal to 5083 items
# consuming the appliance 2 hours 15 minutes 20 seconds that equal to 8120 seconds or 541 items
#
# Days : 14 : Mon
# time to turn-on appliacne on 19 : 48 : 9 equal to 4752 items
# consuming the appliance 1 hours 39 minutes 8 seconds that equal to 5948 seconds or 396 items
#
# Days : 15 : Tue
# time to turn-on appliacne on 21 : 43 : 51 equal to 5215 items
# consuming the appliance 3 hours 31 minutes 47 seconds that equal to 12707 seconds or 847 items
#
# Days : 16 : Thu
# time to turn-on appliacne on 22 : 1 : 29 equal to 5285 items
# consuming the appliance 4 hours 32 minutes 35 seconds that equal to 16355 seconds or 1090 items
#
# Days : 17 : Fri
# time to turn-on appliacne on 20 : 56 : 53 equal to 5027 items
# consuming the appliance 3 hours 33 minutes 14 seconds that equal to 12794 seconds or 852 items
#
# Days : 18 : Sat
# time to turn-on appliacne on 21 : 43 : 8 equal to 5212 items
# consuming the appliance 2 hours 13 minutes 32 seconds that equal to 8012 seconds or 534 items
#
# Days : 19 : Sat
# time to turn-on appliacne on 0 : 59 : 55 equal to 239 items
# consuming the appliance 2 hours 14 minutes 35 seconds that equal to 8075 seconds or 538 items
#
# Days : 20 : Sun
# time to turn-on appliacne on 21 : 25 : 40 equal to 5142 items
# consuming the appliance 0 hours 15 minutes 15 seconds that equal to 915 seconds or 61 items
#
# Days : 21 : Mon
# time to turn-on appliacne on 21 : 2 : 41 equal to 5050 items
# consuming the appliance 2 hours 13 minutes 43 seconds that equal to 8023 seconds or 534 items
#
# Days : 22 : Tue
# time to turn-on appliacne on 20 : 51 : 4 equal to 5004 items
# consuming the appliance 3 hours 34 minutes 55 seconds that equal to 12895 seconds or 859 items
#
# Days : 23 : Thu
# time to turn-on appliacne on 20 : 37 : 54 equal to 4951 items
# consuming the appliance 5 hours 10 minutes 7 seconds that equal to 18607 seconds or 1240 items
#
# Days : 24 : Fri
# time to turn-on appliacne on 21 : 46 : 10 equal to 5224 items
# consuming the appliance 0 hours 37 minutes 33 seconds that equal to 2253 seconds or 150 items
#
# Days : 25 : Fri
# time to turn-on appliacne on 21 : 48 : 29 equal to 5233 items
# consuming the appliance 3 hours 26 minutes 58 seconds that equal to 12418 seconds or 827 items
#
# Days : 26 : Sun
# time to turn-on appliacne on 20 : 50 : 39 equal to 5002 items
# consuming the appliance 1 hours 25 minutes 33 seconds that equal to 5133 seconds or 342 items
#
# Days : 27 : Sun
# time to turn-on appliacne on 19 : 47 : 46 equal to 4751 items
# consuming the appliance 1 hours 30 minutes 0 seconds that equal to 5400 seconds or 360 items
#
# Days : 28 : Mon
# time to turn-on appliacne on 21 : 42 : 22 equal to 5209 items
# consuming the appliance 3 hours 20 minutes 2 seconds that equal to 12002 seconds or 800 items
#
# Days : 29 : Wed
# time to turn-on appliacne on 20 : 58 : 59 equal to 5035 items
# consuming the appliance 1 hours 29 minutes 52 seconds that equal to 5392 seconds or 359 items
#
# Days : 30 : Wed
# time to turn-on appliacne on 20 : 40 : 12 equal to 4960 items
# consuming the appliance 3 hours 39 minutes 10 seconds that equal to 13150 seconds or 876 items
# IndexErrorTraceback (most recent call last)
# <ipython-input-1-cacd28966aed> in <module>()
#      68
#      69     while (off_item+(5760*(days)) <= j <= (no_item+off_item)+(5760*(days))):
# ---> 70         c.execute("INSERT INTO data_month2.iphonecharger (Timestamp, watt) VALUES (%s, %s)",(time_b[j],df.watt[i]))
#      71         conn.commit()
#      72         i += 1
#
# /usr/local/lib/python2.7/dist-packages/pandas/tseries/base.pyc in __getitem__(self, key)
#     249         getitem = self._data.__getitem__
#     250         if is_int:
# --> 251             val = getitem(key)
#     252             return self._box_func(val)
#     253         else:
#
# IndexError: index 178560 is out of bounds for axis 0 with size 178560

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
# %matplotlib inline  


query = "SELECT Timestamp,watt FROM data_month2.iphonecharger WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[5760*10])
df = pd.read_sql(query, conn, index_col=['Timestamp'])
fig, ax = plt.subplots()
ax.set_title('data_month2.iphonecharger')
df.plot(ax=ax )
plt.show()
