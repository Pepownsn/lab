# %% [markdown]
# ## data_month2
# #### TV | LCD ขนาด 49 นิ้ว |

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random


d = 31

time_a = pd.date_range('2016-11-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-11-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####### set databases to empty #########
query_empty = """truncate table data_month2.TV""" 
c.execute(query_empty)
print "data_month2.TV are Empty!!! \n"

query = "SELECT watt FROM collected_info.3_TV WHERE no >= '%s'   AND no <= '%s'; "% (0,1200)
df = pd.read_sql(query, conn)
# print df.watt[5]

#### Random the number of turnon-time per day
def manytime():
    many  = ['1'] * 50 + ['2'] * 44 + ['3'] * 6  ## The number of turn-on time of this appliance 
    manytime = random.choice(many)
    print "\nDays :",days ,":",time_b[j].strftime('%a')
    print "in recent day turn on TV",manytime,"times\n"
    if (int(manytime) == 1):
        x,y,endx,endy = 18,20,2,4  # fix turn on only in evening      
        open_hour =  random.randint(x, y)
        open_min =  random.randint(0, 59)
        open_sec =  random.randint(0, 59)
        if 0 < open_sec  <= 15:
            k = 0
        elif 15 < open_sec  <= 30:
            k = 1
        elif 30 < open_sec  <= 45:
            k = 2
        else:
            k = 3
        off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
        print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
        
        duration_hour =  random.randint(endx, endy)
        duration_min =  random.randint(0, 59)
        duration_sec =  random.randint(0, 59)
        seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
        no_item = seconds/15
        print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"
        return (off_item,no_item)

        
    elif (int(manytime) == 2):
        turn_duratrion  = ['1'] * 70 + ['2'] * 30       #### '1' turn-on morning and evening   OR  '2' turn-on 2 times in evening 
        howturn = random.choice(turn_duratrion)
#         print howturn
        if (int(howturn)== 1 ):
            x,y,endx,endy = 6,7,1,59
            open_hour =  random.randint(x, y)
            open_min =  random.randint(0, 59)
            open_sec =  random.randint(0, 59)
            if 0 < open_sec  <= 15:
                k = 0
            elif 15 < open_sec  <= 30:
                k = 1
            elif 30 < open_sec  <= 45:
                k = 2
            else:
                k = 3
            off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
            print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
            
            duration_hour =  random.randint(0, 0)
            duration_min =  random.randint(endx, endy)
            duration_sec =  random.randint(0, 59)
            seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
            no_item = seconds/15
            print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"

        
            
            x1,y1,endx1,endy1 = 18,20,2,4
            open_hour1 =  random.randint(x1, y1)
            open_min1 =  random.randint(0, 59)
            open_sec1 =  random.randint(0, 59)
            if 0 < open_sec1  <= 15:
                k = 0
            elif 15 < open_sec1  <= 30:
                k = 1
            elif 30 < open_sec1  <= 45:
                k = 2
            else:
                k = 3
            off_item1 = (int(open_hour1)*240) + (int(open_min1)*4)+ k 
            print "time to turn-on appliacne on",open_hour1,":",open_min1,":",open_sec1,"equal to",off_item1,"items"     
            
            duration_hour1 =  random.randint(endx1, endy1)
            duration_min1 =  random.randint(0, 59)
            duration_sec1 =  random.randint(0, 59)
            seconds1 = (duration_hour1*3600)+(duration_min1*60)+duration_sec1
            no_item1 = seconds1/15
            print "consuming the appliance", duration_hour1,"hours",duration_min1,"minutes",duration_sec1,"seconds that equal to",seconds1,"seconds or",no_item1,"items\n"

        else :
            x,y,endx,endy = 18,19,1,59
            open_hour =  random.randint(x, y)
            open_min =  random.randint(0, 59)
            open_sec =  random.randint(0, 59)
            if 0 < open_sec  <= 15:
                k = 0
            elif 15 < open_sec  <= 30:
                k = 1
            elif 30 < open_sec  <= 45:
                k = 2
            else:
                k = 3
            off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
            print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
            
            duration_hour =  random.randint(0, 0)
            duration_min =  random.randint(endx, endy)
            duration_sec =  random.randint(0, 59)
            seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
            no_item = seconds/15
            print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"

        
            x1,y1,endx1,endy1 = 20,22,1,4
            open_hour1 =  random.randint(x1, y1)
            open_min1 =  random.randint(0, 59)
            open_sec1 =  random.randint(0, 59)
            if 0 < open_sec1  <= 15:
                k = 0
            elif 15 < open_sec1  <= 30:
                k = 1
            elif 30 < open_sec1  <= 45:
                k = 2
            else:
                k = 3
            off_item1 = (int(open_hour1)*240) + (int(open_min1)*4)+ k 
            print "time to turn-on appliacne on",open_hour1,":",open_min1,":",open_sec1,"equal to",off_item1,"items"   
            
            duration_hour1 =  random.randint(endx1, endy1)
            duration_min1 =  random.randint(0, 59)
            duration_sec1 =  random.randint(0, 59)
            seconds1 = (duration_hour1*3600)+(duration_min1*60)+duration_sec1
            no_item1 = seconds1/15
            print "consuming the appliance", duration_hour1,"hours",duration_min1,"minutes",duration_sec1,"seconds that equal to",seconds1,"seconds or",no_item1,"items\n"

        return (off_item,no_item,off_item1,no_item1)        
    else:
        x,y,endx,endy = 6,7,30,60
        open_hour =  random.randint(x, y)
        open_min =  random.randint(0, 59)
        open_sec =  random.randint(0, 59)
        if 0 < open_sec  <= 15:
            k = 0
        elif 15 < open_sec  <= 30:
            k = 1
        elif 30 < open_sec  <= 45:
            k = 2
        else:
            k = 3
        off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
        print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
        
        duration_hour =  random.randint(0,0)
        duration_min =  random.randint(endx, endy)
        duration_sec =  random.randint(0, 59)
        seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
        no_item = seconds/15
        print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"

    
    
        x1,y1,endx1,endy1 = 18,19,1,59
        open_hour1 =  random.randint(x1, y1)
        open_min1 =  random.randint(0, 59)
        open_sec1 =  random.randint(0, 59)
        if 0 < open_sec1  <= 15:
            k = 0
        elif 15 < open_sec1  <= 30:
            k = 1
        elif 30 < open_sec1  <= 45:
            k = 2
        else:
            k = 3
        off_item1 = (int(open_hour1)*240) + (int(open_min1)*4)+ k 
        print "time to turn-on appliacne on",open_hour1,":",open_min1,":",open_sec1,"equal to",off_item1,"items" 
        duration_hour1 =  random.randint(0, 0)
        duration_min1 =  random.randint(endx1, endy1)
        duration_sec1 =  random.randint(0, 59)
        seconds1 = (duration_hour1*3600)+(duration_min1*60)+duration_sec1
        no_item1 = seconds1/15
        print "consuming the appliance", duration_hour1,"hours",duration_min1,"minutes",duration_sec1,"seconds that equal to",seconds1,"seconds or",no_item1,"items\n"
    
    
        x2,y2,endx2,endy2 = 20,22,1,4
        open_hour2 =  random.randint(x2, y2)
        open_min2 =  random.randint(0, 59)
        open_sec2 =  random.randint(0, 59)
        if 0 < open_sec2  <= 15:
            k = 0
        elif 15 < open_sec2  <= 30:
            k = 1
        elif 30 < open_sec2  <= 45:
            k = 2
        else:
            k = 3
        off_item2 = (int(open_hour2)*240) + (int(open_min2)*4)+ k 
        print "time to turn-on appliacne on",open_hour2,":",open_min2,":",open_sec2,"equal to",off_item2,"items" 
        duration_hour2 =  random.randint(endx2, endy2)
        duration_min2 =  random.randint(0, 59)
        duration_sec2 =  random.randint(0, 59)
        seconds2 = (duration_hour2*3600)+(duration_min2*60)+duration_sec2
        no_item2 = seconds2/15
        print "consuming the appliance", duration_hour2,"hours",duration_min2,"minutes",duration_sec2,"seconds that equal to",seconds2,"seconds or",no_item2,"items\n"
        return (off_item,no_item,off_item1,no_item1,off_item2,no_item2)    
    
    
        
days = 1
j = 0

## (off_item,no_item,off_item1,no_item1,off_item2,no_item2)    

turn = manytime()
while (j <= (5760*d)-1):   
    if (j == 5760+(5760*(days-1))):
        days +=1
        print "-------------------------ENd-----------------------------\n"
        turn = manytime()          
        
    if len(turn)==2:
        off_item = turn[0] 
        no_item = turn[1]
        if (off_item+(5760*(days-1)) <= j <= (no_item+off_item)+(5760*(days-1))):
            c.execute("INSERT INTO data_month2.TV (Timestamp, watt) VALUES (%s, %s)",(time_b[j],random.randint(64, 68)))
            conn.commit()
            j += 1
        else:
            c.execute("INSERT INTO data_month2.TV (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
            conn.commit()
            j += 1
        
    elif len(turn)==4:
        off_item = turn[0] 
        no_item = turn[1]
        off_item1 = turn[2] 
        no_item1 = turn[3]
        if (off_item+(5760*(days-1)) <= j <= (no_item+off_item)+(5760*(days-1)) or off_item1+(5760*(days-1)) <= j <= (no_item1+off_item1)+(5760*(days-1))):
            c.execute("INSERT INTO data_month2.TV (Timestamp, watt) VALUES (%s, %s)",(time_b[j],random.randint(64, 68)))
            conn.commit()
            j += 1
        else:
            c.execute("INSERT INTO data_month2.TV (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
            conn.commit()
            j += 1
             
    else:
        off_item = turn[0] 
        no_item = turn[1]
        off_item1 = turn[2] 
        no_item1 = turn[3]
        off_item2 = turn[4] 
        no_item2 = turn[5]
        
        if (off_item+(5760*(days-1)) <= j <= (no_item+off_item)+(5760*(days-1)) or off_item1+(5760*(days-1)) <= j <= (no_item1+off_item1)+(5760*(days-1)) or off_item2+(5760*(days-1)) <= j <= (no_item2+off_item2)+(5760*(days-1)))  :
            c.execute("INSERT INTO data_month2.TV (Timestamp, watt) VALUES (%s, %s)",(time_b[j],random.randint(64, 68)))
            conn.commit()
            j += 1
        else:
            c.execute("INSERT INTO data_month2.TV (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
            conn.commit()
            j += 1
 
           
print "DONE!"
# Out:
# data_month2.TV are Empty!!!
#
#
# Days : 1 : Tue
# in recent day turn on TV 3 times
#
# time to turn-on appliacne on 6 : 5 : 58 equal to 1463 items
# consuming the appliance 0 hours 51 minutes 58 seconds that equal to 3118 seconds or 207 items
#
# time to turn-on appliacne on 18 : 41 : 30 equal to 4485 items
# consuming the appliance 0 hours 5 minutes 55 seconds that equal to 355 seconds or 23 items
#
# time to turn-on appliacne on 21 : 44 : 23 equal to 5217 items
# consuming the appliance 4 hours 0 minutes 43 seconds that equal to 14443 seconds or 962 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 2 : Wed
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 6 : 19 : 23 equal to 1517 items
# consuming the appliance 0 hours 16 minutes 57 seconds that equal to 1017 seconds or 67 items
#
# time to turn-on appliacne on 19 : 45 : 41 equal to 4742 items
# consuming the appliance 3 hours 6 minutes 16 seconds that equal to 11176 seconds or 745 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 3 : Thu
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 7 : 8 : 15 equal to 1712 items
# consuming the appliance 0 hours 39 minutes 46 seconds that equal to 2386 seconds or 159 items
#
# time to turn-on appliacne on 19 : 11 : 21 equal to 4605 items
# consuming the appliance 4 hours 47 minutes 35 seconds that equal to 17255 seconds or 1150 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 4 : Fri
# in recent day turn on TV 3 times
#
# time to turn-on appliacne on 7 : 22 : 44 equal to 1770 items
# consuming the appliance 0 hours 55 minutes 31 seconds that equal to 3331 seconds or 222 items
#
# time to turn-on appliacne on 18 : 41 : 52 equal to 4487 items
# consuming the appliance 0 hours 26 minutes 13 seconds that equal to 1573 seconds or 104 items
#
# time to turn-on appliacne on 20 : 32 : 50 equal to 4931 items
# consuming the appliance 3 hours 16 minutes 3 seconds that equal to 11763 seconds or 784 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 5 : Sat
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 18 : 28 : 47 equal to 4435 items
# consuming the appliance 0 hours 12 minutes 37 seconds that equal to 757 seconds or 50 items
#
# time to turn-on appliacne on 20 : 30 : 10 equal to 4920 items
# consuming the appliance 2 hours 11 minutes 14 seconds that equal to 7874 seconds or 524 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 6 : Sun
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 19 : 36 : 49 equal to 4707 items
# consuming the appliance 0 hours 18 minutes 40 seconds that equal to 1120 seconds or 74 items
#
# time to turn-on appliacne on 22 : 46 : 12 equal to 5464 items
# consuming the appliance 2 hours 7 minutes 23 seconds that equal to 7643 seconds or 509 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 7 : Mon
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 18 : 4 : 57 equal to 4339 items
# consuming the appliance 4 hours 30 minutes 4 seconds that equal to 16204 seconds or 1080 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 8 : Tue
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 20 : 1 : 39 equal to 4806 items
# consuming the appliance 3 hours 0 minutes 6 seconds that equal to 10806 seconds or 720 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 9 : Wed
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 19 : 28 : 51 equal to 4675 items
# consuming the appliance 0 hours 32 minutes 5 seconds that equal to 1925 seconds or 128 items
#
# time to turn-on appliacne on 21 : 48 : 32 equal to 5234 items
# consuming the appliance 2 hours 13 minutes 28 seconds that equal to 8008 seconds or 533 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 10 : Thu
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 20 : 16 : 44 equal to 4866 items
# consuming the appliance 2 hours 28 minutes 24 seconds that equal to 8904 seconds or 593 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 11 : Fri
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 20 : 33 : 42 equal to 4934 items
# consuming the appliance 2 hours 49 minutes 11 seconds that equal to 10151 seconds or 676 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 12 : Sat
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 19 : 29 : 47 equal to 4679 items
# consuming the appliance 4 hours 55 minutes 59 seconds that equal to 17759 seconds or 1183 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 13 : Sun
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 19 : 2 : 36 equal to 4570 items
# consuming the appliance 0 hours 53 minutes 51 seconds that equal to 3231 seconds or 215 items
#
# time to turn-on appliacne on 22 : 48 : 42 equal to 5474 items
# consuming the appliance 3 hours 38 minutes 21 seconds that equal to 13101 seconds or 873 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 14 : Mon
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 20 : 20 : 19 equal to 4881 items
# consuming the appliance 4 hours 54 minutes 27 seconds that equal to 17667 seconds or 1177 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 15 : Tue
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 18 : 56 : 34 equal to 4546 items
# consuming the appliance 3 hours 51 minutes 12 seconds that equal to 13872 seconds or 924 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 16 : Wed
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 20 : 25 : 33 equal to 4902 items
# consuming the appliance 2 hours 28 minutes 51 seconds that equal to 8931 seconds or 595 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 17 : Thu
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 18 : 45 : 11 equal to 4500 items
# consuming the appliance 4 hours 24 minutes 25 seconds that equal to 15865 seconds or 1057 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 18 : Fri
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 7 : 48 : 33 equal to 1874 items
# consuming the appliance 0 hours 43 minutes 1 seconds that equal to 2581 seconds or 172 items
#
# time to turn-on appliacne on 19 : 55 : 51 equal to 4783 items
# consuming the appliance 2 hours 39 minutes 29 seconds that equal to 9569 seconds or 637 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 19 : Sat
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 20 : 42 : 48 equal to 4971 items
# consuming the appliance 3 hours 43 minutes 51 seconds that equal to 13431 seconds or 895 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 20 : Sun
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 7 : 35 : 44 equal to 1822 items
# consuming the appliance 0 hours 43 minutes 35 seconds that equal to 2615 seconds or 174 items
#
# time to turn-on appliacne on 18 : 31 : 57 equal to 4447 items
# consuming the appliance 3 hours 53 minutes 36 seconds that equal to 14016 seconds or 934 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 21 : Mon
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 20 : 57 : 32 equal to 5030 items
# consuming the appliance 4 hours 42 minutes 58 seconds that equal to 16978 seconds or 1131 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 22 : Tue
# in recent day turn on TV 3 times
#
# time to turn-on appliacne on 7 : 49 : 14 equal to 1876 items
# consuming the appliance 0 hours 59 minutes 59 seconds that equal to 3599 seconds or 239 items
#
# time to turn-on appliacne on 19 : 31 : 24 equal to 4685 items
# consuming the appliance 0 hours 35 minutes 50 seconds that equal to 2150 seconds or 143 items
#
# time to turn-on appliacne on 20 : 46 : 55 equal to 4987 items
# consuming the appliance 1 hours 56 minutes 16 seconds that equal to 6976 seconds or 465 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 23 : Wed
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 18 : 1 : 44 equal to 4326 items
# consuming the appliance 4 hours 25 minutes 5 seconds that equal to 15905 seconds or 1060 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 24 : Thu
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 20 : 15 : 44 equal to 4862 items
# consuming the appliance 3 hours 8 minutes 30 seconds that equal to 11310 seconds or 754 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 25 : Fri
# in recent day turn on TV 3 times
#
# time to turn-on appliacne on 6 : 4 : 29 equal to 1457 items
# consuming the appliance 0 hours 33 minutes 53 seconds that equal to 2033 seconds or 135 items
#
# time to turn-on appliacne on 19 : 43 : 34 equal to 4734 items
# consuming the appliance 0 hours 23 minutes 15 seconds that equal to 1395 seconds or 93 items
#
# time to turn-on appliacne on 22 : 51 : 41 equal to 5486 items
# consuming the appliance 1 hours 56 minutes 17 seconds that equal to 6977 seconds or 465 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 26 : Sat
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 20 : 47 : 6 equal to 4988 items
# consuming the appliance 3 hours 17 minutes 18 seconds that equal to 11838 seconds or 789 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 27 : Sun
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 19 : 51 : 49 equal to 4767 items
# consuming the appliance 4 hours 3 minutes 1 seconds that equal to 14581 seconds or 972 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 28 : Mon
# in recent day turn on TV 1 times
#
# time to turn-on appliacne on 19 : 13 : 57 equal to 4615 items
# consuming the appliance 4 hours 45 minutes 6 seconds that equal to 17106 seconds or 1140 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 29 : Tue
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 19 : 34 : 8 equal to 4696 items
# consuming the appliance 0 hours 28 minutes 7 seconds that equal to 1687 seconds or 112 items
#
# time to turn-on appliacne on 20 : 21 : 53 equal to 4887 items
# consuming the appliance 4 hours 16 minutes 17 seconds that equal to 15377 seconds or 1025 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 30 : Wed
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 6 : 10 : 47 equal to 1483 items
# consuming the appliance 0 hours 21 minutes 14 seconds that equal to 1274 seconds or 84 items
#
# time to turn-on appliacne on 19 : 53 : 8 equal to 4772 items
# consuming the appliance 3 hours 48 minutes 26 seconds that equal to 13706 seconds or 913 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 31 : Thu
# in recent day turn on TV 2 times
#
# time to turn-on appliacne on 19 : 42 : 8 equal to 4728 items
# consuming the appliance 0 hours 32 minutes 34 seconds that equal to 1954 seconds or 130 items
#
# time to turn-on appliacne on 20 : 11 : 21 equal to 4845 items
# consuming the appliance 3 hours 12 minutes 19 seconds that equal to 11539 seconds or 769 items
#
# DONE!

# %%
import matplotlib.pyplot as plt
# %matplotlib inline  


# query = "SELECT watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
query = "SELECT Timestamp,watt FROM data_month2.TV WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[3000],time_b[5760*4])
df = pd.read_sql(query, conn, index_col=['Timestamp'])

fig, ax = plt.subplots()
ax.set_title('data_month2.TV')
ax.set_ylim(64,68)
df.plot(ax=ax )
plt.show()
# df.to_csv('file.csv')
# len(time_b)
