# %% [markdown]
# ## data_month3
# #### Elec_thermos | ขนาด 2.8 ลิตร  |

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random


d = 31
time_a = pd.date_range('2016-12-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-12-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####### set databases to empty #########
query_empty = """truncate table data_month3.elec_thermos""" 
c.execute(query_empty)
print "data_month3.elec_thermos are Empty!!! \n"

query = "SELECT watt FROM collected_info.8_elec_thermos WHERE no >= '%s'   AND no <= '%s'; "% (0,1167)
df = pd.read_sql(query, conn)
# print df.watt[5]

#### Random the turning-on time appliances
def rand_turnon():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(0, 59)
    duration_hour1 = ['6'] * 2 + ['7'] * 48 + ['8'] * 47 + ['9'] * 3    #SET Start 6-9 am.
    duration_hour = random.choice(duration_hour1)     
    if 0 < duration_sec <= 15:
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
    off_item = (int(duration_hour)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on appliacne on",duration_hour,":",duration_min,":",duration_sec,"equal to",off_item,"items"
    return off_item

 
#### Random the off-duration appliances 
def rand_duration():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(0, 59)
    duration_hour1 = ['0'] * 97 + ['1'] * 2+ ['2'] * 1
    duration_hour = random.choice(duration_hour1)   
    seconds = (int(duration_hour)*3600)+(duration_min*60)+duration_sec
    no_item = seconds/15
    print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items"
    return no_item

days = 0
j = 0
i = 0
print "\nDays :",days ,":",time_b[j].strftime('%a')
off_item = rand_turnon()  
no_item = rand_duration()  

while (j <= (5760*d)-1):  
    c.execute("INSERT INTO data_month3.elec_thermos (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
    conn.commit()
    j += 1 
    
    while (off_item+(5760*(days)) <= j <= (no_item+off_item)+(5760*(days))):                   
        c.execute("INSERT INTO data_month3.elec_thermos (Timestamp, watt) VALUES (%s, %s)",(time_b[j],df.watt[i]))
        conn.commit()
        i += 1 
        j += 1
        if (j == (no_item+off_item)+(5760*(days))):
            days +=1
            print "\nDays :",days ,":",time_b[j].strftime('%a')
            off_item = rand_turnon()  
            no_item = rand_duration() 
            i= 0   

                    
print "DONE!"
# Out:
# data_month3.elec_thermos are Empty!!!
#
#
# Days : 0 : Thu
# time to turn-on appliacne on 8 : 33 : 42 equal to 2054 items
# consuming the appliance 0 hours 6 minutes 5 seconds that equal to 365 seconds or 24 items
#
# Days : 1 : Thu
# time to turn-on appliacne on 8 : 12 : 1 equal to 1968 items
# consuming the appliance 0 hours 2 minutes 27 seconds that equal to 147 seconds or 9 items
#
# Days : 2 : Fri
# time to turn-on appliacne on 8 : 50 : 28 equal to 2121 items
# consuming the appliance 0 hours 10 minutes 31 seconds that equal to 631 seconds or 42 items
#
# Days : 3 : Sat
# time to turn-on appliacne on 7 : 10 : 5 equal to 1720 items
# consuming the appliance 0 hours 21 minutes 22 seconds that equal to 1282 seconds or 85 items
#
# Days : 4 : Sun
# time to turn-on appliacne on 7 : 22 : 4 equal to 1768 items
# consuming the appliance 0 hours 57 minutes 40 seconds that equal to 3460 seconds or 230 items
#
# Days : 5 : Mon
# time to turn-on appliacne on 8 : 11 : 5 equal to 1964 items
# consuming the appliance 0 hours 36 minutes 43 seconds that equal to 2203 seconds or 146 items
#
# Days : 6 : Tue
# time to turn-on appliacne on 7 : 35 : 35 equal to 1822 items
# consuming the appliance 0 hours 42 minutes 38 seconds that equal to 2558 seconds or 170 items
#
# Days : 7 : Wed
# time to turn-on appliacne on 8 : 25 : 10 equal to 2020 items
# consuming the appliance 0 hours 44 minutes 50 seconds that equal to 2690 seconds or 179 items
#
# Days : 8 : Thu
# time to turn-on appliacne on 7 : 16 : 5 equal to 1744 items
# consuming the appliance 0 hours 55 minutes 4 seconds that equal to 3304 seconds or 220 items
#
# Days : 9 : Fri
# time to turn-on appliacne on 6 : 31 : 5 equal to 1564 items
# consuming the appliance 0 hours 7 minutes 26 seconds that equal to 446 seconds or 29 items
#
# Days : 10 : Sat
# time to turn-on appliacne on 8 : 1 : 55 equal to 1927 items
# consuming the appliance 0 hours 1 minutes 29 seconds that equal to 89 seconds or 5 items
#
# Days : 11 : Sun
# time to turn-on appliacne on 9 : 54 : 44 equal to 2378 items
# consuming the appliance 0 hours 50 minutes 44 seconds that equal to 3044 seconds or 202 items
#
# Days : 12 : Mon
# time to turn-on appliacne on 8 : 42 : 35 equal to 2090 items
# consuming the appliance 0 hours 31 minutes 59 seconds that equal to 1919 seconds or 127 items
#
# Days : 13 : Tue
# time to turn-on appliacne on 7 : 36 : 13 equal to 1824 items
# consuming the appliance 0 hours 14 minutes 54 seconds that equal to 894 seconds or 59 items
#
# Days : 14 : Wed
# time to turn-on appliacne on 8 : 48 : 20 equal to 2113 items
# consuming the appliance 0 hours 9 minutes 38 seconds that equal to 578 seconds or 38 items
#
# Days : 15 : Thu
# time to turn-on appliacne on 7 : 4 : 19 equal to 1697 items
# consuming the appliance 0 hours 15 minutes 32 seconds that equal to 932 seconds or 62 items
#
# Days : 16 : Fri
# time to turn-on appliacne on 7 : 26 : 33 equal to 1786 items
# consuming the appliance 0 hours 1 minutes 29 seconds that equal to 89 seconds or 5 items
#
# Days : 17 : Sat
# time to turn-on appliacne on 7 : 29 : 40 equal to 1798 items
# consuming the appliance 0 hours 17 minutes 11 seconds that equal to 1031 seconds or 68 items
#
# Days : 18 : Sun
# time to turn-on appliacne on 8 : 41 : 53 equal to 2087 items
# consuming the appliance 0 hours 55 minutes 35 seconds that equal to 3335 seconds or 222 items
#
# Days : 19 : Mon
# time to turn-on appliacne on 7 : 5 : 18 equal to 1701 items
# consuming the appliance 0 hours 41 minutes 42 seconds that equal to 2502 seconds or 166 items
#
# Days : 20 : Tue
# time to turn-on appliacne on 8 : 37 : 36 equal to 2070 items
# consuming the appliance 0 hours 46 minutes 44 seconds that equal to 2804 seconds or 186 items
#
# Days : 21 : Wed
# time to turn-on appliacne on 8 : 55 : 37 equal to 2142 items
# consuming the appliance 0 hours 55 minutes 50 seconds that equal to 3350 seconds or 223 items
#
# Days : 22 : Thu
# time to turn-on appliacne on 8 : 57 : 28 equal to 2149 items
# consuming the appliance 0 hours 27 minutes 38 seconds that equal to 1658 seconds or 110 items
#
# Days : 23 : Fri
# time to turn-on appliacne on 7 : 17 : 11 equal to 1748 items
# consuming the appliance 0 hours 16 minutes 22 seconds that equal to 982 seconds or 65 items
#
# Days : 24 : Sat
# time to turn-on appliacne on 8 : 41 : 24 equal to 2085 items
# consuming the appliance 0 hours 59 minutes 48 seconds that equal to 3588 seconds or 239 items
#
# Days : 25 : Sun
# time to turn-on appliacne on 7 : 13 : 40 equal to 1734 items
# consuming the appliance 0 hours 8 minutes 46 seconds that equal to 526 seconds or 35 items
#
# Days : 26 : Mon
# time to turn-on appliacne on 7 : 17 : 32 equal to 1750 items
# consuming the appliance 0 hours 56 minutes 19 seconds that equal to 3379 seconds or 225 items
#
# Days : 27 : Tue
# time to turn-on appliacne on 6 : 2 : 2 equal to 1448 items
# consuming the appliance 0 hours 41 minutes 54 seconds that equal to 2514 seconds or 167 items
#
# Days : 28 : Wed
# time to turn-on appliacne on 8 : 3 : 48 equal to 1935 items
# consuming the appliance 0 hours 44 minutes 35 seconds that equal to 2675 seconds or 178 items
#
# Days : 29 : Thu
# time to turn-on appliacne on 7 : 12 : 3 equal to 1728 items
# consuming the appliance 0 hours 42 minutes 22 seconds that equal to 2542 seconds or 169 items
#
# Days : 30 : Fri
# time to turn-on appliacne on 7 : 48 : 13 equal to 1872 items
# consuming the appliance 0 hours 39 minutes 59 seconds that equal to 2399 seconds or 159 items
#
# Days : 31 : Sat
# time to turn-on appliacne on 7 : 34 : 48 equal to 1819 items
# consuming the appliance 0 hours 0 minutes 43 seconds that equal to 43 seconds or 2 items
# DONE!

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
# %matplotlib inline  

# query = "SELECT watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
query = "SELECT Timestamp,watt FROM data_month3.elec_thermos WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
df = pd.read_sql(query, conn, index_col=['Timestamp'])
fig, ax = plt.subplots()
ax.set_title('data_month3.elec_thermos')
df.plot(ax=ax )
plt.show()
