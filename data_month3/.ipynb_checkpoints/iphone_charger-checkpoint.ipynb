# %% [markdown]
# ## data_month3
# #### IPHONE charger | ipad 9.7 นิ้ว |

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random


d = 31
time_a = pd.date_range('2016-12-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-12-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####### set databases to empty #########
query_empty = """truncate table data_month3.iphonecharger""" 
c.execute(query_empty)
print "data_month3.iphonecharger are Empty!!! \n"

query = "SELECT watt FROM collected_info.13_iphonecharger WHERE no >= '%s'   AND no <= '%s'; "% (0,1200)
df = pd.read_sql(query, conn)
# print df.watt[5]

#### Random the turning-on time appliances
def rand_turnon():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(0, 59)
    duration_hour1 = ['18'] * 5 + ['19'] * 8 + ['20'] * 36 + ['21'] * 30 + ['22'] * 13 + ['23'] * 6 + ['0'] * 2
    duration_hour = random.choice(duration_hour1)     
    if 0 < duration_sec <= 15:
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
    off_item = (int(duration_hour)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on appliacne on",duration_hour,":",duration_min,":",duration_sec,"equal to",off_item,"items"
    return off_item

 
#### Random the off-duration appliances 
def rand_duration():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(10, 40)
    duration_hour1 = ['0'] * 2 + ['1'] * 25 + ['2'] * 35+ ['3'] * 20 + ['4'] * 10 + ['5'] * 8
    duration_hour = random.choice(duration_hour1)   
    seconds = (int(duration_hour)*3600)+(duration_min*60)+duration_sec
    no_item = seconds/15
    print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items"
    return no_item

days = 0
j = 0
i = 0
print "\nDays :",days ,":",time_b[j].strftime('%a')
off_item = rand_turnon()  
no_item = rand_duration()  

while (j <= (5760*d)-1):  
    c.execute("INSERT INTO data_month3.iphonecharger (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
    conn.commit()
    j += 1 
          
    while (off_item+(5760*(days)) <= j <= (no_item+off_item)+(5760*(days))):                   
        c.execute("INSERT INTO data_month3.iphonecharger (Timestamp, watt) VALUES (%s, %s)",(time_b[j],df.watt[i]))
        conn.commit()
        i += 1 
        j += 1
            
        if (i >= len(df)):
            i = 0  
        if (j == (no_item+off_item)+(5760*(days))):
            days +=1
            print "\nDays :",days ,":",time_b[j].strftime('%a')
            off_item = rand_turnon()  
            no_item = rand_duration() 
            i= 0   

                    
print "DONE!"
# Out:
# data_month3.iphonecharger are Empty!!!
#
#
# Days : 0 : Thu
# time to turn-on appliacne on 21 : 29 : 45 equal to 5158 items
# consuming the appliance 1 hours 16 minutes 0 seconds that equal to 4560 seconds or 304 items
#
# Days : 1 : Thu
# time to turn-on appliacne on 23 : 0 : 1 equal to 5520 items
# consuming the appliance 3 hours 29 minutes 35 seconds that equal to 12575 seconds or 838 items
#
# Days : 2 : Sat
# time to turn-on appliacne on 20 : 18 : 10 equal to 4872 items
# consuming the appliance 2 hours 26 minutes 7 seconds that equal to 8767 seconds or 584 items
#
# Days : 3 : Sat
# time to turn-on appliacne on 20 : 53 : 29 equal to 5013 items
# consuming the appliance 4 hours 18 minutes 28 seconds that equal to 15508 seconds or 1033 items
#
# Days : 4 : Mon
# time to turn-on appliacne on 19 : 50 : 16 equal to 4761 items
# consuming the appliance 4 hours 29 minutes 53 seconds that equal to 16193 seconds or 1079 items
#
# Days : 5 : Tue
# time to turn-on appliacne on 21 : 20 : 28 equal to 5121 items
# consuming the appliance 3 hours 33 minutes 26 seconds that equal to 12806 seconds or 853 items
#
# Days : 6 : Wed
# time to turn-on appliacne on 21 : 36 : 12 equal to 5184 items
# consuming the appliance 5 hours 18 minutes 33 seconds that equal to 19113 seconds or 1274 items
#
# Days : 7 : Thu
# time to turn-on appliacne on 23 : 27 : 2 equal to 5628 items
# consuming the appliance 5 hours 13 minutes 12 seconds that equal to 18792 seconds or 1252 items
#
# Days : 8 : Fri
# time to turn-on appliacne on 20 : 10 : 11 equal to 4840 items
# consuming the appliance 3 hours 31 minutes 8 seconds that equal to 12668 seconds or 844 items
#
# Days : 9 : Fri
# time to turn-on appliacne on 20 : 11 : 59 equal to 4847 items
# consuming the appliance 1 hours 31 minutes 24 seconds that equal to 5484 seconds or 365 items
#
# Days : 10 : Sat
# time to turn-on appliacne on 21 : 54 : 33 equal to 5258 items
# consuming the appliance 1 hours 12 minutes 53 seconds that equal to 4373 seconds or 291 items
#
# Days : 11 : Sun
# time to turn-on appliacne on 20 : 44 : 40 equal to 4978 items
# consuming the appliance 3 hours 36 minutes 11 seconds that equal to 12971 seconds or 864 items
#
# Days : 12 : Tue
# time to turn-on appliacne on 20 : 0 : 31 equal to 4802 items
# consuming the appliance 1 hours 12 minutes 39 seconds that equal to 4359 seconds or 290 items
#
# Days : 13 : Tue
# time to turn-on appliacne on 21 : 17 : 37 equal to 5110 items
# consuming the appliance 4 hours 22 minutes 50 seconds that equal to 15770 seconds or 1051 items
#
# Days : 14 : Thu
# time to turn-on appliacne on 19 : 59 : 12 equal to 4796 items
# consuming the appliance 2 hours 12 minutes 56 seconds that equal to 7976 seconds or 531 items
#
# Days : 15 : Thu
# time to turn-on appliacne on 20 : 37 : 50 equal to 4951 items
# consuming the appliance 2 hours 32 minutes 21 seconds that equal to 9141 seconds or 609 items
#
# Days : 16 : Fri
# time to turn-on appliacne on 18 : 33 : 3 equal to 4452 items
# consuming the appliance 2 hours 23 minutes 30 seconds that equal to 8610 seconds or 574 items
#
# Days : 17 : Sat
# time to turn-on appliacne on 20 : 5 : 14 equal to 4820 items
# consuming the appliance 2 hours 12 minutes 42 seconds that equal to 7962 seconds or 530 items
#
# Days : 18 : Sun
# time to turn-on appliacne on 20 : 12 : 6 equal to 4848 items
# consuming the appliance 3 hours 25 minutes 6 seconds that equal to 12306 seconds or 820 items
#
# Days : 19 : Mon
# time to turn-on appliacne on 20 : 2 : 45 equal to 4810 items
# consuming the appliance 1 hours 10 minutes 57 seconds that equal to 4257 seconds or 283 items
#
# Days : 20 : Tue
# time to turn-on appliacne on 21 : 5 : 26 equal to 5061 items
# consuming the appliance 5 hours 17 minutes 18 seconds that equal to 19038 seconds or 1269 items
#
# Days : 21 : Thu
# time to turn-on appliacne on 20 : 17 : 21 equal to 4869 items
# consuming the appliance 2 hours 15 minutes 40 seconds that equal to 8140 seconds or 542 items
#
# Days : 22 : Thu
# time to turn-on appliacne on 20 : 27 : 59 equal to 4911 items
# consuming the appliance 2 hours 36 minutes 32 seconds that equal to 9392 seconds or 626 items
#
# Days : 23 : Fri
# time to turn-on appliacne on 21 : 3 : 8 equal to 5052 items
# consuming the appliance 3 hours 24 minutes 7 seconds that equal to 12247 seconds or 816 items
#
# Days : 24 : Sun
# time to turn-on appliacne on 20 : 1 : 20 equal to 4805 items
# consuming the appliance 3 hours 19 minutes 17 seconds that equal to 11957 seconds or 797 items
#
# Days : 25 : Sun
# time to turn-on appliacne on 21 : 8 : 17 equal to 5073 items
# consuming the appliance 2 hours 12 minutes 48 seconds that equal to 7968 seconds or 531 items
#
# Days : 26 : Mon
# time to turn-on appliacne on 20 : 18 : 8 equal to 4872 items
# consuming the appliance 2 hours 15 minutes 42 seconds that equal to 8142 seconds or 542 items
#
# Days : 27 : Tue
# time to turn-on appliacne on 20 : 14 : 34 equal to 4858 items
# consuming the appliance 5 hours 23 minutes 17 seconds that equal to 19397 seconds or 1293 items
#
# Days : 28 : Thu
# time to turn-on appliacne on 20 : 16 : 47 equal to 4867 items
# consuming the appliance 2 hours 24 minutes 6 seconds that equal to 8646 seconds or 576 items
#
# Days : 29 : Thu
# time to turn-on appliacne on 20 : 0 : 18 equal to 4801 items
# consuming the appliance 1 hours 10 minutes 0 seconds that equal to 4200 seconds or 280 items
#
# Days : 30 : Fri
# time to turn-on appliacne on 20 : 0 : 13 equal to 4800 items
# consuming the appliance 3 hours 20 minutes 40 seconds that equal to 12040 seconds or 802 items
#
# Days : 31 : Sat
# time to turn-on appliacne on 21 : 4 : 56 equal to 5059 items
# consuming the appliance 3 hours 24 minutes 58 seconds that equal to 12298 seconds or 819 items
# DONE!

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
# %matplotlib inline  


query = "SELECT Timestamp,watt FROM data_month3.iphonecharger WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[5760*10])
df = pd.read_sql(query, conn, index_col=['Timestamp'])
fig, ax = plt.subplots()
ax.set_title('data_month3.iphonecharger')
df.plot(ax=ax )
plt.show()
