# %% [markdown]
# ## data_month2
# #### Elec_thermos | ขนาด 2.8 ลิตร  |

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random


d = 31
time_a = pd.date_range('2016-11-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-11-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####### set databases to empty #########
query_empty = """truncate table data_month2.elec_thermos""" 
c.execute(query_empty)
print "data_month2.elec_thermos are Empty!!! \n"

query = "SELECT watt FROM collected_info.8_elec_thermos WHERE no >= '%s'   AND no <= '%s'; "% (0,1167)
df = pd.read_sql(query, conn)
# print df.watt[5]

#### Random the turning-on time appliances
def rand_turnon():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(0, 59)
    duration_hour1 = ['6'] * 2 + ['7'] * 48 + ['8'] * 47 + ['9'] * 3    #SET Start 6-9 am.
    duration_hour = random.choice(duration_hour1)     
    if 0 < duration_sec <= 15:
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
    off_item = (int(duration_hour)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on appliacne on",duration_hour,":",duration_min,":",duration_sec,"equal to",off_item,"items"
    return off_item

 
#### Random the off-duration appliances 
def rand_duration():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(0, 59)
    duration_hour1 = ['0'] * 97 + ['1'] * 2+ ['2'] * 1
    duration_hour = random.choice(duration_hour1)   
    seconds = (int(duration_hour)*3600)+(duration_min*60)+duration_sec
    no_item = seconds/15
    print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items"
    return no_item

days = 0
j = 0
i = 0
print "\nDays :",days ,":",time_b[j].strftime('%a')
off_item = rand_turnon()  
no_item = rand_duration()  

while (j <= (5760*d)-1):  
    c.execute("INSERT INTO data_month2.elec_thermos (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
    conn.commit()
    j += 1 
    
    while (off_item+(5760*(days)) <= j <= (no_item+off_item)+(5760*(days))):                   
        c.execute("INSERT INTO data_month2.elec_thermos (Timestamp, watt) VALUES (%s, %s)",(time_b[j],df.watt[i]))
        conn.commit()
        i += 1 
        j += 1
        if (j == (no_item+off_item)+(5760*(days))):
            days +=1
            print "\nDays :",days ,":",time_b[j].strftime('%a')
            off_item = rand_turnon()  
            no_item = rand_duration() 
            i= 0   

                    
print "DONE!"
# Out:
# data_month2.elec_thermos are Empty!!!
#
#
# Days : 0 : Tue
# time to turn-on appliacne on 7 : 3 : 5 equal to 1692 items
# consuming the appliance 0 hours 4 minutes 36 seconds that equal to 276 seconds or 18 items
#
# Days : 1 : Tue
# time to turn-on appliacne on 8 : 54 : 9 equal to 2136 items
# consuming the appliance 0 hours 41 minutes 44 seconds that equal to 2504 seconds or 166 items
#
# Days : 2 : Wed
# time to turn-on appliacne on 9 : 32 : 54 equal to 2291 items
# consuming the appliance 0 hours 53 minutes 55 seconds that equal to 3235 seconds or 215 items
#
# Days : 3 : Thu
# time to turn-on appliacne on 8 : 5 : 42 equal to 1942 items
# consuming the appliance 0 hours 11 minutes 31 seconds that equal to 691 seconds or 46 items
#
# Days : 4 : Fri
# time to turn-on appliacne on 8 : 20 : 16 equal to 2001 items
# consuming the appliance 0 hours 17 minutes 0 seconds that equal to 1020 seconds or 68 items
#
# Days : 5 : Sat
# time to turn-on appliacne on 8 : 4 : 1 equal to 1936 items
# consuming the appliance 1 hours 2 minutes 30 seconds that equal to 3750 seconds or 250 items
#
# Days : 6 : Sun
# time to turn-on appliacne on 7 : 47 : 45 equal to 1870 items
# consuming the appliance 0 hours 46 minutes 0 seconds that equal to 2760 seconds or 184 items
#
# Days : 7 : Mon
# time to turn-on appliacne on 8 : 55 : 49 equal to 2143 items
# consuming the appliance 0 hours 33 minutes 4 seconds that equal to 1984 seconds or 132 items
#
# Days : 8 : Tue
# time to turn-on appliacne on 7 : 38 : 32 equal to 1834 items
# consuming the appliance 2 hours 7 minutes 38 seconds that equal to 7658 seconds or 510 items
#
# Days : 9 : Wed
# time to turn-on appliacne on 7 : 15 : 32 equal to 1742 items
# consuming the appliance 0 hours 48 minutes 2 seconds that equal to 2882 seconds or 192 items
#
# Days : 10 : Thu
# time to turn-on appliacne on 8 : 14 : 9 equal to 1976 items
# consuming the appliance 0 hours 52 minutes 55 seconds that equal to 3175 seconds or 211 items
#
# Days : 11 : Fri
# time to turn-on appliacne on 8 : 4 : 4 equal to 1936 items
# consuming the appliance 0 hours 19 minutes 15 seconds that equal to 1155 seconds or 77 items
#
# Days : 12 : Sat
# time to turn-on appliacne on 7 : 10 : 40 equal to 1722 items
# consuming the appliance 0 hours 5 minutes 3 seconds that equal to 303 seconds or 20 items
#
# Days : 13 : Sun
# time to turn-on appliacne on 7 : 33 : 34 equal to 1814 items
# consuming the appliance 0 hours 31 minutes 12 seconds that equal to 1872 seconds or 124 items
#
# Days : 14 : Mon
# time to turn-on appliacne on 8 : 36 : 35 equal to 2066 items
# consuming the appliance 0 hours 32 minutes 1 seconds that equal to 1921 seconds or 128 items
#
# Days : 15 : Tue
# time to turn-on appliacne on 7 : 23 : 19 equal to 1773 items
# consuming the appliance 0 hours 20 minutes 53 seconds that equal to 1253 seconds or 83 items
#
# Days : 16 : Wed
# time to turn-on appliacne on 7 : 58 : 22 equal to 1913 items
# consuming the appliance 0 hours 27 minutes 27 seconds that equal to 1647 seconds or 109 items
#
# Days : 17 : Thu
# time to turn-on appliacne on 7 : 38 : 22 equal to 1833 items
# consuming the appliance 0 hours 1 minutes 15 seconds that equal to 75 seconds or 5 items
#
# Days : 18 : Fri
# time to turn-on appliacne on 7 : 31 : 16 equal to 1805 items
# consuming the appliance 0 hours 34 minutes 27 seconds that equal to 2067 seconds or 137 items
#
# Days : 19 : Sat
# time to turn-on appliacne on 8 : 16 : 8 equal to 1984 items
# consuming the appliance 0 hours 4 minutes 16 seconds that equal to 256 seconds or 17 items
#
# Days : 20 : Sun
# time to turn-on appliacne on 8 : 9 : 5 equal to 1956 items
# consuming the appliance 0 hours 54 minutes 21 seconds that equal to 3261 seconds or 217 items
#
# Days : 21 : Mon
# time to turn-on appliacne on 8 : 19 : 53 equal to 1999 items
# consuming the appliance 0 hours 2 minutes 45 seconds that equal to 165 seconds or 11 items
#
# Days : 22 : Tue
# time to turn-on appliacne on 9 : 21 : 20 equal to 2245 items
# consuming the appliance 0 hours 8 minutes 28 seconds that equal to 508 seconds or 33 items
#
# Days : 23 : Wed
# time to turn-on appliacne on 8 : 14 : 57 equal to 1979 items
# consuming the appliance 0 hours 5 minutes 51 seconds that equal to 351 seconds or 23 items
#
# Days : 24 : Thu
# time to turn-on appliacne on 7 : 52 : 6 equal to 1888 items
# consuming the appliance 0 hours 18 minutes 8 seconds that equal to 1088 seconds or 72 items
#
# Days : 25 : Fri
# time to turn-on appliacne on 7 : 40 : 26 equal to 1841 items
# consuming the appliance 0 hours 38 minutes 17 seconds that equal to 2297 seconds or 153 items
#
# Days : 26 : Sat
# time to turn-on appliacne on 8 : 49 : 55 equal to 2119 items
# consuming the appliance 0 hours 4 minutes 44 seconds that equal to 284 seconds or 18 items
#
# Days : 27 : Sun
# time to turn-on appliacne on 7 : 23 : 7 equal to 1772 items
# consuming the appliance 0 hours 38 minutes 57 seconds that equal to 2337 seconds or 155 items
#
# Days : 28 : Mon
# time to turn-on appliacne on 8 : 52 : 59 equal to 2131 items
# consuming the appliance 0 hours 44 minutes 39 seconds that equal to 2679 seconds or 178 items
#
# Days : 29 : Tue
# time to turn-on appliacne on 8 : 33 : 57 equal to 2055 items
# consuming the appliance 0 hours 52 minutes 17 seconds that equal to 3137 seconds or 209 items
#
# Days : 30 : Wed
# time to turn-on appliacne on 7 : 28 : 17 equal to 1793 items
# consuming the appliance 0 hours 37 minutes 58 seconds that equal to 2278 seconds or 151 items
#
# Days : 31 : Thu
# time to turn-on appliacne on 8 : 36 : 38 equal to 2066 items
# consuming the appliance 0 hours 59 minutes 44 seconds that equal to 3584 seconds or 238 items
# DONE!

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
# %matplotlib inline  

# query = "SELECT watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
query = "SELECT Timestamp,watt FROM data_month2.elec_thermos WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
df = pd.read_sql(query, conn, index_col=['Timestamp'])
fig, ax = plt.subplots()
ax.set_title('data_month2.elec_thermos')
df.plot(ax=ax )
plt.show()
