# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random

d = 31
time_a = pd.date_range('2016-11-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-11-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####### set databases to empty #########
query_empty = """truncate table data_month2.water_heater""" 
c.execute(query_empty)
print "data_month2.water_heater are Empty!!! \n"

query = "SELECT watt FROM collected_info.5_water_heater WHERE no >= '%s'   AND no <= '%s'; "% (0,1000)
df = pd.read_sql(query, conn)


#### Random the number of turnon-time per day
def manytime():
    many  = ['0'] * 50 + ['1'] * 30 + ['2'] * 20  ## The number of turn-on time of this appliance 
    manytime = random.choice(many)
    print "in recent day turn on water_heater",manytime,"times\n" 
    if (int(manytime) == 0):
        off_item = [0]
        return (off_item)
    
    elif (int(manytime) == 1):
        x,y,endx,endy = 20,23,1,59
        open_hour =  random.randint(x, y)
        open_min =  random.randint(0, 59)
        open_sec =  random.randint(0, 59)
        if 0 < open_sec  <= 15:
            k = 0
        elif 15 < open_sec  <= 30:
            k = 1
        elif 30 < open_sec  <= 45:
            k = 2
        else:
            k = 3
        off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
        print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
            
        duration_hour =  random.randint(0, 0)
        duration_min =  random.randint(endx, endy)
        duration_sec =  random.randint(0, 59)
        seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
        no_item = seconds/15
        print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n" 
        return (off_item,no_item)
              
    else :
        x,y,endx,endy = 7,10,1,59
        open_hour =  random.randint(x, y)
        open_min =  random.randint(0, 59)
        open_sec =  random.randint(0, 59)
        if 0 < open_sec  <= 15:
            k = 0
        elif 15 < open_sec  <= 30:
            k = 1
        elif 30 < open_sec  <= 45:
            k = 2
        else:
            k = 3
        off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
        print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
            
        duration_hour =  random.randint(0, 0)
        duration_min =  random.randint(endx, endy)
        duration_sec =  random.randint(0, 59)
        seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
        no_item = seconds/15
        print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"
            
        x1,y1,endx1,endy1 = 20,23,1,59
        open_hour1 =  random.randint(x1, y1)
        open_min1 =  random.randint(0, 59)
        open_sec1 =  random.randint(0, 59)
        if 0 < open_sec1  <= 15:
            k = 0
        elif 15 < open_sec1  <= 30:
            k = 1
        elif 30 < open_sec1  <= 45:
            k = 2
        else:
            k = 3
        off_item1 = (int(open_hour1)*240) + (int(open_min1)*4)+ k 
        print "time to turn-on appliacne on",open_hour1,":",open_min1,":",open_sec1,"equal to",off_item1,"items"   
            
        duration_hour1 =  random.randint(0, 0)
        duration_min1 =  random.randint(endx1, endy1)
        duration_sec1 =  random.randint(0, 59)
        seconds1 = (duration_hour1*3600)+(duration_min1*60)+duration_sec1
        no_item1 = seconds1/15
        print "consuming the appliance", duration_hour1,"hours",duration_min1,"minutes",duration_sec1,"seconds that equal to",seconds1,"seconds or",no_item1,"items\n"
        return (off_item,no_item,off_item1,no_item1)        
    
        
days = 1
j = 0    
i = 0
turn = manytime()

while (j <= (5760*d)-1):   
    if (j == 5760+(5760*(days-1))):
        days +=1
        i = 0
        print "-------------------------ENd-----------------------------\n"
        turn = manytime()       
           

    if len(turn) == 1 :
        c.execute("INSERT INTO data_month2.water_heater (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
        conn.commit()
        j += 1

    elif len(turn)== 2 :
        off_item = turn[0] 
        no_item = turn[1]
        if (off_item+(5760*(days-1)) <= j <= (no_item+off_item)+(5760*(days-1))):
            c.execute("INSERT INTO data_month2.water_heater (Timestamp, watt) VALUES (%s, %s)",(time_b[j],df.watt[i]))
            conn.commit()
            i += 1 
            j += 1
        else:
            c.execute("INSERT INTO data_month2.water_heater (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
            conn.commit()
            j += 1
            i = 0
              
    else:
        off_item = turn[0] 
        no_item = turn[1]
        off_item1 = turn[2] 
        no_item1 = turn[3]
        if (off_item+(5760*(days-1)) <= j <= (no_item+off_item)+(5760*(days-1)) or off_item1+(5760*(days-1)) <= j <= (no_item1+off_item1)+(5760*(days-1))):
            c.execute("INSERT INTO data_month2.water_heater(Timestamp, watt) VALUES (%s, %s)",(time_b[j],df.watt[i]))
            conn.commit()
            j += 1
            i += 1 
        else:
            c.execute("INSERT INTO data_month2.water_heater(Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
            conn.commit()
            j += 1     
            i = 0
            

print "DONE!"
# print df
# Out:
# data_month2.water_heater are Empty!!!
#
# in recent day turn on water_heater 1 times
#
# time to turn-on appliacne on 21 : 11 : 47 equal to 5087 items
# consuming the appliance 0 hours 11 minutes 30 seconds that equal to 690 seconds or 46 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 0 times
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 2 times
#
# time to turn-on appliacne on 9 : 23 : 6 equal to 2252 items
# consuming the appliance 0 hours 6 minutes 33 seconds that equal to 393 seconds or 26 items
#
# time to turn-on appliacne on 20 : 19 : 2 equal to 4876 items
# consuming the appliance 0 hours 23 minutes 17 seconds that equal to 1397 seconds or 93 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 0 times
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 0 times
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 0 times
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 2 times
#
# time to turn-on appliacne on 7 : 41 : 12 equal to 1844 items
# consuming the appliance 0 hours 27 minutes 7 seconds that equal to 1627 seconds or 108 items
#
# time to turn-on appliacne on 21 : 23 : 5 equal to 5132 items
# consuming the appliance 0 hours 7 minutes 55 seconds that equal to 475 seconds or 31 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 2 times
#
# time to turn-on appliacne on 7 : 53 : 45 equal to 1894 items
# consuming the appliance 0 hours 37 minutes 28 seconds that equal to 2248 seconds or 149 items
#
# time to turn-on appliacne on 22 : 16 : 2 equal to 5344 items
# consuming the appliance 0 hours 5 minutes 47 seconds that equal to 347 seconds or 23 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 2 times
#
# time to turn-on appliacne on 10 : 53 : 30 equal to 2613 items
# consuming the appliance 0 hours 52 minutes 55 seconds that equal to 3175 seconds or 211 items
#
# time to turn-on appliacne on 22 : 27 : 8 equal to 5388 items
# consuming the appliance 0 hours 40 minutes 15 seconds that equal to 2415 seconds or 161 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 2 times
#
# time to turn-on appliacne on 8 : 1 : 42 equal to 1926 items
# consuming the appliance 0 hours 57 minutes 20 seconds that equal to 3440 seconds or 229 items
#
# time to turn-on appliacne on 22 : 41 : 23 equal to 5445 items
# consuming the appliance 0 hours 26 minutes 58 seconds that equal to 1618 seconds or 107 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 0 times
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 0 times
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 2 times
#
# time to turn-on appliacne on 10 : 26 : 16 equal to 2505 items
# consuming the appliance 0 hours 49 minutes 7 seconds that equal to 2947 seconds or 196 items
#
# time to turn-on appliacne on 20 : 9 : 21 equal to 4837 items
# consuming the appliance 0 hours 16 minutes 57 seconds that equal to 1017 seconds or 67 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 1 times
#
# time to turn-on appliacne on 20 : 46 : 43 equal to 4986 items
# consuming the appliance 0 hours 51 minutes 5 seconds that equal to 3065 seconds or 204 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 1 times
#
# time to turn-on appliacne on 22 : 25 : 17 equal to 5381 items
# consuming the appliance 0 hours 44 minutes 0 seconds that equal to 2640 seconds or 176 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 0 times
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 1 times
#
# time to turn-on appliacne on 21 : 21 : 32 equal to 5126 items
# consuming the appliance 0 hours 34 minutes 59 seconds that equal to 2099 seconds or 139 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 0 times
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 2 times
#
# time to turn-on appliacne on 8 : 1 : 7 equal to 1924 items
# consuming the appliance 0 hours 23 minutes 31 seconds that equal to 1411 seconds or 94 items
#
# time to turn-on appliacne on 22 : 13 : 19 equal to 5333 items
# consuming the appliance 0 hours 59 minutes 44 seconds that equal to 3584 seconds or 238 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 0 times
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 2 times
#
# time to turn-on appliacne on 10 : 44 : 40 equal to 2578 items
# consuming the appliance 0 hours 37 minutes 16 seconds that equal to 2236 seconds or 149 items
#
# time to turn-on appliacne on 21 : 39 : 37 equal to 5198 items
# consuming the appliance 0 hours 31 minutes 28 seconds that equal to 1888 seconds or 125 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 2 times
#
# time to turn-on appliacne on 10 : 40 : 25 equal to 2561 items
# consuming the appliance 0 hours 32 minutes 45 seconds that equal to 1965 seconds or 131 items
#
# time to turn-on appliacne on 20 : 9 : 45 equal to 4838 items
# consuming the appliance 0 hours 51 minutes 24 seconds that equal to 3084 seconds or 205 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 0 times
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 1 times
#
# time to turn-on appliacne on 23 : 21 : 55 equal to 5607 items
# consuming the appliance 0 hours 26 minutes 5 seconds that equal to 1565 seconds or 104 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 0 times
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 0 times
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 0 times
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 1 times
#
# time to turn-on appliacne on 21 : 31 : 9 equal to 5164 items
# consuming the appliance 0 hours 47 minutes 35 seconds that equal to 2855 seconds or 190 items
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 0 times
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 0 times
#
# -------------------------ENd-----------------------------
#
# in recent day turn on water_heater 1 times
#
# time to turn-on appliacne on 22 : 56 : 16 equal to 5505 items
# consuming the appliance 0 hours 59 minutes 3 seconds that equal to 3543 seconds or 236 items
#
# DONE!

# %%
import matplotlib.pyplot as plt
# %matplotlib inline  


# query = "SELECT watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
query = "SELECT Timestamp,watt FROM data_month2.water_heater WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
df = pd.read_sql(query, conn, index_col=['Timestamp'])
fig, ax = plt.subplots()
ax.set_title('data_month2.water_heater')
df.plot(ax=ax )
plt.show()
df.to_csv('file.csv')
print len(df)
# Out:
# 178560
