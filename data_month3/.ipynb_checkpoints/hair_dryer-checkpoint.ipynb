# %% [markdown]
# ## data_month3
# #### Hair_dryer | ขนาด ??? |

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random


d = 31
time_a = pd.date_range('2016-12-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-12-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####### set databases to empty #########
query_empty = """truncate table data_month3.hair_dryer""" 
c.execute(query_empty)
print "data_month3.elec_thermos are Empty!!! \n"

query = "SELECT watt FROM collected_info.11_hair_dryer WHERE no >= '%s'   AND no <= '%s'; "% (0,1200)
df = pd.read_sql(query, conn)
# print df.watt[5]

#### Random the turning-on time appliances
def rand_turnon():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(0, 59)
    duration_hour1 = ['21'] * 40 + ['22'] *45 + ['23'] * 15
    duration_hour = random.choice(duration_hour1)     
    if 0 < duration_sec <= 15:
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
    off_item = (int(duration_hour)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on appliacne on",duration_hour,":",duration_min,":",duration_sec,"equal to",off_item,"items"
    return off_item

 
#### Random the off-duration appliances 
def rand_duration():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(30, 59)
    duration_hour1 = ['0'] * 50 + ['1'] * 1+ ['0'] * 49
    duration_hour = random.choice(duration_hour1)   
    seconds = (int(duration_hour)*3600)+(duration_min*60)+duration_sec
    no_item = seconds/15
    print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items"
    return no_item

days = 0
j = 0
i = 0
print "\nDays :",days ,":",time_b[j].strftime('%a')
off_item = rand_turnon()  
no_item = rand_duration()  

while (j <= (5760*d)-1):  
    c.execute("INSERT INTO data_month3.hair_dryer (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
    conn.commit()
    j += 1 
    
    while (off_item+(5760*(days)) <= j <= (no_item+off_item)+(5760*(days))):                   
        c.execute("INSERT INTO data_month3.hair_dryer (Timestamp, watt) VALUES (%s, %s)",(time_b[j],df.watt[i]))
        conn.commit()
        i += 1 
        j += 1
        if (j == (no_item+off_item)+(5760*(days))):
            days +=1
            print "\nDays :",days ,":",time_b[j].strftime('%a')
            off_item = rand_turnon()  
            no_item = rand_duration() 
            i= 0   

                    
print "DONE!"
# Out:
# data_month3.elec_thermos are Empty!!!
#
#
# Days : 0 : Thu
# time to turn-on appliacne on 21 : 24 : 54 equal to 5139 items
# consuming the appliance 0 hours 46 minutes 54 seconds that equal to 2814 seconds or 187 items
#
# Days : 1 : Thu
# time to turn-on appliacne on 22 : 37 : 7 equal to 5428 items
# consuming the appliance 0 hours 31 minutes 51 seconds that equal to 1911 seconds or 127 items
#
# Days : 2 : Fri
# time to turn-on appliacne on 22 : 11 : 46 equal to 5327 items
# consuming the appliance 0 hours 48 minutes 30 seconds that equal to 2910 seconds or 194 items
#
# Days : 3 : Sat
# time to turn-on appliacne on 22 : 22 : 50 equal to 5371 items
# consuming the appliance 0 hours 58 minutes 45 seconds that equal to 3525 seconds or 235 items
#
# Days : 4 : Sun
# time to turn-on appliacne on 21 : 21 : 47 equal to 5127 items
# consuming the appliance 0 hours 58 minutes 21 seconds that equal to 3501 seconds or 233 items
#
# Days : 5 : Mon
# time to turn-on appliacne on 21 : 34 : 11 equal to 5176 items
# consuming the appliance 0 hours 41 minutes 24 seconds that equal to 2484 seconds or 165 items
#
# Days : 6 : Tue
# time to turn-on appliacne on 22 : 45 : 36 equal to 5462 items
# consuming the appliance 0 hours 34 minutes 11 seconds that equal to 2051 seconds or 136 items
#
# Days : 7 : Wed
# time to turn-on appliacne on 21 : 35 : 55 equal to 5183 items
# consuming the appliance 0 hours 54 minutes 49 seconds that equal to 3289 seconds or 219 items
#
# Days : 8 : Thu
# time to turn-on appliacne on 22 : 53 : 11 equal to 5492 items
# consuming the appliance 0 hours 41 minutes 52 seconds that equal to 2512 seconds or 167 items
#
# Days : 9 : Fri
# time to turn-on appliacne on 22 : 1 : 30 equal to 5285 items
# consuming the appliance 0 hours 42 minutes 28 seconds that equal to 2548 seconds or 169 items
#
# Days : 10 : Sat
# time to turn-on appliacne on 22 : 41 : 58 equal to 5447 items
# consuming the appliance 0 hours 38 minutes 59 seconds that equal to 2339 seconds or 155 items
#
# Days : 11 : Sun
# time to turn-on appliacne on 21 : 53 : 11 equal to 5252 items
# consuming the appliance 0 hours 30 minutes 13 seconds that equal to 1813 seconds or 120 items
#
# Days : 12 : Mon
# time to turn-on appliacne on 22 : 53 : 57 equal to 5495 items
# consuming the appliance 0 hours 52 minutes 3 seconds that equal to 3123 seconds or 208 items
#
# Days : 13 : Tue
# time to turn-on appliacne on 22 : 28 : 7 equal to 5392 items
# consuming the appliance 0 hours 32 minutes 23 seconds that equal to 1943 seconds or 129 items
#
# Days : 14 : Wed
# time to turn-on appliacne on 23 : 25 : 21 equal to 5621 items
# consuming the appliance 0 hours 51 minutes 32 seconds that equal to 3092 seconds or 206 items
#
# Days : 15 : Fri
# time to turn-on appliacne on 21 : 27 : 4 equal to 5148 items
# consuming the appliance 0 hours 51 minutes 33 seconds that equal to 3093 seconds or 206 items
#
# Days : 16 : Fri
# time to turn-on appliacne on 22 : 8 : 20 equal to 5313 items
# consuming the appliance 0 hours 56 minutes 24 seconds that equal to 3384 seconds or 225 items
#
# Days : 17 : Sat
# time to turn-on appliacne on 21 : 47 : 39 equal to 5230 items
# consuming the appliance 0 hours 39 minutes 24 seconds that equal to 2364 seconds or 157 items
#
# Days : 18 : Sun
# time to turn-on appliacne on 21 : 17 : 0 equal to 5111 items
# consuming the appliance 0 hours 49 minutes 29 seconds that equal to 2969 seconds or 197 items
#
# Days : 19 : Mon
# time to turn-on appliacne on 22 : 27 : 5 equal to 5388 items
# consuming the appliance 0 hours 50 minutes 43 seconds that equal to 3043 seconds or 202 items
#
# Days : 20 : Tue
# time to turn-on appliacne on 22 : 20 : 58 equal to 5363 items
# consuming the appliance 0 hours 37 minutes 26 seconds that equal to 2246 seconds or 149 items
#
# Days : 21 : Wed
# time to turn-on appliacne on 21 : 18 : 23 equal to 5113 items
# consuming the appliance 0 hours 54 minutes 5 seconds that equal to 3245 seconds or 216 items
#
# Days : 22 : Thu
# time to turn-on appliacne on 21 : 7 : 55 equal to 5071 items
# consuming the appliance 0 hours 49 minutes 0 seconds that equal to 2940 seconds or 196 items
#
# Days : 23 : Fri
# time to turn-on appliacne on 23 : 45 : 27 equal to 5701 items
# consuming the appliance 0 hours 33 minutes 27 seconds that equal to 2007 seconds or 133 items
#
# Days : 24 : Sun
# time to turn-on appliacne on 22 : 55 : 30 equal to 5501 items
# consuming the appliance 0 hours 35 minutes 36 seconds that equal to 2136 seconds or 142 items
#
# Days : 25 : Sun
# time to turn-on appliacne on 21 : 40 : 47 equal to 5203 items
# consuming the appliance 0 hours 56 minutes 16 seconds that equal to 3376 seconds or 225 items
#
# Days : 26 : Mon
# time to turn-on appliacne on 21 : 4 : 39 equal to 5058 items
# consuming the appliance 0 hours 56 minutes 9 seconds that equal to 3369 seconds or 224 items
#
# Days : 27 : Tue
# time to turn-on appliacne on 22 : 8 : 51 equal to 5315 items
# consuming the appliance 0 hours 43 minutes 6 seconds that equal to 2586 seconds or 172 items
#
# Days : 28 : Wed
# time to turn-on appliacne on 21 : 2 : 27 equal to 5049 items
# consuming the appliance 0 hours 44 minutes 31 seconds that equal to 2671 seconds or 178 items
#
# Days : 29 : Thu
# time to turn-on appliacne on 23 : 31 : 26 equal to 5645 items
# consuming the appliance 0 hours 57 minutes 12 seconds that equal to 3432 seconds or 228 items
#
# Days : 30 : Sat
# time to turn-on appliacne on 22 : 4 : 50 equal to 5299 items
# consuming the appliance 0 hours 40 minutes 58 seconds that equal to 2458 seconds or 163 items
#
# Days : 31 : Sat
# time to turn-on appliacne on 22 : 34 : 54 equal to 5419 items
# consuming the appliance 0 hours 41 minutes 55 seconds that equal to 2515 seconds or 167 items
# DONE!

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
# %matplotlib inline  


# query = "SELECT watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
query = "SELECT Timestamp,watt FROM data_month3.hair_dryer WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[5000],time_b[5760*3])
df = pd.read_sql(query, conn, index_col=['Timestamp'])
fig, ax = plt.subplots()
ax.set_title('data_month3.hair_dryer')
df.plot(ax=ax )
plt.show()
