# %% [markdown]
# ## data_month2
# #### FAN | พัดลมตั้งพื้น 16 นิ้ว |

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random


d = 31

time_a = pd.date_range('2016-11-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-11-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####### set databases to empty #########
query_empty = """truncate table data_month2.fan""" 
c.execute(query_empty)
print "data_month2.fan are Empty!!! \n"

query = "SELECT watt FROM collected_info.2_fan WHERE no >= '%s'   AND no <= '%s'; "% (0,1016)
df = pd.read_sql(query, conn)
# print df.watt[5]

#### Random the number of turnon-time per day
def manytime():
    many  = ['1'] * 50 + ['2'] * 44 + ['3'] * 6  ## The number of turn-on time of this appliance 
    manytime = random.choice(many)
    print "\nDays :",days-1 ,":",time_b[j].strftime('%a')
    print "in recent day turn on fan",manytime,"times\n"
    if (int(manytime) == 1):
        x,y,endx,endy = 18,20,2,4  # fix turn on only in evening      
        open_hour =  random.randint(x, y)
        open_min =  random.randint(0, 59)
        open_sec =  random.randint(0, 59)
        if 0 < open_sec  <= 15:
            k = 0
        elif 15 < open_sec  <= 30:
            k = 1
        elif 30 < open_sec  <= 45:
            k = 2
        else:
            k = 3
        off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
        print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
        
        duration_hour =  random.randint(endx, endy)
        duration_min =  random.randint(0, 59)
        duration_sec =  random.randint(0, 59)
        seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
        no_item = seconds/15
        print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"
        return (off_item,no_item)

        
    elif (int(manytime) == 2):
        turn_duratrion  = ['1'] * 70 + ['2'] * 30       #### '1' turn-on morning and evening   OR  '2' turn-on 2 times in evening 
        howturn = random.choice(turn_duratrion)
#         print howturn
        if (int(howturn)== 1 ):
            x,y,endx,endy = 6,7,1,59
            open_hour =  random.randint(x, y)
            open_min =  random.randint(0, 59)
            open_sec =  random.randint(0, 59)
            if 0 < open_sec  <= 15:
                k = 0
            elif 15 < open_sec  <= 30:
                k = 1
            elif 30 < open_sec  <= 45:
                k = 2
            else:
                k = 3
            off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
            print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
            
            duration_hour =  random.randint(0, 0)
            duration_min =  random.randint(endx, endy)
            duration_sec =  random.randint(0, 59)
            seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
            no_item = seconds/15
            print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"

        
            
            x1,y1,endx1,endy1 = 18,20,2,4
            open_hour1 =  random.randint(x1, y1)
            open_min1 =  random.randint(0, 59)
            open_sec1 =  random.randint(0, 59)
            if 0 < open_sec1  <= 15:
                k = 0
            elif 15 < open_sec1  <= 30:
                k = 1
            elif 30 < open_sec1  <= 45:
                k = 2
            else:
                k = 3
            off_item1 = (int(open_hour1)*240) + (int(open_min1)*4)+ k 
            print "time to turn-on appliacne on",open_hour1,":",open_min1,":",open_sec1,"equal to",off_item1,"items"     
            
            duration_hour1 =  random.randint(endx1, endy1)
            duration_min1 =  random.randint(0, 59)
            duration_sec1 =  random.randint(0, 59)
            seconds1 = (duration_hour1*3600)+(duration_min1*60)+duration_sec1
            no_item1 = seconds1/15
            print "consuming the appliance", duration_hour1,"hours",duration_min1,"minutes",duration_sec1,"seconds that equal to",seconds1,"seconds or",no_item1,"items\n"

        else :
            x,y,endx,endy = 18,19,1,59
            open_hour =  random.randint(x, y)
            open_min =  random.randint(0, 59)
            open_sec =  random.randint(0, 59)
            if 0 < open_sec  <= 15:
                k = 0
            elif 15 < open_sec  <= 30:
                k = 1
            elif 30 < open_sec  <= 45:
                k = 2
            else:
                k = 3
            off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
            print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
            
            duration_hour =  random.randint(0, 0)
            duration_min =  random.randint(endx, endy)
            duration_sec =  random.randint(0, 59)
            seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
            no_item = seconds/15
            print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"

        
            x1,y1,endx1,endy1 = 20,22,1,4
            open_hour1 =  random.randint(x1, y1)
            open_min1 =  random.randint(0, 59)
            open_sec1 =  random.randint(0, 59)
            if 0 < open_sec1  <= 15:
                k = 0
            elif 15 < open_sec1  <= 30:
                k = 1
            elif 30 < open_sec1  <= 45:
                k = 2
            else:
                k = 3
            off_item1 = (int(open_hour1)*240) + (int(open_min1)*4)+ k 
            print "time to turn-on appliacne on",open_hour1,":",open_min1,":",open_sec1,"equal to",off_item1,"items"   
            
            duration_hour1 =  random.randint(endx1, endy1)
            duration_min1 =  random.randint(0, 59)
            duration_sec1 =  random.randint(0, 59)
            seconds1 = (duration_hour1*3600)+(duration_min1*60)+duration_sec1
            no_item1 = seconds1/15
            print "consuming the appliance", duration_hour1,"hours",duration_min1,"minutes",duration_sec1,"seconds that equal to",seconds1,"seconds or",no_item1,"items\n"

        return (off_item,no_item,off_item1,no_item1)        
    else:
        x,y,endx,endy = 6,7,30,60
        open_hour =  random.randint(x, y)
        open_min =  random.randint(0, 59)
        open_sec =  random.randint(0, 59)
        if 0 < open_sec  <= 15:
            k = 0
        elif 15 < open_sec  <= 30:
            k = 1
        elif 30 < open_sec  <= 45:
            k = 2
        else:
            k = 3
        off_item = (int(open_hour)*240) + (int(open_min)*4)+ k 
        print "time to turn-on appliacne on",open_hour,":",open_min,":",open_sec,"equal to",off_item,"items"
        
        duration_hour =  random.randint(0,0)
        duration_min =  random.randint(endx, endy)
        duration_sec =  random.randint(0, 59)
        seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
        no_item = seconds/15
        print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items\n"

    
    
        x1,y1,endx1,endy1 = 18,19,1,59
        open_hour1 =  random.randint(x1, y1)
        open_min1 =  random.randint(0, 59)
        open_sec1 =  random.randint(0, 59)
        if 0 < open_sec1  <= 15:
            k = 0
        elif 15 < open_sec1  <= 30:
            k = 1
        elif 30 < open_sec1  <= 45:
            k = 2
        else:
            k = 3
        off_item1 = (int(open_hour1)*240) + (int(open_min1)*4)+ k 
        print "time to turn-on appliacne on",open_hour1,":",open_min1,":",open_sec1,"equal to",off_item1,"items" 
        duration_hour1 =  random.randint(0, 0)
        duration_min1 =  random.randint(endx1, endy1)
        duration_sec1 =  random.randint(0, 59)
        seconds1 = (duration_hour1*3600)+(duration_min1*60)+duration_sec1
        no_item1 = seconds1/15
        print "consuming the appliance", duration_hour1,"hours",duration_min1,"minutes",duration_sec1,"seconds that equal to",seconds1,"seconds or",no_item1,"items\n"
    
    
        x2,y2,endx2,endy2 = 20,22,1,4
        open_hour2 =  random.randint(x2, y2)
        open_min2 =  random.randint(0, 59)
        open_sec2 =  random.randint(0, 59)
        if 0 < open_sec2  <= 15:
            k = 0
        elif 15 < open_sec2  <= 30:
            k = 1
        elif 30 < open_sec2  <= 45:
            k = 2
        else:
            k = 3
        off_item2 = (int(open_hour2)*240) + (int(open_min2)*4)+ k 
        print "time to turn-on appliacne on",open_hour2,":",open_min2,":",open_sec2,"equal to",off_item2,"items" 
        duration_hour2 =  random.randint(endx2, endy2)
        duration_min2 =  random.randint(0, 59)
        duration_sec2 =  random.randint(0, 59)
        seconds2 = (duration_hour2*3600)+(duration_min2*60)+duration_sec2
        no_item2 = seconds2/15
        print "consuming the appliance", duration_hour2,"hours",duration_min2,"minutes",duration_sec2,"seconds that equal to",seconds2,"seconds or",no_item2,"items\n"
        return (off_item,no_item,off_item1,no_item1,off_item2,no_item2)    
    
    
        
days = 1
j = 0

## (off_item,no_item,off_item1,no_item1,off_item2,no_item2)    

turn = manytime()
while (j <= (5760*d)-1):   
    if (j == 5760+(5760*(days-1))):
        days +=1
        print "-------------------------ENd-----------------------------\n"
        turn = manytime()          
        
    if len(turn)==2:
        off_item = turn[0] 
        no_item = turn[1]
        if (off_item+(5760*(days-1)) <= j <= (no_item+off_item)+(5760*(days-1))):
            c.execute("INSERT INTO data_month2.fan (Timestamp, watt) VALUES (%s, %s)",(time_b[j],random.randint(64, 68)))
            conn.commit()
            j += 1
        else:
            c.execute("INSERT INTO data_month2.fan (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
            conn.commit()
            j += 1
        
    elif len(turn)==4:
        off_item = turn[0] 
        no_item = turn[1]
        off_item1 = turn[2] 
        no_item1 = turn[3]
        if (off_item+(5760*(days-1)) <= j <= (no_item+off_item)+(5760*(days-1)) or off_item1+(5760*(days-1)) <= j <= (no_item1+off_item1)+(5760*(days-1))):
            c.execute("INSERT INTO data_month2.fan (Timestamp, watt) VALUES (%s, %s)",(time_b[j],random.randint(64, 68)))
            conn.commit()
            j += 1
        else:
            c.execute("INSERT INTO data_month2.fan (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
            conn.commit()
            j += 1
             
    else:
        off_item = turn[0] 
        no_item = turn[1]
        off_item1 = turn[2] 
        no_item1 = turn[3]
        off_item2 = turn[4] 
        no_item2 = turn[5]
        
        if (off_item+(5760*(days-1)) <= j <= (no_item+off_item)+(5760*(days-1)) or off_item1+(5760*(days-1)) <= j <= (no_item1+off_item1)+(5760*(days-1)) or off_item2+(5760*(days-1)) <= j <= (no_item2+off_item2)+(5760*(days-1)))  :
            c.execute("INSERT INTO data_month2.fan (Timestamp, watt) VALUES (%s, %s)",(time_b[j],random.randint(64, 68)))
            conn.commit()
            j += 1
        else:
            c.execute("INSERT INTO data_month2.fan (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
            conn.commit()
            j += 1
 
           
print "DONE!"
# Out:
# data_month2.fan are Empty!!!
#
#
# Days : 0 : Tue
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 19 : 25 : 20 equal to 4661 items
# consuming the appliance 3 hours 27 minutes 58 seconds that equal to 12478 seconds or 831 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 1 : Wed
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 18 : 3 : 4 equal to 4332 items
# consuming the appliance 2 hours 34 minutes 56 seconds that equal to 9296 seconds or 619 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 2 : Thu
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 19 : 11 : 21 equal to 4605 items
# consuming the appliance 2 hours 37 minutes 32 seconds that equal to 9452 seconds or 630 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 3 : Fri
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 18 : 29 : 20 equal to 4437 items
# consuming the appliance 4 hours 39 minutes 43 seconds that equal to 16783 seconds or 1118 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 4 : Sat
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 7 : 44 : 23 equal to 1857 items
# consuming the appliance 0 hours 5 minutes 52 seconds that equal to 352 seconds or 23 items
#
# time to turn-on appliacne on 20 : 7 : 7 equal to 4828 items
# consuming the appliance 2 hours 21 minutes 51 seconds that equal to 8511 seconds or 567 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 5 : Sun
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 6 : 4 : 33 equal to 1458 items
# consuming the appliance 0 hours 50 minutes 14 seconds that equal to 3014 seconds or 200 items
#
# time to turn-on appliacne on 20 : 41 : 17 equal to 4965 items
# consuming the appliance 2 hours 8 minutes 35 seconds that equal to 7715 seconds or 514 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 6 : Mon
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 7 : 1 : 41 equal to 1686 items
# consuming the appliance 0 hours 58 minutes 36 seconds that equal to 3516 seconds or 234 items
#
# time to turn-on appliacne on 19 : 59 : 24 equal to 4797 items
# consuming the appliance 3 hours 0 minutes 40 seconds that equal to 10840 seconds or 722 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 7 : Tue
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 18 : 10 : 55 equal to 4363 items
# consuming the appliance 2 hours 37 minutes 36 seconds that equal to 9456 seconds or 630 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 8 : Wed
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 7 : 23 : 44 equal to 1774 items
# consuming the appliance 0 hours 17 minutes 39 seconds that equal to 1059 seconds or 70 items
#
# time to turn-on appliacne on 18 : 28 : 55 equal to 4435 items
# consuming the appliance 2 hours 47 minutes 59 seconds that equal to 10079 seconds or 671 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 9 : Thu
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 20 : 20 : 6 equal to 4880 items
# consuming the appliance 3 hours 2 minutes 59 seconds that equal to 10979 seconds or 731 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 10 : Fri
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 18 : 55 : 11 equal to 4540 items
# consuming the appliance 0 hours 32 minutes 47 seconds that equal to 1967 seconds or 131 items
#
# time to turn-on appliacne on 22 : 24 : 37 equal to 5378 items
# consuming the appliance 1 hours 24 minutes 52 seconds that equal to 5092 seconds or 339 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 11 : Sat
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 7 : 20 : 53 equal to 1763 items
# consuming the appliance 0 hours 57 minutes 36 seconds that equal to 3456 seconds or 230 items
#
# time to turn-on appliacne on 18 : 4 : 2 equal to 4336 items
# consuming the appliance 2 hours 48 minutes 19 seconds that equal to 10099 seconds or 673 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 12 : Sun
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 7 : 4 : 41 equal to 1698 items
# consuming the appliance 0 hours 48 minutes 11 seconds that equal to 2891 seconds or 192 items
#
# time to turn-on appliacne on 20 : 29 : 45 equal to 4918 items
# consuming the appliance 4 hours 7 minutes 12 seconds that equal to 14832 seconds or 988 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 13 : Mon
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 18 : 15 : 31 equal to 4382 items
# consuming the appliance 4 hours 59 minutes 21 seconds that equal to 17961 seconds or 1197 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 14 : Tue
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 19 : 3 : 46 equal to 4575 items
# consuming the appliance 4 hours 51 minutes 0 seconds that equal to 17460 seconds or 1164 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 15 : Wed
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 7 : 29 : 43 equal to 1798 items
# consuming the appliance 0 hours 34 minutes 54 seconds that equal to 2094 seconds or 139 items
#
# time to turn-on appliacne on 19 : 50 : 4 equal to 4760 items
# consuming the appliance 4 hours 31 minutes 6 seconds that equal to 16266 seconds or 1084 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 16 : Thu
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 20 : 8 : 4 equal to 4832 items
# consuming the appliance 3 hours 50 minutes 51 seconds that equal to 13851 seconds or 923 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 17 : Fri
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 7 : 43 : 8 equal to 1852 items
# consuming the appliance 0 hours 4 minutes 8 seconds that equal to 248 seconds or 16 items
#
# time to turn-on appliacne on 18 : 41 : 11 equal to 4484 items
# consuming the appliance 4 hours 24 minutes 33 seconds that equal to 15873 seconds or 1058 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 18 : Sat
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 20 : 39 : 1 equal to 4956 items
# consuming the appliance 4 hours 46 minutes 2 seconds that equal to 17162 seconds or 1144 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 19 : Sun
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 6 : 38 : 14 equal to 1592 items
# consuming the appliance 0 hours 1 minutes 5 seconds that equal to 65 seconds or 4 items
#
# time to turn-on appliacne on 20 : 35 : 39 equal to 4942 items
# consuming the appliance 2 hours 3 minutes 47 seconds that equal to 7427 seconds or 495 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 20 : Mon
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 20 : 3 : 16 equal to 4813 items
# consuming the appliance 4 hours 56 minutes 33 seconds that equal to 17793 seconds or 1186 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 21 : Tue
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 7 : 11 : 18 equal to 1725 items
# consuming the appliance 0 hours 33 minutes 36 seconds that equal to 2016 seconds or 134 items
#
# time to turn-on appliacne on 18 : 56 : 26 equal to 4545 items
# consuming the appliance 4 hours 13 minutes 35 seconds that equal to 15215 seconds or 1014 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 22 : Wed
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 18 : 52 : 36 equal to 4530 items
# consuming the appliance 2 hours 54 minutes 5 seconds that equal to 10445 seconds or 696 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 23 : Thu
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 7 : 45 : 40 equal to 1862 items
# consuming the appliance 0 hours 20 minutes 19 seconds that equal to 1219 seconds or 81 items
#
# time to turn-on appliacne on 18 : 27 : 12 equal to 4428 items
# consuming the appliance 3 hours 49 minutes 43 seconds that equal to 13783 seconds or 918 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 24 : Fri
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 7 : 56 : 37 equal to 1906 items
# consuming the appliance 0 hours 41 minutes 29 seconds that equal to 2489 seconds or 165 items
#
# time to turn-on appliacne on 18 : 23 : 32 equal to 4414 items
# consuming the appliance 3 hours 31 minutes 51 seconds that equal to 12711 seconds or 847 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 25 : Sat
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 7 : 53 : 34 equal to 1894 items
# consuming the appliance 0 hours 26 minutes 49 seconds that equal to 1609 seconds or 107 items
#
# time to turn-on appliacne on 20 : 15 : 1 equal to 4860 items
# consuming the appliance 3 hours 6 minutes 4 seconds that equal to 11164 seconds or 744 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 26 : Sun
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 19 : 5 : 49 equal to 4583 items
# consuming the appliance 4 hours 4 minutes 0 seconds that equal to 14640 seconds or 976 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 27 : Mon
# in recent day turn on fan 2 times
#
# time to turn-on appliacne on 6 : 31 : 22 equal to 1565 items
# consuming the appliance 0 hours 5 minutes 23 seconds that equal to 323 seconds or 21 items
#
# time to turn-on appliacne on 18 : 44 : 1 equal to 4496 items
# consuming the appliance 3 hours 41 minutes 14 seconds that equal to 13274 seconds or 884 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 28 : Tue
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 18 : 1 : 17 equal to 4325 items
# consuming the appliance 2 hours 31 minutes 0 seconds that equal to 9060 seconds or 604 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 29 : Wed
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 19 : 54 : 28 equal to 4777 items
# consuming the appliance 4 hours 7 minutes 50 seconds that equal to 14870 seconds or 991 items
#
# -------------------------ENd-----------------------------
#
#
# Days : 30 : Thu
# in recent day turn on fan 1 times
#
# time to turn-on appliacne on 18 : 26 : 26 equal to 4425 items
# consuming the appliance 3 hours 54 minutes 37 seconds that equal to 14077 seconds or 938 items
#
# DONE!

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
# %matplotlib inline  


# query = "SELECT watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
query = "SELECT Timestamp,watt FROM data_month2.fan WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[5760*12])
df = pd.read_sql(query, conn, index_col=['Timestamp'])
fig, ax = plt.subplots()
ax.set_title('data_month2.fan')
df.plot(ax=ax )
plt.show()
