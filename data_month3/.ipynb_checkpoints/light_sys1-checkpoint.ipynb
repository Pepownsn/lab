# %% [markdown]
# ## data_month3
# #### ระบบหลอดไฟส่องสว่าง | LED 7 Watt |

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random



d =31
time_a = pd.date_range('2016-12-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-12-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####### set databases to empty #########
query_empty = """truncate table data_month3.light_sys1""" 
c.execute(query_empty)
print "data_month3.light_sys1 are Empty!!! \n"

query = "SELECT watt FROM collected_info.15_light_sys WHERE no >= '%s'   AND no <= '%s'; "% (0,1500)
df = pd.read_sql(query, conn)

## set no.of light = 2:ห้องน้ำ || 4:ห้องนอน || 2:ห้องครัว || 4 ห้องนั่งเล่น  


def bed():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(0, 59)
    random_bed =   ['20'] * 45 + ['21'] * 50  + ['22'] * 5  
    on_bed = random.choice(random_bed) 
    
    if 0 < duration_sec <= 15 :
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
        
    start_bed = (int(on_bed)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on lamp at bedroom on",on_bed,":",duration_min,":",duration_sec,"equal to", start_bed,"items"
           
    duration_hour1 = ['1'] * 5 + ['2'] * 15 + ['3'] * 42  + ['4'] * 38 
    duration_hour = int(random.choice(duration_hour1))    
    duration_min =  random.randint(0, 59)
    duration_sec =  random.randint(0, 59)
    seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
    no_item_bed = seconds/15
    print "consuming the lamp", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item_bed,"items\n"
    return (start_bed,no_item_bed)

def living():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(0, 59)
    random_living = ['17'] * 25 + ['18'] * 55 + ['19'] * 20
    on_living = random.choice(random_living)   
                    
    if 0 < duration_sec <= 15:
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
    start_living = (int(on_living)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on lamp at living-room on",on_living,":",duration_min,":",duration_sec,"equal to", start_living,"items"
           
    duration_hour1 =  ['2'] * 5 + ['3'] * 65 + ['4'] *25 + ['5'] * 5
    duration_hour = int(random.choice(duration_hour1))        
    duration_min =  random.randint(0, 59)
    duration_sec =  random.randint(0, 59)
    seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
    no_item_living = seconds/15
    print "consuming the lamp", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item_living,"items\n"
    return (start_living,no_item_living)

def kitchen():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(0, 59)
    random_kitc = ['17'] * 60 + ['18'] * 25 + ['19'] * 10  + ['20'] * 5  
    on_kitc = random.choice(random_kitc)     
    
    if 0 < duration_sec <= 15:
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
    start_kitc = (int(on_kitc)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on lamp at kitchen on",on_kitc,":",duration_min,":",duration_sec,"equal to", start_kitc,"items"
           
    duration_hour1 = ['1'] * 60 + ['2'] * 40
    duration_hour = int(random.choice(duration_hour1))      
    duration_min =  random.randint(0, 59)
    duration_sec =  random.randint(0, 59)
    seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
    no_item_kitc= seconds/15
    print "consuming the lamp", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item_kitc,"items\n"
    return (start_kitc,no_item_kitc)


j = 0
days = 0

while (j <= (5760*d)-1): 
            
    if (j%5760 == 0):
        print "\nDays :",days ,":",time_b[j].strftime('%a')
        days +=1        
        turn_bed = bed()
        turn_living = living()
        turn_kitchen = kitchen()
    
    if int(turn_bed[0])+(5760*(days-1) )<= j <= (int(turn_bed[0])+int(turn_bed[1]))+(5760*(days-1) )and int(turn_kitchen[0])+(5760*(days-1)) <= j <= (int(turn_kitchen[0])+int(turn_kitchen[1]))+(5760*(days-1))and int(turn_living[0])+(5760*(days-1)) <= j <= (int(turn_living[0])+int(turn_living[1]))+(5760*(days-1)):
        c.execute("INSERT INTO data_month3.light_sys1 (Timestamp, watt_bed,watt_living, watt_kitc) VALUES (%s, %s, %s, %s)",(time_b[j],4,4,2))
        
    elif  int(turn_bed[0])+(5760*(days-1)) <= j <= (int(turn_bed[0])+int(turn_bed[1]))+(5760*(days-1)) and int(turn_living[0])+(5760*(days-1)) <= j <= (int(turn_living[0])+int(turn_living[1]))+(5760*(days-1)):
        c.execute("INSERT INTO data_month3.light_sys1 (Timestamp, watt_bed,watt_living, watt_kitc) VALUES (%s, %s, %s, %s)",(time_b[j],4,4,0))      
        
    elif  int(turn_kitchen[0])+(5760*(days-1)) <= j <= (int(turn_kitchen[0])+int(turn_kitchen[1]))+(5760*(days-1)) and int(turn_living[0])+(5760*(days-1)) <= j <= (int(turn_living[0])+int(turn_living[1]))+(5760*(days-1)):
        c.execute("INSERT INTO data_month3.light_sys1 (Timestamp, watt_bed,watt_living, watt_kitc) VALUES (%s, %s, %s, %s)",(time_b[j],0,4,2))
        
    elif  int(turn_bed[0])+(5760*(days-1)) <= j <=(int(turn_bed[0])+int(turn_bed[1]))+(5760*(days-1)) and int(turn_kitchen[0])+(5760*(days-1)) <= j <= (int(turn_kitchen[0])+int(turn_kitchen[1]))+(5760*(days-1)):
        c.execute("INSERT INTO data_month3.light_sys1(Timestamp, watt_bed,watt_living, watt_kitc) VALUES (%s, %s, %s, %s)",(time_b[j],4,0,2))
      
    elif  int(turn_bed[0])+(5760*(days-1)) <= j <= (int(turn_bed[0])+int(turn_bed[1]))+(5760*(days-1)):
        c.execute("INSERT INTO data_month3.light_sys1 (Timestamp, watt_bed,watt_living, watt_kitc) VALUES (%s, %s, %s, %s)",(time_b[j],4,0,0))
        
    elif int(turn_living[0])+(5760*(days-1) )<= j <= (int(turn_living[0])+int(turn_living[1]))+(5760*(days-1)):
        c.execute("INSERT INTO data_month3.light_sys1 (Timestamp, watt_bed,watt_living, watt_kitc) VALUES (%s, %s, %s, %s)",(time_b[j],0,4,0))
        
    elif int(turn_kitchen[0]) +(5760*(days-1))<= j <= (int(turn_kitchen[0])+int(turn_kitchen[1]))+(5760*(days-1)):
        c.execute("INSERT INTO data_month3.light_sys1 (Timestamp, watt_bed,watt_living, watt_kitc) VALUES (%s, %s, %s, %s)",(time_b[j],0,0,2))
    else:
        c.execute("INSERT INTO data_month3.light_sys1 (Timestamp, watt_bed,watt_living, watt_kitc) VALUES (%s, %s, %s, %s)",(time_b[j],0,0,0))
            
    j += 1
    conn.commit()
    

print "DONE!"
# Out:
# data_month3.light_sys1 are Empty!!!
#
#
# Days : 0 : Thu
# time to turn-on lamp at bedroom on 21 : 24 : 17 equal to 5137 items
# consuming the lamp 1 hours 19 minutes 53 seconds that equal to 4793 seconds or 319 items
#
# time to turn-on lamp at living-room on 18 : 2 : 5 equal to 4328 items
# consuming the lamp 5 hours 43 minutes 8 seconds that equal to 20588 seconds or 1372 items
#
# time to turn-on lamp at kitchen on 17 : 10 : 27 equal to 4121 items
# consuming the lamp 1 hours 10 minutes 6 seconds that equal to 4206 seconds or 280 items
#
#
# Days : 1 : Fri
# time to turn-on lamp at bedroom on 21 : 27 : 4 equal to 5148 items
# consuming the lamp 4 hours 40 minutes 9 seconds that equal to 16809 seconds or 1120 items
#
# time to turn-on lamp at living-room on 17 : 7 : 28 equal to 4109 items
# consuming the lamp 3 hours 33 minutes 37 seconds that equal to 12817 seconds or 854 items
#
# time to turn-on lamp at kitchen on 20 : 19 : 46 equal to 4879 items
# consuming the lamp 1 hours 2 minutes 13 seconds that equal to 3733 seconds or 248 items
#
#
# Days : 2 : Sat
# time to turn-on lamp at bedroom on 22 : 30 : 5 equal to 5400 items
# consuming the lamp 4 hours 8 minutes 56 seconds that equal to 14936 seconds or 995 items
#
# time to turn-on lamp at living-room on 18 : 56 : 5 equal to 4544 items
# consuming the lamp 3 hours 0 minutes 37 seconds that equal to 10837 seconds or 722 items
#
# time to turn-on lamp at kitchen on 18 : 48 : 40 equal to 4514 items
# consuming the lamp 2 hours 12 minutes 2 seconds that equal to 7922 seconds or 528 items
#
#
# Days : 3 : Sun
# time to turn-on lamp at bedroom on 21 : 52 : 43 equal to 5250 items
# consuming the lamp 4 hours 4 minutes 39 seconds that equal to 14679 seconds or 978 items
#
# time to turn-on lamp at living-room on 17 : 54 : 7 equal to 4296 items
# consuming the lamp 4 hours 46 minutes 50 seconds that equal to 17210 seconds or 1147 items
#
# time to turn-on lamp at kitchen on 17 : 38 : 49 equal to 4235 items
# consuming the lamp 1 hours 56 minutes 25 seconds that equal to 6985 seconds or 465 items
#
#
# Days : 4 : Mon
# time to turn-on lamp at bedroom on 20 : 23 : 4 equal to 4892 items
# consuming the lamp 4 hours 56 minutes 41 seconds that equal to 17801 seconds or 1186 items
#
# time to turn-on lamp at living-room on 19 : 5 : 45 equal to 4582 items
# consuming the lamp 3 hours 16 minutes 32 seconds that equal to 11792 seconds or 786 items
#
# time to turn-on lamp at kitchen on 18 : 59 : 7 equal to 4556 items
# consuming the lamp 1 hours 31 minutes 25 seconds that equal to 5485 seconds or 365 items
#
#
# Days : 5 : Tue
# time to turn-on lamp at bedroom on 21 : 22 : 36 equal to 5130 items
# consuming the lamp 4 hours 50 minutes 52 seconds that equal to 17452 seconds or 1163 items
#
# time to turn-on lamp at living-room on 19 : 25 : 44 equal to 4662 items
# consuming the lamp 4 hours 22 minutes 31 seconds that equal to 15751 seconds or 1050 items
#
# time to turn-on lamp at kitchen on 17 : 0 : 51 equal to 4083 items
# consuming the lamp 1 hours 49 minutes 48 seconds that equal to 6588 seconds or 439 items
#
#
# Days : 6 : Wed
# time to turn-on lamp at bedroom on 21 : 42 : 31 equal to 5210 items
# consuming the lamp 4 hours 36 minutes 22 seconds that equal to 16582 seconds or 1105 items
#
# time to turn-on lamp at living-room on 18 : 38 : 26 equal to 4473 items
# consuming the lamp 3 hours 39 minutes 6 seconds that equal to 13146 seconds or 876 items
#
# time to turn-on lamp at kitchen on 18 : 27 : 48 equal to 4431 items
# consuming the lamp 1 hours 51 minutes 27 seconds that equal to 6687 seconds or 445 items
#
#
# Days : 7 : Thu
# time to turn-on lamp at bedroom on 21 : 59 : 43 equal to 5278 items
# consuming the lamp 2 hours 23 minutes 1 seconds that equal to 8581 seconds or 572 items
#
# time to turn-on lamp at living-room on 17 : 26 : 55 equal to 4187 items
# consuming the lamp 3 hours 58 minutes 41 seconds that equal to 14321 seconds or 954 items
#
# time to turn-on lamp at kitchen on 17 : 8 : 14 equal to 4112 items
# consuming the lamp 2 hours 44 minutes 29 seconds that equal to 9869 seconds or 657 items
#
#
# Days : 8 : Fri
# time to turn-on lamp at bedroom on 21 : 5 : 43 equal to 5062 items
# consuming the lamp 3 hours 43 minutes 52 seconds that equal to 13432 seconds or 895 items
#
# time to turn-on lamp at living-room on 18 : 22 : 35 equal to 4410 items
# consuming the lamp 3 hours 15 minutes 39 seconds that equal to 11739 seconds or 782 items
#
# time to turn-on lamp at kitchen on 18 : 59 : 59 equal to 4559 items
# consuming the lamp 2 hours 32 minutes 58 seconds that equal to 9178 seconds or 611 items
#
#
# Days : 9 : Sat
# time to turn-on lamp at bedroom on 20 : 58 : 56 equal to 5035 items
# consuming the lamp 3 hours 49 minutes 15 seconds that equal to 13755 seconds or 917 items
#
# time to turn-on lamp at living-room on 17 : 28 : 57 equal to 4195 items
# consuming the lamp 4 hours 20 minutes 55 seconds that equal to 15655 seconds or 1043 items
#
# time to turn-on lamp at kitchen on 17 : 50 : 21 equal to 4281 items
# consuming the lamp 1 hours 48 minutes 4 seconds that equal to 6484 seconds or 432 items
#
#
# Days : 10 : Sun
# time to turn-on lamp at bedroom on 21 : 16 : 46 equal to 5107 items
# consuming the lamp 3 hours 37 minutes 47 seconds that equal to 13067 seconds or 871 items
#
# time to turn-on lamp at living-room on 18 : 42 : 14 equal to 4488 items
# consuming the lamp 3 hours 21 minutes 45 seconds that equal to 12105 seconds or 807 items
#
# time to turn-on lamp at kitchen on 17 : 7 : 46 equal to 4111 items
# consuming the lamp 1 hours 0 minutes 19 seconds that equal to 3619 seconds or 241 items
#
#
# Days : 11 : Mon
# time to turn-on lamp at bedroom on 22 : 16 : 29 equal to 5345 items
# consuming the lamp 2 hours 58 minutes 9 seconds that equal to 10689 seconds or 712 items
#
# time to turn-on lamp at living-room on 18 : 34 : 56 equal to 4459 items
# consuming the lamp 3 hours 11 minutes 6 seconds that equal to 11466 seconds or 764 items
#
# time to turn-on lamp at kitchen on 17 : 34 : 2 equal to 4216 items
# consuming the lamp 1 hours 7 minutes 36 seconds that equal to 4056 seconds or 270 items
#
#
# Days : 12 : Tue
# time to turn-on lamp at bedroom on 20 : 14 : 9 equal to 4856 items
# consuming the lamp 3 hours 43 minutes 25 seconds that equal to 13405 seconds or 893 items
#
# time to turn-on lamp at living-room on 19 : 27 : 24 equal to 4669 items
# consuming the lamp 3 hours 9 minutes 10 seconds that equal to 11350 seconds or 756 items
#
# time to turn-on lamp at kitchen on 17 : 57 : 13 equal to 4308 items
# consuming the lamp 1 hours 3 minutes 1 seconds that equal to 3781 seconds or 252 items
#
#
# Days : 13 : Wed
# time to turn-on lamp at bedroom on 21 : 47 : 34 equal to 5230 items
# consuming the lamp 3 hours 9 minutes 26 seconds that equal to 11366 seconds or 757 items
#
# time to turn-on lamp at living-room on 18 : 33 : 51 equal to 4455 items
# consuming the lamp 3 hours 38 minutes 19 seconds that equal to 13099 seconds or 873 items
#
# time to turn-on lamp at kitchen on 20 : 12 : 30 equal to 4849 items
# consuming the lamp 1 hours 14 minutes 44 seconds that equal to 4484 seconds or 298 items
#
#
# Days : 14 : Thu
# time to turn-on lamp at bedroom on 20 : 22 : 5 equal to 4888 items
# consuming the lamp 3 hours 34 minutes 34 seconds that equal to 12874 seconds or 858 items
#
# time to turn-on lamp at living-room on 18 : 39 : 5 equal to 4476 items
# consuming the lamp 3 hours 31 minutes 46 seconds that equal to 12706 seconds or 847 items
#
# time to turn-on lamp at kitchen on 18 : 42 : 51 equal to 4491 items
# consuming the lamp 2 hours 10 minutes 17 seconds that equal to 7817 seconds or 521 items
#
#
# Days : 15 : Fri
# time to turn-on lamp at bedroom on 21 : 20 : 50 equal to 5123 items
# consuming the lamp 3 hours 58 minutes 26 seconds that equal to 14306 seconds or 953 items
#
# time to turn-on lamp at living-room on 17 : 44 : 22 equal to 4257 items
# consuming the lamp 3 hours 9 minutes 32 seconds that equal to 11372 seconds or 758 items
#
# time to turn-on lamp at kitchen on 17 : 25 : 8 equal to 4180 items
# consuming the lamp 1 hours 50 minutes 38 seconds that equal to 6638 seconds or 442 items
#
#
# Days : 16 : Sat
# time to turn-on lamp at bedroom on 20 : 47 : 7 equal to 4988 items
# consuming the lamp 4 hours 14 minutes 5 seconds that equal to 15245 seconds or 1016 items
#
# time to turn-on lamp at living-room on 18 : 42 : 50 equal to 4491 items
# consuming the lamp 3 hours 58 minutes 43 seconds that equal to 14323 seconds or 954 items
#
# time to turn-on lamp at kitchen on 17 : 55 : 32 equal to 4302 items
# consuming the lamp 1 hours 5 minutes 6 seconds that equal to 3906 seconds or 260 items
#
#
# Days : 17 : Sun
# time to turn-on lamp at bedroom on 20 : 15 : 27 equal to 4861 items
# consuming the lamp 3 hours 56 minutes 20 seconds that equal to 14180 seconds or 945 items
#
# time to turn-on lamp at living-room on 18 : 32 : 47 equal to 4451 items
# consuming the lamp 3 hours 31 minutes 58 seconds that equal to 12718 seconds or 847 items
#
# time to turn-on lamp at kitchen on 17 : 3 : 56 equal to 4095 items
# consuming the lamp 1 hours 29 minutes 2 seconds that equal to 5342 seconds or 356 items
#
#
# Days : 18 : Mon
# time to turn-on lamp at bedroom on 21 : 56 : 29 equal to 5265 items
# consuming the lamp 4 hours 21 minutes 23 seconds that equal to 15683 seconds or 1045 items
#
# time to turn-on lamp at living-room on 18 : 34 : 38 equal to 4458 items
# consuming the lamp 4 hours 49 minutes 44 seconds that equal to 17384 seconds or 1158 items
#
# time to turn-on lamp at kitchen on 17 : 27 : 0 equal to 4191 items
# consuming the lamp 1 hours 51 minutes 55 seconds that equal to 6715 seconds or 447 items
#
#
# Days : 19 : Tue
# time to turn-on lamp at bedroom on 21 : 33 : 42 equal to 5174 items
# consuming the lamp 4 hours 38 minutes 22 seconds that equal to 16702 seconds or 1113 items
#
# time to turn-on lamp at living-room on 18 : 2 : 10 equal to 4328 items
# consuming the lamp 4 hours 59 minutes 44 seconds that equal to 17984 seconds or 1198 items
#
# time to turn-on lamp at kitchen on 20 : 11 : 56 equal to 4847 items
# consuming the lamp 1 hours 55 minutes 0 seconds that equal to 6900 seconds or 460 items
#
#
# Days : 20 : Wed
# time to turn-on lamp at bedroom on 21 : 42 : 8 equal to 5208 items
# consuming the lamp 4 hours 56 minutes 28 seconds that equal to 17788 seconds or 1185 items
#
# time to turn-on lamp at living-room on 19 : 27 : 41 equal to 4670 items
# consuming the lamp 3 hours 36 minutes 36 seconds that equal to 12996 seconds or 866 items
#
# time to turn-on lamp at kitchen on 17 : 12 : 35 equal to 4130 items
# consuming the lamp 2 hours 37 minutes 48 seconds that equal to 9468 seconds or 631 items
#
#
# Days : 21 : Thu
# time to turn-on lamp at bedroom on 20 : 32 : 38 equal to 4930 items
# consuming the lamp 4 hours 21 minutes 59 seconds that equal to 15719 seconds or 1047 items
#
# time to turn-on lamp at living-room on 17 : 34 : 48 equal to 4219 items
# consuming the lamp 3 hours 42 minutes 30 seconds that equal to 13350 seconds or 890 items
#
# time to turn-on lamp at kitchen on 17 : 26 : 13 equal to 4184 items
# consuming the lamp 1 hours 19 minutes 21 seconds that equal to 4761 seconds or 317 items
#
#
# Days : 22 : Fri
# time to turn-on lamp at bedroom on 20 : 28 : 21 equal to 4913 items
# consuming the lamp 3 hours 25 minutes 3 seconds that equal to 12303 seconds or 820 items
#
# time to turn-on lamp at living-room on 18 : 28 : 6 equal to 4432 items
# consuming the lamp 3 hours 7 minutes 52 seconds that equal to 11272 seconds or 751 items
#
# time to turn-on lamp at kitchen on 17 : 4 : 38 equal to 4098 items
# consuming the lamp 1 hours 58 minutes 37 seconds that equal to 7117 seconds or 474 items
#
#
# Days : 23 : Sat
# time to turn-on lamp at bedroom on 21 : 57 : 47 equal to 5271 items
# consuming the lamp 2 hours 17 minutes 26 seconds that equal to 8246 seconds or 549 items
#
# time to turn-on lamp at living-room on 18 : 15 : 25 equal to 4381 items
# consuming the lamp 3 hours 23 minutes 43 seconds that equal to 12223 seconds or 814 items
#
# time to turn-on lamp at kitchen on 17 : 3 : 7 equal to 4092 items
# consuming the lamp 2 hours 11 minutes 45 seconds that equal to 7905 seconds or 527 items
#
#
# Days : 24 : Sun
# time to turn-on lamp at bedroom on 20 : 14 : 30 equal to 4857 items
# consuming the lamp 4 hours 46 minutes 59 seconds that equal to 17219 seconds or 1147 items
#
# time to turn-on lamp at living-room on 18 : 27 : 3 equal to 4428 items
# consuming the lamp 3 hours 0 minutes 34 seconds that equal to 10834 seconds or 722 items
#
# time to turn-on lamp at kitchen on 17 : 17 : 40 equal to 4150 items
# consuming the lamp 2 hours 48 minutes 53 seconds that equal to 10133 seconds or 675 items
#
#
# Days : 25 : Mon
# time to turn-on lamp at bedroom on 21 : 41 : 0 equal to 5207 items
# consuming the lamp 4 hours 23 minutes 16 seconds that equal to 15796 seconds or 1053 items
#
# time to turn-on lamp at living-room on 19 : 35 : 49 equal to 4703 items
# consuming the lamp 3 hours 6 minutes 21 seconds that equal to 11181 seconds or 745 items
#
# time to turn-on lamp at kitchen on 18 : 31 : 43 equal to 4446 items
# consuming the lamp 1 hours 0 minutes 47 seconds that equal to 3647 seconds or 243 items
#
#
# Days : 26 : Tue
# time to turn-on lamp at bedroom on 21 : 32 : 25 equal to 5169 items
# consuming the lamp 3 hours 49 minutes 50 seconds that equal to 13790 seconds or 919 items
#
# time to turn-on lamp at living-room on 17 : 46 : 34 equal to 4266 items
# consuming the lamp 3 hours 34 minutes 59 seconds that equal to 12899 seconds or 859 items
#
# time to turn-on lamp at kitchen on 17 : 56 : 56 equal to 4307 items
# consuming the lamp 1 hours 47 minutes 48 seconds that equal to 6468 seconds or 431 items
#
#
# Days : 27 : Wed
# time to turn-on lamp at bedroom on 21 : 37 : 54 equal to 5191 items
# consuming the lamp 4 hours 53 minutes 29 seconds that equal to 17609 seconds or 1173 items
#
# time to turn-on lamp at living-room on 19 : 36 : 39 equal to 4706 items
# consuming the lamp 3 hours 4 minutes 42 seconds that equal to 11082 seconds or 738 items
#
# time to turn-on lamp at kitchen on 17 : 1 : 31 equal to 4086 items
# consuming the lamp 2 hours 16 minutes 7 seconds that equal to 8167 seconds or 544 items
#
#
# Days : 28 : Thu
# time to turn-on lamp at bedroom on 21 : 49 : 5 equal to 5236 items
# consuming the lamp 4 hours 12 minutes 48 seconds that equal to 15168 seconds or 1011 items
#
# time to turn-on lamp at living-room on 19 : 50 : 44 equal to 4762 items
# consuming the lamp 5 hours 2 minutes 50 seconds that equal to 18170 seconds or 1211 items
#
# time to turn-on lamp at kitchen on 17 : 1 : 38 equal to 4086 items
# consuming the lamp 1 hours 20 minutes 0 seconds that equal to 4800 seconds or 320 items
#
#
# Days : 29 : Fri
# time to turn-on lamp at bedroom on 20 : 32 : 5 equal to 4928 items
# consuming the lamp 4 hours 42 minutes 3 seconds that equal to 16923 seconds or 1128 items
#
# time to turn-on lamp at living-room on 18 : 3 : 41 equal to 4334 items
# consuming the lamp 3 hours 35 minutes 27 seconds that equal to 12927 seconds or 861 items
#
# time to turn-on lamp at kitchen on 17 : 5 : 36 equal to 4102 items
# consuming the lamp 2 hours 13 minutes 44 seconds that equal to 8024 seconds or 534 items
#
#
# Days : 30 : Sat
# time to turn-on lamp at bedroom on 21 : 41 : 56 equal to 5207 items
# consuming the lamp 3 hours 51 minutes 23 seconds that equal to 13883 seconds or 925 items
#
# time to turn-on lamp at living-room on 17 : 14 : 17 equal to 4137 items
# consuming the lamp 4 hours 49 minutes 47 seconds that equal to 17387 seconds or 1159 items
#
# time to turn-on lamp at kitchen on 17 : 37 : 16 equal to 4229 items
# consuming the lamp 1 hours 54 minutes 33 seconds that equal to 6873 seconds or 458 items
#
# DONE!

# %%
import matplotlib.pyplot as plt
# %matplotlib inline  


# query = "SELECT watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
query = "SELECT * FROM data_month3.light_sys1 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[4000],time_b[6500])
df = pd.read_sql(query, conn, index_col=['Timestamp'])
fig, ax = plt.subplots()
ax.set_title('data_month3.IRON')
df.plot(ax=ax )
plt.show()
df.to_csv('file.csv')
