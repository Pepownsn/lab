# %% [markdown]
# ## data_month2
# #### ระบบหลอดไฟส่องสว่าง | LED 7 Watt |

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random



d =31
time_a = pd.date_range('2016-11-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-11-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####### set databases to empty #########
query_empty = """truncate table data_month2.light_sys1""" 
c.execute(query_empty)
print "data_month2.light_sys1 are Empty!!! \n"

query = "SELECT watt FROM collected_info.15_light_sys WHERE no >= '%s'   AND no <= '%s'; "% (0,1500)
df = pd.read_sql(query, conn)

## set no.of light = 2:ห้องน้ำ || 4:ห้องนอน || 2:ห้องครัว || 4 ห้องนั่งเล่น  


def bed():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(0, 59)
    random_bed =   ['20'] * 45 + ['21'] * 50  + ['22'] * 5  
    on_bed = random.choice(random_bed) 
    
    if 0 < duration_sec <= 15 :
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
        
    start_bed = (int(on_bed)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on lamp at bedroom on",on_bed,":",duration_min,":",duration_sec,"equal to", start_bed,"items"
           
    duration_hour1 = ['1'] * 5 + ['2'] * 15 + ['3'] * 42  + ['4'] * 38 
    duration_hour = int(random.choice(duration_hour1))    
    duration_min =  random.randint(0, 59)
    duration_sec =  random.randint(0, 59)
    seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
    no_item_bed = seconds/15
    print "consuming the lamp", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item_bed,"items\n"
    return (start_bed,no_item_bed)

def living():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(0, 59)
    random_living = ['17'] * 25 + ['18'] * 55 + ['19'] * 20
    on_living = random.choice(random_living)   
                    
    if 0 < duration_sec <= 15:
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
    start_living = (int(on_living)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on lamp at living-room on",on_living,":",duration_min,":",duration_sec,"equal to", start_living,"items"
           
    duration_hour1 =  ['2'] * 5 + ['3'] * 65 + ['4'] *25 + ['5'] * 5
    duration_hour = int(random.choice(duration_hour1))        
    duration_min =  random.randint(0, 59)
    duration_sec =  random.randint(0, 59)
    seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
    no_item_living = seconds/15
    print "consuming the lamp", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item_living,"items\n"
    return (start_living,no_item_living)

def kitchen():
    duration_sec =  random.randint(0, 59)
    duration_min =  random.randint(0, 59)
    random_kitc = ['17'] * 60 + ['18'] * 25 + ['19'] * 10  + ['20'] * 5  
    on_kitc = random.choice(random_kitc)     
    
    if 0 < duration_sec <= 15:
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
    start_kitc = (int(on_kitc)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on lamp at kitchen on",on_kitc,":",duration_min,":",duration_sec,"equal to", start_kitc,"items"
           
    duration_hour1 = ['1'] * 60 + ['2'] * 40
    duration_hour = int(random.choice(duration_hour1))      
    duration_min =  random.randint(0, 59)
    duration_sec =  random.randint(0, 59)
    seconds = (duration_hour*3600)+(duration_min*60)+duration_sec
    no_item_kitc= seconds/15
    print "consuming the lamp", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item_kitc,"items\n"
    return (start_kitc,no_item_kitc)


j = 0
days = 0

while (j <= (5760*d)-1): 
            
    if (j%5760 == 0):
        print "\nDays :",days ,":",time_b[j].strftime('%a')
        days +=1        
        turn_bed = bed()
        turn_living = living()
        turn_kitchen = kitchen()
    
    if int(turn_bed[0])+(5760*(days-1) )<= j <= (int(turn_bed[0])+int(turn_bed[1]))+(5760*(days-1) )and int(turn_kitchen[0])+(5760*(days-1)) <= j <= (int(turn_kitchen[0])+int(turn_kitchen[1]))+(5760*(days-1))and int(turn_living[0])+(5760*(days-1)) <= j <= (int(turn_living[0])+int(turn_living[1]))+(5760*(days-1)):
        c.execute("INSERT INTO data_month2.light_sys1 (Timestamp, watt_bed,watt_living, watt_kitc) VALUES (%s, %s, %s, %s)",(time_b[j],4,4,2))
        
    elif  int(turn_bed[0])+(5760*(days-1)) <= j <= (int(turn_bed[0])+int(turn_bed[1]))+(5760*(days-1)) and int(turn_living[0])+(5760*(days-1)) <= j <= (int(turn_living[0])+int(turn_living[1]))+(5760*(days-1)):
        c.execute("INSERT INTO data_month2.light_sys1 (Timestamp, watt_bed,watt_living, watt_kitc) VALUES (%s, %s, %s, %s)",(time_b[j],4,4,0))      
        
    elif  int(turn_kitchen[0])+(5760*(days-1)) <= j <= (int(turn_kitchen[0])+int(turn_kitchen[1]))+(5760*(days-1)) and int(turn_living[0])+(5760*(days-1)) <= j <= (int(turn_living[0])+int(turn_living[1]))+(5760*(days-1)):
        c.execute("INSERT INTO data_month2.light_sys1 (Timestamp, watt_bed,watt_living, watt_kitc) VALUES (%s, %s, %s, %s)",(time_b[j],0,4,2))
        
    elif  int(turn_bed[0])+(5760*(days-1)) <= j <=(int(turn_bed[0])+int(turn_bed[1]))+(5760*(days-1)) and int(turn_kitchen[0])+(5760*(days-1)) <= j <= (int(turn_kitchen[0])+int(turn_kitchen[1]))+(5760*(days-1)):
        c.execute("INSERT INTO data_month2.light_sys1(Timestamp, watt_bed,watt_living, watt_kitc) VALUES (%s, %s, %s, %s)",(time_b[j],4,0,2))
      
    elif  int(turn_bed[0])+(5760*(days-1)) <= j <= (int(turn_bed[0])+int(turn_bed[1]))+(5760*(days-1)):
        c.execute("INSERT INTO data_month2.light_sys1 (Timestamp, watt_bed,watt_living, watt_kitc) VALUES (%s, %s, %s, %s)",(time_b[j],4,0,0))
        
    elif int(turn_living[0])+(5760*(days-1) )<= j <= (int(turn_living[0])+int(turn_living[1]))+(5760*(days-1)):
        c.execute("INSERT INTO data_month2.light_sys1 (Timestamp, watt_bed,watt_living, watt_kitc) VALUES (%s, %s, %s, %s)",(time_b[j],0,4,0))
        
    elif int(turn_kitchen[0]) +(5760*(days-1))<= j <= (int(turn_kitchen[0])+int(turn_kitchen[1]))+(5760*(days-1)):
        c.execute("INSERT INTO data_month2.light_sys1 (Timestamp, watt_bed,watt_living, watt_kitc) VALUES (%s, %s, %s, %s)",(time_b[j],0,0,2))
    else:
        c.execute("INSERT INTO data_month2.light_sys1 (Timestamp, watt_bed,watt_living, watt_kitc) VALUES (%s, %s, %s, %s)",(time_b[j],0,0,0))
            
    j += 1
    conn.commit()
    

print "DONE!"
# Out:
# data_month2.light_sys1 are Empty!!!
#
#
# Days : 0 : Tue
# time to turn-on lamp at bedroom on 21 : 5 : 12 equal to 5060 items
# consuming the lamp 3 hours 5 minutes 57 seconds that equal to 11157 seconds or 743 items
#
# time to turn-on lamp at living-room on 18 : 12 : 2 equal to 4368 items
# consuming the lamp 3 hours 8 minutes 52 seconds that equal to 11332 seconds or 755 items
#
# time to turn-on lamp at kitchen on 18 : 56 : 33 equal to 4546 items
# consuming the lamp 1 hours 2 minutes 34 seconds that equal to 3754 seconds or 250 items
#
#
# Days : 1 : Wed
# time to turn-on lamp at bedroom on 20 : 49 : 49 equal to 4999 items
# consuming the lamp 1 hours 10 minutes 0 seconds that equal to 4200 seconds or 280 items
#
# time to turn-on lamp at living-room on 18 : 22 : 33 equal to 4410 items
# consuming the lamp 3 hours 46 minutes 55 seconds that equal to 13615 seconds or 907 items
#
# time to turn-on lamp at kitchen on 17 : 9 : 27 equal to 4117 items
# consuming the lamp 2 hours 43 minutes 18 seconds that equal to 9798 seconds or 653 items
#
#
# Days : 2 : Thu
# time to turn-on lamp at bedroom on 21 : 18 : 5 equal to 5112 items
# consuming the lamp 3 hours 27 minutes 25 seconds that equal to 12445 seconds or 829 items
#
# time to turn-on lamp at living-room on 17 : 7 : 52 equal to 4111 items
# consuming the lamp 3 hours 22 minutes 35 seconds that equal to 12155 seconds or 810 items
#
# time to turn-on lamp at kitchen on 18 : 34 : 39 equal to 4458 items
# consuming the lamp 1 hours 25 minutes 59 seconds that equal to 5159 seconds or 343 items
#
#
# Days : 3 : Fri
# time to turn-on lamp at bedroom on 21 : 36 : 53 equal to 5187 items
# consuming the lamp 4 hours 46 minutes 4 seconds that equal to 17164 seconds or 1144 items
#
# time to turn-on lamp at living-room on 19 : 13 : 2 equal to 4612 items
# consuming the lamp 4 hours 58 minutes 7 seconds that equal to 17887 seconds or 1192 items
#
# time to turn-on lamp at kitchen on 17 : 8 : 48 equal to 4115 items
# consuming the lamp 2 hours 18 minutes 53 seconds that equal to 8333 seconds or 555 items
#
#
# Days : 4 : Sat
# time to turn-on lamp at bedroom on 21 : 35 : 31 equal to 5182 items
# consuming the lamp 4 hours 4 minutes 21 seconds that equal to 14661 seconds or 977 items
#
# time to turn-on lamp at living-room on 18 : 21 : 30 equal to 4405 items
# consuming the lamp 4 hours 30 minutes 4 seconds that equal to 16204 seconds or 1080 items
#
# time to turn-on lamp at kitchen on 17 : 35 : 49 equal to 4223 items
# consuming the lamp 1 hours 57 minutes 40 seconds that equal to 7060 seconds or 470 items
#
#
# Days : 5 : Sun
# time to turn-on lamp at bedroom on 20 : 22 : 14 equal to 4888 items
# consuming the lamp 1 hours 21 minutes 43 seconds that equal to 4903 seconds or 326 items
#
# time to turn-on lamp at living-room on 18 : 37 : 31 equal to 4470 items
# consuming the lamp 3 hours 14 minutes 38 seconds that equal to 11678 seconds or 778 items
#
# time to turn-on lamp at kitchen on 17 : 48 : 10 equal to 4272 items
# consuming the lamp 1 hours 43 minutes 5 seconds that equal to 6185 seconds or 412 items
#
#
# Days : 6 : Mon
# time to turn-on lamp at bedroom on 20 : 7 : 24 equal to 4829 items
# consuming the lamp 3 hours 18 minutes 46 seconds that equal to 11926 seconds or 795 items
#
# time to turn-on lamp at living-room on 18 : 22 : 14 equal to 4408 items
# consuming the lamp 2 hours 47 minutes 48 seconds that equal to 10068 seconds or 671 items
#
# time to turn-on lamp at kitchen on 17 : 27 : 2 equal to 4188 items
# consuming the lamp 1 hours 17 minutes 29 seconds that equal to 4649 seconds or 309 items
#
#
# Days : 7 : Tue
# time to turn-on lamp at bedroom on 21 : 32 : 53 equal to 5171 items
# consuming the lamp 3 hours 57 minutes 32 seconds that equal to 14252 seconds or 950 items
#
# time to turn-on lamp at living-room on 18 : 41 : 43 equal to 4486 items
# consuming the lamp 4 hours 53 minutes 24 seconds that equal to 17604 seconds or 1173 items
#
# time to turn-on lamp at kitchen on 18 : 46 : 55 equal to 4507 items
# consuming the lamp 2 hours 4 minutes 5 seconds that equal to 7445 seconds or 496 items
#
#
# Days : 8 : Wed
# time to turn-on lamp at bedroom on 22 : 8 : 37 equal to 5314 items
# consuming the lamp 4 hours 58 minutes 55 seconds that equal to 17935 seconds or 1195 items
#
# time to turn-on lamp at living-room on 19 : 57 : 7 equal to 4788 items
# consuming the lamp 3 hours 0 minutes 18 seconds that equal to 10818 seconds or 721 items
#
# time to turn-on lamp at kitchen on 17 : 2 : 24 equal to 4089 items
# consuming the lamp 1 hours 45 minutes 1 seconds that equal to 6301 seconds or 420 items
#
#
# Days : 9 : Thu
# time to turn-on lamp at bedroom on 21 : 14 : 37 equal to 5098 items
# consuming the lamp 4 hours 56 minutes 30 seconds that equal to 17790 seconds or 1186 items
#
# time to turn-on lamp at living-room on 18 : 49 : 26 equal to 4517 items
# consuming the lamp 3 hours 42 minutes 5 seconds that equal to 13325 seconds or 888 items
#
# time to turn-on lamp at kitchen on 18 : 18 : 22 equal to 4393 items
# consuming the lamp 1 hours 27 minutes 43 seconds that equal to 5263 seconds or 350 items
#
#
# Days : 10 : Fri
# time to turn-on lamp at bedroom on 20 : 23 : 1 equal to 4892 items
# consuming the lamp 3 hours 3 minutes 59 seconds that equal to 11039 seconds or 735 items
#
# time to turn-on lamp at living-room on 18 : 29 : 20 equal to 4437 items
# consuming the lamp 3 hours 11 minutes 56 seconds that equal to 11516 seconds or 767 items
#
# time to turn-on lamp at kitchen on 17 : 51 : 59 equal to 4287 items
# consuming the lamp 2 hours 29 minutes 7 seconds that equal to 8947 seconds or 596 items
#
#
# Days : 11 : Sat
# time to turn-on lamp at bedroom on 20 : 5 : 24 equal to 4821 items
# consuming the lamp 1 hours 13 minutes 30 seconds that equal to 4410 seconds or 294 items
#
# time to turn-on lamp at living-room on 18 : 51 : 12 equal to 4524 items
# consuming the lamp 3 hours 0 minutes 49 seconds that equal to 10849 seconds or 723 items
#
# time to turn-on lamp at kitchen on 17 : 57 : 59 equal to 4311 items
# consuming the lamp 1 hours 8 minutes 8 seconds that equal to 4088 seconds or 272 items
#
#
# Days : 12 : Sun
# time to turn-on lamp at bedroom on 21 : 12 : 7 equal to 5088 items
# consuming the lamp 3 hours 11 minutes 55 seconds that equal to 11515 seconds or 767 items
#
# time to turn-on lamp at living-room on 18 : 10 : 11 equal to 4360 items
# consuming the lamp 3 hours 29 minutes 23 seconds that equal to 12563 seconds or 837 items
#
# time to turn-on lamp at kitchen on 19 : 8 : 5 equal to 4592 items
# consuming the lamp 1 hours 21 minutes 18 seconds that equal to 4878 seconds or 325 items
#
#
# Days : 13 : Mon
# time to turn-on lamp at bedroom on 20 : 10 : 48 equal to 4843 items
# consuming the lamp 3 hours 24 minutes 38 seconds that equal to 12278 seconds or 818 items
#
# time to turn-on lamp at living-room on 19 : 32 : 59 equal to 4691 items
# consuming the lamp 3 hours 45 minutes 5 seconds that equal to 13505 seconds or 900 items
#
# time to turn-on lamp at kitchen on 18 : 27 : 14 equal to 4428 items
# consuming the lamp 2 hours 21 minutes 52 seconds that equal to 8512 seconds or 567 items
#
#
# Days : 14 : Tue
# time to turn-on lamp at bedroom on 20 : 4 : 19 equal to 4817 items
# consuming the lamp 4 hours 41 minutes 34 seconds that equal to 16894 seconds or 1126 items
#
# time to turn-on lamp at living-room on 17 : 7 : 33 equal to 4110 items
# consuming the lamp 5 hours 41 minutes 4 seconds that equal to 20464 seconds or 1364 items
#
# time to turn-on lamp at kitchen on 17 : 50 : 46 equal to 4283 items
# consuming the lamp 2 hours 33 minutes 35 seconds that equal to 9215 seconds or 614 items
#
#
# Days : 15 : Wed
# time to turn-on lamp at bedroom on 20 : 3 : 40 equal to 4814 items
# consuming the lamp 3 hours 52 minutes 10 seconds that equal to 13930 seconds or 928 items
#
# time to turn-on lamp at living-room on 18 : 23 : 3 equal to 4412 items
# consuming the lamp 4 hours 46 minutes 37 seconds that equal to 17197 seconds or 1146 items
#
# time to turn-on lamp at kitchen on 17 : 46 : 13 equal to 4264 items
# consuming the lamp 1 hours 1 minutes 8 seconds that equal to 3668 seconds or 244 items
#
#
# Days : 16 : Thu
# time to turn-on lamp at bedroom on 21 : 22 : 52 equal to 5131 items
# consuming the lamp 4 hours 15 minutes 8 seconds that equal to 15308 seconds or 1020 items
#
# time to turn-on lamp at living-room on 17 : 51 : 26 equal to 4285 items
# consuming the lamp 4 hours 59 minutes 24 seconds that equal to 17964 seconds or 1197 items
#
# time to turn-on lamp at kitchen on 17 : 42 : 11 equal to 4248 items
# consuming the lamp 1 hours 28 minutes 11 seconds that equal to 5291 seconds or 352 items
#
#
# Days : 17 : Fri
# time to turn-on lamp at bedroom on 21 : 58 : 57 equal to 5275 items
# consuming the lamp 4 hours 22 minutes 7 seconds that equal to 15727 seconds or 1048 items
#
# time to turn-on lamp at living-room on 17 : 0 : 7 equal to 4080 items
# consuming the lamp 3 hours 40 minutes 8 seconds that equal to 13208 seconds or 880 items
#
# time to turn-on lamp at kitchen on 17 : 3 : 34 equal to 4094 items
# consuming the lamp 1 hours 21 minutes 21 seconds that equal to 4881 seconds or 325 items
#
#
# Days : 18 : Sat
# time to turn-on lamp at bedroom on 21 : 47 : 10 equal to 5228 items
# consuming the lamp 4 hours 43 minutes 41 seconds that equal to 17021 seconds or 1134 items
#
# time to turn-on lamp at living-room on 18 : 48 : 57 equal to 4515 items
# consuming the lamp 3 hours 11 minutes 49 seconds that equal to 11509 seconds or 767 items
#
# time to turn-on lamp at kitchen on 17 : 11 : 52 equal to 4127 items
# consuming the lamp 2 hours 4 minutes 29 seconds that equal to 7469 seconds or 497 items
#
#
# Days : 19 : Sun
# time to turn-on lamp at bedroom on 20 : 24 : 17 equal to 4897 items
# consuming the lamp 3 hours 40 minutes 5 seconds that equal to 13205 seconds or 880 items
#
# time to turn-on lamp at living-room on 18 : 10 : 28 equal to 4361 items
# consuming the lamp 4 hours 49 minutes 6 seconds that equal to 17346 seconds or 1156 items
#
# time to turn-on lamp at kitchen on 17 : 38 : 14 equal to 4232 items
# consuming the lamp 1 hours 24 minutes 28 seconds that equal to 5068 seconds or 337 items
#
#
# Days : 20 : Mon
# time to turn-on lamp at bedroom on 20 : 43 : 27 equal to 4973 items
# consuming the lamp 4 hours 2 minutes 18 seconds that equal to 14538 seconds or 969 items
#
# time to turn-on lamp at living-room on 17 : 7 : 20 equal to 4109 items
# consuming the lamp 3 hours 47 minutes 29 seconds that equal to 13649 seconds or 909 items
#
# time to turn-on lamp at kitchen on 17 : 45 : 17 equal to 4261 items
# consuming the lamp 1 hours 49 minutes 2 seconds that equal to 6542 seconds or 436 items
#
#
# Days : 21 : Tue
# time to turn-on lamp at bedroom on 21 : 1 : 49 equal to 5047 items
# consuming the lamp 3 hours 23 minutes 33 seconds that equal to 12213 seconds or 814 items
#
# time to turn-on lamp at living-room on 18 : 22 : 53 equal to 4411 items
# consuming the lamp 3 hours 33 minutes 28 seconds that equal to 12808 seconds or 853 items
#
# time to turn-on lamp at kitchen on 19 : 34 : 33 equal to 4698 items
# consuming the lamp 1 hours 28 minutes 44 seconds that equal to 5324 seconds or 354 items
#
#
# Days : 22 : Wed
# time to turn-on lamp at bedroom on 20 : 28 : 2 equal to 4912 items
# consuming the lamp 4 hours 35 minutes 2 seconds that equal to 16502 seconds or 1100 items
#
# time to turn-on lamp at living-room on 18 : 31 : 49 equal to 4447 items
# consuming the lamp 3 hours 5 minutes 9 seconds that equal to 11109 seconds or 740 items
#
# time to turn-on lamp at kitchen on 17 : 20 : 35 equal to 4162 items
# consuming the lamp 1 hours 51 minutes 32 seconds that equal to 6692 seconds or 446 items
#
#
# Days : 23 : Thu
# time to turn-on lamp at bedroom on 21 : 29 : 40 equal to 5158 items
# consuming the lamp 2 hours 3 minutes 14 seconds that equal to 7394 seconds or 492 items
#
# time to turn-on lamp at living-room on 17 : 47 : 18 equal to 4269 items
# consuming the lamp 4 hours 4 minutes 3 seconds that equal to 14643 seconds or 976 items
#
# time to turn-on lamp at kitchen on 17 : 33 : 44 equal to 4214 items
# consuming the lamp 1 hours 3 minutes 37 seconds that equal to 3817 seconds or 254 items
#
#
# Days : 24 : Fri
# time to turn-on lamp at bedroom on 21 : 15 : 43 equal to 5102 items
# consuming the lamp 3 hours 39 minutes 36 seconds that equal to 13176 seconds or 878 items
#
# time to turn-on lamp at living-room on 18 : 41 : 18 equal to 4485 items
# consuming the lamp 3 hours 53 minutes 52 seconds that equal to 14032 seconds or 935 items
#
# time to turn-on lamp at kitchen on 18 : 59 : 37 equal to 4558 items
# consuming the lamp 2 hours 54 minutes 11 seconds that equal to 10451 seconds or 696 items
#
#
# Days : 25 : Sat
# time to turn-on lamp at bedroom on 21 : 13 : 4 equal to 5092 items
# consuming the lamp 2 hours 53 minutes 54 seconds that equal to 10434 seconds or 695 items
#
# time to turn-on lamp at living-room on 18 : 45 : 20 equal to 4501 items
# consuming the lamp 5 hours 45 minutes 30 seconds that equal to 20730 seconds or 1382 items
#
# time to turn-on lamp at kitchen on 18 : 45 : 46 equal to 4503 items
# consuming the lamp 2 hours 58 minutes 51 seconds that equal to 10731 seconds or 715 items
#
#
# Days : 26 : Sun
# time to turn-on lamp at bedroom on 20 : 51 : 42 equal to 5006 items
# consuming the lamp 4 hours 41 minutes 57 seconds that equal to 16917 seconds or 1127 items
#
# time to turn-on lamp at living-room on 18 : 50 : 3 equal to 4520 items
# consuming the lamp 4 hours 31 minutes 47 seconds that equal to 16307 seconds or 1087 items
#
# time to turn-on lamp at kitchen on 18 : 29 : 42 equal to 4438 items
# consuming the lamp 2 hours 2 minutes 10 seconds that equal to 7330 seconds or 488 items
#
#
# Days : 27 : Mon
# time to turn-on lamp at bedroom on 20 : 42 : 40 equal to 4970 items
# consuming the lamp 3 hours 19 minutes 15 seconds that equal to 11955 seconds or 797 items
#
# time to turn-on lamp at living-room on 18 : 34 : 50 equal to 4459 items
# consuming the lamp 5 hours 45 minutes 49 seconds that equal to 20749 seconds or 1383 items
#
# time to turn-on lamp at kitchen on 17 : 57 : 2 equal to 4308 items
# consuming the lamp 2 hours 10 minutes 18 seconds that equal to 7818 seconds or 521 items
#
#
# Days : 28 : Tue
# time to turn-on lamp at bedroom on 21 : 2 : 17 equal to 5049 items
# consuming the lamp 4 hours 24 minutes 49 seconds that equal to 15889 seconds or 1059 items
#
# time to turn-on lamp at living-room on 18 : 16 : 26 equal to 4385 items
# consuming the lamp 4 hours 17 minutes 36 seconds that equal to 15456 seconds or 1030 items
#
# time to turn-on lamp at kitchen on 17 : 31 : 29 equal to 4205 items
# consuming the lamp 1 hours 44 minutes 40 seconds that equal to 6280 seconds or 418 items
#
#
# Days : 29 : Wed
# time to turn-on lamp at bedroom on 21 : 35 : 32 equal to 5182 items
# consuming the lamp 3 hours 50 minutes 27 seconds that equal to 13827 seconds or 921 items
#
# time to turn-on lamp at living-room on 17 : 19 : 8 equal to 4156 items
# consuming the lamp 3 hours 3 minutes 41 seconds that equal to 11021 seconds or 734 items
#
# time to turn-on lamp at kitchen on 17 : 39 : 54 equal to 4239 items
# consuming the lamp 1 hours 14 minutes 39 seconds that equal to 4479 seconds or 298 items
#
#
# Days : 30 : Thu
# time to turn-on lamp at bedroom on 20 : 36 : 55 equal to 4947 items
# consuming the lamp 4 hours 44 minutes 18 seconds that equal to 17058 seconds or 1137 items
#
# time to turn-on lamp at living-room on 18 : 52 : 49 equal to 4531 items
# consuming the lamp 5 hours 25 minutes 10 seconds that equal to 19510 seconds or 1300 items
#
# time to turn-on lamp at kitchen on 17 : 54 : 14 equal to 4296 items
# consuming the lamp 2 hours 18 minutes 25 seconds that equal to 8305 seconds or 553 items
#
# DONE!

# %%
import matplotlib.pyplot as plt
# %matplotlib inline  


# query = "SELECT watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
query = "SELECT * FROM data_month2.light_sys1 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[4000],time_b[6500])
df = pd.read_sql(query, conn, index_col=['Timestamp'])
fig, ax = plt.subplots()
ax.set_title('data_month2.IRON')
df.plot(ax=ax )
plt.show()
df.to_csv('file.csv')
