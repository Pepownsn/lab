# %% [markdown]
# ## data_month3
# #### COMPUTER | psu 600W + LED 23" |

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random


d = 31
time_a = pd.date_range('2016-12-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-12-01 00:00:14', periods=5760*d, freq='15S')
# print time_b

conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()


####### set databases to empty #########
query_empty = """truncate table data_month3.Computer""" 
c.execute(query_empty)
print " data_month2.Computer are Empty!!! \n"

query = "SELECT watt FROM collected_info.4_Computer WHERE no >= '%s'   AND no <= '%s'; "% (0,1240)
df = pd.read_sql(query, conn)
# print df.watt[5]

#### Random the turning-on time appliances
def rand_turnon():
    duration_sec =  random.randint(10, 59)
    duration_min =  random.randint(10, 59)
    duration_hour1 = ['18'] * 4+['19'] * 6 + ['20'] * 46 + ['21'] * 41 +['22'] * 3     #SET Start 7-10 pm.
    duration_hour = random.choice(duration_hour1)     
    if 0 < duration_sec <= 15:
        k = 0
    elif 15 < duration_sec <= 30:
        k = 1
    elif 30 < duration_sec <= 45:
        k = 2
    else:
        k = 3
    off_item = (int(duration_hour)*240) + (int(duration_min)*4)+ k 
    print "time to turn-on appliacne on",duration_hour,":",duration_min,":",duration_sec,"equal to",off_item,"items"
    return off_item

 
#### Random the off-duration appliances 
def rand_duration():
    duration_sec =  random.randint(10, 59)
    duration_min =  random.randint(10, 59)
    duration_hour1 = ['1'] * 9 + ['2'] * 59 + ['3'] * 30 +['4'] * 1+['5'] * 1   
    duration_hour = random.choice(duration_hour1)   
    seconds = (int(duration_hour)*3600)+(duration_min*60)+duration_sec
    no_item = seconds/15
    print "consuming the appliance", duration_hour,"hours",duration_min,"minutes",duration_sec,"seconds that equal to",seconds,"seconds or",no_item,"items"
    return no_item

days = 0
j = 0
i = 0
print "\nDays :",days ,":",time_b[j].strftime('%a')
off_item = rand_turnon()  
no_item = rand_duration()  

while (j <= (5760*d)-1):  
    c.execute("INSERT INTO  data_month3.Computer (Timestamp, watt) VALUES (%s, %s)",(time_b[j],0))
    conn.commit()
    j += 1 
    
    while (off_item+(5760*(days)) <= j <= (no_item+off_item)+(5760*(days))):                   
        c.execute("INSERT INTO data_month3.Computer (Timestamp, watt) VALUES (%s, %s)",(time_b[j],df.watt[i]))
        conn.commit()
        i += 1 
        j += 1
        if (j == (no_item+off_item)+(5760*(days))):
            days +=1
            print "\nDays :",days ,":",time_b[j].strftime('%a')
            off_item = rand_turnon()  
            no_item = rand_duration() 
            i= 0   
                    
print "DONE!"
# Out:
#  data_month2.Computer are Empty!!!
#
#
# Days : 0 : Thu
# time to turn-on appliacne on 21 : 54 : 45 equal to 5258 items
# consuming the appliance 2 hours 16 minutes 21 seconds that equal to 8181 seconds or 545 items
#
# Days : 1 : Fri
# time to turn-on appliacne on 20 : 44 : 46 equal to 4979 items
# consuming the appliance 1 hours 38 minutes 20 seconds that equal to 5900 seconds or 393 items
#
# Days : 2 : Fri
# time to turn-on appliacne on 21 : 14 : 20 equal to 5097 items
# consuming the appliance 4 hours 50 minutes 36 seconds that equal to 17436 seconds or 1162 items
#
# Days : 3 : Sun
# time to turn-on appliacne on 20 : 26 : 21 equal to 4905 items
# consuming the appliance 3 hours 41 minutes 23 seconds that equal to 13283 seconds or 885 items
#
# Days : 4 : Mon
# time to turn-on appliacne on 20 : 27 : 59 equal to 4911 items
# consuming the appliance 2 hours 10 minutes 53 seconds that equal to 7853 seconds or 523 items
#
# Days : 5 : Mon
# time to turn-on appliacne on 20 : 28 : 29 equal to 4913 items
# consuming the appliance 2 hours 42 minutes 31 seconds that equal to 9751 seconds or 650 items
#
# Days : 6 : Tue
# time to turn-on appliacne on 21 : 50 : 43 equal to 5242 items
# consuming the appliance 2 hours 18 minutes 19 seconds that equal to 8299 seconds or 553 items
#
# Days : 7 : Thu
# time to turn-on appliacne on 18 : 51 : 21 equal to 4525 items
# consuming the appliance 2 hours 19 minutes 15 seconds that equal to 8355 seconds or 557 items
#
# Days : 8 : Thu
# time to turn-on appliacne on 18 : 14 : 45 equal to 4378 items
# consuming the appliance 2 hours 33 minutes 44 seconds that equal to 9224 seconds or 614 items
#
# Days : 9 : Fri
# time to turn-on appliacne on 21 : 29 : 44 equal to 5158 items
# consuming the appliance 2 hours 10 minutes 12 seconds that equal to 7812 seconds or 520 items
#
# Days : 10 : Sat
# time to turn-on appliacne on 21 : 36 : 42 equal to 5186 items
# consuming the appliance 3 hours 18 minutes 50 seconds that equal to 11930 seconds or 795 items
#
# Days : 11 : Mon
# time to turn-on appliacne on 21 : 51 : 57 equal to 5247 items
# consuming the appliance 2 hours 20 minutes 33 seconds that equal to 8433 seconds or 562 items
#
# Days : 12 : Tue
# time to turn-on appliacne on 20 : 48 : 21 equal to 4993 items
# consuming the appliance 2 hours 38 minutes 13 seconds that equal to 9493 seconds or 632 items
#
# Days : 13 : Tue
# time to turn-on appliacne on 20 : 42 : 55 equal to 4971 items
# consuming the appliance 2 hours 52 minutes 13 seconds that equal to 10333 seconds or 688 items
#
# Days : 14 : Wed
# time to turn-on appliacne on 20 : 47 : 42 equal to 4990 items
# consuming the appliance 1 hours 40 minutes 13 seconds that equal to 6013 seconds or 400 items
#
# Days : 15 : Thu
# time to turn-on appliacne on 20 : 23 : 54 equal to 4895 items
# consuming the appliance 2 hours 12 minutes 24 seconds that equal to 7944 seconds or 529 items
#
# Days : 16 : Fri
# time to turn-on appliacne on 20 : 38 : 11 equal to 4952 items
# consuming the appliance 3 hours 19 minutes 49 seconds that equal to 11989 seconds or 799 items
#
# Days : 17 : Sat
# time to turn-on appliacne on 21 : 15 : 59 equal to 5103 items
# consuming the appliance 2 hours 53 minutes 46 seconds that equal to 10426 seconds or 695 items
#
# Days : 18 : Mon
# time to turn-on appliacne on 22 : 38 : 11 equal to 5432 items
# consuming the appliance 1 hours 25 minutes 17 seconds that equal to 5117 seconds or 341 items
#
# Days : 19 : Tue
# time to turn-on appliacne on 20 : 42 : 44 equal to 4970 items
# consuming the appliance 2 hours 27 minutes 33 seconds that equal to 8853 seconds or 590 items
#
# Days : 20 : Tue
# time to turn-on appliacne on 18 : 45 : 59 equal to 4503 items
# consuming the appliance 2 hours 55 minutes 44 seconds that equal to 10544 seconds or 702 items
#
# Days : 21 : Wed
# time to turn-on appliacne on 20 : 19 : 21 equal to 4877 items
# consuming the appliance 2 hours 31 minutes 52 seconds that equal to 9112 seconds or 607 items
#
# Days : 22 : Thu
# time to turn-on appliacne on 20 : 42 : 16 equal to 4969 items
# consuming the appliance 2 hours 48 minutes 41 seconds that equal to 10121 seconds or 674 items
#
# Days : 23 : Fri
# time to turn-on appliacne on 21 : 23 : 24 equal to 5133 items
# consuming the appliance 3 hours 48 minutes 24 seconds that equal to 13704 seconds or 913 items
#
# Days : 24 : Sun
# time to turn-on appliacne on 20 : 20 : 11 equal to 4880 items
# consuming the appliance 2 hours 50 minutes 43 seconds that equal to 10243 seconds or 682 items
#
# Days : 25 : Sun
# time to turn-on appliacne on 21 : 29 : 11 equal to 5156 items
# consuming the appliance 2 hours 15 minutes 35 seconds that equal to 8135 seconds or 542 items
#
# Days : 26 : Mon
# time to turn-on appliacne on 21 : 25 : 46 equal to 5143 items
# consuming the appliance 2 hours 58 minutes 16 seconds that equal to 10696 seconds or 713 items
#
# Days : 27 : Wed
# time to turn-on appliacne on 21 : 18 : 48 equal to 5115 items
# consuming the appliance 1 hours 46 minutes 48 seconds that equal to 6408 seconds or 427 items
#
# Days : 28 : Wed
# time to turn-on appliacne on 20 : 57 : 33 equal to 5030 items
# consuming the appliance 3 hours 52 minutes 51 seconds that equal to 13971 seconds or 931 items
#
# Days : 29 : Fri
# time to turn-on appliacne on 18 : 29 : 22 equal to 4437 items
# consuming the appliance 3 hours 37 minutes 57 seconds that equal to 13077 seconds or 871 items
#
# Days : 30 : Fri
# time to turn-on appliacne on 19 : 58 : 44 equal to 4794 items
# consuming the appliance 2 hours 27 minutes 49 seconds that equal to 8869 seconds or 591 items
#
# Days : 31 : Sat
# time to turn-on appliacne on 20 : 59 : 57 equal to 5039 items
# consuming the appliance 2 hours 23 minutes 49 seconds that equal to 8629 seconds or 575 items
# DONE!

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
# %matplotlib inline  


d = 31
time_a = pd.date_range('2016-12-01 00:00:00', periods=5760*d, freq='15S')
# print time_a
time_b = pd.date_range('2016-12-01 00:00:14', periods=5760*d, freq='15S')
# print time_b
# query = "SELECT watt FROM device.aircont WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; "% (time_a[0],time_b[j-1])
query = "SELECT Timestamp,watt FROM data_month3.Computer WHERE Timestamp >= '%s' AND Timestamp <= '%s'; "% (time_a[0],time_b[5760*10])
df = pd.read_sql(query, conn, index_col=['Timestamp'])
fig,ax = plt.subplots()
ax.set_title('data_month3.Computer ')
df.plot(ax=ax )
plt.show()
